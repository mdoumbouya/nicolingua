# %%
from pathlib import Path
import csv
from itertools import groupby
import h5py
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.svm import SVC
# from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import random
import matplotlib
from matplotlib import pyplot as plt
import torchaudio

# %% [markdown]
# # Configuration & Utilities

# %%
random.seed(42)
COLORS = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
ANNOTATIONS_PATH = "/media/xtrem/data/experiments/nicolingua-0001-language-id/language-id-annotations/metadata.csv"
FEATURE_DIRS = [
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-z',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-z'
]


AUDIO_BASE_DIR = "/media/xtrem/data/experiments/nicolingua-0001-language-id/language-id-annotations/audio_samples"
dropout_p = 0.75
fc_dropout_p = 0.6

RESULTS_DIR = f'results_010_gn_lang_classification__spectrogram_dropout_{dropout_p}__fc_dropout_{fc_dropout_p}'

GPU_ID = 0

# %%
annotation_specification = {
    0: {
        'id': 0,
        'label': "maninka",
        'required_tags': set(['ct-speech', 'lng-maninka']),
        'forbidden_tags':  set(['lng-susu', 'lng-pular'])
    },
    1: {
        'id': 1,
        'label': "susu",
        'required_tags': set(['ct-speech', 'lng-susu']),
        'forbidden_tags':  set(['lng-maninka', 'lng-pular'])
    },
    2: {
        'id': 2,
        'label': "pular",
        'required_tags': set(['ct-speech', 'lng-pular']),
        'forbidden_tags':  set(['lng-susu', 'lng-maninka'])
    }
}

# %%
bias_category_specification = [
    {
        "category": "utterance",
        "subcategories": [
            {
                "subcategory": "verbal_nod",
                "tags": set(["utt-verbal-nod"])
            },
            {
                "subcategory": "multilingual",
                "tags": set(["utt-multi-lingual", "utt-multi-lingual-named-endity"])
            }
        ]
    },
    {
        "category": "speaker_count",
        "subcategories": [
            {
                "subcategory": "single",
                "tags": set(["spkr-single"])
            },
            {
                "subcategory": "multiple",
                "tags": set(["spkr-mult", "spkr-multi"])
            }
        ]
    },
    {
        "category": "gender",
        "subcategories": [
            {
                "subcategory": "male",
                "tags": set(["spkr-male"])
            },
            {
                "subcategory": "female",
                "tags": set(["spkr-female"])
            },
        ]
    },
    {
        "category": "language",
        "subcategories": [
            {
                "subcategory": "susu",
                "tags": set(["lng-susu"])
            },
            {
                "subcategory": "maninka",
                "tags": set(["lng-maninka"])
            },
            {
                "subcategory": "pular",
                "tags": set(["lng-pular"])
            }
        ]
    },
    {
        "category": "channel",
        "subcategories": [
            {
                "subcategory": "telephone",
                "tags": set(["ct-telephone"])
            },
            {
                "subcategory": "noise",
                "tags": set(["ct-noise"])
            },
            {
                "subcategory": "music",
                "tags": set(["ct-fg-music", "ct-tr-music", "ct-bg-music"])
            }
        ]
    }
]

flat_bias_category_specification = {}

for c in bias_category_specification:
    for sc in c['subcategories']:
        k = f"{c['category']}_{sc['subcategory']}"
        flat_bias_category_specification[k] = sc['tags']

_ = [print(f"{k}: {v}") for k,v in flat_bias_category_specification.items()]
# Out:
# utterance_verbal_nod: {'utt-verbal-nod'}
# utterance_multilingual: {'utt-multi-lingual-named-endity', 'utt-multi-lingual'}
# speaker_count_single: {'spkr-single'}
# speaker_count_multiple: {'spkr-mult', 'spkr-multi'}
# gender_male: {'spkr-male'}
# gender_female: {'spkr-female'}
# language_susu: {'lng-susu'}
# language_maninka: {'lng-maninka'}
# language_pular: {'lng-pular'}
# channel_telephone: {'ct-telephone'}
# channel_noise: {'ct-noise'}
# channel_music: {'ct-fg-music', 'ct-tr-music', 'ct-bg-music'}

# %%
def to_user_friendly_feature_name(fv_name):
    name = fv_name \
        .replace("features-", "") \
        .replace("wav2vec_", "") \
        .replace("average", "avg") \
        .replace("timestep", "T") \
        .replace("c.", "Context") \
        .replace("z.", "Latent")
    return name

# %% [markdown]
# # Load annotations

# %%
def load_annotations(a_file_path, a_specification):
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for row in reader:
            tag_set = set([t.strip() for t in row['tags'].split(";")])
            for label in annotation_specification.keys():
                spec = annotation_specification[label]
                if spec['required_tags'].issubset(tag_set):
                    if spec['forbidden_tags'].isdisjoint(tag_set):
                        yield row['file'], label, tag_set
                        break

data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
audio_files, audio_labels, audio_tags = zip(*data)

# %% [markdown]
# ## Inspect label counts

# %%
def inspect_label_counts():
    for label in annotation_specification:
        count = len([l for l in audio_labels if l == label])
        print("{:10} ({}): {}".format(
            annotation_specification[label]['label'],
            label, 
            count
        ))
inspect_label_counts()
# Out:
# maninka    (0): 114
# susu       (1): 32
# pular      (2): 28

# %% [markdown]
# ## Balance data

# %%
count_per_class = 28
data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
balanced_data = []
for label in annotation_specification:
    balanced_data.extend([d for d in data if d[1] == label][:count_per_class])
audio_files, audio_labels, audio_tags = zip(*balanced_data)

# %%
inspect_label_counts()
# Out:
# maninka    (0): 28
# susu       (1): 28
# pular      (2): 28

# %% [markdown]
# ## Inspect bias category counts in balanded data

# %%
def inspect_bias_category_counts():
    for name, tags in flat_bias_category_specification.items():
        count = len([ts for ts in audio_tags if len(tags.intersection(ts))>0])
        print(name, count, "/", len(audio_tags))
            
inspect_bias_category_counts()
# Out:
# utterance_verbal_nod 48 / 84
# utterance_multilingual 21 / 84
# speaker_count_single 25 / 84
# speaker_count_multiple 58 / 84
# gender_male 81 / 84
# gender_female 15 / 84
# language_susu 28 / 84
# language_maninka 28 / 84
# language_pular 28 / 84
# channel_telephone 27 / 84
# channel_noise 21 / 84
# channel_music 24 / 84

# %% [markdown]
# # Prepare 10 cross validation folds

# %%
TRAIN_PERCENT = .6
FOLD_COUNT = 10

n = len(audio_files)
n_train = int(np.ceil(n * .6))
n_test = n - n_train
all_indices = range(n)

cv_folds = {}
train_count_by_index = {i:0 for i in all_indices}
test_count_by_index = {i:0 for i in all_indices}

for fold_index in range(FOLD_COUNT):
    fold_rsampler = np.random.RandomState(seed=fold_index)
    train_index_set = set(fold_rsampler.choice(all_indices, n_train, replace=False))
    test_index_set = set(all_indices).difference(train_index_set)
        
    cv_folds[fold_index] = {
        'train_indices': sorted(list(train_index_set)),
        'test_indices': sorted(list(test_index_set)),
    }

# %% [markdown]
# # Load features

# %%
def load_features(audio_files, features_input_dir):
    id_list = []
    features_list = []

    for audio_file_name in audio_files:
        feature_file_name = audio_file_name.replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            # features = pool_feature_last_seq(features)
            features_list.append(features)
    return features_list


def load_spectrogram_features(audio_files):
    id_list = []
    features_list = []

    for audio_file_name in audio_files:
        audio_file_path = Path(AUDIO_BASE_DIR) / audio_file_name

        waveform, sample_rate = torchaudio.load(audio_file_path)
        specgram = torchaudio.transforms.MelSpectrogram()(waveform).numpy()
        
        assert specgram.shape[0] == 1
        specgram = specgram[0, :, :].T
        
        features_list.append(specgram)
        
    return features_list

# %%
raw_features = {}
#for feature_dir in FEATURE_DIRS:
#    feature_name = Path(feature_dir).stem
#    raw_features[feature_name] = load_features(audio_files, feature_dir)
    
    
raw_features['spectrogram'] = load_spectrogram_features(audio_files)

# %%
len(raw_features['spectrogram'])
# Out:
# 84

# %% [markdown]
# ## Inspect feature shapes

# %%
for feature_name in raw_features.keys():
    print("feature_name: {}. feature shape: {}".format(
        to_user_friendly_feature_name(feature_name),
        raw_features[feature_name][0].shape
    ))
# Out:
# feature_name: spectrogram. feature shape: (2401, 128)

# %% [markdown]
# ## Extract feature vectors

# %%
def extract_last_timestep_features(raw_features):
    return raw_features[-1, :]

def extract_neuron_average_features(raw_features):
    return np.mean(raw_features, axis=0)

def identity(x):
    return x

feature_extractors = {
    'last_timestep': extract_last_timestep_features,
    'neuron_average': extract_neuron_average_features,
    'raw_features': identity
}

# %%
feature_vectors = {}
for feature_name in raw_features.keys():
    for feature_extractor_name in feature_extractors.keys():
        fv_name = f"{feature_name}__{feature_extractor_name}"
        feature_vectors[fv_name] = []
        for f in raw_features[feature_name]:
            feature_vectors[fv_name].append(
                feature_extractors[feature_extractor_name](f)
            )
            
        feature_vectors[fv_name] = np.array(feature_vectors[fv_name])

# %% [markdown]
# ## Inspect feature vectors

# %%
for fvname in feature_vectors.keys():
    print(fvname, feature_vectors[fvname][0].shape)
# Out:
# spectrogram__last_timestep (128,)
# spectrogram__neuron_average (128,)
# spectrogram__raw_features (2401, 128)

# %% [markdown]
# # Classification Models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
class LangIdCNN_Mean2_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_Mean2_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=9, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x
    

class LangIdCNN_Mean2_FCD_Spectrogram(nn.Module):
    def __init__(self):
        super(LangIdCNN_Mean2_FCD_Spectrogram, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=128, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=9, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x

# %% [markdown]
# # Train Classification Models

# %%
def get_data_for_fold(fold_id, feature_name, batch_size):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']    

    train_x = np.take(raw_features[feature_name], train_indices, axis=0)
    train_y = np.take(audio_labels, train_indices, axis=0)
    train_tags = np.take(audio_tags, train_indices, axis=0)
    train_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        train_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in train_tags]

    test_x = np.take(raw_features[feature_name], test_indices, axis=0)
    test_y = np.take(audio_labels, test_indices, axis=0)
    test_tags = np.take(audio_tags, test_indices, axis=0)
    test_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        test_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in test_tags]
        
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

def get_audio_files_for_fold(fold_id):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']
    
    train_files = np.take(audio_files, train_indices, axis=0)
    test_files = np.take(audio_files, test_indices, axis=0)
    
    return train_files, test_files
    

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name, batch_size)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y)
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y)
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
l2 = nn.PairwiseDistance(p=2)
margin = 1

# See:
# http://caffe.berkeleyvision.org/doxygen/classcaffe_1_1ContrastiveLossLayer.html#details
# http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf

def contrastive_loss(representations, labels):
    normalized_reps = F.normalize(representations, dim=1)
    
    loss = 0
    n = 0
    for i in range(normalized_reps.shape[0]):
        for j in range(normalized_reps.shape[0]):
            d = l2(
                normalized_reps[i].view(1, -1), 
                normalized_reps[j].view(1, -1)
            )
            if labels[i] == labels[j]:
                loss += torch.square(d)
            else:
                loss += torch.square(torch.max(
                    torch.tensor([margin-d, 0]).to(representations.device)
                ))
            
            n+=1
            
    loss = loss / (2*n)
    
    return loss[0]

# %%
def save_model(model, optimizer, fold_id, feature_name, epoch):
    model_name =  model.__class__.__name__
    
    save_dir = Path(f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}_checkpoints")
    save_path = save_dir / f"{epoch:04}.pt"
    
    save_dir.mkdir(parents=True, exist_ok=True)
    
    torch.save(
        {
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'fold_id': fold_id,
            'feature_name': feature_name,
            'model_name':  model_name,
            'dropout_p': dropout_p,
            'fc_dropout_p': fc_dropout_p
        }, 
        save_path
    )

# %%
def train_on_fold(model_class, fold_id, feature_name, batch_size, epochs, use_contrastive_term):
    device = torch.device(f"cuda:{GPU_ID}")
    torch.manual_seed(0)
    results = {}
    
    model = model_class().to(device)

    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    # print(summary(model_class(), torch.zeros((10, 2998, 512)), show_input=False))
    print(summary(model_class(), torch.zeros((10, 2401, 128)), show_input=False))

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0
        pred_train_classes = []
        true_train_classes = []

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
            
            optimizer.zero_grad()
            representations, outputs = model(x)
            pred_train_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )
            true_train_classes.extend(y.cpu().numpy())
            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += 0.1 * contrastive_loss(representations, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_n = len(true_train_classes)
        
        train_loss = train_loss/len(train_loader)
        train_acc = sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes)
        train_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes, sample_weight=sw)
            for category, sw in train_bias_category_labels.items()
        }
        

        pred_test_logits = []
        
        pred_test_classes = []
        true_test_classes = []
        
        model.eval()
        test_loss = 0
        for batch_idx, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            
            representations, outputs = model(x)
            
            pred_test_logits.extend(outputs.detach().cpu().numpy())

            pred_test_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )

            true_test_classes.extend(y.cpu().numpy())

            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += contrastive_loss(representations, y)
                
            test_loss += loss.item()


        test_n = len(true_test_classes)
        
        test_loss = test_loss / len(test_loader)
        test_acc = sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes)
        test_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes, sample_weight=sw)
            for category, sw in test_bias_category_labels.items()
        }

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_loss:0.4}. Test Loss: {test_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
        results[epoch] = {
            'epoch': epoch,
            'train_loss': train_loss,
            'test_loss': test_loss,
            'train_acc': train_acc,
            'test_acc': test_acc,
            'train_n': train_n,
            'test_n': test_n,
            'test_logits': pred_test_logits,
            'test_true_classes': true_test_classes
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))
            
        save_model(model, optimizer, fold_id, feature_name, epoch)
        
    del model
    return results

# %%
import csv
from pathlib import Path

def write_epoch_test_logits(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        train_audio_files, test_audio_files = get_audio_files_for_fold(fold_index)
        
        for epoch in sorted(result_entry['epochs'].keys()):
            
            parent_dir = Path(f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}_data")
            parent_dir.mkdir(parents=True, exist_ok=True)

            file_name = parent_dir / f"epoch_{epoch:04}.csv"
            with open(file_name, "w") as f:
                writer = csv.DictWriter(f, fieldnames=["fold_id", "datum_index", "datum_name", "true_class_id", "logits"])
                writer.writeheader()
                
                test_logits = result_entry['epochs'][epoch]["test_logits"]
                test_true_classes = result_entry['epochs'][epoch]["test_true_classes"]
                
                for datum_index in range(len(test_logits)):
                    writer.writerow({
                        "fold_id": fold_index,
                        "datum_index": datum_index,
                        "datum_name": test_audio_files[datum_index],
                        "true_class_id": test_true_classes[datum_index],
                        "logits": test_logits[datum_index]
                    })
                

            annotation_specification.keys()

            field_names = ["index", "fname", "logits"]

            fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            fieldnames.remove("test_logits") # logged separately, differently
            fieldnames.remove("test_true_classes") # logged separately, differently
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='ignore')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
model_classes = [
    LangIdCNN_Mean2_FCD_Spectrogram,
    # LangIdCNN_Mean2_FCD,
]



for model_class in model_classes:
    all_folds_results = []
    for fold_index in cv_folds:
        for feature_name in ['spectrogram']:
            use_contrastive_term = "Contrastive" in model_class.__name__
            
            print(f"{model_class.__name__} using {feature_name} on fold#{fold_index}. Contrastive: {use_contrastive_term}")
            resutls = train_on_fold(model_class, fold_index, feature_name, batch_size=100, epochs=1000, use_contrastive_term=use_contrastive_term)
            all_folds_results.append({
                'fold_index': fold_index,
                'feature_name': feature_name,
                'epochs': resutls
            })
            save_results(model_class.__name__, all_folds_results)
            write_epoch_test_logits(model_class.__name__, all_folds_results)
# Out:
# LangIdCNN_Mean2_FCD_Spectrogram using spectrogram on fold#0. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2401]             387             387
#           Conv1d-2       [10, 1, 2399]              10              10
#          Dropout-3       [10, 1, 2399]               0               0
#        AvgPool1d-4       [10, 1, 1199]               0               0
#           Conv1d-5       [10, 3, 1197]              12              12
#          Dropout-6       [10, 3, 1197]               0               0
#        AvgPool1d-7        [10, 3, 598]               0               0
#           Conv1d-8        [10, 3, 596]              30              30
#          Dropout-9        [10, 3, 596]               0               0
#       AvgPool1d-10        [10, 3, 298]               0               0
#          Conv1d-11        [10, 3, 296]              30              30
#         Dropout-12        [10, 3, 296]               0               0
#       AvgPool1d-13        [10, 3, 148]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.71. Test Loss: 1.093. Train Acc: 0.2549. Test Acc:0.3939
# Epoch: 20. Train Loss: 1.225. Test Loss: 1.095. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.223. Test Loss: 1.099. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.158. Test Loss: 1.097. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.141. Test Loss: 1.094. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.145. Test Loss: 1.091. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.163. Test Loss: 1.089. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 80. Train Loss: 1.134. Test Loss: 1.087. Train Acc: 0.2353. Test Acc:0.3636
# Epoch: 90. Train Loss: 1.158. Test Loss: 1.084. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 100. Train Loss: 1.128. Test Loss: 1.083. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 110. Train Loss: 1.105. Test Loss: 1.081. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 120. Train Loss: 1.11. Test Loss: 1.078. Train Acc: 0.2745. Test Acc:0.3939
# Epoch: 130. Train Loss: 1.086. Test Loss: 1.077. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 140. Train Loss: 1.086. Test Loss: 1.076. Train Acc: 0.4118. Test Acc:0.3939
# Epoch: 150. Train Loss: 1.116. Test Loss: 1.074. Train Acc: 0.3333. Test Acc:0.4242
# Epoch: 160. Train Loss: 1.072. Test Loss: 1.073. Train Acc: 0.3529. Test Acc:0.4545
# Epoch: 170. Train Loss: 1.091. Test Loss: 1.072. Train Acc: 0.3922. Test Acc:0.4545
# Epoch: 180. Train Loss: 1.068. Test Loss: 1.072. Train Acc: 0.3922. Test Acc:0.4545
# Epoch: 190. Train Loss: 1.095. Test Loss: 1.07. Train Acc: 0.3529. Test Acc:0.5455
# Epoch: 200. Train Loss: 1.105. Test Loss: 1.068. Train Acc: 0.2157. Test Acc:0.5455
# Epoch: 210. Train Loss: 1.094. Test Loss: 1.067. Train Acc: 0.3529. Test Acc:0.5455
# Epoch: 220. Train Loss: 1.096. Test Loss: 1.067. Train Acc: 0.3529. Test Acc:0.5152
# Epoch: 230. Train Loss: 1.082. Test Loss: 1.069. Train Acc: 0.3922. Test Acc:0.5152
# Epoch: 240. Train Loss: 1.141. Test Loss: 1.069. Train Acc: 0.2549. Test Acc:0.4848
# Epoch: 250. Train Loss: 1.085. Test Loss: 1.068. Train Acc: 0.3529. Test Acc:0.4848
# Epoch: 260. Train Loss: 1.123. Test Loss: 1.067. Train Acc: 0.3333. Test Acc:0.4545
# Epoch: 270. Train Loss: 1.062. Test Loss: 1.064. Train Acc: 0.4118. Test Acc:0.4545
# Epoch: 280. Train Loss: 1.06. Test Loss: 1.064. Train Acc: 0.5098. Test Acc:0.4848
# Epoch: 290. Train Loss: 1.082. Test Loss: 1.065. Train Acc: 0.4314. Test Acc:0.5758
# Epoch: 300. Train Loss: 1.067. Test Loss: 1.06. Train Acc: 0.2941. Test Acc:0.5455
# Epoch: 310. Train Loss: 1.078. Test Loss: 1.055. Train Acc: 0.3725. Test Acc:0.5152
# Epoch: 320. Train Loss: 1.1. Test Loss: 1.055. Train Acc: 0.3137. Test Acc:0.5152
# Epoch: 330. Train Loss: 1.057. Test Loss: 1.059. Train Acc: 0.451. Test Acc:0.5455
# Epoch: 340. Train Loss: 1.102. Test Loss: 1.058. Train Acc: 0.2941. Test Acc:0.5455
# Epoch: 350. Train Loss: 1.068. Test Loss: 1.055. Train Acc: 0.4314. Test Acc:0.5455
# Epoch: 360. Train Loss: 1.07. Test Loss: 1.049. Train Acc: 0.4314. Test Acc:0.5758
# Epoch: 370. Train Loss: 1.024. Test Loss: 1.045. Train Acc: 0.3725. Test Acc:0.5152
# Epoch: 380. Train Loss: 1.065. Test Loss: 1.041. Train Acc: 0.5098. Test Acc:0.5152
# Epoch: 390. Train Loss: 1.037. Test Loss: 1.038. Train Acc: 0.4314. Test Acc:0.5455
# Epoch: 400. Train Loss: 1.081. Test Loss: 1.035. Train Acc: 0.3922. Test Acc:0.5455
# Epoch: 410. Train Loss: 1.086. Test Loss: 1.042. Train Acc: 0.451. Test Acc:0.5758
# Epoch: 420. Train Loss: 1.059. Test Loss: 1.041. Train Acc: 0.451. Test Acc:0.6061
# Epoch: 430. Train Loss: 1.048. Test Loss: 1.035. Train Acc: 0.5882. Test Acc:0.5455
# Epoch: 440. Train Loss: 1.06. Test Loss: 1.024. Train Acc: 0.3725. Test Acc:0.5455
# Epoch: 450. Train Loss: 1.064. Test Loss: 1.022. Train Acc: 0.4706. Test Acc:0.5455
# Epoch: 460. Train Loss: 1.091. Test Loss: 1.017. Train Acc: 0.3922. Test Acc:0.6061
# Epoch: 470. Train Loss: 1.038. Test Loss: 1.017. Train Acc: 0.4118. Test Acc:0.6061
# Epoch: 480. Train Loss: 1.047. Test Loss: 1.01. Train Acc: 0.4118. Test Acc:0.6667
# Epoch: 490. Train Loss: 1.025. Test Loss: 1.005. Train Acc: 0.5686. Test Acc:0.697
# Epoch: 500. Train Loss: 1.016. Test Loss: 1.007. Train Acc: 0.5098. Test Acc:0.6667
# Epoch: 510. Train Loss: 1.025. Test Loss: 1.004. Train Acc: 0.3529. Test Acc:0.6667
# Epoch: 520. Train Loss: 1.016. Test Loss: 0.9956. Train Acc: 0.549. Test Acc:0.6667
# Epoch: 530. Train Loss: 1.06. Test Loss: 0.9811. Train Acc: 0.4706. Test Acc:0.6667
# Epoch: 540. Train Loss: 1.01. Test Loss: 0.9815. Train Acc: 0.4706. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.9947. Test Loss: 0.9792. Train Acc: 0.5294. Test Acc:0.6364
# Epoch: 560. Train Loss: 1.093. Test Loss: 0.9645. Train Acc: 0.451. Test Acc:0.6667
# Epoch: 570. Train Loss: 0.9938. Test Loss: 0.9727. Train Acc: 0.4314. Test Acc:0.6061
# Epoch: 580. Train Loss: 0.9828. Test Loss: 0.9712. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 590. Train Loss: 1.02. Test Loss: 0.9558. Train Acc: 0.549. Test Acc:0.5758
# Epoch: 600. Train Loss: 0.9752. Test Loss: 0.9571. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 610. Train Loss: 1.006. Test Loss: 0.9545. Train Acc: 0.4902. Test Acc:0.6061
# Epoch: 620. Train Loss: 1.016. Test Loss: 0.951. Train Acc: 0.4902. Test Acc:0.6061
# Epoch: 630. Train Loss: 0.9037. Test Loss: 0.9478. Train Acc: 0.549. Test Acc:0.5758
# Epoch: 640. Train Loss: 0.9978. Test Loss: 0.9461. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 650. Train Loss: 0.9096. Test Loss: 0.9536. Train Acc: 0.549. Test Acc:0.5152
# Epoch: 660. Train Loss: 0.9654. Test Loss: 0.9341. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 670. Train Loss: 0.9423. Test Loss: 0.9557. Train Acc: 0.5294. Test Acc:0.5455
# Epoch: 680. Train Loss: 0.9011. Test Loss: 0.9568. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 690. Train Loss: 0.8866. Test Loss: 0.9538. Train Acc: 0.5098. Test Acc:0.6061
# Epoch: 700. Train Loss: 0.8754. Test Loss: 0.9772. Train Acc: 0.6471. Test Acc:0.5455
# Epoch: 710. Train Loss: 0.8301. Test Loss: 0.9883. Train Acc: 0.6471. Test Acc:0.5455
# Epoch: 720. Train Loss: 0.8188. Test Loss: 0.9713. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 730. Train Loss: 0.8318. Test Loss: 1.008. Train Acc: 0.549. Test Acc:0.6364
# Epoch: 740. Train Loss: 0.8525. Test Loss: 0.9912. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 750. Train Loss: 0.8935. Test Loss: 0.9972. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 760. Train Loss: 0.8802. Test Loss: 0.9987. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 770. Train Loss: 0.8197. Test Loss: 1.005. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 780. Train Loss: 0.8447. Test Loss: 1.016. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 790. Train Loss: 0.7806. Test Loss: 1.021. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.7641. Test Loss: 1.059. Train Acc: 0.6078. Test Acc:0.5152
# Epoch: 810. Train Loss: 0.8817. Test Loss: 1.034. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 820. Train Loss: 0.8583. Test Loss: 1.038. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 830. Train Loss: 0.759. Test Loss: 1.059. Train Acc: 0.549. Test Acc:0.5152
# Epoch: 840. Train Loss: 0.8076. Test Loss: 1.104. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 850. Train Loss: 0.7205. Test Loss: 1.077. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 860. Train Loss: 0.7541. Test Loss: 1.091. Train Acc: 0.6667. Test Acc:0.5455
# Epoch: 870. Train Loss: 0.7524. Test Loss: 1.107. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 880. Train Loss: 0.7353. Test Loss: 1.1. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 890. Train Loss: 0.7631. Test Loss: 1.07. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 900. Train Loss: 0.8025. Test Loss: 1.11. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 910. Train Loss: 0.7385. Test Loss: 1.124. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 920. Train Loss: 0.7871. Test Loss: 1.121. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 930. Train Loss: 0.6809. Test Loss: 1.114. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 940. Train Loss: 0.7791. Test Loss: 1.102. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 950. Train Loss: 0.7017. Test Loss: 1.136. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 960. Train Loss: 0.7561. Test Loss: 1.136. Train Acc: 0.7059. Test Acc:0.6061
# Epoch: 970. Train Loss: 0.7023. Test Loss: 1.21. Train Acc: 0.6471. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.6905. Test Loss: 1.192. Train Acc: 0.6667. Test Acc:0.5758
# Epoch: 990. Train Loss: 0.7548. Test Loss: 1.127. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 1000. Train Loss: 0.7072. Test Loss: 1.21. Train Acc: 0.6667. Test Acc:0.5758
# LangIdCNN_Mean2_FCD_Spectrogram using spectrogram on fold#1. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2401]             387             387
#           Conv1d-2       [10, 1, 2399]              10              10
#          Dropout-3       [10, 1, 2399]               0               0
#        AvgPool1d-4       [10, 1, 1199]               0               0
#           Conv1d-5       [10, 3, 1197]              12              12
#          Dropout-6       [10, 3, 1197]               0               0
#        AvgPool1d-7        [10, 3, 598]               0               0
#           Conv1d-8        [10, 3, 596]              30              30
#          Dropout-9        [10, 3, 596]               0               0
#       AvgPool1d-10        [10, 3, 298]               0               0
#          Conv1d-11        [10, 3, 296]              30              30
#         Dropout-12        [10, 3, 296]               0               0
#       AvgPool1d-13        [10, 3, 148]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.587. Test Loss: 1.123. Train Acc: 0.2745. Test Acc:0.2727
# Epoch: 20. Train Loss: 1.151. Test Loss: 1.168. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 30. Train Loss: 1.153. Test Loss: 1.188. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 40. Train Loss: 1.137. Test Loss: 1.193. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 50. Train Loss: 1.085. Test Loss: 1.193. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 60. Train Loss: 1.093. Test Loss: 1.193. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 70. Train Loss: 1.131. Test Loss: 1.192. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 80. Train Loss: 1.101. Test Loss: 1.191. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 90. Train Loss: 1.09. Test Loss: 1.191. Train Acc: 0.3529. Test Acc:0.2424
# Epoch: 100. Train Loss: 1.077. Test Loss: 1.19. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 110. Train Loss: 1.077. Test Loss: 1.188. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 120. Train Loss: 1.092. Test Loss: 1.184. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 130. Train Loss: 1.083. Test Loss: 1.184. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 140. Train Loss: 1.073. Test Loss: 1.185. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 150. Train Loss: 1.07. Test Loss: 1.186. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 160. Train Loss: 1.064. Test Loss: 1.185. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 170. Train Loss: 1.066. Test Loss: 1.184. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 180. Train Loss: 1.059. Test Loss: 1.183. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 190. Train Loss: 1.059. Test Loss: 1.181. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 200. Train Loss: 1.101. Test Loss: 1.178. Train Acc: 0.3333. Test Acc:0.2424
# Epoch: 210. Train Loss: 1.074. Test Loss: 1.175. Train Acc: 0.4902. Test Acc:0.2424
# Epoch: 220. Train Loss: 1.085. Test Loss: 1.172. Train Acc: 0.2549. Test Acc:0.2424
# Epoch: 230. Train Loss: 1.082. Test Loss: 1.172. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 240. Train Loss: 1.084. Test Loss: 1.171. Train Acc: 0.3333. Test Acc:0.2424
# Epoch: 250. Train Loss: 1.048. Test Loss: 1.169. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 260. Train Loss: 1.078. Test Loss: 1.168. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 270. Train Loss: 1.072. Test Loss: 1.165. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 280. Train Loss: 1.06. Test Loss: 1.161. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 290. Train Loss: 1.055. Test Loss: 1.159. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 300. Train Loss: 1.062. Test Loss: 1.164. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 310. Train Loss: 1.054. Test Loss: 1.165. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 320. Train Loss: 1.079. Test Loss: 1.166. Train Acc: 0.3333. Test Acc:0.2424
# Epoch: 330. Train Loss: 1.059. Test Loss: 1.169. Train Acc: 0.2941. Test Acc:0.2424
# Epoch: 340. Train Loss: 1.07. Test Loss: 1.168. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 350. Train Loss: 1.073. Test Loss: 1.166. Train Acc: 0.3529. Test Acc:0.2424
# Epoch: 360. Train Loss: 1.077. Test Loss: 1.163. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 370. Train Loss: 1.042. Test Loss: 1.16. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 380. Train Loss: 1.068. Test Loss: 1.155. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 390. Train Loss: 1.089. Test Loss: 1.155. Train Acc: 0.2157. Test Acc:0.2424
# Epoch: 400. Train Loss: 1.082. Test Loss: 1.152. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 410. Train Loss: 1.033. Test Loss: 1.143. Train Acc: 0.5686. Test Acc:0.2424
# Epoch: 420. Train Loss: 1.026. Test Loss: 1.131. Train Acc: 0.4902. Test Acc:0.2727
# Epoch: 430. Train Loss: 1.082. Test Loss: 1.13. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 440. Train Loss: 1.031. Test Loss: 1.138. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 450. Train Loss: 1.043. Test Loss: 1.139. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 460. Train Loss: 1.054. Test Loss: 1.137. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 470. Train Loss: 1.037. Test Loss: 1.137. Train Acc: 0.4902. Test Acc:0.2727
# Epoch: 480. Train Loss: 1.089. Test Loss: 1.13. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 490. Train Loss: 1.044. Test Loss: 1.121. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 500. Train Loss: 1.027. Test Loss: 1.119. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 510. Train Loss: 1.065. Test Loss: 1.121. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 520. Train Loss: 1.067. Test Loss: 1.135. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 530. Train Loss: 1.015. Test Loss: 1.138. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 540. Train Loss: 1.067. Test Loss: 1.13. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 550. Train Loss: 1.053. Test Loss: 1.116. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 560. Train Loss: 1.025. Test Loss: 1.105. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 570. Train Loss: 1.057. Test Loss: 1.119. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 580. Train Loss: 1.045. Test Loss: 1.129. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 590. Train Loss: 1.056. Test Loss: 1.148. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 600. Train Loss: 1.08. Test Loss: 1.148. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 610. Train Loss: 1.068. Test Loss: 1.131. Train Acc: 0.4314. Test Acc:0.303
# Epoch: 620. Train Loss: 1.038. Test Loss: 1.11. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 630. Train Loss: 1.02. Test Loss: 1.079. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 640. Train Loss: 1.033. Test Loss: 1.093. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 650. Train Loss: 1.073. Test Loss: 1.112. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 660. Train Loss: 1.081. Test Loss: 1.106. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 670. Train Loss: 1.067. Test Loss: 1.093. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 680. Train Loss: 1.023. Test Loss: 1.113. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 690. Train Loss: 1.04. Test Loss: 1.115. Train Acc: 0.3529. Test Acc:0.4242
# Epoch: 700. Train Loss: 1.072. Test Loss: 1.094. Train Acc: 0.3137. Test Acc:0.3939
# Epoch: 710. Train Loss: 0.9923. Test Loss: 1.08. Train Acc: 0.549. Test Acc:0.4545
# Epoch: 720. Train Loss: 1.017. Test Loss: 1.077. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 730. Train Loss: 0.9807. Test Loss: 1.071. Train Acc: 0.5098. Test Acc:0.4545
# Epoch: 740. Train Loss: 1.002. Test Loss: 1.068. Train Acc: 0.4118. Test Acc:0.4545
# Epoch: 750. Train Loss: 1.012. Test Loss: 1.084. Train Acc: 0.3922. Test Acc:0.4242
# Epoch: 760. Train Loss: 1.044. Test Loss: 1.073. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 770. Train Loss: 1.08. Test Loss: 1.065. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 780. Train Loss: 1.037. Test Loss: 1.072. Train Acc: 0.4706. Test Acc:0.4242
# Epoch: 790. Train Loss: 0.9929. Test Loss: 1.037. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 800. Train Loss: 1.011. Test Loss: 1.018. Train Acc: 0.451. Test Acc:0.4545
# Epoch: 810. Train Loss: 1.037. Test Loss: 1.06. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 820. Train Loss: 1.038. Test Loss: 1.05. Train Acc: 0.3529. Test Acc:0.4242
# Epoch: 830. Train Loss: 1.067. Test Loss: 1.019. Train Acc: 0.3725. Test Acc:0.4545
# Epoch: 840. Train Loss: 0.9959. Test Loss: 1.04. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 850. Train Loss: 1.015. Test Loss: 1.016. Train Acc: 0.3922. Test Acc:0.3939
# Epoch: 860. Train Loss: 1.028. Test Loss: 1.016. Train Acc: 0.3725. Test Acc:0.3939
# Epoch: 870. Train Loss: 1.1. Test Loss: 1.018. Train Acc: 0.4706. Test Acc:0.4242
# Epoch: 880. Train Loss: 1.006. Test Loss: 1.032. Train Acc: 0.4314. Test Acc:0.4545
# Epoch: 890. Train Loss: 1.011. Test Loss: 1.019. Train Acc: 0.3922. Test Acc:0.4242
# Epoch: 900. Train Loss: 1.042. Test Loss: 1.001. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 910. Train Loss: 0.9942. Test Loss: 1.03. Train Acc: 0.3922. Test Acc:0.4242
# Epoch: 920. Train Loss: 0.9548. Test Loss: 1.003. Train Acc: 0.549. Test Acc:0.4242
# Epoch: 930. Train Loss: 0.9682. Test Loss: 1.012. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 940. Train Loss: 1.019. Test Loss: 1.006. Train Acc: 0.4314. Test Acc:0.3939
# Epoch: 950. Train Loss: 0.981. Test Loss: 1.007. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 960. Train Loss: 0.9653. Test Loss: 0.9878. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 970. Train Loss: 0.9492. Test Loss: 0.9837. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 980. Train Loss: 1.083. Test Loss: 0.9504. Train Acc: 0.3333. Test Acc:0.5152
# Epoch: 990. Train Loss: 0.97. Test Loss: 1.067. Train Acc: 0.5098. Test Acc:0.4545
# Epoch: 1000. Train Loss: 0.9235. Test Loss: 0.9679. Train Acc: 0.5098. Test Acc:0.4545
# LangIdCNN_Mean2_FCD_Spectrogram using spectrogram on fold#2. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2401]             387             387
#           Conv1d-2       [10, 1, 2399]              10              10
#          Dropout-3       [10, 1, 2399]               0               0
#        AvgPool1d-4       [10, 1, 1199]               0               0
#           Conv1d-5       [10, 3, 1197]              12              12
#          Dropout-6       [10, 3, 1197]               0               0
#        AvgPool1d-7        [10, 3, 598]               0               0
#           Conv1d-8        [10, 3, 596]              30              30
#          Dropout-9        [10, 3, 596]               0               0
#       AvgPool1d-10        [10, 3, 298]               0               0
#          Conv1d-11        [10, 3, 296]              30              30
#         Dropout-12        [10, 3, 296]               0               0
#       AvgPool1d-13        [10, 3, 148]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.517. Test Loss: 1.224. Train Acc: 0.3333. Test Acc:0.2424
# Epoch: 20. Train Loss: 1.226. Test Loss: 1.176. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 30. Train Loss: 1.12. Test Loss: 1.163. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 40. Train Loss: 1.175. Test Loss: 1.155. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 50. Train Loss: 1.106. Test Loss: 1.149. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 60. Train Loss: 1.116. Test Loss: 1.144. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 70. Train Loss: 1.16. Test Loss: 1.14. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 80. Train Loss: 1.116. Test Loss: 1.137. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 90. Train Loss: 1.111. Test Loss: 1.135. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 100. Train Loss: 1.117. Test Loss: 1.133. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 110. Train Loss: 1.099. Test Loss: 1.131. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 120. Train Loss: 1.12. Test Loss: 1.128. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 130. Train Loss: 1.069. Test Loss: 1.127. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.067. Test Loss: 1.126. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 150. Train Loss: 1.072. Test Loss: 1.124. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 160. Train Loss: 1.09. Test Loss: 1.122. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 170. Train Loss: 1.068. Test Loss: 1.121. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 180. Train Loss: 1.085. Test Loss: 1.119. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 190. Train Loss: 1.069. Test Loss: 1.116. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 200. Train Loss: 1.099. Test Loss: 1.113. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 210. Train Loss: 1.015. Test Loss: 1.112. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 220. Train Loss: 1.092. Test Loss: 1.111. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 230. Train Loss: 1.073. Test Loss: 1.109. Train Acc: 0.451. Test Acc:0.2727
# Epoch: 240. Train Loss: 1.072. Test Loss: 1.108. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 250. Train Loss: 1.036. Test Loss: 1.106. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 260. Train Loss: 1.07. Test Loss: 1.105. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 270. Train Loss: 1.014. Test Loss: 1.103. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 280. Train Loss: 1.009. Test Loss: 1.101. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 290. Train Loss: 1.05. Test Loss: 1.1. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 300. Train Loss: 1.011. Test Loss: 1.099. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 310. Train Loss: 1.038. Test Loss: 1.098. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 320. Train Loss: 1.06. Test Loss: 1.096. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 330. Train Loss: 1.058. Test Loss: 1.095. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 340. Train Loss: 1.046. Test Loss: 1.092. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 350. Train Loss: 1.068. Test Loss: 1.089. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 360. Train Loss: 1.021. Test Loss: 1.087. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 370. Train Loss: 1.019. Test Loss: 1.086. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 380. Train Loss: 0.9837. Test Loss: 1.084. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 390. Train Loss: 1.004. Test Loss: 1.08. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 400. Train Loss: 1.049. Test Loss: 1.076. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 410. Train Loss: 0.9889. Test Loss: 1.075. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 420. Train Loss: 1.044. Test Loss: 1.071. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 430. Train Loss: 0.9806. Test Loss: 1.07. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 440. Train Loss: 1.02. Test Loss: 1.067. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 450. Train Loss: 1.021. Test Loss: 1.061. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 460. Train Loss: 1.034. Test Loss: 1.069. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 470. Train Loss: 0.9983. Test Loss: 1.076. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 480. Train Loss: 0.9455. Test Loss: 1.075. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 490. Train Loss: 0.9031. Test Loss: 1.065. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 500. Train Loss: 0.9689. Test Loss: 1.055. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 510. Train Loss: 0.9658. Test Loss: 1.057. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 520. Train Loss: 0.8971. Test Loss: 1.057. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 530. Train Loss: 0.9595. Test Loss: 1.058. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 540. Train Loss: 0.9323. Test Loss: 1.048. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 550. Train Loss: 0.9066. Test Loss: 1.047. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 560. Train Loss: 1.007. Test Loss: 1.057. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 570. Train Loss: 0.882. Test Loss: 1.05. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 580. Train Loss: 0.9643. Test Loss: 1.062. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 590. Train Loss: 0.9225. Test Loss: 1.058. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 600. Train Loss: 0.8579. Test Loss: 1.043. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 610. Train Loss: 0.9217. Test Loss: 1.032. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 620. Train Loss: 0.9894. Test Loss: 1.025. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 630. Train Loss: 0.8478. Test Loss: 1.028. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 640. Train Loss: 0.884. Test Loss: 1.08. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 650. Train Loss: 0.8853. Test Loss: 1.083. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 660. Train Loss: 0.8922. Test Loss: 1.053. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 670. Train Loss: 0.856. Test Loss: 1.053. Train Acc: 0.6275. Test Acc:0.3333
# Epoch: 680. Train Loss: 0.8317. Test Loss: 1.062. Train Acc: 0.6275. Test Acc:0.3333
# Epoch: 690. Train Loss: 0.9111. Test Loss: 1.057. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 700. Train Loss: 0.877. Test Loss: 1.056. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 710. Train Loss: 0.7717. Test Loss: 1.063. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 720. Train Loss: 0.7568. Test Loss: 1.069. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 730. Train Loss: 0.7481. Test Loss: 1.072. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 740. Train Loss: 0.8996. Test Loss: 1.078. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 750. Train Loss: 0.8621. Test Loss: 1.058. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 760. Train Loss: 0.9083. Test Loss: 1.053. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 770. Train Loss: 0.9047. Test Loss: 1.07. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 780. Train Loss: 0.815. Test Loss: 1.067. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 790. Train Loss: 0.8577. Test Loss: 1.072. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 800. Train Loss: 0.7321. Test Loss: 1.058. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 810. Train Loss: 0.8285. Test Loss: 1.071. Train Acc: 0.6078. Test Acc:0.303
# Epoch: 820. Train Loss: 0.8802. Test Loss: 1.075. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 830. Train Loss: 0.7514. Test Loss: 1.074. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 840. Train Loss: 0.8021. Test Loss: 1.065. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 850. Train Loss: 0.8007. Test Loss: 1.064. Train Acc: 0.6471. Test Acc:0.3636
# Epoch: 860. Train Loss: 0.8236. Test Loss: 1.086. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 870. Train Loss: 0.7961. Test Loss: 1.077. Train Acc: 0.6275. Test Acc:0.3333
# Epoch: 880. Train Loss: 0.7912. Test Loss: 1.054. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 890. Train Loss: 0.7625. Test Loss: 1.072. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 900. Train Loss: 0.8046. Test Loss: 1.049. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 910. Train Loss: 0.711. Test Loss: 1.056. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 920. Train Loss: 0.7573. Test Loss: 1.03. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 930. Train Loss: 0.8106. Test Loss: 1.057. Train Acc: 0.6863. Test Acc:0.3636
# Epoch: 940. Train Loss: 0.7233. Test Loss: 1.019. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 950. Train Loss: 0.7181. Test Loss: 1.079. Train Acc: 0.6863. Test Acc:0.3636
# Epoch: 960. Train Loss: 0.8134. Test Loss: 1.027. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 970. Train Loss: 0.7099. Test Loss: 1.035. Train Acc: 0.6667. Test Acc:0.4848
# Epoch: 980. Train Loss: 0.7718. Test Loss: 1.036. Train Acc: 0.6667. Test Acc:0.3939
# Epoch: 990. Train Loss: 0.8282. Test Loss: 1.051. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 1000. Train Loss: 0.7396. Test Loss: 1.049. Train Acc: 0.6863. Test Acc:0.3939
# LangIdCNN_Mean2_FCD_Spectrogram using spectrogram on fold#3. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2401]             387             387
#           Conv1d-2       [10, 1, 2399]              10              10
#          Dropout-3       [10, 1, 2399]               0               0
#        AvgPool1d-4       [10, 1, 1199]               0               0
#           Conv1d-5       [10, 3, 1197]              12              12
#          Dropout-6       [10, 3, 1197]               0               0
#        AvgPool1d-7        [10, 3, 598]               0               0
#           Conv1d-8        [10, 3, 596]              30              30
#          Dropout-9        [10, 3, 596]               0               0
#       AvgPool1d-10        [10, 3, 298]               0               0
#          Conv1d-11        [10, 3, 296]              30              30
#         Dropout-12        [10, 3, 296]               0               0
#       AvgPool1d-13        [10, 3, 148]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.638. Test Loss: 1.226. Train Acc: 0.2745. Test Acc:0.2424
# Epoch: 20. Train Loss: 1.222. Test Loss: 1.202. Train Acc: 0.3529. Test Acc:0.2424
# Epoch: 30. Train Loss: 1.196. Test Loss: 1.196. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 40. Train Loss: 1.141. Test Loss: 1.189. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 50. Train Loss: 1.1. Test Loss: 1.182. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 60. Train Loss: 1.121. Test Loss: 1.175. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 70. Train Loss: 1.144. Test Loss: 1.17. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 80. Train Loss: 1.118. Test Loss: 1.165. Train Acc: 0.3529. Test Acc:0.2424
# Epoch: 90. Train Loss: 1.102. Test Loss: 1.16. Train Acc: 0.4118. Test Acc:0.2424
# Epoch: 100. Train Loss: 1.06. Test Loss: 1.156. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 110. Train Loss: 1.098. Test Loss: 1.152. Train Acc: 0.3137. Test Acc:0.2424
# Epoch: 120. Train Loss: 1.074. Test Loss: 1.147. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 130. Train Loss: 1.061. Test Loss: 1.144. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 140. Train Loss: 1.035. Test Loss: 1.141. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 150. Train Loss: 1.09. Test Loss: 1.138. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 160. Train Loss: 1.053. Test Loss: 1.139. Train Acc: 0.4902. Test Acc:0.2424
# Epoch: 170. Train Loss: 1.049. Test Loss: 1.138. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 180. Train Loss: 1.071. Test Loss: 1.137. Train Acc: 0.4902. Test Acc:0.2424
# Epoch: 190. Train Loss: 1.066. Test Loss: 1.134. Train Acc: 0.4118. Test Acc:0.2121
# Epoch: 200. Train Loss: 1.065. Test Loss: 1.132. Train Acc: 0.4902. Test Acc:0.2121
# Epoch: 210. Train Loss: 1.029. Test Loss: 1.134. Train Acc: 0.451. Test Acc:0.2121
# Epoch: 220. Train Loss: 1.029. Test Loss: 1.134. Train Acc: 0.4314. Test Acc:0.2121
# Epoch: 230. Train Loss: 1.043. Test Loss: 1.133. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 240. Train Loss: 1.047. Test Loss: 1.133. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 250. Train Loss: 1.009. Test Loss: 1.134. Train Acc: 0.4902. Test Acc:0.2424
# Epoch: 260. Train Loss: 0.9816. Test Loss: 1.136. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 270. Train Loss: 0.989. Test Loss: 1.134. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 280. Train Loss: 1.033. Test Loss: 1.135. Train Acc: 0.451. Test Acc:0.303
# Epoch: 290. Train Loss: 1.062. Test Loss: 1.137. Train Acc: 0.451. Test Acc:0.303
# Epoch: 300. Train Loss: 1.032. Test Loss: 1.142. Train Acc: 0.5098. Test Acc:0.2727
# Epoch: 310. Train Loss: 1.04. Test Loss: 1.145. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 320. Train Loss: 0.9656. Test Loss: 1.143. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 330. Train Loss: 1.017. Test Loss: 1.143. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 340. Train Loss: 0.9722. Test Loss: 1.145. Train Acc: 0.5098. Test Acc:0.2727
# Epoch: 350. Train Loss: 0.9367. Test Loss: 1.141. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 360. Train Loss: 1.004. Test Loss: 1.142. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 370. Train Loss: 0.9564. Test Loss: 1.146. Train Acc: 0.6078. Test Acc:0.303
# Epoch: 380. Train Loss: 0.9912. Test Loss: 1.159. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 390. Train Loss: 0.9811. Test Loss: 1.161. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 400. Train Loss: 1.029. Test Loss: 1.149. Train Acc: 0.451. Test Acc:0.303
# Epoch: 410. Train Loss: 0.9244. Test Loss: 1.152. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 420. Train Loss: 1.027. Test Loss: 1.152. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 430. Train Loss: 0.9075. Test Loss: 1.155. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 440. Train Loss: 0.9155. Test Loss: 1.165. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 450. Train Loss: 0.9688. Test Loss: 1.172. Train Acc: 0.5098. Test Acc:0.2727
# Epoch: 460. Train Loss: 0.907. Test Loss: 1.17. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 470. Train Loss: 1.093. Test Loss: 1.168. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 480. Train Loss: 0.9228. Test Loss: 1.173. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 490. Train Loss: 0.8225. Test Loss: 1.18. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 500. Train Loss: 0.9534. Test Loss: 1.172. Train Acc: 0.451. Test Acc:0.303
# Epoch: 510. Train Loss: 0.9574. Test Loss: 1.177. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 520. Train Loss: 0.8971. Test Loss: 1.184. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 530. Train Loss: 0.9191. Test Loss: 1.184. Train Acc: 0.549. Test Acc:0.303
# Epoch: 540. Train Loss: 0.8265. Test Loss: 1.191. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 550. Train Loss: 0.9342. Test Loss: 1.184. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 560. Train Loss: 0.8816. Test Loss: 1.191. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 570. Train Loss: 0.9154. Test Loss: 1.204. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 580. Train Loss: 0.8087. Test Loss: 1.206. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 590. Train Loss: 0.8701. Test Loss: 1.183. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 600. Train Loss: 0.8555. Test Loss: 1.194. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 610. Train Loss: 0.9105. Test Loss: 1.193. Train Acc: 0.451. Test Acc:0.2727
# Epoch: 620. Train Loss: 0.9537. Test Loss: 1.202. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 630. Train Loss: 0.8191. Test Loss: 1.213. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 640. Train Loss: 0.8508. Test Loss: 1.206. Train Acc: 0.549. Test Acc:0.303
# Epoch: 650. Train Loss: 0.9197. Test Loss: 1.22. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 660. Train Loss: 0.798. Test Loss: 1.203. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 670. Train Loss: 0.9277. Test Loss: 1.21. Train Acc: 0.549. Test Acc:0.303
# Epoch: 680. Train Loss: 0.7983. Test Loss: 1.214. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 690. Train Loss: 0.8379. Test Loss: 1.215. Train Acc: 0.549. Test Acc:0.303
# Epoch: 700. Train Loss: 0.8799. Test Loss: 1.214. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 710. Train Loss: 0.8152. Test Loss: 1.214. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 720. Train Loss: 0.8689. Test Loss: 1.222. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 730. Train Loss: 0.8301. Test Loss: 1.226. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 740. Train Loss: 0.7896. Test Loss: 1.212. Train Acc: 0.6275. Test Acc:0.3333
# Epoch: 750. Train Loss: 0.7829. Test Loss: 1.224. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 760. Train Loss: 0.8367. Test Loss: 1.228. Train Acc: 0.549. Test Acc:0.303
# Epoch: 770. Train Loss: 0.8525. Test Loss: 1.22. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 780. Train Loss: 0.7959. Test Loss: 1.226. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 790. Train Loss: 0.7394. Test Loss: 1.23. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 800. Train Loss: 0.7366. Test Loss: 1.252. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 810. Train Loss: 0.8778. Test Loss: 1.241. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 820. Train Loss: 0.8076. Test Loss: 1.244. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 830. Train Loss: 0.7898. Test Loss: 1.233. Train Acc: 0.6275. Test Acc:0.3333
# Epoch: 840. Train Loss: 0.7799. Test Loss: 1.257. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 850. Train Loss: 0.754. Test Loss: 1.259. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 860. Train Loss: 0.7625. Test Loss: 1.257. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 870. Train Loss: 0.826. Test Loss: 1.271. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 880. Train Loss: 0.7954. Test Loss: 1.266. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 890. Train Loss: 0.739. Test Loss: 1.273. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 900. Train Loss: 0.7741. Test Loss: 1.278. Train Acc: 0.6471. Test Acc:0.3636
# Epoch: 910. Train Loss: 0.784. Test Loss: 1.264. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 920. Train Loss: 0.8247. Test Loss: 1.254. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 930. Train Loss: 0.8438. Test Loss: 1.293. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 940. Train Loss: 0.7162. Test Loss: 1.275. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 950. Train Loss: 0.7533. Test Loss: 1.251. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 960. Train Loss: 0.8182. Test Loss: 1.271. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 970. Train Loss: 0.7038. Test Loss: 1.306. Train Acc: 0.6667. Test Acc:0.3939
# Epoch: 980. Train Loss: 0.7893. Test Loss: 1.296. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 990. Train Loss: 0.7. Test Loss: 1.301. Train Acc: 0.6863. Test Acc:0.3636
# Epoch: 1000. Train Loss: 0.8011. Test Loss: 1.285. Train Acc: 0.6471. Test Acc:0.3636
# LangIdCNN_Mean2_FCD_Spectrogram using spectrogram on fold#4. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2401]             387             387
#           Conv1d-2       [10, 1, 2399]              10              10
#          Dropout-3       [10, 1, 2399]               0               0
#        AvgPool1d-4       [10, 1, 1199]               0               0
#           Conv1d-5       [10, 3, 1197]              12              12
#          Dropout-6       [10, 3, 1197]               0               0
#        AvgPool1d-7        [10, 3, 598]               0               0
#           Conv1d-8        [10, 3, 596]              30              30
#          Dropout-9        [10, 3, 596]               0               0
#       AvgPool1d-10        [10, 3, 298]               0               0
#          Conv1d-11        [10, 3, 296]              30              30
#         Dropout-12        [10, 3, 296]               0               0
#       AvgPool1d-13        [10, 3, 148]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.851. Test Loss: 1.124. Train Acc: 0.2353. Test Acc:0.4848
# Epoch: 20. Train Loss: 1.328. Test Loss: 1.063. Train Acc: 0.2549. Test Acc:0.4242
# Epoch: 30. Train Loss: 1.217. Test Loss: 1.058. Train Acc: 0.2549. Test Acc:0.4545
# Epoch: 40. Train Loss: 1.195. Test Loss: 1.057. Train Acc: 0.2157. Test Acc:0.4545
# Epoch: 50. Train Loss: 1.135. Test Loss: 1.058. Train Acc: 0.3333. Test Acc:0.4545
# Epoch: 60. Train Loss: 1.162. Test Loss: 1.059. Train Acc: 0.2745. Test Acc:0.4545
# Epoch: 70. Train Loss: 1.196. Test Loss: 1.062. Train Acc: 0.2157. Test Acc:0.4545
# Epoch: 80. Train Loss: 1.136. Test Loss: 1.064. Train Acc: 0.2745. Test Acc:0.4242
# Epoch: 90. Train Loss: 1.147. Test Loss: 1.066. Train Acc: 0.1961. Test Acc:0.4545
# Epoch: 100. Train Loss: 1.115. Test Loss: 1.069. Train Acc: 0.3137. Test Acc:0.5152
# Epoch: 110. Train Loss: 1.083. Test Loss: 1.073. Train Acc: 0.3529. Test Acc:0.4848
# Epoch: 120. Train Loss: 1.123. Test Loss: 1.077. Train Acc: 0.2353. Test Acc:0.4545
# Epoch: 130. Train Loss: 1.07. Test Loss: 1.081. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 140. Train Loss: 1.044. Test Loss: 1.085. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 150. Train Loss: 1.088. Test Loss: 1.088. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 160. Train Loss: 1.066. Test Loss: 1.09. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 170. Train Loss: 1.049. Test Loss: 1.093. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 180. Train Loss: 1.063. Test Loss: 1.096. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 190. Train Loss: 1.081. Test Loss: 1.099. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 200. Train Loss: 1.047. Test Loss: 1.102. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 210. Train Loss: 1.084. Test Loss: 1.104. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 220. Train Loss: 1.108. Test Loss: 1.106. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 230. Train Loss: 1.039. Test Loss: 1.108. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 240. Train Loss: 1.098. Test Loss: 1.111. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 250. Train Loss: 1.099. Test Loss: 1.11. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 260. Train Loss: 1.062. Test Loss: 1.107. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 270. Train Loss: 0.9995. Test Loss: 1.104. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 280. Train Loss: 1.069. Test Loss: 1.102. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 290. Train Loss: 1.056. Test Loss: 1.103. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 300. Train Loss: 0.9771. Test Loss: 1.109. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 310. Train Loss: 1.037. Test Loss: 1.117. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 320. Train Loss: 1.04. Test Loss: 1.11. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 330. Train Loss: 1.046. Test Loss: 1.094. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 340. Train Loss: 1.038. Test Loss: 1.091. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 350. Train Loss: 1.044. Test Loss: 1.099. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 360. Train Loss: 1.043. Test Loss: 1.11. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 370. Train Loss: 1.029. Test Loss: 1.099. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 380. Train Loss: 1.028. Test Loss: 1.092. Train Acc: 0.4314. Test Acc:0.303
# Epoch: 390. Train Loss: 1.032. Test Loss: 1.087. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 400. Train Loss: 1.021. Test Loss: 1.094. Train Acc: 0.4314. Test Acc:0.303
# Epoch: 410. Train Loss: 1.05. Test Loss: 1.082. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 420. Train Loss: 0.9713. Test Loss: 1.086. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 430. Train Loss: 0.9761. Test Loss: 1.088. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 440. Train Loss: 1.047. Test Loss: 1.087. Train Acc: 0.4314. Test Acc:0.303
# Epoch: 450. Train Loss: 1.018. Test Loss: 1.082. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 460. Train Loss: 1.065. Test Loss: 1.074. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 470. Train Loss: 1.028. Test Loss: 1.066. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 480. Train Loss: 0.9686. Test Loss: 1.07. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 490. Train Loss: 1.018. Test Loss: 1.092. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 500. Train Loss: 1.026. Test Loss: 1.07. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 510. Train Loss: 1.027. Test Loss: 1.06. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 520. Train Loss: 0.9736. Test Loss: 1.089. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 530. Train Loss: 0.9895. Test Loss: 1.063. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 540. Train Loss: 0.9841. Test Loss: 1.063. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 550. Train Loss: 0.9556. Test Loss: 1.063. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 560. Train Loss: 0.9713. Test Loss: 1.064. Train Acc: 0.549. Test Acc:0.303
# Epoch: 570. Train Loss: 0.8989. Test Loss: 1.034. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 580. Train Loss: 0.8528. Test Loss: 1.055. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 590. Train Loss: 0.9666. Test Loss: 1.039. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 600. Train Loss: 0.9688. Test Loss: 1.037. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 610. Train Loss: 1.011. Test Loss: 1.066. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 620. Train Loss: 0.9441. Test Loss: 1.092. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 630. Train Loss: 0.9142. Test Loss: 1.1. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 640. Train Loss: 0.9609. Test Loss: 1.079. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 650. Train Loss: 0.9616. Test Loss: 1.086. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 660. Train Loss: 0.9001. Test Loss: 1.172. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 670. Train Loss: 0.9514. Test Loss: 1.161. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 680. Train Loss: 0.8931. Test Loss: 1.212. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.9973. Test Loss: 1.263. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 700. Train Loss: 0.9065. Test Loss: 1.278. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 710. Train Loss: 0.8936. Test Loss: 1.227. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 720. Train Loss: 0.8788. Test Loss: 1.329. Train Acc: 0.6471. Test Acc:0.3636
# Epoch: 730. Train Loss: 0.8681. Test Loss: 1.424. Train Acc: 0.6863. Test Acc:0.3636
# Epoch: 740. Train Loss: 0.8951. Test Loss: 1.418. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 750. Train Loss: 0.8871. Test Loss: 1.488. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 760. Train Loss: 0.8496. Test Loss: 1.495. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 770. Train Loss: 0.808. Test Loss: 1.413. Train Acc: 0.7255. Test Acc:0.3636
# Epoch: 780. Train Loss: 0.857. Test Loss: 1.447. Train Acc: 0.7255. Test Acc:0.4242
# ...
# Epoch: 300. Train Loss: 0.9874. Test Loss: 1.073. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 310. Train Loss: 1.004. Test Loss: 1.073. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 320. Train Loss: 1.015. Test Loss: 1.072. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 330. Train Loss: 1.044. Test Loss: 1.072. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 340. Train Loss: 1.01. Test Loss: 1.071. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 350. Train Loss: 0.9693. Test Loss: 1.072. Train Acc: 0.451. Test Acc:0.4242
# Epoch: 360. Train Loss: 1.052. Test Loss: 1.067. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 370. Train Loss: 0.9465. Test Loss: 1.065. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 380. Train Loss: 0.9566. Test Loss: 1.068. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 390. Train Loss: 1.008. Test Loss: 1.07. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 400. Train Loss: 1.03. Test Loss: 1.073. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 410. Train Loss: 1.015. Test Loss: 1.064. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 420. Train Loss: 0.9571. Test Loss: 1.063. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 430. Train Loss: 0.971. Test Loss: 1.067. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 440. Train Loss: 0.9404. Test Loss: 1.065. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 450. Train Loss: 0.9445. Test Loss: 1.062. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 460. Train Loss: 1.006. Test Loss: 1.064. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 470. Train Loss: 0.9927. Test Loss: 1.072. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 480. Train Loss: 0.9584. Test Loss: 1.074. Train Acc: 0.4706. Test Acc:0.4242
# Epoch: 490. Train Loss: 0.9896. Test Loss: 1.066. Train Acc: 0.451. Test Acc:0.4545
# Epoch: 500. Train Loss: 0.9259. Test Loss: 1.065. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 510. Train Loss: 1.004. Test Loss: 1.076. Train Acc: 0.4706. Test Acc:0.5152
# Epoch: 520. Train Loss: 0.9465. Test Loss: 1.065. Train Acc: 0.5098. Test Acc:0.4848
# Epoch: 530. Train Loss: 0.9982. Test Loss: 1.078. Train Acc: 0.4706. Test Acc:0.4848
# Epoch: 540. Train Loss: 0.9493. Test Loss: 1.064. Train Acc: 0.451. Test Acc:0.5152
# Epoch: 550. Train Loss: 0.918. Test Loss: 1.067. Train Acc: 0.4902. Test Acc:0.4848
# Epoch: 560. Train Loss: 1.04. Test Loss: 1.064. Train Acc: 0.451. Test Acc:0.5152
# Epoch: 570. Train Loss: 0.8896. Test Loss: 1.064. Train Acc: 0.4902. Test Acc:0.5455
# Epoch: 580. Train Loss: 0.9763. Test Loss: 1.084. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 590. Train Loss: 0.9809. Test Loss: 1.065. Train Acc: 0.451. Test Acc:0.5152
# Epoch: 600. Train Loss: 0.9279. Test Loss: 1.055. Train Acc: 0.451. Test Acc:0.4848
# Epoch: 610. Train Loss: 1.008. Test Loss: 1.049. Train Acc: 0.3922. Test Acc:0.5152
# Epoch: 620. Train Loss: 1.01. Test Loss: 1.056. Train Acc: 0.4118. Test Acc:0.5152
# Epoch: 630. Train Loss: 0.9467. Test Loss: 1.055. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 640. Train Loss: 0.9383. Test Loss: 1.035. Train Acc: 0.549. Test Acc:0.5152
# Epoch: 650. Train Loss: 0.9412. Test Loss: 1.033. Train Acc: 0.5294. Test Acc:0.5152
# Epoch: 660. Train Loss: 0.9753. Test Loss: 1.04. Train Acc: 0.4902. Test Acc:0.5455
# Epoch: 670. Train Loss: 0.9781. Test Loss: 1.041. Train Acc: 0.5098. Test Acc:0.5758
# Epoch: 680. Train Loss: 0.9319. Test Loss: 1.034. Train Acc: 0.5882. Test Acc:0.5455
# Epoch: 690. Train Loss: 0.9044. Test Loss: 1.042. Train Acc: 0.4706. Test Acc:0.5455
# Epoch: 700. Train Loss: 0.9324. Test Loss: 1.027. Train Acc: 0.4706. Test Acc:0.5455
# Epoch: 710. Train Loss: 0.9173. Test Loss: 1.026. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 720. Train Loss: 0.9119. Test Loss: 1.028. Train Acc: 0.5686. Test Acc:0.5152
# Epoch: 730. Train Loss: 0.7855. Test Loss: 1.039. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 740. Train Loss: 0.9149. Test Loss: 1.025. Train Acc: 0.451. Test Acc:0.4848
# Epoch: 750. Train Loss: 0.9093. Test Loss: 1.028. Train Acc: 0.4314. Test Acc:0.5455
# Epoch: 760. Train Loss: 0.9796. Test Loss: 1.022. Train Acc: 0.451. Test Acc:0.5455
# Epoch: 770. Train Loss: 0.8226. Test Loss: 1.013. Train Acc: 0.549. Test Acc:0.4545
# Epoch: 780. Train Loss: 0.88. Test Loss: 1.012. Train Acc: 0.6078. Test Acc:0.5152
# Epoch: 790. Train Loss: 0.8768. Test Loss: 1.012. Train Acc: 0.6275. Test Acc:0.5152
# Epoch: 800. Train Loss: 0.7835. Test Loss: 0.9937. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 810. Train Loss: 0.9236. Test Loss: 0.9966. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 820. Train Loss: 0.9106. Test Loss: 0.9992. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 830. Train Loss: 0.8368. Test Loss: 1.0. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 840. Train Loss: 0.8275. Test Loss: 1.017. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 850. Train Loss: 0.844. Test Loss: 0.9968. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 860. Train Loss: 0.8094. Test Loss: 0.9909. Train Acc: 0.6667. Test Acc:0.5758
# Epoch: 870. Train Loss: 0.8933. Test Loss: 1.003. Train Acc: 0.5686. Test Acc:0.5152
# Epoch: 880. Train Loss: 0.85. Test Loss: 1.014. Train Acc: 0.5294. Test Acc:0.5455
# Epoch: 890. Train Loss: 0.9405. Test Loss: 0.9908. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 900. Train Loss: 0.9191. Test Loss: 0.9899. Train Acc: 0.5098. Test Acc:0.4545
# Epoch: 910. Train Loss: 0.8531. Test Loss: 0.9824. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 920. Train Loss: 0.8242. Test Loss: 1.018. Train Acc: 0.6667. Test Acc:0.4242
# Epoch: 930. Train Loss: 0.8822. Test Loss: 0.9734. Train Acc: 0.6275. Test Acc:0.5152
# Epoch: 940. Train Loss: 0.8404. Test Loss: 0.9841. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 950. Train Loss: 0.8456. Test Loss: 0.9866. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 960. Train Loss: 0.9256. Test Loss: 0.9747. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 970. Train Loss: 0.8706. Test Loss: 0.9775. Train Acc: 0.6667. Test Acc:0.5455
# Epoch: 980. Train Loss: 0.8065. Test Loss: 0.9811. Train Acc: 0.6078. Test Acc:0.4242
# Epoch: 990. Train Loss: 0.8769. Test Loss: 0.9727. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 1000. Train Loss: 0.82. Test Loss: 0.9954. Train Acc: 0.549. Test Acc:0.4242
# LangIdCNN_Mean2_FCD_Spectrogram using spectrogram on fold#9. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2401]             387             387
#           Conv1d-2       [10, 1, 2399]              10              10
#          Dropout-3       [10, 1, 2399]               0               0
#        AvgPool1d-4       [10, 1, 1199]               0               0
#           Conv1d-5       [10, 3, 1197]              12              12
#          Dropout-6       [10, 3, 1197]               0               0
#        AvgPool1d-7        [10, 3, 598]               0               0
#           Conv1d-8        [10, 3, 596]              30              30
#          Dropout-9        [10, 3, 596]               0               0
#       AvgPool1d-10        [10, 3, 298]               0               0
#          Conv1d-11        [10, 3, 296]              30              30
#         Dropout-12        [10, 3, 296]               0               0
#       AvgPool1d-13        [10, 3, 148]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 499
# Trainable params: 499
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.866. Test Loss: 1.103. Train Acc: 0.2745. Test Acc:0.3939
# Epoch: 20. Train Loss: 1.25. Test Loss: 1.07. Train Acc: 0.2353. Test Acc:0.4242
# Epoch: 30. Train Loss: 1.257. Test Loss: 1.07. Train Acc: 0.2745. Test Acc:0.4242
# Epoch: 40. Train Loss: 1.19. Test Loss: 1.069. Train Acc: 0.2745. Test Acc:0.4242
# Epoch: 50. Train Loss: 1.142. Test Loss: 1.068. Train Acc: 0.3137. Test Acc:0.4242
# Epoch: 60. Train Loss: 1.153. Test Loss: 1.067. Train Acc: 0.3137. Test Acc:0.4242
# Epoch: 70. Train Loss: 1.15. Test Loss: 1.067. Train Acc: 0.2941. Test Acc:0.4242
# Epoch: 80. Train Loss: 1.147. Test Loss: 1.067. Train Acc: 0.1765. Test Acc:0.4242
# Epoch: 90. Train Loss: 1.132. Test Loss: 1.067. Train Acc: 0.2353. Test Acc:0.4242
# Epoch: 100. Train Loss: 1.142. Test Loss: 1.068. Train Acc: 0.3529. Test Acc:0.4545
# Epoch: 110. Train Loss: 1.113. Test Loss: 1.07. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 120. Train Loss: 1.126. Test Loss: 1.071. Train Acc: 0.2745. Test Acc:0.5152
# Epoch: 130. Train Loss: 1.099. Test Loss: 1.072. Train Acc: 0.3725. Test Acc:0.5152
# Epoch: 140. Train Loss: 1.059. Test Loss: 1.073. Train Acc: 0.451. Test Acc:0.4242
# Epoch: 150. Train Loss: 1.098. Test Loss: 1.074. Train Acc: 0.3529. Test Acc:0.3939
# Epoch: 160. Train Loss: 1.07. Test Loss: 1.077. Train Acc: 0.3529. Test Acc:0.3939
# Epoch: 170. Train Loss: 1.048. Test Loss: 1.08. Train Acc: 0.4314. Test Acc:0.3939
# Epoch: 180. Train Loss: 1.082. Test Loss: 1.082. Train Acc: 0.3725. Test Acc:0.3939
# Epoch: 190. Train Loss: 1.068. Test Loss: 1.085. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 200. Train Loss: 1.087. Test Loss: 1.088. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 210. Train Loss: 1.082. Test Loss: 1.09. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 220. Train Loss: 1.126. Test Loss: 1.09. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 230. Train Loss: 1.104. Test Loss: 1.091. Train Acc: 0.3725. Test Acc:0.3939
# Epoch: 240. Train Loss: 1.103. Test Loss: 1.092. Train Acc: 0.2941. Test Acc:0.3939
# Epoch: 250. Train Loss: 1.151. Test Loss: 1.088. Train Acc: 0.3137. Test Acc:0.3939
# Epoch: 260. Train Loss: 1.092. Test Loss: 1.085. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 270. Train Loss: 1.012. Test Loss: 1.085. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 280. Train Loss: 1.091. Test Loss: 1.084. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 290. Train Loss: 1.071. Test Loss: 1.082. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 300. Train Loss: 1.026. Test Loss: 1.081. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 310. Train Loss: 1.05. Test Loss: 1.082. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 320. Train Loss: 1.068. Test Loss: 1.085. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 330. Train Loss: 1.092. Test Loss: 1.086. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 340. Train Loss: 1.101. Test Loss: 1.089. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 350. Train Loss: 1.02. Test Loss: 1.088. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 360. Train Loss: 1.037. Test Loss: 1.089. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 370. Train Loss: 1.034. Test Loss: 1.082. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 380. Train Loss: 1.058. Test Loss: 1.081. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 390. Train Loss: 1.075. Test Loss: 1.077. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 400. Train Loss: 1.023. Test Loss: 1.076. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 410. Train Loss: 1.053. Test Loss: 1.072. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 420. Train Loss: 1.032. Test Loss: 1.07. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 430. Train Loss: 1.027. Test Loss: 1.069. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 440. Train Loss: 1.009. Test Loss: 1.07. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 450. Train Loss: 1.035. Test Loss: 1.065. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 460. Train Loss: 1.055. Test Loss: 1.062. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 470. Train Loss: 1.061. Test Loss: 1.075. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 480. Train Loss: 1.004. Test Loss: 1.071. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 490. Train Loss: 1.056. Test Loss: 1.067. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 500. Train Loss: 1.019. Test Loss: 1.052. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 510. Train Loss: 1.028. Test Loss: 1.054. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 520. Train Loss: 0.9959. Test Loss: 1.064. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 530. Train Loss: 1.003. Test Loss: 1.065. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 540. Train Loss: 1.016. Test Loss: 1.052. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 550. Train Loss: 1.01. Test Loss: 1.047. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 560. Train Loss: 1.053. Test Loss: 1.052. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 570. Train Loss: 0.9436. Test Loss: 1.05. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 580. Train Loss: 0.9409. Test Loss: 1.06. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 590. Train Loss: 1.025. Test Loss: 1.061. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 600. Train Loss: 0.9703. Test Loss: 1.061. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 610. Train Loss: 1.026. Test Loss: 1.101. Train Acc: 0.4314. Test Acc:0.3333
# Epoch: 620. Train Loss: 1.048. Test Loss: 1.04. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 630. Train Loss: 0.9883. Test Loss: 1.062. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 640. Train Loss: 1.008. Test Loss: 1.055. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 650. Train Loss: 0.9941. Test Loss: 1.075. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 660. Train Loss: 0.9341. Test Loss: 1.081. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 670. Train Loss: 0.967. Test Loss: 1.08. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 680. Train Loss: 0.9739. Test Loss: 1.071. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 690. Train Loss: 1.002. Test Loss: 1.1. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 700. Train Loss: 0.9745. Test Loss: 1.087. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 710. Train Loss: 0.9219. Test Loss: 1.059. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 720. Train Loss: 0.9079. Test Loss: 1.13. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 730. Train Loss: 0.9055. Test Loss: 1.076. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 740. Train Loss: 1.008. Test Loss: 1.076. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 750. Train Loss: 0.9835. Test Loss: 1.068. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 760. Train Loss: 0.8908. Test Loss: 1.082. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 770. Train Loss: 0.9573. Test Loss: 1.104. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 780. Train Loss: 0.96. Test Loss: 1.08. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 790. Train Loss: 0.9002. Test Loss: 1.124. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 800. Train Loss: 0.885. Test Loss: 1.089. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 810. Train Loss: 0.9088. Test Loss: 1.112. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 820. Train Loss: 0.9435. Test Loss: 1.146. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 830. Train Loss: 0.822. Test Loss: 1.099. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 840. Train Loss: 0.851. Test Loss: 1.141. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 850. Train Loss: 0.973. Test Loss: 1.131. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 860. Train Loss: 0.8957. Test Loss: 1.108. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 870. Train Loss: 0.9296. Test Loss: 1.083. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 880. Train Loss: 0.9732. Test Loss: 1.176. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 890. Train Loss: 0.9587. Test Loss: 1.174. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 900. Train Loss: 0.8759. Test Loss: 1.154. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 910. Train Loss: 0.9059. Test Loss: 1.118. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 920. Train Loss: 0.8836. Test Loss: 1.087. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 930. Train Loss: 0.8504. Test Loss: 1.186. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 940. Train Loss: 0.8651. Test Loss: 1.122. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 950. Train Loss: 0.8921. Test Loss: 1.179. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 960. Train Loss: 0.918. Test Loss: 1.21. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 970. Train Loss: 0.8153. Test Loss: 1.263. Train Acc: 0.6471. Test Acc:0.3636
# Epoch: 980. Train Loss: 0.8649. Test Loss: 1.204. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 990. Train Loss: 0.8013. Test Loss: 1.139. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 1000. Train Loss: 0.936. Test Loss: 1.162. Train Acc: 0.5294. Test Acc:0.3636

# %%
# raw_features.keys()
# ['wav2vec_features-c', 'wav2vec_features-z', 'retrained-wav2vec_features-c', 'retrained-wav2vec_features-z']
