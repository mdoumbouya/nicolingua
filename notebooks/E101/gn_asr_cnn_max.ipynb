# %%
from pathlib import Path
import csv
import itertools
import numpy as np
from pprint import PrettyPrinter


import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

import h5py

import sklearn
import sklearn.metrics

pprint = PrettyPrinter()

# %% [markdown]
# ## Configuration

# %%
SELECTED_LANGUAGES = {'_language_independent', 'francais', 'maninka', 'pular', 'susu'}

BASE_DIR = Path('/media/xtrem/data/experiments/nicolingua-0002-va-asr/datasets/gn_va_asr_dataset_2020-08-24_02')


ANNOTATIONS_PATH = BASE_DIR/ "annotated_segments" / "metadata.csv"


FEATURE_NAMES = [
    "wav2vec_features-c", 
    "wav2vec_features-z", 
    "retrained-wav2vec_features-c", 
    "retrained-wav2vec_features-z"
]

# CONV_POOLING_TYPES = ['avg', 'max']
CONV_POOLING_TYPES = ['max']
OBJECTIVE_TYPES = ['voice_cmd', 'voice_cmd__and__voice_cmd_lng']
CONV_DROPOUT_PROBABILITIES = [0.2]
FC_DROPOUT_PROBABILITIES = [0.2]


TRAIN_PERCENT = .7
FOLD_COUNT = 5


RESULTS_DIR = f'results_101'
EPOCHS = 1000
BATCH_SIZE = 512
MAX_FEATURE_SEQUENCE_LENGTH = 200

GPU_ID = 1
device = torch.device(f"cuda:{GPU_ID}")

# %% [markdown]
# ## Load & shuffle metadata records

# %%
def load_metadata():
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for r in reader:
            if r['language'] in SELECTED_LANGUAGES:
                yield r

# %%
# load
metadata_records = list(load_metadata())

# shuffle
metadata_shuffler_rs = np.random.RandomState(seed=42)
metadata_shuffler_rs.shuffle(metadata_records)

# %%
bias_category_fields = [
     "device_id"
    ,"language"
    ,"speaker_gender"
    ,"speaker_mothertongue"
]

bias_categories = {}
for c in bias_category_fields:
    bias_categories[c] = sorted({r[c] for r in metadata_records})


_ = [print(f"\n{k}: \n\t{','.join(v)}") for k,v in bias_categories.items()]
# Out:
# device_id:
# 	d001,d002,d003
#
# language:
# 	_language_independent,francais,maninka,pular,susu
#
# speaker_gender:
# 	F,M
#
# speaker_mothertongue:
# 	maninka,pular,susu

# %% [markdown]
# ### Labels

# %%
# VOICE COMMANDS
voice_cmd_class_names = sorted({r['label'] for r in metadata_records})
voice_cmd_class_count = len(voice_cmd_class_names)
voice_cmd_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_class_names)}

print("Classes - Voice Commands")
_ = [print(f"{v:4}: {k}") for k,v in voice_cmd_class_id_by_name.items()]

print("---------------------")


# VOICE COMMAND LANGUAGES
voice_cmd_lng_class_names = sorted({r['language'] for r in metadata_records})
voice_cmd_lng_class_count = len(voice_cmd_lng_class_names)
voice_cmd_lng_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_lng_class_names)}

print("Classes - Voice Command Languages")
_ = [print(f"{v:3}: {k}") for k,v in voice_cmd_lng_class_id_by_name.items()]

print("---------------------")



# SPEAKER MOTHERTONGUE
spkr_mothertongue_class_names = sorted({r['speaker_mothertongue'] for r in metadata_records})
spkr_mothertongue_class_count = len(spkr_mothertongue_class_names)
spkr_mothertongue_class_id_by_name = {c:i for i,c in enumerate(spkr_mothertongue_class_names)}

print("Classes - Speaker Mothertongues")
_ = [print(f"{v:3}: {k}") for k,v in spkr_mothertongue_class_id_by_name.items()]

print("---------------------")



# SPEAKER GENDER
spkr_gender_class_names = sorted({r['speaker_gender'] for r in metadata_records})
spkr_gender_class_count = len(spkr_gender_class_names)
spkr_gender_class_id_by_name = {c:i for i, c in enumerate(spkr_gender_class_names)}

print("Classes - Speaker Gender")
_ = [print(f"{v:3}: {k}") for k,v in spkr_gender_class_id_by_name.items()]

print("----------------------")
# Out:
# Classes - Voice Commands
#    0: 101_wake_word__francais
#    1: 101_wake_word__maninka
#    2: 101_wake_word__pular
#    3: 101_wake_word__susu
#    4: 201_add_contact__francais
#    5: 201_add_contact__maninka
#    6: 201_add_contact__pular
#    7: 201_add_contact__susu
#    8: 202_search_contact__francais
#    9: 202_search_contact__maninka
#   10: 202_search_contact__pular
#   11: 202_search_contact__susu
#   12: 203_update_contact__francais
#   13: 203_update_contact__maninka
#   14: 203_update_contact__pular
#   15: 203_update_contact__susu
#   16: 204_delete_contact__francais
#   17: 204_delete_contact__maninka
#   18: 204_delete_contact__pular
#   19: 204_delete_contact__susu
#   20: 205_call_contact__francais
#   21: 205_call_contact__maninka
#   22: 205_call_contact__pular
#   23: 205_call_contact__susu
#   24: 206_yes__francais
#   25: 206_yes__maninka
#   26: 206_yes__pular
#   27: 206_yes__susu
#   28: 207_no__francais
#   29: 207_no__maninka
#   30: 207_no__pular
#   31: 207_no__susu
#   32: 301_zero__francais
#   33: 301_zero__maninka
#   34: 301_zero__pular
#   35: 301_zero__susu
#   36: 302_one__francais
#   37: 302_one__maninka
#   38: 302_one__pular
#   39: 302_one__susu
#   40: 303_two__francais
#   41: 303_two__maninka
#   42: 303_two__pular
#   43: 303_two__susu
#   44: 304_three__francais
#   45: 304_three__maninka
#   46: 304_three__pular
#   47: 304_three__susu
#   48: 305_four__francais
#   49: 305_four__maninka
#   50: 305_four__pular
#   51: 305_four__susu
#   52: 306_five__francais
#   53: 306_five__maninka
#   54: 306_five__pular
#   55: 306_five__susu
#   56: 307_six__francais
#   57: 307_six__maninka
#   58: 307_six__pular
#   59: 307_six__susu
#   60: 308_seven__francais
#   61: 308_seven__maninka
#   62: 308_seven__pular
#   63: 308_seven__susu
#   64: 309_eight__francais
#   65: 309_eight__maninka
#   66: 309_eight__pular
#   67: 309_eight__susu
#   68: 310_nine__francais
#   69: 310_nine__maninka
#   70: 310_nine__pular
#   71: 310_nine__susu
#   72: 401_mom__francais
#   73: 401_mom__maninka
#   74: 401_mom__pular
#   75: 401_mom__susu
#   76: 402_dad__francais
#   77: 402_dad__maninka
#   78: 402_dad__pular
#   79: 402_dad__susu
#   80: 501_fatoumata___language_independent
#   81: 502_mamadou___language_independent
#   82: 503_mariama___language_independent
#   83: 504_mohamed___language_independent
#   84: 505_kadiatou___language_independent
#   85: 506_ibrahima___language_independent
#   86: 507_aissatou___language_independent
#   87: 508_aminata___language_independent
#   88: 509_alpha___language_independent
#   89: 510_thierno___language_independent
#   90: 511_abdoulaye___language_independent
#   91: 512_aboubacar___language_independent
#   92: 513_amadou___language_independent
#   93: 514_fanta___language_independent
#   94: 515_mariame___language_independent
#   95: 516_oumou___language_independent
#   96: 517_ousmane___language_independent
#   97: 518_adama___language_independent
#   98: 519_marie___language_independent
#   99: 520_moussa___language_independent
#  100: 521_aissata___language_independent
#  101: 522_hawa___language_independent
#  102: 523_sekou___language_independent
#  103: 524_hadja___language_independent
#  104: 525_djenabou___language_independent
# ---------------------
# Classes - Voice Command Languages
#   0: _language_independent
#   1: francais
#   2: maninka
#   3: pular
#   4: susu
# ---------------------
# Classes - Speaker Mothertongues
#   0: maninka
#   1: pular
#   2: susu
# ---------------------
# Classes - Speaker Gender
#   0: F
#   1: M
# ----------------------

# %% [markdown]
# ### Inspect metadata

# %%
def count_by_attribute(records, attribute_names):
    attribute_name_instances = {}
    for attribute_name in attribute_names:
        attribute_name_instances[attribute_name] = {r[attribute_name] for r in records}
        
    l = [attribute_name_instances[attribute_name] for attribute_name in attribute_names]
    
    
    
    for attribute_values in sorted(itertools.product(*l)):
        
        def record_match(r):
            for i in range(len(attribute_names)):
                if r[attribute_names[i]] != attribute_values[i]:
                    return False
            return True
            
        record_instances = [r for r in records if record_match(r)]
        count = len(record_instances)
        
        yield (attribute_values, count)

# %%
print("RECORDS BY DEVICE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['device_id']))]
print("")

print("RECORDS BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['language']))]
print("")

print("RECORDS BY GENDER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_gender']))]
print("")

print("RECORDS BY AGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_age']))]
print("")

print("RECORDS BY SPEAKER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id']))]
print("")

print("RECORDS BY SPEAKER BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id', 'language']))]
print("")

print("RECORDS BY SPEAKER BY LABEL")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['label']))]
print("")
# Out:
# RECORDS BY DEVICE
# 	(('d001',), 2759)
# 	(('d002',), 2741)
# 	(('d003',), 2759)
#
# RECORDS BY LANGUAGE
# 	(('_language_independent',), 3072)
# 	(('francais',), 1260)
# 	(('maninka',), 1356)
# 	(('pular',), 909)
# 	(('susu',), 1662)
#
# RECORDS BY GENDER
# 	(('F',), 2820)
# 	(('M',), 5439)
#
# RECORDS BY AGE
# 	(('12',), 237)
# 	(('13',), 252)
# 	(('15',), 603)
# 	(('17',), 1050)
# 	(('18',), 855)
# 	(('19',), 273)
# 	(('20',), 291)
# 	(('27',), 255)
# 	(('28',), 183)
# 	(('29',), 237)
# 	(('31',), 255)
# 	(('32',), 291)
# 	(('33',), 183)
# 	(('34',), 129)
# 	(('35',), 498)
# 	(('37',), 309)
# 	(('38',), 441)
# 	(('43',), 183)
# 	(('44',), 540)
# 	(('5',), 129)
# 	(('55',), 183)
# 	(('61',), 390)
# 	(('63',), 237)
# 	(('67',), 255)
#
# RECORDS BY SPEAKER
# 	(('s001',), 183)
# 	(('s002',), 129)
# 	(('s003',), 183)
# 	(('s004',), 183)
# 	(('s005',), 129)
# 	(('s006',), 129)
# 	(('s007',), 183)
# 	(('s008',), 129)
# 	(('s009',), 237)
# 	(('s010',), 291)
# 	(('s011',), 129)
# 	(('s012',), 183)
# 	(('s013',), 129)
# 	(('s014',), 237)
# 	(('s015',), 291)
# 	(('s016',), 183)
# 	(('s017',), 237)
# 	(('s018',), 237)
# 	(('s019',), 237)
# 	(('s020',), 291)
# 	(('s021',), 273)
# 	(('s022',), 183)
# 	(('s023',), 309)
# 	(('s024',), 255)
# 	(('s025',), 315)
# 	(('s026',), 252)
# 	(('s027',), 540)
# 	(('s028',), 540)
# 	(('s029',), 390)
# 	(('s030',), 195)
# 	(('s031',), 252)
# 	(('s032',), 315)
# 	(('s033',), 255)
# 	(('s034',), 255)
#
# RECORDS BY SPEAKER BY LANGUAGE
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'francais'), 0)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'pular'), 0)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'francais'), 0)
# 	(('s002', 'maninka'), 54)
# 	(('s002', 'pular'), 0)
# 	(('s002', 'susu'), 0)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'francais'), 0)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'pular'), 0)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'francais'), 0)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'pular'), 0)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'francais'), 0)
# 	(('s005', 'maninka'), 0)
# 	(('s005', 'pular'), 0)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'francais'), 0)
# 	(('s006', 'maninka'), 54)
# 	(('s006', 'pular'), 0)
# 	(('s006', 'susu'), 0)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'francais'), 0)
# 	(('s007', 'maninka'), 0)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'francais'), 0)
# 	(('s008', 'maninka'), 54)
# 	(('s008', 'pular'), 0)
# 	(('s008', 'susu'), 0)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'maninka'), 0)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'francais'), 0)
# 	(('s011', 'maninka'), 0)
# 	(('s011', 'pular'), 0)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'maninka'), 0)
# 	(('s012', 'pular'), 0)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'francais'), 0)
# 	(('s013', 'maninka'), 0)
# 	(('s013', 'pular'), 0)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'pular'), 0)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'francais'), 0)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'pular'), 0)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'maninka'), 0)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'maninka'), 0)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'pular'), 0)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'francais'), 0)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'pular'), 0)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'pular'), 0)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'pular'), 0)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'maninka'), 0)
# 	(('s030', 'pular'), 60)
# 	(('s030', 'susu'), 0)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'maninka'), 0)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'pular'), 0)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'pular'), 0)
# 	(('s034', 'susu'), 60)
#
# RECORDS BY SPEAKER BY LABEL
# 	(('101_wake_word__francais',), 66)
# 	(('101_wake_word__maninka',), 72)
# 	(('101_wake_word__pular',), 48)
# 	(('101_wake_word__susu',), 89)
# 	(('201_add_contact__francais',), 66)
# 	(('201_add_contact__maninka',), 72)
# 	(('201_add_contact__pular',), 48)
# 	(('201_add_contact__susu',), 89)
# 	(('202_search_contact__francais',), 66)
# 	(('202_search_contact__maninka',), 72)
# 	(('202_search_contact__pular',), 48)
# 	(('202_search_contact__susu',), 89)
# 	(('203_update_contact__francais',), 66)
# 	(('203_update_contact__maninka',), 72)
# 	(('203_update_contact__pular',), 48)
# 	(('203_update_contact__susu',), 89)
# 	(('204_delete_contact__francais',), 66)
# 	(('204_delete_contact__maninka',), 72)
# 	(('204_delete_contact__pular',), 48)
# 	(('204_delete_contact__susu',), 89)
# 	(('205_call_contact__francais',), 66)
# 	(('205_call_contact__maninka',), 72)
# 	(('205_call_contact__pular',), 45)
# 	(('205_call_contact__susu',), 89)
# 	(('206_yes__francais',), 66)
# 	(('206_yes__maninka',), 72)
# 	(('206_yes__pular',), 48)
# 	(('206_yes__susu',), 89)
# 	(('207_no__francais',), 66)
# 	(('207_no__maninka',), 72)
# 	(('207_no__pular',), 48)
# 	(('207_no__susu',), 89)
# 	(('301_zero__francais',), 66)
# 	(('301_zero__maninka',), 72)
# 	(('301_zero__pular',), 48)
# 	(('301_zero__susu',), 89)
# 	(('302_one__francais',), 66)
# 	(('302_one__maninka',), 72)
# 	(('302_one__pular',), 48)
# 	(('302_one__susu',), 89)
# 	(('303_two__francais',), 66)
# 	(('303_two__maninka',), 72)
# 	(('303_two__pular',), 48)
# 	(('303_two__susu',), 89)
# 	(('304_three__francais',), 66)
# 	(('304_three__maninka',), 72)
# 	(('304_three__pular',), 48)
# 	(('304_three__susu',), 89)
# 	(('305_four__francais',), 66)
# 	(('305_four__maninka',), 72)
# 	(('305_four__pular',), 48)
# 	(('305_four__susu',), 89)
# 	(('306_five__francais',), 66)
# 	(('306_five__maninka',), 72)
# 	(('306_five__pular',), 48)
# 	(('306_five__susu',), 89)
# 	(('307_six__francais',), 66)
# 	(('307_six__maninka',), 72)
# 	(('307_six__pular',), 48)
# 	(('307_six__susu',), 89)
# 	(('308_seven__francais',), 66)
# 	(('308_seven__maninka',), 72)
# 	(('308_seven__pular',), 48)
# 	(('308_seven__susu',), 89)
# 	(('309_eight__francais',), 66)
# 	(('309_eight__maninka',), 72)
# 	(('309_eight__pular',), 48)
# 	(('309_eight__susu',), 89)
# 	(('310_nine__francais',), 66)
# 	(('310_nine__maninka',), 72)
# 	(('310_nine__pular',), 48)
# 	(('310_nine__susu',), 89)
# 	(('401_mom__francais',), 36)
# 	(('401_mom__maninka',), 30)
# 	(('401_mom__pular',), 24)
# 	(('401_mom__susu',), 30)
# 	(('402_dad__francais',), 36)
# 	(('402_dad__maninka',), 30)
# 	(('402_dad__pular',), 24)
# 	(('402_dad__susu',), 30)
# 	(('501_fatoumata___language_independent',), 123)
# 	(('502_mamadou___language_independent',), 123)
# 	(('503_mariama___language_independent',), 123)
# 	(('504_mohamed___language_independent',), 123)
# 	(('505_kadiatou___language_independent',), 123)
# 	(('506_ibrahima___language_independent',), 123)
# 	(('507_aissatou___language_independent',), 123)
# 	(('508_aminata___language_independent',), 123)
# 	(('509_alpha___language_independent',), 123)
# 	(('510_thierno___language_independent',), 120)
# 	(('511_abdoulaye___language_independent',), 123)
# 	(('512_aboubacar___language_independent',), 123)
# 	(('513_amadou___language_independent',), 123)
# 	(('514_fanta___language_independent',), 123)
# 	(('515_mariame___language_independent',), 123)
# 	(('516_oumou___language_independent',), 123)
# 	(('517_ousmane___language_independent',), 123)
# 	(('518_adama___language_independent',), 123)
# 	(('519_marie___language_independent',), 123)
# 	(('520_moussa___language_independent',), 123)
# 	(('521_aissata___language_independent',), 123)
# 	(('522_hawa___language_independent',), 123)
# 	(('523_sekou___language_independent',), 123)
# 	(('524_hadja___language_independent',), 123)
# 	(('525_djenabou___language_independent',), 123)

# %% [markdown]
# ## Prepare Cross Validation Folds
# - Partition by (speaker, language)
# - Each (speaker, language) correspond to `utterance_count * device_count`
# - For each fold, all `utterance_count * device_count` records for the same speaker in the same language are either in the TRAIN or the VALIDATION sets, but not both.

# %%
def generate_train_test_records_per_fold(all_records):
    records_per_fold = {}
    
    all_speaker_languages = sorted({(r['speaker_id'], r['language']) for r in all_records})

    sl_count = len(all_speaker_languages)
    all_sl_indices = range(sl_count)
    train_sl_count = int(np.ceil(sl_count*TRAIN_PERCENT))
    test_sl_count = sl_count - train_sl_count

    for fold_index in range(FOLD_COUNT):
        fold_rsampler = np.random.RandomState(seed=fold_index)

        train_sl_index_set = set(fold_rsampler.choice(all_sl_indices, train_sl_count, replace=False))
        train_sl_set = {all_speaker_languages[i] for i in train_sl_index_set}

        test_sl_index_set = set(all_sl_indices).difference(train_sl_index_set)
        test_sl_set = {all_speaker_languages[i] for i in test_sl_index_set}

        train_records = [r for r in all_records if (r['speaker_id'], r['language']) in train_sl_set]
        test_records = [r for r in all_records if (r['speaker_id'], r['language']) in test_sl_set]
        
        
        records_per_fold[fold_index] = {
            "train_records": train_records,
            "test_records": test_records
        }
    
    return records_per_fold

# %%
records_per_fold = generate_train_test_records_per_fold(metadata_records)

# %% [markdown]
# ### Inspect Folds

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['speaker_id', 'language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['speaker_id', 'language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', '_language_independent'), 75)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 0 -- TEST
# 	(('s004', 'maninka'), 54)
# 	(('s005', 'susu'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'susu'), 54)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 1 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'susu'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 1 -- TEST
# 	(('s001', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s030', 'francais'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s033', 'susu'), 60)
# ---------------------
# Fold 2 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', 'francais'), 54)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 2 -- TEST
# 	(('s002', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s033', '_language_independent'), 75)
# ---------------------
# Fold 3 -- TRAIN
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', 'susu'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 3 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s006', 'maninka'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s029', 'francais'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 4 -- TRAIN
# 	(('s001', 'susu'), 54)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'susu'), 54)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'susu'), 60)
# Fold 4 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN: ({len(train_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST: ({len(test_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN: (6018)
# 	(('_language_independent',), 2400)
# 	(('francais',), 738)
# 	(('maninka',), 960)
# 	(('pular',), 852)
# 	(('susu',), 1068)
# Fold 0 -- TEST: (2241)
# 	(('_language_independent',), 672)
# 	(('francais',), 522)
# 	(('maninka',), 396)
# 	(('pular',), 57)
# 	(('susu',), 594)
# ---------------------
# Fold 1 -- TRAIN: (5940)
# 	(('_language_independent',), 2325)
# 	(('francais',), 978)
# 	(('maninka',), 906)
# 	(('pular',), 519)
# 	(('susu',), 1212)
# Fold 1 -- TEST: (2319)
# 	(('_language_independent',), 747)
# 	(('francais',), 282)
# 	(('maninka',), 450)
# 	(('pular',), 390)
# 	(('susu',), 450)
# ---------------------
# Fold 2 -- TRAIN: (6036)
# 	(('_language_independent',), 2397)
# 	(('francais',), 972)
# 	(('maninka',), 912)
# 	(('pular',), 573)
# 	(('susu',), 1182)
# Fold 2 -- TEST: (2223)
# 	(('_language_independent',), 675)
# 	(('francais',), 288)
# 	(('maninka',), 444)
# 	(('pular',), 336)
# 	(('susu',), 480)
# ---------------------
# Fold 3 -- TRAIN: (5796)
# 	(('_language_independent',), 2097)
# 	(('francais',), 918)
# 	(('maninka',), 912)
# 	(('pular',), 801)
# 	(('susu',), 1068)
# Fold 3 -- TEST: (2463)
# 	(('_language_independent',), 975)
# 	(('francais',), 342)
# 	(('maninka',), 444)
# 	(('pular',), 108)
# 	(('susu',), 594)
# ---------------------
# Fold 4 -- TRAIN: (6003)
# 	(('_language_independent',), 2325)
# 	(('francais',), 924)
# 	(('maninka',), 906)
# 	(('pular',), 558)
# 	(('susu',), 1290)
# Fold 4 -- TEST: (2256)
# 	(('_language_independent',), 747)
# 	(('francais',), 336)
# 	(('maninka',), 450)
# 	(('pular',), 351)
# 	(('susu',), 372)
# ---------------------

# %% [markdown]
# ## Load Features

# %%
def load_features(records, feature_name):
    features_list = []
    
    features_input_dir = BASE_DIR / feature_name

    for r in records:
        feature_file_name = r['file'].replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            
            padded_features = np.zeros((MAX_FEATURE_SEQUENCE_LENGTH, 512), dtype=features.dtype)
            padded_features[:features_shape[0], :] = features
            
            
            features_list.append(padded_features)
    return features_list

# %%
def get_bias_category_labels(records):
    bias_category_labels = {}
    
    for cat in bias_categories:
        for cat_val in bias_categories[cat]:
            bias_category_labels[f"{cat}__{cat_val}"] = [1 if r[cat]==cat_val else 0 for r in records]
            
    return bias_category_labels

# %% [markdown]
# # Classification Models

# %%
class ASRCNN(nn.Module):
    def __init__(self, 
                 conv_pooling_type, 
                 conv_dropout_p, 
                 fc_dropout_p, 
                 voice_cmd_neuron_count, 
                 voice_cmd_lng_neuron_count,
                 objective_type
                ):
        
        super(ASRCNN, self).__init__()
        
        if conv_pooling_type not in {"max", "avg"}:
            raise ValueError(f"Unknown Conv Pooling Type: {conv_pooling_type}")
            
        conv_pooling_class_by_type = {
            "max": nn.MaxPool1d,
            "avg": nn.AvgPool1d,
        }
        
        conv_pooling_class = conv_pooling_class_by_type[conv_pooling_type]
        
        self.objective_type = objective_type
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=8, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=3)
        self.drop1 = nn.Dropout(p=conv_dropout_p)
        self.pool1 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=8, out_channels=16, kernel_size=3)
        self.drop2 = nn.Dropout(p=conv_dropout_p)
        self.pool2 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3)
        self.drop3 = nn.Dropout(p=conv_dropout_p)
        self.pool3 = conv_pooling_class(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3)
        self.drop4 = nn.Dropout(p=conv_dropout_p)
        self.pool4 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)
        
        self.lin61 = nn.Linear(in_features=112, out_features=voice_cmd_neuron_count)
        
        # 'voice_cmd', 'voice_cmd__and__voice_cmd_lng'
        if self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            self.lin62 = nn.Linear(in_features=112, out_features=voice_cmd_lng_neuron_count)
                
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        if self.objective_type == 'voice_cmd':
            logits_voice_cmd = self.lin61(v)
            return logits_voice_cmd
        elif self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd = self.lin61(v)
            logits_voice_cmd_lng = self.lin62(v)
            return logits_voice_cmd, logits_voice_cmd_lng
        else:
            raise(f"Unknown objective type: {self.objective_type}")

# %%
def get_data_for_fold(fold_id, feature_name):
    
    train_records = records_per_fold[fold_id]["train_records"]
    test_records = records_per_fold[fold_id]["test_records"]
    
    train_features = load_features(train_records, feature_name)
    test_features = load_features(test_records, feature_name)
    
    train_x = np.array(train_features)
    test_x = np.array(test_features)
    
    train_y = {}
    train_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in train_records])
    train_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in train_records])
    train_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in train_records])
    train_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in train_records])
    
    

    
    test_y = {}
    test_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in test_records])
    test_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in test_records])
    test_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in test_records])
    test_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in test_records])

    train_bias_category_labels = get_bias_category_labels(train_records)
    test_bias_category_labels = get_bias_category_labels(test_records)
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y['voice_cmd']),
        torch.tensor(train_y['voice_cmd_lng']),
        # torch.tensor(train_y['spkr_mothertongue']),
        # torch.tensor(train_y['spkr_gender']),
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y['voice_cmd']),
        torch.tensor(test_y['voice_cmd_lng']),
        # torch.tensor(test_y['spkr_mothertongue']),
        # torch.tensor(test_y['spkr_gender']),
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
def train(model, optimizer, criterion, objective_type, train_loader):
    model.train()
    train_loss = 0

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(train_loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        optimizer.zero_grad()
        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs
            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs    
            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) / 2
            
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        

def test(model, criterion, objective_type, loader, bias_category_labels):
    model.eval()
    accumulated_loss = 0

    pred_classes = []
    true_classes = []

    pred_classes_lng = []
    true_classes_lng = []

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs

            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs
            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            pred_classes_lng.extend(
                get_predictions_for_logits(logits_voice_cmd_lng).cpu().numpy()
            )
            true_classes_lng.extend(y_voice_cmd_lng.cpu().numpy())

            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) /2
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        accumulated_loss += loss.item()

    n = len(true_classes)

    average_loss = accumulated_loss/n
    
    acc = sklearn.metrics.accuracy_score(true_classes, pred_classes)
    acc_by_bais_category = {
        category: sklearn.metrics.accuracy_score(true_classes, pred_classes, sample_weight=sw)
        for category, sw in bias_category_labels.items()
    }
    
    
    if objective_type == 'voice_cmd__and__voice_cmd_lng':
        acc_lng = sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng)
        acc_by_bais_category_lng = {
            category: sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng, sample_weight=sw)
            for category, sw in bias_category_labels.items()
        }
    else:
        acc_lng = -1
        acc_by_bais_category_lng = {
            category: -1
            for category, sw in bias_category_labels.items()
        }
        
    return n, average_loss, acc, acc_by_bais_category, acc_lng, acc_by_bais_category_lng
      
        
def train_on_fold(model, fold_id, feature_name, objective_type, batch_size, epochs):
    torch.manual_seed(0)
    results = {}
    
    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model, torch.zeros((10, MAX_FEATURE_SEQUENCE_LENGTH, 512)).to(device), show_input=False))
    print(f"train_n: {len(train_loader.dataset)}")
    print(f"test_n: {len(test_loader.dataset)}")

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(reduction='sum')

    for epoch in range(1, epochs+1):
        
        # train on training set
        train(model, optimizer, criterion, objective_type, train_loader)
        
        # test on training set
        train_n, train_average_loss, train_acc, train_acc_by_bais_category, train_acc_lng, train_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, train_loader, train_bias_category_labels)
        
        # test on test set
        test_n, test_average_loss, test_acc, test_acc_by_bais_category, test_acc_lng, test_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, test_loader, test_bias_category_labels)
        

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_average_loss:0.4}. Test Loss: {test_average_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
         
        results[epoch] = {
            'epoch': epoch,
            
            'train_n': train_n,
            'train_loss': train_average_loss,
            'train_acc': train_acc,
            'train_acc_lng': train_acc_lng,
            
            'test_n': test_n,
            'test_loss': test_average_loss,
            'test_acc': test_acc,
            'test_acc_lng': test_acc_lng
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in train_acc_by_bais_category_lng:
            results[epoch][f"train_acc_lng_{c}"] = train_acc_by_bais_category_lng[c]
            
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))

        for c in test_acc_by_bais_category_lng:
            results[epoch][f"test_acc_lng_{c}"] = test_acc_by_bais_category_lng[c]
            

    return results

# %%
import csv
from pathlib import Path

def results_exist(model_name, feature_name, fold_id):
    fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_id}.csv"
    return Path(fname).is_file()
    

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='raise')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
trial_params = list(
    itertools.product(
        range(FOLD_COUNT),
        CONV_POOLING_TYPES,
        CONV_DROPOUT_PROBABILITIES,
        FC_DROPOUT_PROBABILITIES,
        FEATURE_NAMES, 
        OBJECTIVE_TYPES
    )
)    

print("Plan:")
_ = [print(t) for t in trial_params]
print()

for fold_id, conv_pooling_type, conv_dropout_p, fc_dropout_p, feature_name, objective_type in trial_params:

    model_name = f"ASRCNN" + \
    f"__conv_pool_{conv_pooling_type}" + \
    f"__conv_dp_{conv_dropout_p}" + \
    f"__fc_dp_{fc_dropout_p}" + \
    f"__fn_{feature_name}" + \
    f"__obj_{objective_type}"

    if results_exist(model_name, feature_name, fold_id):
        print(f"skipping ({fold_id}, {conv_pooling_type}, {conv_dropout_p}, {fc_dropout_p}, {feature_name}, {objective_type})")
        continue

        
    model = ASRCNN(
        conv_pooling_type, 
        conv_dropout_p, 
        fc_dropout_p, 
        voice_cmd_neuron_count = voice_cmd_class_count, 
        voice_cmd_lng_neuron_count = voice_cmd_lng_class_count,
        objective_type = objective_type
    ).to(device)

    print(f"{model_name} using {feature_name} on fold#{fold_id}")

    epochs_results = train_on_fold(
        model, 
        fold_id, 
        feature_name, 
        objective_type, 
        batch_size = BATCH_SIZE, 
        epochs = EPOCHS
    )

    # results for only one fold
    folds_results = [{
        'fold_index': fold_id,
        'feature_name': feature_name,
        'epochs': epochs_results
    }]
    
    
    save_results(model_name, folds_results)
    # write_epoch_test_logits(model_name, all_folds_results)

    del model
# Out:
# Plan:
# (0, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (0, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (0, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (0, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (0, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (1, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (1, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (1, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (1, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (2, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (2, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (2, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (2, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (3, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (3, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (3, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (3, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (4, 'max', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (4, 'max', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (4, 'max', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (4, 'max', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
#
# ASRCNN__conv_pool_max__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-c__obj_voice_cmd using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.302. Test Loss: 3.387. Train Acc: 0.1587. Test Acc:0.137
# Epoch: 20. Train Loss: 2.499. Test Loss: 2.742. Train Acc: 0.3519. Test Acc:0.2682
# Epoch: 30. Train Loss: 1.825. Test Loss: 2.182. Train Acc: 0.5339. Test Acc:0.419
# Epoch: 40. Train Loss: 1.375. Test Loss: 1.772. Train Acc: 0.6607. Test Acc:0.539
# Epoch: 50. Train Loss: 1.122. Test Loss: 1.58. Train Acc: 0.724. Test Acc:0.5734
# Epoch: 60. Train Loss: 0.9098. Test Loss: 1.416. Train Acc: 0.7855. Test Acc:0.6238
# Epoch: 70. Train Loss: 0.749. Test Loss: 1.274. Train Acc: 0.829. Test Acc:0.672
# Epoch: 80. Train Loss: 0.6589. Test Loss: 1.231. Train Acc: 0.8471. Test Acc:0.6845
# Epoch: 90. Train Loss: 0.5599. Test Loss: 1.166. Train Acc: 0.875. Test Acc:0.6939
# Epoch: 100. Train Loss: 0.479. Test Loss: 1.1. Train Acc: 0.8942. Test Acc:0.7175
# Epoch: 110. Train Loss: 0.4413. Test Loss: 1.081. Train Acc: 0.905. Test Acc:0.7256
# Epoch: 120. Train Loss: 0.3956. Test Loss: 1.066. Train Acc: 0.9186. Test Acc:0.7305
# Epoch: 130. Train Loss: 0.3788. Test Loss: 1.064. Train Acc: 0.9141. Test Acc:0.7372
# Epoch: 140. Train Loss: 0.3371. Test Loss: 1.035. Train Acc: 0.93. Test Acc:0.7425
# Epoch: 150. Train Loss: 0.3204. Test Loss: 1.034. Train Acc: 0.9309. Test Acc:0.7394
# Epoch: 160. Train Loss: 0.3021. Test Loss: 1.048. Train Acc: 0.9315. Test Acc:0.7363
# Epoch: 170. Train Loss: 0.2621. Test Loss: 1.03. Train Acc: 0.9398. Test Acc:0.7434
# Epoch: 180. Train Loss: 0.2636. Test Loss: 1.058. Train Acc: 0.9407. Test Acc:0.7327
# Epoch: 190. Train Loss: 0.2631. Test Loss: 1.073. Train Acc: 0.9347. Test Acc:0.7332
# Epoch: 200. Train Loss: 0.2408. Test Loss: 1.057. Train Acc: 0.9413. Test Acc:0.7434
# Epoch: 210. Train Loss: 0.2033. Test Loss: 0.984. Train Acc: 0.9545. Test Acc:0.7689
# Epoch: 220. Train Loss: 0.1977. Test Loss: 1.036. Train Acc: 0.9548. Test Acc:0.7523
# Epoch: 230. Train Loss: 0.2037. Test Loss: 1.04. Train Acc: 0.95. Test Acc:0.7497
# Epoch: 240. Train Loss: 0.1918. Test Loss: 1.058. Train Acc: 0.9543. Test Acc:0.755
# Epoch: 250. Train Loss: 0.2167. Test Loss: 1.124. Train Acc: 0.9413. Test Acc:0.7416
# Epoch: 260. Train Loss: 0.2049. Test Loss: 1.126. Train Acc: 0.9437. Test Acc:0.739
# Epoch: 270. Train Loss: 0.1857. Test Loss: 1.099. Train Acc: 0.9526. Test Acc:0.7532
# Epoch: 280. Train Loss: 0.1276. Test Loss: 1.033. Train Acc: 0.9714. Test Acc:0.7733
# Epoch: 290. Train Loss: 0.1045. Test Loss: 1.012. Train Acc: 0.9772. Test Acc:0.7787
# Epoch: 300. Train Loss: 0.1003. Test Loss: 1.019. Train Acc: 0.9781. Test Acc:0.7782
# Epoch: 310. Train Loss: 0.08797. Test Loss: 1.021. Train Acc: 0.9834. Test Acc:0.7787
# Epoch: 320. Train Loss: 0.08597. Test Loss: 1.041. Train Acc: 0.9852. Test Acc:0.7738
# Epoch: 330. Train Loss: 0.07707. Test Loss: 1.055. Train Acc: 0.9854. Test Acc:0.7782
# Epoch: 340. Train Loss: 0.07312. Test Loss: 1.068. Train Acc: 0.9875. Test Acc:0.7751
# Epoch: 350. Train Loss: 0.06833. Test Loss: 1.064. Train Acc: 0.9865. Test Acc:0.7787
# Epoch: 360. Train Loss: 0.06745. Test Loss: 1.077. Train Acc: 0.9872. Test Acc:0.7778
# Epoch: 370. Train Loss: 0.05388. Test Loss: 1.106. Train Acc: 0.9932. Test Acc:0.7796
# Epoch: 380. Train Loss: 0.05169. Test Loss: 1.101. Train Acc: 0.9925. Test Acc:0.7787
# Epoch: 390. Train Loss: 0.05687. Test Loss: 1.111. Train Acc: 0.99. Test Acc:0.776
# Epoch: 400. Train Loss: 0.04985. Test Loss: 1.105. Train Acc: 0.9927. Test Acc:0.7796
# Epoch: 410. Train Loss: 0.04218. Test Loss: 1.113. Train Acc: 0.9955. Test Acc:0.7849
# Epoch: 420. Train Loss: 0.04813. Test Loss: 1.126. Train Acc: 0.9929. Test Acc:0.7773
# Epoch: 430. Train Loss: 0.04171. Test Loss: 1.121. Train Acc: 0.9963. Test Acc:0.7778
# Epoch: 440. Train Loss: 0.04241. Test Loss: 1.144. Train Acc: 0.9939. Test Acc:0.7764
# Epoch: 450. Train Loss: 0.04048. Test Loss: 1.135. Train Acc: 0.9953. Test Acc:0.7831
# Epoch: 460. Train Loss: 0.03851. Test Loss: 1.132. Train Acc: 0.9963. Test Acc:0.7867
# Epoch: 470. Train Loss: 0.03794. Test Loss: 1.156. Train Acc: 0.9952. Test Acc:0.7827
# Epoch: 480. Train Loss: 0.0434. Test Loss: 1.175. Train Acc: 0.9925. Test Acc:0.7733
# Epoch: 490. Train Loss: 0.02869. Test Loss: 1.163. Train Acc: 0.9978. Test Acc:0.7867
# Epoch: 500. Train Loss: 0.03276. Test Loss: 1.174. Train Acc: 0.997. Test Acc:0.7791
# Epoch: 510. Train Loss: 0.03528. Test Loss: 1.171. Train Acc: 0.9955. Test Acc:0.7769
# Epoch: 520. Train Loss: 0.02681. Test Loss: 1.184. Train Acc: 0.9972. Test Acc:0.7805
# Epoch: 530. Train Loss: 0.03155. Test Loss: 1.2. Train Acc: 0.9967. Test Acc:0.7715
# Epoch: 540. Train Loss: 0.02142. Test Loss: 1.178. Train Acc: 0.9987. Test Acc:0.7885
# Epoch: 550. Train Loss: 0.02521. Test Loss: 1.193. Train Acc: 0.9972. Test Acc:0.7863
# Epoch: 560. Train Loss: 0.0225. Test Loss: 1.194. Train Acc: 0.9985. Test Acc:0.784
# Epoch: 570. Train Loss: 0.02632. Test Loss: 1.217. Train Acc: 0.9972. Test Acc:0.7827
# Epoch: 580. Train Loss: 0.01943. Test Loss: 1.197. Train Acc: 0.9985. Test Acc:0.7885
# Epoch: 590. Train Loss: 0.0246. Test Loss: 1.193. Train Acc: 0.9973. Test Acc:0.7854
# Epoch: 600. Train Loss: 0.02087. Test Loss: 1.199. Train Acc: 0.9987. Test Acc:0.7889
# Epoch: 610. Train Loss: 0.02017. Test Loss: 1.244. Train Acc: 0.9988. Test Acc:0.7818
# Epoch: 620. Train Loss: 0.02508. Test Loss: 1.257. Train Acc: 0.997. Test Acc:0.776
# Epoch: 630. Train Loss: 0.01481. Test Loss: 1.193. Train Acc: 0.9995. Test Acc:0.7979
# Epoch: 640. Train Loss: 0.0171. Test Loss: 1.214. Train Acc: 0.9988. Test Acc:0.7974
# Epoch: 650. Train Loss: 0.01336. Test Loss: 1.258. Train Acc: 0.9992. Test Acc:0.7925
# Epoch: 660. Train Loss: 0.016. Test Loss: 1.293. Train Acc: 0.9987. Test Acc:0.7805
# Epoch: 670. Train Loss: 0.01599. Test Loss: 1.254. Train Acc: 0.9992. Test Acc:0.7867
# Epoch: 680. Train Loss: 0.01764. Test Loss: 1.273. Train Acc: 0.999. Test Acc:0.7854
# Epoch: 690. Train Loss: 0.02533. Test Loss: 1.286. Train Acc: 0.9967. Test Acc:0.7733
# Epoch: 700. Train Loss: 0.01887. Test Loss: 1.272. Train Acc: 0.998. Test Acc:0.78
# Epoch: 710. Train Loss: 0.01585. Test Loss: 1.244. Train Acc: 0.9988. Test Acc:0.7934
# Epoch: 720. Train Loss: 0.01612. Test Loss: 1.299. Train Acc: 0.9983. Test Acc:0.7822
# Epoch: 730. Train Loss: 0.01906. Test Loss: 1.31. Train Acc: 0.9977. Test Acc:0.7805
# Epoch: 740. Train Loss: 0.01188. Test Loss: 1.228. Train Acc: 0.9995. Test Acc:0.7996
# Epoch: 750. Train Loss: 0.01435. Test Loss: 1.308. Train Acc: 0.999. Test Acc:0.7827
# Epoch: 760. Train Loss: 0.01103. Test Loss: 1.302. Train Acc: 0.9988. Test Acc:0.7889
# Epoch: 770. Train Loss: 0.02386. Test Loss: 1.306. Train Acc: 0.9952. Test Acc:0.788
# Epoch: 780. Train Loss: 0.00835. Test Loss: 1.273. Train Acc: 0.9998. Test Acc:0.7952
# Epoch: 790. Train Loss: 0.009254. Test Loss: 1.274. Train Acc: 0.9997. Test Acc:0.7974
# Epoch: 800. Train Loss: 0.01025. Test Loss: 1.31. Train Acc: 0.9988. Test Acc:0.7894
# Epoch: 810. Train Loss: 0.009706. Test Loss: 1.326. Train Acc: 0.9995. Test Acc:0.7867
# Epoch: 820. Train Loss: 0.008218. Test Loss: 1.325. Train Acc: 0.9998. Test Acc:0.7921
# Epoch: 830. Train Loss: 0.01516. Test Loss: 1.327. Train Acc: 0.9985. Test Acc:0.7845
# Epoch: 840. Train Loss: 0.007584. Test Loss: 1.303. Train Acc: 0.9998. Test Acc:0.7894
# Epoch: 850. Train Loss: 0.009175. Test Loss: 1.327. Train Acc: 0.9993. Test Acc:0.788
# Epoch: 860. Train Loss: 0.00982. Test Loss: 1.3. Train Acc: 0.9997. Test Acc:0.788
# Epoch: 870. Train Loss: 0.01155. Test Loss: 1.336. Train Acc: 0.999. Test Acc:0.7831
# Epoch: 880. Train Loss: 0.009893. Test Loss: 1.369. Train Acc: 0.999. Test Acc:0.7796
# Epoch: 890. Train Loss: 0.007564. Test Loss: 1.311. Train Acc: 0.9998. Test Acc:0.8014
# Epoch: 900. Train Loss: 0.006715. Test Loss: 1.316. Train Acc: 0.9998. Test Acc:0.797
# Epoch: 910. Train Loss: 0.006639. Test Loss: 1.362. Train Acc: 0.9995. Test Acc:0.7889
# Epoch: 920. Train Loss: 0.006659. Test Loss: 1.35. Train Acc: 0.9997. Test Acc:0.7898
# Epoch: 930. Train Loss: 0.01357. Test Loss: 1.353. Train Acc: 0.9982. Test Acc:0.7782
# Epoch: 940. Train Loss: 0.007954. Test Loss: 1.327. Train Acc: 1.0. Test Acc:0.7907
# Epoch: 950. Train Loss: 0.00668. Test Loss: 1.349. Train Acc: 1.0. Test Acc:0.7912
# Epoch: 960. Train Loss: 0.00593. Test Loss: 1.358. Train Acc: 0.9997. Test Acc:0.7907
# Epoch: 970. Train Loss: 0.006527. Test Loss: 1.377. Train Acc: 0.9997. Test Acc:0.7889
# Epoch: 980. Train Loss: 0.006956. Test Loss: 1.345. Train Acc: 0.9997. Test Acc:0.7925
# Epoch: 990. Train Loss: 0.008305. Test Loss: 1.356. Train Acc: 0.9993. Test Acc:0.7818
# Epoch: 1000. Train Loss: 0.008966. Test Loss: 1.381. Train Acc: 0.9992. Test Acc:0.7822
# ASRCNN__conv_pool_max__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.475. Test Loss: 2.635. Train Acc: 0.127. Test Acc:0.08121
# Epoch: 20. Train Loss: 1.986. Test Loss: 2.19. Train Acc: 0.3179. Test Acc:0.2378
# Epoch: 30. Train Loss: 1.616. Test Loss: 1.858. Train Acc: 0.4669. Test Acc:0.3842
# Epoch: 40. Train Loss: 1.321. Test Loss: 1.592. Train Acc: 0.6017. Test Acc:0.4788
# Epoch: 50. Train Loss: 1.078. Test Loss: 1.384. Train Acc: 0.7027. Test Acc:0.5707
# Epoch: 60. Train Loss: 0.9296. Test Loss: 1.262. Train Acc: 0.7655. Test Acc:0.6194
# Epoch: 70. Train Loss: 0.8153. Test Loss: 1.178. Train Acc: 0.8122. Test Acc:0.6457
# Epoch: 80. Train Loss: 0.7515. Test Loss: 1.135. Train Acc: 0.8295. Test Acc:0.6577
# Epoch: 90. Train Loss: 0.6843. Test Loss: 1.101. Train Acc: 0.8498. Test Acc:0.6693
# Epoch: 100. Train Loss: 0.6231. Test Loss: 1.065. Train Acc: 0.8722. Test Acc:0.6827
# Epoch: 110. Train Loss: 0.59. Test Loss: 1.048. Train Acc: 0.8744. Test Acc:0.6899
# Epoch: 120. Train Loss: 0.5561. Test Loss: 1.04. Train Acc: 0.8825. Test Acc:0.6939
# Epoch: 130. Train Loss: 0.5081. Test Loss: 1.0. Train Acc: 0.902. Test Acc:0.7024
# Epoch: 140. Train Loss: 0.4859. Test Loss: 0.9987. Train Acc: 0.9026. Test Acc:0.7077
# Epoch: 150. Train Loss: 0.4582. Test Loss: 0.9834. Train Acc: 0.9109. Test Acc:0.7104
# Epoch: 160. Train Loss: 0.4327. Test Loss: 0.9791. Train Acc: 0.9156. Test Acc:0.7158
# Epoch: 170. Train Loss: 0.428. Test Loss: 0.9831. Train Acc: 0.9093. Test Acc:0.7037
# Epoch: 180. Train Loss: 0.3934. Test Loss: 0.9675. Train Acc: 0.9212. Test Acc:0.7131
# Epoch: 190. Train Loss: 0.3786. Test Loss: 0.9952. Train Acc: 0.9226. Test Acc:0.7113
# Epoch: 200. Train Loss: 0.3731. Test Loss: 0.9922. Train Acc: 0.9196. Test Acc:0.7108
# Epoch: 210. Train Loss: 0.3293. Test Loss: 0.97. Train Acc: 0.9377. Test Acc:0.7336
# Epoch: 220. Train Loss: 0.2984. Test Loss: 0.9476. Train Acc: 0.9501. Test Acc:0.743
# Epoch: 230. Train Loss: 0.2904. Test Loss: 0.951. Train Acc: 0.95. Test Acc:0.743
# Epoch: 240. Train Loss: 0.269. Test Loss: 0.9556. Train Acc: 0.9551. Test Acc:0.7367
# Epoch: 250. Train Loss: 0.2598. Test Loss: 0.9402. Train Acc: 0.9575. Test Acc:0.7421
# Epoch: 260. Train Loss: 0.2474. Test Loss: 0.9417. Train Acc: 0.9566. Test Acc:0.743
# Epoch: 270. Train Loss: 0.232. Test Loss: 0.9497. Train Acc: 0.9616. Test Acc:0.7434
# Epoch: 280. Train Loss: 0.2391. Test Loss: 0.967. Train Acc: 0.9593. Test Acc:0.7291
# Epoch: 290. Train Loss: 0.2183. Test Loss: 0.9446. Train Acc: 0.9614. Test Acc:0.7367
# Epoch: 300. Train Loss: 0.2078. Test Loss: 0.9824. Train Acc: 0.9636. Test Acc:0.7385
# Epoch: 310. Train Loss: 0.2019. Test Loss: 0.9631. Train Acc: 0.9673. Test Acc:0.7381
# Epoch: 320. Train Loss: 0.1985. Test Loss: 0.9808. Train Acc: 0.9631. Test Acc:0.7354
# Epoch: 330. Train Loss: 0.1853. Test Loss: 0.9806. Train Acc: 0.9674. Test Acc:0.7354
# Epoch: 340. Train Loss: 0.1838. Test Loss: 0.997. Train Acc: 0.9696. Test Acc:0.7367
# Epoch: 350. Train Loss: 0.1761. Test Loss: 1.012. Train Acc: 0.9669. Test Acc:0.734
# Epoch: 360. Train Loss: 0.1725. Test Loss: 0.9989. Train Acc: 0.9706. Test Acc:0.7376
# Epoch: 370. Train Loss: 0.1632. Test Loss: 1.004. Train Acc: 0.9693. Test Acc:0.7403
# Epoch: 380. Train Loss: 0.1556. Test Loss: 0.988. Train Acc: 0.9721. Test Acc:0.7416
# Epoch: 390. Train Loss: 0.1655. Test Loss: 1.023. Train Acc: 0.9654. Test Acc:0.7354
# Epoch: 400. Train Loss: 0.1621. Test Loss: 1.068. Train Acc: 0.9651. Test Acc:0.7278
# Epoch: 410. Train Loss: 0.1475. Test Loss: 1.031. Train Acc: 0.9727. Test Acc:0.7349
# Epoch: 420. Train Loss: 0.1432. Test Loss: 1.005. Train Acc: 0.9716. Test Acc:0.7394
# Epoch: 430. Train Loss: 0.1285. Test Loss: 0.9939. Train Acc: 0.9796. Test Acc:0.743
# Epoch: 440. Train Loss: 0.1324. Test Loss: 1.011. Train Acc: 0.9787. Test Acc:0.7434
# Epoch: 450. Train Loss: 0.1195. Test Loss: 1.005. Train Acc: 0.9794. Test Acc:0.7354
# Epoch: 460. Train Loss: 0.1233. Test Loss: 1.01. Train Acc: 0.9766. Test Acc:0.7367
# Epoch: 470. Train Loss: 0.1058. Test Loss: 1.033. Train Acc: 0.9854. Test Acc:0.7492
# Epoch: 480. Train Loss: 0.1039. Test Loss: 1.026. Train Acc: 0.984. Test Acc:0.7461
# Epoch: 490. Train Loss: 0.1047. Test Loss: 1.055. Train Acc: 0.9816. Test Acc:0.739
# Epoch: 500. Train Loss: 0.09919. Test Loss: 1.034. Train Acc: 0.9834. Test Acc:0.7416
# Epoch: 510. Train Loss: 0.1001. Test Loss: 1.073. Train Acc: 0.9824. Test Acc:0.7314
# Epoch: 520. Train Loss: 0.08969. Test Loss: 1.039. Train Acc: 0.9869. Test Acc:0.7403
# Epoch: 530. Train Loss: 0.09233. Test Loss: 1.068. Train Acc: 0.985. Test Acc:0.7385
# Epoch: 540. Train Loss: 0.08466. Test Loss: 1.048. Train Acc: 0.987. Test Acc:0.7465
# Epoch: 550. Train Loss: 0.08442. Test Loss: 1.05. Train Acc: 0.9864. Test Acc:0.7479
# Epoch: 560. Train Loss: 0.08163. Test Loss: 1.097. Train Acc: 0.989. Test Acc:0.7416
# Epoch: 570. Train Loss: 0.07705. Test Loss: 1.082. Train Acc: 0.9879. Test Acc:0.747
# Epoch: 580. Train Loss: 0.08032. Test Loss: 1.06. Train Acc: 0.9859. Test Acc:0.7452
# Epoch: 590. Train Loss: 0.07315. Test Loss: 1.084. Train Acc: 0.9884. Test Acc:0.7443
# Epoch: 600. Train Loss: 0.06831. Test Loss: 1.11. Train Acc: 0.9905. Test Acc:0.747
# Epoch: 610. Train Loss: 0.06534. Test Loss: 1.081. Train Acc: 0.9904. Test Acc:0.7465
# Epoch: 620. Train Loss: 0.06509. Test Loss: 1.107. Train Acc: 0.9917. Test Acc:0.7412
# Epoch: 630. Train Loss: 0.06889. Test Loss: 1.122. Train Acc: 0.9872. Test Acc:0.7425
# Epoch: 640. Train Loss: 0.07711. Test Loss: 1.158. Train Acc: 0.9875. Test Acc:0.7314
# Epoch: 650. Train Loss: 0.06423. Test Loss: 1.107. Train Acc: 0.989. Test Acc:0.7465
# Epoch: 660. Train Loss: 0.06337. Test Loss: 1.149. Train Acc: 0.9912. Test Acc:0.7407
# Epoch: 670. Train Loss: 0.06114. Test Loss: 1.165. Train Acc: 0.9924. Test Acc:0.7425
# Epoch: 680. Train Loss: 0.06517. Test Loss: 1.149. Train Acc: 0.9894. Test Acc:0.7412
# Epoch: 690. Train Loss: 0.06612. Test Loss: 1.137. Train Acc: 0.9877. Test Acc:0.7385
# Epoch: 700. Train Loss: 0.05868. Test Loss: 1.131. Train Acc: 0.9915. Test Acc:0.7443
# Epoch: 710. Train Loss: 0.0696. Test Loss: 1.181. Train Acc: 0.9889. Test Acc:0.7394
# Epoch: 720. Train Loss: 0.07873. Test Loss: 1.206. Train Acc: 0.9859. Test Acc:0.7327
# Epoch: 730. Train Loss: 0.06505. Test Loss: 1.093. Train Acc: 0.993. Test Acc:0.7497
# Epoch: 740. Train Loss: 0.04996. Test Loss: 1.115. Train Acc: 0.9944. Test Acc:0.7492
# Epoch: 750. Train Loss: 0.04514. Test Loss: 1.111. Train Acc: 0.9953. Test Acc:0.7506
# Epoch: 760. Train Loss: 0.05113. Test Loss: 1.142. Train Acc: 0.9937. Test Acc:0.7501
# Epoch: 770. Train Loss: 0.04759. Test Loss: 1.117. Train Acc: 0.9937. Test Acc:0.7465
# Epoch: 780. Train Loss: 0.04138. Test Loss: 1.142. Train Acc: 0.9958. Test Acc:0.7546
# Epoch: 790. Train Loss: 0.04279. Test Loss: 1.144. Train Acc: 0.9953. Test Acc:0.7537
# Epoch: 800. Train Loss: 0.0381. Test Loss: 1.152. Train Acc: 0.9962. Test Acc:0.7515
# Epoch: 810. Train Loss: 0.03605. Test Loss: 1.173. Train Acc: 0.9973. Test Acc:0.7515
# Epoch: 820. Train Loss: 0.0379. Test Loss: 1.156. Train Acc: 0.997. Test Acc:0.7528
# Epoch: 830. Train Loss: 0.03593. Test Loss: 1.162. Train Acc: 0.9977. Test Acc:0.7506
# Epoch: 840. Train Loss: 0.0333. Test Loss: 1.169. Train Acc: 0.9963. Test Acc:0.7564
# Epoch: 850. Train Loss: 0.03151. Test Loss: 1.199. Train Acc: 0.9983. Test Acc:0.7608
# Epoch: 860. Train Loss: 0.03224. Test Loss: 1.201. Train Acc: 0.9968. Test Acc:0.7564
# Epoch: 870. Train Loss: 0.02961. Test Loss: 1.21. Train Acc: 0.9978. Test Acc:0.7568
# Epoch: 880. Train Loss: 0.03703. Test Loss: 1.193. Train Acc: 0.995. Test Acc:0.7443
# Epoch: 890. Train Loss: 0.03094. Test Loss: 1.205. Train Acc: 0.9962. Test Acc:0.7532
# Epoch: 900. Train Loss: 0.0288. Test Loss: 1.188. Train Acc: 0.9983. Test Acc:0.7568
# Epoch: 910. Train Loss: 0.03081. Test Loss: 1.177. Train Acc: 0.9963. Test Acc:0.7532
# Epoch: 920. Train Loss: 0.02726. Test Loss: 1.225. Train Acc: 0.9978. Test Acc:0.7528
# Epoch: 930. Train Loss: 0.02796. Test Loss: 1.241. Train Acc: 0.9978. Test Acc:0.751
# Epoch: 940. Train Loss: 0.02954. Test Loss: 1.24. Train Acc: 0.9962. Test Acc:0.755
# Epoch: 950. Train Loss: 0.02882. Test Loss: 1.196. Train Acc: 0.9967. Test Acc:0.7559
# Epoch: 960. Train Loss: 0.02542. Test Loss: 1.256. Train Acc: 0.9982. Test Acc:0.7528
# Epoch: 970. Train Loss: 0.02562. Test Loss: 1.258. Train Acc: 0.9985. Test Acc:0.747
# Epoch: 980. Train Loss: 0.02706. Test Loss: 1.249. Train Acc: 0.9977. Test Acc:0.7528
# Epoch: 990. Train Loss: 0.0227. Test Loss: 1.235. Train Acc: 0.9985. Test Acc:0.7497
# Epoch: 1000. Train Loss: 0.02352. Test Loss: 1.263. Train Acc: 0.9978. Test Acc:0.7528
# ASRCNN__conv_pool_max__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-z__obj_voice_cmd using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 4.012. Test Loss: 4.066. Train Acc: 0.054. Test Acc:0.04328
# Epoch: 20. Train Loss: 3.307. Test Loss: 3.428. Train Acc: 0.1437. Test Acc:0.1272
# Epoch: 30. Train Loss: 2.894. Test Loss: 3.089. Train Acc: 0.2494. Test Acc:0.2044
# Epoch: 40. Train Loss: 2.395. Test Loss: 2.695. Train Acc: 0.3785. Test Acc:0.2918
# Epoch: 50. Train Loss: 1.998. Test Loss: 2.389. Train Acc: 0.487. Test Acc:0.3775
# Epoch: 60. Train Loss: 1.68. Test Loss: 2.123. Train Acc: 0.5758. Test Acc:0.4498
# Epoch: 70. Train Loss: 1.431. Test Loss: 1.925. Train Acc: 0.6338. Test Acc:0.502
# Epoch: 80. Train Loss: 1.189. Test Loss: 1.668. Train Acc: 0.709. Test Acc:0.5716
# Epoch: 90. Train Loss: 1.043. Test Loss: 1.537. Train Acc: 0.7433. Test Acc:0.5988
# Epoch: 100. Train Loss: 0.9003. Test Loss: 1.405. Train Acc: 0.7836. Test Acc:0.6372
# Epoch: 110. Train Loss: 0.8208. Test Loss: 1.353. Train Acc: 0.8038. Test Acc:0.6484
# Epoch: 120. Train Loss: 0.759. Test Loss: 1.303. Train Acc: 0.8141. Test Acc:0.6609
# Epoch: 130. Train Loss: 0.7199. Test Loss: 1.29. Train Acc: 0.8195. Test Acc:0.6685
# Epoch: 140. Train Loss: 0.6497. Test Loss: 1.227. Train Acc: 0.8441. Test Acc:0.6818
# Epoch: 150. Train Loss: 0.6031. Test Loss: 1.2. Train Acc: 0.8576. Test Acc:0.6983
# Epoch: 160. Train Loss: 0.5622. Test Loss: 1.179. Train Acc: 0.8672. Test Acc:0.697
# Epoch: 170. Train Loss: 0.5695. Test Loss: 1.205. Train Acc: 0.8598. Test Acc:0.6921
# Epoch: 180. Train Loss: 0.5191. Test Loss: 1.158. Train Acc: 0.875. Test Acc:0.7046
# Epoch: 190. Train Loss: 0.4827. Test Loss: 1.149. Train Acc: 0.8853. Test Acc:0.7068
# Epoch: 200. Train Loss: 0.4618. Test Loss: 1.136. Train Acc: 0.8897. Test Acc:0.7108
# Epoch: 210. Train Loss: 0.445. Test Loss: 1.136. Train Acc: 0.8955. Test Acc:0.7117
# Epoch: 220. Train Loss: 0.4302. Test Loss: 1.146. Train Acc: 0.8973. Test Acc:0.7108
# Epoch: 230. Train Loss: 0.4048. Test Loss: 1.118. Train Acc: 0.902. Test Acc:0.7224
# Epoch: 240. Train Loss: 0.3955. Test Loss: 1.135. Train Acc: 0.9036. Test Acc:0.7158
# Epoch: 250. Train Loss: 0.3833. Test Loss: 1.143. Train Acc: 0.9079. Test Acc:0.7059
# Epoch: 260. Train Loss: 0.353. Test Loss: 1.123. Train Acc: 0.9177. Test Acc:0.7149
# Epoch: 270. Train Loss: 0.3473. Test Loss: 1.115. Train Acc: 0.9171. Test Acc:0.7256
# Epoch: 280. Train Loss: 0.3321. Test Loss: 1.106. Train Acc: 0.9199. Test Acc:0.726
# Epoch: 290. Train Loss: 0.3781. Test Loss: 1.178. Train Acc: 0.8963. Test Acc:0.7082
# Epoch: 300. Train Loss: 0.3268. Test Loss: 1.124. Train Acc: 0.9169. Test Acc:0.7247
# Epoch: 310. Train Loss: 0.3153. Test Loss: 1.14. Train Acc: 0.9199. Test Acc:0.7282
# Epoch: 320. Train Loss: 0.3249. Test Loss: 1.146. Train Acc: 0.9146. Test Acc:0.7265
# Epoch: 330. Train Loss: 0.3253. Test Loss: 1.157. Train Acc: 0.9148. Test Acc:0.7265
# Epoch: 340. Train Loss: 0.2553. Test Loss: 1.091. Train Acc: 0.9403. Test Acc:0.7439
# Epoch: 350. Train Loss: 0.2374. Test Loss: 1.087. Train Acc: 0.9433. Test Acc:0.7416
# Epoch: 360. Train Loss: 0.2339. Test Loss: 1.094. Train Acc: 0.9438. Test Acc:0.7416
# Epoch: 370. Train Loss: 0.231. Test Loss: 1.092. Train Acc: 0.9443. Test Acc:0.7483
# Epoch: 380. Train Loss: 0.2275. Test Loss: 1.103. Train Acc: 0.9428. Test Acc:0.7474
# Epoch: 390. Train Loss: 0.2269. Test Loss: 1.105. Train Acc: 0.9433. Test Acc:0.7483
# Epoch: 400. Train Loss: 0.2032. Test Loss: 1.104. Train Acc: 0.952. Test Acc:0.7461
# Epoch: 410. Train Loss: 0.2077. Test Loss: 1.093. Train Acc: 0.9485. Test Acc:0.7488
# Epoch: 420. Train Loss: 0.1895. Test Loss: 1.097. Train Acc: 0.9555. Test Acc:0.7461
# Epoch: 430. Train Loss: 0.1915. Test Loss: 1.107. Train Acc: 0.955. Test Acc:0.7452
# Epoch: 440. Train Loss: 0.1702. Test Loss: 1.097. Train Acc: 0.9616. Test Acc:0.7559
# Epoch: 450. Train Loss: 0.1878. Test Loss: 1.114. Train Acc: 0.9535. Test Acc:0.7452
# Epoch: 460. Train Loss: 0.1688. Test Loss: 1.115. Train Acc: 0.9585. Test Acc:0.7456
# Epoch: 470. Train Loss: 0.1648. Test Loss: 1.118. Train Acc: 0.9601. Test Acc:0.7434
# Epoch: 480. Train Loss: 0.16. Test Loss: 1.116. Train Acc: 0.9606. Test Acc:0.7465
# Epoch: 490. Train Loss: 0.1636. Test Loss: 1.125. Train Acc: 0.9586. Test Acc:0.7506
# Epoch: 500. Train Loss: 0.1576. Test Loss: 1.121. Train Acc: 0.9595. Test Acc:0.7483
# Epoch: 510. Train Loss: 0.1495. Test Loss: 1.109. Train Acc: 0.9643. Test Acc:0.7537
# Epoch: 520. Train Loss: 0.1394. Test Loss: 1.131. Train Acc: 0.9634. Test Acc:0.7448
# Epoch: 530. Train Loss: 0.1479. Test Loss: 1.127. Train Acc: 0.9613. Test Acc:0.743
# Epoch: 540. Train Loss: 0.1404. Test Loss: 1.132. Train Acc: 0.9638. Test Acc:0.7474
# Epoch: 550. Train Loss: 0.1307. Test Loss: 1.112. Train Acc: 0.9678. Test Acc:0.7506
# Epoch: 560. Train Loss: 0.1203. Test Loss: 1.113. Train Acc: 0.9706. Test Acc:0.7568
# Epoch: 570. Train Loss: 0.1239. Test Loss: 1.138. Train Acc: 0.9701. Test Acc:0.7483
# Epoch: 580. Train Loss: 0.1185. Test Loss: 1.147. Train Acc: 0.9721. Test Acc:0.7439
# Epoch: 590. Train Loss: 0.1055. Test Loss: 1.129. Train Acc: 0.9771. Test Acc:0.747
# Epoch: 600. Train Loss: 0.09684. Test Loss: 1.141. Train Acc: 0.9781. Test Acc:0.7501
# Epoch: 610. Train Loss: 0.09749. Test Loss: 1.131. Train Acc: 0.9781. Test Acc:0.7555
# Epoch: 620. Train Loss: 0.09504. Test Loss: 1.125. Train Acc: 0.9792. Test Acc:0.7528
# Epoch: 630. Train Loss: 0.08845. Test Loss: 1.158. Train Acc: 0.9806. Test Acc:0.7439
# Epoch: 640. Train Loss: 0.08773. Test Loss: 1.152. Train Acc: 0.9835. Test Acc:0.7497
# Epoch: 650. Train Loss: 0.08941. Test Loss: 1.173. Train Acc: 0.9802. Test Acc:0.7439
# Epoch: 660. Train Loss: 0.09501. Test Loss: 1.152. Train Acc: 0.9782. Test Acc:0.7452
# Epoch: 670. Train Loss: 0.07932. Test Loss: 1.155. Train Acc: 0.9826. Test Acc:0.7532
# Epoch: 680. Train Loss: 0.09204. Test Loss: 1.169. Train Acc: 0.9786. Test Acc:0.7448
# Epoch: 690. Train Loss: 0.07735. Test Loss: 1.145. Train Acc: 0.9822. Test Acc:0.7523
# Epoch: 700. Train Loss: 0.08137. Test Loss: 1.172. Train Acc: 0.9832. Test Acc:0.7479
# Epoch: 710. Train Loss: 0.08061. Test Loss: 1.146. Train Acc: 0.9849. Test Acc:0.7595
# Epoch: 720. Train Loss: 0.07081. Test Loss: 1.17. Train Acc: 0.986. Test Acc:0.7479
# Epoch: 730. Train Loss: 0.08404. Test Loss: 1.207. Train Acc: 0.9792. Test Acc:0.7488
# Epoch: 740. Train Loss: 0.06956. Test Loss: 1.15. Train Acc: 0.9852. Test Acc:0.7604
# Epoch: 750. Train Loss: 0.06493. Test Loss: 1.15. Train Acc: 0.9874. Test Acc:0.7617
# Epoch: 760. Train Loss: 0.05849. Test Loss: 1.16. Train Acc: 0.9882. Test Acc:0.7581
# Epoch: 770. Train Loss: 0.06383. Test Loss: 1.176. Train Acc: 0.9877. Test Acc:0.7528
# Epoch: 780. Train Loss: 0.05374. Test Loss: 1.215. Train Acc: 0.9912. Test Acc:0.7528
# Epoch: 790. Train Loss: 0.0554. Test Loss: 1.172. Train Acc: 0.9892. Test Acc:0.7608
# Epoch: 800. Train Loss: 0.05895. Test Loss: 1.173. Train Acc: 0.9877. Test Acc:0.7608
# Epoch: 810. Train Loss: 0.05083. Test Loss: 1.198. Train Acc: 0.9917. Test Acc:0.7639
# Epoch: 820. Train Loss: 0.05034. Test Loss: 1.208. Train Acc: 0.9907. Test Acc:0.7604
# Epoch: 830. Train Loss: 0.05035. Test Loss: 1.198. Train Acc: 0.9904. Test Acc:0.7599
# Epoch: 840. Train Loss: 0.04823. Test Loss: 1.197. Train Acc: 0.9909. Test Acc:0.7581
# Epoch: 850. Train Loss: 0.04746. Test Loss: 1.197. Train Acc: 0.9907. Test Acc:0.7617
# Epoch: 860. Train Loss: 0.04142. Test Loss: 1.179. Train Acc: 0.9937. Test Acc:0.7648
# Epoch: 870. Train Loss: 0.05591. Test Loss: 1.199. Train Acc: 0.988. Test Acc:0.7622
# Epoch: 880. Train Loss: 0.04549. Test Loss: 1.211. Train Acc: 0.992. Test Acc:0.7635
# Epoch: 890. Train Loss: 0.04059. Test Loss: 1.189. Train Acc: 0.9937. Test Acc:0.7657
# Epoch: 900. Train Loss: 0.03786. Test Loss: 1.204. Train Acc: 0.9934. Test Acc:0.7706
# Epoch: 910. Train Loss: 0.03933. Test Loss: 1.203. Train Acc: 0.9944. Test Acc:0.7733
# Epoch: 920. Train Loss: 0.04105. Test Loss: 1.215. Train Acc: 0.9935. Test Acc:0.7648
# Epoch: 930. Train Loss: 0.04047. Test Loss: 1.232. Train Acc: 0.9924. Test Acc:0.7693
# Epoch: 940. Train Loss: 0.03876. Test Loss: 1.221. Train Acc: 0.9939. Test Acc:0.7689
# Epoch: 950. Train Loss: 0.03186. Test Loss: 1.217. Train Acc: 0.9962. Test Acc:0.7639
# Epoch: 960. Train Loss: 0.03475. Test Loss: 1.209. Train Acc: 0.9967. Test Acc:0.7702
# Epoch: 970. Train Loss: 0.03181. Test Loss: 1.214. Train Acc: 0.9957. Test Acc:0.772
# Epoch: 980. Train Loss: 0.02882. Test Loss: 1.227. Train Acc: 0.9968. Test Acc:0.7671
# Epoch: 990. Train Loss: 0.03591. Test Loss: 1.265. Train Acc: 0.9944. Test Acc:0.7657
# Epoch: 1000. Train Loss: 0.03307. Test Loss: 1.228. Train Acc: 0.9947. Test Acc:0.7715
# ASRCNN__conv_pool_max__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-z__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.662. Test Loss: 2.805. Train Acc: 0.0678. Test Acc:0.07229
# Epoch: 20. Train Loss: 2.259. Test Loss: 2.451. Train Acc: 0.1996. Test Acc:0.1673
# Epoch: 30. Train Loss: 1.955. Test Loss: 2.184. Train Acc: 0.3029. Test Acc:0.2588
# Epoch: 40. Train Loss: 1.684. Test Loss: 1.954. Train Acc: 0.4241. Test Acc:0.34
# Epoch: 50. Train Loss: 1.446. Test Loss: 1.749. Train Acc: 0.5284. Test Acc:0.4275
# Epoch: 60. Train Loss: 1.258. Test Loss: 1.581. Train Acc: 0.6176. Test Acc:0.5029
# Epoch: 70. Train Loss: 1.122. Test Loss: 1.462. Train Acc: 0.6735. Test Acc:0.5569
# Epoch: 80. Train Loss: 1.031. Test Loss: 1.379. Train Acc: 0.7167. Test Acc:0.5868
# Epoch: 90. Train Loss: 0.9679. Test Loss: 1.334. Train Acc: 0.7316. Test Acc:0.5957
# Epoch: 100. Train Loss: 0.9039. Test Loss: 1.289. Train Acc: 0.7566. Test Acc:0.6154
# Epoch: 110. Train Loss: 0.8382. Test Loss: 1.234. Train Acc: 0.782. Test Acc:0.6354
# Epoch: 120. Train Loss: 0.7878. Test Loss: 1.193. Train Acc: 0.8043. Test Acc:0.6457
# Epoch: 130. Train Loss: 0.7462. Test Loss: 1.172. Train Acc: 0.8152. Test Acc:0.6542
# Epoch: 140. Train Loss: 0.7081. Test Loss: 1.145. Train Acc: 0.8308. Test Acc:0.6568
# Epoch: 150. Train Loss: 0.6756. Test Loss: 1.11. Train Acc: 0.8436. Test Acc:0.6716
# Epoch: 160. Train Loss: 0.6538. Test Loss: 1.119. Train Acc: 0.8466. Test Acc:0.672
# Epoch: 170. Train Loss: 0.6215. Test Loss: 1.092. Train Acc: 0.8664. Test Acc:0.6796
# Epoch: 180. Train Loss: 0.6028. Test Loss: 1.08. Train Acc: 0.8652. Test Acc:0.6783
# Epoch: 190. Train Loss: 0.5734. Test Loss: 1.074. Train Acc: 0.8744. Test Acc:0.685
# Epoch: 200. Train Loss: 0.5562. Test Loss: 1.061. Train Acc: 0.8774. Test Acc:0.6818
# Epoch: 210. Train Loss: 0.5436. Test Loss: 1.056. Train Acc: 0.8868. Test Acc:0.6912
# Epoch: 220. Train Loss: 0.5171. Test Loss: 1.037. Train Acc: 0.8963. Test Acc:0.6975
# Epoch: 230. Train Loss: 0.52. Test Loss: 1.049. Train Acc: 0.8862. Test Acc:0.6908
# Epoch: 240. Train Loss: 0.4948. Test Loss: 1.043. Train Acc: 0.898. Test Acc:0.6983
# Epoch: 250. Train Loss: 0.4759. Test Loss: 1.027. Train Acc: 0.9058. Test Acc:0.6979
# Epoch: 260. Train Loss: 0.4607. Test Loss: 1.03. Train Acc: 0.9055. Test Acc:0.7064
# Epoch: 270. Train Loss: 0.4523. Test Loss: 1.025. Train Acc: 0.9051. Test Acc:0.6997
# Epoch: 280. Train Loss: 0.4372. Test Loss: 1.009. Train Acc: 0.9116. Test Acc:0.7068
# Epoch: 290. Train Loss: 0.423. Test Loss: 1.027. Train Acc: 0.9133. Test Acc:0.7033
# Epoch: 300. Train Loss: 0.413. Test Loss: 1.01. Train Acc: 0.9179. Test Acc:0.7041
# Epoch: 310. Train Loss: 0.3875. Test Loss: 1.005. Train Acc: 0.9241. Test Acc:0.7064
# Epoch: 320. Train Loss: 0.3792. Test Loss: 1.008. Train Acc: 0.9252. Test Acc:0.7095
# Epoch: 330. Train Loss: 0.3821. Test Loss: 1.014. Train Acc: 0.9222. Test Acc:0.6979
# Epoch: 340. Train Loss: 0.3643. Test Loss: 0.9955. Train Acc: 0.9277. Test Acc:0.7068
# Epoch: 350. Train Loss: 0.3462. Test Loss: 1.024. Train Acc: 0.936. Test Acc:0.7126
# Epoch: 360. Train Loss: 0.3328. Test Loss: 0.9981. Train Acc: 0.9369. Test Acc:0.7198
# Epoch: 370. Train Loss: 0.3388. Test Loss: 1.012. Train Acc: 0.9287. Test Acc:0.7037
# Epoch: 380. Train Loss: 0.3118. Test Loss: 1.019. Train Acc: 0.9443. Test Acc:0.7193
# Epoch: 390. Train Loss: 0.3063. Test Loss: 1.008. Train Acc: 0.9417. Test Acc:0.7153
# Epoch: 400. Train Loss: 0.3014. Test Loss: 1.023. Train Acc: 0.9402. Test Acc:0.7135
# Epoch: 410. Train Loss: 0.2829. Test Loss: 0.9995. Train Acc: 0.9482. Test Acc:0.7198
# Epoch: 420. Train Loss: 0.276. Test Loss: 1.014. Train Acc: 0.9485. Test Acc:0.7184
# Epoch: 430. Train Loss: 0.2663. Test Loss: 1.007. Train Acc: 0.9528. Test Acc:0.7274
# Epoch: 440. Train Loss: 0.2734. Test Loss: 1.017. Train Acc: 0.946. Test Acc:0.7149
# Epoch: 450. Train Loss: 0.2598. Test Loss: 1.023. Train Acc: 0.9482. Test Acc:0.7184
# Epoch: 460. Train Loss: 0.2517. Test Loss: 1.019. Train Acc: 0.9516. Test Acc:0.7189
# Epoch: 470. Train Loss: 0.2338. Test Loss: 1.014. Train Acc: 0.9608. Test Acc:0.7309
# Epoch: 480. Train Loss: 0.2267. Test Loss: 1.014. Train Acc: 0.9634. Test Acc:0.7305
# Epoch: 490. Train Loss: 0.2215. Test Loss: 1.031. Train Acc: 0.9648. Test Acc:0.7265
# Epoch: 500. Train Loss: 0.2248. Test Loss: 1.044. Train Acc: 0.9583. Test Acc:0.714
# Epoch: 510. Train Loss: 0.215. Test Loss: 1.047. Train Acc: 0.9606. Test Acc:0.7175
# Epoch: 520. Train Loss: 0.2121. Test Loss: 1.052. Train Acc: 0.9626. Test Acc:0.7158
# Epoch: 530. Train Loss: 0.2013. Test Loss: 1.038. Train Acc: 0.9646. Test Acc:0.7211
# Epoch: 540. Train Loss: 0.2052. Test Loss: 1.052. Train Acc: 0.9588. Test Acc:0.7153
# Epoch: 550. Train Loss: 0.1915. Test Loss: 1.058. Train Acc: 0.9676. Test Acc:0.7189
# Epoch: 560. Train Loss: 0.1985. Test Loss: 1.051. Train Acc: 0.9613. Test Acc:0.714
# Epoch: 570. Train Loss: 0.1991. Test Loss: 1.083. Train Acc: 0.96. Test Acc:0.7122
# Epoch: 580. Train Loss: 0.1875. Test Loss: 1.097. Train Acc: 0.9646. Test Acc:0.7144
# Epoch: 590. Train Loss: 0.1737. Test Loss: 1.063. Train Acc: 0.9706. Test Acc:0.722
# Epoch: 600. Train Loss: 0.1902. Test Loss: 1.087. Train Acc: 0.9624. Test Acc:0.7144
# Epoch: 610. Train Loss: 0.191. Test Loss: 1.107. Train Acc: 0.9651. Test Acc:0.7184
# Epoch: 620. Train Loss: 0.1814. Test Loss: 1.114. Train Acc: 0.9671. Test Acc:0.7158
# Epoch: 630. Train Loss: 0.1806. Test Loss: 1.099. Train Acc: 0.9644. Test Acc:0.7144
# Epoch: 640. Train Loss: 0.1746. Test Loss: 1.104. Train Acc: 0.9658. Test Acc:0.714
# Epoch: 650. Train Loss: 0.1712. Test Loss: 1.126. Train Acc: 0.9673. Test Acc:0.7122
# Epoch: 660. Train Loss: 0.149. Test Loss: 1.073. Train Acc: 0.9739. Test Acc:0.722
# Epoch: 670. Train Loss: 0.1496. Test Loss: 1.038. Train Acc: 0.9774. Test Acc:0.7242
# Epoch: 680. Train Loss: 0.1444. Test Loss: 1.061. Train Acc: 0.9771. Test Acc:0.718
# Epoch: 690. Train Loss: 0.1372. Test Loss: 1.047. Train Acc: 0.9789. Test Acc:0.7216
# Epoch: 700. Train Loss: 0.1414. Test Loss: 1.064. Train Acc: 0.9756. Test Acc:0.7175
# Epoch: 710. Train Loss: 0.1351. Test Loss: 1.075. Train Acc: 0.9781. Test Acc:0.7193
# Epoch: 720. Train Loss: 0.1386. Test Loss: 1.062. Train Acc: 0.9779. Test Acc:0.7238
# Epoch: 730. Train Loss: 0.1266. Test Loss: 1.069. Train Acc: 0.9811. Test Acc:0.7229
# Epoch: 740. Train Loss: 0.1313. Test Loss: 1.093. Train Acc: 0.9792. Test Acc:0.7166
# Epoch: 750. Train Loss: 0.1297. Test Loss: 1.095. Train Acc: 0.9754. Test Acc:0.7153
# Epoch: 760. Train Loss: 0.1217. Test Loss: 1.091. Train Acc: 0.9819. Test Acc:0.7122
# Epoch: 770. Train Loss: 0.1186. Test Loss: 1.092. Train Acc: 0.9804. Test Acc:0.718
# Epoch: 780. Train Loss: 0.121. Test Loss: 1.083. Train Acc: 0.9831. Test Acc:0.7175
# Epoch: 790. Train Loss: 0.1146. Test Loss: 1.098. Train Acc: 0.9837. Test Acc:0.7158
# Epoch: 800. Train Loss: 0.107. Test Loss: 1.098. Train Acc: 0.9847. Test Acc:0.7242
# Epoch: 810. Train Loss: 0.1044. Test Loss: 1.105. Train Acc: 0.9829. Test Acc:0.7202
# Epoch: 820. Train Loss: 0.1167. Test Loss: 1.119. Train Acc: 0.9797. Test Acc:0.7126
# Epoch: 830. Train Loss: 0.1061. Test Loss: 1.116. Train Acc: 0.9839. Test Acc:0.7224
# Epoch: 840. Train Loss: 0.1053. Test Loss: 1.121. Train Acc: 0.9827. Test Acc:0.7166
# Epoch: 850. Train Loss: 0.09664. Test Loss: 1.115. Train Acc: 0.9855. Test Acc:0.7251
# Epoch: 860. Train Loss: 0.09791. Test Loss: 1.122. Train Acc: 0.9852. Test Acc:0.718
# Epoch: 870. Train Loss: 0.09699. Test Loss: 1.166. Train Acc: 0.9834. Test Acc:0.7171
# Epoch: 880. Train Loss: 0.09783. Test Loss: 1.128. Train Acc: 0.9864. Test Acc:0.7224
# Epoch: 890. Train Loss: 0.09085. Test Loss: 1.135. Train Acc: 0.9855. Test Acc:0.7216
# Epoch: 900. Train Loss: 0.0874. Test Loss: 1.113. Train Acc: 0.987. Test Acc:0.7256
# Epoch: 910. Train Loss: 0.09324. Test Loss: 1.136. Train Acc: 0.9867. Test Acc:0.7202
# Epoch: 920. Train Loss: 0.09117. Test Loss: 1.138. Train Acc: 0.9862. Test Acc:0.7207
# Epoch: 930. Train Loss: 0.09155. Test Loss: 1.152. Train Acc: 0.9865. Test Acc:0.7166
# Epoch: 940. Train Loss: 0.08369. Test Loss: 1.162. Train Acc: 0.9877. Test Acc:0.7256
# Epoch: 950. Train Loss: 0.08913. Test Loss: 1.129. Train Acc: 0.9864. Test Acc:0.7269
# Epoch: 960. Train Loss: 0.08371. Test Loss: 1.136. Train Acc: 0.9882. Test Acc:0.722
# Epoch: 970. Train Loss: 0.07614. Test Loss: 1.159. Train Acc: 0.9894. Test Acc:0.7233
# Epoch: 980. Train Loss: 0.07294. Test Loss: 1.166. Train Acc: 0.9905. Test Acc:0.7247
# Epoch: 990. Train Loss: 0.07586. Test Loss: 1.181. Train Acc: 0.9889. Test Acc:0.7166
# Epoch: 1000. Train Loss: 0.07498. Test Loss: 1.16. Train Acc: 0.9922. Test Acc:0.7207
# ASRCNN__conv_pool_max__conv_dp_0.1__fc_dp_0.1__fn_retrained-wav2vec_features-c__obj_voice_cmd using retrained-wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.907. Test Loss: 3.963. Train Acc: 0.06331. Test Acc:0.05444
# Epoch: 20. Train Loss: 3.654. Test Loss: 3.772. Train Acc: 0.09704. Test Acc:0.06604
# Epoch: 30. Train Loss: 3.219. Test Loss: 3.443. Train Acc: 0.1677. Test Acc:0.1218
# Epoch: 40. Train Loss: 2.875. Test Loss: 3.158. Train Acc: 0.2403. Test Acc:0.1758
# Epoch: 50. Train Loss: 2.54. Test Loss: 2.873. Train Acc: 0.3247. Test Acc:0.2436
# Epoch: 60. Train Loss: 2.212. Test Loss: 2.588. Train Acc: 0.4061. Test Acc:0.3066
# Epoch: 70. Train Loss: 1.962. Test Loss: 2.381. Train Acc: 0.4721. Test Acc:0.3677
# Epoch: 80. Train Loss: 1.717. Test Loss: 2.179. Train Acc: 0.545. Test Acc:0.4145
# Epoch: 90. Train Loss: 1.521. Test Loss: 2.017. Train Acc: 0.6024. Test Acc:0.4596
# Epoch: 100. Train Loss: 1.352. Test Loss: 1.872. Train Acc: 0.6484. Test Acc:0.5029
# Epoch: 110. Train Loss: 1.223. Test Loss: 1.774. Train Acc: 0.6816. Test Acc:0.5203
# Epoch: 120. Train Loss: 1.13. Test Loss: 1.708. Train Acc: 0.7067. Test Acc:0.5408
# Epoch: 130. Train Loss: 1.002. Test Loss: 1.595. Train Acc: 0.7491. Test Acc:0.5761
# Epoch: 140. Train Loss: 0.9092. Test Loss: 1.535. Train Acc: 0.7725. Test Acc:0.5921
# Epoch: 150. Train Loss: 0.8472. Test Loss: 1.478. Train Acc: 0.788. Test Acc:0.6104
# Epoch: 160. Train Loss: 0.7854. Test Loss: 1.453. Train Acc: 0.8067. Test Acc:0.6113
# Epoch: 170. Train Loss: 0.714. Test Loss: 1.381. Train Acc: 0.8259. Test Acc:0.6314
# Epoch: 180. Train Loss: 0.6478. Test Loss: 1.336. Train Acc: 0.8406. Test Acc:0.6533
# Epoch: 190. Train Loss: 0.6043. Test Loss: 1.304. Train Acc: 0.8564. Test Acc:0.66
# Epoch: 200. Train Loss: 0.5605. Test Loss: 1.282. Train Acc: 0.8652. Test Acc:0.6622
# Epoch: 210. Train Loss: 0.5487. Test Loss: 1.281. Train Acc: 0.8681. Test Acc:0.6644
# Epoch: 220. Train Loss: 0.5163. Test Loss: 1.263. Train Acc: 0.8745. Test Acc:0.6716
# Epoch: 230. Train Loss: 0.4731. Test Loss: 1.233. Train Acc: 0.886. Test Acc:0.6832
# Epoch: 240. Train Loss: 0.4802. Test Loss: 1.26. Train Acc: 0.883. Test Acc:0.6778
# Epoch: 250. Train Loss: 0.4636. Test Loss: 1.253. Train Acc: 0.8868. Test Acc:0.6814
# Epoch: 260. Train Loss: 0.3978. Test Loss: 1.18. Train Acc: 0.9069. Test Acc:0.7028
# Epoch: 270. Train Loss: 0.361. Test Loss: 1.157. Train Acc: 0.9202. Test Acc:0.7113
# Epoch: 280. Train Loss: 0.3359. Test Loss: 1.151. Train Acc: 0.9289. Test Acc:0.71
# Epoch: 290. Train Loss: 0.3163. Test Loss: 1.158. Train Acc: 0.9319. Test Acc:0.7153
# Epoch: 300. Train Loss: 0.3072. Test Loss: 1.156. Train Acc: 0.9319. Test Acc:0.7149
# Epoch: 310. Train Loss: 0.288. Test Loss: 1.156. Train Acc: 0.9387. Test Acc:0.7086
# Epoch: 320. Train Loss: 0.2759. Test Loss: 1.17. Train Acc: 0.9397. Test Acc:0.7131
# ...
# Epoch: 320. Train Loss: 0.1548. Test Loss: 1.049. Train Acc: 0.9628. Test Acc:0.7421
# Epoch: 330. Train Loss: 0.1767. Test Loss: 1.046. Train Acc: 0.9586. Test Acc:0.7447
# Epoch: 340. Train Loss: 0.1621. Test Loss: 1.071. Train Acc: 0.9603. Test Acc:0.7443
# Epoch: 350. Train Loss: 0.1591. Test Loss: 1.091. Train Acc: 0.9603. Test Acc:0.7417
# Epoch: 360. Train Loss: 0.1642. Test Loss: 1.103. Train Acc: 0.9572. Test Acc:0.7322
# Epoch: 370. Train Loss: 0.1489. Test Loss: 1.121. Train Acc: 0.9621. Test Acc:0.737
# Epoch: 380. Train Loss: 0.1373. Test Loss: 1.124. Train Acc: 0.9641. Test Acc:0.7387
# Epoch: 390. Train Loss: 0.1512. Test Loss: 1.164. Train Acc: 0.9601. Test Acc:0.7395
# Epoch: 400. Train Loss: 0.1293. Test Loss: 1.134. Train Acc: 0.9677. Test Acc:0.7443
# Epoch: 410. Train Loss: 0.1524. Test Loss: 1.17. Train Acc: 0.9586. Test Acc:0.7352
# Epoch: 420. Train Loss: 0.1359. Test Loss: 1.171. Train Acc: 0.9633. Test Acc:0.7344
# Epoch: 430. Train Loss: 0.1275. Test Loss: 1.168. Train Acc: 0.9652. Test Acc:0.7426
# Epoch: 440. Train Loss: 0.106. Test Loss: 1.154. Train Acc: 0.9724. Test Acc:0.7361
# Epoch: 450. Train Loss: 0.1115. Test Loss: 1.17. Train Acc: 0.9705. Test Acc:0.7374
# Epoch: 460. Train Loss: 0.1149. Test Loss: 1.214. Train Acc: 0.9692. Test Acc:0.7404
# Epoch: 470. Train Loss: 0.08693. Test Loss: 1.147. Train Acc: 0.98. Test Acc:0.7464
# Epoch: 480. Train Loss: 0.09556. Test Loss: 1.168. Train Acc: 0.9758. Test Acc:0.7464
# Epoch: 490. Train Loss: 0.08793. Test Loss: 1.1. Train Acc: 0.9778. Test Acc:0.7542
# Epoch: 500. Train Loss: 0.07091. Test Loss: 1.093. Train Acc: 0.9848. Test Acc:0.7602
# Epoch: 510. Train Loss: 0.06559. Test Loss: 1.105. Train Acc: 0.9843. Test Acc:0.7559
# Epoch: 520. Train Loss: 0.05795. Test Loss: 1.133. Train Acc: 0.9884. Test Acc:0.7559
# Epoch: 530. Train Loss: 0.06221. Test Loss: 1.164. Train Acc: 0.9872. Test Acc:0.7477
# Epoch: 540. Train Loss: 0.05803. Test Loss: 1.155. Train Acc: 0.9884. Test Acc:0.7542
# Epoch: 550. Train Loss: 0.0545. Test Loss: 1.134. Train Acc: 0.9904. Test Acc:0.7589
# Epoch: 560. Train Loss: 0.05074. Test Loss: 1.163. Train Acc: 0.9909. Test Acc:0.7538
# Epoch: 570. Train Loss: 0.04752. Test Loss: 1.16. Train Acc: 0.9912. Test Acc:0.7585
# Epoch: 580. Train Loss: 0.05173. Test Loss: 1.182. Train Acc: 0.9904. Test Acc:0.7533
# Epoch: 590. Train Loss: 0.04517. Test Loss: 1.188. Train Acc: 0.9923. Test Acc:0.7564
# Epoch: 600. Train Loss: 0.04452. Test Loss: 1.202. Train Acc: 0.9921. Test Acc:0.7538
# Epoch: 610. Train Loss: 0.04366. Test Loss: 1.201. Train Acc: 0.9933. Test Acc:0.7495
# Epoch: 620. Train Loss: 0.04781. Test Loss: 1.229. Train Acc: 0.9921. Test Acc:0.7551
# Epoch: 630. Train Loss: 0.04703. Test Loss: 1.231. Train Acc: 0.9914. Test Acc:0.7559
# Epoch: 640. Train Loss: 0.03671. Test Loss: 1.208. Train Acc: 0.9955. Test Acc:0.7572
# Epoch: 650. Train Loss: 0.03921. Test Loss: 1.217. Train Acc: 0.9939. Test Acc:0.7564
# Epoch: 660. Train Loss: 0.03096. Test Loss: 1.225. Train Acc: 0.9961. Test Acc:0.7602
# Epoch: 670. Train Loss: 0.03042. Test Loss: 1.248. Train Acc: 0.9961. Test Acc:0.7538
# Epoch: 680. Train Loss: 0.02964. Test Loss: 1.266. Train Acc: 0.9966. Test Acc:0.7542
# Epoch: 690. Train Loss: 0.02972. Test Loss: 1.249. Train Acc: 0.9966. Test Acc:0.7555
# Epoch: 700. Train Loss: 0.02371. Test Loss: 1.27. Train Acc: 0.9976. Test Acc:0.762
# Epoch: 710. Train Loss: 0.03512. Test Loss: 1.29. Train Acc: 0.9931. Test Acc:0.7572
# Epoch: 720. Train Loss: 0.02714. Test Loss: 1.254. Train Acc: 0.9968. Test Acc:0.7663
# Epoch: 730. Train Loss: 0.02471. Test Loss: 1.263. Train Acc: 0.9968. Test Acc:0.7633
# Epoch: 740. Train Loss: 0.02512. Test Loss: 1.259. Train Acc: 0.9968. Test Acc:0.7581
# Epoch: 750. Train Loss: 0.02253. Test Loss: 1.269. Train Acc: 0.999. Test Acc:0.7637
# Epoch: 760. Train Loss: 0.02631. Test Loss: 1.314. Train Acc: 0.9975. Test Acc:0.7477
# Epoch: 770. Train Loss: 0.02634. Test Loss: 1.254. Train Acc: 0.997. Test Acc:0.7577
# Epoch: 780. Train Loss: 0.02709. Test Loss: 1.324. Train Acc: 0.9965. Test Acc:0.7516
# Epoch: 790. Train Loss: 0.03205. Test Loss: 1.298. Train Acc: 0.9951. Test Acc:0.7581
# Epoch: 800. Train Loss: 0.03374. Test Loss: 1.355. Train Acc: 0.9941. Test Acc:0.7529
# Epoch: 810. Train Loss: 0.02352. Test Loss: 1.295. Train Acc: 0.9978. Test Acc:0.7615
# Epoch: 820. Train Loss: 0.01802. Test Loss: 1.313. Train Acc: 0.9988. Test Acc:0.7637
# Epoch: 830. Train Loss: 0.01691. Test Loss: 1.318. Train Acc: 0.9988. Test Acc:0.7697
# Epoch: 840. Train Loss: 0.01419. Test Loss: 1.334. Train Acc: 0.9997. Test Acc:0.7598
# Epoch: 850. Train Loss: 0.02019. Test Loss: 1.367. Train Acc: 0.997. Test Acc:0.7598
# Epoch: 860. Train Loss: 0.01706. Test Loss: 1.326. Train Acc: 0.9985. Test Acc:0.7572
# Epoch: 870. Train Loss: 0.01571. Test Loss: 1.329. Train Acc: 0.9992. Test Acc:0.7641
# Epoch: 880. Train Loss: 0.01414. Test Loss: 1.294. Train Acc: 0.9993. Test Acc:0.7671
# Epoch: 890. Train Loss: 0.01953. Test Loss: 1.334. Train Acc: 0.9968. Test Acc:0.7654
# Epoch: 900. Train Loss: 0.02024. Test Loss: 1.339. Train Acc: 0.9976. Test Acc:0.7615
# Epoch: 910. Train Loss: 0.02035. Test Loss: 1.374. Train Acc: 0.9968. Test Acc:0.7542
# Epoch: 920. Train Loss: 0.01619. Test Loss: 1.344. Train Acc: 0.9988. Test Acc:0.7581
# Epoch: 930. Train Loss: 0.01542. Test Loss: 1.354. Train Acc: 0.9992. Test Acc:0.7646
# Epoch: 940. Train Loss: 0.01232. Test Loss: 1.337. Train Acc: 0.9995. Test Acc:0.7633
# Epoch: 950. Train Loss: 0.01641. Test Loss: 1.342. Train Acc: 0.9987. Test Acc:0.7624
# Epoch: 960. Train Loss: 0.01701. Test Loss: 1.357. Train Acc: 0.998. Test Acc:0.7585
# Epoch: 970. Train Loss: 0.01413. Test Loss: 1.4. Train Acc: 0.999. Test Acc:0.7542
# Epoch: 980. Train Loss: 0.01654. Test Loss: 1.371. Train Acc: 0.9988. Test Acc:0.7611
# Epoch: 990. Train Loss: 0.01125. Test Loss: 1.348. Train Acc: 0.9998. Test Acc:0.7732
# Epoch: 1000. Train Loss: 0.01094. Test Loss: 1.387. Train Acc: 0.999. Test Acc:0.7689
# ASRCNN__conv_pool_max__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#1
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 5940
# test_n: 2319
# Epoch: 10. Train Loss: 2.537. Test Loss: 2.682. Train Acc: 0.1101. Test Acc:0.09746
# Epoch: 20. Train Loss: 1.983. Test Loss: 2.242. Train Acc: 0.3061. Test Acc:0.2126
# Epoch: 30. Train Loss: 1.483. Test Loss: 1.857. Train Acc: 0.5281. Test Acc:0.3687
# Epoch: 40. Train Loss: 1.135. Test Loss: 1.567. Train Acc: 0.683. Test Acc:0.5119
# Epoch: 50. Train Loss: 0.9408. Test Loss: 1.38. Train Acc: 0.7633. Test Acc:0.5744
# Epoch: 60. Train Loss: 0.8219. Test Loss: 1.276. Train Acc: 0.8002. Test Acc:0.6166
# Epoch: 70. Train Loss: 0.7376. Test Loss: 1.21. Train Acc: 0.8281. Test Acc:0.6339
# Epoch: 80. Train Loss: 0.6616. Test Loss: 1.152. Train Acc: 0.852. Test Acc:0.6615
# Epoch: 90. Train Loss: 0.608. Test Loss: 1.129. Train Acc: 0.8653. Test Acc:0.6731
# Epoch: 100. Train Loss: 0.5649. Test Loss: 1.116. Train Acc: 0.8781. Test Acc:0.6774
# Epoch: 110. Train Loss: 0.545. Test Loss: 1.099. Train Acc: 0.8739. Test Acc:0.671
# Epoch: 120. Train Loss: 0.5394. Test Loss: 1.114. Train Acc: 0.8667. Test Acc:0.6641
# Epoch: 130. Train Loss: 0.4416. Test Loss: 0.9843. Train Acc: 0.9187. Test Acc:0.7063
# Epoch: 140. Train Loss: 0.4126. Test Loss: 0.9647. Train Acc: 0.9212. Test Acc:0.7206
# Epoch: 150. Train Loss: 0.3872. Test Loss: 0.9571. Train Acc: 0.9301. Test Acc:0.7206
# Epoch: 160. Train Loss: 0.3654. Test Loss: 0.9625. Train Acc: 0.936. Test Acc:0.7201
# Epoch: 170. Train Loss: 0.3427. Test Loss: 0.964. Train Acc: 0.9392. Test Acc:0.7197
# Epoch: 180. Train Loss: 0.3292. Test Loss: 0.9626. Train Acc: 0.9367. Test Acc:0.7176
# Epoch: 190. Train Loss: 0.3087. Test Loss: 0.9643. Train Acc: 0.9487. Test Acc:0.724
# Epoch: 200. Train Loss: 0.2991. Test Loss: 0.9674. Train Acc: 0.9487. Test Acc:0.7296
# Epoch: 210. Train Loss: 0.2821. Test Loss: 0.9716. Train Acc: 0.9495. Test Acc:0.7257
# Epoch: 220. Train Loss: 0.2808. Test Loss: 0.9605. Train Acc: 0.9421. Test Acc:0.7219
# Epoch: 230. Train Loss: 0.2541. Test Loss: 0.9512. Train Acc: 0.9547. Test Acc:0.7296
# Epoch: 240. Train Loss: 0.2449. Test Loss: 0.9517. Train Acc: 0.9569. Test Acc:0.7344
# Epoch: 250. Train Loss: 0.2366. Test Loss: 0.9832. Train Acc: 0.9588. Test Acc:0.7326
# Epoch: 260. Train Loss: 0.2181. Test Loss: 0.9474. Train Acc: 0.9631. Test Acc:0.7374
# Epoch: 270. Train Loss: 0.2223. Test Loss: 0.9697. Train Acc: 0.9606. Test Acc:0.7309
# Epoch: 280. Train Loss: 0.2187. Test Loss: 0.9564. Train Acc: 0.9572. Test Acc:0.7288
# Epoch: 290. Train Loss: 0.231. Test Loss: 0.9866. Train Acc: 0.9534. Test Acc:0.7214
# Epoch: 300. Train Loss: 0.1865. Test Loss: 0.9488. Train Acc: 0.968. Test Acc:0.7404
# Epoch: 310. Train Loss: 0.1763. Test Loss: 0.9465. Train Acc: 0.97. Test Acc:0.7413
# Epoch: 320. Train Loss: 0.1674. Test Loss: 0.9543. Train Acc: 0.9737. Test Acc:0.7365
# Epoch: 330. Train Loss: 0.1707. Test Loss: 0.9477. Train Acc: 0.9695. Test Acc:0.7365
# Epoch: 340. Train Loss: 0.1511. Test Loss: 0.9665. Train Acc: 0.9783. Test Acc:0.7408
# Epoch: 350. Train Loss: 0.1613. Test Loss: 0.9724. Train Acc: 0.9675. Test Acc:0.7313
# Epoch: 360. Train Loss: 0.1414. Test Loss: 0.9717. Train Acc: 0.9796. Test Acc:0.7473
# Epoch: 370. Train Loss: 0.1437. Test Loss: 0.996. Train Acc: 0.9753. Test Acc:0.7361
# Epoch: 380. Train Loss: 0.1426. Test Loss: 0.9886. Train Acc: 0.9707. Test Acc:0.7318
# Epoch: 390. Train Loss: 0.1483. Test Loss: 0.995. Train Acc: 0.9722. Test Acc:0.7331
# Epoch: 400. Train Loss: 0.121. Test Loss: 1.017. Train Acc: 0.9818. Test Acc:0.7357
# Epoch: 410. Train Loss: 0.1194. Test Loss: 0.9779. Train Acc: 0.9793. Test Acc:0.7469
# Epoch: 420. Train Loss: 0.1147. Test Loss: 1.004. Train Acc: 0.984. Test Acc:0.7447
# Epoch: 430. Train Loss: 0.1255. Test Loss: 1.022. Train Acc: 0.9731. Test Acc:0.7266
# Epoch: 440. Train Loss: 0.1104. Test Loss: 1.009. Train Acc: 0.9788. Test Acc:0.7374
# Epoch: 450. Train Loss: 0.1027. Test Loss: 1.008. Train Acc: 0.9847. Test Acc:0.7391
# Epoch: 460. Train Loss: 0.1026. Test Loss: 1.054. Train Acc: 0.9832. Test Acc:0.7348
# Epoch: 470. Train Loss: 0.1034. Test Loss: 1.042. Train Acc: 0.9825. Test Acc:0.7296
# Epoch: 480. Train Loss: 0.09599. Test Loss: 1.052. Train Acc: 0.9852. Test Acc:0.7313
# Epoch: 490. Train Loss: 0.09172. Test Loss: 1.056. Train Acc: 0.988. Test Acc:0.7382
# Epoch: 500. Train Loss: 0.09105. Test Loss: 1.051. Train Acc: 0.985. Test Acc:0.737
# Epoch: 510. Train Loss: 0.0945. Test Loss: 1.104. Train Acc: 0.9842. Test Acc:0.7292
# Epoch: 520. Train Loss: 0.08711. Test Loss: 1.061. Train Acc: 0.9875. Test Acc:0.737
# Epoch: 530. Train Loss: 0.08615. Test Loss: 1.072. Train Acc: 0.9875. Test Acc:0.7322
# Epoch: 540. Train Loss: 0.08026. Test Loss: 1.069. Train Acc: 0.987. Test Acc:0.7322
# Epoch: 550. Train Loss: 0.07655. Test Loss: 1.064. Train Acc: 0.9911. Test Acc:0.7404
# Epoch: 560. Train Loss: 0.08143. Test Loss: 1.086. Train Acc: 0.9854. Test Acc:0.7262
# Epoch: 570. Train Loss: 0.07958. Test Loss: 1.078. Train Acc: 0.9887. Test Acc:0.7374
# Epoch: 580. Train Loss: 0.0834. Test Loss: 1.096. Train Acc: 0.986. Test Acc:0.7322
# Epoch: 590. Train Loss: 0.07429. Test Loss: 1.082. Train Acc: 0.9884. Test Acc:0.7236
# Epoch: 600. Train Loss: 0.07568. Test Loss: 1.112. Train Acc: 0.985. Test Acc:0.7365
# Epoch: 610. Train Loss: 0.07422. Test Loss: 1.096. Train Acc: 0.9875. Test Acc:0.7395
# Epoch: 620. Train Loss: 0.07328. Test Loss: 1.088. Train Acc: 0.9874. Test Acc:0.7456
# Epoch: 630. Train Loss: 0.07308. Test Loss: 1.138. Train Acc: 0.9875. Test Acc:0.7275
# Epoch: 640. Train Loss: 0.09011. Test Loss: 1.188. Train Acc: 0.9788. Test Acc:0.7227
# Epoch: 650. Train Loss: 0.09658. Test Loss: 1.201. Train Acc: 0.9774. Test Acc:0.7145
# Epoch: 660. Train Loss: 0.06544. Test Loss: 1.175. Train Acc: 0.9929. Test Acc:0.727
# Epoch: 670. Train Loss: 0.09117. Test Loss: 1.302. Train Acc: 0.9892. Test Acc:0.7288
# Epoch: 680. Train Loss: 0.06726. Test Loss: 1.242. Train Acc: 0.9953. Test Acc:0.7413
# Epoch: 690. Train Loss: 0.05065. Test Loss: 1.159. Train Acc: 0.9961. Test Acc:0.7413
# Epoch: 700. Train Loss: 0.05765. Test Loss: 1.211. Train Acc: 0.9944. Test Acc:0.7365
# Epoch: 710. Train Loss: 0.0592. Test Loss: 1.212. Train Acc: 0.9934. Test Acc:0.7395
# Epoch: 720. Train Loss: 0.05497. Test Loss: 1.195. Train Acc: 0.9929. Test Acc:0.7344
# Epoch: 730. Train Loss: 0.05276. Test Loss: 1.2. Train Acc: 0.9941. Test Acc:0.7439
# Epoch: 740. Train Loss: 0.04742. Test Loss: 1.164. Train Acc: 0.9961. Test Acc:0.7408
# Epoch: 750. Train Loss: 0.05059. Test Loss: 1.185. Train Acc: 0.9951. Test Acc:0.7421
# Epoch: 760. Train Loss: 0.04604. Test Loss: 1.217. Train Acc: 0.9961. Test Acc:0.743
# Epoch: 770. Train Loss: 0.04162. Test Loss: 1.179. Train Acc: 0.997. Test Acc:0.74
# Epoch: 780. Train Loss: 0.04561. Test Loss: 1.194. Train Acc: 0.9946. Test Acc:0.7374
# Epoch: 790. Train Loss: 0.03906. Test Loss: 1.159. Train Acc: 0.9971. Test Acc:0.7447
# Epoch: 800. Train Loss: 0.04083. Test Loss: 1.239. Train Acc: 0.998. Test Acc:0.7421
# Epoch: 810. Train Loss: 0.03636. Test Loss: 1.206. Train Acc: 0.998. Test Acc:0.7365
# Epoch: 820. Train Loss: 0.0368. Test Loss: 1.226. Train Acc: 0.996. Test Acc:0.7404
# Epoch: 830. Train Loss: 0.0376. Test Loss: 1.228. Train Acc: 0.9963. Test Acc:0.7387
# Epoch: 840. Train Loss: 0.04214. Test Loss: 1.219. Train Acc: 0.9948. Test Acc:0.7318
# Epoch: 850. Train Loss: 0.0458. Test Loss: 1.243. Train Acc: 0.9939. Test Acc:0.7279
# Epoch: 860. Train Loss: 0.04452. Test Loss: 1.266. Train Acc: 0.9958. Test Acc:0.7344
# Epoch: 870. Train Loss: 0.05318. Test Loss: 1.332. Train Acc: 0.9943. Test Acc:0.7361
# Epoch: 880. Train Loss: 0.05202. Test Loss: 1.324. Train Acc: 0.9907. Test Acc:0.7313
# Epoch: 890. Train Loss: 0.0313. Test Loss: 1.218. Train Acc: 0.9975. Test Acc:0.7503
# Epoch: 900. Train Loss: 0.03357. Test Loss: 1.216. Train Acc: 0.9948. Test Acc:0.7413
# Epoch: 910. Train Loss: 0.03695. Test Loss: 1.27. Train Acc: 0.996. Test Acc:0.7426
# Epoch: 920. Train Loss: 0.03757. Test Loss: 1.28. Train Acc: 0.9973. Test Acc:0.7408
# Epoch: 930. Train Loss: 0.02819. Test Loss: 1.244. Train Acc: 0.9983. Test Acc:0.7447
# Epoch: 940. Train Loss: 0.0315. Test Loss: 1.278. Train Acc: 0.9983. Test Acc:0.74
# Epoch: 950. Train Loss: 0.03295. Test Loss: 1.29. Train Acc: 0.9985. Test Acc:0.7339
# Epoch: 960. Train Loss: 0.03923. Test Loss: 1.317. Train Acc: 0.9976. Test Acc:0.7387
# Epoch: 970. Train Loss: 0.0312. Test Loss: 1.259. Train Acc: 0.9956. Test Acc:0.7451
# Epoch: 980. Train Loss: 0.02647. Test Loss: 1.24. Train Acc: 0.9988. Test Acc:0.7477
