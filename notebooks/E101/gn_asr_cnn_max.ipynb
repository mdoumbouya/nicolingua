# %%
from pathlib import Path
import csv
import itertools
import numpy as np
from pprint import PrettyPrinter


import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

import h5py

import sklearn
import sklearn.metrics

pprint = PrettyPrinter()

# %% [markdown]
# ## Configuration

# %%
SELECTED_LANGUAGES = {'_language_independent', 'francais', 'maninka', 'pular', 'susu'}

BASE_DIR = Path('/media/xtrem/data/experiments/nicolingua-0002-va-asr/datasets/gn_va_asr_dataset_2020-08-24_02')


ANNOTATIONS_PATH = BASE_DIR/ "annotated_segments" / "metadata.csv"


FEATURE_NAMES = [
    "wav2vec_features-c", 
    "wav2vec_features-z", 
    "retrained-wav2vec_features-c", 
    "retrained-wav2vec_features-z"
]

# CONV_POOLING_TYPES = ['avg', 'max']
CONV_POOLING_TYPES = ['max']
OBJECTIVE_TYPES = ['voice_cmd', 'voice_cmd__and__voice_cmd_lng']
CONV_DROPOUT_PROBABILITIES = [0.3]
FC_DROPOUT_PROBABILITIES = [0.3]


TRAIN_PERCENT = .7
FOLD_COUNT = 5


RESULTS_DIR = f'results_101'
EPOCHS = 1000
BATCH_SIZE = 512
MAX_FEATURE_SEQUENCE_LENGTH = 200

GPU_ID = 1
device = torch.device(f"cuda:{GPU_ID}")

# %% [markdown]
# ## Load & shuffle metadata records

# %%
def load_metadata():
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for r in reader:
            if r['language'] in SELECTED_LANGUAGES:
                yield r

# %%
# load
metadata_records = list(load_metadata())

# shuffle
metadata_shuffler_rs = np.random.RandomState(seed=42)
metadata_shuffler_rs.shuffle(metadata_records)

# %%
bias_category_fields = [
     "device_id"
    ,"language"
    ,"speaker_gender"
    ,"speaker_mothertongue"
]

bias_categories = {}
for c in bias_category_fields:
    bias_categories[c] = sorted({r[c] for r in metadata_records})


_ = [print(f"\n{k}: \n\t{','.join(v)}") for k,v in bias_categories.items()]
# Out:
# device_id:
# 	d001,d002,d003
#
# language:
# 	_language_independent,francais,maninka,pular,susu
#
# speaker_gender:
# 	F,M
#
# speaker_mothertongue:
# 	maninka,pular,susu

# %% [markdown]
# ### Labels

# %%
# VOICE COMMANDS
voice_cmd_class_names = sorted({r['label'] for r in metadata_records})
voice_cmd_class_count = len(voice_cmd_class_names)
voice_cmd_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_class_names)}

print("Classes - Voice Commands")
_ = [print(f"{v:4}: {k}") for k,v in voice_cmd_class_id_by_name.items()]

print("---------------------")


# VOICE COMMAND LANGUAGES
voice_cmd_lng_class_names = sorted({r['language'] for r in metadata_records})
voice_cmd_lng_class_count = len(voice_cmd_lng_class_names)
voice_cmd_lng_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_lng_class_names)}

print("Classes - Voice Command Languages")
_ = [print(f"{v:3}: {k}") for k,v in voice_cmd_lng_class_id_by_name.items()]

print("---------------------")



# SPEAKER MOTHERTONGUE
spkr_mothertongue_class_names = sorted({r['speaker_mothertongue'] for r in metadata_records})
spkr_mothertongue_class_count = len(spkr_mothertongue_class_names)
spkr_mothertongue_class_id_by_name = {c:i for i,c in enumerate(spkr_mothertongue_class_names)}

print("Classes - Speaker Mothertongues")
_ = [print(f"{v:3}: {k}") for k,v in spkr_mothertongue_class_id_by_name.items()]

print("---------------------")



# SPEAKER GENDER
spkr_gender_class_names = sorted({r['speaker_gender'] for r in metadata_records})
spkr_gender_class_count = len(spkr_gender_class_names)
spkr_gender_class_id_by_name = {c:i for i, c in enumerate(spkr_gender_class_names)}

print("Classes - Speaker Gender")
_ = [print(f"{v:3}: {k}") for k,v in spkr_gender_class_id_by_name.items()]

print("----------------------")
# Out:
# Classes - Voice Commands
#    0: 101_wake_word__francais
#    1: 101_wake_word__maninka
#    2: 101_wake_word__pular
#    3: 101_wake_word__susu
#    4: 201_add_contact__francais
#    5: 201_add_contact__maninka
#    6: 201_add_contact__pular
#    7: 201_add_contact__susu
#    8: 202_search_contact__francais
#    9: 202_search_contact__maninka
#   10: 202_search_contact__pular
#   11: 202_search_contact__susu
#   12: 203_update_contact__francais
#   13: 203_update_contact__maninka
#   14: 203_update_contact__pular
#   15: 203_update_contact__susu
#   16: 204_delete_contact__francais
#   17: 204_delete_contact__maninka
#   18: 204_delete_contact__pular
#   19: 204_delete_contact__susu
#   20: 205_call_contact__francais
#   21: 205_call_contact__maninka
#   22: 205_call_contact__pular
#   23: 205_call_contact__susu
#   24: 206_yes__francais
#   25: 206_yes__maninka
#   26: 206_yes__pular
#   27: 206_yes__susu
#   28: 207_no__francais
#   29: 207_no__maninka
#   30: 207_no__pular
#   31: 207_no__susu
#   32: 301_zero__francais
#   33: 301_zero__maninka
#   34: 301_zero__pular
#   35: 301_zero__susu
#   36: 302_one__francais
#   37: 302_one__maninka
#   38: 302_one__pular
#   39: 302_one__susu
#   40: 303_two__francais
#   41: 303_two__maninka
#   42: 303_two__pular
#   43: 303_two__susu
#   44: 304_three__francais
#   45: 304_three__maninka
#   46: 304_three__pular
#   47: 304_three__susu
#   48: 305_four__francais
#   49: 305_four__maninka
#   50: 305_four__pular
#   51: 305_four__susu
#   52: 306_five__francais
#   53: 306_five__maninka
#   54: 306_five__pular
#   55: 306_five__susu
#   56: 307_six__francais
#   57: 307_six__maninka
#   58: 307_six__pular
#   59: 307_six__susu
#   60: 308_seven__francais
#   61: 308_seven__maninka
#   62: 308_seven__pular
#   63: 308_seven__susu
#   64: 309_eight__francais
#   65: 309_eight__maninka
#   66: 309_eight__pular
#   67: 309_eight__susu
#   68: 310_nine__francais
#   69: 310_nine__maninka
#   70: 310_nine__pular
#   71: 310_nine__susu
#   72: 401_mom__francais
#   73: 401_mom__maninka
#   74: 401_mom__pular
#   75: 401_mom__susu
#   76: 402_dad__francais
#   77: 402_dad__maninka
#   78: 402_dad__pular
#   79: 402_dad__susu
#   80: 501_fatoumata___language_independent
#   81: 502_mamadou___language_independent
#   82: 503_mariama___language_independent
#   83: 504_mohamed___language_independent
#   84: 505_kadiatou___language_independent
#   85: 506_ibrahima___language_independent
#   86: 507_aissatou___language_independent
#   87: 508_aminata___language_independent
#   88: 509_alpha___language_independent
#   89: 510_thierno___language_independent
#   90: 511_abdoulaye___language_independent
#   91: 512_aboubacar___language_independent
#   92: 513_amadou___language_independent
#   93: 514_fanta___language_independent
#   94: 515_mariame___language_independent
#   95: 516_oumou___language_independent
#   96: 517_ousmane___language_independent
#   97: 518_adama___language_independent
#   98: 519_marie___language_independent
#   99: 520_moussa___language_independent
#  100: 521_aissata___language_independent
#  101: 522_hawa___language_independent
#  102: 523_sekou___language_independent
#  103: 524_hadja___language_independent
#  104: 525_djenabou___language_independent
# ---------------------
# Classes - Voice Command Languages
#   0: _language_independent
#   1: francais
#   2: maninka
#   3: pular
#   4: susu
# ---------------------
# Classes - Speaker Mothertongues
#   0: maninka
#   1: pular
#   2: susu
# ---------------------
# Classes - Speaker Gender
#   0: F
#   1: M
# ----------------------

# %% [markdown]
# ### Inspect metadata

# %%
def count_by_attribute(records, attribute_names):
    attribute_name_instances = {}
    for attribute_name in attribute_names:
        attribute_name_instances[attribute_name] = {r[attribute_name] for r in records}
        
    l = [attribute_name_instances[attribute_name] for attribute_name in attribute_names]
    
    
    
    for attribute_values in sorted(itertools.product(*l)):
        
        def record_match(r):
            for i in range(len(attribute_names)):
                if r[attribute_names[i]] != attribute_values[i]:
                    return False
            return True
            
        record_instances = [r for r in records if record_match(r)]
        count = len(record_instances)
        
        yield (attribute_values, count)

# %%
print("RECORDS BY DEVICE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['device_id']))]
print("")

print("RECORDS BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['language']))]
print("")

print("RECORDS BY GENDER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_gender']))]
print("")

print("RECORDS BY AGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_age']))]
print("")

print("RECORDS BY SPEAKER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id']))]
print("")

print("RECORDS BY SPEAKER BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id', 'language']))]
print("")

print("RECORDS BY SPEAKER BY LABEL")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['label']))]
print("")
# Out:
# RECORDS BY DEVICE
# 	(('d001',), 2759)
# 	(('d002',), 2741)
# 	(('d003',), 2759)
#
# RECORDS BY LANGUAGE
# 	(('_language_independent',), 3072)
# 	(('francais',), 1260)
# 	(('maninka',), 1356)
# 	(('pular',), 909)
# 	(('susu',), 1662)
#
# RECORDS BY GENDER
# 	(('F',), 2820)
# 	(('M',), 5439)
#
# RECORDS BY AGE
# 	(('12',), 237)
# 	(('13',), 252)
# 	(('15',), 603)
# 	(('17',), 1050)
# 	(('18',), 855)
# 	(('19',), 273)
# 	(('20',), 291)
# 	(('27',), 255)
# 	(('28',), 183)
# 	(('29',), 237)
# 	(('31',), 255)
# 	(('32',), 291)
# 	(('33',), 183)
# 	(('34',), 129)
# 	(('35',), 498)
# 	(('37',), 309)
# 	(('38',), 441)
# 	(('43',), 183)
# 	(('44',), 540)
# 	(('5',), 129)
# 	(('55',), 183)
# 	(('61',), 390)
# 	(('63',), 237)
# 	(('67',), 255)
#
# RECORDS BY SPEAKER
# 	(('s001',), 183)
# 	(('s002',), 129)
# 	(('s003',), 183)
# 	(('s004',), 183)
# 	(('s005',), 129)
# 	(('s006',), 129)
# 	(('s007',), 183)
# 	(('s008',), 129)
# 	(('s009',), 237)
# 	(('s010',), 291)
# 	(('s011',), 129)
# 	(('s012',), 183)
# 	(('s013',), 129)
# 	(('s014',), 237)
# 	(('s015',), 291)
# 	(('s016',), 183)
# 	(('s017',), 237)
# 	(('s018',), 237)
# 	(('s019',), 237)
# 	(('s020',), 291)
# 	(('s021',), 273)
# 	(('s022',), 183)
# 	(('s023',), 309)
# 	(('s024',), 255)
# 	(('s025',), 315)
# 	(('s026',), 252)
# 	(('s027',), 540)
# 	(('s028',), 540)
# 	(('s029',), 390)
# 	(('s030',), 195)
# 	(('s031',), 252)
# 	(('s032',), 315)
# 	(('s033',), 255)
# 	(('s034',), 255)
#
# RECORDS BY SPEAKER BY LANGUAGE
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'francais'), 0)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'pular'), 0)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'francais'), 0)
# 	(('s002', 'maninka'), 54)
# 	(('s002', 'pular'), 0)
# 	(('s002', 'susu'), 0)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'francais'), 0)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'pular'), 0)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'francais'), 0)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'pular'), 0)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'francais'), 0)
# 	(('s005', 'maninka'), 0)
# 	(('s005', 'pular'), 0)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'francais'), 0)
# 	(('s006', 'maninka'), 54)
# 	(('s006', 'pular'), 0)
# 	(('s006', 'susu'), 0)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'francais'), 0)
# 	(('s007', 'maninka'), 0)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'francais'), 0)
# 	(('s008', 'maninka'), 54)
# 	(('s008', 'pular'), 0)
# 	(('s008', 'susu'), 0)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'maninka'), 0)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'francais'), 0)
# 	(('s011', 'maninka'), 0)
# 	(('s011', 'pular'), 0)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'maninka'), 0)
# 	(('s012', 'pular'), 0)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'francais'), 0)
# 	(('s013', 'maninka'), 0)
# 	(('s013', 'pular'), 0)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'pular'), 0)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'francais'), 0)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'pular'), 0)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'maninka'), 0)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'maninka'), 0)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'pular'), 0)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'francais'), 0)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'pular'), 0)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'pular'), 0)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'pular'), 0)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'maninka'), 0)
# 	(('s030', 'pular'), 60)
# 	(('s030', 'susu'), 0)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'maninka'), 0)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'pular'), 0)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'pular'), 0)
# 	(('s034', 'susu'), 60)
#
# RECORDS BY SPEAKER BY LABEL
# 	(('101_wake_word__francais',), 66)
# 	(('101_wake_word__maninka',), 72)
# 	(('101_wake_word__pular',), 48)
# 	(('101_wake_word__susu',), 89)
# 	(('201_add_contact__francais',), 66)
# 	(('201_add_contact__maninka',), 72)
# 	(('201_add_contact__pular',), 48)
# 	(('201_add_contact__susu',), 89)
# 	(('202_search_contact__francais',), 66)
# 	(('202_search_contact__maninka',), 72)
# 	(('202_search_contact__pular',), 48)
# 	(('202_search_contact__susu',), 89)
# 	(('203_update_contact__francais',), 66)
# 	(('203_update_contact__maninka',), 72)
# 	(('203_update_contact__pular',), 48)
# 	(('203_update_contact__susu',), 89)
# 	(('204_delete_contact__francais',), 66)
# 	(('204_delete_contact__maninka',), 72)
# 	(('204_delete_contact__pular',), 48)
# 	(('204_delete_contact__susu',), 89)
# 	(('205_call_contact__francais',), 66)
# 	(('205_call_contact__maninka',), 72)
# 	(('205_call_contact__pular',), 45)
# 	(('205_call_contact__susu',), 89)
# 	(('206_yes__francais',), 66)
# 	(('206_yes__maninka',), 72)
# 	(('206_yes__pular',), 48)
# 	(('206_yes__susu',), 89)
# 	(('207_no__francais',), 66)
# 	(('207_no__maninka',), 72)
# 	(('207_no__pular',), 48)
# 	(('207_no__susu',), 89)
# 	(('301_zero__francais',), 66)
# 	(('301_zero__maninka',), 72)
# 	(('301_zero__pular',), 48)
# 	(('301_zero__susu',), 89)
# 	(('302_one__francais',), 66)
# 	(('302_one__maninka',), 72)
# 	(('302_one__pular',), 48)
# 	(('302_one__susu',), 89)
# 	(('303_two__francais',), 66)
# 	(('303_two__maninka',), 72)
# 	(('303_two__pular',), 48)
# 	(('303_two__susu',), 89)
# 	(('304_three__francais',), 66)
# 	(('304_three__maninka',), 72)
# 	(('304_three__pular',), 48)
# 	(('304_three__susu',), 89)
# 	(('305_four__francais',), 66)
# 	(('305_four__maninka',), 72)
# 	(('305_four__pular',), 48)
# 	(('305_four__susu',), 89)
# 	(('306_five__francais',), 66)
# 	(('306_five__maninka',), 72)
# 	(('306_five__pular',), 48)
# 	(('306_five__susu',), 89)
# 	(('307_six__francais',), 66)
# 	(('307_six__maninka',), 72)
# 	(('307_six__pular',), 48)
# 	(('307_six__susu',), 89)
# 	(('308_seven__francais',), 66)
# 	(('308_seven__maninka',), 72)
# 	(('308_seven__pular',), 48)
# 	(('308_seven__susu',), 89)
# 	(('309_eight__francais',), 66)
# 	(('309_eight__maninka',), 72)
# 	(('309_eight__pular',), 48)
# 	(('309_eight__susu',), 89)
# 	(('310_nine__francais',), 66)
# 	(('310_nine__maninka',), 72)
# 	(('310_nine__pular',), 48)
# 	(('310_nine__susu',), 89)
# 	(('401_mom__francais',), 36)
# 	(('401_mom__maninka',), 30)
# 	(('401_mom__pular',), 24)
# 	(('401_mom__susu',), 30)
# 	(('402_dad__francais',), 36)
# 	(('402_dad__maninka',), 30)
# 	(('402_dad__pular',), 24)
# 	(('402_dad__susu',), 30)
# 	(('501_fatoumata___language_independent',), 123)
# 	(('502_mamadou___language_independent',), 123)
# 	(('503_mariama___language_independent',), 123)
# 	(('504_mohamed___language_independent',), 123)
# 	(('505_kadiatou___language_independent',), 123)
# 	(('506_ibrahima___language_independent',), 123)
# 	(('507_aissatou___language_independent',), 123)
# 	(('508_aminata___language_independent',), 123)
# 	(('509_alpha___language_independent',), 123)
# 	(('510_thierno___language_independent',), 120)
# 	(('511_abdoulaye___language_independent',), 123)
# 	(('512_aboubacar___language_independent',), 123)
# 	(('513_amadou___language_independent',), 123)
# 	(('514_fanta___language_independent',), 123)
# 	(('515_mariame___language_independent',), 123)
# 	(('516_oumou___language_independent',), 123)
# 	(('517_ousmane___language_independent',), 123)
# 	(('518_adama___language_independent',), 123)
# 	(('519_marie___language_independent',), 123)
# 	(('520_moussa___language_independent',), 123)
# 	(('521_aissata___language_independent',), 123)
# 	(('522_hawa___language_independent',), 123)
# 	(('523_sekou___language_independent',), 123)
# 	(('524_hadja___language_independent',), 123)
# 	(('525_djenabou___language_independent',), 123)

# %% [markdown]
# ## Prepare Cross Validation Folds
# - Partition by (speaker, language)
# - Each (speaker, language) correspond to `utterance_count * device_count`
# - For each fold, all `utterance_count * device_count` records for the same speaker in the same language are either in the TRAIN or the VALIDATION sets, but not both.

# %%
def generate_train_test_records_per_fold(all_records):
    records_per_fold = {}
    
    all_speaker_languages = sorted({(r['speaker_id'], r['language']) for r in all_records})

    sl_count = len(all_speaker_languages)
    all_sl_indices = range(sl_count)
    train_sl_count = int(np.ceil(sl_count*TRAIN_PERCENT))
    test_sl_count = sl_count - train_sl_count

    for fold_index in range(FOLD_COUNT):
        fold_rsampler = np.random.RandomState(seed=fold_index)

        train_sl_index_set = set(fold_rsampler.choice(all_sl_indices, train_sl_count, replace=False))
        train_sl_set = {all_speaker_languages[i] for i in train_sl_index_set}

        test_sl_index_set = set(all_sl_indices).difference(train_sl_index_set)
        test_sl_set = {all_speaker_languages[i] for i in test_sl_index_set}

        train_records = [r for r in all_records if (r['speaker_id'], r['language']) in train_sl_set]
        test_records = [r for r in all_records if (r['speaker_id'], r['language']) in test_sl_set]
        
        
        records_per_fold[fold_index] = {
            "train_records": train_records,
            "test_records": test_records
        }
    
    return records_per_fold

# %%
records_per_fold = generate_train_test_records_per_fold(metadata_records)

# %% [markdown]
# ### Inspect Folds

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['speaker_id', 'language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['speaker_id', 'language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', '_language_independent'), 75)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 0 -- TEST
# 	(('s004', 'maninka'), 54)
# 	(('s005', 'susu'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'susu'), 54)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 1 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'susu'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 1 -- TEST
# 	(('s001', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s030', 'francais'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s033', 'susu'), 60)
# ---------------------
# Fold 2 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', 'francais'), 54)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 2 -- TEST
# 	(('s002', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s033', '_language_independent'), 75)
# ---------------------
# Fold 3 -- TRAIN
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', 'susu'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 3 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s006', 'maninka'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s029', 'francais'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 4 -- TRAIN
# 	(('s001', 'susu'), 54)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'susu'), 54)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'susu'), 60)
# Fold 4 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN: ({len(train_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST: ({len(test_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN: (6018)
# 	(('_language_independent',), 2400)
# 	(('francais',), 738)
# 	(('maninka',), 960)
# 	(('pular',), 852)
# 	(('susu',), 1068)
# Fold 0 -- TEST: (2241)
# 	(('_language_independent',), 672)
# 	(('francais',), 522)
# 	(('maninka',), 396)
# 	(('pular',), 57)
# 	(('susu',), 594)
# ---------------------
# Fold 1 -- TRAIN: (5940)
# 	(('_language_independent',), 2325)
# 	(('francais',), 978)
# 	(('maninka',), 906)
# 	(('pular',), 519)
# 	(('susu',), 1212)
# Fold 1 -- TEST: (2319)
# 	(('_language_independent',), 747)
# 	(('francais',), 282)
# 	(('maninka',), 450)
# 	(('pular',), 390)
# 	(('susu',), 450)
# ---------------------
# Fold 2 -- TRAIN: (6036)
# 	(('_language_independent',), 2397)
# 	(('francais',), 972)
# 	(('maninka',), 912)
# 	(('pular',), 573)
# 	(('susu',), 1182)
# Fold 2 -- TEST: (2223)
# 	(('_language_independent',), 675)
# 	(('francais',), 288)
# 	(('maninka',), 444)
# 	(('pular',), 336)
# 	(('susu',), 480)
# ---------------------
# Fold 3 -- TRAIN: (5796)
# 	(('_language_independent',), 2097)
# 	(('francais',), 918)
# 	(('maninka',), 912)
# 	(('pular',), 801)
# 	(('susu',), 1068)
# Fold 3 -- TEST: (2463)
# 	(('_language_independent',), 975)
# 	(('francais',), 342)
# 	(('maninka',), 444)
# 	(('pular',), 108)
# 	(('susu',), 594)
# ---------------------
# Fold 4 -- TRAIN: (6003)
# 	(('_language_independent',), 2325)
# 	(('francais',), 924)
# 	(('maninka',), 906)
# 	(('pular',), 558)
# 	(('susu',), 1290)
# Fold 4 -- TEST: (2256)
# 	(('_language_independent',), 747)
# 	(('francais',), 336)
# 	(('maninka',), 450)
# 	(('pular',), 351)
# 	(('susu',), 372)
# ---------------------

# %% [markdown]
# ## Load Features

# %%
def load_features(records, feature_name):
    features_list = []
    
    features_input_dir = BASE_DIR / feature_name

    for r in records:
        feature_file_name = r['file'].replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            
            padded_features = np.zeros((MAX_FEATURE_SEQUENCE_LENGTH, 512), dtype=features.dtype)
            padded_features[:features_shape[0], :] = features
            
            
            features_list.append(padded_features)
    return features_list

# %%
def get_bias_category_labels(records):
    bias_category_labels = {}
    
    for cat in bias_categories:
        for cat_val in bias_categories[cat]:
            bias_category_labels[f"{cat}__{cat_val}"] = [1 if r[cat]==cat_val else 0 for r in records]
            
    return bias_category_labels

# %% [markdown]
# # Classification Models

# %%
class ASRCNN(nn.Module):
    def __init__(self, 
                 conv_pooling_type, 
                 conv_dropout_p, 
                 fc_dropout_p, 
                 voice_cmd_neuron_count, 
                 voice_cmd_lng_neuron_count,
                 objective_type
                ):
        
        super(ASRCNN, self).__init__()
        
        if conv_pooling_type not in {"max", "avg"}:
            raise ValueError(f"Unknown Conv Pooling Type: {conv_pooling_type}")
            
        conv_pooling_class_by_type = {
            "max": nn.MaxPool1d,
            "avg": nn.AvgPool1d,
        }
        
        conv_pooling_class = conv_pooling_class_by_type[conv_pooling_type]
        
        self.objective_type = objective_type
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=8, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=3)
        self.drop1 = nn.Dropout(p=conv_dropout_p)
        self.pool1 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=8, out_channels=16, kernel_size=3)
        self.drop2 = nn.Dropout(p=conv_dropout_p)
        self.pool2 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3)
        self.drop3 = nn.Dropout(p=conv_dropout_p)
        self.pool3 = conv_pooling_class(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3)
        self.drop4 = nn.Dropout(p=conv_dropout_p)
        self.pool4 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)
        
        self.lin61 = nn.Linear(in_features=112, out_features=voice_cmd_neuron_count)
        
        # 'voice_cmd', 'voice_cmd__and__voice_cmd_lng'
        if self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            self.lin62 = nn.Linear(in_features=112, out_features=voice_cmd_lng_neuron_count)
                
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        if self.objective_type == 'voice_cmd':
            logits_voice_cmd = self.lin61(v)
            return logits_voice_cmd
        elif self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd = self.lin61(v)
            logits_voice_cmd_lng = self.lin62(v)
            return logits_voice_cmd, logits_voice_cmd_lng
        else:
            raise(f"Unknown objective type: {self.objective_type}")

# %%
def get_data_for_fold(fold_id, feature_name):
    
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]
    
    train_features = load_features(train_records, feature_name)
    test_features = load_features(test_records, feature_name)
    
    train_x = np.array(train_features)
    test_x = np.array(test_features)
    
    train_y = {}
    train_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in train_records])
    train_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in train_records])
    train_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in train_records])
    train_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in train_records])
    
    

    
    test_y = {}
    test_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in test_records])
    test_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in test_records])
    test_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in test_records])
    test_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in test_records])

    train_bias_category_labels = get_bias_category_labels(train_records)
    test_bias_category_labels = get_bias_category_labels(test_records)
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y['voice_cmd']),
        torch.tensor(train_y['voice_cmd_lng']),
        # torch.tensor(train_y['spkr_mothertongue']),
        # torch.tensor(train_y['spkr_gender']),
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y['voice_cmd']),
        torch.tensor(test_y['voice_cmd_lng']),
        # torch.tensor(test_y['spkr_mothertongue']),
        # torch.tensor(test_y['spkr_gender']),
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
def train(model, optimizer, criterion, objective_type, train_loader):
    model.train()
    train_loss = 0

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(train_loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        optimizer.zero_grad()
        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs
            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs    
            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) / 2
            
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        

def test(model, criterion, objective_type, loader, bias_category_labels):
    model.eval()
    accumulated_loss = 0

    pred_classes = []
    true_classes = []

    pred_classes_lng = []
    true_classes_lng = []

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs

            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs
            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            pred_classes_lng.extend(
                get_predictions_for_logits(logits_voice_cmd_lng).cpu().numpy()
            )
            true_classes_lng.extend(y_voice_cmd_lng.cpu().numpy())

            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) /2
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        accumulated_loss += loss.item()

    n = len(true_classes)

    average_loss = accumulated_loss/n
    
    acc = sklearn.metrics.accuracy_score(true_classes, pred_classes)
    acc_by_bais_category = {
        category: sklearn.metrics.accuracy_score(true_classes, pred_classes, sample_weight=sw)
        for category, sw in bias_category_labels.items()
    }
    
    
    if objective_type == 'voice_cmd__and__voice_cmd_lng':
        acc_lng = sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng)
        acc_by_bais_category_lng = {
            category: sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng, sample_weight=sw)
            for category, sw in bias_category_labels.items()
        }
    else:
        acc_lng = -1
        acc_by_bais_category_lng = {
            category: -1
            for category, sw in bias_category_labels.items()
        }
        
    return n, average_loss, acc, acc_by_bais_category, acc_lng, acc_by_bais_category_lng
      
        
def train_on_fold(model, fold_id, feature_name, objective_type, batch_size, epochs):
    torch.manual_seed(0)
    results = {}
    
    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model, torch.zeros((10, MAX_FEATURE_SEQUENCE_LENGTH, 512)).to(device), show_input=False))
    print(f"train_n: {len(train_loader.dataset)}")
    print(f"test_n: {len(test_loader.dataset)}")

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(reduction='sum')

    for epoch in range(1, epochs+1):
        
        # train on training set
        train(model, optimizer, criterion, objective_type, train_loader)
        
        # test on training set
        train_n, train_average_loss, train_acc, train_acc_by_bais_category, train_acc_lng, train_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, train_loader, train_bias_category_labels)
        
        # test on test set
        test_n, test_average_loss, test_acc, test_acc_by_bais_category, test_acc_lng, test_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, test_loader, test_bias_category_labels)
        

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_average_loss:0.4}. Test Loss: {test_average_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
         
        results[epoch] = {
            'epoch': epoch,
            
            'train_n': train_n,
            'train_loss': train_average_loss,
            'train_acc': train_acc,
            'train_acc_lng': train_acc_lng,
            
            'test_n': test_n,
            'test_loss': test_average_loss,
            'test_acc': test_acc,
            'test_acc_lng': test_acc_lng
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in train_acc_by_bais_category_lng:
            results[epoch][f"train_acc_lng_{c}"] = train_acc_by_bais_category_lng[c]
            
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))

        for c in test_acc_by_bais_category_lng:
            results[epoch][f"test_acc_lng_{c}"] = test_acc_by_bais_category_lng[c]
            

    return results

# %%
import csv
from pathlib import Path

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='raise')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
trial_params = list(
    itertools.product(
        range(FOLD_COUNT),
        CONV_POOLING_TYPES,
        CONV_DROPOUT_PROBABILITIES,
        FC_DROPOUT_PROBABILITIES,
        FEATURE_NAMES, 
        OBJECTIVE_TYPES
    )
)    

_ = [print(t) for t in trial_params]

for fold_id, conv_pooling_type, conv_dropout_p, fc_dropout_p, feature_name, objective_type in trial_params:

    model_name = f"ASRCNN" + \
    f"__conv_pool_{conv_pooling_type}" + \
    f"__conv_dp_{conv_dropout_p}" + \
    f"__fc_dp_{fc_dropout_p}" + \
    f"__fn_{feature_name}" + \
    f"__obj_{objective_type}"
    
    model = ASRCNN(
        conv_pooling_type, 
        conv_dropout_p, 
        fc_dropout_p, 
        voice_cmd_neuron_count = voice_cmd_class_count, 
        voice_cmd_lng_neuron_count = voice_cmd_lng_class_count,
        objective_type = objective_type
    ).to(device)

    print(f"{model_name} using {feature_name} on fold#{fold_id}")

    epochs_results = train_on_fold(
        model, 
        fold_id, 
        feature_name, 
        objective_type, 
        batch_size = BATCH_SIZE, 
        epochs = EPOCHS
    )

    # results for only one fold
    folds_results = [{
        'fold_index': fold_id,
        'feature_name': feature_name,
        'epochs': epochs_results
    }]
    
    
    save_results(model_name, folds_results)
    # write_epoch_test_logits(model_name, all_folds_results)

    del model
# Out:
# (0, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd')
# (0, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd')
# (0, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd')
# (0, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd')
# (0, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd')
# (1, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd')
# (1, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd')
# (1, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd')
# (1, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd')
# (2, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd')
# (2, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd')
# (2, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd')
# (2, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd')
# (3, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd')
# (3, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd')
# (3, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd')
# (3, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd')
# (4, 'max', 0.3, 0.3, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd')
# (4, 'max', 0.3, 0.3, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd')
# (4, 'max', 0.3, 0.3, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd')
# (4, 'max', 0.3, 0.3, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# ASRCNN__conv_pool_max__conv_dp_0.3__fc_dp_0.3__fn_wav2vec_features-c__obj_voice_cmd using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6003
# test_n: 2256
# Epoch: 10. Train Loss: 3.969. Test Loss: 4.044. Train Acc: 0.07113. Test Acc:0.05541
# Epoch: 20. Train Loss: 3.239. Test Loss: 3.413. Train Acc: 0.1994. Test Acc:0.1467
# Epoch: 30. Train Loss: 2.832. Test Loss: 3.076. Train Acc: 0.2774. Test Acc:0.2278
# Epoch: 40. Train Loss: 2.529. Test Loss: 2.819. Train Acc: 0.3253. Test Acc:0.2726
# Epoch: 50. Train Loss: 2.222. Test Loss: 2.546. Train Acc: 0.4033. Test Acc:0.3236
# Epoch: 60. Train Loss: 1.948. Test Loss: 2.286. Train Acc: 0.4663. Test Acc:0.3861
# Epoch: 70. Train Loss: 1.705. Test Loss: 2.065. Train Acc: 0.5414. Test Acc:0.4344
# Epoch: 80. Train Loss: 1.558. Test Loss: 1.938. Train Acc: 0.5757. Test Acc:0.4761
# Epoch: 90. Train Loss: 1.571. Test Loss: 1.973. Train Acc: 0.5592. Test Acc:0.473
# Epoch: 100. Train Loss: 1.458. Test Loss: 1.884. Train Acc: 0.5874. Test Acc:0.4987
# Epoch: 110. Train Loss: 1.403. Test Loss: 1.856. Train Acc: 0.6015. Test Acc:0.5035
# Epoch: 120. Train Loss: 1.316. Test Loss: 1.784. Train Acc: 0.6214. Test Acc:0.523
# Epoch: 130. Train Loss: 1.246. Test Loss: 1.733. Train Acc: 0.6385. Test Acc:0.543
# Epoch: 140. Train Loss: 1.183. Test Loss: 1.685. Train Acc: 0.6545. Test Acc:0.5559
# Epoch: 150. Train Loss: 1.159. Test Loss: 1.666. Train Acc: 0.6547. Test Acc:0.5559
# Epoch: 160. Train Loss: 1.109. Test Loss: 1.644. Train Acc: 0.669. Test Acc:0.5621
# Epoch: 170. Train Loss: 1.06. Test Loss: 1.604. Train Acc: 0.6835. Test Acc:0.5652
# Epoch: 180. Train Loss: 0.9306. Test Loss: 1.495. Train Acc: 0.7241. Test Acc:0.6002
# Epoch: 190. Train Loss: 0.9795. Test Loss: 1.554. Train Acc: 0.7066. Test Acc:0.5842
# Epoch: 200. Train Loss: 0.97. Test Loss: 1.546. Train Acc: 0.7048. Test Acc:0.5847
# Epoch: 210. Train Loss: 1.101. Test Loss: 1.702. Train Acc: 0.666. Test Acc:0.5426
# Epoch: 220. Train Loss: 0.9369. Test Loss: 1.55. Train Acc: 0.7171. Test Acc:0.586
# Epoch: 230. Train Loss: 0.8554. Test Loss: 1.475. Train Acc: 0.7378. Test Acc:0.6082
# Epoch: 240. Train Loss: 0.8269. Test Loss: 1.449. Train Acc: 0.7495. Test Acc:0.6197
# Epoch: 250. Train Loss: 0.798. Test Loss: 1.432. Train Acc: 0.7596. Test Acc:0.6179
# Epoch: 260. Train Loss: 0.8714. Test Loss: 1.53. Train Acc: 0.7326. Test Acc:0.5953
# Epoch: 270. Train Loss: 0.8109. Test Loss: 1.459. Train Acc: 0.7553. Test Acc:0.6104
# Epoch: 280. Train Loss: 0.7823. Test Loss: 1.446. Train Acc: 0.7611. Test Acc:0.6197
# Epoch: 290. Train Loss: 0.7047. Test Loss: 1.352. Train Acc: 0.7843. Test Acc:0.6396
# Epoch: 300. Train Loss: 0.7923. Test Loss: 1.468. Train Acc: 0.7555. Test Acc:0.6113
# Epoch: 310. Train Loss: 0.7416. Test Loss: 1.427. Train Acc: 0.7749. Test Acc:0.6228
# Epoch: 320. Train Loss: 0.8185. Test Loss: 1.527. Train Acc: 0.7473. Test Acc:0.6037
# Epoch: 330. Train Loss: 0.6859. Test Loss: 1.383. Train Acc: 0.7916. Test Acc:0.6365
# Epoch: 340. Train Loss: 0.7292. Test Loss: 1.447. Train Acc: 0.7746. Test Acc:0.6316
# Epoch: 350. Train Loss: 0.6721. Test Loss: 1.399. Train Acc: 0.7941. Test Acc:0.6343
# Epoch: 360. Train Loss: 0.7876. Test Loss: 1.538. Train Acc: 0.7565. Test Acc:0.6099
# Epoch: 370. Train Loss: 0.6545. Test Loss: 1.389. Train Acc: 0.7966. Test Acc:0.6379
# Epoch: 380. Train Loss: 0.7488. Test Loss: 1.506. Train Acc: 0.7714. Test Acc:0.6201
# Epoch: 390. Train Loss: 0.7284. Test Loss: 1.492. Train Acc: 0.7758. Test Acc:0.6241
# Epoch: 400. Train Loss: 0.6659. Test Loss: 1.42. Train Acc: 0.7921. Test Acc:0.6352
# Epoch: 410. Train Loss: 0.6511. Test Loss: 1.414. Train Acc: 0.7988. Test Acc:0.6383
# Epoch: 420. Train Loss: 0.6661. Test Loss: 1.453. Train Acc: 0.7916. Test Acc:0.6343
# Epoch: 430. Train Loss: 0.627. Test Loss: 1.4. Train Acc: 0.8019. Test Acc:0.652
# Epoch: 440. Train Loss: 0.582. Test Loss: 1.363. Train Acc: 0.8218. Test Acc:0.6538
# Epoch: 450. Train Loss: 0.6734. Test Loss: 1.485. Train Acc: 0.7893. Test Acc:0.6281
# Epoch: 460. Train Loss: 0.6436. Test Loss: 1.46. Train Acc: 0.7954. Test Acc:0.6294
# Epoch: 470. Train Loss: 0.6956. Test Loss: 1.53. Train Acc: 0.7844. Test Acc:0.6268
# Epoch: 480. Train Loss: 0.6203. Test Loss: 1.421. Train Acc: 0.8034. Test Acc:0.6423
# Epoch: 490. Train Loss: 0.5933. Test Loss: 1.391. Train Acc: 0.8124. Test Acc:0.6503
# Epoch: 500. Train Loss: 0.5431. Test Loss: 1.342. Train Acc: 0.8324. Test Acc:0.6622
# Epoch: 510. Train Loss: 0.5956. Test Loss: 1.438. Train Acc: 0.8138. Test Acc:0.6432
# Epoch: 520. Train Loss: 0.6563. Test Loss: 1.512. Train Acc: 0.7919. Test Acc:0.6299
# Epoch: 530. Train Loss: 0.6022. Test Loss: 1.466. Train Acc: 0.8094. Test Acc:0.633
# Epoch: 540. Train Loss: 0.6117. Test Loss: 1.47. Train Acc: 0.8073. Test Acc:0.6494
# Epoch: 550. Train Loss: 0.5296. Test Loss: 1.368. Train Acc: 0.8349. Test Acc:0.6653
# Epoch: 560. Train Loss: 0.603. Test Loss: 1.488. Train Acc: 0.8076. Test Acc:0.6449
# Epoch: 570. Train Loss: 0.568. Test Loss: 1.425. Train Acc: 0.8149. Test Acc:0.656
# Epoch: 580. Train Loss: 0.5509. Test Loss: 1.432. Train Acc: 0.8226. Test Acc:0.6578
# Epoch: 590. Train Loss: 0.5237. Test Loss: 1.394. Train Acc: 0.8324. Test Acc:0.6645
# Epoch: 600. Train Loss: 0.5146. Test Loss: 1.388. Train Acc: 0.8374. Test Acc:0.664
# Epoch: 610. Train Loss: 0.6538. Test Loss: 1.572. Train Acc: 0.7929. Test Acc:0.625
# Epoch: 620. Train Loss: 0.5056. Test Loss: 1.386. Train Acc: 0.8411. Test Acc:0.6667
# Epoch: 630. Train Loss: 0.4521. Test Loss: 1.329. Train Acc: 0.8557. Test Acc:0.676
# Epoch: 640. Train Loss: 0.5052. Test Loss: 1.395. Train Acc: 0.8426. Test Acc:0.6574
# Epoch: 650. Train Loss: 0.4614. Test Loss: 1.355. Train Acc: 0.8534. Test Acc:0.6755
# Epoch: 660. Train Loss: 0.4752. Test Loss: 1.377. Train Acc: 0.8451. Test Acc:0.6715
# Epoch: 670. Train Loss: 0.4349. Test Loss: 1.325. Train Acc: 0.8619. Test Acc:0.6729
# Epoch: 680. Train Loss: 0.4654. Test Loss: 1.358. Train Acc: 0.8491. Test Acc:0.6769
# Epoch: 690. Train Loss: 0.4442. Test Loss: 1.339. Train Acc: 0.8571. Test Acc:0.6835
# Epoch: 700. Train Loss: 0.5339. Test Loss: 1.478. Train Acc: 0.8273. Test Acc:0.648
# Epoch: 710. Train Loss: 0.5951. Test Loss: 1.562. Train Acc: 0.8086. Test Acc:0.6379
# Epoch: 720. Train Loss: 0.5553. Test Loss: 1.513. Train Acc: 0.8211. Test Acc:0.6414
# Epoch: 730. Train Loss: 0.5023. Test Loss: 1.464. Train Acc: 0.8371. Test Acc:0.6534
# Epoch: 740. Train Loss: 0.5797. Test Loss: 1.556. Train Acc: 0.8171. Test Acc:0.6387
# Epoch: 750. Train Loss: 0.4416. Test Loss: 1.376. Train Acc: 0.8561. Test Acc:0.6738
# Epoch: 760. Train Loss: 0.4784. Test Loss: 1.434. Train Acc: 0.8461. Test Acc:0.6605
# Epoch: 770. Train Loss: 0.6121. Test Loss: 1.625. Train Acc: 0.8071. Test Acc:0.6215
# Epoch: 780. Train Loss: 0.5382. Test Loss: 1.524. Train Acc: 0.8276. Test Acc:0.6405
# Epoch: 790. Train Loss: 0.426. Test Loss: 1.389. Train Acc: 0.8566. Test Acc:0.6684
# Epoch: 800. Train Loss: 0.61. Test Loss: 1.64. Train Acc: 0.8046. Test Acc:0.6175
# Epoch: 810. Train Loss: 0.5931. Test Loss: 1.625. Train Acc: 0.8113. Test Acc:0.6246
# Epoch: 820. Train Loss: 0.5598. Test Loss: 1.585. Train Acc: 0.8208. Test Acc:0.6339
# Epoch: 830. Train Loss: 0.5095. Test Loss: 1.489. Train Acc: 0.8352. Test Acc:0.6512
# Epoch: 840. Train Loss: 0.4934. Test Loss: 1.478. Train Acc: 0.8402. Test Acc:0.6565
# Epoch: 850. Train Loss: 0.5955. Test Loss: 1.621. Train Acc: 0.8104. Test Acc:0.6223
# Epoch: 860. Train Loss: 0.5799. Test Loss: 1.594. Train Acc: 0.8163. Test Acc:0.6299
# Epoch: 870. Train Loss: 0.5537. Test Loss: 1.584. Train Acc: 0.8214. Test Acc:0.6396
# Epoch: 880. Train Loss: 0.6009. Test Loss: 1.672. Train Acc: 0.8094. Test Acc:0.6206
# Epoch: 890. Train Loss: 0.5034. Test Loss: 1.552. Train Acc: 0.8319. Test Acc:0.6503
# Epoch: 900. Train Loss: 0.6065. Test Loss: 1.682. Train Acc: 0.8073. Test Acc:0.6277
# Epoch: 910. Train Loss: 0.636. Test Loss: 1.691. Train Acc: 0.8021. Test Acc:0.6219
# Epoch: 920. Train Loss: 0.5557. Test Loss: 1.605. Train Acc: 0.8231. Test Acc:0.6379
# Epoch: 930. Train Loss: 0.4886. Test Loss: 1.507. Train Acc: 0.8437. Test Acc:0.6591
# Epoch: 940. Train Loss: 0.5522. Test Loss: 1.615. Train Acc: 0.8236. Test Acc:0.6418
# Epoch: 950. Train Loss: 0.4319. Test Loss: 1.451. Train Acc: 0.8567. Test Acc:0.6676
# Epoch: 960. Train Loss: 0.4095. Test Loss: 1.422. Train Acc: 0.8666. Test Acc:0.6698
# Epoch: 970. Train Loss: 0.3937. Test Loss: 1.404. Train Acc: 0.8724. Test Acc:0.6755
# Epoch: 980. Train Loss: 0.3878. Test Loss: 1.411. Train Acc: 0.8692. Test Acc:0.68
# Epoch: 990. Train Loss: 0.422. Test Loss: 1.441. Train Acc: 0.8632. Test Acc:0.6698
# Epoch: 1000. Train Loss: 0.4155. Test Loss: 1.45. Train Acc: 0.8639. Test Acc:0.6724
# ASRCNN__conv_pool_max__conv_dp_0.3__fc_dp_0.3__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6003
# test_n: 2256
# Epoch: 10. Train Loss: 2.79. Test Loss: 2.87. Train Acc: 0.04514. Test Acc:0.03989
# Epoch: 20. Train Loss: 2.414. Test Loss: 2.525. Train Acc: 0.1203. Test Acc:0.09309
# Epoch: 30. Train Loss: 2.197. Test Loss: 2.312. Train Acc: 0.1679. Test Acc:0.1348
# Epoch: 40. Train Loss: 1.934. Test Loss: 2.088. Train Acc: 0.2682. Test Acc:0.2061
# Epoch: 50. Train Loss: 1.857. Test Loss: 2.024. Train Acc: 0.2799. Test Acc:0.2261
# Epoch: 60. Train Loss: 1.795. Test Loss: 1.987. Train Acc: 0.2945. Test Acc:0.2518
# Epoch: 70. Train Loss: 1.689. Test Loss: 1.904. Train Acc: 0.3357. Test Acc:0.2841
# Epoch: 80. Train Loss: 1.575. Test Loss: 1.829. Train Acc: 0.3801. Test Acc:0.3156
# Epoch: 90. Train Loss: 1.495. Test Loss: 1.787. Train Acc: 0.4153. Test Acc:0.3449
# Epoch: 100. Train Loss: 1.475. Test Loss: 1.775. Train Acc: 0.4138. Test Acc:0.3466
# Epoch: 110. Train Loss: 1.355. Test Loss: 1.697. Train Acc: 0.4729. Test Acc:0.3825
# Epoch: 120. Train Loss: 1.307. Test Loss: 1.662. Train Acc: 0.4939. Test Acc:0.4038
# Epoch: 130. Train Loss: 1.392. Test Loss: 1.732. Train Acc: 0.4373. Test Acc:0.3697
# Epoch: 140. Train Loss: 1.295. Test Loss: 1.652. Train Acc: 0.4886. Test Acc:0.398
# Epoch: 150. Train Loss: 1.166. Test Loss: 1.556. Train Acc: 0.5627. Test Acc:0.4366
# Epoch: 160. Train Loss: 1.146. Test Loss: 1.561. Train Acc: 0.5667. Test Acc:0.4322
# Epoch: 170. Train Loss: 1.134. Test Loss: 1.547. Train Acc: 0.567. Test Acc:0.4388
# Epoch: 180. Train Loss: 1.116. Test Loss: 1.536. Train Acc: 0.5704. Test Acc:0.445
# Epoch: 190. Train Loss: 1.033. Test Loss: 1.452. Train Acc: 0.6149. Test Acc:0.477
# Epoch: 200. Train Loss: 1.053. Test Loss: 1.505. Train Acc: 0.5997. Test Acc:0.4601
# Epoch: 210. Train Loss: 0.9697. Test Loss: 1.399. Train Acc: 0.6402. Test Acc:0.4978
# Epoch: 220. Train Loss: 0.9576. Test Loss: 1.378. Train Acc: 0.647. Test Acc:0.5089
# Epoch: 230. Train Loss: 0.8543. Test Loss: 1.302. Train Acc: 0.7. Test Acc:0.5421
# Epoch: 240. Train Loss: 0.8459. Test Loss: 1.297. Train Acc: 0.7013. Test Acc:0.5426
# Epoch: 250. Train Loss: 0.9419. Test Loss: 1.388. Train Acc: 0.6423. Test Acc:0.5027
# Epoch: 260. Train Loss: 0.8603. Test Loss: 1.313. Train Acc: 0.6873. Test Acc:0.539
# Epoch: 270. Train Loss: 0.8419. Test Loss: 1.316. Train Acc: 0.6903. Test Acc:0.5372
# Epoch: 280. Train Loss: 0.7818. Test Loss: 1.281. Train Acc: 0.7291. Test Acc:0.5705
# Epoch: 290. Train Loss: 0.6874. Test Loss: 1.147. Train Acc: 0.7829. Test Acc:0.625
# Epoch: 300. Train Loss: 0.7208. Test Loss: 1.194. Train Acc: 0.7548. Test Acc:0.598
# Epoch: 310. Train Loss: 0.7021. Test Loss: 1.184. Train Acc: 0.7656. Test Acc:0.6095
# Epoch: 320. Train Loss: 0.6711. Test Loss: 1.146. Train Acc: 0.7811. Test Acc:0.6232
# Epoch: 330. Train Loss: 0.6757. Test Loss: 1.18. Train Acc: 0.7734. Test Acc:0.6082
# Epoch: 340. Train Loss: 0.6871. Test Loss: 1.169. Train Acc: 0.762. Test Acc:0.6068
# Epoch: 350. Train Loss: 0.7312. Test Loss: 1.226. Train Acc: 0.7311. Test Acc:0.5798
# Epoch: 360. Train Loss: 0.6649. Test Loss: 1.188. Train Acc: 0.7693. Test Acc:0.6104
# Epoch: 370. Train Loss: 0.649. Test Loss: 1.148. Train Acc: 0.7706. Test Acc:0.6161
# Epoch: 380. Train Loss: 0.6079. Test Loss: 1.139. Train Acc: 0.7978. Test Acc:0.6303
# Epoch: 390. Train Loss: 0.5965. Test Loss: 1.138. Train Acc: 0.8043. Test Acc:0.6401
# Epoch: 400. Train Loss: 0.5691. Test Loss: 1.089. Train Acc: 0.8133. Test Acc:0.6565
# Epoch: 410. Train Loss: 0.5139. Test Loss: 1.059. Train Acc: 0.8477. Test Acc:0.6707
# Epoch: 420. Train Loss: 0.5431. Test Loss: 1.083. Train Acc: 0.8316. Test Acc:0.6613
# Epoch: 430. Train Loss: 0.5573. Test Loss: 1.108. Train Acc: 0.8216. Test Acc:0.6458
# Epoch: 440. Train Loss: 0.498. Test Loss: 1.046. Train Acc: 0.8482. Test Acc:0.664
# Epoch: 450. Train Loss: 0.4987. Test Loss: 1.036. Train Acc: 0.8416. Test Acc:0.668
# Epoch: 460. Train Loss: 0.5042. Test Loss: 1.064. Train Acc: 0.8392. Test Acc:0.6609
# Epoch: 470. Train Loss: 0.4875. Test Loss: 1.038. Train Acc: 0.8441. Test Acc:0.6662
# Epoch: 480. Train Loss: 0.5059. Test Loss: 1.057. Train Acc: 0.8276. Test Acc:0.6578
# Epoch: 490. Train Loss: 0.5252. Test Loss: 1.101. Train Acc: 0.8229. Test Acc:0.6498
# Epoch: 500. Train Loss: 0.4854. Test Loss: 1.02. Train Acc: 0.8339. Test Acc:0.6671
# Epoch: 510. Train Loss: 0.4434. Test Loss: 1.009. Train Acc: 0.8631. Test Acc:0.6862
# Epoch: 520. Train Loss: 0.4388. Test Loss: 1.015. Train Acc: 0.8624. Test Acc:0.68
# Epoch: 530. Train Loss: 0.4507. Test Loss: 1.039. Train Acc: 0.8586. Test Acc:0.6671
# Epoch: 540. Train Loss: 0.4342. Test Loss: 1.005. Train Acc: 0.8629. Test Acc:0.691
# Epoch: 550. Train Loss: 0.4431. Test Loss: 1.015. Train Acc: 0.8512. Test Acc:0.6662
# Epoch: 560. Train Loss: 0.4036. Test Loss: 0.9853. Train Acc: 0.8737. Test Acc:0.6866
# Epoch: 570. Train Loss: 0.4031. Test Loss: 1.013. Train Acc: 0.8736. Test Acc:0.6897
# Epoch: 580. Train Loss: 0.3985. Test Loss: 0.9977. Train Acc: 0.8759. Test Acc:0.6902
# Epoch: 590. Train Loss: 0.4224. Test Loss: 1.026. Train Acc: 0.8577. Test Acc:0.6751
# Epoch: 600. Train Loss: 0.3915. Test Loss: 1.022. Train Acc: 0.8757. Test Acc:0.6879
# Epoch: 610. Train Loss: 0.3891. Test Loss: 0.9868. Train Acc: 0.8729. Test Acc:0.6959
# Epoch: 620. Train Loss: 0.3725. Test Loss: 1.003. Train Acc: 0.8876. Test Acc:0.6897
# Epoch: 630. Train Loss: 0.3963. Test Loss: 1.015. Train Acc: 0.8679. Test Acc:0.6817
# Epoch: 640. Train Loss: 0.3771. Test Loss: 1.04. Train Acc: 0.8794. Test Acc:0.6804
# Epoch: 650. Train Loss: 0.3591. Test Loss: 0.9781. Train Acc: 0.8814. Test Acc:0.6977
# Epoch: 660. Train Loss: 0.3868. Test Loss: 1.033. Train Acc: 0.8704. Test Acc:0.6875
# Epoch: 670. Train Loss: 0.3522. Test Loss: 1.019. Train Acc: 0.8834. Test Acc:0.6893
# Epoch: 680. Train Loss: 0.3615. Test Loss: 1.008. Train Acc: 0.8819. Test Acc:0.6955
# Epoch: 690. Train Loss: 0.3748. Test Loss: 1.02. Train Acc: 0.8691. Test Acc:0.6941
# Epoch: 700. Train Loss: 0.3506. Test Loss: 1.036. Train Acc: 0.8846. Test Acc:0.699
# Epoch: 710. Train Loss: 0.3552. Test Loss: 0.9642. Train Acc: 0.8736. Test Acc:0.7083
# Epoch: 720. Train Loss: 0.3195. Test Loss: 0.9736. Train Acc: 0.9025. Test Acc:0.6981
# Epoch: 730. Train Loss: 0.3319. Test Loss: 0.9973. Train Acc: 0.8907. Test Acc:0.6999
# Epoch: 740. Train Loss: 0.3447. Test Loss: 0.9892. Train Acc: 0.8762. Test Acc:0.6964
# Epoch: 750. Train Loss: 0.3372. Test Loss: 0.9817. Train Acc: 0.8839. Test Acc:0.6999
# Epoch: 760. Train Loss: 0.3204. Test Loss: 0.9605. Train Acc: 0.8834. Test Acc:0.703
# Epoch: 770. Train Loss: 0.3025. Test Loss: 0.9702. Train Acc: 0.9037. Test Acc:0.7145
# Epoch: 780. Train Loss: 0.2905. Test Loss: 0.9273. Train Acc: 0.9042. Test Acc:0.7234
# Epoch: 790. Train Loss: 0.3225. Test Loss: 1.009. Train Acc: 0.8929. Test Acc:0.6955
# Epoch: 800. Train Loss: 0.3196. Test Loss: 1.005. Train Acc: 0.8889. Test Acc:0.6968
# Epoch: 810. Train Loss: 0.2977. Test Loss: 1.013. Train Acc: 0.9052. Test Acc:0.7017
# Epoch: 820. Train Loss: 0.3287. Test Loss: 1.007. Train Acc: 0.8816. Test Acc:0.6946
# Epoch: 830. Train Loss: 0.2775. Test Loss: 0.9744. Train Acc: 0.9087. Test Acc:0.7137
# Epoch: 840. Train Loss: 0.2954. Test Loss: 1.013. Train Acc: 0.8982. Test Acc:0.6999
# Epoch: 850. Train Loss: 0.2834. Test Loss: 0.9778. Train Acc: 0.9084. Test Acc:0.715
# Epoch: 860. Train Loss: 0.3144. Test Loss: 1.027. Train Acc: 0.8819. Test Acc:0.6937
# Epoch: 870. Train Loss: 0.2886. Test Loss: 0.963. Train Acc: 0.8982. Test Acc:0.7141
# Epoch: 880. Train Loss: 0.2934. Test Loss: 1.054. Train Acc: 0.8987. Test Acc:0.6946
# Epoch: 890. Train Loss: 0.2788. Test Loss: 0.9849. Train Acc: 0.9059. Test Acc:0.7079
# Epoch: 900. Train Loss: 0.2943. Test Loss: 1.05. Train Acc: 0.8941. Test Acc:0.6928
# Epoch: 910. Train Loss: 0.2648. Test Loss: 0.9706. Train Acc: 0.9109. Test Acc:0.7145
# Epoch: 920. Train Loss: 0.259. Test Loss: 0.9805. Train Acc: 0.9112. Test Acc:0.7079
# Epoch: 930. Train Loss: 0.2634. Test Loss: 0.9681. Train Acc: 0.9114. Test Acc:0.7163
# Epoch: 940. Train Loss: 0.2891. Test Loss: 1.005. Train Acc: 0.8951. Test Acc:0.7012
# Epoch: 950. Train Loss: 0.2494. Test Loss: 0.9734. Train Acc: 0.9155. Test Acc:0.715
# Epoch: 960. Train Loss: 0.2596. Test Loss: 0.9567. Train Acc: 0.9077. Test Acc:0.7105
# Epoch: 970. Train Loss: 0.2499. Test Loss: 0.9599. Train Acc: 0.9167. Test Acc:0.711
# Epoch: 980. Train Loss: 0.2694. Test Loss: 0.9878. Train Acc: 0.9114. Test Acc:0.7105
# Epoch: 990. Train Loss: 0.2511. Test Loss: 0.9752. Train Acc: 0.9159. Test Acc:0.7154
# Epoch: 1000. Train Loss: 0.241. Test Loss: 0.9397. Train Acc: 0.9217. Test Acc:0.7172
# ASRCNN__conv_pool_max__conv_dp_0.3__fc_dp_0.3__fn_wav2vec_features-z__obj_voice_cmd using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6003
# test_n: 2256
# Epoch: 10. Train Loss: 4.277. Test Loss: 4.346. Train Acc: 0.03115. Test Acc:0.02615
# Epoch: 20. Train Loss: 4.307. Test Loss: 4.418. Train Acc: 0.03598. Test Acc:0.02837
# Epoch: 30. Train Loss: 4.024. Test Loss: 4.161. Train Acc: 0.06264. Test Acc:0.04699
# Epoch: 40. Train Loss: 3.872. Test Loss: 3.991. Train Acc: 0.07796. Test Acc:0.07491
# Epoch: 50. Train Loss: 3.538. Test Loss: 3.667. Train Acc: 0.1206. Test Acc:0.1042
# Epoch: 60. Train Loss: 3.432. Test Loss: 3.566. Train Acc: 0.1369. Test Acc:0.1241
# Epoch: 70. Train Loss: 3.183. Test Loss: 3.361. Train Acc: 0.1819. Test Acc:0.1582
# Epoch: 80. Train Loss: 2.834. Test Loss: 3.057. Train Acc: 0.2459. Test Acc:0.2114
# Epoch: 90. Train Loss: 2.724. Test Loss: 2.982. Train Acc: 0.2742. Test Acc:0.2376
# Epoch: 100. Train Loss: 2.599. Test Loss: 2.88. Train Acc: 0.2952. Test Acc:0.2482
# Epoch: 110. Train Loss: 2.676. Test Loss: 2.969. Train Acc: 0.2814. Test Acc:0.2398
# Epoch: 120. Train Loss: 2.524. Test Loss: 2.856. Train Acc: 0.3145. Test Acc:0.2606
# Epoch: 130. Train Loss: 2.288. Test Loss: 2.639. Train Acc: 0.3652. Test Acc:0.3032
# Epoch: 140. Train Loss: 2.235. Test Loss: 2.608. Train Acc: 0.3723. Test Acc:0.3085
# Epoch: 150. Train Loss: 2.18. Test Loss: 2.577. Train Acc: 0.3893. Test Acc:0.3169
# Epoch: 160. Train Loss: 2.179. Test Loss: 2.592. Train Acc: 0.3891. Test Acc:0.3125
# Epoch: 170. Train Loss: 2.143. Test Loss: 2.58. Train Acc: 0.3973. Test Acc:0.3125
# Epoch: 180. Train Loss: 1.995. Test Loss: 2.441. Train Acc: 0.4313. Test Acc:0.3462
# Epoch: 190. Train Loss: 1.891. Test Loss: 2.35. Train Acc: 0.4689. Test Acc:0.3741
# Epoch: 200. Train Loss: 1.878. Test Loss: 2.346. Train Acc: 0.4703. Test Acc:0.375
# Epoch: 210. Train Loss: 1.774. Test Loss: 2.274. Train Acc: 0.4919. Test Acc:0.3941
# Epoch: 220. Train Loss: 1.664. Test Loss: 2.183. Train Acc: 0.5241. Test Acc:0.4176
# Epoch: 230. Train Loss: 1.724. Test Loss: 2.245. Train Acc: 0.5039. Test Acc:0.402
# Epoch: 240. Train Loss: 1.568. Test Loss: 2.094. Train Acc: 0.5582. Test Acc:0.4393
# Epoch: 250. Train Loss: 1.704. Test Loss: 2.233. Train Acc: 0.5161. Test Acc:0.4082
# Epoch: 260. Train Loss: 1.459. Test Loss: 2.024. Train Acc: 0.5809. Test Acc:0.4703
# Epoch: 270. Train Loss: 1.585. Test Loss: 2.133. Train Acc: 0.5459. Test Acc:0.4428
# Epoch: 280. Train Loss: 1.472. Test Loss: 2.03. Train Acc: 0.5722. Test Acc:0.4707
# Epoch: 290. Train Loss: 1.448. Test Loss: 2.005. Train Acc: 0.5802. Test Acc:0.4814
# Epoch: 300. Train Loss: 1.299. Test Loss: 1.873. Train Acc: 0.625. Test Acc:0.5199
# Epoch: 310. Train Loss: 1.354. Test Loss: 1.918. Train Acc: 0.6037. Test Acc:0.5124
# Epoch: 320. Train Loss: 1.208. Test Loss: 1.783. Train Acc: 0.6498. Test Acc:0.5386
# Epoch: 330. Train Loss: 1.301. Test Loss: 1.876. Train Acc: 0.6134. Test Acc:0.516
# Epoch: 340. Train Loss: 1.144. Test Loss: 1.728. Train Acc: 0.6638. Test Acc:0.559
# Epoch: 350. Train Loss: 1.205. Test Loss: 1.795. Train Acc: 0.6477. Test Acc:0.543
# Epoch: 360. Train Loss: 1.199. Test Loss: 1.8. Train Acc: 0.6458. Test Acc:0.5426
# Epoch: 370. Train Loss: 1.109. Test Loss: 1.716. Train Acc: 0.6692. Test Acc:0.5585
# Epoch: 380. Train Loss: 1.245. Test Loss: 1.856. Train Acc: 0.6295. Test Acc:0.5337
# Epoch: 390. Train Loss: 1.137. Test Loss: 1.762. Train Acc: 0.6608. Test Acc:0.5576
# Epoch: 400. Train Loss: 1.167. Test Loss: 1.801. Train Acc: 0.65. Test Acc:0.5474
# Epoch: 410. Train Loss: 1.08. Test Loss: 1.715. Train Acc: 0.6758. Test Acc:0.5696
# Epoch: 420. Train Loss: 1.125. Test Loss: 1.755. Train Acc: 0.6627. Test Acc:0.5674
# Epoch: 430. Train Loss: 1.047. Test Loss: 1.661. Train Acc: 0.6877. Test Acc:0.5878
# Epoch: 440. Train Loss: 0.9954. Test Loss: 1.621. Train Acc: 0.7018. Test Acc:0.5971
# Epoch: 450. Train Loss: 1.079. Test Loss: 1.725. Train Acc: 0.6762. Test Acc:0.5776
# Epoch: 460. Train Loss: 0.9514. Test Loss: 1.584. Train Acc: 0.7113. Test Acc:0.6068
# Epoch: 470. Train Loss: 0.9974. Test Loss: 1.65. Train Acc: 0.7003. Test Acc:0.5957
# Epoch: 480. Train Loss: 0.9614. Test Loss: 1.594. Train Acc: 0.7116. Test Acc:0.6064
# Epoch: 490. Train Loss: 0.8435. Test Loss: 1.491. Train Acc: 0.7458. Test Acc:0.6263
# Epoch: 500. Train Loss: 0.9124. Test Loss: 1.559. Train Acc: 0.722. Test Acc:0.6113
# Epoch: 510. Train Loss: 0.95. Test Loss: 1.588. Train Acc: 0.7113. Test Acc:0.6095
# Epoch: 520. Train Loss: 0.9599. Test Loss: 1.617. Train Acc: 0.705. Test Acc:0.6046
# Epoch: 530. Train Loss: 0.8821. Test Loss: 1.524. Train Acc: 0.73. Test Acc:0.6277
# Epoch: 540. Train Loss: 0.8791. Test Loss: 1.531. Train Acc: 0.7286. Test Acc:0.625
# Epoch: 550. Train Loss: 0.8609. Test Loss: 1.517. Train Acc: 0.7405. Test Acc:0.6325
# Epoch: 560. Train Loss: 0.8817. Test Loss: 1.525. Train Acc: 0.731. Test Acc:0.629
# Epoch: 570. Train Loss: 0.7855. Test Loss: 1.437. Train Acc: 0.7618. Test Acc:0.6498
# Epoch: 580. Train Loss: 0.8448. Test Loss: 1.522. Train Acc: 0.7431. Test Acc:0.6348
# Epoch: 590. Train Loss: 0.8181. Test Loss: 1.478. Train Acc: 0.7503. Test Acc:0.6383
# Epoch: 600. Train Loss: 0.8457. Test Loss: 1.506. Train Acc: 0.7396. Test Acc:0.6325
# Epoch: 610. Train Loss: 0.8125. Test Loss: 1.476. Train Acc: 0.7491. Test Acc:0.6374
# Epoch: 620. Train Loss: 0.8333. Test Loss: 1.497. Train Acc: 0.745. Test Acc:0.6343
# Epoch: 630. Train Loss: 0.8022. Test Loss: 1.469. Train Acc: 0.75. Test Acc:0.6458
# Epoch: 640. Train Loss: 0.7399. Test Loss: 1.413. Train Acc: 0.7743. Test Acc:0.6622
# Epoch: 650. Train Loss: 0.7573. Test Loss: 1.426. Train Acc: 0.7655. Test Acc:0.6556
# Epoch: 660. Train Loss: 0.8398. Test Loss: 1.518. Train Acc: 0.7401. Test Acc:0.6356
# Epoch: 670. Train Loss: 0.78. Test Loss: 1.458. Train Acc: 0.7626. Test Acc:0.6489
# Epoch: 680. Train Loss: 0.8219. Test Loss: 1.511. Train Acc: 0.7491. Test Acc:0.6418
# Epoch: 690. Train Loss: 0.7465. Test Loss: 1.419. Train Acc: 0.7696. Test Acc:0.6596
# Epoch: 700. Train Loss: 0.7438. Test Loss: 1.421. Train Acc: 0.7706. Test Acc:0.6609
# Epoch: 710. Train Loss: 0.7614. Test Loss: 1.446. Train Acc: 0.7661. Test Acc:0.6591
# Epoch: 720. Train Loss: 0.7499. Test Loss: 1.442. Train Acc: 0.7699. Test Acc:0.6569
# Epoch: 730. Train Loss: 0.7516. Test Loss: 1.435. Train Acc: 0.7736. Test Acc:0.6587
# Epoch: 740. Train Loss: 0.669. Test Loss: 1.358. Train Acc: 0.7951. Test Acc:0.6809
# Epoch: 750. Train Loss: 0.7483. Test Loss: 1.452. Train Acc: 0.7663. Test Acc:0.6543
# Epoch: 760. Train Loss: 0.7723. Test Loss: 1.456. Train Acc: 0.7606. Test Acc:0.6503
# Epoch: 770. Train Loss: 0.8062. Test Loss: 1.529. Train Acc: 0.7511. Test Acc:0.6401
# Epoch: 780. Train Loss: 0.7465. Test Loss: 1.462. Train Acc: 0.7711. Test Acc:0.6476
# Epoch: 790. Train Loss: 0.7592. Test Loss: 1.483. Train Acc: 0.7668. Test Acc:0.6512
# Epoch: 800. Train Loss: 0.7365. Test Loss: 1.458. Train Acc: 0.7709. Test Acc:0.6489
# Epoch: 810. Train Loss: 0.7741. Test Loss: 1.493. Train Acc: 0.76. Test Acc:0.6379
# Epoch: 820. Train Loss: 0.6585. Test Loss: 1.387. Train Acc: 0.7953. Test Acc:0.6698
# Epoch: 830. Train Loss: 0.6924. Test Loss: 1.428. Train Acc: 0.7849. Test Acc:0.66
# Epoch: 840. Train Loss: 0.7788. Test Loss: 1.503. Train Acc: 0.7588. Test Acc:0.6494
# Epoch: 850. Train Loss: 0.7425. Test Loss: 1.482. Train Acc: 0.7684. Test Acc:0.652
# Epoch: 860. Train Loss: 0.7497. Test Loss: 1.476. Train Acc: 0.7698. Test Acc:0.6525
# Epoch: 870. Train Loss: 0.68. Test Loss: 1.407. Train Acc: 0.7889. Test Acc:0.6667
# Epoch: 880. Train Loss: 0.6646. Test Loss: 1.401. Train Acc: 0.7964. Test Acc:0.6693
# Epoch: 890. Train Loss: 0.768. Test Loss: 1.515. Train Acc: 0.7641. Test Acc:0.6485
# Epoch: 900. Train Loss: 0.6755. Test Loss: 1.429. Train Acc: 0.7911. Test Acc:0.6631
# Epoch: 910. Train Loss: 0.7153. Test Loss: 1.45. Train Acc: 0.7779. Test Acc:0.6543
# Epoch: 920. Train Loss: 0.7725. Test Loss: 1.529. Train Acc: 0.7606. Test Acc:0.6458
# Epoch: 930. Train Loss: 0.7692. Test Loss: 1.521. Train Acc: 0.762. Test Acc:0.6494
