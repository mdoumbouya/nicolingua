# %%
from pathlib import Path
import csv
import itertools
import numpy as np
from pprint import PrettyPrinter


import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

import h5py

import sklearn
import sklearn.metrics

pprint = PrettyPrinter()

# %% [markdown]
# ## Configuration

# %%
SELECTED_LANGUAGES = {'_language_independent', 'francais', 'maninka', 'pular', 'susu'}

BASE_DIR = Path('/media/xtrem/data/experiments/nicolingua-0002-va-asr/datasets/gn_va_asr_dataset_2020-08-24_02')


ANNOTATIONS_PATH = BASE_DIR/ "annotated_segments" / "metadata.csv"


FEATURE_NAMES = [
    "wav2vec_features-c", 
    "wav2vec_features-z", 
    "retrained-wav2vec_features-c", 
    "retrained-wav2vec_features-z"
]

# CONV_POOLING_TYPES = ['avg', 'max']
CONV_POOLING_TYPES = ['max']
OBJECTIVE_TYPES = ['voice_cmd', 'voice_cmd__and__voice_cmd_lng']
CONV_DROPOUT_PROBABILITIES = [0.2]
FC_DROPOUT_PROBABILITIES = [0.2]


TRAIN_PERCENT = .7
FOLD_COUNT = 5


RESULTS_DIR = f'results_101'
EPOCHS = 1000
BATCH_SIZE = 512
MAX_FEATURE_SEQUENCE_LENGTH = 200

GPU_ID = 1
device = torch.device(f"cuda:{GPU_ID}")

# %% [markdown]
# ## Load & shuffle metadata records

# %%
def load_metadata():
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for r in reader:
            if r['language'] in SELECTED_LANGUAGES:
                yield r

# %%
# load
metadata_records = list(load_metadata())

# shuffle
metadata_shuffler_rs = np.random.RandomState(seed=42)
metadata_shuffler_rs.shuffle(metadata_records)

# %%
bias_category_fields = [
     "device_id"
    ,"language"
    ,"speaker_gender"
    ,"speaker_mothertongue"
]

bias_categories = {}
for c in bias_category_fields:
    bias_categories[c] = sorted({r[c] for r in metadata_records})


_ = [print(f"\n{k}: \n\t{','.join(v)}") for k,v in bias_categories.items()]
# Out:
# device_id:
# 	d001,d002,d003
#
# language:
# 	_language_independent,francais,maninka,pular,susu
#
# speaker_gender:
# 	F,M
#
# speaker_mothertongue:
# 	maninka,pular,susu

# %% [markdown]
# ### Labels

# %%
# VOICE COMMANDS
voice_cmd_class_names = sorted({r['label'] for r in metadata_records})
voice_cmd_class_count = len(voice_cmd_class_names)
voice_cmd_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_class_names)}

print("Classes - Voice Commands")
_ = [print(f"{v:4}: {k}") for k,v in voice_cmd_class_id_by_name.items()]

print("---------------------")


# VOICE COMMAND LANGUAGES
voice_cmd_lng_class_names = sorted({r['language'] for r in metadata_records})
voice_cmd_lng_class_count = len(voice_cmd_lng_class_names)
voice_cmd_lng_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_lng_class_names)}

print("Classes - Voice Command Languages")
_ = [print(f"{v:3}: {k}") for k,v in voice_cmd_lng_class_id_by_name.items()]

print("---------------------")



# SPEAKER MOTHERTONGUE
spkr_mothertongue_class_names = sorted({r['speaker_mothertongue'] for r in metadata_records})
spkr_mothertongue_class_count = len(spkr_mothertongue_class_names)
spkr_mothertongue_class_id_by_name = {c:i for i,c in enumerate(spkr_mothertongue_class_names)}

print("Classes - Speaker Mothertongues")
_ = [print(f"{v:3}: {k}") for k,v in spkr_mothertongue_class_id_by_name.items()]

print("---------------------")



# SPEAKER GENDER
spkr_gender_class_names = sorted({r['speaker_gender'] for r in metadata_records})
spkr_gender_class_count = len(spkr_gender_class_names)
spkr_gender_class_id_by_name = {c:i for i, c in enumerate(spkr_gender_class_names)}

print("Classes - Speaker Gender")
_ = [print(f"{v:3}: {k}") for k,v in spkr_gender_class_id_by_name.items()]

print("----------------------")
# Out:
# Classes - Voice Commands
#    0: 101_wake_word__francais
#    1: 101_wake_word__maninka
#    2: 101_wake_word__pular
#    3: 101_wake_word__susu
#    4: 201_add_contact__francais
#    5: 201_add_contact__maninka
#    6: 201_add_contact__pular
#    7: 201_add_contact__susu
#    8: 202_search_contact__francais
#    9: 202_search_contact__maninka
#   10: 202_search_contact__pular
#   11: 202_search_contact__susu
#   12: 203_update_contact__francais
#   13: 203_update_contact__maninka
#   14: 203_update_contact__pular
#   15: 203_update_contact__susu
#   16: 204_delete_contact__francais
#   17: 204_delete_contact__maninka
#   18: 204_delete_contact__pular
#   19: 204_delete_contact__susu
#   20: 205_call_contact__francais
#   21: 205_call_contact__maninka
#   22: 205_call_contact__pular
#   23: 205_call_contact__susu
#   24: 206_yes__francais
#   25: 206_yes__maninka
#   26: 206_yes__pular
#   27: 206_yes__susu
#   28: 207_no__francais
#   29: 207_no__maninka
#   30: 207_no__pular
#   31: 207_no__susu
#   32: 301_zero__francais
#   33: 301_zero__maninka
#   34: 301_zero__pular
#   35: 301_zero__susu
#   36: 302_one__francais
#   37: 302_one__maninka
#   38: 302_one__pular
#   39: 302_one__susu
#   40: 303_two__francais
#   41: 303_two__maninka
#   42: 303_two__pular
#   43: 303_two__susu
#   44: 304_three__francais
#   45: 304_three__maninka
#   46: 304_three__pular
#   47: 304_three__susu
#   48: 305_four__francais
#   49: 305_four__maninka
#   50: 305_four__pular
#   51: 305_four__susu
#   52: 306_five__francais
#   53: 306_five__maninka
#   54: 306_five__pular
#   55: 306_five__susu
#   56: 307_six__francais
#   57: 307_six__maninka
#   58: 307_six__pular
#   59: 307_six__susu
#   60: 308_seven__francais
#   61: 308_seven__maninka
#   62: 308_seven__pular
#   63: 308_seven__susu
#   64: 309_eight__francais
#   65: 309_eight__maninka
#   66: 309_eight__pular
#   67: 309_eight__susu
#   68: 310_nine__francais
#   69: 310_nine__maninka
#   70: 310_nine__pular
#   71: 310_nine__susu
#   72: 401_mom__francais
#   73: 401_mom__maninka
#   74: 401_mom__pular
#   75: 401_mom__susu
#   76: 402_dad__francais
#   77: 402_dad__maninka
#   78: 402_dad__pular
#   79: 402_dad__susu
#   80: 501_fatoumata___language_independent
#   81: 502_mamadou___language_independent
#   82: 503_mariama___language_independent
#   83: 504_mohamed___language_independent
#   84: 505_kadiatou___language_independent
#   85: 506_ibrahima___language_independent
#   86: 507_aissatou___language_independent
#   87: 508_aminata___language_independent
#   88: 509_alpha___language_independent
#   89: 510_thierno___language_independent
#   90: 511_abdoulaye___language_independent
#   91: 512_aboubacar___language_independent
#   92: 513_amadou___language_independent
#   93: 514_fanta___language_independent
#   94: 515_mariame___language_independent
#   95: 516_oumou___language_independent
#   96: 517_ousmane___language_independent
#   97: 518_adama___language_independent
#   98: 519_marie___language_independent
#   99: 520_moussa___language_independent
#  100: 521_aissata___language_independent
#  101: 522_hawa___language_independent
#  102: 523_sekou___language_independent
#  103: 524_hadja___language_independent
#  104: 525_djenabou___language_independent
# ---------------------
# Classes - Voice Command Languages
#   0: _language_independent
#   1: francais
#   2: maninka
#   3: pular
#   4: susu
# ---------------------
# Classes - Speaker Mothertongues
#   0: maninka
#   1: pular
#   2: susu
# ---------------------
# Classes - Speaker Gender
#   0: F
#   1: M
# ----------------------

# %% [markdown]
# ### Inspect metadata

# %%
def count_by_attribute(records, attribute_names):
    attribute_name_instances = {}
    for attribute_name in attribute_names:
        attribute_name_instances[attribute_name] = {r[attribute_name] for r in records}
        
    l = [attribute_name_instances[attribute_name] for attribute_name in attribute_names]
    
    
    
    for attribute_values in sorted(itertools.product(*l)):
        
        def record_match(r):
            for i in range(len(attribute_names)):
                if r[attribute_names[i]] != attribute_values[i]:
                    return False
            return True
            
        record_instances = [r for r in records if record_match(r)]
        count = len(record_instances)
        
        yield (attribute_values, count)

# %%
print("RECORDS BY DEVICE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['device_id']))]
print("")

print("RECORDS BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['language']))]
print("")

print("RECORDS BY GENDER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_gender']))]
print("")

print("RECORDS BY AGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_age']))]
print("")

print("RECORDS BY SPEAKER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id']))]
print("")

print("RECORDS BY SPEAKER BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id', 'language']))]
print("")

print("RECORDS BY SPEAKER BY LABEL")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['label']))]
print("")
# Out:
# RECORDS BY DEVICE
# 	(('d001',), 2759)
# 	(('d002',), 2741)
# 	(('d003',), 2759)
#
# RECORDS BY LANGUAGE
# 	(('_language_independent',), 3072)
# 	(('francais',), 1260)
# 	(('maninka',), 1356)
# 	(('pular',), 909)
# 	(('susu',), 1662)
#
# RECORDS BY GENDER
# 	(('F',), 2820)
# 	(('M',), 5439)
#
# RECORDS BY AGE
# 	(('12',), 237)
# 	(('13',), 252)
# 	(('15',), 603)
# 	(('17',), 1050)
# 	(('18',), 855)
# 	(('19',), 273)
# 	(('20',), 291)
# 	(('27',), 255)
# 	(('28',), 183)
# 	(('29',), 237)
# 	(('31',), 255)
# 	(('32',), 291)
# 	(('33',), 183)
# 	(('34',), 129)
# 	(('35',), 498)
# 	(('37',), 309)
# 	(('38',), 441)
# 	(('43',), 183)
# 	(('44',), 540)
# 	(('5',), 129)
# 	(('55',), 183)
# 	(('61',), 390)
# 	(('63',), 237)
# 	(('67',), 255)
#
# RECORDS BY SPEAKER
# 	(('s001',), 183)
# 	(('s002',), 129)
# 	(('s003',), 183)
# 	(('s004',), 183)
# 	(('s005',), 129)
# 	(('s006',), 129)
# 	(('s007',), 183)
# 	(('s008',), 129)
# 	(('s009',), 237)
# 	(('s010',), 291)
# 	(('s011',), 129)
# 	(('s012',), 183)
# 	(('s013',), 129)
# 	(('s014',), 237)
# 	(('s015',), 291)
# 	(('s016',), 183)
# 	(('s017',), 237)
# 	(('s018',), 237)
# 	(('s019',), 237)
# 	(('s020',), 291)
# 	(('s021',), 273)
# 	(('s022',), 183)
# 	(('s023',), 309)
# 	(('s024',), 255)
# 	(('s025',), 315)
# 	(('s026',), 252)
# 	(('s027',), 540)
# 	(('s028',), 540)
# 	(('s029',), 390)
# 	(('s030',), 195)
# 	(('s031',), 252)
# 	(('s032',), 315)
# 	(('s033',), 255)
# 	(('s034',), 255)
#
# RECORDS BY SPEAKER BY LANGUAGE
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'francais'), 0)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'pular'), 0)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'francais'), 0)
# 	(('s002', 'maninka'), 54)
# 	(('s002', 'pular'), 0)
# 	(('s002', 'susu'), 0)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'francais'), 0)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'pular'), 0)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'francais'), 0)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'pular'), 0)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'francais'), 0)
# 	(('s005', 'maninka'), 0)
# 	(('s005', 'pular'), 0)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'francais'), 0)
# 	(('s006', 'maninka'), 54)
# 	(('s006', 'pular'), 0)
# 	(('s006', 'susu'), 0)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'francais'), 0)
# 	(('s007', 'maninka'), 0)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'francais'), 0)
# 	(('s008', 'maninka'), 54)
# 	(('s008', 'pular'), 0)
# 	(('s008', 'susu'), 0)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'maninka'), 0)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'francais'), 0)
# 	(('s011', 'maninka'), 0)
# 	(('s011', 'pular'), 0)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'maninka'), 0)
# 	(('s012', 'pular'), 0)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'francais'), 0)
# 	(('s013', 'maninka'), 0)
# 	(('s013', 'pular'), 0)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'pular'), 0)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'francais'), 0)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'pular'), 0)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'maninka'), 0)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'maninka'), 0)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'pular'), 0)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'francais'), 0)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'pular'), 0)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'pular'), 0)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'pular'), 0)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'maninka'), 0)
# 	(('s030', 'pular'), 60)
# 	(('s030', 'susu'), 0)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'maninka'), 0)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'pular'), 0)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'pular'), 0)
# 	(('s034', 'susu'), 60)
#
# RECORDS BY SPEAKER BY LABEL
# 	(('101_wake_word__francais',), 66)
# 	(('101_wake_word__maninka',), 72)
# 	(('101_wake_word__pular',), 48)
# 	(('101_wake_word__susu',), 89)
# 	(('201_add_contact__francais',), 66)
# 	(('201_add_contact__maninka',), 72)
# 	(('201_add_contact__pular',), 48)
# 	(('201_add_contact__susu',), 89)
# 	(('202_search_contact__francais',), 66)
# 	(('202_search_contact__maninka',), 72)
# 	(('202_search_contact__pular',), 48)
# 	(('202_search_contact__susu',), 89)
# 	(('203_update_contact__francais',), 66)
# 	(('203_update_contact__maninka',), 72)
# 	(('203_update_contact__pular',), 48)
# 	(('203_update_contact__susu',), 89)
# 	(('204_delete_contact__francais',), 66)
# 	(('204_delete_contact__maninka',), 72)
# 	(('204_delete_contact__pular',), 48)
# 	(('204_delete_contact__susu',), 89)
# 	(('205_call_contact__francais',), 66)
# 	(('205_call_contact__maninka',), 72)
# 	(('205_call_contact__pular',), 45)
# 	(('205_call_contact__susu',), 89)
# 	(('206_yes__francais',), 66)
# 	(('206_yes__maninka',), 72)
# 	(('206_yes__pular',), 48)
# 	(('206_yes__susu',), 89)
# 	(('207_no__francais',), 66)
# 	(('207_no__maninka',), 72)
# 	(('207_no__pular',), 48)
# 	(('207_no__susu',), 89)
# 	(('301_zero__francais',), 66)
# 	(('301_zero__maninka',), 72)
# 	(('301_zero__pular',), 48)
# 	(('301_zero__susu',), 89)
# 	(('302_one__francais',), 66)
# 	(('302_one__maninka',), 72)
# 	(('302_one__pular',), 48)
# 	(('302_one__susu',), 89)
# 	(('303_two__francais',), 66)
# 	(('303_two__maninka',), 72)
# 	(('303_two__pular',), 48)
# 	(('303_two__susu',), 89)
# 	(('304_three__francais',), 66)
# 	(('304_three__maninka',), 72)
# 	(('304_three__pular',), 48)
# 	(('304_three__susu',), 89)
# 	(('305_four__francais',), 66)
# 	(('305_four__maninka',), 72)
# 	(('305_four__pular',), 48)
# 	(('305_four__susu',), 89)
# 	(('306_five__francais',), 66)
# 	(('306_five__maninka',), 72)
# 	(('306_five__pular',), 48)
# 	(('306_five__susu',), 89)
# 	(('307_six__francais',), 66)
# 	(('307_six__maninka',), 72)
# 	(('307_six__pular',), 48)
# 	(('307_six__susu',), 89)
# 	(('308_seven__francais',), 66)
# 	(('308_seven__maninka',), 72)
# 	(('308_seven__pular',), 48)
# 	(('308_seven__susu',), 89)
# 	(('309_eight__francais',), 66)
# 	(('309_eight__maninka',), 72)
# 	(('309_eight__pular',), 48)
# 	(('309_eight__susu',), 89)
# 	(('310_nine__francais',), 66)
# 	(('310_nine__maninka',), 72)
# 	(('310_nine__pular',), 48)
# 	(('310_nine__susu',), 89)
# 	(('401_mom__francais',), 36)
# 	(('401_mom__maninka',), 30)
# 	(('401_mom__pular',), 24)
# 	(('401_mom__susu',), 30)
# 	(('402_dad__francais',), 36)
# 	(('402_dad__maninka',), 30)
# 	(('402_dad__pular',), 24)
# 	(('402_dad__susu',), 30)
# 	(('501_fatoumata___language_independent',), 123)
# 	(('502_mamadou___language_independent',), 123)
# 	(('503_mariama___language_independent',), 123)
# 	(('504_mohamed___language_independent',), 123)
# 	(('505_kadiatou___language_independent',), 123)
# 	(('506_ibrahima___language_independent',), 123)
# 	(('507_aissatou___language_independent',), 123)
# 	(('508_aminata___language_independent',), 123)
# 	(('509_alpha___language_independent',), 123)
# 	(('510_thierno___language_independent',), 120)
# 	(('511_abdoulaye___language_independent',), 123)
# 	(('512_aboubacar___language_independent',), 123)
# 	(('513_amadou___language_independent',), 123)
# 	(('514_fanta___language_independent',), 123)
# 	(('515_mariame___language_independent',), 123)
# 	(('516_oumou___language_independent',), 123)
# 	(('517_ousmane___language_independent',), 123)
# 	(('518_adama___language_independent',), 123)
# 	(('519_marie___language_independent',), 123)
# 	(('520_moussa___language_independent',), 123)
# 	(('521_aissata___language_independent',), 123)
# 	(('522_hawa___language_independent',), 123)
# 	(('523_sekou___language_independent',), 123)
# 	(('524_hadja___language_independent',), 123)
# 	(('525_djenabou___language_independent',), 123)

# %% [markdown]
# ## Prepare Cross Validation Folds
# - Partition by (speaker, language)
# - Each (speaker, language) correspond to `utterance_count * device_count`
# - For each fold, all `utterance_count * device_count` records for the same speaker in the same language are either in the TRAIN or the VALIDATION sets, but not both.

# %%
def generate_train_test_records_per_fold(all_records):
    records_per_fold = {}
    
    all_speaker_languages = sorted({(r['speaker_id'], r['language']) for r in all_records})

    sl_count = len(all_speaker_languages)
    all_sl_indices = range(sl_count)
    train_sl_count = int(np.ceil(sl_count*TRAIN_PERCENT))
    test_sl_count = sl_count - train_sl_count

    for fold_index in range(FOLD_COUNT):
        fold_rsampler = np.random.RandomState(seed=fold_index)

        train_sl_index_set = set(fold_rsampler.choice(all_sl_indices, train_sl_count, replace=False))
        train_sl_set = {all_speaker_languages[i] for i in train_sl_index_set}

        test_sl_index_set = set(all_sl_indices).difference(train_sl_index_set)
        test_sl_set = {all_speaker_languages[i] for i in test_sl_index_set}

        train_records = [r for r in all_records if (r['speaker_id'], r['language']) in train_sl_set]
        test_records = [r for r in all_records if (r['speaker_id'], r['language']) in test_sl_set]
        
        
        records_per_fold[fold_index] = {
            "train_records": train_records,
            "test_records": test_records
        }
    
    return records_per_fold

# %%
records_per_fold = generate_train_test_records_per_fold(metadata_records)

# %% [markdown]
# ### Inspect Folds

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['speaker_id', 'language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['speaker_id', 'language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', '_language_independent'), 75)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 0 -- TEST
# 	(('s004', 'maninka'), 54)
# 	(('s005', 'susu'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'susu'), 54)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 1 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'susu'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 1 -- TEST
# 	(('s001', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s030', 'francais'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s033', 'susu'), 60)
# ---------------------
# Fold 2 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', 'francais'), 54)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 2 -- TEST
# 	(('s002', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s033', '_language_independent'), 75)
# ---------------------
# Fold 3 -- TRAIN
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', 'susu'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 3 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s006', 'maninka'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s029', 'francais'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 4 -- TRAIN
# 	(('s001', 'susu'), 54)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'susu'), 54)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'susu'), 60)
# Fold 4 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN: ({len(train_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST: ({len(test_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN: (6018)
# 	(('_language_independent',), 2400)
# 	(('francais',), 738)
# 	(('maninka',), 960)
# 	(('pular',), 852)
# 	(('susu',), 1068)
# Fold 0 -- TEST: (2241)
# 	(('_language_independent',), 672)
# 	(('francais',), 522)
# 	(('maninka',), 396)
# 	(('pular',), 57)
# 	(('susu',), 594)
# ---------------------
# Fold 1 -- TRAIN: (5940)
# 	(('_language_independent',), 2325)
# 	(('francais',), 978)
# 	(('maninka',), 906)
# 	(('pular',), 519)
# 	(('susu',), 1212)
# Fold 1 -- TEST: (2319)
# 	(('_language_independent',), 747)
# 	(('francais',), 282)
# 	(('maninka',), 450)
# 	(('pular',), 390)
# 	(('susu',), 450)
# ---------------------
# Fold 2 -- TRAIN: (6036)
# 	(('_language_independent',), 2397)
# 	(('francais',), 972)
# 	(('maninka',), 912)
# 	(('pular',), 573)
# 	(('susu',), 1182)
# Fold 2 -- TEST: (2223)
# 	(('_language_independent',), 675)
# 	(('francais',), 288)
# 	(('maninka',), 444)
# 	(('pular',), 336)
# 	(('susu',), 480)
# ---------------------
# Fold 3 -- TRAIN: (5796)
# 	(('_language_independent',), 2097)
# 	(('francais',), 918)
# 	(('maninka',), 912)
# 	(('pular',), 801)
# 	(('susu',), 1068)
# Fold 3 -- TEST: (2463)
# 	(('_language_independent',), 975)
# 	(('francais',), 342)
# 	(('maninka',), 444)
# 	(('pular',), 108)
# 	(('susu',), 594)
# ---------------------
# Fold 4 -- TRAIN: (6003)
# 	(('_language_independent',), 2325)
# 	(('francais',), 924)
# 	(('maninka',), 906)
# 	(('pular',), 558)
# 	(('susu',), 1290)
# Fold 4 -- TEST: (2256)
# 	(('_language_independent',), 747)
# 	(('francais',), 336)
# 	(('maninka',), 450)
# 	(('pular',), 351)
# 	(('susu',), 372)
# ---------------------

# %% [markdown]
# ## Load Features

# %%
def load_features(records, feature_name):
    features_list = []
    
    features_input_dir = BASE_DIR / feature_name

    for r in records:
        feature_file_name = r['file'].replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            
            padded_features = np.zeros((MAX_FEATURE_SEQUENCE_LENGTH, 512), dtype=features.dtype)
            padded_features[:features_shape[0], :] = features
            
            
            features_list.append(padded_features)
    return features_list

# %%
def get_bias_category_labels(records):
    bias_category_labels = {}
    
    for cat in bias_categories:
        for cat_val in bias_categories[cat]:
            bias_category_labels[f"{cat}__{cat_val}"] = [1 if r[cat]==cat_val else 0 for r in records]
            
    return bias_category_labels

# %% [markdown]
# # Classification Models

# %%
class ASRCNN(nn.Module):
    def __init__(self, 
                 conv_pooling_type, 
                 conv_dropout_p, 
                 fc_dropout_p, 
                 voice_cmd_neuron_count, 
                 voice_cmd_lng_neuron_count,
                 objective_type
                ):
        
        super(ASRCNN, self).__init__()
        
        if conv_pooling_type not in {"max", "avg"}:
            raise ValueError(f"Unknown Conv Pooling Type: {conv_pooling_type}")
            
        conv_pooling_class_by_type = {
            "max": nn.MaxPool1d,
            "avg": nn.AvgPool1d,
        }
        
        conv_pooling_class = conv_pooling_class_by_type[conv_pooling_type]
        
        self.objective_type = objective_type
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=8, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=3)
        self.drop1 = nn.Dropout(p=conv_dropout_p)
        self.pool1 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=8, out_channels=16, kernel_size=3)
        self.drop2 = nn.Dropout(p=conv_dropout_p)
        self.pool2 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3)
        self.drop3 = nn.Dropout(p=conv_dropout_p)
        self.pool3 = conv_pooling_class(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3)
        self.drop4 = nn.Dropout(p=conv_dropout_p)
        self.pool4 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)
        
        self.lin61 = nn.Linear(in_features=112, out_features=voice_cmd_neuron_count)
        
        # 'voice_cmd', 'voice_cmd__and__voice_cmd_lng'
        if self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            self.lin62 = nn.Linear(in_features=112, out_features=voice_cmd_lng_neuron_count)
                
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        if self.objective_type == 'voice_cmd':
            logits_voice_cmd = self.lin61(v)
            return logits_voice_cmd
        elif self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd = self.lin61(v)
            logits_voice_cmd_lng = self.lin62(v)
            return logits_voice_cmd, logits_voice_cmd_lng
        else:
            raise(f"Unknown objective type: {self.objective_type}")

# %%
def get_data_for_fold(fold_id, feature_name):
    
    train_records = records_per_fold[fold_id]["train_records"]
    test_records = records_per_fold[fold_id]["test_records"]
    
    train_features = load_features(train_records, feature_name)
    test_features = load_features(test_records, feature_name)
    
    train_x = np.array(train_features)
    test_x = np.array(test_features)
    
    train_y = {}
    train_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in train_records])
    train_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in train_records])
    train_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in train_records])
    train_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in train_records])
    
    

    
    test_y = {}
    test_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in test_records])
    test_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in test_records])
    test_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in test_records])
    test_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in test_records])

    train_bias_category_labels = get_bias_category_labels(train_records)
    test_bias_category_labels = get_bias_category_labels(test_records)
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y['voice_cmd']),
        torch.tensor(train_y['voice_cmd_lng']),
        # torch.tensor(train_y['spkr_mothertongue']),
        # torch.tensor(train_y['spkr_gender']),
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y['voice_cmd']),
        torch.tensor(test_y['voice_cmd_lng']),
        # torch.tensor(test_y['spkr_mothertongue']),
        # torch.tensor(test_y['spkr_gender']),
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
def train(model, optimizer, criterion, objective_type, train_loader):
    model.train()
    train_loss = 0

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(train_loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        optimizer.zero_grad()
        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs
            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs    
            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) / 2
            
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        

def test(model, criterion, objective_type, loader, bias_category_labels):
    model.eval()
    accumulated_loss = 0

    pred_classes = []
    true_classes = []

    pred_classes_lng = []
    true_classes_lng = []

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs

            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs
            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            pred_classes_lng.extend(
                get_predictions_for_logits(logits_voice_cmd_lng).cpu().numpy()
            )
            true_classes_lng.extend(y_voice_cmd_lng.cpu().numpy())

            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) /2
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        accumulated_loss += loss.item()

    n = len(true_classes)

    average_loss = accumulated_loss/n
    
    acc = sklearn.metrics.accuracy_score(true_classes, pred_classes)
    acc_by_bais_category = {
        category: sklearn.metrics.accuracy_score(true_classes, pred_classes, sample_weight=sw)
        for category, sw in bias_category_labels.items()
    }
    
    
    if objective_type == 'voice_cmd__and__voice_cmd_lng':
        acc_lng = sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng)
        acc_by_bais_category_lng = {
            category: sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng, sample_weight=sw)
            for category, sw in bias_category_labels.items()
        }
    else:
        acc_lng = -1
        acc_by_bais_category_lng = {
            category: -1
            for category, sw in bias_category_labels.items()
        }
        
    return n, average_loss, acc, acc_by_bais_category, acc_lng, acc_by_bais_category_lng
      
        
def train_on_fold(model, fold_id, feature_name, objective_type, batch_size, epochs):
    torch.manual_seed(0)
    results = {}
    
    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model, torch.zeros((10, MAX_FEATURE_SEQUENCE_LENGTH, 512)).to(device), show_input=False))
    print(f"train_n: {len(train_loader.dataset)}")
    print(f"test_n: {len(test_loader.dataset)}")

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(reduction='sum')

    for epoch in range(1, epochs+1):
        
        # train on training set
        train(model, optimizer, criterion, objective_type, train_loader)
        
        # test on training set
        train_n, train_average_loss, train_acc, train_acc_by_bais_category, train_acc_lng, train_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, train_loader, train_bias_category_labels)
        
        # test on test set
        test_n, test_average_loss, test_acc, test_acc_by_bais_category, test_acc_lng, test_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, test_loader, test_bias_category_labels)
        

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_average_loss:0.4}. Test Loss: {test_average_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
         
        results[epoch] = {
            'epoch': epoch,
            
            'train_n': train_n,
            'train_loss': train_average_loss,
            'train_acc': train_acc,
            'train_acc_lng': train_acc_lng,
            
            'test_n': test_n,
            'test_loss': test_average_loss,
            'test_acc': test_acc,
            'test_acc_lng': test_acc_lng
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in train_acc_by_bais_category_lng:
            results[epoch][f"train_acc_lng_{c}"] = train_acc_by_bais_category_lng[c]
            
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))

        for c in test_acc_by_bais_category_lng:
            results[epoch][f"test_acc_lng_{c}"] = test_acc_by_bais_category_lng[c]
            

    return results

# %%
import csv
from pathlib import Path

def results_exist(model_name, feature_name, fold_id):
    fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_id}.csv"
    return Path(fname).is_file()
    

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='raise')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
trial_params = list(
    itertools.product(
        range(FOLD_COUNT),
        CONV_POOLING_TYPES,
        CONV_DROPOUT_PROBABILITIES,
        FC_DROPOUT_PROBABILITIES,
        FEATURE_NAMES, 
        OBJECTIVE_TYPES
    )
)    

print("Plan:")
_ = [print(t) for t in trial_params]
print()

for fold_id, conv_pooling_type, conv_dropout_p, fc_dropout_p, feature_name, objective_type in trial_params:

    model_name = f"ASRCNN" + \
    f"__conv_pool_{conv_pooling_type}" + \
    f"__conv_dp_{conv_dropout_p}" + \
    f"__fc_dp_{fc_dropout_p}" + \
    f"__fn_{feature_name}" + \
    f"__obj_{objective_type}"

    if results_exist(model_name, feature_name, fold_id):
        print(f"skipping ({fold_id}, {conv_pooling_type}, {conv_dropout_p}, {fc_dropout_p}, {feature_name}, {objective_type})")
        continue

        
    model = ASRCNN(
        conv_pooling_type, 
        conv_dropout_p, 
        fc_dropout_p, 
        voice_cmd_neuron_count = voice_cmd_class_count, 
        voice_cmd_lng_neuron_count = voice_cmd_lng_class_count,
        objective_type = objective_type
    ).to(device)

    print(f"{model_name} using {feature_name} on fold#{fold_id}")

    epochs_results = train_on_fold(
        model, 
        fold_id, 
        feature_name, 
        objective_type, 
        batch_size = BATCH_SIZE, 
        epochs = EPOCHS
    )

    # results for only one fold
    folds_results = [{
        'fold_index': fold_id,
        'feature_name': feature_name,
        'epochs': epochs_results
    }]
    
    
    save_results(model_name, folds_results)
    # write_epoch_test_logits(model_name, all_folds_results)

    del model
# Out:
# Plan:
# (0, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (0, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (0, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (0, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (0, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (1, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (1, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (1, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (1, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (2, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (2, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (2, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (2, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (3, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (3, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (3, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (3, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (4, 'max', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (4, 'max', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (4, 'max', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (4, 'max', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
#
# ASRCNN__conv_pool_max__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-c__obj_voice_cmd using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.814. Test Loss: 3.979. Train Acc: 0.08907. Test Acc:0.06292
# Epoch: 20. Train Loss: 2.994. Test Loss: 3.181. Train Acc: 0.2406. Test Acc:0.2004
# Epoch: 30. Train Loss: 2.569. Test Loss: 2.795. Train Acc: 0.3435. Test Acc:0.2842
# Epoch: 40. Train Loss: 2.276. Test Loss: 2.531. Train Acc: 0.4237. Test Acc:0.3521
# Epoch: 50. Train Loss: 1.989. Test Loss: 2.293. Train Acc: 0.4904. Test Acc:0.4047
# Epoch: 60. Train Loss: 1.684. Test Loss: 2.033. Train Acc: 0.566. Test Acc:0.4632
# Epoch: 70. Train Loss: 1.458. Test Loss: 1.849. Train Acc: 0.6208. Test Acc:0.5065
# Epoch: 80. Train Loss: 1.257. Test Loss: 1.677. Train Acc: 0.6773. Test Acc:0.5587
# Epoch: 90. Train Loss: 1.107. Test Loss: 1.549. Train Acc: 0.723. Test Acc:0.5935
# Epoch: 100. Train Loss: 0.9902. Test Loss: 1.456. Train Acc: 0.7529. Test Acc:0.6234
# Epoch: 110. Train Loss: 0.916. Test Loss: 1.387. Train Acc: 0.7712. Test Acc:0.6363
# Epoch: 120. Train Loss: 0.8367. Test Loss: 1.324. Train Acc: 0.791. Test Acc:0.6475
# Epoch: 130. Train Loss: 0.7929. Test Loss: 1.298. Train Acc: 0.8019. Test Acc:0.6533
# Epoch: 140. Train Loss: 0.7105. Test Loss: 1.237. Train Acc: 0.8234. Test Acc:0.6649
# Epoch: 150. Train Loss: 0.7092. Test Loss: 1.253. Train Acc: 0.821. Test Acc:0.6609
# Epoch: 160. Train Loss: 0.6486. Test Loss: 1.2. Train Acc: 0.8377. Test Acc:0.6796
# Epoch: 170. Train Loss: 0.6325. Test Loss: 1.194. Train Acc: 0.8393. Test Acc:0.6818
# Epoch: 180. Train Loss: 0.6107. Test Loss: 1.19. Train Acc: 0.8357. Test Acc:0.6783
# Epoch: 190. Train Loss: 0.5868. Test Loss: 1.176. Train Acc: 0.843. Test Acc:0.6814
# Epoch: 200. Train Loss: 0.5921. Test Loss: 1.205. Train Acc: 0.838. Test Acc:0.6693
# Epoch: 210. Train Loss: 0.5262. Test Loss: 1.135. Train Acc: 0.8591. Test Acc:0.6832
# Epoch: 220. Train Loss: 0.5063. Test Loss: 1.131. Train Acc: 0.8692. Test Acc:0.6966
# Epoch: 230. Train Loss: 0.473. Test Loss: 1.103. Train Acc: 0.8785. Test Acc:0.7019
# Epoch: 240. Train Loss: 0.4883. Test Loss: 1.132. Train Acc: 0.8677. Test Acc:0.6952
# Epoch: 250. Train Loss: 0.5178. Test Loss: 1.165. Train Acc: 0.8559. Test Acc:0.6881
# Epoch: 260. Train Loss: 0.4718. Test Loss: 1.133. Train Acc: 0.8691. Test Acc:0.6912
# Epoch: 270. Train Loss: 0.4279. Test Loss: 1.09. Train Acc: 0.8822. Test Acc:0.7024
# Epoch: 280. Train Loss: 0.4315. Test Loss: 1.111. Train Acc: 0.8787. Test Acc:0.6992
# Epoch: 290. Train Loss: 0.4356. Test Loss: 1.112. Train Acc: 0.8742. Test Acc:0.6975
# Epoch: 300. Train Loss: 0.3973. Test Loss: 1.08. Train Acc: 0.8888. Test Acc:0.7082
# Epoch: 310. Train Loss: 0.3873. Test Loss: 1.066. Train Acc: 0.895. Test Acc:0.7082
# Epoch: 320. Train Loss: 0.3144. Test Loss: 0.9951. Train Acc: 0.9186. Test Acc:0.7327
# Epoch: 330. Train Loss: 0.3095. Test Loss: 0.9877. Train Acc: 0.9177. Test Acc:0.7318
# Epoch: 340. Train Loss: 0.3025. Test Loss: 0.9985. Train Acc: 0.9201. Test Acc:0.7309
# Epoch: 350. Train Loss: 0.3052. Test Loss: 1.007. Train Acc: 0.9161. Test Acc:0.7296
# Epoch: 360. Train Loss: 0.3014. Test Loss: 1.008. Train Acc: 0.9166. Test Acc:0.7238
# Epoch: 370. Train Loss: 0.29. Test Loss: 1.002. Train Acc: 0.9181. Test Acc:0.7274
# Epoch: 380. Train Loss: 0.2948. Test Loss: 1.026. Train Acc: 0.9199. Test Acc:0.7224
# Epoch: 390. Train Loss: 0.3089. Test Loss: 1.053. Train Acc: 0.9104. Test Acc:0.7149
# Epoch: 400. Train Loss: 0.2539. Test Loss: 0.9837. Train Acc: 0.9315. Test Acc:0.7398
# Epoch: 410. Train Loss: 0.2676. Test Loss: 1.012. Train Acc: 0.9222. Test Acc:0.7291
# Epoch: 420. Train Loss: 0.2653. Test Loss: 1.027. Train Acc: 0.9237. Test Acc:0.726
# Epoch: 430. Train Loss: 0.2429. Test Loss: 0.9888. Train Acc: 0.9355. Test Acc:0.7394
# Epoch: 440. Train Loss: 0.2651. Test Loss: 1.033. Train Acc: 0.9242. Test Acc:0.7247
# Epoch: 450. Train Loss: 0.2535. Test Loss: 1.034. Train Acc: 0.9277. Test Acc:0.7349
# Epoch: 460. Train Loss: 0.2512. Test Loss: 1.021. Train Acc: 0.9287. Test Acc:0.7327
# Epoch: 470. Train Loss: 0.2695. Test Loss: 1.066. Train Acc: 0.9171. Test Acc:0.7247
# Epoch: 480. Train Loss: 0.2286. Test Loss: 1.026. Train Acc: 0.9332. Test Acc:0.7367
# Epoch: 490. Train Loss: 0.2442. Test Loss: 1.036. Train Acc: 0.9256. Test Acc:0.7372
# Epoch: 500. Train Loss: 0.2243. Test Loss: 1.015. Train Acc: 0.935. Test Acc:0.7448
# Epoch: 510. Train Loss: 0.2236. Test Loss: 1.044. Train Acc: 0.9357. Test Acc:0.7363
# Epoch: 520. Train Loss: 0.2229. Test Loss: 1.048. Train Acc: 0.9314. Test Acc:0.7278
# Epoch: 530. Train Loss: 0.2531. Test Loss: 1.091. Train Acc: 0.9216. Test Acc:0.7282
# Epoch: 540. Train Loss: 0.2529. Test Loss: 1.094. Train Acc: 0.9189. Test Acc:0.7251
# Epoch: 550. Train Loss: 0.2577. Test Loss: 1.131. Train Acc: 0.9186. Test Acc:0.7224
# Epoch: 560. Train Loss: 0.2035. Test Loss: 1.05. Train Acc: 0.9379. Test Acc:0.7394
# Epoch: 570. Train Loss: 0.2271. Test Loss: 1.11. Train Acc: 0.9297. Test Acc:0.7256
# Epoch: 580. Train Loss: 0.2299. Test Loss: 1.085. Train Acc: 0.9254. Test Acc:0.7332
# Epoch: 590. Train Loss: 0.2498. Test Loss: 1.119. Train Acc: 0.9197. Test Acc:0.7265
# Epoch: 600. Train Loss: 0.1815. Test Loss: 1.004. Train Acc: 0.9458. Test Acc:0.7501
# Epoch: 610. Train Loss: 0.2171. Test Loss: 1.079. Train Acc: 0.9337. Test Acc:0.7376
# Epoch: 620. Train Loss: 0.2072. Test Loss: 1.084. Train Acc: 0.935. Test Acc:0.7318
# Epoch: 630. Train Loss: 0.179. Test Loss: 1.038. Train Acc: 0.9463. Test Acc:0.7492
# Epoch: 640. Train Loss: 0.1782. Test Loss: 1.052. Train Acc: 0.9448. Test Acc:0.7434
# Epoch: 650. Train Loss: 0.1891. Test Loss: 1.058. Train Acc: 0.939. Test Acc:0.7443
# Epoch: 660. Train Loss: 0.1756. Test Loss: 1.037. Train Acc: 0.941. Test Acc:0.7448
# Epoch: 670. Train Loss: 0.1963. Test Loss: 1.096. Train Acc: 0.9359. Test Acc:0.7345
# Epoch: 680. Train Loss: 0.1738. Test Loss: 1.054. Train Acc: 0.9465. Test Acc:0.7407
# Epoch: 690. Train Loss: 0.1776. Test Loss: 1.073. Train Acc: 0.9447. Test Acc:0.7465
# Epoch: 700. Train Loss: 0.1568. Test Loss: 1.04. Train Acc: 0.9501. Test Acc:0.7479
# Epoch: 710. Train Loss: 0.161. Test Loss: 1.078. Train Acc: 0.9473. Test Acc:0.7456
# Epoch: 720. Train Loss: 0.1404. Test Loss: 1.042. Train Acc: 0.9573. Test Acc:0.7546
# Epoch: 730. Train Loss: 0.1706. Test Loss: 1.113. Train Acc: 0.9438. Test Acc:0.7448
# Epoch: 740. Train Loss: 0.1441. Test Loss: 1.056. Train Acc: 0.9543. Test Acc:0.7519
# Epoch: 750. Train Loss: 0.1522. Test Loss: 1.069. Train Acc: 0.952. Test Acc:0.751
# Epoch: 760. Train Loss: 0.1431. Test Loss: 1.072. Train Acc: 0.9553. Test Acc:0.7488
# Epoch: 770. Train Loss: 0.1554. Test Loss: 1.068. Train Acc: 0.9513. Test Acc:0.7559
# Epoch: 780. Train Loss: 0.1556. Test Loss: 1.087. Train Acc: 0.9531. Test Acc:0.7461
# Epoch: 790. Train Loss: 0.1339. Test Loss: 1.039. Train Acc: 0.9586. Test Acc:0.7581
# Epoch: 800. Train Loss: 0.1393. Test Loss: 1.073. Train Acc: 0.9556. Test Acc:0.7519
# Epoch: 810. Train Loss: 0.1548. Test Loss: 1.1. Train Acc: 0.9487. Test Acc:0.7497
# Epoch: 820. Train Loss: 0.1401. Test Loss: 1.086. Train Acc: 0.9556. Test Acc:0.7479
# Epoch: 830. Train Loss: 0.1467. Test Loss: 1.091. Train Acc: 0.9505. Test Acc:0.7443
# Epoch: 840. Train Loss: 0.1553. Test Loss: 1.131. Train Acc: 0.9498. Test Acc:0.7497
# Epoch: 850. Train Loss: 0.1319. Test Loss: 1.106. Train Acc: 0.9595. Test Acc:0.7506
# Epoch: 860. Train Loss: 0.1313. Test Loss: 1.099. Train Acc: 0.958. Test Acc:0.7519
# Epoch: 870. Train Loss: 0.1278. Test Loss: 1.083. Train Acc: 0.958. Test Acc:0.7537
# Epoch: 880. Train Loss: 0.1739. Test Loss: 1.174. Train Acc: 0.9413. Test Acc:0.7367
# Epoch: 890. Train Loss: 0.2261. Test Loss: 1.257. Train Acc: 0.9217. Test Acc:0.7282
# Epoch: 900. Train Loss: 0.1292. Test Loss: 1.12. Train Acc: 0.9576. Test Acc:0.7564
# Epoch: 910. Train Loss: 0.09521. Test Loss: 1.028. Train Acc: 0.9719. Test Acc:0.7657
# Epoch: 920. Train Loss: 0.1178. Test Loss: 1.108. Train Acc: 0.9629. Test Acc:0.7599
# Epoch: 930. Train Loss: 0.1162. Test Loss: 1.103. Train Acc: 0.9618. Test Acc:0.7622
# Epoch: 940. Train Loss: 0.127. Test Loss: 1.138. Train Acc: 0.9593. Test Acc:0.7501
# Epoch: 950. Train Loss: 0.1446. Test Loss: 1.17. Train Acc: 0.955. Test Acc:0.7479
# Epoch: 960. Train Loss: 0.1101. Test Loss: 1.11. Train Acc: 0.9658. Test Acc:0.7564
# Epoch: 970. Train Loss: 0.1258. Test Loss: 1.132. Train Acc: 0.9583. Test Acc:0.7528
# Epoch: 980. Train Loss: 0.1101. Test Loss: 1.114. Train Acc: 0.9651. Test Acc:0.7586
# Epoch: 990. Train Loss: 0.1133. Test Loss: 1.106. Train Acc: 0.9646. Test Acc:0.7537
# Epoch: 1000. Train Loss: 0.08882. Test Loss: 1.061. Train Acc: 0.9747. Test Acc:0.7711
# ASRCNN__conv_pool_max__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.629. Test Loss: 2.77. Train Acc: 0.09372. Test Acc:0.06203
# Epoch: 20. Train Loss: 2.174. Test Loss: 2.36. Train Acc: 0.2438. Test Acc:0.1834
# Epoch: 30. Train Loss: 1.755. Test Loss: 1.959. Train Acc: 0.4045. Test Acc:0.3155
# Epoch: 40. Train Loss: 1.468. Test Loss: 1.698. Train Acc: 0.5219. Test Acc:0.4105
# Epoch: 50. Train Loss: 1.284. Test Loss: 1.535. Train Acc: 0.5975. Test Acc:0.4748
# Epoch: 60. Train Loss: 1.121. Test Loss: 1.396. Train Acc: 0.6722. Test Acc:0.5422
# Epoch: 70. Train Loss: 1.016. Test Loss: 1.31. Train Acc: 0.7092. Test Acc:0.581
# Epoch: 80. Train Loss: 0.9341. Test Loss: 1.239. Train Acc: 0.7388. Test Acc:0.6078
# Epoch: 90. Train Loss: 0.8784. Test Loss: 1.207. Train Acc: 0.762. Test Acc:0.6261
# Epoch: 100. Train Loss: 0.8353. Test Loss: 1.171. Train Acc: 0.7675. Test Acc:0.6319
# Epoch: 110. Train Loss: 0.799. Test Loss: 1.137. Train Acc: 0.7709. Test Acc:0.6386
# Epoch: 120. Train Loss: 0.7639. Test Loss: 1.116. Train Acc: 0.7787. Test Acc:0.6479
# Epoch: 130. Train Loss: 0.7133. Test Loss: 1.074. Train Acc: 0.8001. Test Acc:0.6564
# Epoch: 140. Train Loss: 0.6856. Test Loss: 1.066. Train Acc: 0.8137. Test Acc:0.6716
# Epoch: 150. Train Loss: 0.6609. Test Loss: 1.054. Train Acc: 0.8137. Test Acc:0.6698
# Epoch: 160. Train Loss: 0.6497. Test Loss: 1.048. Train Acc: 0.8132. Test Acc:0.6743
# Epoch: 170. Train Loss: 0.6486. Test Loss: 1.063. Train Acc: 0.8056. Test Acc:0.6582
# Epoch: 180. Train Loss: 0.637. Test Loss: 1.035. Train Acc: 0.8084. Test Acc:0.6653
# Epoch: 190. Train Loss: 0.615. Test Loss: 1.03. Train Acc: 0.8157. Test Acc:0.6622
# Epoch: 200. Train Loss: 0.5591. Test Loss: 0.9704. Train Acc: 0.8451. Test Acc:0.6966
# Epoch: 210. Train Loss: 0.5226. Test Loss: 0.9623. Train Acc: 0.8594. Test Acc:0.7041
# Epoch: 220. Train Loss: 0.4775. Test Loss: 0.9211. Train Acc: 0.8819. Test Acc:0.7265
# Epoch: 230. Train Loss: 0.4692. Test Loss: 0.9321. Train Acc: 0.8837. Test Acc:0.7207
# Epoch: 240. Train Loss: 0.4697. Test Loss: 0.9341. Train Acc: 0.8784. Test Acc:0.7126
# Epoch: 250. Train Loss: 0.4489. Test Loss: 0.9138. Train Acc: 0.8877. Test Acc:0.7238
# Epoch: 260. Train Loss: 0.4504. Test Loss: 0.9281. Train Acc: 0.8822. Test Acc:0.7198
# Epoch: 270. Train Loss: 0.4323. Test Loss: 0.9043. Train Acc: 0.8888. Test Acc:0.7282
# Epoch: 280. Train Loss: 0.4316. Test Loss: 0.9129. Train Acc: 0.8838. Test Acc:0.7171
# Epoch: 290. Train Loss: 0.3963. Test Loss: 0.8813. Train Acc: 0.9023. Test Acc:0.7336
# Epoch: 300. Train Loss: 0.3852. Test Loss: 0.8881. Train Acc: 0.9064. Test Acc:0.7327
# Epoch: 310. Train Loss: 0.3721. Test Loss: 0.8683. Train Acc: 0.9101. Test Acc:0.7412
# Epoch: 320. Train Loss: 0.3827. Test Loss: 0.8857. Train Acc: 0.9033. Test Acc:0.7287
# Epoch: 330. Train Loss: 0.3643. Test Loss: 0.8725. Train Acc: 0.9089. Test Acc:0.7349
# Epoch: 340. Train Loss: 0.3372. Test Loss: 0.8571. Train Acc: 0.9247. Test Acc:0.7416
# Epoch: 350. Train Loss: 0.3305. Test Loss: 0.8436. Train Acc: 0.9237. Test Acc:0.7456
# Epoch: 360. Train Loss: 0.3305. Test Loss: 0.8524. Train Acc: 0.9189. Test Acc:0.7381
# Epoch: 370. Train Loss: 0.3174. Test Loss: 0.8615. Train Acc: 0.9216. Test Acc:0.7398
# Epoch: 380. Train Loss: 0.309. Test Loss: 0.8413. Train Acc: 0.9217. Test Acc:0.7394
# Epoch: 390. Train Loss: 0.314. Test Loss: 0.8526. Train Acc: 0.9201. Test Acc:0.743
# Epoch: 400. Train Loss: 0.2991. Test Loss: 0.8296. Train Acc: 0.928. Test Acc:0.7452
# Epoch: 410. Train Loss: 0.2817. Test Loss: 0.8351. Train Acc: 0.9349. Test Acc:0.743
# Epoch: 420. Train Loss: 0.2871. Test Loss: 0.8434. Train Acc: 0.9307. Test Acc:0.7416
# Epoch: 430. Train Loss: 0.2815. Test Loss: 0.8509. Train Acc: 0.9317. Test Acc:0.7425
# Epoch: 440. Train Loss: 0.2663. Test Loss: 0.8244. Train Acc: 0.9365. Test Acc:0.7465
# Epoch: 450. Train Loss: 0.2829. Test Loss: 0.8496. Train Acc: 0.9261. Test Acc:0.7336
# Epoch: 460. Train Loss: 0.2646. Test Loss: 0.8295. Train Acc: 0.9314. Test Acc:0.7421
# Epoch: 470. Train Loss: 0.2498. Test Loss: 0.808. Train Acc: 0.9405. Test Acc:0.7479
# Epoch: 480. Train Loss: 0.2568. Test Loss: 0.8249. Train Acc: 0.9369. Test Acc:0.7515
# Epoch: 490. Train Loss: 0.2378. Test Loss: 0.8216. Train Acc: 0.9432. Test Acc:0.7479
# Epoch: 500. Train Loss: 0.2373. Test Loss: 0.8336. Train Acc: 0.9422. Test Acc:0.7425
# Epoch: 510. Train Loss: 0.2333. Test Loss: 0.8321. Train Acc: 0.9422. Test Acc:0.7425
# Epoch: 520. Train Loss: 0.2132. Test Loss: 0.8125. Train Acc: 0.9526. Test Acc:0.7537
# Epoch: 530. Train Loss: 0.2283. Test Loss: 0.8218. Train Acc: 0.9407. Test Acc:0.7483
# Epoch: 540. Train Loss: 0.2019. Test Loss: 0.7982. Train Acc: 0.9556. Test Acc:0.7595
# Epoch: 550. Train Loss: 0.2162. Test Loss: 0.8037. Train Acc: 0.947. Test Acc:0.7532
# Epoch: 560. Train Loss: 0.221. Test Loss: 0.8246. Train Acc: 0.9428. Test Acc:0.7461
# Epoch: 570. Train Loss: 0.2027. Test Loss: 0.8032. Train Acc: 0.9503. Test Acc:0.7506
# Epoch: 580. Train Loss: 0.2224. Test Loss: 0.8159. Train Acc: 0.939. Test Acc:0.7483
# Epoch: 590. Train Loss: 0.2178. Test Loss: 0.8236. Train Acc: 0.945. Test Acc:0.7483
# Epoch: 600. Train Loss: 0.1952. Test Loss: 0.8143. Train Acc: 0.9535. Test Acc:0.7515
# Epoch: 610. Train Loss: 0.1915. Test Loss: 0.8054. Train Acc: 0.955. Test Acc:0.7492
# Epoch: 620. Train Loss: 0.1804. Test Loss: 0.8028. Train Acc: 0.9593. Test Acc:0.7537
# Epoch: 630. Train Loss: 0.1894. Test Loss: 0.8132. Train Acc: 0.953. Test Acc:0.7523
# Epoch: 640. Train Loss: 0.188. Test Loss: 0.8134. Train Acc: 0.9568. Test Acc:0.7523
# Epoch: 650. Train Loss: 0.1796. Test Loss: 0.8062. Train Acc: 0.9596. Test Acc:0.7555
# Epoch: 660. Train Loss: 0.1724. Test Loss: 0.8067. Train Acc: 0.9581. Test Acc:0.7568
# Epoch: 670. Train Loss: 0.181. Test Loss: 0.8112. Train Acc: 0.9531. Test Acc:0.755
# Epoch: 680. Train Loss: 0.1687. Test Loss: 0.8038. Train Acc: 0.9588. Test Acc:0.7546
# Epoch: 690. Train Loss: 0.1542. Test Loss: 0.7956. Train Acc: 0.9658. Test Acc:0.7662
# Epoch: 700. Train Loss: 0.165. Test Loss: 0.8191. Train Acc: 0.961. Test Acc:0.7573
# Epoch: 710. Train Loss: 0.1643. Test Loss: 0.832. Train Acc: 0.9583. Test Acc:0.7506
# Epoch: 720. Train Loss: 0.1542. Test Loss: 0.8307. Train Acc: 0.9646. Test Acc:0.7604
# Epoch: 730. Train Loss: 0.1782. Test Loss: 0.8523. Train Acc: 0.9493. Test Acc:0.7439
# Epoch: 740. Train Loss: 0.1491. Test Loss: 0.8155. Train Acc: 0.9649. Test Acc:0.7635
# Epoch: 750. Train Loss: 0.1472. Test Loss: 0.8259. Train Acc: 0.9654. Test Acc:0.7586
# Epoch: 760. Train Loss: 0.1423. Test Loss: 0.8278. Train Acc: 0.9691. Test Acc:0.7586
# Epoch: 770. Train Loss: 0.1505. Test Loss: 0.8364. Train Acc: 0.9634. Test Acc:0.7519
# Epoch: 780. Train Loss: 0.1626. Test Loss: 0.8431. Train Acc: 0.9566. Test Acc:0.7497
# Epoch: 790. Train Loss: 0.1429. Test Loss: 0.8296. Train Acc: 0.9649. Test Acc:0.7532
# Epoch: 800. Train Loss: 0.1325. Test Loss: 0.8146. Train Acc: 0.9714. Test Acc:0.7648
# Epoch: 810. Train Loss: 0.1392. Test Loss: 0.8462. Train Acc: 0.9676. Test Acc:0.7555
# Epoch: 820. Train Loss: 0.1268. Test Loss: 0.8163. Train Acc: 0.9718. Test Acc:0.7595
# Epoch: 830. Train Loss: 0.1292. Test Loss: 0.8465. Train Acc: 0.9714. Test Acc:0.7622
# Epoch: 840. Train Loss: 0.1316. Test Loss: 0.8364. Train Acc: 0.9664. Test Acc:0.7599
# Epoch: 850. Train Loss: 0.1329. Test Loss: 0.8556. Train Acc: 0.9676. Test Acc:0.7577
# Epoch: 860. Train Loss: 0.1276. Test Loss: 0.8304. Train Acc: 0.9714. Test Acc:0.7626
# Epoch: 870. Train Loss: 0.1161. Test Loss: 0.8451. Train Acc: 0.9746. Test Acc:0.7626
# Epoch: 880. Train Loss: 0.1309. Test Loss: 0.8534. Train Acc: 0.9661. Test Acc:0.7559
# Epoch: 890. Train Loss: 0.1166. Test Loss: 0.8419. Train Acc: 0.9759. Test Acc:0.7635
# Epoch: 900. Train Loss: 0.1208. Test Loss: 0.8657. Train Acc: 0.9709. Test Acc:0.7564
# Epoch: 910. Train Loss: 0.1174. Test Loss: 0.8414. Train Acc: 0.9727. Test Acc:0.7622
# Epoch: 920. Train Loss: 0.1156. Test Loss: 0.8446. Train Acc: 0.9724. Test Acc:0.7631
# Epoch: 930. Train Loss: 0.1108. Test Loss: 0.839. Train Acc: 0.9756. Test Acc:0.7595
# Epoch: 940. Train Loss: 0.1103. Test Loss: 0.8632. Train Acc: 0.9732. Test Acc:0.7653
# Epoch: 950. Train Loss: 0.1121. Test Loss: 0.8491. Train Acc: 0.9734. Test Acc:0.7617
# Epoch: 960. Train Loss: 0.1066. Test Loss: 0.8836. Train Acc: 0.9761. Test Acc:0.7595
# Epoch: 970. Train Loss: 0.1067. Test Loss: 0.853. Train Acc: 0.9756. Test Acc:0.7559
# Epoch: 980. Train Loss: 0.1089. Test Loss: 0.8502. Train Acc: 0.9766. Test Acc:0.7644
# Epoch: 990. Train Loss: 0.1074. Test Loss: 0.864. Train Acc: 0.9767. Test Acc:0.7617
# Epoch: 1000. Train Loss: 0.1242. Test Loss: 0.8704. Train Acc: 0.9668. Test Acc:0.7546
# ASRCNN__conv_pool_max__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-z__obj_voice_cmd using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 4.154. Test Loss: 4.173. Train Acc: 0.0437. Test Acc:0.04685
# Epoch: 20. Train Loss: 3.603. Test Loss: 3.719. Train Acc: 0.09887. Test Acc:0.08925
# Epoch: 30. Train Loss: 3.021. Test Loss: 3.212. Train Acc: 0.2404. Test Acc:0.2035
# Epoch: 40. Train Loss: 2.582. Test Loss: 2.836. Train Acc: 0.3435. Test Acc:0.2914
# Epoch: 50. Train Loss: 2.235. Test Loss: 2.561. Train Acc: 0.4216. Test Acc:0.34
# Epoch: 60. Train Loss: 2.011. Test Loss: 2.372. Train Acc: 0.4772. Test Acc:0.3833
# Epoch: 70. Train Loss: 1.762. Test Loss: 2.164. Train Acc: 0.5402. Test Acc:0.4257
# Epoch: 80. Train Loss: 1.577. Test Loss: 1.992. Train Acc: 0.5877. Test Acc:0.465
# Epoch: 90. Train Loss: 1.432. Test Loss: 1.86. Train Acc: 0.6226. Test Acc:0.5051
# Epoch: 100. Train Loss: 1.279. Test Loss: 1.72. Train Acc: 0.672. Test Acc:0.5328
# Epoch: 110. Train Loss: 1.223. Test Loss: 1.685. Train Acc: 0.6785. Test Acc:0.5448
# Epoch: 120. Train Loss: 1.176. Test Loss: 1.645. Train Acc: 0.6894. Test Acc:0.5618
# Epoch: 130. Train Loss: 1.086. Test Loss: 1.558. Train Acc: 0.7144. Test Acc:0.5823
# Epoch: 140. Train Loss: 1.014. Test Loss: 1.488. Train Acc: 0.7353. Test Acc:0.6055
# Epoch: 150. Train Loss: 0.9547. Test Loss: 1.417. Train Acc: 0.7434. Test Acc:0.6154
# Epoch: 160. Train Loss: 0.9255. Test Loss: 1.406. Train Acc: 0.7501. Test Acc:0.6162
# Epoch: 170. Train Loss: 0.8702. Test Loss: 1.35. Train Acc: 0.7677. Test Acc:0.6332
# Epoch: 180. Train Loss: 0.832. Test Loss: 1.308. Train Acc: 0.7757. Test Acc:0.6363
# Epoch: 190. Train Loss: 0.8096. Test Loss: 1.298. Train Acc: 0.7807. Test Acc:0.643
# Epoch: 200. Train Loss: 0.7195. Test Loss: 1.214. Train Acc: 0.8106. Test Acc:0.6685
# Epoch: 210. Train Loss: 0.7112. Test Loss: 1.22. Train Acc: 0.8129. Test Acc:0.6685
# Epoch: 220. Train Loss: 0.7192. Test Loss: 1.235. Train Acc: 0.8021. Test Acc:0.6631
# Epoch: 230. Train Loss: 0.726. Test Loss: 1.241. Train Acc: 0.8034. Test Acc:0.6595
# Epoch: 240. Train Loss: 0.6601. Test Loss: 1.18. Train Acc: 0.8227. Test Acc:0.6756
# Epoch: 250. Train Loss: 0.6367. Test Loss: 1.168. Train Acc: 0.8303. Test Acc:0.6854
# Epoch: 260. Train Loss: 0.5691. Test Loss: 1.108. Train Acc: 0.8514. Test Acc:0.6992
# Epoch: 270. Train Loss: 0.614. Test Loss: 1.174. Train Acc: 0.836. Test Acc:0.6823
# Epoch: 280. Train Loss: 0.596. Test Loss: 1.143. Train Acc: 0.8375. Test Acc:0.6908
# Epoch: 290. Train Loss: 0.6001. Test Loss: 1.175. Train Acc: 0.8352. Test Acc:0.6863
# Epoch: 300. Train Loss: 0.5986. Test Loss: 1.171. Train Acc: 0.8358. Test Acc:0.6863
# Epoch: 310. Train Loss: 0.5877. Test Loss: 1.17. Train Acc: 0.8355. Test Acc:0.6818
# Epoch: 320. Train Loss: 0.5687. Test Loss: 1.158. Train Acc: 0.8446. Test Acc:0.6912
# Epoch: 330. Train Loss: 0.4934. Test Loss: 1.063. Train Acc: 0.8684. Test Acc:0.7166
# Epoch: 340. Train Loss: 0.4601. Test Loss: 1.057. Train Acc: 0.8815. Test Acc:0.7216
# Epoch: 350. Train Loss: 0.4291. Test Loss: 1.026. Train Acc: 0.8917. Test Acc:0.7291
# Epoch: 360. Train Loss: 0.4081. Test Loss: 1.016. Train Acc: 0.8995. Test Acc:0.734
# Epoch: 370. Train Loss: 0.4238. Test Loss: 1.04. Train Acc: 0.8927. Test Acc:0.7233
# Epoch: 380. Train Loss: 0.4134. Test Loss: 1.042. Train Acc: 0.8933. Test Acc:0.7229
# Epoch: 390. Train Loss: 0.4247. Test Loss: 1.061. Train Acc: 0.8875. Test Acc:0.7135
# Epoch: 400. Train Loss: 0.4045. Test Loss: 1.046. Train Acc: 0.8953. Test Acc:0.7242
# Epoch: 410. Train Loss: 0.393. Test Loss: 1.039. Train Acc: 0.8988. Test Acc:0.7251
# Epoch: 420. Train Loss: 0.4065. Test Loss: 1.062. Train Acc: 0.8937. Test Acc:0.7211
# Epoch: 430. Train Loss: 0.4057. Test Loss: 1.064. Train Acc: 0.8961. Test Acc:0.7184
# Epoch: 440. Train Loss: 0.37. Test Loss: 1.031. Train Acc: 0.9053. Test Acc:0.7354
# Epoch: 450. Train Loss: 0.372. Test Loss: 1.034. Train Acc: 0.9008. Test Acc:0.7287
# Epoch: 460. Train Loss: 0.3552. Test Loss: 1.02. Train Acc: 0.9066. Test Acc:0.7323
# Epoch: 470. Train Loss: 0.378. Test Loss: 1.062. Train Acc: 0.8983. Test Acc:0.7189
# Epoch: 480. Train Loss: 0.3433. Test Loss: 1.023. Train Acc: 0.9068. Test Acc:0.7354
# Epoch: 490. Train Loss: 0.3459. Test Loss: 1.053. Train Acc: 0.9084. Test Acc:0.7332
# Epoch: 500. Train Loss: 0.3672. Test Loss: 1.072. Train Acc: 0.8991. Test Acc:0.7207
# Epoch: 510. Train Loss: 0.3329. Test Loss: 1.038. Train Acc: 0.9096. Test Acc:0.7336
# Epoch: 520. Train Loss: 0.3236. Test Loss: 1.041. Train Acc: 0.9146. Test Acc:0.7332
# Epoch: 530. Train Loss: 0.3141. Test Loss: 1.021. Train Acc: 0.9159. Test Acc:0.7363
# Epoch: 540. Train Loss: 0.2921. Test Loss: 1.0. Train Acc: 0.9232. Test Acc:0.747
# Epoch: 550. Train Loss: 0.2928. Test Loss: 1.026. Train Acc: 0.9221. Test Acc:0.7345
# Epoch: 560. Train Loss: 0.2945. Test Loss: 1.023. Train Acc: 0.9177. Test Acc:0.7358
# Epoch: 570. Train Loss: 0.291. Test Loss: 1.03. Train Acc: 0.9197. Test Acc:0.7363
# Epoch: 580. Train Loss: 0.3118. Test Loss: 1.07. Train Acc: 0.9128. Test Acc:0.7247
# Epoch: 590. Train Loss: 0.2846. Test Loss: 1.05. Train Acc: 0.9231. Test Acc:0.7372
# Epoch: 600. Train Loss: 0.2714. Test Loss: 1.013. Train Acc: 0.9297. Test Acc:0.7412
# Epoch: 610. Train Loss: 0.2718. Test Loss: 1.019. Train Acc: 0.9251. Test Acc:0.7407
# Epoch: 620. Train Loss: 0.3002. Test Loss: 1.067. Train Acc: 0.9146. Test Acc:0.7278
# Epoch: 630. Train Loss: 0.2559. Test Loss: 1.032. Train Acc: 0.928. Test Acc:0.739
# Epoch: 640. Train Loss: 0.2783. Test Loss: 1.063. Train Acc: 0.9212. Test Acc:0.7309
# Epoch: 650. Train Loss: 0.2813. Test Loss: 1.074. Train Acc: 0.9186. Test Acc:0.7381
# Epoch: 660. Train Loss: 0.2425. Test Loss: 1.02. Train Acc: 0.9342. Test Acc:0.743
# Epoch: 670. Train Loss: 0.241. Test Loss: 1.031. Train Acc: 0.9317. Test Acc:0.7407
# Epoch: 680. Train Loss: 0.2769. Test Loss: 1.085. Train Acc: 0.9202. Test Acc:0.7318
# Epoch: 690. Train Loss: 0.2562. Test Loss: 1.067. Train Acc: 0.9302. Test Acc:0.734
# Epoch: 700. Train Loss: 0.2441. Test Loss: 1.049. Train Acc: 0.9295. Test Acc:0.739
# Epoch: 710. Train Loss: 0.2199. Test Loss: 1.022. Train Acc: 0.9412. Test Acc:0.7465
# Epoch: 720. Train Loss: 0.2497. Test Loss: 1.069. Train Acc: 0.9292. Test Acc:0.7358
# Epoch: 730. Train Loss: 0.2466. Test Loss: 1.054. Train Acc: 0.9322. Test Acc:0.7394
# Epoch: 740. Train Loss: 0.2433. Test Loss: 1.09. Train Acc: 0.931. Test Acc:0.7291
# Epoch: 750. Train Loss: 0.2244. Test Loss: 1.05. Train Acc: 0.9352. Test Acc:0.7456
# Epoch: 760. Train Loss: 0.2474. Test Loss: 1.109. Train Acc: 0.929. Test Acc:0.7332
# Epoch: 770. Train Loss: 0.2485. Test Loss: 1.124. Train Acc: 0.9271. Test Acc:0.7296
# Epoch: 780. Train Loss: 0.2139. Test Loss: 1.044. Train Acc: 0.9389. Test Acc:0.7448
# Epoch: 790. Train Loss: 0.2029. Test Loss: 1.045. Train Acc: 0.9417. Test Acc:0.7461
# Epoch: 800. Train Loss: 0.2048. Test Loss: 1.046. Train Acc: 0.9413. Test Acc:0.743
# Epoch: 810. Train Loss: 0.1926. Test Loss: 1.053. Train Acc: 0.9435. Test Acc:0.7479
# Epoch: 820. Train Loss: 0.2143. Test Loss: 1.079. Train Acc: 0.9377. Test Acc:0.7434
# Epoch: 830. Train Loss: 0.2046. Test Loss: 1.078. Train Acc: 0.9405. Test Acc:0.739
# Epoch: 840. Train Loss: 0.2014. Test Loss: 1.101. Train Acc: 0.9413. Test Acc:0.7434
# Epoch: 850. Train Loss: 0.2059. Test Loss: 1.095. Train Acc: 0.9403. Test Acc:0.7416
# Epoch: 860. Train Loss: 0.2223. Test Loss: 1.122. Train Acc: 0.9324. Test Acc:0.734
# Epoch: 870. Train Loss: 0.183. Test Loss: 1.071. Train Acc: 0.9467. Test Acc:0.7488
# Epoch: 880. Train Loss: 0.2001. Test Loss: 1.117. Train Acc: 0.9432. Test Acc:0.7349
# Epoch: 890. Train Loss: 0.1699. Test Loss: 1.05. Train Acc: 0.9505. Test Acc:0.7523
# Epoch: 900. Train Loss: 0.1969. Test Loss: 1.114. Train Acc: 0.9408. Test Acc:0.7354
# Epoch: 910. Train Loss: 0.1784. Test Loss: 1.099. Train Acc: 0.9455. Test Acc:0.739
# Epoch: 920. Train Loss: 0.1911. Test Loss: 1.118. Train Acc: 0.9428. Test Acc:0.7398
# Epoch: 930. Train Loss: 0.1924. Test Loss: 1.142. Train Acc: 0.9423. Test Acc:0.7425
# Epoch: 940. Train Loss: 0.1595. Test Loss: 1.078. Train Acc: 0.9528. Test Acc:0.7501
# Epoch: 950. Train Loss: 0.1671. Test Loss: 1.091. Train Acc: 0.9508. Test Acc:0.7479
# Epoch: 960. Train Loss: 0.1579. Test Loss: 1.095. Train Acc: 0.9531. Test Acc:0.7443
# Epoch: 970. Train Loss: 0.1755. Test Loss: 1.105. Train Acc: 0.9472. Test Acc:0.7376
# Epoch: 980. Train Loss: 0.1901. Test Loss: 1.131. Train Acc: 0.942. Test Acc:0.7336
# Epoch: 990. Train Loss: 0.1502. Test Loss: 1.081. Train Acc: 0.9555. Test Acc:0.7412
# Epoch: 1000. Train Loss: 0.1807. Test Loss: 1.134. Train Acc: 0.9452. Test Acc:0.7381
# ASRCNN__conv_pool_max__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-z__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.734. Test Loss: 2.848. Train Acc: 0.06215. Test Acc:0.06292
# Epoch: 20. Train Loss: 2.391. Test Loss: 2.494. Train Acc: 0.1321. Test Acc:0.1272
# Epoch: 30. Train Loss: 2.141. Test Loss: 2.286. Train Acc: 0.2268. Test Acc:0.2102
# Epoch: 40. Train Loss: 1.936. Test Loss: 2.117. Train Acc: 0.3039. Test Acc:0.2468
# Epoch: 50. Train Loss: 1.754. Test Loss: 1.96. Train Acc: 0.3784. Test Acc:0.3128
# Epoch: 60. Train Loss: 1.594. Test Loss: 1.809. Train Acc: 0.4369. Test Acc:0.3717
# Epoch: 70. Train Loss: 1.429. Test Loss: 1.653. Train Acc: 0.5193. Test Acc:0.4391
# Epoch: 80. Train Loss: 1.309. Test Loss: 1.539. Train Acc: 0.5736. Test Acc:0.4859
# Epoch: 90. Train Loss: 1.21. Test Loss: 1.454. Train Acc: 0.6203. Test Acc:0.5283
# Epoch: 100. Train Loss: 1.171. Test Loss: 1.426. Train Acc: 0.6293. Test Acc:0.5346
# Epoch: 110. Train Loss: 1.115. Test Loss: 1.385. Train Acc: 0.6535. Test Acc:0.5502
# Epoch: 120. Train Loss: 1.041. Test Loss: 1.329. Train Acc: 0.6926. Test Acc:0.5743
# Epoch: 130. Train Loss: 1.016. Test Loss: 1.312. Train Acc: 0.6884. Test Acc:0.5788
# Epoch: 140. Train Loss: 0.9787. Test Loss: 1.287. Train Acc: 0.7069. Test Acc:0.5841
# Epoch: 150. Train Loss: 0.9043. Test Loss: 1.226. Train Acc: 0.7483. Test Acc:0.6207
# Epoch: 160. Train Loss: 0.869. Test Loss: 1.209. Train Acc: 0.7602. Test Acc:0.6336
# Epoch: 170. Train Loss: 0.8629. Test Loss: 1.203. Train Acc: 0.7574. Test Acc:0.6292
# Epoch: 180. Train Loss: 0.8351. Test Loss: 1.195. Train Acc: 0.767. Test Acc:0.6292
# Epoch: 190. Train Loss: 0.8127. Test Loss: 1.177. Train Acc: 0.7777. Test Acc:0.6444
# Epoch: 200. Train Loss: 0.8389. Test Loss: 1.208. Train Acc: 0.7449. Test Acc:0.6185
# Epoch: 210. Train Loss: 0.7622. Test Loss: 1.145. Train Acc: 0.7903. Test Acc:0.6493
# Epoch: 220. Train Loss: 0.7373. Test Loss: 1.121. Train Acc: 0.7994. Test Acc:0.6542
# Epoch: 230. Train Loss: 0.7196. Test Loss: 1.103. Train Acc: 0.8071. Test Acc:0.6649
# Epoch: 240. Train Loss: 0.7051. Test Loss: 1.115. Train Acc: 0.8043. Test Acc:0.6622
# Epoch: 250. Train Loss: 0.7343. Test Loss: 1.133. Train Acc: 0.7798. Test Acc:0.6354
# Epoch: 260. Train Loss: 0.6805. Test Loss: 1.094. Train Acc: 0.8041. Test Acc:0.6537
# Epoch: 270. Train Loss: 0.6487. Test Loss: 1.062. Train Acc: 0.8234. Test Acc:0.6765
# Epoch: 280. Train Loss: 0.6517. Test Loss: 1.07. Train Acc: 0.8139. Test Acc:0.664
# Epoch: 290. Train Loss: 0.6302. Test Loss: 1.059. Train Acc: 0.819. Test Acc:0.6765
# Epoch: 300. Train Loss: 0.622. Test Loss: 1.049. Train Acc: 0.822. Test Acc:0.6725
# Epoch: 310. Train Loss: 0.5982. Test Loss: 1.028. Train Acc: 0.8347. Test Acc:0.6859
# Epoch: 320. Train Loss: 0.583. Test Loss: 1.026. Train Acc: 0.838. Test Acc:0.6814
# Epoch: 330. Train Loss: 0.5826. Test Loss: 1.031. Train Acc: 0.8347. Test Acc:0.6863
# Epoch: 340. Train Loss: 0.5708. Test Loss: 1.022. Train Acc: 0.833. Test Acc:0.6859
# Epoch: 350. Train Loss: 0.5425. Test Loss: 1.007. Train Acc: 0.8486. Test Acc:0.693
# Epoch: 360. Train Loss: 0.5502. Test Loss: 1.016. Train Acc: 0.8433. Test Acc:0.6925
# Epoch: 370. Train Loss: 0.5292. Test Loss: 0.9992. Train Acc: 0.8506. Test Acc:0.6943
# Epoch: 380. Train Loss: 0.5163. Test Loss: 0.9913. Train Acc: 0.8539. Test Acc:0.6961
# Epoch: 390. Train Loss: 0.5163. Test Loss: 0.9893. Train Acc: 0.8534. Test Acc:0.6975
# Epoch: 400. Train Loss: 0.4891. Test Loss: 0.9723. Train Acc: 0.8634. Test Acc:0.71
# Epoch: 410. Train Loss: 0.4731. Test Loss: 0.9613. Train Acc: 0.8716. Test Acc:0.7131
# Epoch: 420. Train Loss: 0.4793. Test Loss: 0.9796. Train Acc: 0.8696. Test Acc:0.7095
# Epoch: 430. Train Loss: 0.4759. Test Loss: 0.9748. Train Acc: 0.8639. Test Acc:0.7001
# Epoch: 440. Train Loss: 0.4694. Test Loss: 0.9825. Train Acc: 0.8666. Test Acc:0.7068
# Epoch: 450. Train Loss: 0.4599. Test Loss: 0.991. Train Acc: 0.8696. Test Acc:0.7095
# Epoch: 460. Train Loss: 0.4465. Test Loss: 0.9806. Train Acc: 0.8785. Test Acc:0.7131
# Epoch: 470. Train Loss: 0.4329. Test Loss: 0.973. Train Acc: 0.8838. Test Acc:0.7162
# Epoch: 480. Train Loss: 0.4091. Test Loss: 0.9419. Train Acc: 0.8915. Test Acc:0.7189
# Epoch: 490. Train Loss: 0.4208. Test Loss: 0.9637. Train Acc: 0.8794. Test Acc:0.7117
# Epoch: 500. Train Loss: 0.4069. Test Loss: 0.9557. Train Acc: 0.8843. Test Acc:0.7153
# Epoch: 510. Train Loss: 0.3843. Test Loss: 0.9497. Train Acc: 0.894. Test Acc:0.722
# Epoch: 520. Train Loss: 0.3819. Test Loss: 0.937. Train Acc: 0.8958. Test Acc:0.7202
# Epoch: 530. Train Loss: 0.3743. Test Loss: 0.9497. Train Acc: 0.8983. Test Acc:0.7149
# Epoch: 540. Train Loss: 0.3631. Test Loss: 0.9331. Train Acc: 0.9033. Test Acc:0.7184
# Epoch: 550. Train Loss: 0.3445. Test Loss: 0.9231. Train Acc: 0.9146. Test Acc:0.7323
# Epoch: 560. Train Loss: 0.3505. Test Loss: 0.9287. Train Acc: 0.9058. Test Acc:0.7296
# Epoch: 570. Train Loss: 0.3343. Test Loss: 0.919. Train Acc: 0.9167. Test Acc:0.7345
# Epoch: 580. Train Loss: 0.3357. Test Loss: 0.9082. Train Acc: 0.9123. Test Acc:0.73
# Epoch: 590. Train Loss: 0.3203. Test Loss: 0.9274. Train Acc: 0.9171. Test Acc:0.7376
# Epoch: 600. Train Loss: 0.3137. Test Loss: 0.9061. Train Acc: 0.9207. Test Acc:0.739
# Epoch: 610. Train Loss: 0.3242. Test Loss: 0.9308. Train Acc: 0.9104. Test Acc:0.7291
# Epoch: 620. Train Loss: 0.3115. Test Loss: 0.9002. Train Acc: 0.9209. Test Acc:0.7381
# Epoch: 630. Train Loss: 0.2984. Test Loss: 0.9062. Train Acc: 0.9239. Test Acc:0.7309
# Epoch: 640. Train Loss: 0.2952. Test Loss: 0.8978. Train Acc: 0.9246. Test Acc:0.743
# Epoch: 650. Train Loss: 0.3031. Test Loss: 0.9153. Train Acc: 0.9174. Test Acc:0.7332
# Epoch: 660. Train Loss: 0.2897. Test Loss: 0.9075. Train Acc: 0.9251. Test Acc:0.7349
# Epoch: 670. Train Loss: 0.2661. Test Loss: 0.8911. Train Acc: 0.9382. Test Acc:0.7488
# Epoch: 680. Train Loss: 0.2742. Test Loss: 0.916. Train Acc: 0.928. Test Acc:0.7461
# Epoch: 690. Train Loss: 0.2562. Test Loss: 0.9078. Train Acc: 0.9362. Test Acc:0.7381
# Epoch: 700. Train Loss: 0.2673. Test Loss: 0.9125. Train Acc: 0.9324. Test Acc:0.7385
# Epoch: 710. Train Loss: 0.2616. Test Loss: 0.908. Train Acc: 0.9307. Test Acc:0.743
# Epoch: 720. Train Loss: 0.2539. Test Loss: 0.8997. Train Acc: 0.9384. Test Acc:0.751
# Epoch: 730. Train Loss: 0.2435. Test Loss: 0.8837. Train Acc: 0.9427. Test Acc:0.7515
# Epoch: 740. Train Loss: 0.2484. Test Loss: 0.8971. Train Acc: 0.9375. Test Acc:0.7474
# Epoch: 750. Train Loss: 0.2342. Test Loss: 0.8857. Train Acc: 0.9462. Test Acc:0.7559
# Epoch: 760. Train Loss: 0.2332. Test Loss: 0.8965. Train Acc: 0.945. Test Acc:0.7501
# Epoch: 770. Train Loss: 0.2312. Test Loss: 0.929. Train Acc: 0.9452. Test Acc:0.7412
# Epoch: 780. Train Loss: 0.2259. Test Loss: 0.9046. Train Acc: 0.9488. Test Acc:0.7492
# Epoch: 790. Train Loss: 0.2238. Test Loss: 0.8877. Train Acc: 0.9485. Test Acc:0.7537
# Epoch: 800. Train Loss: 0.2126. Test Loss: 0.9112. Train Acc: 0.954. Test Acc:0.7492
# Epoch: 810. Train Loss: 0.2236. Test Loss: 0.9053. Train Acc: 0.9458. Test Acc:0.7492
# Epoch: 820. Train Loss: 0.2028. Test Loss: 0.8917. Train Acc: 0.9541. Test Acc:0.7492
# Epoch: 830. Train Loss: 0.2038. Test Loss: 0.9005. Train Acc: 0.9555. Test Acc:0.7448
# Epoch: 840. Train Loss: 0.2199. Test Loss: 0.9063. Train Acc: 0.9437. Test Acc:0.7354
# Epoch: 850. Train Loss: 0.2011. Test Loss: 0.8843. Train Acc: 0.9561. Test Acc:0.7456
# Epoch: 860. Train Loss: 0.1969. Test Loss: 0.9095. Train Acc: 0.957. Test Acc:0.7421
# Epoch: 870. Train Loss: 0.2127. Test Loss: 0.9138. Train Acc: 0.9453. Test Acc:0.7421
# Epoch: 880. Train Loss: 0.2094. Test Loss: 0.9165. Train Acc: 0.9488. Test Acc:0.7332
# Epoch: 890. Train Loss: 0.1882. Test Loss: 0.911. Train Acc: 0.9566. Test Acc:0.747
# Epoch: 900. Train Loss: 0.189. Test Loss: 0.9156. Train Acc: 0.9558. Test Acc:0.739
# Epoch: 910. Train Loss: 0.1886. Test Loss: 0.9077. Train Acc: 0.9565. Test Acc:0.7456
# Epoch: 920. Train Loss: 0.1855. Test Loss: 0.9071. Train Acc: 0.9596. Test Acc:0.7448
# Epoch: 930. Train Loss: 0.1884. Test Loss: 0.9042. Train Acc: 0.955. Test Acc:0.7443
# Epoch: 940. Train Loss: 0.1841. Test Loss: 0.9235. Train Acc: 0.957. Test Acc:0.7398
# Epoch: 950. Train Loss: 0.1813. Test Loss: 0.9231. Train Acc: 0.957. Test Acc:0.7403
# Epoch: 960. Train Loss: 0.1783. Test Loss: 0.9086. Train Acc: 0.9591. Test Acc:0.7474
# Epoch: 970. Train Loss: 0.1803. Test Loss: 0.9111. Train Acc: 0.958. Test Acc:0.7421
# Epoch: 980. Train Loss: 0.1798. Test Loss: 0.8996. Train Acc: 0.9585. Test Acc:0.7434
# Epoch: 990. Train Loss: 0.1741. Test Loss: 0.9145. Train Acc: 0.9603. Test Acc:0.7448
# Epoch: 1000. Train Loss: 0.1778. Test Loss: 0.9157. Train Acc: 0.9575. Test Acc:0.7394
# ASRCNN__conv_pool_max__conv_dp_0.2__fc_dp_0.2__fn_retrained-wav2vec_features-c__obj_voice_cmd using retrained-wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 4.028. Test Loss: 4.071. Train Acc: 0.05434. Test Acc:0.04596
# Epoch: 20. Train Loss: 3.776. Test Loss: 3.907. Train Acc: 0.08159. Test Acc:0.0589
# Epoch: 30. Train Loss: 3.396. Test Loss: 3.62. Train Acc: 0.1414. Test Acc:0.09862
# Epoch: 40. Train Loss: 2.967. Test Loss: 3.224. Train Acc: 0.2275. Test Acc:0.1803
# Epoch: 50. Train Loss: 2.611. Test Loss: 2.916. Train Acc: 0.3144. Test Acc:0.2405
# Epoch: 60. Train Loss: 2.274. Test Loss: 2.602. Train Acc: 0.4026. Test Acc:0.3128
# Epoch: 70. Train Loss: 2.006. Test Loss: 2.361. Train Acc: 0.4691. Test Acc:0.3802
# Epoch: 80. Train Loss: 1.752. Test Loss: 2.133. Train Acc: 0.5415. Test Acc:0.436
# Epoch: 90. Train Loss: 1.605. Test Loss: 2.0. Train Acc: 0.5771. Test Acc:0.465
# Epoch: 100. Train Loss: 1.475. Test Loss: 1.887. Train Acc: 0.6112. Test Acc:0.4864
# Epoch: 110. Train Loss: 1.382. Test Loss: 1.808. Train Acc: 0.6437. Test Acc:0.5065
# Epoch: 120. Train Loss: 1.261. Test Loss: 1.712. Train Acc: 0.6725. Test Acc:0.5377
# Epoch: 130. Train Loss: 1.172. Test Loss: 1.629. Train Acc: 0.7036. Test Acc:0.5578
# Epoch: 140. Train Loss: 1.111. Test Loss: 1.588. Train Acc: 0.7193. Test Acc:0.5645
# Epoch: 150. Train Loss: 1.013. Test Loss: 1.504. Train Acc: 0.7502. Test Acc:0.5926
# Epoch: 160. Train Loss: 0.9742. Test Loss: 1.485. Train Acc: 0.7596. Test Acc:0.5921
# Epoch: 170. Train Loss: 0.9097. Test Loss: 1.432. Train Acc: 0.7732. Test Acc:0.6087
# Epoch: 180. Train Loss: 0.8543. Test Loss: 1.383. Train Acc: 0.7883. Test Acc:0.6287
# Epoch: 190. Train Loss: 0.7926. Test Loss: 1.324. Train Acc: 0.8121. Test Acc:0.6386
# Epoch: 200. Train Loss: 0.7813. Test Loss: 1.328. Train Acc: 0.8117. Test Acc:0.6354
# Epoch: 210. Train Loss: 0.7439. Test Loss: 1.305. Train Acc: 0.8157. Test Acc:0.6475
# Epoch: 220. Train Loss: 0.7375. Test Loss: 1.314. Train Acc: 0.8119. Test Acc:0.6417
# Epoch: 230. Train Loss: 0.718. Test Loss: 1.313. Train Acc: 0.8152. Test Acc:0.6408
# Epoch: 240. Train Loss: 0.6744. Test Loss: 1.269. Train Acc: 0.8307. Test Acc:0.6555
# Epoch: 250. Train Loss: 0.66. Test Loss: 1.278. Train Acc: 0.8317. Test Acc:0.6497
# Epoch: 260. Train Loss: 0.6338. Test Loss: 1.245. Train Acc: 0.8405. Test Acc:0.6582
# Epoch: 270. Train Loss: 0.5956. Test Loss: 1.22. Train Acc: 0.8531. Test Acc:0.6734
# Epoch: 280. Train Loss: 0.6071. Test Loss: 1.258. Train Acc: 0.844. Test Acc:0.6604
# Epoch: 290. Train Loss: 0.5648. Test Loss: 1.213. Train Acc: 0.8584. Test Acc:0.6689
# Epoch: 300. Train Loss: 0.5505. Test Loss: 1.207. Train Acc: 0.8637. Test Acc:0.6809
# Epoch: 310. Train Loss: 0.5112. Test Loss: 1.184. Train Acc: 0.8749. Test Acc:0.6805
# Epoch: 320. Train Loss: 0.5077. Test Loss: 1.191. Train Acc: 0.8714. Test Acc:0.6796
# Epoch: 330. Train Loss: 0.5101. Test Loss: 1.204. Train Acc: 0.8707. Test Acc:0.6832
# ...
# Epoch: 290. Train Loss: 0.6939. Test Loss: 1.502. Train Acc: 0.8. Test Acc:0.6175
# Epoch: 300. Train Loss: 0.635. Test Loss: 1.427. Train Acc: 0.8175. Test Acc:0.6378
# Epoch: 310. Train Loss: 0.7134. Test Loss: 1.554. Train Acc: 0.7926. Test Acc:0.6145
# Epoch: 320. Train Loss: 0.634. Test Loss: 1.455. Train Acc: 0.8143. Test Acc:0.6335
# Epoch: 330. Train Loss: 0.5901. Test Loss: 1.393. Train Acc: 0.8305. Test Acc:0.6464
# Epoch: 340. Train Loss: 0.5482. Test Loss: 1.351. Train Acc: 0.8481. Test Acc:0.6606
# Epoch: 350. Train Loss: 0.5718. Test Loss: 1.381. Train Acc: 0.8364. Test Acc:0.6524
# Epoch: 360. Train Loss: 0.5289. Test Loss: 1.339. Train Acc: 0.8498. Test Acc:0.6615
# Epoch: 370. Train Loss: 0.5243. Test Loss: 1.342. Train Acc: 0.8503. Test Acc:0.6611
# Epoch: 380. Train Loss: 0.4908. Test Loss: 1.306. Train Acc: 0.8623. Test Acc:0.6753
# Epoch: 390. Train Loss: 0.51. Test Loss: 1.341. Train Acc: 0.8515. Test Acc:0.6675
# Epoch: 400. Train Loss: 0.5189. Test Loss: 1.365. Train Acc: 0.8441. Test Acc:0.655
# Epoch: 410. Train Loss: 0.5133. Test Loss: 1.368. Train Acc: 0.8453. Test Acc:0.6628
# Epoch: 420. Train Loss: 0.4759. Test Loss: 1.337. Train Acc: 0.8591. Test Acc:0.6701
# Epoch: 430. Train Loss: 0.4292. Test Loss: 1.294. Train Acc: 0.8791. Test Acc:0.6792
# Epoch: 440. Train Loss: 0.3914. Test Loss: 1.221. Train Acc: 0.8907. Test Acc:0.693
# Epoch: 450. Train Loss: 0.4564. Test Loss: 1.345. Train Acc: 0.8646. Test Acc:0.6697
# Epoch: 460. Train Loss: 0.3565. Test Loss: 1.202. Train Acc: 0.9012. Test Acc:0.7012
# Epoch: 470. Train Loss: 0.3915. Test Loss: 1.272. Train Acc: 0.8848. Test Acc:0.6848
# Epoch: 480. Train Loss: 0.3968. Test Loss: 1.315. Train Acc: 0.8827. Test Acc:0.6787
# Epoch: 490. Train Loss: 0.3832. Test Loss: 1.295. Train Acc: 0.8884. Test Acc:0.6826
# Epoch: 500. Train Loss: 0.3577. Test Loss: 1.257. Train Acc: 0.8968. Test Acc:0.6895
# Epoch: 510. Train Loss: 0.359. Test Loss: 1.27. Train Acc: 0.8973. Test Acc:0.6887
# Epoch: 520. Train Loss: 0.3387. Test Loss: 1.227. Train Acc: 0.9024. Test Acc:0.6964
# Epoch: 530. Train Loss: 0.338. Test Loss: 1.239. Train Acc: 0.9015. Test Acc:0.6964
# Epoch: 540. Train Loss: 0.3621. Test Loss: 1.302. Train Acc: 0.8879. Test Acc:0.6835
# Epoch: 550. Train Loss: 0.3304. Test Loss: 1.233. Train Acc: 0.9007. Test Acc:0.6999
# Epoch: 560. Train Loss: 0.2793. Test Loss: 1.186. Train Acc: 0.9222. Test Acc:0.7081
# Epoch: 570. Train Loss: 0.3483. Test Loss: 1.291. Train Acc: 0.8924. Test Acc:0.6848
# Epoch: 580. Train Loss: 0.2989. Test Loss: 1.247. Train Acc: 0.9113. Test Acc:0.699
# Epoch: 590. Train Loss: 0.2753. Test Loss: 1.203. Train Acc: 0.9212. Test Acc:0.7107
# Epoch: 600. Train Loss: 0.2993. Test Loss: 1.254. Train Acc: 0.9094. Test Acc:0.6999
# Epoch: 610. Train Loss: 0.2666. Test Loss: 1.221. Train Acc: 0.9227. Test Acc:0.7033
# Epoch: 620. Train Loss: 0.2862. Test Loss: 1.248. Train Acc: 0.913. Test Acc:0.699
# Epoch: 630. Train Loss: 0.254. Test Loss: 1.201. Train Acc: 0.9241. Test Acc:0.7171
# Epoch: 640. Train Loss: 0.2758. Test Loss: 1.261. Train Acc: 0.9141. Test Acc:0.6994
# Epoch: 650. Train Loss: 0.2787. Test Loss: 1.275. Train Acc: 0.9153. Test Acc:0.7003
# Epoch: 660. Train Loss: 0.276. Test Loss: 1.26. Train Acc: 0.9136. Test Acc:0.7003
# Epoch: 670. Train Loss: 0.2736. Test Loss: 1.279. Train Acc: 0.9123. Test Acc:0.7007
# Epoch: 680. Train Loss: 0.2392. Test Loss: 1.215. Train Acc: 0.9298. Test Acc:0.715
# Epoch: 690. Train Loss: 0.2646. Test Loss: 1.28. Train Acc: 0.919. Test Acc:0.7046
# Epoch: 700. Train Loss: 0.2465. Test Loss: 1.231. Train Acc: 0.9241. Test Acc:0.7089
# Epoch: 710. Train Loss: 0.2131. Test Loss: 1.199. Train Acc: 0.9342. Test Acc:0.7145
# Epoch: 720. Train Loss: 0.2051. Test Loss: 1.18. Train Acc: 0.9391. Test Acc:0.7283
# Epoch: 730. Train Loss: 0.2013. Test Loss: 1.205. Train Acc: 0.9404. Test Acc:0.7232
# Epoch: 740. Train Loss: 0.2212. Test Loss: 1.215. Train Acc: 0.9295. Test Acc:0.718
# Epoch: 750. Train Loss: 0.2175. Test Loss: 1.226. Train Acc: 0.9332. Test Acc:0.7188
# Epoch: 760. Train Loss: 0.2537. Test Loss: 1.295. Train Acc: 0.9184. Test Acc:0.7029
# Epoch: 770. Train Loss: 0.2041. Test Loss: 1.2. Train Acc: 0.936. Test Acc:0.7227
# Epoch: 780. Train Loss: 0.2273. Test Loss: 1.256. Train Acc: 0.9276. Test Acc:0.7132
# Epoch: 790. Train Loss: 0.2253. Test Loss: 1.267. Train Acc: 0.9264. Test Acc:0.7171
# Epoch: 800. Train Loss: 0.2075. Test Loss: 1.23. Train Acc: 0.937. Test Acc:0.7184
# Epoch: 810. Train Loss: 0.2078. Test Loss: 1.217. Train Acc: 0.9337. Test Acc:0.7236
# Epoch: 820. Train Loss: 0.2271. Test Loss: 1.268. Train Acc: 0.9283. Test Acc:0.715
# Epoch: 830. Train Loss: 0.1927. Test Loss: 1.224. Train Acc: 0.9397. Test Acc:0.7249
# Epoch: 840. Train Loss: 0.1843. Test Loss: 1.211. Train Acc: 0.9426. Test Acc:0.721
# Epoch: 850. Train Loss: 0.2185. Test Loss: 1.279. Train Acc: 0.9305. Test Acc:0.7167
# Epoch: 860. Train Loss: 0.2048. Test Loss: 1.278. Train Acc: 0.9348. Test Acc:0.7158
# Epoch: 870. Train Loss: 0.1932. Test Loss: 1.257. Train Acc: 0.9391. Test Acc:0.7201
# Epoch: 880. Train Loss: 0.1897. Test Loss: 1.25. Train Acc: 0.9416. Test Acc:0.7232
# Epoch: 890. Train Loss: 0.1795. Test Loss: 1.25. Train Acc: 0.9441. Test Acc:0.7197
# Epoch: 900. Train Loss: 0.1742. Test Loss: 1.232. Train Acc: 0.9456. Test Acc:0.7262
# Epoch: 910. Train Loss: 0.1923. Test Loss: 1.257. Train Acc: 0.9401. Test Acc:0.7201
# Epoch: 920. Train Loss: 0.2043. Test Loss: 1.287. Train Acc: 0.933. Test Acc:0.7158
# Epoch: 930. Train Loss: 0.1539. Test Loss: 1.19. Train Acc: 0.9551. Test Acc:0.7288
# Epoch: 940. Train Loss: 0.1538. Test Loss: 1.241. Train Acc: 0.954. Test Acc:0.7266
# Epoch: 950. Train Loss: 0.1583. Test Loss: 1.225. Train Acc: 0.9508. Test Acc:0.7227
# Epoch: 960. Train Loss: 0.1886. Test Loss: 1.303. Train Acc: 0.9399. Test Acc:0.7141
# Epoch: 970. Train Loss: 0.1721. Test Loss: 1.247. Train Acc: 0.9455. Test Acc:0.7262
# Epoch: 980. Train Loss: 0.1805. Test Loss: 1.253. Train Acc: 0.9406. Test Acc:0.7288
# Epoch: 990. Train Loss: 0.1414. Test Loss: 1.205. Train Acc: 0.9549. Test Acc:0.7348
# Epoch: 1000. Train Loss: 0.1328. Test Loss: 1.186. Train Acc: 0.9586. Test Acc:0.7361
# ASRCNN__conv_pool_max__conv_dp_0.2__fc_dp_0.2__fn_retrained-wav2vec_features-z__obj_voice_cmd__and__voice_cmd_lng using retrained-wav2vec_features-z on fold#1
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        MaxPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        MaxPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       MaxPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       MaxPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 5940
# test_n: 2319
# Epoch: 10. Train Loss: 2.75. Test Loss: 2.834. Train Acc: 0.0532. Test Acc:0.047
# Epoch: 20. Train Loss: 2.223. Test Loss: 2.389. Train Acc: 0.2256. Test Acc:0.1695
# Epoch: 30. Train Loss: 1.818. Test Loss: 2.093. Train Acc: 0.3685. Test Acc:0.2911
# Epoch: 40. Train Loss: 1.572. Test Loss: 1.89. Train Acc: 0.483. Test Acc:0.3786
# Epoch: 50. Train Loss: 1.341. Test Loss: 1.711. Train Acc: 0.5837. Test Acc:0.4506
# Epoch: 60. Train Loss: 1.203. Test Loss: 1.615. Train Acc: 0.6394. Test Acc:0.4761
# Epoch: 70. Train Loss: 1.11. Test Loss: 1.553. Train Acc: 0.6805. Test Acc:0.5127
# Epoch: 80. Train Loss: 1.025. Test Loss: 1.491. Train Acc: 0.7155. Test Acc:0.5244
# Epoch: 90. Train Loss: 0.9708. Test Loss: 1.443. Train Acc: 0.7387. Test Acc:0.5511
# Epoch: 100. Train Loss: 0.918. Test Loss: 1.402. Train Acc: 0.7596. Test Acc:0.5653
# Epoch: 110. Train Loss: 0.8741. Test Loss: 1.368. Train Acc: 0.7749. Test Acc:0.5791
# Epoch: 120. Train Loss: 0.8825. Test Loss: 1.393. Train Acc: 0.7628. Test Acc:0.5796
# Epoch: 130. Train Loss: 0.8393. Test Loss: 1.345. Train Acc: 0.782. Test Acc:0.5921
# Epoch: 140. Train Loss: 0.821. Test Loss: 1.346. Train Acc: 0.7842. Test Acc:0.5934
# Epoch: 150. Train Loss: 0.7884. Test Loss: 1.324. Train Acc: 0.7963. Test Acc:0.6033
# Epoch: 160. Train Loss: 0.751. Test Loss: 1.293. Train Acc: 0.814. Test Acc:0.6093
# Epoch: 170. Train Loss: 0.7653. Test Loss: 1.306. Train Acc: 0.798. Test Acc:0.608
# Epoch: 180. Train Loss: 0.7213. Test Loss: 1.273. Train Acc: 0.8214. Test Acc:0.6266
# Epoch: 190. Train Loss: 0.7054. Test Loss: 1.267. Train Acc: 0.8254. Test Acc:0.627
# Epoch: 200. Train Loss: 0.6802. Test Loss: 1.252. Train Acc: 0.8283. Test Acc:0.63
# Epoch: 210. Train Loss: 0.6449. Test Loss: 1.217. Train Acc: 0.8488. Test Acc:0.6404
# Epoch: 220. Train Loss: 0.6431. Test Loss: 1.226. Train Acc: 0.8436. Test Acc:0.6399
# Epoch: 230. Train Loss: 0.6137. Test Loss: 1.2. Train Acc: 0.8485. Test Acc:0.646
# Epoch: 240. Train Loss: 0.6088. Test Loss: 1.201. Train Acc: 0.8488. Test Acc:0.6382
# Epoch: 250. Train Loss: 0.5974. Test Loss: 1.198. Train Acc: 0.8532. Test Acc:0.6391
# Epoch: 260. Train Loss: 0.5894. Test Loss: 1.194. Train Acc: 0.8586. Test Acc:0.6498
# Epoch: 270. Train Loss: 0.5569. Test Loss: 1.168. Train Acc: 0.8658. Test Acc:0.655
# Epoch: 280. Train Loss: 0.5526. Test Loss: 1.176. Train Acc: 0.8611. Test Acc:0.649
# Epoch: 290. Train Loss: 0.5318. Test Loss: 1.159. Train Acc: 0.8695. Test Acc:0.6546
# Epoch: 300. Train Loss: 0.5196. Test Loss: 1.159. Train Acc: 0.8722. Test Acc:0.6563
# Epoch: 310. Train Loss: 0.5211. Test Loss: 1.168. Train Acc: 0.8645. Test Acc:0.6464
# Epoch: 320. Train Loss: 0.5024. Test Loss: 1.152. Train Acc: 0.8704. Test Acc:0.6503
# Epoch: 330. Train Loss: 0.4967. Test Loss: 1.157. Train Acc: 0.8734. Test Acc:0.649
# Epoch: 340. Train Loss: 0.5064. Test Loss: 1.18. Train Acc: 0.8552. Test Acc:0.6429
# Epoch: 350. Train Loss: 0.4762. Test Loss: 1.151. Train Acc: 0.8744. Test Acc:0.6524
# Epoch: 360. Train Loss: 0.4664. Test Loss: 1.155. Train Acc: 0.8773. Test Acc:0.6555
# Epoch: 370. Train Loss: 0.4619. Test Loss: 1.155. Train Acc: 0.8783. Test Acc:0.6533
# Epoch: 380. Train Loss: 0.4488. Test Loss: 1.151. Train Acc: 0.8805. Test Acc:0.6494
# Epoch: 390. Train Loss: 0.4258. Test Loss: 1.116. Train Acc: 0.8975. Test Acc:0.6654
# Epoch: 400. Train Loss: 0.418. Test Loss: 1.135. Train Acc: 0.8953. Test Acc:0.6662
# Epoch: 410. Train Loss: 0.422. Test Loss: 1.165. Train Acc: 0.8838. Test Acc:0.6567
# Epoch: 420. Train Loss: 0.3947. Test Loss: 1.116. Train Acc: 0.9042. Test Acc:0.677
# Epoch: 430. Train Loss: 0.4012. Test Loss: 1.15. Train Acc: 0.8923. Test Acc:0.668
# Epoch: 440. Train Loss: 0.383. Test Loss: 1.13. Train Acc: 0.9027. Test Acc:0.6697
# Epoch: 450. Train Loss: 0.3702. Test Loss: 1.125. Train Acc: 0.9082. Test Acc:0.668
# Epoch: 460. Train Loss: 0.3797. Test Loss: 1.161. Train Acc: 0.8944. Test Acc:0.6654
# Epoch: 470. Train Loss: 0.3716. Test Loss: 1.152. Train Acc: 0.8968. Test Acc:0.6593
# Epoch: 480. Train Loss: 0.3655. Test Loss: 1.158. Train Acc: 0.8975. Test Acc:0.6567
# Epoch: 490. Train Loss: 0.3554. Test Loss: 1.155. Train Acc: 0.9015. Test Acc:0.6658
# Epoch: 500. Train Loss: 0.3547. Test Loss: 1.174. Train Acc: 0.897. Test Acc:0.6559
# Epoch: 510. Train Loss: 0.3493. Test Loss: 1.165. Train Acc: 0.9037. Test Acc:0.6654
# Epoch: 520. Train Loss: 0.3371. Test Loss: 1.168. Train Acc: 0.9002. Test Acc:0.6624
# Epoch: 530. Train Loss: 0.3238. Test Loss: 1.157. Train Acc: 0.9121. Test Acc:0.6701
# Epoch: 540. Train Loss: 0.3203. Test Loss: 1.154. Train Acc: 0.9121. Test Acc:0.6632
# Epoch: 550. Train Loss: 0.3222. Test Loss: 1.168. Train Acc: 0.9099. Test Acc:0.6658
# Epoch: 560. Train Loss: 0.3266. Test Loss: 1.187. Train Acc: 0.9017. Test Acc:0.6589
# Epoch: 570. Train Loss: 0.3034. Test Loss: 1.162. Train Acc: 0.9187. Test Acc:0.6693
# Epoch: 580. Train Loss: 0.3099. Test Loss: 1.194. Train Acc: 0.9098. Test Acc:0.6636
# Epoch: 590. Train Loss: 0.3092. Test Loss: 1.2. Train Acc: 0.914. Test Acc:0.6671
# Epoch: 600. Train Loss: 0.2954. Test Loss: 1.194. Train Acc: 0.9146. Test Acc:0.6667
# Epoch: 610. Train Loss: 0.3031. Test Loss: 1.202. Train Acc: 0.9123. Test Acc:0.6658
# Epoch: 620. Train Loss: 0.2797. Test Loss: 1.187. Train Acc: 0.9231. Test Acc:0.6779
# Epoch: 630. Train Loss: 0.2886. Test Loss: 1.207. Train Acc: 0.9185. Test Acc:0.6697
# Epoch: 640. Train Loss: 0.2761. Test Loss: 1.199. Train Acc: 0.9184. Test Acc:0.6684
# Epoch: 650. Train Loss: 0.2664. Test Loss: 1.194. Train Acc: 0.9227. Test Acc:0.6662
# Epoch: 660. Train Loss: 0.282. Test Loss: 1.231. Train Acc: 0.9146. Test Acc:0.6585
# Epoch: 670. Train Loss: 0.2862. Test Loss: 1.258. Train Acc: 0.9066. Test Acc:0.655
# Epoch: 680. Train Loss: 0.2755. Test Loss: 1.229. Train Acc: 0.9192. Test Acc:0.6654
# Epoch: 690. Train Loss: 0.25. Test Loss: 1.214. Train Acc: 0.9291. Test Acc:0.6792
# Epoch: 700. Train Loss: 0.263. Test Loss: 1.247. Train Acc: 0.9178. Test Acc:0.6619
# Epoch: 710. Train Loss: 0.2499. Test Loss: 1.223. Train Acc: 0.9259. Test Acc:0.6662
# Epoch: 720. Train Loss: 0.2544. Test Loss: 1.24. Train Acc: 0.9232. Test Acc:0.6619
# Epoch: 730. Train Loss: 0.2337. Test Loss: 1.221. Train Acc: 0.93. Test Acc:0.6779
# Epoch: 740. Train Loss: 0.2415. Test Loss: 1.242. Train Acc: 0.9239. Test Acc:0.6693
# Epoch: 750. Train Loss: 0.2395. Test Loss: 1.245. Train Acc: 0.9269. Test Acc:0.6714
# Epoch: 760. Train Loss: 0.2244. Test Loss: 1.223. Train Acc: 0.9345. Test Acc:0.6792
# Epoch: 770. Train Loss: 0.2315. Test Loss: 1.231. Train Acc: 0.9266. Test Acc:0.671
# Epoch: 780. Train Loss: 0.2162. Test Loss: 1.241. Train Acc: 0.937. Test Acc:0.6731
# Epoch: 790. Train Loss: 0.2304. Test Loss: 1.246. Train Acc: 0.9278. Test Acc:0.6727
# Epoch: 800. Train Loss: 0.224. Test Loss: 1.251. Train Acc: 0.9306. Test Acc:0.6714
# Epoch: 810. Train Loss: 0.2126. Test Loss: 1.253. Train Acc: 0.9379. Test Acc:0.6779
# Epoch: 820. Train Loss: 0.2083. Test Loss: 1.246. Train Acc: 0.9365. Test Acc:0.6757
# Epoch: 830. Train Loss: 0.2098. Test Loss: 1.258. Train Acc: 0.9377. Test Acc:0.6705
# Epoch: 840. Train Loss: 0.1953. Test Loss: 1.221. Train Acc: 0.9492. Test Acc:0.6891
# Epoch: 850. Train Loss: 0.1899. Test Loss: 1.224. Train Acc: 0.9473. Test Acc:0.6826
# Epoch: 860. Train Loss: 0.1999. Test Loss: 1.255. Train Acc: 0.9406. Test Acc:0.6774
# Epoch: 870. Train Loss: 0.1974. Test Loss: 1.256. Train Acc: 0.9423. Test Acc:0.6796
# Epoch: 880. Train Loss: 0.1948. Test Loss: 1.26. Train Acc: 0.9397. Test Acc:0.6727
# Epoch: 890. Train Loss: 0.1851. Test Loss: 1.249. Train Acc: 0.9433. Test Acc:0.6787
# Epoch: 900. Train Loss: 0.1986. Test Loss: 1.285. Train Acc: 0.9337. Test Acc:0.6662
# Epoch: 910. Train Loss: 0.1999. Test Loss: 1.275. Train Acc: 0.9332. Test Acc:0.6671
# Epoch: 920. Train Loss: 0.2001. Test Loss: 1.291. Train Acc: 0.9332. Test Acc:0.6662
# Epoch: 930. Train Loss: 0.1917. Test Loss: 1.278. Train Acc: 0.9365. Test Acc:0.6731
# Epoch: 940. Train Loss: 0.1816. Test Loss: 1.277. Train Acc: 0.9451. Test Acc:0.6723
# Epoch: 950. Train Loss: 0.1815. Test Loss: 1.273. Train Acc: 0.9375. Test Acc:0.6753
# Epoch: 960. Train Loss: 0.1927. Test Loss: 1.305. Train Acc: 0.9296. Test Acc:0.6628
