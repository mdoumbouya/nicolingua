# %%
from pathlib import Path
import csv
import itertools
import numpy as np
from pprint import PrettyPrinter


import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

import h5py

import sklearn
import sklearn.metrics

pprint = PrettyPrinter()

# %% [markdown]
# ## Configuration

# %%
SELECTED_LANGUAGES = {'_language_independent', 'francais', 'maninka', 'pular', 'susu'}

BASE_DIR = Path('/media/xtrem/data/experiments/nicolingua-0002-va-asr/datasets/gn_va_asr_dataset_2020-08-24_02')


ANNOTATIONS_PATH = BASE_DIR/ "annotated_segments" / "metadata.csv"


FEATURE_NAMES = [
    "wav2vec_features-c", 
    "wav2vec_features-z", 
    "retrained-wav2vec_features-c", 
    "retrained-wav2vec_features-z"
]

# CONV_POOLING_TYPES = ['avg', 'max']
CONV_POOLING_TYPES = ['avg']
OBJECTIVE_TYPES = ['voice_cmd', 'voice_cmd__and__voice_cmd_lng']
CONV_DROPOUT_PROBABILITIES = [0.2]
FC_DROPOUT_PROBABILITIES = [0.2]


TRAIN_PERCENT = .7
FOLD_COUNT = 5


RESULTS_DIR = f'results_101'
EPOCHS = 1000
BATCH_SIZE = 512
MAX_FEATURE_SEQUENCE_LENGTH = 200

GPU_ID = 0
device = torch.device(f"cuda:{GPU_ID}")

# %% [markdown]
# ## Load & shuffle metadata records

# %%
def load_metadata():
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for r in reader:
            if r['language'] in SELECTED_LANGUAGES:
                yield r

# %%
# load
metadata_records = list(load_metadata())

# shuffle
metadata_shuffler_rs = np.random.RandomState(seed=42)
metadata_shuffler_rs.shuffle(metadata_records)

# %%
bias_category_fields = [
     "device_id"
    ,"language"
    ,"speaker_gender"
    ,"speaker_mothertongue"
]

bias_categories = {}
for c in bias_category_fields:
    bias_categories[c] = sorted({r[c] for r in metadata_records})


_ = [print(f"\n{k}: \n\t{','.join(v)}") for k,v in bias_categories.items()]
# Out:
# device_id:
# 	d001,d002,d003
#
# language:
# 	_language_independent,francais,maninka,pular,susu
#
# speaker_gender:
# 	F,M
#
# speaker_mothertongue:
# 	maninka,pular,susu

# %% [markdown]
# ### Labels

# %%
# VOICE COMMANDS
voice_cmd_class_names = sorted({r['label'] for r in metadata_records})
voice_cmd_class_count = len(voice_cmd_class_names)
voice_cmd_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_class_names)}

print("Classes - Voice Commands")
_ = [print(f"{v:4}: {k}") for k,v in voice_cmd_class_id_by_name.items()]

print("---------------------")


# VOICE COMMAND LANGUAGES
voice_cmd_lng_class_names = sorted({r['language'] for r in metadata_records})
voice_cmd_lng_class_count = len(voice_cmd_lng_class_names)
voice_cmd_lng_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_lng_class_names)}

print("Classes - Voice Command Languages")
_ = [print(f"{v:3}: {k}") for k,v in voice_cmd_lng_class_id_by_name.items()]

print("---------------------")



# SPEAKER MOTHERTONGUE
spkr_mothertongue_class_names = sorted({r['speaker_mothertongue'] for r in metadata_records})
spkr_mothertongue_class_count = len(spkr_mothertongue_class_names)
spkr_mothertongue_class_id_by_name = {c:i for i,c in enumerate(spkr_mothertongue_class_names)}

print("Classes - Speaker Mothertongues")
_ = [print(f"{v:3}: {k}") for k,v in spkr_mothertongue_class_id_by_name.items()]

print("---------------------")



# SPEAKER GENDER
spkr_gender_class_names = sorted({r['speaker_gender'] for r in metadata_records})
spkr_gender_class_count = len(spkr_gender_class_names)
spkr_gender_class_id_by_name = {c:i for i, c in enumerate(spkr_gender_class_names)}

print("Classes - Speaker Gender")
_ = [print(f"{v:3}: {k}") for k,v in spkr_gender_class_id_by_name.items()]

print("----------------------")
# Out:
# Classes - Voice Commands
#    0: 101_wake_word__francais
#    1: 101_wake_word__maninka
#    2: 101_wake_word__pular
#    3: 101_wake_word__susu
#    4: 201_add_contact__francais
#    5: 201_add_contact__maninka
#    6: 201_add_contact__pular
#    7: 201_add_contact__susu
#    8: 202_search_contact__francais
#    9: 202_search_contact__maninka
#   10: 202_search_contact__pular
#   11: 202_search_contact__susu
#   12: 203_update_contact__francais
#   13: 203_update_contact__maninka
#   14: 203_update_contact__pular
#   15: 203_update_contact__susu
#   16: 204_delete_contact__francais
#   17: 204_delete_contact__maninka
#   18: 204_delete_contact__pular
#   19: 204_delete_contact__susu
#   20: 205_call_contact__francais
#   21: 205_call_contact__maninka
#   22: 205_call_contact__pular
#   23: 205_call_contact__susu
#   24: 206_yes__francais
#   25: 206_yes__maninka
#   26: 206_yes__pular
#   27: 206_yes__susu
#   28: 207_no__francais
#   29: 207_no__maninka
#   30: 207_no__pular
#   31: 207_no__susu
#   32: 301_zero__francais
#   33: 301_zero__maninka
#   34: 301_zero__pular
#   35: 301_zero__susu
#   36: 302_one__francais
#   37: 302_one__maninka
#   38: 302_one__pular
#   39: 302_one__susu
#   40: 303_two__francais
#   41: 303_two__maninka
#   42: 303_two__pular
#   43: 303_two__susu
#   44: 304_three__francais
#   45: 304_three__maninka
#   46: 304_three__pular
#   47: 304_three__susu
#   48: 305_four__francais
#   49: 305_four__maninka
#   50: 305_four__pular
#   51: 305_four__susu
#   52: 306_five__francais
#   53: 306_five__maninka
#   54: 306_five__pular
#   55: 306_five__susu
#   56: 307_six__francais
#   57: 307_six__maninka
#   58: 307_six__pular
#   59: 307_six__susu
#   60: 308_seven__francais
#   61: 308_seven__maninka
#   62: 308_seven__pular
#   63: 308_seven__susu
#   64: 309_eight__francais
#   65: 309_eight__maninka
#   66: 309_eight__pular
#   67: 309_eight__susu
#   68: 310_nine__francais
#   69: 310_nine__maninka
#   70: 310_nine__pular
#   71: 310_nine__susu
#   72: 401_mom__francais
#   73: 401_mom__maninka
#   74: 401_mom__pular
#   75: 401_mom__susu
#   76: 402_dad__francais
#   77: 402_dad__maninka
#   78: 402_dad__pular
#   79: 402_dad__susu
#   80: 501_fatoumata___language_independent
#   81: 502_mamadou___language_independent
#   82: 503_mariama___language_independent
#   83: 504_mohamed___language_independent
#   84: 505_kadiatou___language_independent
#   85: 506_ibrahima___language_independent
#   86: 507_aissatou___language_independent
#   87: 508_aminata___language_independent
#   88: 509_alpha___language_independent
#   89: 510_thierno___language_independent
#   90: 511_abdoulaye___language_independent
#   91: 512_aboubacar___language_independent
#   92: 513_amadou___language_independent
#   93: 514_fanta___language_independent
#   94: 515_mariame___language_independent
#   95: 516_oumou___language_independent
#   96: 517_ousmane___language_independent
#   97: 518_adama___language_independent
#   98: 519_marie___language_independent
#   99: 520_moussa___language_independent
#  100: 521_aissata___language_independent
#  101: 522_hawa___language_independent
#  102: 523_sekou___language_independent
#  103: 524_hadja___language_independent
#  104: 525_djenabou___language_independent
# ---------------------
# Classes - Voice Command Languages
#   0: _language_independent
#   1: francais
#   2: maninka
#   3: pular
#   4: susu
# ---------------------
# Classes - Speaker Mothertongues
#   0: maninka
#   1: pular
#   2: susu
# ---------------------
# Classes - Speaker Gender
#   0: F
#   1: M
# ----------------------

# %% [markdown]
# ### Inspect metadata

# %%
def count_by_attribute(records, attribute_names):
    attribute_name_instances = {}
    for attribute_name in attribute_names:
        attribute_name_instances[attribute_name] = {r[attribute_name] for r in records}
        
    l = [attribute_name_instances[attribute_name] for attribute_name in attribute_names]
    
    
    
    for attribute_values in sorted(itertools.product(*l)):
        
        def record_match(r):
            for i in range(len(attribute_names)):
                if r[attribute_names[i]] != attribute_values[i]:
                    return False
            return True
            
        record_instances = [r for r in records if record_match(r)]
        count = len(record_instances)
        
        yield (attribute_values, count)

# %%
print("RECORDS BY DEVICE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['device_id']))]
print("")

print("RECORDS BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['language']))]
print("")

print("RECORDS BY GENDER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_gender']))]
print("")

print("RECORDS BY AGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_age']))]
print("")

print("RECORDS BY SPEAKER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id']))]
print("")

print("RECORDS BY SPEAKER BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id', 'language']))]
print("")

print("RECORDS BY SPEAKER BY LABEL")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['label']))]
print("")
# Out:
# RECORDS BY DEVICE
# 	(('d001',), 2759)
# 	(('d002',), 2741)
# 	(('d003',), 2759)
#
# RECORDS BY LANGUAGE
# 	(('_language_independent',), 3072)
# 	(('francais',), 1260)
# 	(('maninka',), 1356)
# 	(('pular',), 909)
# 	(('susu',), 1662)
#
# RECORDS BY GENDER
# 	(('F',), 2820)
# 	(('M',), 5439)
#
# RECORDS BY AGE
# 	(('12',), 237)
# 	(('13',), 252)
# 	(('15',), 603)
# 	(('17',), 1050)
# 	(('18',), 855)
# 	(('19',), 273)
# 	(('20',), 291)
# 	(('27',), 255)
# 	(('28',), 183)
# 	(('29',), 237)
# 	(('31',), 255)
# 	(('32',), 291)
# 	(('33',), 183)
# 	(('34',), 129)
# 	(('35',), 498)
# 	(('37',), 309)
# 	(('38',), 441)
# 	(('43',), 183)
# 	(('44',), 540)
# 	(('5',), 129)
# 	(('55',), 183)
# 	(('61',), 390)
# 	(('63',), 237)
# 	(('67',), 255)
#
# RECORDS BY SPEAKER
# 	(('s001',), 183)
# 	(('s002',), 129)
# 	(('s003',), 183)
# 	(('s004',), 183)
# 	(('s005',), 129)
# 	(('s006',), 129)
# 	(('s007',), 183)
# 	(('s008',), 129)
# 	(('s009',), 237)
# 	(('s010',), 291)
# 	(('s011',), 129)
# 	(('s012',), 183)
# 	(('s013',), 129)
# 	(('s014',), 237)
# 	(('s015',), 291)
# 	(('s016',), 183)
# 	(('s017',), 237)
# 	(('s018',), 237)
# 	(('s019',), 237)
# 	(('s020',), 291)
# 	(('s021',), 273)
# 	(('s022',), 183)
# 	(('s023',), 309)
# 	(('s024',), 255)
# 	(('s025',), 315)
# 	(('s026',), 252)
# 	(('s027',), 540)
# 	(('s028',), 540)
# 	(('s029',), 390)
# 	(('s030',), 195)
# 	(('s031',), 252)
# 	(('s032',), 315)
# 	(('s033',), 255)
# 	(('s034',), 255)
#
# RECORDS BY SPEAKER BY LANGUAGE
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'francais'), 0)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'pular'), 0)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'francais'), 0)
# 	(('s002', 'maninka'), 54)
# 	(('s002', 'pular'), 0)
# 	(('s002', 'susu'), 0)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'francais'), 0)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'pular'), 0)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'francais'), 0)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'pular'), 0)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'francais'), 0)
# 	(('s005', 'maninka'), 0)
# 	(('s005', 'pular'), 0)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'francais'), 0)
# 	(('s006', 'maninka'), 54)
# 	(('s006', 'pular'), 0)
# 	(('s006', 'susu'), 0)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'francais'), 0)
# 	(('s007', 'maninka'), 0)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'francais'), 0)
# 	(('s008', 'maninka'), 54)
# 	(('s008', 'pular'), 0)
# 	(('s008', 'susu'), 0)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'maninka'), 0)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'francais'), 0)
# 	(('s011', 'maninka'), 0)
# 	(('s011', 'pular'), 0)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'maninka'), 0)
# 	(('s012', 'pular'), 0)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'francais'), 0)
# 	(('s013', 'maninka'), 0)
# 	(('s013', 'pular'), 0)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'pular'), 0)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'francais'), 0)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'pular'), 0)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'maninka'), 0)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'maninka'), 0)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'pular'), 0)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'francais'), 0)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'pular'), 0)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'pular'), 0)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'pular'), 0)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'maninka'), 0)
# 	(('s030', 'pular'), 60)
# 	(('s030', 'susu'), 0)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'maninka'), 0)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'pular'), 0)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'pular'), 0)
# 	(('s034', 'susu'), 60)
#
# RECORDS BY SPEAKER BY LABEL
# 	(('101_wake_word__francais',), 66)
# 	(('101_wake_word__maninka',), 72)
# 	(('101_wake_word__pular',), 48)
# 	(('101_wake_word__susu',), 89)
# 	(('201_add_contact__francais',), 66)
# 	(('201_add_contact__maninka',), 72)
# 	(('201_add_contact__pular',), 48)
# 	(('201_add_contact__susu',), 89)
# 	(('202_search_contact__francais',), 66)
# 	(('202_search_contact__maninka',), 72)
# 	(('202_search_contact__pular',), 48)
# 	(('202_search_contact__susu',), 89)
# 	(('203_update_contact__francais',), 66)
# 	(('203_update_contact__maninka',), 72)
# 	(('203_update_contact__pular',), 48)
# 	(('203_update_contact__susu',), 89)
# 	(('204_delete_contact__francais',), 66)
# 	(('204_delete_contact__maninka',), 72)
# 	(('204_delete_contact__pular',), 48)
# 	(('204_delete_contact__susu',), 89)
# 	(('205_call_contact__francais',), 66)
# 	(('205_call_contact__maninka',), 72)
# 	(('205_call_contact__pular',), 45)
# 	(('205_call_contact__susu',), 89)
# 	(('206_yes__francais',), 66)
# 	(('206_yes__maninka',), 72)
# 	(('206_yes__pular',), 48)
# 	(('206_yes__susu',), 89)
# 	(('207_no__francais',), 66)
# 	(('207_no__maninka',), 72)
# 	(('207_no__pular',), 48)
# 	(('207_no__susu',), 89)
# 	(('301_zero__francais',), 66)
# 	(('301_zero__maninka',), 72)
# 	(('301_zero__pular',), 48)
# 	(('301_zero__susu',), 89)
# 	(('302_one__francais',), 66)
# 	(('302_one__maninka',), 72)
# 	(('302_one__pular',), 48)
# 	(('302_one__susu',), 89)
# 	(('303_two__francais',), 66)
# 	(('303_two__maninka',), 72)
# 	(('303_two__pular',), 48)
# 	(('303_two__susu',), 89)
# 	(('304_three__francais',), 66)
# 	(('304_three__maninka',), 72)
# 	(('304_three__pular',), 48)
# 	(('304_three__susu',), 89)
# 	(('305_four__francais',), 66)
# 	(('305_four__maninka',), 72)
# 	(('305_four__pular',), 48)
# 	(('305_four__susu',), 89)
# 	(('306_five__francais',), 66)
# 	(('306_five__maninka',), 72)
# 	(('306_five__pular',), 48)
# 	(('306_five__susu',), 89)
# 	(('307_six__francais',), 66)
# 	(('307_six__maninka',), 72)
# 	(('307_six__pular',), 48)
# 	(('307_six__susu',), 89)
# 	(('308_seven__francais',), 66)
# 	(('308_seven__maninka',), 72)
# 	(('308_seven__pular',), 48)
# 	(('308_seven__susu',), 89)
# 	(('309_eight__francais',), 66)
# 	(('309_eight__maninka',), 72)
# 	(('309_eight__pular',), 48)
# 	(('309_eight__susu',), 89)
# 	(('310_nine__francais',), 66)
# 	(('310_nine__maninka',), 72)
# 	(('310_nine__pular',), 48)
# 	(('310_nine__susu',), 89)
# 	(('401_mom__francais',), 36)
# 	(('401_mom__maninka',), 30)
# 	(('401_mom__pular',), 24)
# 	(('401_mom__susu',), 30)
# 	(('402_dad__francais',), 36)
# 	(('402_dad__maninka',), 30)
# 	(('402_dad__pular',), 24)
# 	(('402_dad__susu',), 30)
# 	(('501_fatoumata___language_independent',), 123)
# 	(('502_mamadou___language_independent',), 123)
# 	(('503_mariama___language_independent',), 123)
# 	(('504_mohamed___language_independent',), 123)
# 	(('505_kadiatou___language_independent',), 123)
# 	(('506_ibrahima___language_independent',), 123)
# 	(('507_aissatou___language_independent',), 123)
# 	(('508_aminata___language_independent',), 123)
# 	(('509_alpha___language_independent',), 123)
# 	(('510_thierno___language_independent',), 120)
# 	(('511_abdoulaye___language_independent',), 123)
# 	(('512_aboubacar___language_independent',), 123)
# 	(('513_amadou___language_independent',), 123)
# 	(('514_fanta___language_independent',), 123)
# 	(('515_mariame___language_independent',), 123)
# 	(('516_oumou___language_independent',), 123)
# 	(('517_ousmane___language_independent',), 123)
# 	(('518_adama___language_independent',), 123)
# 	(('519_marie___language_independent',), 123)
# 	(('520_moussa___language_independent',), 123)
# 	(('521_aissata___language_independent',), 123)
# 	(('522_hawa___language_independent',), 123)
# 	(('523_sekou___language_independent',), 123)
# 	(('524_hadja___language_independent',), 123)
# 	(('525_djenabou___language_independent',), 123)

# %% [markdown]
# ## Prepare Cross Validation Folds
# - Partition by (speaker, language)
# - Each (speaker, language) correspond to `utterance_count * device_count`
# - For each fold, all `utterance_count * device_count` records for the same speaker in the same language are either in the TRAIN or the VALIDATION sets, but not both.

# %%
def generate_train_test_records_per_fold(all_records):
    records_per_fold = {}
    
    all_speaker_languages = sorted({(r['speaker_id'], r['language']) for r in all_records})

    sl_count = len(all_speaker_languages)
    all_sl_indices = range(sl_count)
    train_sl_count = int(np.ceil(sl_count*TRAIN_PERCENT))
    test_sl_count = sl_count - train_sl_count

    for fold_index in range(FOLD_COUNT):
        fold_rsampler = np.random.RandomState(seed=fold_index)

        train_sl_index_set = set(fold_rsampler.choice(all_sl_indices, train_sl_count, replace=False))
        train_sl_set = {all_speaker_languages[i] for i in train_sl_index_set}

        test_sl_index_set = set(all_sl_indices).difference(train_sl_index_set)
        test_sl_set = {all_speaker_languages[i] for i in test_sl_index_set}

        train_records = [r for r in all_records if (r['speaker_id'], r['language']) in train_sl_set]
        test_records = [r for r in all_records if (r['speaker_id'], r['language']) in test_sl_set]
        
        
        records_per_fold[fold_index] = {
            "train_records": train_records,
            "test_records": test_records
        }
    
    return records_per_fold

# %%
records_per_fold = generate_train_test_records_per_fold(metadata_records)

# %% [markdown]
# ### Inspect Folds

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['speaker_id', 'language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['speaker_id', 'language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', '_language_independent'), 75)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 0 -- TEST
# 	(('s004', 'maninka'), 54)
# 	(('s005', 'susu'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'susu'), 54)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 1 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'susu'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 1 -- TEST
# 	(('s001', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s030', 'francais'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s033', 'susu'), 60)
# ---------------------
# Fold 2 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', 'francais'), 54)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 2 -- TEST
# 	(('s002', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s033', '_language_independent'), 75)
# ---------------------
# Fold 3 -- TRAIN
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', 'susu'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 3 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s006', 'maninka'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s029', 'francais'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 4 -- TRAIN
# 	(('s001', 'susu'), 54)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'susu'), 54)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'susu'), 60)
# Fold 4 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN: ({len(train_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST: ({len(test_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN: (6018)
# 	(('_language_independent',), 2400)
# 	(('francais',), 738)
# 	(('maninka',), 960)
# 	(('pular',), 852)
# 	(('susu',), 1068)
# Fold 0 -- TEST: (2241)
# 	(('_language_independent',), 672)
# 	(('francais',), 522)
# 	(('maninka',), 396)
# 	(('pular',), 57)
# 	(('susu',), 594)
# ---------------------
# Fold 1 -- TRAIN: (5940)
# 	(('_language_independent',), 2325)
# 	(('francais',), 978)
# 	(('maninka',), 906)
# 	(('pular',), 519)
# 	(('susu',), 1212)
# Fold 1 -- TEST: (2319)
# 	(('_language_independent',), 747)
# 	(('francais',), 282)
# 	(('maninka',), 450)
# 	(('pular',), 390)
# 	(('susu',), 450)
# ---------------------
# Fold 2 -- TRAIN: (6036)
# 	(('_language_independent',), 2397)
# 	(('francais',), 972)
# 	(('maninka',), 912)
# 	(('pular',), 573)
# 	(('susu',), 1182)
# Fold 2 -- TEST: (2223)
# 	(('_language_independent',), 675)
# 	(('francais',), 288)
# 	(('maninka',), 444)
# 	(('pular',), 336)
# 	(('susu',), 480)
# ---------------------
# Fold 3 -- TRAIN: (5796)
# 	(('_language_independent',), 2097)
# 	(('francais',), 918)
# 	(('maninka',), 912)
# 	(('pular',), 801)
# 	(('susu',), 1068)
# Fold 3 -- TEST: (2463)
# 	(('_language_independent',), 975)
# 	(('francais',), 342)
# 	(('maninka',), 444)
# 	(('pular',), 108)
# 	(('susu',), 594)
# ---------------------
# Fold 4 -- TRAIN: (6003)
# 	(('_language_independent',), 2325)
# 	(('francais',), 924)
# 	(('maninka',), 906)
# 	(('pular',), 558)
# 	(('susu',), 1290)
# Fold 4 -- TEST: (2256)
# 	(('_language_independent',), 747)
# 	(('francais',), 336)
# 	(('maninka',), 450)
# 	(('pular',), 351)
# 	(('susu',), 372)
# ---------------------

# %% [markdown]
# ## Load Features

# %%
def load_features(records, feature_name):
    features_list = []
    
    features_input_dir = BASE_DIR / feature_name

    for r in records:
        feature_file_name = r['file'].replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            
            padded_features = np.zeros((MAX_FEATURE_SEQUENCE_LENGTH, 512), dtype=features.dtype)
            padded_features[:features_shape[0], :] = features
            
            
            features_list.append(padded_features)
    return features_list

# %%
def get_bias_category_labels(records):
    bias_category_labels = {}
    
    for cat in bias_categories:
        for cat_val in bias_categories[cat]:
            bias_category_labels[f"{cat}__{cat_val}"] = [1 if r[cat]==cat_val else 0 for r in records]
            
    return bias_category_labels

# %% [markdown]
# # Classification Models

# %%
class ASRCNN(nn.Module):
    def __init__(self, 
                 conv_pooling_type, 
                 conv_dropout_p, 
                 fc_dropout_p, 
                 voice_cmd_neuron_count, 
                 voice_cmd_lng_neuron_count,
                 objective_type
                ):
        
        super(ASRCNN, self).__init__()
        
        if conv_pooling_type not in {"max", "avg"}:
            raise ValueError(f"Unknown Conv Pooling Type: {conv_pooling_type}")
            
        conv_pooling_class_by_type = {
            "max": nn.MaxPool1d,
            "avg": nn.AvgPool1d,
        }
        
        conv_pooling_class = conv_pooling_class_by_type[conv_pooling_type]
        
        self.objective_type = objective_type
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=8, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=3)
        self.drop1 = nn.Dropout(p=conv_dropout_p)
        self.pool1 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=8, out_channels=16, kernel_size=3)
        self.drop2 = nn.Dropout(p=conv_dropout_p)
        self.pool2 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3)
        self.drop3 = nn.Dropout(p=conv_dropout_p)
        self.pool3 = conv_pooling_class(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3)
        self.drop4 = nn.Dropout(p=conv_dropout_p)
        self.pool4 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)
        
        self.lin61 = nn.Linear(in_features=112, out_features=voice_cmd_neuron_count)
        
        # 'voice_cmd', 'voice_cmd__and__voice_cmd_lng'
        if self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            self.lin62 = nn.Linear(in_features=112, out_features=voice_cmd_lng_neuron_count)
                
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        if self.objective_type == 'voice_cmd':
            logits_voice_cmd = self.lin61(v)
            return logits_voice_cmd
        elif self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd = self.lin61(v)
            logits_voice_cmd_lng = self.lin62(v)
            return logits_voice_cmd, logits_voice_cmd_lng
        else:
            raise(f"Unknown objective type: {self.objective_type}")

# %%
def get_data_for_fold(fold_id, feature_name):
    
    train_records = records_per_fold[fold_id]["train_records"]
    test_records = records_per_fold[fold_id]["test_records"]
    
    train_features = load_features(train_records, feature_name)
    test_features = load_features(test_records, feature_name)
    
    train_x = np.array(train_features)
    test_x = np.array(test_features)
    
    train_y = {}
    train_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in train_records])
    train_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in train_records])
    train_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in train_records])
    train_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in train_records])
    
    

    
    test_y = {}
    test_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in test_records])
    test_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in test_records])
    test_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in test_records])
    test_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in test_records])

    train_bias_category_labels = get_bias_category_labels(train_records)
    test_bias_category_labels = get_bias_category_labels(test_records)
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y['voice_cmd']),
        torch.tensor(train_y['voice_cmd_lng']),
        # torch.tensor(train_y['spkr_mothertongue']),
        # torch.tensor(train_y['spkr_gender']),
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y['voice_cmd']),
        torch.tensor(test_y['voice_cmd_lng']),
        # torch.tensor(test_y['spkr_mothertongue']),
        # torch.tensor(test_y['spkr_gender']),
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
def train(model, optimizer, criterion, objective_type, train_loader):
    model.train()
    train_loss = 0

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(train_loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        optimizer.zero_grad()
        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs
            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs    
            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) / 2
            
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        

def test(model, criterion, objective_type, loader, bias_category_labels):
    model.eval()
    accumulated_loss = 0

    pred_classes = []
    true_classes = []

    pred_classes_lng = []
    true_classes_lng = []

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs

            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs
            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            pred_classes_lng.extend(
                get_predictions_for_logits(logits_voice_cmd_lng).cpu().numpy()
            )
            true_classes_lng.extend(y_voice_cmd_lng.cpu().numpy())

            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) /2
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        accumulated_loss += loss.item()

    n = len(true_classes)

    average_loss = accumulated_loss/n
    
    acc = sklearn.metrics.accuracy_score(true_classes, pred_classes)
    acc_by_bais_category = {
        category: sklearn.metrics.accuracy_score(true_classes, pred_classes, sample_weight=sw)
        for category, sw in bias_category_labels.items()
    }
    
    
    if objective_type == 'voice_cmd__and__voice_cmd_lng':
        acc_lng = sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng)
        acc_by_bais_category_lng = {
            category: sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng, sample_weight=sw)
            for category, sw in bias_category_labels.items()
        }
    else:
        acc_lng = -1
        acc_by_bais_category_lng = {
            category: -1
            for category, sw in bias_category_labels.items()
        }
        
    return n, average_loss, acc, acc_by_bais_category, acc_lng, acc_by_bais_category_lng
      
        
def train_on_fold(model, fold_id, feature_name, objective_type, batch_size, epochs):
    torch.manual_seed(0)
    results = {}
    
    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model, torch.zeros((10, MAX_FEATURE_SEQUENCE_LENGTH, 512)).to(device), show_input=False))
    print(f"train_n: {len(train_loader.dataset)}")
    print(f"test_n: {len(test_loader.dataset)}")

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(reduction='sum')

    for epoch in range(1, epochs+1):
        
        # train on training set
        train(model, optimizer, criterion, objective_type, train_loader)
        
        # test on training set
        train_n, train_average_loss, train_acc, train_acc_by_bais_category, train_acc_lng, train_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, train_loader, train_bias_category_labels)
        
        # test on test set
        test_n, test_average_loss, test_acc, test_acc_by_bais_category, test_acc_lng, test_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, test_loader, test_bias_category_labels)
        

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_average_loss:0.4}. Test Loss: {test_average_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
         
        results[epoch] = {
            'epoch': epoch,
            
            'train_n': train_n,
            'train_loss': train_average_loss,
            'train_acc': train_acc,
            'train_acc_lng': train_acc_lng,
            
            'test_n': test_n,
            'test_loss': test_average_loss,
            'test_acc': test_acc,
            'test_acc_lng': test_acc_lng
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in train_acc_by_bais_category_lng:
            results[epoch][f"train_acc_lng_{c}"] = train_acc_by_bais_category_lng[c]
            
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))

        for c in test_acc_by_bais_category_lng:
            results[epoch][f"test_acc_lng_{c}"] = test_acc_by_bais_category_lng[c]
            

    return results

# %%
import csv
from pathlib import Path

def results_exist(model_name, feature_name, fold_id):
    fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_id}.csv"
    return Path(fname).is_file()
    
    

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='raise')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
trial_params = list(
    itertools.product(
        range(FOLD_COUNT),
        CONV_POOLING_TYPES,
        CONV_DROPOUT_PROBABILITIES,
        FC_DROPOUT_PROBABILITIES,
        FEATURE_NAMES, 
        OBJECTIVE_TYPES
    )
)    

print("Plan:")
_ = [print(t) for t in trial_params]
print()

for fold_id, conv_pooling_type, conv_dropout_p, fc_dropout_p, feature_name, objective_type in trial_params:

    model_name = f"ASRCNN" + \
    f"__conv_pool_{conv_pooling_type}" + \
    f"__conv_dp_{conv_dropout_p}" + \
    f"__fc_dp_{fc_dropout_p}" + \
    f"__fn_{feature_name}" + \
    f"__obj_{objective_type}"
    
    if results_exist(model_name, feature_name, fold_id):
        print(f"skipping ({fold_id}, {conv_pooling_type}, {conv_dropout_p}, {fc_dropout_p}, {feature_name}, {objective_type})")
        continue
    
    model = ASRCNN(
        conv_pooling_type, 
        conv_dropout_p, 
        fc_dropout_p, 
        voice_cmd_neuron_count = voice_cmd_class_count, 
        voice_cmd_lng_neuron_count = voice_cmd_lng_class_count,
        objective_type = objective_type
    ).to(device)

    print(f"{model_name} using {feature_name} on fold#{fold_id}")

    epochs_results = train_on_fold(
        model, 
        fold_id, 
        feature_name, 
        objective_type, 
        batch_size = BATCH_SIZE, 
        epochs = EPOCHS
    )

    # results for only one fold
    folds_results = [{
        'fold_index': fold_id,
        'feature_name': feature_name,
        'epochs': epochs_results
    }]
    
    
    save_results(model_name, folds_results)
    # write_epoch_test_logits(model_name, all_folds_results)

    del model
# Out:
# Plan:
# (0, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (0, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (0, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (0, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (0, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (0, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (1, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (1, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (1, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (1, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (2, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (2, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (2, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (2, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (3, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (3, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (3, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (3, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd')
# (4, 'avg', 0.1, 0.1, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd')
# (4, 'avg', 0.1, 0.1, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd')
# (4, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd')
# (4, 'avg', 0.1, 0.1, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
#
# ASRCNN__conv_pool_avg__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-c__obj_voice_cmd using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.292. Test Loss: 3.464. Train Acc: 0.1522. Test Acc:0.1267
# Epoch: 20. Train Loss: 2.638. Test Loss: 2.89. Train Acc: 0.3109. Test Acc:0.2535
# Epoch: 30. Train Loss: 2.138. Test Loss: 2.468. Train Acc: 0.4377. Test Acc:0.3521
# Epoch: 40. Train Loss: 1.786. Test Loss: 2.2. Train Acc: 0.5256. Test Acc:0.423
# Epoch: 50. Train Loss: 1.512. Test Loss: 1.964. Train Acc: 0.599. Test Acc:0.4788
# Epoch: 60. Train Loss: 1.302. Test Loss: 1.77. Train Acc: 0.6585. Test Acc:0.5261
# Epoch: 70. Train Loss: 1.12. Test Loss: 1.606. Train Acc: 0.7109. Test Acc:0.573
# Epoch: 80. Train Loss: 0.9847. Test Loss: 1.501. Train Acc: 0.7474. Test Acc:0.5984
# Epoch: 90. Train Loss: 0.8957. Test Loss: 1.413. Train Acc: 0.7689. Test Acc:0.6207
# Epoch: 100. Train Loss: 0.8007. Test Loss: 1.357. Train Acc: 0.7963. Test Acc:0.6372
# Epoch: 110. Train Loss: 0.7347. Test Loss: 1.316. Train Acc: 0.8119. Test Acc:0.647
# Epoch: 120. Train Loss: 0.6686. Test Loss: 1.286. Train Acc: 0.8323. Test Acc:0.66
# Epoch: 130. Train Loss: 0.615. Test Loss: 1.256. Train Acc: 0.847. Test Acc:0.6702
# Epoch: 140. Train Loss: 0.573. Test Loss: 1.226. Train Acc: 0.8589. Test Acc:0.6809
# Epoch: 150. Train Loss: 0.525. Test Loss: 1.2. Train Acc: 0.8724. Test Acc:0.6912
# Epoch: 160. Train Loss: 0.4894. Test Loss: 1.172. Train Acc: 0.8825. Test Acc:0.6992
# Epoch: 170. Train Loss: 0.4552. Test Loss: 1.154. Train Acc: 0.8937. Test Acc:0.7077
# Epoch: 180. Train Loss: 0.4147. Test Loss: 1.137. Train Acc: 0.9023. Test Acc:0.7166
# Epoch: 190. Train Loss: 0.3834. Test Loss: 1.106. Train Acc: 0.9156. Test Acc:0.7291
# Epoch: 200. Train Loss: 0.3659. Test Loss: 1.107. Train Acc: 0.9179. Test Acc:0.7336
# Epoch: 210. Train Loss: 0.3315. Test Loss: 1.074. Train Acc: 0.9279. Test Acc:0.7367
# Epoch: 220. Train Loss: 0.3072. Test Loss: 1.076. Train Acc: 0.9325. Test Acc:0.7385
# Epoch: 230. Train Loss: 0.2861. Test Loss: 1.052. Train Acc: 0.9374. Test Acc:0.747
# Epoch: 240. Train Loss: 0.2669. Test Loss: 1.055. Train Acc: 0.9417. Test Acc:0.7519
# Epoch: 250. Train Loss: 0.2444. Test Loss: 1.038. Train Acc: 0.947. Test Acc:0.7586
# Epoch: 260. Train Loss: 0.2375. Test Loss: 1.04. Train Acc: 0.9462. Test Acc:0.7626
# Epoch: 270. Train Loss: 0.2128. Test Loss: 1.041. Train Acc: 0.9533. Test Acc:0.7586
# Epoch: 280. Train Loss: 0.2027. Test Loss: 1.034. Train Acc: 0.9538. Test Acc:0.7639
# Epoch: 290. Train Loss: 0.1907. Test Loss: 1.045. Train Acc: 0.9566. Test Acc:0.7639
# Epoch: 300. Train Loss: 0.173. Test Loss: 1.052. Train Acc: 0.9626. Test Acc:0.768
# Epoch: 310. Train Loss: 0.1654. Test Loss: 1.06. Train Acc: 0.9626. Test Acc:0.7622
# Epoch: 320. Train Loss: 0.1557. Test Loss: 1.053. Train Acc: 0.9639. Test Acc:0.7648
# Epoch: 330. Train Loss: 0.143. Test Loss: 1.068. Train Acc: 0.9684. Test Acc:0.7662
# Epoch: 340. Train Loss: 0.137. Test Loss: 1.067. Train Acc: 0.9686. Test Acc:0.7684
# Epoch: 350. Train Loss: 0.1287. Test Loss: 1.074. Train Acc: 0.9688. Test Acc:0.7671
# Epoch: 360. Train Loss: 0.1217. Test Loss: 1.064. Train Acc: 0.9714. Test Acc:0.7689
# Epoch: 370. Train Loss: 0.1117. Test Loss: 1.102. Train Acc: 0.9731. Test Acc:0.7738
# Epoch: 380. Train Loss: 0.1096. Test Loss: 1.087. Train Acc: 0.9726. Test Acc:0.7738
# Epoch: 390. Train Loss: 0.1016. Test Loss: 1.117. Train Acc: 0.9764. Test Acc:0.7702
# Epoch: 400. Train Loss: 0.09814. Test Loss: 1.105. Train Acc: 0.9766. Test Acc:0.776
# Epoch: 410. Train Loss: 0.08813. Test Loss: 1.142. Train Acc: 0.9779. Test Acc:0.7751
# Epoch: 420. Train Loss: 0.1074. Test Loss: 1.228. Train Acc: 0.9714. Test Acc:0.7653
# Epoch: 430. Train Loss: 0.07675. Test Loss: 1.114. Train Acc: 0.9832. Test Acc:0.7769
# Epoch: 440. Train Loss: 0.07764. Test Loss: 1.119. Train Acc: 0.9824. Test Acc:0.7809
# Epoch: 450. Train Loss: 0.06693. Test Loss: 1.12. Train Acc: 0.9842. Test Acc:0.7849
# Epoch: 460. Train Loss: 0.06146. Test Loss: 1.125. Train Acc: 0.9867. Test Acc:0.7796
# Epoch: 470. Train Loss: 0.05545. Test Loss: 1.136. Train Acc: 0.9894. Test Acc:0.7764
# Epoch: 480. Train Loss: 0.05112. Test Loss: 1.151. Train Acc: 0.9894. Test Acc:0.7813
# Epoch: 490. Train Loss: 0.04693. Test Loss: 1.146. Train Acc: 0.9915. Test Acc:0.7822
# Epoch: 500. Train Loss: 0.0486. Test Loss: 1.172. Train Acc: 0.9907. Test Acc:0.7796
# Epoch: 510. Train Loss: 0.04207. Test Loss: 1.142. Train Acc: 0.9934. Test Acc:0.78
# Epoch: 520. Train Loss: 0.04026. Test Loss: 1.186. Train Acc: 0.9922. Test Acc:0.7813
# Epoch: 530. Train Loss: 0.0385. Test Loss: 1.175. Train Acc: 0.9937. Test Acc:0.7813
# Epoch: 540. Train Loss: 0.03469. Test Loss: 1.187. Train Acc: 0.9942. Test Acc:0.7791
# Epoch: 550. Train Loss: 0.03437. Test Loss: 1.16. Train Acc: 0.9944. Test Acc:0.7854
# Epoch: 560. Train Loss: 0.03132. Test Loss: 1.201. Train Acc: 0.995. Test Acc:0.784
# Epoch: 570. Train Loss: 0.02988. Test Loss: 1.197. Train Acc: 0.9957. Test Acc:0.7805
# Epoch: 580. Train Loss: 0.03194. Test Loss: 1.211. Train Acc: 0.9945. Test Acc:0.7849
# Epoch: 590. Train Loss: 0.02586. Test Loss: 1.224. Train Acc: 0.9963. Test Acc:0.7822
# Epoch: 600. Train Loss: 0.0257. Test Loss: 1.226. Train Acc: 0.9952. Test Acc:0.7782
# Epoch: 610. Train Loss: 0.02345. Test Loss: 1.226. Train Acc: 0.9963. Test Acc:0.7755
# Epoch: 620. Train Loss: 0.02391. Test Loss: 1.228. Train Acc: 0.997. Test Acc:0.7809
# Epoch: 630. Train Loss: 0.02012. Test Loss: 1.247. Train Acc: 0.998. Test Acc:0.7791
# Epoch: 640. Train Loss: 0.01927. Test Loss: 1.23. Train Acc: 0.9982. Test Acc:0.7854
# Epoch: 650. Train Loss: 0.01848. Test Loss: 1.265. Train Acc: 0.9982. Test Acc:0.7773
# Epoch: 660. Train Loss: 0.01643. Test Loss: 1.25. Train Acc: 0.9982. Test Acc:0.7827
# Epoch: 670. Train Loss: 0.01877. Test Loss: 1.282. Train Acc: 0.9977. Test Acc:0.7733
# Epoch: 680. Train Loss: 0.01582. Test Loss: 1.255. Train Acc: 0.9985. Test Acc:0.7836
# Epoch: 690. Train Loss: 0.01656. Test Loss: 1.281. Train Acc: 0.9978. Test Acc:0.7796
# Epoch: 700. Train Loss: 0.01781. Test Loss: 1.259. Train Acc: 0.9977. Test Acc:0.7791
# Epoch: 710. Train Loss: 0.01396. Test Loss: 1.272. Train Acc: 0.9985. Test Acc:0.78
# Epoch: 720. Train Loss: 0.0143. Test Loss: 1.279. Train Acc: 0.9987. Test Acc:0.7845
# Epoch: 730. Train Loss: 0.01187. Test Loss: 1.268. Train Acc: 0.9992. Test Acc:0.7831
# Epoch: 740. Train Loss: 0.01237. Test Loss: 1.289. Train Acc: 0.9988. Test Acc:0.7894
# Epoch: 750. Train Loss: 0.01101. Test Loss: 1.292. Train Acc: 0.9987. Test Acc:0.7863
# Epoch: 760. Train Loss: 0.009649. Test Loss: 1.308. Train Acc: 0.9995. Test Acc:0.7876
# Epoch: 770. Train Loss: 0.01155. Test Loss: 1.319. Train Acc: 0.999. Test Acc:0.7764
# Epoch: 780. Train Loss: 0.009576. Test Loss: 1.321. Train Acc: 0.9993. Test Acc:0.7787
# Epoch: 790. Train Loss: 0.009496. Test Loss: 1.317. Train Acc: 0.9993. Test Acc:0.7791
# Epoch: 800. Train Loss: 0.009078. Test Loss: 1.302. Train Acc: 0.9995. Test Acc:0.7871
# Epoch: 810. Train Loss: 0.008963. Test Loss: 1.354. Train Acc: 0.9992. Test Acc:0.7791
# Epoch: 820. Train Loss: 0.007658. Test Loss: 1.339. Train Acc: 1.0. Test Acc:0.7818
# Epoch: 830. Train Loss: 0.007947. Test Loss: 1.321. Train Acc: 0.9993. Test Acc:0.7871
# Epoch: 840. Train Loss: 0.007525. Test Loss: 1.338. Train Acc: 0.9993. Test Acc:0.7831
# Epoch: 850. Train Loss: 0.007144. Test Loss: 1.357. Train Acc: 0.9997. Test Acc:0.7822
# Epoch: 860. Train Loss: 0.0065. Test Loss: 1.343. Train Acc: 0.9998. Test Acc:0.7822
# Epoch: 870. Train Loss: 0.007674. Test Loss: 1.352. Train Acc: 0.9993. Test Acc:0.7827
# Epoch: 880. Train Loss: 0.008579. Test Loss: 1.36. Train Acc: 0.9995. Test Acc:0.7773
# Epoch: 890. Train Loss: 0.006104. Test Loss: 1.375. Train Acc: 0.9997. Test Acc:0.7845
# Epoch: 900. Train Loss: 0.006608. Test Loss: 1.37. Train Acc: 1.0. Test Acc:0.776
# Epoch: 910. Train Loss: 0.006886. Test Loss: 1.369. Train Acc: 0.9997. Test Acc:0.7787
# Epoch: 920. Train Loss: 0.005195. Test Loss: 1.379. Train Acc: 0.9998. Test Acc:0.7867
# Epoch: 930. Train Loss: 0.005195. Test Loss: 1.365. Train Acc: 1.0. Test Acc:0.7805
# Epoch: 940. Train Loss: 0.00475. Test Loss: 1.368. Train Acc: 1.0. Test Acc:0.7831
# Epoch: 950. Train Loss: 0.004136. Test Loss: 1.377. Train Acc: 1.0. Test Acc:0.7822
# Epoch: 960. Train Loss: 0.005645. Test Loss: 1.371. Train Acc: 0.9998. Test Acc:0.7822
# Epoch: 970. Train Loss: 0.006596. Test Loss: 1.371. Train Acc: 0.9995. Test Acc:0.7827
# Epoch: 980. Train Loss: 0.003963. Test Loss: 1.39. Train Acc: 1.0. Test Acc:0.7769
# Epoch: 990. Train Loss: 0.004628. Test Loss: 1.402. Train Acc: 1.0. Test Acc:0.7791
# Epoch: 1000. Train Loss: 0.005226. Test Loss: 1.393. Train Acc: 1.0. Test Acc:0.7889
# ASRCNN__conv_pool_avg__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.397. Test Loss: 2.577. Train Acc: 0.1311. Test Acc:0.09371
# Epoch: 20. Train Loss: 2.027. Test Loss: 2.229. Train Acc: 0.2733. Test Acc:0.2231
# Epoch: 30. Train Loss: 1.755. Test Loss: 1.977. Train Acc: 0.3965. Test Acc:0.3266
# Epoch: 40. Train Loss: 1.535. Test Loss: 1.803. Train Acc: 0.496. Test Acc:0.3954
# Epoch: 50. Train Loss: 1.33. Test Loss: 1.631. Train Acc: 0.5864. Test Acc:0.4797
# Epoch: 60. Train Loss: 1.179. Test Loss: 1.527. Train Acc: 0.6557. Test Acc:0.5328
# Epoch: 70. Train Loss: 1.063. Test Loss: 1.44. Train Acc: 0.7084. Test Acc:0.5739
# Epoch: 80. Train Loss: 0.9619. Test Loss: 1.344. Train Acc: 0.7444. Test Acc:0.5988
# Epoch: 90. Train Loss: 0.8731. Test Loss: 1.259. Train Acc: 0.7767. Test Acc:0.622
# Epoch: 100. Train Loss: 0.8108. Test Loss: 1.216. Train Acc: 0.7998. Test Acc:0.6332
# Epoch: 110. Train Loss: 0.7605. Test Loss: 1.157. Train Acc: 0.8169. Test Acc:0.6457
# Epoch: 120. Train Loss: 0.7114. Test Loss: 1.131. Train Acc: 0.8335. Test Acc:0.6542
# Epoch: 130. Train Loss: 0.6681. Test Loss: 1.107. Train Acc: 0.8506. Test Acc:0.6658
# Epoch: 140. Train Loss: 0.6352. Test Loss: 1.068. Train Acc: 0.8556. Test Acc:0.6689
# Epoch: 150. Train Loss: 0.5963. Test Loss: 1.053. Train Acc: 0.8696. Test Acc:0.6729
# Epoch: 160. Train Loss: 0.5705. Test Loss: 1.024. Train Acc: 0.8762. Test Acc:0.6899
# Epoch: 170. Train Loss: 0.5415. Test Loss: 1.025. Train Acc: 0.8848. Test Acc:0.6939
# Epoch: 180. Train Loss: 0.51. Test Loss: 0.9899. Train Acc: 0.892. Test Acc:0.7059
# Epoch: 190. Train Loss: 0.483. Test Loss: 0.9815. Train Acc: 0.9013. Test Acc:0.7113
# Epoch: 200. Train Loss: 0.4621. Test Loss: 0.9682. Train Acc: 0.9068. Test Acc:0.7198
# Epoch: 210. Train Loss: 0.437. Test Loss: 0.9623. Train Acc: 0.9141. Test Acc:0.7153
# Epoch: 220. Train Loss: 0.4185. Test Loss: 0.9584. Train Acc: 0.9207. Test Acc:0.722
# Epoch: 230. Train Loss: 0.4018. Test Loss: 0.9662. Train Acc: 0.9209. Test Acc:0.7251
# Epoch: 240. Train Loss: 0.381. Test Loss: 0.9364. Train Acc: 0.9262. Test Acc:0.73
# Epoch: 250. Train Loss: 0.368. Test Loss: 0.9396. Train Acc: 0.9276. Test Acc:0.7332
# Epoch: 260. Train Loss: 0.3497. Test Loss: 0.937. Train Acc: 0.9315. Test Acc:0.7305
# Epoch: 270. Train Loss: 0.3354. Test Loss: 0.9361. Train Acc: 0.9349. Test Acc:0.7314
# Epoch: 280. Train Loss: 0.3195. Test Loss: 0.9346. Train Acc: 0.9408. Test Acc:0.7372
# Epoch: 290. Train Loss: 0.3077. Test Loss: 0.936. Train Acc: 0.9397. Test Acc:0.7381
# Epoch: 300. Train Loss: 0.2958. Test Loss: 0.9508. Train Acc: 0.943. Test Acc:0.7363
# Epoch: 310. Train Loss: 0.287. Test Loss: 0.9442. Train Acc: 0.9455. Test Acc:0.7394
# Epoch: 320. Train Loss: 0.2631. Test Loss: 0.9233. Train Acc: 0.9518. Test Acc:0.7456
# Epoch: 330. Train Loss: 0.2507. Test Loss: 0.9314. Train Acc: 0.9548. Test Acc:0.7421
# Epoch: 340. Train Loss: 0.2463. Test Loss: 0.9198. Train Acc: 0.9556. Test Acc:0.7425
# Epoch: 350. Train Loss: 0.2304. Test Loss: 0.9349. Train Acc: 0.9588. Test Acc:0.7443
# Epoch: 360. Train Loss: 0.221. Test Loss: 0.9351. Train Acc: 0.9611. Test Acc:0.7532
# Epoch: 370. Train Loss: 0.2155. Test Loss: 0.9871. Train Acc: 0.9628. Test Acc:0.7425
# Epoch: 380. Train Loss: 0.2139. Test Loss: 0.9446. Train Acc: 0.9621. Test Acc:0.7443
# Epoch: 390. Train Loss: 0.1985. Test Loss: 0.9536. Train Acc: 0.9631. Test Acc:0.7501
# Epoch: 400. Train Loss: 0.1865. Test Loss: 0.9607. Train Acc: 0.9676. Test Acc:0.7528
# Epoch: 410. Train Loss: 0.1797. Test Loss: 0.9603. Train Acc: 0.9693. Test Acc:0.7555
# Epoch: 420. Train Loss: 0.1702. Test Loss: 0.9713. Train Acc: 0.9704. Test Acc:0.7515
# Epoch: 430. Train Loss: 0.1655. Test Loss: 0.9367. Train Acc: 0.9724. Test Acc:0.7564
# Epoch: 440. Train Loss: 0.1567. Test Loss: 0.958. Train Acc: 0.9714. Test Acc:0.7537
# Epoch: 450. Train Loss: 0.1505. Test Loss: 0.9602. Train Acc: 0.9749. Test Acc:0.7581
# Epoch: 460. Train Loss: 0.1442. Test Loss: 0.9898. Train Acc: 0.9739. Test Acc:0.7515
# Epoch: 470. Train Loss: 0.1374. Test Loss: 0.9719. Train Acc: 0.9766. Test Acc:0.7523
# Epoch: 480. Train Loss: 0.1342. Test Loss: 0.9543. Train Acc: 0.9782. Test Acc:0.7581
# Epoch: 490. Train Loss: 0.1276. Test Loss: 1.001. Train Acc: 0.9791. Test Acc:0.755
# Epoch: 500. Train Loss: 0.1196. Test Loss: 0.984. Train Acc: 0.9792. Test Acc:0.7581
# Epoch: 510. Train Loss: 0.1199. Test Loss: 1.041. Train Acc: 0.9792. Test Acc:0.747
# Epoch: 520. Train Loss: 0.1094. Test Loss: 0.9997. Train Acc: 0.9835. Test Acc:0.7555
# Epoch: 530. Train Loss: 0.1135. Test Loss: 0.9735. Train Acc: 0.9801. Test Acc:0.7604
# Epoch: 540. Train Loss: 0.106. Test Loss: 1.029. Train Acc: 0.9819. Test Acc:0.7581
# Epoch: 550. Train Loss: 0.1014. Test Loss: 1.015. Train Acc: 0.9814. Test Acc:0.7497
# Epoch: 560. Train Loss: 0.09496. Test Loss: 1.045. Train Acc: 0.9844. Test Acc:0.7515
# Epoch: 570. Train Loss: 0.09022. Test Loss: 1.02. Train Acc: 0.9872. Test Acc:0.7617
# Epoch: 580. Train Loss: 0.09548. Test Loss: 1.074. Train Acc: 0.9837. Test Acc:0.7537
# Epoch: 590. Train Loss: 0.09394. Test Loss: 1.102. Train Acc: 0.9845. Test Acc:0.7488
# Epoch: 600. Train Loss: 0.08371. Test Loss: 1.066. Train Acc: 0.9857. Test Acc:0.7559
# Epoch: 610. Train Loss: 0.08212. Test Loss: 1.094. Train Acc: 0.9874. Test Acc:0.7537
# Epoch: 620. Train Loss: 0.07827. Test Loss: 1.098. Train Acc: 0.9869. Test Acc:0.7515
# Epoch: 630. Train Loss: 0.07219. Test Loss: 1.086. Train Acc: 0.989. Test Acc:0.7506
# Epoch: 640. Train Loss: 0.07157. Test Loss: 1.151. Train Acc: 0.9887. Test Acc:0.7501
# Epoch: 650. Train Loss: 0.07146. Test Loss: 1.16. Train Acc: 0.9889. Test Acc:0.7483
# Epoch: 660. Train Loss: 0.07262. Test Loss: 1.177. Train Acc: 0.9892. Test Acc:0.7403
# Epoch: 670. Train Loss: 0.06928. Test Loss: 1.138. Train Acc: 0.9894. Test Acc:0.7546
# Epoch: 680. Train Loss: 0.06692. Test Loss: 1.125. Train Acc: 0.99. Test Acc:0.751
# Epoch: 690. Train Loss: 0.06249. Test Loss: 1.087. Train Acc: 0.9895. Test Acc:0.7559
# Epoch: 700. Train Loss: 0.06755. Test Loss: 1.177. Train Acc: 0.988. Test Acc:0.7492
# Epoch: 710. Train Loss: 0.0684. Test Loss: 1.144. Train Acc: 0.9874. Test Acc:0.7532
# Epoch: 720. Train Loss: 0.07081. Test Loss: 1.211. Train Acc: 0.9867. Test Acc:0.747
# Epoch: 730. Train Loss: 0.05768. Test Loss: 1.073. Train Acc: 0.9902. Test Acc:0.7595
# Epoch: 740. Train Loss: 0.05285. Test Loss: 1.068. Train Acc: 0.992. Test Acc:0.7653
# Epoch: 750. Train Loss: 0.05357. Test Loss: 1.043. Train Acc: 0.9887. Test Acc:0.7608
# Epoch: 760. Train Loss: 0.04794. Test Loss: 1.079. Train Acc: 0.9927. Test Acc:0.7653
# Epoch: 770. Train Loss: 0.04573. Test Loss: 1.084. Train Acc: 0.9944. Test Acc:0.7675
# Epoch: 780. Train Loss: 0.04369. Test Loss: 1.103. Train Acc: 0.9948. Test Acc:0.7639
# Epoch: 790. Train Loss: 0.04304. Test Loss: 1.078. Train Acc: 0.9948. Test Acc:0.7666
# Epoch: 800. Train Loss: 0.04004. Test Loss: 1.106. Train Acc: 0.9952. Test Acc:0.7635
# Epoch: 810. Train Loss: 0.03973. Test Loss: 1.118. Train Acc: 0.9952. Test Acc:0.7608
# Epoch: 820. Train Loss: 0.03936. Test Loss: 1.14. Train Acc: 0.9962. Test Acc:0.7599
# Epoch: 830. Train Loss: 0.03846. Test Loss: 1.148. Train Acc: 0.9957. Test Acc:0.7581
# Epoch: 840. Train Loss: 0.03656. Test Loss: 1.111. Train Acc: 0.9953. Test Acc:0.7613
# Epoch: 850. Train Loss: 0.03451. Test Loss: 1.179. Train Acc: 0.9952. Test Acc:0.7581
# Epoch: 860. Train Loss: 0.03386. Test Loss: 1.154. Train Acc: 0.9948. Test Acc:0.7604
# Epoch: 870. Train Loss: 0.03529. Test Loss: 1.24. Train Acc: 0.9955. Test Acc:0.7506
# Epoch: 880. Train Loss: 0.03174. Test Loss: 1.22. Train Acc: 0.9975. Test Acc:0.759
# Epoch: 890. Train Loss: 0.0317. Test Loss: 1.156. Train Acc: 0.9948. Test Acc:0.7653
# Epoch: 900. Train Loss: 0.02916. Test Loss: 1.129. Train Acc: 0.9967. Test Acc:0.7595
# Epoch: 910. Train Loss: 0.02985. Test Loss: 1.181. Train Acc: 0.9965. Test Acc:0.7635
# Epoch: 920. Train Loss: 0.02735. Test Loss: 1.233. Train Acc: 0.998. Test Acc:0.7523
# Epoch: 930. Train Loss: 0.02734. Test Loss: 1.172. Train Acc: 0.9963. Test Acc:0.7586
# Epoch: 940. Train Loss: 0.02637. Test Loss: 1.16. Train Acc: 0.9982. Test Acc:0.755
# Epoch: 950. Train Loss: 0.02547. Test Loss: 1.21. Train Acc: 0.9973. Test Acc:0.7617
# Epoch: 960. Train Loss: 0.02471. Test Loss: 1.266. Train Acc: 0.9978. Test Acc:0.7573
# Epoch: 970. Train Loss: 0.02521. Test Loss: 1.201. Train Acc: 0.9978. Test Acc:0.7523
# Epoch: 980. Train Loss: 0.02761. Test Loss: 1.27. Train Acc: 0.9977. Test Acc:0.7532
# Epoch: 990. Train Loss: 0.02443. Test Loss: 1.183. Train Acc: 0.9963. Test Acc:0.759
# Epoch: 1000. Train Loss: 0.02097. Test Loss: 1.253. Train Acc: 0.9982. Test Acc:0.7599
# ASRCNN__conv_pool_avg__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-z__obj_voice_cmd using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.904. Test Loss: 4.011. Train Acc: 0.07527. Test Acc:0.05712
# Epoch: 20. Train Loss: 3.271. Test Loss: 3.471. Train Acc: 0.1489. Test Acc:0.1156
# Epoch: 30. Train Loss: 2.998. Test Loss: 3.242. Train Acc: 0.2275. Test Acc:0.1794
# Epoch: 40. Train Loss: 2.645. Test Loss: 2.951. Train Acc: 0.3084. Test Acc:0.2477
# Epoch: 50. Train Loss: 2.312. Test Loss: 2.669. Train Acc: 0.3933. Test Acc:0.3097
# Epoch: 60. Train Loss: 2.021. Test Loss: 2.439. Train Acc: 0.4653. Test Acc:0.3677
# Epoch: 70. Train Loss: 1.785. Test Loss: 2.241. Train Acc: 0.5221. Test Acc:0.4132
# Epoch: 80. Train Loss: 1.59. Test Loss: 2.066. Train Acc: 0.5809. Test Acc:0.4645
# Epoch: 90. Train Loss: 1.434. Test Loss: 1.932. Train Acc: 0.6183. Test Acc:0.5025
# Epoch: 100. Train Loss: 1.303. Test Loss: 1.807. Train Acc: 0.6607. Test Acc:0.5301
# Epoch: 110. Train Loss: 1.179. Test Loss: 1.712. Train Acc: 0.6947. Test Acc:0.5591
# Epoch: 120. Train Loss: 1.081. Test Loss: 1.617. Train Acc: 0.724. Test Acc:0.5877
# Epoch: 130. Train Loss: 0.9873. Test Loss: 1.54. Train Acc: 0.7502. Test Acc:0.6082
# Epoch: 140. Train Loss: 0.9066. Test Loss: 1.478. Train Acc: 0.7704. Test Acc:0.6216
# Epoch: 150. Train Loss: 0.8406. Test Loss: 1.428. Train Acc: 0.791. Test Acc:0.6372
# Epoch: 160. Train Loss: 0.7734. Test Loss: 1.363. Train Acc: 0.8091. Test Acc:0.6613
# Epoch: 170. Train Loss: 0.7187. Test Loss: 1.34. Train Acc: 0.823. Test Acc:0.6707
# Epoch: 180. Train Loss: 0.6713. Test Loss: 1.312. Train Acc: 0.8337. Test Acc:0.676
# Epoch: 190. Train Loss: 0.6265. Test Loss: 1.278. Train Acc: 0.8465. Test Acc:0.6921
# Epoch: 200. Train Loss: 0.5786. Test Loss: 1.243. Train Acc: 0.8589. Test Acc:0.7019
# Epoch: 210. Train Loss: 0.5394. Test Loss: 1.215. Train Acc: 0.8709. Test Acc:0.7113
# Epoch: 220. Train Loss: 0.5074. Test Loss: 1.198. Train Acc: 0.8775. Test Acc:0.71
# Epoch: 230. Train Loss: 0.4771. Test Loss: 1.184. Train Acc: 0.8863. Test Acc:0.7207
# Epoch: 240. Train Loss: 0.4482. Test Loss: 1.156. Train Acc: 0.8958. Test Acc:0.7269
# Epoch: 250. Train Loss: 0.4244. Test Loss: 1.155. Train Acc: 0.9056. Test Acc:0.7314
# Epoch: 260. Train Loss: 0.4023. Test Loss: 1.148. Train Acc: 0.9091. Test Acc:0.7318
# Epoch: 270. Train Loss: 0.3824. Test Loss: 1.15. Train Acc: 0.9151. Test Acc:0.7349
# Epoch: 280. Train Loss: 0.3637. Test Loss: 1.148. Train Acc: 0.9191. Test Acc:0.7416
# Epoch: 290. Train Loss: 0.3455. Test Loss: 1.141. Train Acc: 0.9226. Test Acc:0.7412
# Epoch: 300. Train Loss: 0.3284. Test Loss: 1.123. Train Acc: 0.9276. Test Acc:0.7465
# Epoch: 310. Train Loss: 0.3146. Test Loss: 1.105. Train Acc: 0.9307. Test Acc:0.7474
# Epoch: 320. Train Loss: 0.301. Test Loss: 1.145. Train Acc: 0.9339. Test Acc:0.7497
# Epoch: 330. Train Loss: 0.285. Test Loss: 1.126. Train Acc: 0.9384. Test Acc:0.747
# Epoch: 340. Train Loss: 0.2722. Test Loss: 1.124. Train Acc: 0.9389. Test Acc:0.7488
# Epoch: 350. Train Loss: 0.2602. Test Loss: 1.122. Train Acc: 0.9442. Test Acc:0.7506
# Epoch: 360. Train Loss: 0.2532. Test Loss: 1.119. Train Acc: 0.9462. Test Acc:0.7506
# Epoch: 370. Train Loss: 0.2372. Test Loss: 1.113. Train Acc: 0.9478. Test Acc:0.7501
# Epoch: 380. Train Loss: 0.2296. Test Loss: 1.119. Train Acc: 0.9485. Test Acc:0.7564
# Epoch: 390. Train Loss: 0.2151. Test Loss: 1.111. Train Acc: 0.9508. Test Acc:0.7622
# Epoch: 400. Train Loss: 0.2095. Test Loss: 1.119. Train Acc: 0.9541. Test Acc:0.7604
# Epoch: 410. Train Loss: 0.2055. Test Loss: 1.142. Train Acc: 0.9541. Test Acc:0.7546
# Epoch: 420. Train Loss: 0.194. Test Loss: 1.115. Train Acc: 0.9555. Test Acc:0.7604
# Epoch: 430. Train Loss: 0.1825. Test Loss: 1.134. Train Acc: 0.9595. Test Acc:0.7631
# Epoch: 440. Train Loss: 0.1746. Test Loss: 1.153. Train Acc: 0.9593. Test Acc:0.7635
# Epoch: 450. Train Loss: 0.1676. Test Loss: 1.156. Train Acc: 0.9616. Test Acc:0.7666
# Epoch: 460. Train Loss: 0.1608. Test Loss: 1.171. Train Acc: 0.9648. Test Acc:0.7581
# Epoch: 470. Train Loss: 0.154. Test Loss: 1.172. Train Acc: 0.9638. Test Acc:0.759
# Epoch: 480. Train Loss: 0.1467. Test Loss: 1.181. Train Acc: 0.9658. Test Acc:0.7631
# Epoch: 490. Train Loss: 0.143. Test Loss: 1.188. Train Acc: 0.9681. Test Acc:0.7639
# Epoch: 500. Train Loss: 0.1421. Test Loss: 1.179. Train Acc: 0.9666. Test Acc:0.7635
# Epoch: 510. Train Loss: 0.1358. Test Loss: 1.176. Train Acc: 0.9679. Test Acc:0.7653
# Epoch: 520. Train Loss: 0.1267. Test Loss: 1.181. Train Acc: 0.9689. Test Acc:0.7639
# Epoch: 530. Train Loss: 0.1235. Test Loss: 1.21. Train Acc: 0.9709. Test Acc:0.7648
# Epoch: 540. Train Loss: 0.1162. Test Loss: 1.183. Train Acc: 0.9721. Test Acc:0.7657
# Epoch: 550. Train Loss: 0.1128. Test Loss: 1.214. Train Acc: 0.9742. Test Acc:0.7604
# Epoch: 560. Train Loss: 0.1194. Test Loss: 1.193. Train Acc: 0.9713. Test Acc:0.7622
# Epoch: 570. Train Loss: 0.1055. Test Loss: 1.224. Train Acc: 0.9752. Test Acc:0.7622
# Epoch: 580. Train Loss: 0.09934. Test Loss: 1.234. Train Acc: 0.9766. Test Acc:0.7675
# Epoch: 590. Train Loss: 0.0988. Test Loss: 1.27. Train Acc: 0.9767. Test Acc:0.7586
# Epoch: 600. Train Loss: 0.09259. Test Loss: 1.242. Train Acc: 0.9789. Test Acc:0.7644
# Epoch: 610. Train Loss: 0.08771. Test Loss: 1.24. Train Acc: 0.9802. Test Acc:0.7635
# Epoch: 620. Train Loss: 0.08441. Test Loss: 1.233. Train Acc: 0.9814. Test Acc:0.7666
# Epoch: 630. Train Loss: 0.08204. Test Loss: 1.232. Train Acc: 0.9812. Test Acc:0.7693
# Epoch: 640. Train Loss: 0.0815. Test Loss: 1.24. Train Acc: 0.9809. Test Acc:0.7675
# Epoch: 650. Train Loss: 0.07967. Test Loss: 1.231. Train Acc: 0.9814. Test Acc:0.7653
# Epoch: 660. Train Loss: 0.07682. Test Loss: 1.3. Train Acc: 0.9822. Test Acc:0.7586
# Epoch: 670. Train Loss: 0.07366. Test Loss: 1.271. Train Acc: 0.9826. Test Acc:0.7648
# Epoch: 680. Train Loss: 0.0714. Test Loss: 1.282. Train Acc: 0.9822. Test Acc:0.7662
# Epoch: 690. Train Loss: 0.06597. Test Loss: 1.288. Train Acc: 0.9842. Test Acc:0.772
# Epoch: 700. Train Loss: 0.06362. Test Loss: 1.258. Train Acc: 0.985. Test Acc:0.7675
# Epoch: 710. Train Loss: 0.06028. Test Loss: 1.287. Train Acc: 0.9854. Test Acc:0.7662
# Epoch: 720. Train Loss: 0.05831. Test Loss: 1.301. Train Acc: 0.9862. Test Acc:0.7675
# Epoch: 730. Train Loss: 0.05871. Test Loss: 1.27. Train Acc: 0.9869. Test Acc:0.7666
# Epoch: 740. Train Loss: 0.05571. Test Loss: 1.284. Train Acc: 0.9874. Test Acc:0.7662
# Epoch: 750. Train Loss: 0.0562. Test Loss: 1.337. Train Acc: 0.9885. Test Acc:0.7666
# Epoch: 760. Train Loss: 0.05226. Test Loss: 1.305. Train Acc: 0.9885. Test Acc:0.7604
# Epoch: 770. Train Loss: 0.0489. Test Loss: 1.347. Train Acc: 0.99. Test Acc:0.7604
# Epoch: 780. Train Loss: 0.0478. Test Loss: 1.298. Train Acc: 0.9887. Test Acc:0.7675
# Epoch: 790. Train Loss: 0.04731. Test Loss: 1.313. Train Acc: 0.9894. Test Acc:0.768
# Epoch: 800. Train Loss: 0.04533. Test Loss: 1.327. Train Acc: 0.9905. Test Acc:0.7684
# Epoch: 810. Train Loss: 0.0429. Test Loss: 1.32. Train Acc: 0.9919. Test Acc:0.7675
# Epoch: 820. Train Loss: 0.0419. Test Loss: 1.323. Train Acc: 0.9907. Test Acc:0.7675
# Epoch: 830. Train Loss: 0.04012. Test Loss: 1.321. Train Acc: 0.992. Test Acc:0.7706
# Epoch: 840. Train Loss: 0.04322. Test Loss: 1.306. Train Acc: 0.9907. Test Acc:0.7662
# Epoch: 850. Train Loss: 0.03713. Test Loss: 1.339. Train Acc: 0.9924. Test Acc:0.7724
# Epoch: 860. Train Loss: 0.0371. Test Loss: 1.323. Train Acc: 0.9935. Test Acc:0.768
# Epoch: 870. Train Loss: 0.03611. Test Loss: 1.373. Train Acc: 0.993. Test Acc:0.7675
# Epoch: 880. Train Loss: 0.03546. Test Loss: 1.332. Train Acc: 0.9935. Test Acc:0.7724
# Epoch: 890. Train Loss: 0.0321. Test Loss: 1.381. Train Acc: 0.994. Test Acc:0.7729
# Epoch: 900. Train Loss: 0.03149. Test Loss: 1.407. Train Acc: 0.9937. Test Acc:0.759
# Epoch: 910. Train Loss: 0.03153. Test Loss: 1.339. Train Acc: 0.9948. Test Acc:0.7751
# Epoch: 920. Train Loss: 0.02901. Test Loss: 1.371. Train Acc: 0.9952. Test Acc:0.7689
# Epoch: 930. Train Loss: 0.02865. Test Loss: 1.377. Train Acc: 0.995. Test Acc:0.7724
# Epoch: 940. Train Loss: 0.02867. Test Loss: 1.351. Train Acc: 0.9957. Test Acc:0.7693
# Epoch: 950. Train Loss: 0.02757. Test Loss: 1.389. Train Acc: 0.9957. Test Acc:0.7755
# Epoch: 960. Train Loss: 0.02811. Test Loss: 1.408. Train Acc: 0.9955. Test Acc:0.7693
# Epoch: 970. Train Loss: 0.02493. Test Loss: 1.368. Train Acc: 0.9952. Test Acc:0.7724
# Epoch: 980. Train Loss: 0.02451. Test Loss: 1.391. Train Acc: 0.9962. Test Acc:0.7702
# Epoch: 990. Train Loss: 0.0232. Test Loss: 1.403. Train Acc: 0.9963. Test Acc:0.7711
# Epoch: 1000. Train Loss: 0.03135. Test Loss: 1.362. Train Acc: 0.995. Test Acc:0.776
# ASRCNN__conv_pool_avg__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-z__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.68. Test Loss: 2.841. Train Acc: 0.05949. Test Acc:0.06113
# Epoch: 20. Train Loss: 2.33. Test Loss: 2.541. Train Acc: 0.1873. Test Acc:0.1526
# Epoch: 30. Train Loss: 2.09. Test Loss: 2.344. Train Acc: 0.269. Test Acc:0.2271
# Epoch: 40. Train Loss: 1.886. Test Loss: 2.17. Train Acc: 0.3348. Test Acc:0.3008
# Epoch: 50. Train Loss: 1.7. Test Loss: 2.028. Train Acc: 0.4106. Test Acc:0.344
# Epoch: 60. Train Loss: 1.545. Test Loss: 1.885. Train Acc: 0.4844. Test Acc:0.394
# Epoch: 70. Train Loss: 1.419. Test Loss: 1.76. Train Acc: 0.5336. Test Acc:0.4404
# Epoch: 80. Train Loss: 1.313. Test Loss: 1.671. Train Acc: 0.5821. Test Acc:0.4734
# Epoch: 90. Train Loss: 1.223. Test Loss: 1.59. Train Acc: 0.6223. Test Acc:0.4993
# Epoch: 100. Train Loss: 1.146. Test Loss: 1.521. Train Acc: 0.6567. Test Acc:0.5279
# Epoch: 110. Train Loss: 1.079. Test Loss: 1.458. Train Acc: 0.6803. Test Acc:0.5591
# Epoch: 120. Train Loss: 1.018. Test Loss: 1.413. Train Acc: 0.7157. Test Acc:0.5819
# Epoch: 130. Train Loss: 0.9656. Test Loss: 1.375. Train Acc: 0.7351. Test Acc:0.5944
# Epoch: 140. Train Loss: 0.9144. Test Loss: 1.341. Train Acc: 0.7607. Test Acc:0.6055
# Epoch: 150. Train Loss: 0.8751. Test Loss: 1.309. Train Acc: 0.78. Test Acc:0.6198
# Epoch: 160. Train Loss: 0.8296. Test Loss: 1.271. Train Acc: 0.7949. Test Acc:0.6296
# Epoch: 170. Train Loss: 0.7927. Test Loss: 1.235. Train Acc: 0.8074. Test Acc:0.6448
# Epoch: 180. Train Loss: 0.761. Test Loss: 1.229. Train Acc: 0.8177. Test Acc:0.6448
# Epoch: 190. Train Loss: 0.7251. Test Loss: 1.204. Train Acc: 0.8328. Test Acc:0.6653
# Epoch: 200. Train Loss: 0.6922. Test Loss: 1.189. Train Acc: 0.8421. Test Acc:0.6725
# Epoch: 210. Train Loss: 0.6604. Test Loss: 1.17. Train Acc: 0.8541. Test Acc:0.6814
# Epoch: 220. Train Loss: 0.6331. Test Loss: 1.152. Train Acc: 0.8646. Test Acc:0.6827
# Epoch: 230. Train Loss: 0.6047. Test Loss: 1.12. Train Acc: 0.8709. Test Acc:0.6939
# Epoch: 240. Train Loss: 0.5788. Test Loss: 1.122. Train Acc: 0.8814. Test Acc:0.7001
# Epoch: 250. Train Loss: 0.5556. Test Loss: 1.102. Train Acc: 0.8908. Test Acc:0.7104
# Epoch: 260. Train Loss: 0.5328. Test Loss: 1.105. Train Acc: 0.8932. Test Acc:0.7091
# Epoch: 270. Train Loss: 0.5113. Test Loss: 1.092. Train Acc: 0.9001. Test Acc:0.7166
# Epoch: 280. Train Loss: 0.4961. Test Loss: 1.057. Train Acc: 0.9023. Test Acc:0.7126
# Epoch: 290. Train Loss: 0.4738. Test Loss: 1.062. Train Acc: 0.9093. Test Acc:0.7166
# Epoch: 300. Train Loss: 0.4577. Test Loss: 1.057. Train Acc: 0.9146. Test Acc:0.7202
# Epoch: 310. Train Loss: 0.4402. Test Loss: 1.062. Train Acc: 0.9186. Test Acc:0.7265
# Epoch: 320. Train Loss: 0.4243. Test Loss: 1.067. Train Acc: 0.9214. Test Acc:0.7202
# Epoch: 330. Train Loss: 0.4116. Test Loss: 1.057. Train Acc: 0.9249. Test Acc:0.7247
# Epoch: 340. Train Loss: 0.3963. Test Loss: 1.042. Train Acc: 0.9262. Test Acc:0.7269
# Epoch: 350. Train Loss: 0.3837. Test Loss: 1.049. Train Acc: 0.9302. Test Acc:0.73
# Epoch: 360. Train Loss: 0.3746. Test Loss: 1.08. Train Acc: 0.9319. Test Acc:0.7305
# Epoch: 370. Train Loss: 0.3575. Test Loss: 1.061. Train Acc: 0.9339. Test Acc:0.73
# Epoch: 380. Train Loss: 0.347. Test Loss: 1.078. Train Acc: 0.9389. Test Acc:0.7278
# Epoch: 390. Train Loss: 0.3387. Test Loss: 1.082. Train Acc: 0.9384. Test Acc:0.7336
# Epoch: 400. Train Loss: 0.327. Test Loss: 1.084. Train Acc: 0.9398. Test Acc:0.734
# Epoch: 410. Train Loss: 0.3157. Test Loss: 1.077. Train Acc: 0.9473. Test Acc:0.739
# Epoch: 420. Train Loss: 0.3091. Test Loss: 1.085. Train Acc: 0.945. Test Acc:0.7332
# Epoch: 430. Train Loss: 0.2964. Test Loss: 1.07. Train Acc: 0.9487. Test Acc:0.7372
# Epoch: 440. Train Loss: 0.2877. Test Loss: 1.06. Train Acc: 0.951. Test Acc:0.7394
# Epoch: 450. Train Loss: 0.2852. Test Loss: 1.084. Train Acc: 0.9493. Test Acc:0.7358
# Epoch: 460. Train Loss: 0.2782. Test Loss: 1.083. Train Acc: 0.9518. Test Acc:0.7363
# Epoch: 470. Train Loss: 0.2664. Test Loss: 1.086. Train Acc: 0.9528. Test Acc:0.7349
# Epoch: 480. Train Loss: 0.2595. Test Loss: 1.101. Train Acc: 0.9573. Test Acc:0.739
# Epoch: 490. Train Loss: 0.2506. Test Loss: 1.097. Train Acc: 0.9575. Test Acc:0.7336
# Epoch: 500. Train Loss: 0.252. Test Loss: 1.144. Train Acc: 0.957. Test Acc:0.7367
# Epoch: 510. Train Loss: 0.2365. Test Loss: 1.117. Train Acc: 0.9614. Test Acc:0.7385
# Epoch: 520. Train Loss: 0.2301. Test Loss: 1.088. Train Acc: 0.9626. Test Acc:0.7372
# Epoch: 530. Train Loss: 0.2282. Test Loss: 1.134. Train Acc: 0.9608. Test Acc:0.7381
# Epoch: 540. Train Loss: 0.2216. Test Loss: 1.132. Train Acc: 0.9634. Test Acc:0.7349
# Epoch: 550. Train Loss: 0.216. Test Loss: 1.136. Train Acc: 0.9631. Test Acc:0.7327
# Epoch: 560. Train Loss: 0.2113. Test Loss: 1.139. Train Acc: 0.9643. Test Acc:0.7376
# Epoch: 570. Train Loss: 0.2036. Test Loss: 1.122. Train Acc: 0.9689. Test Acc:0.7394
# Epoch: 580. Train Loss: 0.1988. Test Loss: 1.151. Train Acc: 0.9676. Test Acc:0.7349
# Epoch: 590. Train Loss: 0.1967. Test Loss: 1.144. Train Acc: 0.9676. Test Acc:0.7323
# Epoch: 600. Train Loss: 0.1895. Test Loss: 1.132. Train Acc: 0.9691. Test Acc:0.7407
# Epoch: 610. Train Loss: 0.1834. Test Loss: 1.128. Train Acc: 0.9706. Test Acc:0.7394
# Epoch: 620. Train Loss: 0.1799. Test Loss: 1.154. Train Acc: 0.9718. Test Acc:0.7367
# Epoch: 630. Train Loss: 0.1735. Test Loss: 1.129. Train Acc: 0.9719. Test Acc:0.7398
# Epoch: 640. Train Loss: 0.1701. Test Loss: 1.11. Train Acc: 0.9731. Test Acc:0.7367
# Epoch: 650. Train Loss: 0.1658. Test Loss: 1.122. Train Acc: 0.9727. Test Acc:0.7336
# Epoch: 660. Train Loss: 0.1656. Test Loss: 1.13. Train Acc: 0.9731. Test Acc:0.7345
# Epoch: 670. Train Loss: 0.1692. Test Loss: 1.159. Train Acc: 0.9708. Test Acc:0.73
# Epoch: 680. Train Loss: 0.162. Test Loss: 1.117. Train Acc: 0.9742. Test Acc:0.7314
# Epoch: 690. Train Loss: 0.1767. Test Loss: 1.14. Train Acc: 0.9656. Test Acc:0.7282
# Epoch: 700. Train Loss: 0.1541. Test Loss: 1.116. Train Acc: 0.9742. Test Acc:0.743
# Epoch: 710. Train Loss: 0.145. Test Loss: 1.14. Train Acc: 0.9757. Test Acc:0.7381
# Epoch: 720. Train Loss: 0.1424. Test Loss: 1.134. Train Acc: 0.9781. Test Acc:0.7349
# Epoch: 730. Train Loss: 0.1527. Test Loss: 1.211. Train Acc: 0.9724. Test Acc:0.73
# Epoch: 740. Train Loss: 0.1496. Test Loss: 1.166. Train Acc: 0.9746. Test Acc:0.7274
# Epoch: 750. Train Loss: 0.1383. Test Loss: 1.18. Train Acc: 0.9789. Test Acc:0.7349
# Epoch: 760. Train Loss: 0.1428. Test Loss: 1.232. Train Acc: 0.9751. Test Acc:0.7336
# Epoch: 770. Train Loss: 0.1356. Test Loss: 1.23. Train Acc: 0.9757. Test Acc:0.7287
# Epoch: 780. Train Loss: 0.1509. Test Loss: 1.251. Train Acc: 0.9713. Test Acc:0.73
# Epoch: 790. Train Loss: 0.1296. Test Loss: 1.173. Train Acc: 0.9796. Test Acc:0.7425
# Epoch: 800. Train Loss: 0.1201. Test Loss: 1.149. Train Acc: 0.9829. Test Acc:0.7456
# Epoch: 810. Train Loss: 0.1159. Test Loss: 1.127. Train Acc: 0.9835. Test Acc:0.7456
# Epoch: 820. Train Loss: 0.1143. Test Loss: 1.162. Train Acc: 0.9845. Test Acc:0.7434
# Epoch: 830. Train Loss: 0.112. Test Loss: 1.131. Train Acc: 0.984. Test Acc:0.7425
# Epoch: 840. Train Loss: 0.1071. Test Loss: 1.172. Train Acc: 0.9854. Test Acc:0.7398
# Epoch: 850. Train Loss: 0.1036. Test Loss: 1.172. Train Acc: 0.986. Test Acc:0.7394
# Epoch: 860. Train Loss: 0.0999. Test Loss: 1.183. Train Acc: 0.9862. Test Acc:0.7425
# Epoch: 870. Train Loss: 0.1012. Test Loss: 1.199. Train Acc: 0.9854. Test Acc:0.739
# Epoch: 880. Train Loss: 0.09633. Test Loss: 1.178. Train Acc: 0.987. Test Acc:0.7421
# Epoch: 890. Train Loss: 0.09675. Test Loss: 1.201. Train Acc: 0.985. Test Acc:0.7448
# Epoch: 900. Train Loss: 0.09396. Test Loss: 1.179. Train Acc: 0.9869. Test Acc:0.7421
# Epoch: 910. Train Loss: 0.08845. Test Loss: 1.228. Train Acc: 0.9874. Test Acc:0.7363
# Epoch: 920. Train Loss: 0.08804. Test Loss: 1.225. Train Acc: 0.9882. Test Acc:0.7416
# Epoch: 930. Train Loss: 0.08668. Test Loss: 1.212. Train Acc: 0.9875. Test Acc:0.7403
# Epoch: 940. Train Loss: 0.08533. Test Loss: 1.226. Train Acc: 0.9882. Test Acc:0.7363
# Epoch: 950. Train Loss: 0.08089. Test Loss: 1.263. Train Acc: 0.9899. Test Acc:0.7385
# Epoch: 960. Train Loss: 0.08046. Test Loss: 1.256. Train Acc: 0.9902. Test Acc:0.7381
# Epoch: 970. Train Loss: 0.07641. Test Loss: 1.226. Train Acc: 0.9897. Test Acc:0.7412
# Epoch: 980. Train Loss: 0.07816. Test Loss: 1.26. Train Acc: 0.9909. Test Acc:0.7398
# Epoch: 990. Train Loss: 0.07499. Test Loss: 1.215. Train Acc: 0.9905. Test Acc:0.7421
# Epoch: 1000. Train Loss: 0.07582. Test Loss: 1.254. Train Acc: 0.9889. Test Acc:0.7434
# ASRCNN__conv_pool_avg__conv_dp_0.1__fc_dp_0.1__fn_retrained-wav2vec_features-c__obj_voice_cmd using retrained-wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.856. Test Loss: 3.937. Train Acc: 0.06514. Test Acc:0.05176
# Epoch: 20. Train Loss: 3.623. Test Loss: 3.734. Train Acc: 0.08973. Test Acc:0.07363
# Epoch: 30. Train Loss: 3.224. Test Loss: 3.432. Train Acc: 0.1545. Test Acc:0.1124
# Epoch: 40. Train Loss: 2.867. Test Loss: 3.111. Train Acc: 0.2272. Test Acc:0.1937
# Epoch: 50. Train Loss: 2.54. Test Loss: 2.853. Train Acc: 0.3102. Test Acc:0.2539
# Epoch: 60. Train Loss: 2.269. Test Loss: 2.647. Train Acc: 0.3764. Test Acc:0.3101
# Epoch: 70. Train Loss: 2.065. Test Loss: 2.492. Train Acc: 0.4312. Test Acc:0.34
# Epoch: 80. Train Loss: 1.868. Test Loss: 2.327. Train Acc: 0.4837. Test Acc:0.3905
# Epoch: 90. Train Loss: 1.699. Test Loss: 2.171. Train Acc: 0.5309. Test Acc:0.4226
# Epoch: 100. Train Loss: 1.55. Test Loss: 2.052. Train Acc: 0.5668. Test Acc:0.4507
# Epoch: 110. Train Loss: 1.427. Test Loss: 1.945. Train Acc: 0.5962. Test Acc:0.4708
# Epoch: 120. Train Loss: 1.322. Test Loss: 1.862. Train Acc: 0.6319. Test Acc:0.4958
# Epoch: 130. Train Loss: 1.233. Test Loss: 1.779. Train Acc: 0.6584. Test Acc:0.5248
# Epoch: 140. Train Loss: 1.139. Test Loss: 1.714. Train Acc: 0.6869. Test Acc:0.5466
# Epoch: 150. Train Loss: 1.063. Test Loss: 1.662. Train Acc: 0.706. Test Acc:0.5547
# Epoch: 160. Train Loss: 0.997. Test Loss: 1.603. Train Acc: 0.7272. Test Acc:0.568
# Epoch: 170. Train Loss: 0.9392. Test Loss: 1.568. Train Acc: 0.7451. Test Acc:0.5872
# Epoch: 180. Train Loss: 0.8889. Test Loss: 1.538. Train Acc: 0.7617. Test Acc:0.5917
# Epoch: 190. Train Loss: 0.8338. Test Loss: 1.498. Train Acc: 0.7748. Test Acc:0.5984
# Epoch: 200. Train Loss: 0.7908. Test Loss: 1.47. Train Acc: 0.7881. Test Acc:0.6104
# Epoch: 210. Train Loss: 0.761. Test Loss: 1.465. Train Acc: 0.7976. Test Acc:0.6024
# Epoch: 220. Train Loss: 0.7253. Test Loss: 1.45. Train Acc: 0.8057. Test Acc:0.6185
# Epoch: 230. Train Loss: 0.6938. Test Loss: 1.422. Train Acc: 0.8172. Test Acc:0.6216
# Epoch: 240. Train Loss: 0.6573. Test Loss: 1.409. Train Acc: 0.83. Test Acc:0.6238
# Epoch: 250. Train Loss: 0.613. Test Loss: 1.389. Train Acc: 0.8403. Test Acc:0.6296
# Epoch: 260. Train Loss: 0.5898. Test Loss: 1.389. Train Acc: 0.8455. Test Acc:0.635
# Epoch: 270. Train Loss: 0.5597. Test Loss: 1.366. Train Acc: 0.8546. Test Acc:0.6439
# Epoch: 280. Train Loss: 0.5385. Test Loss: 1.363. Train Acc: 0.8588. Test Acc:0.6435
# Epoch: 290. Train Loss: 0.5046. Test Loss: 1.339. Train Acc: 0.8686. Test Acc:0.6564
# Epoch: 300. Train Loss: 0.4788. Test Loss: 1.331. Train Acc: 0.8787. Test Acc:0.66
# Epoch: 310. Train Loss: 0.4674. Test Loss: 1.337. Train Acc: 0.879. Test Acc:0.6577
# Epoch: 320. Train Loss: 0.4466. Test Loss: 1.328. Train Acc: 0.8852. Test Acc:0.6671
# Epoch: 330. Train Loss: 0.4361. Test Loss: 1.324. Train Acc: 0.8875. Test Acc:0.672
# ...
# Epoch: 50. Train Loss: 1.77. Test Loss: 2.194. Train Acc: 0.5347. Test Acc:0.4278
# Epoch: 60. Train Loss: 1.454. Test Loss: 1.918. Train Acc: 0.6184. Test Acc:0.4925
# Epoch: 70. Train Loss: 1.234. Test Loss: 1.729. Train Acc: 0.6818. Test Acc:0.5446
# Epoch: 80. Train Loss: 1.069. Test Loss: 1.593. Train Acc: 0.7311. Test Acc:0.5813
# Epoch: 90. Train Loss: 0.942. Test Loss: 1.485. Train Acc: 0.7645. Test Acc:0.6097
# Epoch: 100. Train Loss: 0.8385. Test Loss: 1.411. Train Acc: 0.7919. Test Acc:0.6218
# Epoch: 110. Train Loss: 0.7542. Test Loss: 1.345. Train Acc: 0.8152. Test Acc:0.6447
# Epoch: 120. Train Loss: 0.6819. Test Loss: 1.292. Train Acc: 0.838. Test Acc:0.6606
# Epoch: 130. Train Loss: 0.6253. Test Loss: 1.247. Train Acc: 0.8529. Test Acc:0.6757
# Epoch: 140. Train Loss: 0.5804. Test Loss: 1.204. Train Acc: 0.865. Test Acc:0.6861
# Epoch: 150. Train Loss: 0.5391. Test Loss: 1.189. Train Acc: 0.87. Test Acc:0.7003
# Epoch: 160. Train Loss: 0.4912. Test Loss: 1.153. Train Acc: 0.8835. Test Acc:0.7132
# Epoch: 170. Train Loss: 0.457. Test Loss: 1.134. Train Acc: 0.8924. Test Acc:0.7167
# Epoch: 180. Train Loss: 0.427. Test Loss: 1.117. Train Acc: 0.9019. Test Acc:0.7201
# Epoch: 190. Train Loss: 0.4007. Test Loss: 1.108. Train Acc: 0.9111. Test Acc:0.7275
# Epoch: 200. Train Loss: 0.3778. Test Loss: 1.088. Train Acc: 0.914. Test Acc:0.7292
# Epoch: 210. Train Loss: 0.3665. Test Loss: 1.112. Train Acc: 0.9109. Test Acc:0.7292
# Epoch: 220. Train Loss: 0.3483. Test Loss: 1.108. Train Acc: 0.9153. Test Acc:0.7382
# Epoch: 230. Train Loss: 0.3161. Test Loss: 1.091. Train Acc: 0.9286. Test Acc:0.7322
# Epoch: 240. Train Loss: 0.298. Test Loss: 1.072. Train Acc: 0.9288. Test Acc:0.7486
# Epoch: 250. Train Loss: 0.2857. Test Loss: 1.084. Train Acc: 0.9313. Test Acc:0.7434
# Epoch: 260. Train Loss: 0.2707. Test Loss: 1.063. Train Acc: 0.9379. Test Acc:0.7495
# Epoch: 270. Train Loss: 0.2626. Test Loss: 1.086. Train Acc: 0.9384. Test Acc:0.7456
# Epoch: 280. Train Loss: 0.2504. Test Loss: 1.085. Train Acc: 0.9406. Test Acc:0.7512
# Epoch: 290. Train Loss: 0.2423. Test Loss: 1.078. Train Acc: 0.9458. Test Acc:0.7525
# Epoch: 300. Train Loss: 0.2222. Test Loss: 1.075. Train Acc: 0.9463. Test Acc:0.7499
# Epoch: 310. Train Loss: 0.2106. Test Loss: 1.067. Train Acc: 0.9502. Test Acc:0.7572
# Epoch: 320. Train Loss: 0.2007. Test Loss: 1.08. Train Acc: 0.9513. Test Acc:0.7508
# Epoch: 330. Train Loss: 0.1872. Test Loss: 1.072. Train Acc: 0.9545. Test Acc:0.7564
# Epoch: 340. Train Loss: 0.1819. Test Loss: 1.08. Train Acc: 0.9552. Test Acc:0.7564
# Epoch: 350. Train Loss: 0.1707. Test Loss: 1.084. Train Acc: 0.9581. Test Acc:0.762
# Epoch: 360. Train Loss: 0.173. Test Loss: 1.094. Train Acc: 0.9551. Test Acc:0.7594
# Epoch: 370. Train Loss: 0.1768. Test Loss: 1.113. Train Acc: 0.9534. Test Acc:0.7572
# Epoch: 380. Train Loss: 0.1775. Test Loss: 1.078. Train Acc: 0.9557. Test Acc:0.7646
# Epoch: 390. Train Loss: 0.1483. Test Loss: 1.062. Train Acc: 0.9653. Test Acc:0.768
# Epoch: 400. Train Loss: 0.1375. Test Loss: 1.064. Train Acc: 0.967. Test Acc:0.7745
# Epoch: 410. Train Loss: 0.1405. Test Loss: 1.104. Train Acc: 0.9645. Test Acc:0.7641
# Epoch: 420. Train Loss: 0.1278. Test Loss: 1.089. Train Acc: 0.9684. Test Acc:0.7753
# Epoch: 430. Train Loss: 0.1237. Test Loss: 1.1. Train Acc: 0.9702. Test Acc:0.7749
# Epoch: 440. Train Loss: 0.1108. Test Loss: 1.103. Train Acc: 0.9726. Test Acc:0.774
# Epoch: 450. Train Loss: 0.1037. Test Loss: 1.105. Train Acc: 0.9747. Test Acc:0.7762
# Epoch: 460. Train Loss: 0.1023. Test Loss: 1.097. Train Acc: 0.9761. Test Acc:0.7719
# Epoch: 470. Train Loss: 0.09279. Test Loss: 1.126. Train Acc: 0.9788. Test Acc:0.7745
# Epoch: 480. Train Loss: 0.09123. Test Loss: 1.123. Train Acc: 0.9783. Test Acc:0.7736
# Epoch: 490. Train Loss: 0.09036. Test Loss: 1.127. Train Acc: 0.9785. Test Acc:0.7775
# Epoch: 500. Train Loss: 0.08855. Test Loss: 1.132. Train Acc: 0.9795. Test Acc:0.7784
# Epoch: 510. Train Loss: 0.08797. Test Loss: 1.14. Train Acc: 0.979. Test Acc:0.7766
# Epoch: 520. Train Loss: 0.07801. Test Loss: 1.154. Train Acc: 0.9815. Test Acc:0.7758
# Epoch: 530. Train Loss: 0.07399. Test Loss: 1.168. Train Acc: 0.9825. Test Acc:0.7766
# Epoch: 540. Train Loss: 0.06784. Test Loss: 1.165. Train Acc: 0.9848. Test Acc:0.774
# Epoch: 550. Train Loss: 0.06448. Test Loss: 1.173. Train Acc: 0.9847. Test Acc:0.7723
# Epoch: 560. Train Loss: 0.05901. Test Loss: 1.179. Train Acc: 0.9864. Test Acc:0.7775
# Epoch: 570. Train Loss: 0.06007. Test Loss: 1.161. Train Acc: 0.9852. Test Acc:0.7818
# Epoch: 580. Train Loss: 0.06117. Test Loss: 1.194. Train Acc: 0.9855. Test Acc:0.7818
# Epoch: 590. Train Loss: 0.06598. Test Loss: 1.228. Train Acc: 0.9838. Test Acc:0.7736
# Epoch: 600. Train Loss: 0.04804. Test Loss: 1.186. Train Acc: 0.9896. Test Acc:0.7818
# Epoch: 610. Train Loss: 0.04608. Test Loss: 1.214. Train Acc: 0.9896. Test Acc:0.7753
# Epoch: 620. Train Loss: 0.04728. Test Loss: 1.221. Train Acc: 0.9887. Test Acc:0.7779
# Epoch: 630. Train Loss: 0.04502. Test Loss: 1.237. Train Acc: 0.9886. Test Acc:0.7766
# Epoch: 640. Train Loss: 0.04121. Test Loss: 1.236. Train Acc: 0.9896. Test Acc:0.7758
# Epoch: 650. Train Loss: 0.03728. Test Loss: 1.263. Train Acc: 0.9924. Test Acc:0.771
# Epoch: 660. Train Loss: 0.0377. Test Loss: 1.27. Train Acc: 0.9916. Test Acc:0.774
# Epoch: 670. Train Loss: 0.03644. Test Loss: 1.239. Train Acc: 0.9918. Test Acc:0.7784
# Epoch: 680. Train Loss: 0.03457. Test Loss: 1.281. Train Acc: 0.9916. Test Acc:0.7784
# Epoch: 690. Train Loss: 0.03668. Test Loss: 1.295. Train Acc: 0.9921. Test Acc:0.7775
# Epoch: 700. Train Loss: 0.03443. Test Loss: 1.293. Train Acc: 0.9929. Test Acc:0.7727
# Epoch: 710. Train Loss: 0.03706. Test Loss: 1.329. Train Acc: 0.9907. Test Acc:0.7762
# Epoch: 720. Train Loss: 0.03162. Test Loss: 1.293. Train Acc: 0.9938. Test Acc:0.774
# Epoch: 730. Train Loss: 0.0315. Test Loss: 1.331. Train Acc: 0.9948. Test Acc:0.7663
# Epoch: 740. Train Loss: 0.02861. Test Loss: 1.306. Train Acc: 0.9946. Test Acc:0.7831
# Epoch: 750. Train Loss: 0.02713. Test Loss: 1.317. Train Acc: 0.9951. Test Acc:0.7749
# Epoch: 760. Train Loss: 0.03939. Test Loss: 1.36. Train Acc: 0.9919. Test Acc:0.7585
# Epoch: 770. Train Loss: 0.02419. Test Loss: 1.298. Train Acc: 0.996. Test Acc:0.7818
# Epoch: 780. Train Loss: 0.02896. Test Loss: 1.318. Train Acc: 0.9939. Test Acc:0.7719
# Epoch: 790. Train Loss: 0.02229. Test Loss: 1.301. Train Acc: 0.9965. Test Acc:0.7736
# Epoch: 800. Train Loss: 0.0189. Test Loss: 1.324. Train Acc: 0.9981. Test Acc:0.774
# Epoch: 810. Train Loss: 0.0195. Test Loss: 1.322. Train Acc: 0.9975. Test Acc:0.7771
# Epoch: 820. Train Loss: 0.01861. Test Loss: 1.341. Train Acc: 0.9968. Test Acc:0.7809
# Epoch: 830. Train Loss: 0.01938. Test Loss: 1.355. Train Acc: 0.9981. Test Acc:0.7689
# Epoch: 840. Train Loss: 0.02174. Test Loss: 1.375. Train Acc: 0.9956. Test Acc:0.7762
# Epoch: 850. Train Loss: 0.01926. Test Loss: 1.348. Train Acc: 0.9966. Test Acc:0.771
# Epoch: 860. Train Loss: 0.01675. Test Loss: 1.354. Train Acc: 0.998. Test Acc:0.7788
# Epoch: 870. Train Loss: 0.01766. Test Loss: 1.377. Train Acc: 0.9976. Test Acc:0.7723
# Epoch: 880. Train Loss: 0.01663. Test Loss: 1.378. Train Acc: 0.9975. Test Acc:0.7727
# Epoch: 890. Train Loss: 0.01438. Test Loss: 1.393. Train Acc: 0.9983. Test Acc:0.7749
# Epoch: 900. Train Loss: 0.01363. Test Loss: 1.372. Train Acc: 0.9988. Test Acc:0.7775
# Epoch: 910. Train Loss: 0.01475. Test Loss: 1.438. Train Acc: 0.9981. Test Acc:0.7715
# Epoch: 920. Train Loss: 0.01375. Test Loss: 1.403. Train Acc: 0.9987. Test Acc:0.7702
# Epoch: 930. Train Loss: 0.01177. Test Loss: 1.429. Train Acc: 0.9988. Test Acc:0.7706
# Epoch: 940. Train Loss: 0.01201. Test Loss: 1.428. Train Acc: 0.999. Test Acc:0.7641
# Epoch: 950. Train Loss: 0.01307. Test Loss: 1.454. Train Acc: 0.9992. Test Acc:0.7663
# Epoch: 960. Train Loss: 0.01008. Test Loss: 1.454. Train Acc: 0.9995. Test Acc:0.7667
# Epoch: 970. Train Loss: 0.01099. Test Loss: 1.439. Train Acc: 0.9985. Test Acc:0.7697
# Epoch: 980. Train Loss: 0.01334. Test Loss: 1.456. Train Acc: 0.9981. Test Acc:0.7706
# Epoch: 990. Train Loss: 0.00881. Test Loss: 1.415. Train Acc: 0.9993. Test Acc:0.7758
# Epoch: 1000. Train Loss: 0.01045. Test Loss: 1.437. Train Acc: 0.9995. Test Acc:0.7753
# ASRCNN__conv_pool_avg__conv_dp_0.1__fc_dp_0.1__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#1
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 5940
# test_n: 2319
# Epoch: 10. Train Loss: 2.373. Test Loss: 2.569. Train Acc: 0.1419. Test Acc:0.1108
# Epoch: 20. Train Loss: 2.0. Test Loss: 2.31. Train Acc: 0.2729. Test Acc:0.1936
# Epoch: 30. Train Loss: 1.679. Test Loss: 2.105. Train Acc: 0.4141. Test Acc:0.3001
# Epoch: 40. Train Loss: 1.367. Test Loss: 1.818. Train Acc: 0.5593. Test Acc:0.4105
# Epoch: 50. Train Loss: 1.149. Test Loss: 1.63. Train Acc: 0.6655. Test Acc:0.489
# Epoch: 60. Train Loss: 0.9927. Test Loss: 1.477. Train Acc: 0.7246. Test Acc:0.5515
# Epoch: 70. Train Loss: 0.883. Test Loss: 1.362. Train Acc: 0.7737. Test Acc:0.5929
# Epoch: 80. Train Loss: 0.7959. Test Loss: 1.282. Train Acc: 0.8098. Test Acc:0.6283
# Epoch: 90. Train Loss: 0.7093. Test Loss: 1.21. Train Acc: 0.8414. Test Acc:0.6507
# Epoch: 100. Train Loss: 0.6499. Test Loss: 1.187. Train Acc: 0.8535. Test Acc:0.6632
# Epoch: 110. Train Loss: 0.6012. Test Loss: 1.133. Train Acc: 0.8714. Test Acc:0.6826
# Epoch: 120. Train Loss: 0.551. Test Loss: 1.097. Train Acc: 0.8847. Test Acc:0.6999
# Epoch: 130. Train Loss: 0.5125. Test Loss: 1.071. Train Acc: 0.8971. Test Acc:0.7111
# Epoch: 140. Train Loss: 0.4767. Test Loss: 1.044. Train Acc: 0.9054. Test Acc:0.7236
# Epoch: 150. Train Loss: 0.4517. Test Loss: 1.041. Train Acc: 0.9126. Test Acc:0.7223
# Epoch: 160. Train Loss: 0.4251. Test Loss: 1.026. Train Acc: 0.9175. Test Acc:0.7301
# Epoch: 170. Train Loss: 0.4058. Test Loss: 1.018. Train Acc: 0.9241. Test Acc:0.7352
# Epoch: 180. Train Loss: 0.3929. Test Loss: 1.016. Train Acc: 0.9244. Test Acc:0.7361
# Epoch: 190. Train Loss: 0.3698. Test Loss: 0.997. Train Acc: 0.9293. Test Acc:0.7395
# Epoch: 200. Train Loss: 0.349. Test Loss: 1.002. Train Acc: 0.935. Test Acc:0.7421
# Epoch: 210. Train Loss: 0.3315. Test Loss: 0.992. Train Acc: 0.9396. Test Acc:0.7417
# Epoch: 220. Train Loss: 0.3268. Test Loss: 0.984. Train Acc: 0.9397. Test Acc:0.7456
# Epoch: 230. Train Loss: 0.3144. Test Loss: 0.9898. Train Acc: 0.9392. Test Acc:0.7382
# Epoch: 240. Train Loss: 0.3043. Test Loss: 0.9903. Train Acc: 0.9411. Test Acc:0.7456
# Epoch: 250. Train Loss: 0.3016. Test Loss: 1.004. Train Acc: 0.9423. Test Acc:0.7387
# Epoch: 260. Train Loss: 0.2965. Test Loss: 0.9855. Train Acc: 0.9428. Test Acc:0.7499
# Epoch: 270. Train Loss: 0.2715. Test Loss: 0.9903. Train Acc: 0.9466. Test Acc:0.7482
# Epoch: 280. Train Loss: 0.2512. Test Loss: 0.9974. Train Acc: 0.9544. Test Acc:0.7495
# Epoch: 290. Train Loss: 0.2579. Test Loss: 1.001. Train Acc: 0.952. Test Acc:0.7473
# Epoch: 300. Train Loss: 0.237. Test Loss: 0.9786. Train Acc: 0.9547. Test Acc:0.7533
# Epoch: 310. Train Loss: 0.2291. Test Loss: 1.005. Train Acc: 0.9571. Test Acc:0.7477
# Epoch: 320. Train Loss: 0.2254. Test Loss: 1.008. Train Acc: 0.9577. Test Acc:0.746
# Epoch: 330. Train Loss: 0.2126. Test Loss: 0.9836. Train Acc: 0.9601. Test Acc:0.7555
# Epoch: 340. Train Loss: 0.2169. Test Loss: 1.013. Train Acc: 0.9567. Test Acc:0.749
# Epoch: 350. Train Loss: 0.2104. Test Loss: 1.008. Train Acc: 0.9601. Test Acc:0.7525
# Epoch: 360. Train Loss: 0.1903. Test Loss: 0.9853. Train Acc: 0.9665. Test Acc:0.7641
# Epoch: 370. Train Loss: 0.2015. Test Loss: 0.9996. Train Acc: 0.9613. Test Acc:0.7611
# Epoch: 380. Train Loss: 0.1789. Test Loss: 0.9815. Train Acc: 0.9694. Test Acc:0.7693
# Epoch: 390. Train Loss: 0.1689. Test Loss: 0.9993. Train Acc: 0.9719. Test Acc:0.7577
# Epoch: 400. Train Loss: 0.1721. Test Loss: 1.006. Train Acc: 0.9702. Test Acc:0.7628
# Epoch: 410. Train Loss: 0.1577. Test Loss: 1.011. Train Acc: 0.9724. Test Acc:0.7598
# Epoch: 420. Train Loss: 0.1515. Test Loss: 1.025. Train Acc: 0.9732. Test Acc:0.7589
# Epoch: 430. Train Loss: 0.1516. Test Loss: 1.03. Train Acc: 0.9724. Test Acc:0.7581
# Epoch: 440. Train Loss: 0.1469. Test Loss: 1.033. Train Acc: 0.9751. Test Acc:0.762
# Epoch: 450. Train Loss: 0.145. Test Loss: 1.04. Train Acc: 0.9737. Test Acc:0.7615
# Epoch: 460. Train Loss: 0.1423. Test Loss: 1.045. Train Acc: 0.9742. Test Acc:0.7577
# Epoch: 470. Train Loss: 0.1448. Test Loss: 1.041. Train Acc: 0.9721. Test Acc:0.7641
# Epoch: 480. Train Loss: 0.1379. Test Loss: 1.066. Train Acc: 0.9727. Test Acc:0.7581
# Epoch: 490. Train Loss: 0.1372. Test Loss: 1.072. Train Acc: 0.9724. Test Acc:0.7555
# Epoch: 500. Train Loss: 0.1277. Test Loss: 1.076. Train Acc: 0.9763. Test Acc:0.7602
# Epoch: 510. Train Loss: 0.1421. Test Loss: 1.102. Train Acc: 0.9715. Test Acc:0.7529
# Epoch: 520. Train Loss: 0.1228. Test Loss: 1.058. Train Acc: 0.9756. Test Acc:0.7598
# Epoch: 530. Train Loss: 0.113. Test Loss: 1.108. Train Acc: 0.9813. Test Acc:0.7572
# Epoch: 540. Train Loss: 0.1096. Test Loss: 1.113. Train Acc: 0.9823. Test Acc:0.7589
# Epoch: 550. Train Loss: 0.1089. Test Loss: 1.142. Train Acc: 0.984. Test Acc:0.7495
# Epoch: 560. Train Loss: 0.1018. Test Loss: 1.116. Train Acc: 0.9848. Test Acc:0.7542
# Epoch: 570. Train Loss: 0.09762. Test Loss: 1.143. Train Acc: 0.986. Test Acc:0.746
# Epoch: 580. Train Loss: 0.09885. Test Loss: 1.129. Train Acc: 0.9855. Test Acc:0.7568
# Epoch: 590. Train Loss: 0.09265. Test Loss: 1.132. Train Acc: 0.9869. Test Acc:0.7525
# Epoch: 600. Train Loss: 0.08848. Test Loss: 1.118. Train Acc: 0.9882. Test Acc:0.7589
# Epoch: 610. Train Loss: 0.08374. Test Loss: 1.149. Train Acc: 0.9899. Test Acc:0.7577
# Epoch: 620. Train Loss: 0.08294. Test Loss: 1.136. Train Acc: 0.9884. Test Acc:0.7529
# Epoch: 630. Train Loss: 0.07961. Test Loss: 1.155. Train Acc: 0.9874. Test Acc:0.7546
# Epoch: 640. Train Loss: 0.07809. Test Loss: 1.135. Train Acc: 0.9886. Test Acc:0.7577
# Epoch: 650. Train Loss: 0.07767. Test Loss: 1.14. Train Acc: 0.9889. Test Acc:0.7598
# Epoch: 660. Train Loss: 0.07582. Test Loss: 1.128. Train Acc: 0.9887. Test Acc:0.7568
# Epoch: 670. Train Loss: 0.0689. Test Loss: 1.139. Train Acc: 0.9907. Test Acc:0.7568
# Epoch: 680. Train Loss: 0.06994. Test Loss: 1.144. Train Acc: 0.9892. Test Acc:0.7525
# Epoch: 690. Train Loss: 0.06625. Test Loss: 1.133. Train Acc: 0.9902. Test Acc:0.7542
# Epoch: 700. Train Loss: 0.06164. Test Loss: 1.137. Train Acc: 0.9919. Test Acc:0.752
# Epoch: 710. Train Loss: 0.06286. Test Loss: 1.152. Train Acc: 0.9931. Test Acc:0.7464
