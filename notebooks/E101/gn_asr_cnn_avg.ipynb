# %%
from pathlib import Path
import csv
import itertools
import numpy as np
from pprint import PrettyPrinter


import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

import h5py

import sklearn
import sklearn.metrics

pprint = PrettyPrinter()

# %% [markdown]
# ## Configuration

# %%
SELECTED_LANGUAGES = {'_language_independent', 'francais', 'maninka', 'pular', 'susu'}

BASE_DIR = Path('/media/xtrem/data/experiments/nicolingua-0002-va-asr/datasets/gn_va_asr_dataset_2020-08-24_02')


ANNOTATIONS_PATH = BASE_DIR/ "annotated_segments" / "metadata.csv"


FEATURE_NAMES = [
    "wav2vec_features-c", 
    "wav2vec_features-z", 
    "retrained-wav2vec_features-c", 
    "retrained-wav2vec_features-z"
]

# CONV_POOLING_TYPES = ['avg', 'max']
CONV_POOLING_TYPES = ['avg']
OBJECTIVE_TYPES = ['voice_cmd', 'voice_cmd__and__voice_cmd_lng']
CONV_DROPOUT_PROBABILITIES = [0.2]
FC_DROPOUT_PROBABILITIES = [0.2]


TRAIN_PERCENT = .7
FOLD_COUNT = 5


RESULTS_DIR = f'results_101'
EPOCHS = 1000
BATCH_SIZE = 512
MAX_FEATURE_SEQUENCE_LENGTH = 200

GPU_ID = 0
device = torch.device(f"cuda:{GPU_ID}")

# %% [markdown]
# ## Load & shuffle metadata records

# %%
def load_metadata():
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for r in reader:
            if r['language'] in SELECTED_LANGUAGES:
                yield r

# %%
# load
metadata_records = list(load_metadata())

# shuffle
metadata_shuffler_rs = np.random.RandomState(seed=42)
metadata_shuffler_rs.shuffle(metadata_records)

# %%
bias_category_fields = [
     "device_id"
    ,"language"
    ,"speaker_gender"
    ,"speaker_mothertongue"
]

bias_categories = {}
for c in bias_category_fields:
    bias_categories[c] = sorted({r[c] for r in metadata_records})


_ = [print(f"\n{k}: \n\t{','.join(v)}") for k,v in bias_categories.items()]
# Out:
# device_id:
# 	d001,d002,d003
#
# language:
# 	_language_independent,francais,maninka,pular,susu
#
# speaker_gender:
# 	F,M
#
# speaker_mothertongue:
# 	maninka,pular,susu

# %% [markdown]
# ### Labels

# %%
# VOICE COMMANDS
voice_cmd_class_names = sorted({r['label'] for r in metadata_records})
voice_cmd_class_count = len(voice_cmd_class_names)
voice_cmd_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_class_names)}

print("Classes - Voice Commands")
_ = [print(f"{v:4}: {k}") for k,v in voice_cmd_class_id_by_name.items()]

print("---------------------")


# VOICE COMMAND LANGUAGES
voice_cmd_lng_class_names = sorted({r['language'] for r in metadata_records})
voice_cmd_lng_class_count = len(voice_cmd_lng_class_names)
voice_cmd_lng_class_id_by_name = {c:i for i, c in enumerate(voice_cmd_lng_class_names)}

print("Classes - Voice Command Languages")
_ = [print(f"{v:3}: {k}") for k,v in voice_cmd_lng_class_id_by_name.items()]

print("---------------------")



# SPEAKER MOTHERTONGUE
spkr_mothertongue_class_names = sorted({r['speaker_mothertongue'] for r in metadata_records})
spkr_mothertongue_class_count = len(spkr_mothertongue_class_names)
spkr_mothertongue_class_id_by_name = {c:i for i,c in enumerate(spkr_mothertongue_class_names)}

print("Classes - Speaker Mothertongues")
_ = [print(f"{v:3}: {k}") for k,v in spkr_mothertongue_class_id_by_name.items()]

print("---------------------")



# SPEAKER GENDER
spkr_gender_class_names = sorted({r['speaker_gender'] for r in metadata_records})
spkr_gender_class_count = len(spkr_gender_class_names)
spkr_gender_class_id_by_name = {c:i for i, c in enumerate(spkr_gender_class_names)}

print("Classes - Speaker Gender")
_ = [print(f"{v:3}: {k}") for k,v in spkr_gender_class_id_by_name.items()]

print("----------------------")
# Out:
# Classes - Voice Commands
#    0: 101_wake_word__francais
#    1: 101_wake_word__maninka
#    2: 101_wake_word__pular
#    3: 101_wake_word__susu
#    4: 201_add_contact__francais
#    5: 201_add_contact__maninka
#    6: 201_add_contact__pular
#    7: 201_add_contact__susu
#    8: 202_search_contact__francais
#    9: 202_search_contact__maninka
#   10: 202_search_contact__pular
#   11: 202_search_contact__susu
#   12: 203_update_contact__francais
#   13: 203_update_contact__maninka
#   14: 203_update_contact__pular
#   15: 203_update_contact__susu
#   16: 204_delete_contact__francais
#   17: 204_delete_contact__maninka
#   18: 204_delete_contact__pular
#   19: 204_delete_contact__susu
#   20: 205_call_contact__francais
#   21: 205_call_contact__maninka
#   22: 205_call_contact__pular
#   23: 205_call_contact__susu
#   24: 206_yes__francais
#   25: 206_yes__maninka
#   26: 206_yes__pular
#   27: 206_yes__susu
#   28: 207_no__francais
#   29: 207_no__maninka
#   30: 207_no__pular
#   31: 207_no__susu
#   32: 301_zero__francais
#   33: 301_zero__maninka
#   34: 301_zero__pular
#   35: 301_zero__susu
#   36: 302_one__francais
#   37: 302_one__maninka
#   38: 302_one__pular
#   39: 302_one__susu
#   40: 303_two__francais
#   41: 303_two__maninka
#   42: 303_two__pular
#   43: 303_two__susu
#   44: 304_three__francais
#   45: 304_three__maninka
#   46: 304_three__pular
#   47: 304_three__susu
#   48: 305_four__francais
#   49: 305_four__maninka
#   50: 305_four__pular
#   51: 305_four__susu
#   52: 306_five__francais
#   53: 306_five__maninka
#   54: 306_five__pular
#   55: 306_five__susu
#   56: 307_six__francais
#   57: 307_six__maninka
#   58: 307_six__pular
#   59: 307_six__susu
#   60: 308_seven__francais
#   61: 308_seven__maninka
#   62: 308_seven__pular
#   63: 308_seven__susu
#   64: 309_eight__francais
#   65: 309_eight__maninka
#   66: 309_eight__pular
#   67: 309_eight__susu
#   68: 310_nine__francais
#   69: 310_nine__maninka
#   70: 310_nine__pular
#   71: 310_nine__susu
#   72: 401_mom__francais
#   73: 401_mom__maninka
#   74: 401_mom__pular
#   75: 401_mom__susu
#   76: 402_dad__francais
#   77: 402_dad__maninka
#   78: 402_dad__pular
#   79: 402_dad__susu
#   80: 501_fatoumata___language_independent
#   81: 502_mamadou___language_independent
#   82: 503_mariama___language_independent
#   83: 504_mohamed___language_independent
#   84: 505_kadiatou___language_independent
#   85: 506_ibrahima___language_independent
#   86: 507_aissatou___language_independent
#   87: 508_aminata___language_independent
#   88: 509_alpha___language_independent
#   89: 510_thierno___language_independent
#   90: 511_abdoulaye___language_independent
#   91: 512_aboubacar___language_independent
#   92: 513_amadou___language_independent
#   93: 514_fanta___language_independent
#   94: 515_mariame___language_independent
#   95: 516_oumou___language_independent
#   96: 517_ousmane___language_independent
#   97: 518_adama___language_independent
#   98: 519_marie___language_independent
#   99: 520_moussa___language_independent
#  100: 521_aissata___language_independent
#  101: 522_hawa___language_independent
#  102: 523_sekou___language_independent
#  103: 524_hadja___language_independent
#  104: 525_djenabou___language_independent
# ---------------------
# Classes - Voice Command Languages
#   0: _language_independent
#   1: francais
#   2: maninka
#   3: pular
#   4: susu
# ---------------------
# Classes - Speaker Mothertongues
#   0: maninka
#   1: pular
#   2: susu
# ---------------------
# Classes - Speaker Gender
#   0: F
#   1: M
# ----------------------

# %% [markdown]
# ### Inspect metadata

# %%
def count_by_attribute(records, attribute_names):
    attribute_name_instances = {}
    for attribute_name in attribute_names:
        attribute_name_instances[attribute_name] = {r[attribute_name] for r in records}
        
    l = [attribute_name_instances[attribute_name] for attribute_name in attribute_names]
    
    
    
    for attribute_values in sorted(itertools.product(*l)):
        
        def record_match(r):
            for i in range(len(attribute_names)):
                if r[attribute_names[i]] != attribute_values[i]:
                    return False
            return True
            
        record_instances = [r for r in records if record_match(r)]
        count = len(record_instances)
        
        yield (attribute_values, count)

# %%
print("RECORDS BY DEVICE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['device_id']))]
print("")

print("RECORDS BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['language']))]
print("")

print("RECORDS BY GENDER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_gender']))]
print("")

print("RECORDS BY AGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_age']))]
print("")

print("RECORDS BY SPEAKER")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id']))]
print("")

print("RECORDS BY SPEAKER BY LANGUAGE")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['speaker_id', 'language']))]
print("")

print("RECORDS BY SPEAKER BY LABEL")
_ = [print(f"\t{r}") for r in sorted(count_by_attribute(metadata_records, ['label']))]
print("")
# Out:
# RECORDS BY DEVICE
# 	(('d001',), 2759)
# 	(('d002',), 2741)
# 	(('d003',), 2759)
#
# RECORDS BY LANGUAGE
# 	(('_language_independent',), 3072)
# 	(('francais',), 1260)
# 	(('maninka',), 1356)
# 	(('pular',), 909)
# 	(('susu',), 1662)
#
# RECORDS BY GENDER
# 	(('F',), 2820)
# 	(('M',), 5439)
#
# RECORDS BY AGE
# 	(('12',), 237)
# 	(('13',), 252)
# 	(('15',), 603)
# 	(('17',), 1050)
# 	(('18',), 855)
# 	(('19',), 273)
# 	(('20',), 291)
# 	(('27',), 255)
# 	(('28',), 183)
# 	(('29',), 237)
# 	(('31',), 255)
# 	(('32',), 291)
# 	(('33',), 183)
# 	(('34',), 129)
# 	(('35',), 498)
# 	(('37',), 309)
# 	(('38',), 441)
# 	(('43',), 183)
# 	(('44',), 540)
# 	(('5',), 129)
# 	(('55',), 183)
# 	(('61',), 390)
# 	(('63',), 237)
# 	(('67',), 255)
#
# RECORDS BY SPEAKER
# 	(('s001',), 183)
# 	(('s002',), 129)
# 	(('s003',), 183)
# 	(('s004',), 183)
# 	(('s005',), 129)
# 	(('s006',), 129)
# 	(('s007',), 183)
# 	(('s008',), 129)
# 	(('s009',), 237)
# 	(('s010',), 291)
# 	(('s011',), 129)
# 	(('s012',), 183)
# 	(('s013',), 129)
# 	(('s014',), 237)
# 	(('s015',), 291)
# 	(('s016',), 183)
# 	(('s017',), 237)
# 	(('s018',), 237)
# 	(('s019',), 237)
# 	(('s020',), 291)
# 	(('s021',), 273)
# 	(('s022',), 183)
# 	(('s023',), 309)
# 	(('s024',), 255)
# 	(('s025',), 315)
# 	(('s026',), 252)
# 	(('s027',), 540)
# 	(('s028',), 540)
# 	(('s029',), 390)
# 	(('s030',), 195)
# 	(('s031',), 252)
# 	(('s032',), 315)
# 	(('s033',), 255)
# 	(('s034',), 255)
#
# RECORDS BY SPEAKER BY LANGUAGE
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'francais'), 0)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'pular'), 0)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'francais'), 0)
# 	(('s002', 'maninka'), 54)
# 	(('s002', 'pular'), 0)
# 	(('s002', 'susu'), 0)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'francais'), 0)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'pular'), 0)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'francais'), 0)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'pular'), 0)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'francais'), 0)
# 	(('s005', 'maninka'), 0)
# 	(('s005', 'pular'), 0)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'francais'), 0)
# 	(('s006', 'maninka'), 54)
# 	(('s006', 'pular'), 0)
# 	(('s006', 'susu'), 0)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'francais'), 0)
# 	(('s007', 'maninka'), 0)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'francais'), 0)
# 	(('s008', 'maninka'), 54)
# 	(('s008', 'pular'), 0)
# 	(('s008', 'susu'), 0)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'maninka'), 0)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'francais'), 0)
# 	(('s011', 'maninka'), 0)
# 	(('s011', 'pular'), 0)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'maninka'), 0)
# 	(('s012', 'pular'), 0)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'francais'), 0)
# 	(('s013', 'maninka'), 0)
# 	(('s013', 'pular'), 0)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'pular'), 0)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'francais'), 0)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'pular'), 0)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'maninka'), 0)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'maninka'), 0)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'pular'), 0)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'francais'), 0)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'pular'), 0)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'pular'), 0)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'pular'), 0)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'maninka'), 0)
# 	(('s030', 'pular'), 60)
# 	(('s030', 'susu'), 0)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'maninka'), 0)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'pular'), 0)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'pular'), 0)
# 	(('s034', 'susu'), 60)
#
# RECORDS BY SPEAKER BY LABEL
# 	(('101_wake_word__francais',), 66)
# 	(('101_wake_word__maninka',), 72)
# 	(('101_wake_word__pular',), 48)
# 	(('101_wake_word__susu',), 89)
# 	(('201_add_contact__francais',), 66)
# 	(('201_add_contact__maninka',), 72)
# 	(('201_add_contact__pular',), 48)
# 	(('201_add_contact__susu',), 89)
# 	(('202_search_contact__francais',), 66)
# 	(('202_search_contact__maninka',), 72)
# 	(('202_search_contact__pular',), 48)
# 	(('202_search_contact__susu',), 89)
# 	(('203_update_contact__francais',), 66)
# 	(('203_update_contact__maninka',), 72)
# 	(('203_update_contact__pular',), 48)
# 	(('203_update_contact__susu',), 89)
# 	(('204_delete_contact__francais',), 66)
# 	(('204_delete_contact__maninka',), 72)
# 	(('204_delete_contact__pular',), 48)
# 	(('204_delete_contact__susu',), 89)
# 	(('205_call_contact__francais',), 66)
# 	(('205_call_contact__maninka',), 72)
# 	(('205_call_contact__pular',), 45)
# 	(('205_call_contact__susu',), 89)
# 	(('206_yes__francais',), 66)
# 	(('206_yes__maninka',), 72)
# 	(('206_yes__pular',), 48)
# 	(('206_yes__susu',), 89)
# 	(('207_no__francais',), 66)
# 	(('207_no__maninka',), 72)
# 	(('207_no__pular',), 48)
# 	(('207_no__susu',), 89)
# 	(('301_zero__francais',), 66)
# 	(('301_zero__maninka',), 72)
# 	(('301_zero__pular',), 48)
# 	(('301_zero__susu',), 89)
# 	(('302_one__francais',), 66)
# 	(('302_one__maninka',), 72)
# 	(('302_one__pular',), 48)
# 	(('302_one__susu',), 89)
# 	(('303_two__francais',), 66)
# 	(('303_two__maninka',), 72)
# 	(('303_two__pular',), 48)
# 	(('303_two__susu',), 89)
# 	(('304_three__francais',), 66)
# 	(('304_three__maninka',), 72)
# 	(('304_three__pular',), 48)
# 	(('304_three__susu',), 89)
# 	(('305_four__francais',), 66)
# 	(('305_four__maninka',), 72)
# 	(('305_four__pular',), 48)
# 	(('305_four__susu',), 89)
# 	(('306_five__francais',), 66)
# 	(('306_five__maninka',), 72)
# 	(('306_five__pular',), 48)
# 	(('306_five__susu',), 89)
# 	(('307_six__francais',), 66)
# 	(('307_six__maninka',), 72)
# 	(('307_six__pular',), 48)
# 	(('307_six__susu',), 89)
# 	(('308_seven__francais',), 66)
# 	(('308_seven__maninka',), 72)
# 	(('308_seven__pular',), 48)
# 	(('308_seven__susu',), 89)
# 	(('309_eight__francais',), 66)
# 	(('309_eight__maninka',), 72)
# 	(('309_eight__pular',), 48)
# 	(('309_eight__susu',), 89)
# 	(('310_nine__francais',), 66)
# 	(('310_nine__maninka',), 72)
# 	(('310_nine__pular',), 48)
# 	(('310_nine__susu',), 89)
# 	(('401_mom__francais',), 36)
# 	(('401_mom__maninka',), 30)
# 	(('401_mom__pular',), 24)
# 	(('401_mom__susu',), 30)
# 	(('402_dad__francais',), 36)
# 	(('402_dad__maninka',), 30)
# 	(('402_dad__pular',), 24)
# 	(('402_dad__susu',), 30)
# 	(('501_fatoumata___language_independent',), 123)
# 	(('502_mamadou___language_independent',), 123)
# 	(('503_mariama___language_independent',), 123)
# 	(('504_mohamed___language_independent',), 123)
# 	(('505_kadiatou___language_independent',), 123)
# 	(('506_ibrahima___language_independent',), 123)
# 	(('507_aissatou___language_independent',), 123)
# 	(('508_aminata___language_independent',), 123)
# 	(('509_alpha___language_independent',), 123)
# 	(('510_thierno___language_independent',), 120)
# 	(('511_abdoulaye___language_independent',), 123)
# 	(('512_aboubacar___language_independent',), 123)
# 	(('513_amadou___language_independent',), 123)
# 	(('514_fanta___language_independent',), 123)
# 	(('515_mariame___language_independent',), 123)
# 	(('516_oumou___language_independent',), 123)
# 	(('517_ousmane___language_independent',), 123)
# 	(('518_adama___language_independent',), 123)
# 	(('519_marie___language_independent',), 123)
# 	(('520_moussa___language_independent',), 123)
# 	(('521_aissata___language_independent',), 123)
# 	(('522_hawa___language_independent',), 123)
# 	(('523_sekou___language_independent',), 123)
# 	(('524_hadja___language_independent',), 123)
# 	(('525_djenabou___language_independent',), 123)

# %% [markdown]
# ## Prepare Cross Validation Folds
# - Partition by (speaker, language)
# - Each (speaker, language) correspond to `utterance_count * device_count`
# - For each fold, all `utterance_count * device_count` records for the same speaker in the same language are either in the TRAIN or the VALIDATION sets, but not both.

# %%
def generate_train_test_records_per_fold(all_records):
    records_per_fold = {}
    
    all_speaker_languages = sorted({(r['speaker_id'], r['language']) for r in all_records})

    sl_count = len(all_speaker_languages)
    all_sl_indices = range(sl_count)
    train_sl_count = int(np.ceil(sl_count*TRAIN_PERCENT))
    test_sl_count = sl_count - train_sl_count

    for fold_index in range(FOLD_COUNT):
        fold_rsampler = np.random.RandomState(seed=fold_index)

        train_sl_index_set = set(fold_rsampler.choice(all_sl_indices, train_sl_count, replace=False))
        train_sl_set = {all_speaker_languages[i] for i in train_sl_index_set}

        test_sl_index_set = set(all_sl_indices).difference(train_sl_index_set)
        test_sl_set = {all_speaker_languages[i] for i in test_sl_index_set}

        train_records = [r for r in all_records if (r['speaker_id'], r['language']) in train_sl_set]
        test_records = [r for r in all_records if (r['speaker_id'], r['language']) in test_sl_set]
        
        
        records_per_fold[fold_index] = {
            "train_records": train_records,
            "test_records": test_records
        }
    
    return records_per_fold

# %%
records_per_fold = generate_train_test_records_per_fold(metadata_records)

# %% [markdown]
# ### Inspect Folds

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['speaker_id', 'language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['speaker_id', 'language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', '_language_independent'), 75)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 0 -- TEST
# 	(('s004', 'maninka'), 54)
# 	(('s005', 'susu'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'susu'), 54)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 1 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s002', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'susu'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 1 -- TEST
# 	(('s001', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s024', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s030', 'francais'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'susu'), 60)
# 	(('s033', 'susu'), 60)
# ---------------------
# Fold 2 -- TRAIN
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s011', 'susu'), 54)
# 	(('s012', 'francais'), 54)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'francais'), 54)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# 	(('s034', 'susu'), 60)
# Fold 2 -- TEST
# 	(('s002', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s033', '_language_independent'), 75)
# ---------------------
# Fold 3 -- TRAIN
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s009', 'susu'), 54)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'francais'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'maninka'), 54)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s018', 'susu'), 54)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', '_language_independent'), 72)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'pular'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'susu'), 60)
# Fold 3 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s001', 'susu'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s006', 'maninka'), 54)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'francais'), 54)
# 	(('s009', 'pular'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'maninka'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s017', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s029', 'francais'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------
# Fold 4 -- TRAIN
# 	(('s001', 'susu'), 54)
# 	(('s002', 'maninka'), 54)
# 	(('s003', '_language_independent'), 75)
# 	(('s003', 'maninka'), 54)
# 	(('s003', 'susu'), 54)
# 	(('s004', 'susu'), 54)
# 	(('s005', '_language_independent'), 75)
# 	(('s005', 'susu'), 54)
# 	(('s006', '_language_independent'), 75)
# 	(('s006', 'maninka'), 54)
# 	(('s007', '_language_independent'), 75)
# 	(('s007', 'pular'), 54)
# 	(('s007', 'susu'), 54)
# 	(('s008', '_language_independent'), 75)
# 	(('s008', 'maninka'), 54)
# 	(('s009', '_language_independent'), 75)
# 	(('s009', 'pular'), 54)
# 	(('s009', 'susu'), 54)
# 	(('s010', '_language_independent'), 75)
# 	(('s010', 'francais'), 54)
# 	(('s010', 'maninka'), 54)
# 	(('s010', 'pular'), 54)
# 	(('s010', 'susu'), 54)
# 	(('s011', '_language_independent'), 75)
# 	(('s012', '_language_independent'), 75)
# 	(('s012', 'francais'), 54)
# 	(('s012', 'susu'), 54)
# 	(('s013', '_language_independent'), 75)
# 	(('s013', 'susu'), 54)
# 	(('s014', 'francais'), 54)
# 	(('s014', 'susu'), 54)
# 	(('s015', '_language_independent'), 75)
# 	(('s015', 'francais'), 54)
# 	(('s015', 'maninka'), 54)
# 	(('s015', 'pular'), 54)
# 	(('s016', '_language_independent'), 75)
# 	(('s016', 'susu'), 54)
# 	(('s017', '_language_independent'), 75)
# 	(('s017', 'susu'), 54)
# 	(('s018', 'francais'), 54)
# 	(('s018', 'pular'), 54)
# 	(('s019', 'susu'), 54)
# 	(('s020', '_language_independent'), 75)
# 	(('s020', 'francais'), 54)
# 	(('s020', 'maninka'), 54)
# 	(('s020', 'pular'), 54)
# 	(('s020', 'susu'), 54)
# 	(('s021', '_language_independent'), 75)
# 	(('s021', 'maninka'), 54)
# 	(('s021', 'pular'), 54)
# 	(('s022', '_language_independent'), 75)
# 	(('s022', 'maninka'), 54)
# 	(('s023', 'francais'), 60)
# 	(('s023', 'maninka'), 60)
# 	(('s023', 'pular'), 60)
# 	(('s023', 'susu'), 54)
# 	(('s024', '_language_independent'), 75)
# 	(('s024', 'francais'), 60)
# 	(('s024', 'maninka'), 60)
# 	(('s024', 'susu'), 60)
# 	(('s025', '_language_independent'), 75)
# 	(('s025', 'francais'), 60)
# 	(('s025', 'maninka'), 60)
# 	(('s025', 'pular'), 60)
# 	(('s025', 'susu'), 60)
# 	(('s026', 'francais'), 60)
# 	(('s026', 'maninka'), 60)
# 	(('s026', 'susu'), 60)
# 	(('s027', '_language_independent'), 300)
# 	(('s027', 'francais'), 60)
# 	(('s027', 'maninka'), 60)
# 	(('s027', 'susu'), 60)
# 	(('s028', '_language_independent'), 300)
# 	(('s028', 'francais'), 60)
# 	(('s028', 'maninka'), 60)
# 	(('s028', 'susu'), 60)
# 	(('s029', '_language_independent'), 150)
# 	(('s029', 'francais'), 60)
# 	(('s029', 'susu'), 60)
# 	(('s030', '_language_independent'), 75)
# 	(('s030', 'francais'), 60)
# 	(('s032', '_language_independent'), 75)
# 	(('s032', 'francais'), 60)
# 	(('s032', 'maninka'), 60)
# 	(('s032', 'pular'), 60)
# 	(('s033', '_language_independent'), 75)
# 	(('s033', 'francais'), 60)
# 	(('s033', 'susu'), 60)
# 	(('s034', 'susu'), 60)
# Fold 4 -- TEST
# 	(('s001', '_language_independent'), 75)
# 	(('s001', 'maninka'), 54)
# 	(('s002', '_language_independent'), 75)
# 	(('s004', '_language_independent'), 75)
# 	(('s004', 'maninka'), 54)
# 	(('s009', 'francais'), 54)
# 	(('s011', 'susu'), 54)
# 	(('s014', '_language_independent'), 75)
# 	(('s014', 'maninka'), 54)
# 	(('s015', 'susu'), 54)
# 	(('s016', 'maninka'), 54)
# 	(('s017', 'francais'), 54)
# 	(('s017', 'pular'), 54)
# 	(('s018', '_language_independent'), 75)
# 	(('s018', 'susu'), 54)
# 	(('s019', '_language_independent'), 75)
# 	(('s019', 'francais'), 54)
# 	(('s019', 'maninka'), 54)
# 	(('s021', 'francais'), 54)
# 	(('s021', 'susu'), 36)
# 	(('s022', 'susu'), 54)
# 	(('s023', '_language_independent'), 75)
# 	(('s026', '_language_independent'), 72)
# 	(('s027', 'pular'), 60)
# 	(('s028', 'pular'), 60)
# 	(('s029', 'maninka'), 60)
# 	(('s029', 'pular'), 60)
# 	(('s030', 'pular'), 60)
# 	(('s031', '_language_independent'), 75)
# 	(('s031', 'francais'), 60)
# 	(('s031', 'pular'), 57)
# 	(('s031', 'susu'), 60)
# 	(('s032', 'susu'), 60)
# 	(('s033', 'maninka'), 60)
# 	(('s034', '_language_independent'), 75)
# 	(('s034', 'francais'), 60)
# 	(('s034', 'maninka'), 60)
# ---------------------

# %%
for fold_index in range(FOLD_COUNT):
    train_records = records_per_fold[fold_index]["train_records"]
    test_records = records_per_fold[fold_index]["test_records"]

    print(f"Fold {fold_index} -- TRAIN: ({len(train_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(train_records, ['language'])) if r[1]>0]

    print(f"Fold {fold_index} -- TEST: ({len(test_records)})")
    _ = [print(f"\t{r}") for r in sorted(count_by_attribute(test_records, ['language'])) if r[1]>0]
    
    print("---------------------")
# Out:
# Fold 0 -- TRAIN: (6018)
# 	(('_language_independent',), 2400)
# 	(('francais',), 738)
# 	(('maninka',), 960)
# 	(('pular',), 852)
# 	(('susu',), 1068)
# Fold 0 -- TEST: (2241)
# 	(('_language_independent',), 672)
# 	(('francais',), 522)
# 	(('maninka',), 396)
# 	(('pular',), 57)
# 	(('susu',), 594)
# ---------------------
# Fold 1 -- TRAIN: (5940)
# 	(('_language_independent',), 2325)
# 	(('francais',), 978)
# 	(('maninka',), 906)
# 	(('pular',), 519)
# 	(('susu',), 1212)
# Fold 1 -- TEST: (2319)
# 	(('_language_independent',), 747)
# 	(('francais',), 282)
# 	(('maninka',), 450)
# 	(('pular',), 390)
# 	(('susu',), 450)
# ---------------------
# Fold 2 -- TRAIN: (6036)
# 	(('_language_independent',), 2397)
# 	(('francais',), 972)
# 	(('maninka',), 912)
# 	(('pular',), 573)
# 	(('susu',), 1182)
# Fold 2 -- TEST: (2223)
# 	(('_language_independent',), 675)
# 	(('francais',), 288)
# 	(('maninka',), 444)
# 	(('pular',), 336)
# 	(('susu',), 480)
# ---------------------
# Fold 3 -- TRAIN: (5796)
# 	(('_language_independent',), 2097)
# 	(('francais',), 918)
# 	(('maninka',), 912)
# 	(('pular',), 801)
# 	(('susu',), 1068)
# Fold 3 -- TEST: (2463)
# 	(('_language_independent',), 975)
# 	(('francais',), 342)
# 	(('maninka',), 444)
# 	(('pular',), 108)
# 	(('susu',), 594)
# ---------------------
# Fold 4 -- TRAIN: (6003)
# 	(('_language_independent',), 2325)
# 	(('francais',), 924)
# 	(('maninka',), 906)
# 	(('pular',), 558)
# 	(('susu',), 1290)
# Fold 4 -- TEST: (2256)
# 	(('_language_independent',), 747)
# 	(('francais',), 336)
# 	(('maninka',), 450)
# 	(('pular',), 351)
# 	(('susu',), 372)
# ---------------------

# %% [markdown]
# ## Load Features

# %%
def load_features(records, feature_name):
    features_list = []
    
    features_input_dir = BASE_DIR / feature_name

    for r in records:
        feature_file_name = r['file'].replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            
            padded_features = np.zeros((MAX_FEATURE_SEQUENCE_LENGTH, 512), dtype=features.dtype)
            padded_features[:features_shape[0], :] = features
            
            
            features_list.append(padded_features)
    return features_list

# %%
def get_bias_category_labels(records):
    bias_category_labels = {}
    
    for cat in bias_categories:
        for cat_val in bias_categories[cat]:
            bias_category_labels[f"{cat}__{cat_val}"] = [1 if r[cat]==cat_val else 0 for r in records]
            
    return bias_category_labels

# %% [markdown]
# # Classification Models

# %%
class ASRCNN(nn.Module):
    def __init__(self, 
                 conv_pooling_type, 
                 conv_dropout_p, 
                 fc_dropout_p, 
                 voice_cmd_neuron_count, 
                 voice_cmd_lng_neuron_count,
                 objective_type
                ):
        
        super(ASRCNN, self).__init__()
        
        if conv_pooling_type not in {"max", "avg"}:
            raise ValueError(f"Unknown Conv Pooling Type: {conv_pooling_type}")
            
        conv_pooling_class_by_type = {
            "max": nn.MaxPool1d,
            "avg": nn.AvgPool1d,
        }
        
        conv_pooling_class = conv_pooling_class_by_type[conv_pooling_type]
        
        self.objective_type = objective_type
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=8, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=8, out_channels=8, kernel_size=3)
        self.drop1 = nn.Dropout(p=conv_dropout_p)
        self.pool1 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=8, out_channels=16, kernel_size=3)
        self.drop2 = nn.Dropout(p=conv_dropout_p)
        self.pool2 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3)
        self.drop3 = nn.Dropout(p=conv_dropout_p)
        self.pool3 = conv_pooling_class(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3)
        self.drop4 = nn.Dropout(p=conv_dropout_p)
        self.pool4 = conv_pooling_class(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)
        
        self.lin61 = nn.Linear(in_features=112, out_features=voice_cmd_neuron_count)
        
        # 'voice_cmd', 'voice_cmd__and__voice_cmd_lng'
        if self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            self.lin62 = nn.Linear(in_features=112, out_features=voice_cmd_lng_neuron_count)
                
    def forward(self, x):
        x = x.permute(0, 2, 1)
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        if self.objective_type == 'voice_cmd':
            logits_voice_cmd = self.lin61(v)
            return logits_voice_cmd
        elif self.objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd = self.lin61(v)
            logits_voice_cmd_lng = self.lin62(v)
            return logits_voice_cmd, logits_voice_cmd_lng
        else:
            raise(f"Unknown objective type: {self.objective_type}")

# %%
def get_data_for_fold(fold_id, feature_name):
    
    train_records = records_per_fold[fold_id]["train_records"]
    test_records = records_per_fold[fold_id]["test_records"]
    
    train_features = load_features(train_records, feature_name)
    test_features = load_features(test_records, feature_name)
    
    train_x = np.array(train_features)
    test_x = np.array(test_features)
    
    train_y = {}
    train_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in train_records])
    train_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in train_records])
    train_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in train_records])
    train_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in train_records])
    
    

    
    test_y = {}
    test_y['voice_cmd'] = np.array([voice_cmd_class_id_by_name[r['label']] for r in test_records])
    test_y['voice_cmd_lng'] = np.array([voice_cmd_lng_class_id_by_name[r['language']] for r in test_records])
    test_y['spkr_mothertongue'] = np.array([spkr_mothertongue_class_id_by_name[r['speaker_mothertongue']] for r in test_records])
    test_y['spkr_gender'] = np.array([spkr_gender_class_id_by_name[r['speaker_gender']] for r in test_records])

    train_bias_category_labels = get_bias_category_labels(train_records)
    test_bias_category_labels = get_bias_category_labels(test_records)
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y['voice_cmd']),
        torch.tensor(train_y['voice_cmd_lng']),
        # torch.tensor(train_y['spkr_mothertongue']),
        # torch.tensor(train_y['spkr_gender']),
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y['voice_cmd']),
        torch.tensor(test_y['voice_cmd_lng']),
        # torch.tensor(test_y['spkr_mothertongue']),
        # torch.tensor(test_y['spkr_gender']),
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
def train(model, optimizer, criterion, objective_type, train_loader):
    model.train()
    train_loss = 0

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(train_loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        optimizer.zero_grad()
        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs
            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs    
            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) / 2
            
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        

def test(model, criterion, objective_type, loader, bias_category_labels):
    model.eval()
    accumulated_loss = 0

    pred_classes = []
    true_classes = []

    pred_classes_lng = []
    true_classes_lng = []

    for batch_idx, (x, y_voice_cmd, y_voice_cmd_lng) in enumerate(loader):
        x = x.to(device)
        y_voice_cmd = y_voice_cmd.to(device)
        y_voice_cmd_lng = y_voice_cmd_lng.to(device)

        outputs = model(x)

        if objective_type == 'voice_cmd':
            logits_voice_cmd = outputs

            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            loss = criterion(logits_voice_cmd, y_voice_cmd)
        elif objective_type == 'voice_cmd__and__voice_cmd_lng':
            logits_voice_cmd, logits_voice_cmd_lng = outputs
            pred_classes.extend(
                get_predictions_for_logits(logits_voice_cmd).cpu().numpy()
            )
            true_classes.extend(y_voice_cmd.cpu().numpy())

            pred_classes_lng.extend(
                get_predictions_for_logits(logits_voice_cmd_lng).cpu().numpy()
            )
            true_classes_lng.extend(y_voice_cmd_lng.cpu().numpy())

            loss = (criterion(logits_voice_cmd, y_voice_cmd) + criterion(logits_voice_cmd_lng, y_voice_cmd_lng)) /2
        else:
            raise ValueError(f"Unknown objective type: {objective_type}")

        accumulated_loss += loss.item()

    n = len(true_classes)

    average_loss = accumulated_loss/n
    
    acc = sklearn.metrics.accuracy_score(true_classes, pred_classes)
    acc_by_bais_category = {
        category: sklearn.metrics.accuracy_score(true_classes, pred_classes, sample_weight=sw)
        for category, sw in bias_category_labels.items()
    }
    
    
    if objective_type == 'voice_cmd__and__voice_cmd_lng':
        acc_lng = sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng)
        acc_by_bais_category_lng = {
            category: sklearn.metrics.accuracy_score(true_classes_lng, pred_classes_lng, sample_weight=sw)
            for category, sw in bias_category_labels.items()
        }
    else:
        acc_lng = -1
        acc_by_bais_category_lng = {
            category: -1
            for category, sw in bias_category_labels.items()
        }
        
    return n, average_loss, acc, acc_by_bais_category, acc_lng, acc_by_bais_category_lng
      
        
def train_on_fold(model, fold_id, feature_name, objective_type, batch_size, epochs):
    torch.manual_seed(0)
    results = {}
    
    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model, torch.zeros((10, MAX_FEATURE_SEQUENCE_LENGTH, 512)).to(device), show_input=False))
    print(f"train_n: {len(train_loader.dataset)}")
    print(f"test_n: {len(test_loader.dataset)}")

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss(reduction='sum')

    for epoch in range(1, epochs+1):
        
        # train on training set
        train(model, optimizer, criterion, objective_type, train_loader)
        
        # test on training set
        train_n, train_average_loss, train_acc, train_acc_by_bais_category, train_acc_lng, train_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, train_loader, train_bias_category_labels)
        
        # test on test set
        test_n, test_average_loss, test_acc, test_acc_by_bais_category, test_acc_lng, test_acc_by_bais_category_lng = \
            test(model, criterion, objective_type, test_loader, test_bias_category_labels)
        

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_average_loss:0.4}. Test Loss: {test_average_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
         
        results[epoch] = {
            'epoch': epoch,
            
            'train_n': train_n,
            'train_loss': train_average_loss,
            'train_acc': train_acc,
            'train_acc_lng': train_acc_lng,
            
            'test_n': test_n,
            'test_loss': test_average_loss,
            'test_acc': test_acc,
            'test_acc_lng': test_acc_lng
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in train_acc_by_bais_category_lng:
            results[epoch][f"train_acc_lng_{c}"] = train_acc_by_bais_category_lng[c]
            
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))

        for c in test_acc_by_bais_category_lng:
            results[epoch][f"test_acc_lng_{c}"] = test_acc_by_bais_category_lng[c]
            

    return results

# %%
import csv
from pathlib import Path

def results_exist(model_name, feature_name, fold_id):
    fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_id}.csv"
    return Path(fname).is_file()
    
    

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='raise')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
trial_params = list(
    itertools.product(
        range(FOLD_COUNT),
        CONV_POOLING_TYPES,
        CONV_DROPOUT_PROBABILITIES,
        FC_DROPOUT_PROBABILITIES,
        FEATURE_NAMES, 
        OBJECTIVE_TYPES
    )
)    

print("Plan:")
_ = [print(t) for t in trial_params]
print()

for fold_id, conv_pooling_type, conv_dropout_p, fc_dropout_p, feature_name, objective_type in trial_params:

    model_name = f"ASRCNN" + \
    f"__conv_pool_{conv_pooling_type}" + \
    f"__conv_dp_{conv_dropout_p}" + \
    f"__fc_dp_{fc_dropout_p}" + \
    f"__fn_{feature_name}" + \
    f"__obj_{objective_type}"
    
    if results_exist(model_name, feature_name, fold_id):
        print(f"skipping ({fold_id}, {conv_pooling_type}, {conv_dropout_p}, {fc_dropout_p}, {feature_name}, {objective_type})")
        continue
    
    model = ASRCNN(
        conv_pooling_type, 
        conv_dropout_p, 
        fc_dropout_p, 
        voice_cmd_neuron_count = voice_cmd_class_count, 
        voice_cmd_lng_neuron_count = voice_cmd_lng_class_count,
        objective_type = objective_type
    ).to(device)

    print(f"{model_name} using {feature_name} on fold#{fold_id}")

    epochs_results = train_on_fold(
        model, 
        fold_id, 
        feature_name, 
        objective_type, 
        batch_size = BATCH_SIZE, 
        epochs = EPOCHS
    )

    # results for only one fold
    folds_results = [{
        'fold_index': fold_id,
        'feature_name': feature_name,
        'epochs': epochs_results
    }]
    
    
    save_results(model_name, folds_results)
    # write_epoch_test_logits(model_name, all_folds_results)

    del model
# Out:
# Plan:
# (0, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (0, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (0, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (0, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (0, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (0, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (0, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (1, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (1, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (1, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (1, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (1, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (2, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (2, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (2, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (2, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (2, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (3, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (3, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (3, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (3, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (3, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd')
# (4, 'avg', 0.2, 0.2, 'wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd')
# (4, 'avg', 0.2, 0.2, 'wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd')
# (4, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-c', 'voice_cmd__and__voice_cmd_lng')
# (4, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd')
# (4, 'avg', 0.2, 0.2, 'retrained-wav2vec_features-z', 'voice_cmd__and__voice_cmd_lng')
#
# ASRCNN__conv_pool_avg__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-c__obj_voice_cmd using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.857. Test Loss: 3.967. Train Acc: 0.08259. Test Acc:0.06203
# Epoch: 20. Train Loss: 3.015. Test Loss: 3.202. Train Acc: 0.2218. Test Acc:0.1816
# Epoch: 30. Train Loss: 2.454. Test Loss: 2.707. Train Acc: 0.3518. Test Acc:0.2914
# Epoch: 40. Train Loss: 2.074. Test Loss: 2.423. Train Acc: 0.4618. Test Acc:0.3771
# Epoch: 50. Train Loss: 1.711. Test Loss: 2.121. Train Acc: 0.5513. Test Acc:0.4373
# Epoch: 60. Train Loss: 1.469. Test Loss: 1.896. Train Acc: 0.6195. Test Acc:0.5042
# Epoch: 70. Train Loss: 1.277. Test Loss: 1.722. Train Acc: 0.671. Test Acc:0.5533
# Epoch: 80. Train Loss: 1.092. Test Loss: 1.54. Train Acc: 0.7257. Test Acc:0.5939
# Epoch: 90. Train Loss: 0.9499. Test Loss: 1.408. Train Acc: 0.7637. Test Acc:0.6261
# Epoch: 100. Train Loss: 0.8363. Test Loss: 1.311. Train Acc: 0.7968. Test Acc:0.6533
# Epoch: 110. Train Loss: 0.7577. Test Loss: 1.249. Train Acc: 0.8142. Test Acc:0.6685
# Epoch: 120. Train Loss: 0.6689. Test Loss: 1.19. Train Acc: 0.8446. Test Acc:0.6912
# Epoch: 130. Train Loss: 0.6066. Test Loss: 1.135. Train Acc: 0.8606. Test Acc:0.7091
# Epoch: 140. Train Loss: 0.5518. Test Loss: 1.091. Train Acc: 0.8717. Test Acc:0.7171
# Epoch: 150. Train Loss: 0.514. Test Loss: 1.057. Train Acc: 0.8835. Test Acc:0.7287
# Epoch: 160. Train Loss: 0.5024. Test Loss: 1.05. Train Acc: 0.8833. Test Acc:0.7345
# Epoch: 170. Train Loss: 0.4529. Test Loss: 1.018. Train Acc: 0.899. Test Acc:0.7349
# Epoch: 180. Train Loss: 0.4224. Test Loss: 0.9932. Train Acc: 0.9073. Test Acc:0.7474
# Epoch: 190. Train Loss: 0.3945. Test Loss: 0.9692. Train Acc: 0.9139. Test Acc:0.7568
# Epoch: 200. Train Loss: 0.3745. Test Loss: 0.9657. Train Acc: 0.9146. Test Acc:0.7546
# Epoch: 210. Train Loss: 0.357. Test Loss: 0.9481. Train Acc: 0.9202. Test Acc:0.7622
# Epoch: 220. Train Loss: 0.3317. Test Loss: 0.9315. Train Acc: 0.9271. Test Acc:0.7644
# Epoch: 230. Train Loss: 0.323. Test Loss: 0.9178. Train Acc: 0.9262. Test Acc:0.7706
# Epoch: 240. Train Loss: 0.3045. Test Loss: 0.9149. Train Acc: 0.9322. Test Acc:0.7729
# Epoch: 250. Train Loss: 0.2928. Test Loss: 0.9084. Train Acc: 0.9357. Test Acc:0.772
# Epoch: 260. Train Loss: 0.28. Test Loss: 0.9033. Train Acc: 0.9365. Test Acc:0.7733
# Epoch: 270. Train Loss: 0.2615. Test Loss: 0.9034. Train Acc: 0.9418. Test Acc:0.7755
# Epoch: 280. Train Loss: 0.2551. Test Loss: 0.9191. Train Acc: 0.9438. Test Acc:0.7836
# Epoch: 290. Train Loss: 0.2403. Test Loss: 0.8735. Train Acc: 0.9503. Test Acc:0.7876
# Epoch: 300. Train Loss: 0.2332. Test Loss: 0.8685. Train Acc: 0.9505. Test Acc:0.7867
# Epoch: 310. Train Loss: 0.2251. Test Loss: 0.8793. Train Acc: 0.9503. Test Acc:0.7925
# Epoch: 320. Train Loss: 0.2208. Test Loss: 0.8695. Train Acc: 0.9516. Test Acc:0.7898
# Epoch: 330. Train Loss: 0.2113. Test Loss: 0.8663. Train Acc: 0.9546. Test Acc:0.7979
# Epoch: 340. Train Loss: 0.204. Test Loss: 0.8671. Train Acc: 0.9548. Test Acc:0.7938
# Epoch: 350. Train Loss: 0.1901. Test Loss: 0.859. Train Acc: 0.9603. Test Acc:0.7983
# Epoch: 360. Train Loss: 0.1817. Test Loss: 0.8609. Train Acc: 0.9616. Test Acc:0.7974
# Epoch: 370. Train Loss: 0.1874. Test Loss: 0.8485. Train Acc: 0.958. Test Acc:0.7996
# Epoch: 380. Train Loss: 0.1725. Test Loss: 0.8617. Train Acc: 0.9621. Test Acc:0.8019
# Epoch: 390. Train Loss: 0.1645. Test Loss: 0.8555. Train Acc: 0.9643. Test Acc:0.8059
# Epoch: 400. Train Loss: 0.1577. Test Loss: 0.8705. Train Acc: 0.9674. Test Acc:0.8019
# Epoch: 410. Train Loss: 0.1581. Test Loss: 0.8786. Train Acc: 0.9649. Test Acc:0.8001
# Epoch: 420. Train Loss: 0.1469. Test Loss: 0.8742. Train Acc: 0.9686. Test Acc:0.8001
# Epoch: 430. Train Loss: 0.142. Test Loss: 0.8766. Train Acc: 0.9708. Test Acc:0.8099
# Epoch: 440. Train Loss: 0.1431. Test Loss: 0.8652. Train Acc: 0.9686. Test Acc:0.805
# Epoch: 450. Train Loss: 0.1359. Test Loss: 0.8786. Train Acc: 0.9691. Test Acc:0.8046
# Epoch: 460. Train Loss: 0.1328. Test Loss: 0.8589. Train Acc: 0.9696. Test Acc:0.8072
# Epoch: 470. Train Loss: 0.1242. Test Loss: 0.875. Train Acc: 0.9736. Test Acc:0.8072
# Epoch: 480. Train Loss: 0.1203. Test Loss: 0.8746. Train Acc: 0.9727. Test Acc:0.8019
# Epoch: 490. Train Loss: 0.1214. Test Loss: 0.868. Train Acc: 0.9729. Test Acc:0.813
# Epoch: 500. Train Loss: 0.1176. Test Loss: 0.8744. Train Acc: 0.9724. Test Acc:0.809
# Epoch: 510. Train Loss: 0.1099. Test Loss: 0.8872. Train Acc: 0.9744. Test Acc:0.8068
# Epoch: 520. Train Loss: 0.1149. Test Loss: 0.8826. Train Acc: 0.9726. Test Acc:0.8059
# Epoch: 530. Train Loss: 0.1062. Test Loss: 0.9073. Train Acc: 0.9744. Test Acc:0.805
# Epoch: 540. Train Loss: 0.1036. Test Loss: 0.8947. Train Acc: 0.9767. Test Acc:0.8095
# Epoch: 550. Train Loss: 0.105. Test Loss: 0.8989. Train Acc: 0.9732. Test Acc:0.8041
# Epoch: 560. Train Loss: 0.1071. Test Loss: 0.921. Train Acc: 0.9716. Test Acc:0.801
# Epoch: 570. Train Loss: 0.1014. Test Loss: 0.9192. Train Acc: 0.9759. Test Acc:0.8041
# Epoch: 580. Train Loss: 0.09418. Test Loss: 0.9081. Train Acc: 0.9777. Test Acc:0.8086
# Epoch: 590. Train Loss: 0.08551. Test Loss: 0.9112. Train Acc: 0.9812. Test Acc:0.8104
# Epoch: 600. Train Loss: 0.08285. Test Loss: 0.9141. Train Acc: 0.9816. Test Acc:0.8121
# Epoch: 610. Train Loss: 0.0883. Test Loss: 0.9162. Train Acc: 0.9802. Test Acc:0.8086
# Epoch: 620. Train Loss: 0.07992. Test Loss: 0.9157. Train Acc: 0.9816. Test Acc:0.8086
# Epoch: 630. Train Loss: 0.09562. Test Loss: 0.9338. Train Acc: 0.9784. Test Acc:0.8054
# Epoch: 640. Train Loss: 0.08181. Test Loss: 0.9215. Train Acc: 0.9784. Test Acc:0.8077
# Epoch: 650. Train Loss: 0.07508. Test Loss: 0.9228. Train Acc: 0.9812. Test Acc:0.8086
# Epoch: 660. Train Loss: 0.07501. Test Loss: 0.911. Train Acc: 0.9821. Test Acc:0.8126
# Epoch: 670. Train Loss: 0.08049. Test Loss: 0.9501. Train Acc: 0.9791. Test Acc:0.8032
# Epoch: 680. Train Loss: 0.06923. Test Loss: 0.954. Train Acc: 0.985. Test Acc:0.8112
# Epoch: 690. Train Loss: 0.0701. Test Loss: 0.9784. Train Acc: 0.9847. Test Acc:0.8023
# Epoch: 700. Train Loss: 0.06386. Test Loss: 0.9642. Train Acc: 0.9865. Test Acc:0.8108
# Epoch: 710. Train Loss: 0.06375. Test Loss: 0.9652. Train Acc: 0.9854. Test Acc:0.8117
# Epoch: 720. Train Loss: 0.05693. Test Loss: 0.9479. Train Acc: 0.9867. Test Acc:0.8157
# Epoch: 730. Train Loss: 0.06795. Test Loss: 0.9918. Train Acc: 0.9826. Test Acc:0.8028
# Epoch: 740. Train Loss: 0.05631. Test Loss: 0.9899. Train Acc: 0.9882. Test Acc:0.8077
# Epoch: 750. Train Loss: 0.05464. Test Loss: 0.9752. Train Acc: 0.9885. Test Acc:0.8148
# Epoch: 760. Train Loss: 0.05361. Test Loss: 0.9809. Train Acc: 0.9879. Test Acc:0.8077
# Epoch: 770. Train Loss: 0.05607. Test Loss: 0.9854. Train Acc: 0.987. Test Acc:0.8112
# Epoch: 780. Train Loss: 0.05206. Test Loss: 0.9972. Train Acc: 0.9887. Test Acc:0.8081
# Epoch: 790. Train Loss: 0.05041. Test Loss: 0.9747. Train Acc: 0.9894. Test Acc:0.8081
# Epoch: 800. Train Loss: 0.04762. Test Loss: 0.9825. Train Acc: 0.9904. Test Acc:0.8086
# Epoch: 810. Train Loss: 0.05372. Test Loss: 0.97. Train Acc: 0.9877. Test Acc:0.8068
# Epoch: 820. Train Loss: 0.04731. Test Loss: 0.9747. Train Acc: 0.9899. Test Acc:0.8112
# Epoch: 830. Train Loss: 0.04453. Test Loss: 0.9711. Train Acc: 0.9914. Test Acc:0.817
# Epoch: 840. Train Loss: 0.04112. Test Loss: 0.9645. Train Acc: 0.9922. Test Acc:0.8139
# Epoch: 850. Train Loss: 0.04093. Test Loss: 0.9996. Train Acc: 0.9919. Test Acc:0.813
# Epoch: 860. Train Loss: 0.03893. Test Loss: 0.9756. Train Acc: 0.9927. Test Acc:0.8148
# Epoch: 870. Train Loss: 0.04188. Test Loss: 0.9996. Train Acc: 0.9897. Test Acc:0.8063
# Epoch: 880. Train Loss: 0.04354. Test Loss: 1.032. Train Acc: 0.9905. Test Acc:0.8014
# Epoch: 890. Train Loss: 0.0392. Test Loss: 1.021. Train Acc: 0.9915. Test Acc:0.8037
# Epoch: 900. Train Loss: 0.03665. Test Loss: 1.006. Train Acc: 0.9922. Test Acc:0.8095
# Epoch: 910. Train Loss: 0.03615. Test Loss: 1.021. Train Acc: 0.9927. Test Acc:0.809
# Epoch: 920. Train Loss: 0.03228. Test Loss: 1.011. Train Acc: 0.9932. Test Acc:0.8126
# Epoch: 930. Train Loss: 0.03068. Test Loss: 0.9874. Train Acc: 0.9939. Test Acc:0.8104
# Epoch: 940. Train Loss: 0.03394. Test Loss: 1.051. Train Acc: 0.992. Test Acc:0.8032
# Epoch: 950. Train Loss: 0.03132. Test Loss: 1.029. Train Acc: 0.9925. Test Acc:0.8126
# Epoch: 960. Train Loss: 0.03704. Test Loss: 1.049. Train Acc: 0.9912. Test Acc:0.8046
# Epoch: 970. Train Loss: 0.03054. Test Loss: 1.041. Train Acc: 0.9947. Test Acc:0.8081
# Epoch: 980. Train Loss: 0.0341. Test Loss: 1.063. Train Acc: 0.9924. Test Acc:0.8095
# Epoch: 990. Train Loss: 0.02905. Test Loss: 1.039. Train Acc: 0.9934. Test Acc:0.8095
# Epoch: 1000. Train Loss: 0.02835. Test Loss: 1.019. Train Acc: 0.9939. Test Acc:0.8139
# ASRCNN__conv_pool_avg__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-c__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.429. Test Loss: 2.598. Train Acc: 0.1275. Test Acc:0.09237
# Epoch: 20. Train Loss: 2.077. Test Loss: 2.275. Train Acc: 0.2498. Test Acc:0.2142
# Epoch: 30. Train Loss: 1.829. Test Loss: 2.061. Train Acc: 0.3719. Test Acc:0.2865
# Epoch: 40. Train Loss: 1.605. Test Loss: 1.87. Train Acc: 0.4701. Test Acc:0.3739
# Epoch: 50. Train Loss: 1.419. Test Loss: 1.701. Train Acc: 0.5502. Test Acc:0.4395
# Epoch: 60. Train Loss: 1.255. Test Loss: 1.56. Train Acc: 0.6324. Test Acc:0.5127
# Epoch: 70. Train Loss: 1.134. Test Loss: 1.459. Train Acc: 0.6785. Test Acc:0.5457
# Epoch: 80. Train Loss: 1.036. Test Loss: 1.378. Train Acc: 0.7175. Test Acc:0.5926
# Epoch: 90. Train Loss: 0.9514. Test Loss: 1.29. Train Acc: 0.7512. Test Acc:0.6145
# Epoch: 100. Train Loss: 0.8869. Test Loss: 1.233. Train Acc: 0.7725. Test Acc:0.6216
# Epoch: 110. Train Loss: 0.8363. Test Loss: 1.19. Train Acc: 0.7915. Test Acc:0.6341
# Epoch: 120. Train Loss: 0.791. Test Loss: 1.148. Train Acc: 0.8072. Test Acc:0.6421
# Epoch: 130. Train Loss: 0.746. Test Loss: 1.115. Train Acc: 0.8239. Test Acc:0.6568
# Epoch: 140. Train Loss: 0.7109. Test Loss: 1.082. Train Acc: 0.8342. Test Acc:0.6707
# Epoch: 150. Train Loss: 0.6786. Test Loss: 1.07. Train Acc: 0.8465. Test Acc:0.6801
# Epoch: 160. Train Loss: 0.6558. Test Loss: 1.047. Train Acc: 0.8526. Test Acc:0.6809
# Epoch: 170. Train Loss: 0.6163. Test Loss: 1.025. Train Acc: 0.8712. Test Acc:0.6934
# Epoch: 180. Train Loss: 0.5969. Test Loss: 1.026. Train Acc: 0.876. Test Acc:0.7015
# Epoch: 190. Train Loss: 0.5756. Test Loss: 1.005. Train Acc: 0.8765. Test Acc:0.7015
# Epoch: 200. Train Loss: 0.5452. Test Loss: 0.984. Train Acc: 0.8898. Test Acc:0.7144
# Epoch: 210. Train Loss: 0.525. Test Loss: 0.9732. Train Acc: 0.8955. Test Acc:0.7149
# Epoch: 220. Train Loss: 0.502. Test Loss: 0.9614. Train Acc: 0.8988. Test Acc:0.7202
# Epoch: 230. Train Loss: 0.483. Test Loss: 0.9735. Train Acc: 0.9033. Test Acc:0.73
# Epoch: 240. Train Loss: 0.4691. Test Loss: 0.9343. Train Acc: 0.9041. Test Acc:0.7269
# Epoch: 250. Train Loss: 0.4434. Test Loss: 0.9372. Train Acc: 0.9119. Test Acc:0.7287
# Epoch: 260. Train Loss: 0.4256. Test Loss: 0.9437. Train Acc: 0.9154. Test Acc:0.7345
# Epoch: 270. Train Loss: 0.409. Test Loss: 0.9241. Train Acc: 0.9217. Test Acc:0.7394
# Epoch: 280. Train Loss: 0.4045. Test Loss: 0.9417. Train Acc: 0.9181. Test Acc:0.7367
# Epoch: 290. Train Loss: 0.3846. Test Loss: 0.9167. Train Acc: 0.9239. Test Acc:0.7412
# Epoch: 300. Train Loss: 0.3675. Test Loss: 0.9127. Train Acc: 0.9284. Test Acc:0.7479
# Epoch: 310. Train Loss: 0.3529. Test Loss: 0.9006. Train Acc: 0.9317. Test Acc:0.751
# Epoch: 320. Train Loss: 0.3371. Test Loss: 0.909. Train Acc: 0.9364. Test Acc:0.751
# Epoch: 330. Train Loss: 0.3297. Test Loss: 0.8791. Train Acc: 0.9349. Test Acc:0.7541
# Epoch: 340. Train Loss: 0.3188. Test Loss: 0.9307. Train Acc: 0.938. Test Acc:0.7479
# Epoch: 350. Train Loss: 0.3067. Test Loss: 0.904. Train Acc: 0.9417. Test Acc:0.7564
# Epoch: 360. Train Loss: 0.2941. Test Loss: 0.9048. Train Acc: 0.9422. Test Acc:0.7546
# Epoch: 370. Train Loss: 0.2872. Test Loss: 0.887. Train Acc: 0.9452. Test Acc:0.7581
# Epoch: 380. Train Loss: 0.2818. Test Loss: 0.9355. Train Acc: 0.9432. Test Acc:0.7555
# Epoch: 390. Train Loss: 0.2686. Test Loss: 0.8869. Train Acc: 0.9478. Test Acc:0.7639
# Epoch: 400. Train Loss: 0.2594. Test Loss: 0.8925. Train Acc: 0.9513. Test Acc:0.7564
# Epoch: 410. Train Loss: 0.256. Test Loss: 0.9255. Train Acc: 0.9515. Test Acc:0.7581
# Epoch: 420. Train Loss: 0.2442. Test Loss: 0.9119. Train Acc: 0.9536. Test Acc:0.7604
# Epoch: 430. Train Loss: 0.2398. Test Loss: 0.8874. Train Acc: 0.9528. Test Acc:0.7666
# Epoch: 440. Train Loss: 0.2381. Test Loss: 0.9027. Train Acc: 0.9548. Test Acc:0.7662
# Epoch: 450. Train Loss: 0.2367. Test Loss: 0.9181. Train Acc: 0.9543. Test Acc:0.7684
# Epoch: 460. Train Loss: 0.2222. Test Loss: 0.8842. Train Acc: 0.958. Test Acc:0.7715
# Epoch: 470. Train Loss: 0.2133. Test Loss: 0.8973. Train Acc: 0.959. Test Acc:0.7653
# Epoch: 480. Train Loss: 0.2068. Test Loss: 0.8742. Train Acc: 0.9603. Test Acc:0.7738
# Epoch: 490. Train Loss: 0.203. Test Loss: 0.9335. Train Acc: 0.9618. Test Acc:0.7693
# Epoch: 500. Train Loss: 0.1977. Test Loss: 0.9277. Train Acc: 0.9614. Test Acc:0.7689
# Epoch: 510. Train Loss: 0.1919. Test Loss: 0.9548. Train Acc: 0.9643. Test Acc:0.7671
# Epoch: 520. Train Loss: 0.1966. Test Loss: 0.9732. Train Acc: 0.9623. Test Acc:0.7648
# Epoch: 530. Train Loss: 0.1855. Test Loss: 0.8847. Train Acc: 0.9643. Test Acc:0.7738
# Epoch: 540. Train Loss: 0.1816. Test Loss: 0.9706. Train Acc: 0.9636. Test Acc:0.7631
# Epoch: 550. Train Loss: 0.1734. Test Loss: 0.9156. Train Acc: 0.9669. Test Acc:0.7729
# Epoch: 560. Train Loss: 0.1695. Test Loss: 0.9817. Train Acc: 0.9679. Test Acc:0.7581
# Epoch: 570. Train Loss: 0.1803. Test Loss: 0.984. Train Acc: 0.9651. Test Acc:0.7639
# Epoch: 580. Train Loss: 0.1643. Test Loss: 0.9755. Train Acc: 0.9679. Test Acc:0.7608
# Epoch: 590. Train Loss: 0.1634. Test Loss: 0.9847. Train Acc: 0.9674. Test Acc:0.7622
# Epoch: 600. Train Loss: 0.1604. Test Loss: 0.9795. Train Acc: 0.9689. Test Acc:0.7671
# Epoch: 610. Train Loss: 0.1586. Test Loss: 0.9818. Train Acc: 0.9693. Test Acc:0.7599
# Epoch: 620. Train Loss: 0.1591. Test Loss: 0.9495. Train Acc: 0.9688. Test Acc:0.7711
# Epoch: 630. Train Loss: 0.1581. Test Loss: 0.9659. Train Acc: 0.9709. Test Acc:0.7671
# Epoch: 640. Train Loss: 0.1604. Test Loss: 0.9976. Train Acc: 0.9673. Test Acc:0.7595
# Epoch: 650. Train Loss: 0.1517. Test Loss: 1.006. Train Acc: 0.9701. Test Acc:0.759
# Epoch: 660. Train Loss: 0.1401. Test Loss: 0.962. Train Acc: 0.9701. Test Acc:0.7648
# Epoch: 670. Train Loss: 0.1436. Test Loss: 0.9346. Train Acc: 0.9714. Test Acc:0.7764
# Epoch: 680. Train Loss: 0.1342. Test Loss: 0.9571. Train Acc: 0.9722. Test Acc:0.7639
# Epoch: 690. Train Loss: 0.1298. Test Loss: 0.9273. Train Acc: 0.9742. Test Acc:0.7675
# Epoch: 700. Train Loss: 0.1372. Test Loss: 0.9739. Train Acc: 0.9734. Test Acc:0.7666
# Epoch: 710. Train Loss: 0.1264. Test Loss: 0.9434. Train Acc: 0.9744. Test Acc:0.7782
# Epoch: 720. Train Loss: 0.1235. Test Loss: 0.9392. Train Acc: 0.9726. Test Acc:0.7689
# Epoch: 730. Train Loss: 0.1193. Test Loss: 0.9343. Train Acc: 0.9759. Test Acc:0.772
# Epoch: 740. Train Loss: 0.119. Test Loss: 0.9605. Train Acc: 0.9749. Test Acc:0.7626
# Epoch: 750. Train Loss: 0.1138. Test Loss: 0.9554. Train Acc: 0.9774. Test Acc:0.7666
# Epoch: 760. Train Loss: 0.1174. Test Loss: 0.944. Train Acc: 0.9754. Test Acc:0.7702
# Epoch: 770. Train Loss: 0.1112. Test Loss: 0.927. Train Acc: 0.9767. Test Acc:0.7697
# Epoch: 780. Train Loss: 0.1143. Test Loss: 0.9147. Train Acc: 0.9739. Test Acc:0.7751
# Epoch: 790. Train Loss: 0.1084. Test Loss: 0.9577. Train Acc: 0.9757. Test Acc:0.7666
# Epoch: 800. Train Loss: 0.1046. Test Loss: 0.9675. Train Acc: 0.9777. Test Acc:0.7666
# Epoch: 810. Train Loss: 0.1113. Test Loss: 0.9238. Train Acc: 0.9759. Test Acc:0.7751
# Epoch: 820. Train Loss: 0.1256. Test Loss: 0.9617. Train Acc: 0.9711. Test Acc:0.7644
# Epoch: 830. Train Loss: 0.116. Test Loss: 0.9636. Train Acc: 0.9729. Test Acc:0.7635
# Epoch: 840. Train Loss: 0.1142. Test Loss: 0.9662. Train Acc: 0.9744. Test Acc:0.7644
# Epoch: 850. Train Loss: 0.09799. Test Loss: 0.9552. Train Acc: 0.9796. Test Acc:0.7742
# Epoch: 860. Train Loss: 0.1033. Test Loss: 0.9533. Train Acc: 0.9782. Test Acc:0.7729
# Epoch: 870. Train Loss: 0.1081. Test Loss: 1.036. Train Acc: 0.9774. Test Acc:0.7626
# Epoch: 880. Train Loss: 0.09813. Test Loss: 0.9895. Train Acc: 0.9792. Test Acc:0.7706
# Epoch: 890. Train Loss: 0.1107. Test Loss: 1.019. Train Acc: 0.9764. Test Acc:0.7689
# Epoch: 900. Train Loss: 0.09462. Test Loss: 0.9648. Train Acc: 0.9782. Test Acc:0.7724
# Epoch: 910. Train Loss: 0.08997. Test Loss: 0.982. Train Acc: 0.9789. Test Acc:0.7724
# Epoch: 920. Train Loss: 0.08871. Test Loss: 1.025. Train Acc: 0.9801. Test Acc:0.7577
# Epoch: 930. Train Loss: 0.0913. Test Loss: 1.047. Train Acc: 0.9797. Test Acc:0.7639
# Epoch: 940. Train Loss: 0.08792. Test Loss: 0.9864. Train Acc: 0.9806. Test Acc:0.7724
# Epoch: 950. Train Loss: 0.083. Test Loss: 0.9745. Train Acc: 0.9819. Test Acc:0.7724
# Epoch: 960. Train Loss: 0.08431. Test Loss: 0.9609. Train Acc: 0.9814. Test Acc:0.776
# Epoch: 970. Train Loss: 0.07771. Test Loss: 0.9831. Train Acc: 0.9829. Test Acc:0.7689
# Epoch: 980. Train Loss: 0.07895. Test Loss: 0.9897. Train Acc: 0.9817. Test Acc:0.7738
# Epoch: 990. Train Loss: 0.07995. Test Loss: 1.02. Train Acc: 0.9812. Test Acc:0.7671
# Epoch: 1000. Train Loss: 0.08386. Test Loss: 1.025. Train Acc: 0.9782. Test Acc:0.7617
# ASRCNN__conv_pool_avg__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-z__obj_voice_cmd using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.971. Test Loss: 4.063. Train Acc: 0.07178. Test Acc:0.05667
# Epoch: 20. Train Loss: 3.313. Test Loss: 3.489. Train Acc: 0.1401. Test Acc:0.1124
# Epoch: 30. Train Loss: 3.024. Test Loss: 3.242. Train Acc: 0.2203. Test Acc:0.1798
# Epoch: 40. Train Loss: 2.716. Test Loss: 2.998. Train Acc: 0.2941. Test Acc:0.2414
# Epoch: 50. Train Loss: 2.394. Test Loss: 2.729. Train Acc: 0.3853. Test Acc:0.3048
# Epoch: 60. Train Loss: 2.113. Test Loss: 2.484. Train Acc: 0.455. Test Acc:0.3606
# Epoch: 70. Train Loss: 1.885. Test Loss: 2.302. Train Acc: 0.5113. Test Acc:0.4061
# Epoch: 80. Train Loss: 1.689. Test Loss: 2.115. Train Acc: 0.5641. Test Acc:0.4547
# Epoch: 90. Train Loss: 1.537. Test Loss: 1.979. Train Acc: 0.6017. Test Acc:0.4873
# Epoch: 100. Train Loss: 1.386. Test Loss: 1.842. Train Acc: 0.6442. Test Acc:0.5243
# Epoch: 110. Train Loss: 1.281. Test Loss: 1.748. Train Acc: 0.6728. Test Acc:0.5556
# Epoch: 120. Train Loss: 1.17. Test Loss: 1.65. Train Acc: 0.7094. Test Acc:0.585
# Epoch: 130. Train Loss: 1.089. Test Loss: 1.578. Train Acc: 0.7301. Test Acc:0.6011
# Epoch: 140. Train Loss: 1.007. Test Loss: 1.508. Train Acc: 0.7552. Test Acc:0.6225
# Epoch: 150. Train Loss: 0.9479. Test Loss: 1.458. Train Acc: 0.7699. Test Acc:0.6323
# Epoch: 160. Train Loss: 0.8954. Test Loss: 1.418. Train Acc: 0.782. Test Acc:0.6448
# Epoch: 170. Train Loss: 0.8427. Test Loss: 1.378. Train Acc: 0.7986. Test Acc:0.6537
# Epoch: 180. Train Loss: 0.8051. Test Loss: 1.347. Train Acc: 0.8033. Test Acc:0.6622
# Epoch: 190. Train Loss: 0.7483. Test Loss: 1.298. Train Acc: 0.8222. Test Acc:0.6805
# Epoch: 200. Train Loss: 0.7134. Test Loss: 1.286. Train Acc: 0.8307. Test Acc:0.6854
# Epoch: 210. Train Loss: 0.6765. Test Loss: 1.234. Train Acc: 0.8396. Test Acc:0.6979
# Epoch: 220. Train Loss: 0.647. Test Loss: 1.221. Train Acc: 0.8461. Test Acc:0.7019
# Epoch: 230. Train Loss: 0.6119. Test Loss: 1.172. Train Acc: 0.8519. Test Acc:0.7104
# Epoch: 240. Train Loss: 0.5808. Test Loss: 1.15. Train Acc: 0.8656. Test Acc:0.7171
# Epoch: 250. Train Loss: 0.5543. Test Loss: 1.129. Train Acc: 0.8704. Test Acc:0.7207
# Epoch: 260. Train Loss: 0.5287. Test Loss: 1.129. Train Acc: 0.8812. Test Acc:0.7274
# Epoch: 270. Train Loss: 0.5021. Test Loss: 1.089. Train Acc: 0.8843. Test Acc:0.7278
# Epoch: 280. Train Loss: 0.4762. Test Loss: 1.069. Train Acc: 0.891. Test Acc:0.7398
# Epoch: 290. Train Loss: 0.4558. Test Loss: 1.054. Train Acc: 0.893. Test Acc:0.7385
# Epoch: 300. Train Loss: 0.4457. Test Loss: 1.034. Train Acc: 0.8976. Test Acc:0.7403
# Epoch: 310. Train Loss: 0.4259. Test Loss: 1.024. Train Acc: 0.902. Test Acc:0.7488
# Epoch: 320. Train Loss: 0.4086. Test Loss: 1.017. Train Acc: 0.9053. Test Acc:0.7474
# Epoch: 330. Train Loss: 0.3906. Test Loss: 1.031. Train Acc: 0.9131. Test Acc:0.7488
# Epoch: 340. Train Loss: 0.3831. Test Loss: 1.026. Train Acc: 0.9121. Test Acc:0.7532
# Epoch: 350. Train Loss: 0.3699. Test Loss: 1.014. Train Acc: 0.9164. Test Acc:0.7532
# Epoch: 360. Train Loss: 0.3628. Test Loss: 1.01. Train Acc: 0.9138. Test Acc:0.755
# Epoch: 370. Train Loss: 0.3573. Test Loss: 0.9998. Train Acc: 0.9171. Test Acc:0.7541
# Epoch: 380. Train Loss: 0.3508. Test Loss: 1.004. Train Acc: 0.9171. Test Acc:0.7595
# Epoch: 390. Train Loss: 0.3489. Test Loss: 1.002. Train Acc: 0.9172. Test Acc:0.7555
# Epoch: 400. Train Loss: 0.3222. Test Loss: 0.9962. Train Acc: 0.9247. Test Acc:0.7648
# Epoch: 410. Train Loss: 0.3327. Test Loss: 1.001. Train Acc: 0.9207. Test Acc:0.7586
# Epoch: 420. Train Loss: 0.3093. Test Loss: 0.9857. Train Acc: 0.928. Test Acc:0.7644
# Epoch: 430. Train Loss: 0.2988. Test Loss: 0.9894. Train Acc: 0.931. Test Acc:0.7631
# Epoch: 440. Train Loss: 0.2829. Test Loss: 0.9976. Train Acc: 0.9364. Test Acc:0.7684
# Epoch: 450. Train Loss: 0.2748. Test Loss: 0.9918. Train Acc: 0.94. Test Acc:0.7706
# Epoch: 460. Train Loss: 0.2665. Test Loss: 0.9942. Train Acc: 0.9405. Test Acc:0.7671
# Epoch: 470. Train Loss: 0.2618. Test Loss: 1.014. Train Acc: 0.9407. Test Acc:0.7675
# Epoch: 480. Train Loss: 0.2541. Test Loss: 1.009. Train Acc: 0.9422. Test Acc:0.7648
# Epoch: 490. Train Loss: 0.2473. Test Loss: 1.004. Train Acc: 0.9465. Test Acc:0.7675
# Epoch: 500. Train Loss: 0.2481. Test Loss: 0.9885. Train Acc: 0.9435. Test Acc:0.7697
# Epoch: 510. Train Loss: 0.2391. Test Loss: 0.9922. Train Acc: 0.9452. Test Acc:0.7724
# Epoch: 520. Train Loss: 0.2346. Test Loss: 0.9967. Train Acc: 0.9477. Test Acc:0.7689
# Epoch: 530. Train Loss: 0.2278. Test Loss: 0.9947. Train Acc: 0.9488. Test Acc:0.7671
# Epoch: 540. Train Loss: 0.2249. Test Loss: 1.001. Train Acc: 0.9495. Test Acc:0.7702
# Epoch: 550. Train Loss: 0.2192. Test Loss: 1.025. Train Acc: 0.9488. Test Acc:0.7666
# Epoch: 560. Train Loss: 0.2138. Test Loss: 1.005. Train Acc: 0.9515. Test Acc:0.7675
# Epoch: 570. Train Loss: 0.2084. Test Loss: 0.9843. Train Acc: 0.9516. Test Acc:0.7724
# Epoch: 580. Train Loss: 0.2006. Test Loss: 1.001. Train Acc: 0.9533. Test Acc:0.7733
# Epoch: 590. Train Loss: 0.1994. Test Loss: 0.9948. Train Acc: 0.9531. Test Acc:0.7751
# Epoch: 600. Train Loss: 0.1922. Test Loss: 1.018. Train Acc: 0.9556. Test Acc:0.7715
# Epoch: 610. Train Loss: 0.1877. Test Loss: 0.9919. Train Acc: 0.9575. Test Acc:0.7747
# Epoch: 620. Train Loss: 0.1859. Test Loss: 1.01. Train Acc: 0.9573. Test Acc:0.7729
# Epoch: 630. Train Loss: 0.1857. Test Loss: 0.9826. Train Acc: 0.9565. Test Acc:0.7724
# Epoch: 640. Train Loss: 0.1798. Test Loss: 0.9913. Train Acc: 0.9581. Test Acc:0.7755
# Epoch: 650. Train Loss: 0.175. Test Loss: 1.001. Train Acc: 0.9596. Test Acc:0.7773
# Epoch: 660. Train Loss: 0.174. Test Loss: 1.019. Train Acc: 0.9595. Test Acc:0.7724
# Epoch: 670. Train Loss: 0.1727. Test Loss: 1.016. Train Acc: 0.9595. Test Acc:0.7742
# Epoch: 680. Train Loss: 0.1649. Test Loss: 0.9955. Train Acc: 0.9633. Test Acc:0.7738
# Epoch: 690. Train Loss: 0.1586. Test Loss: 1.014. Train Acc: 0.9634. Test Acc:0.7755
# Epoch: 700. Train Loss: 0.1581. Test Loss: 1.008. Train Acc: 0.9598. Test Acc:0.7796
# Epoch: 710. Train Loss: 0.1567. Test Loss: 1.008. Train Acc: 0.9638. Test Acc:0.772
# Epoch: 720. Train Loss: 0.1525. Test Loss: 0.9889. Train Acc: 0.9648. Test Acc:0.7809
# Epoch: 730. Train Loss: 0.1498. Test Loss: 1.017. Train Acc: 0.9646. Test Acc:0.7755
# Epoch: 740. Train Loss: 0.141. Test Loss: 1.024. Train Acc: 0.9666. Test Acc:0.7773
# Epoch: 750. Train Loss: 0.1399. Test Loss: 1.009. Train Acc: 0.9679. Test Acc:0.7747
# Epoch: 760. Train Loss: 0.1368. Test Loss: 1.011. Train Acc: 0.9669. Test Acc:0.776
# Epoch: 770. Train Loss: 0.1345. Test Loss: 1.021. Train Acc: 0.9693. Test Acc:0.7751
# Epoch: 780. Train Loss: 0.1318. Test Loss: 1.017. Train Acc: 0.9693. Test Acc:0.7747
# Epoch: 790. Train Loss: 0.1327. Test Loss: 1.005. Train Acc: 0.9684. Test Acc:0.7818
# Epoch: 800. Train Loss: 0.1281. Test Loss: 1.032. Train Acc: 0.9703. Test Acc:0.7791
# Epoch: 810. Train Loss: 0.1256. Test Loss: 0.9742. Train Acc: 0.9704. Test Acc:0.7818
# Epoch: 820. Train Loss: 0.131. Test Loss: 0.994. Train Acc: 0.9696. Test Acc:0.78
# Epoch: 830. Train Loss: 0.119. Test Loss: 1.014. Train Acc: 0.9726. Test Acc:0.7782
# Epoch: 840. Train Loss: 0.1216. Test Loss: 0.9836. Train Acc: 0.9709. Test Acc:0.7863
# Epoch: 850. Train Loss: 0.1167. Test Loss: 1.02. Train Acc: 0.9718. Test Acc:0.7773
# Epoch: 860. Train Loss: 0.1116. Test Loss: 1.02. Train Acc: 0.9739. Test Acc:0.784
# Epoch: 870. Train Loss: 0.1122. Test Loss: 1.007. Train Acc: 0.9724. Test Acc:0.7871
# Epoch: 880. Train Loss: 0.1114. Test Loss: 1.008. Train Acc: 0.9731. Test Acc:0.7827
# Epoch: 890. Train Loss: 0.1056. Test Loss: 1.011. Train Acc: 0.9744. Test Acc:0.7827
# Epoch: 900. Train Loss: 0.1025. Test Loss: 1.039. Train Acc: 0.9751. Test Acc:0.7831
# Epoch: 910. Train Loss: 0.1011. Test Loss: 1.038. Train Acc: 0.9761. Test Acc:0.7769
# Epoch: 920. Train Loss: 0.09764. Test Loss: 1.017. Train Acc: 0.9772. Test Acc:0.7849
# Epoch: 930. Train Loss: 0.09844. Test Loss: 1.028. Train Acc: 0.9772. Test Acc:0.7769
# Epoch: 940. Train Loss: 0.1098. Test Loss: 1.023. Train Acc: 0.9703. Test Acc:0.7755
# Epoch: 950. Train Loss: 0.116. Test Loss: 0.9968. Train Acc: 0.9701. Test Acc:0.7782
# Epoch: 960. Train Loss: 0.1042. Test Loss: 0.9824. Train Acc: 0.9732. Test Acc:0.7831
# Epoch: 970. Train Loss: 0.1029. Test Loss: 1.01. Train Acc: 0.9746. Test Acc:0.7854
# Epoch: 980. Train Loss: 0.09183. Test Loss: 1.021. Train Acc: 0.9779. Test Acc:0.7849
# Epoch: 990. Train Loss: 0.08735. Test Loss: 1.042. Train Acc: 0.9776. Test Acc:0.784
# Epoch: 1000. Train Loss: 0.08658. Test Loss: 1.067. Train Acc: 0.9801. Test Acc:0.7769
# ASRCNN__conv_pool_avg__conv_dp_0.2__fc_dp_0.2__fn_wav2vec_features-z__obj_voice_cmd__and__voice_cmd_lng using wav2vec_features-z on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 2.699. Test Loss: 2.854. Train Acc: 0.05484. Test Acc:0.05712
# Epoch: 20. Train Loss: 2.364. Test Loss: 2.548. Train Acc: 0.1741. Test Acc:0.1397
# Epoch: 30. Train Loss: 2.118. Test Loss: 2.357. Train Acc: 0.2614. Test Acc:0.2187
# Epoch: 40. Train Loss: 1.916. Test Loss: 2.176. Train Acc: 0.3277. Test Acc:0.2905
# Epoch: 50. Train Loss: 1.739. Test Loss: 2.03. Train Acc: 0.399. Test Acc:0.3414
# Epoch: 60. Train Loss: 1.58. Test Loss: 1.884. Train Acc: 0.4762. Test Acc:0.3887
# Epoch: 70. Train Loss: 1.451. Test Loss: 1.766. Train Acc: 0.5359. Test Acc:0.4404
# Epoch: 80. Train Loss: 1.353. Test Loss: 1.683. Train Acc: 0.5761. Test Acc:0.4717
# Epoch: 90. Train Loss: 1.266. Test Loss: 1.618. Train Acc: 0.6155. Test Acc:0.4975
# Epoch: 100. Train Loss: 1.192. Test Loss: 1.553. Train Acc: 0.6442. Test Acc:0.5274
# Epoch: 110. Train Loss: 1.126. Test Loss: 1.497. Train Acc: 0.6756. Test Acc:0.552
# Epoch: 120. Train Loss: 1.068. Test Loss: 1.448. Train Acc: 0.7034. Test Acc:0.581
# Epoch: 130. Train Loss: 1.011. Test Loss: 1.4. Train Acc: 0.728. Test Acc:0.5966
# Epoch: 140. Train Loss: 0.9579. Test Loss: 1.356. Train Acc: 0.7534. Test Acc:0.6118
# Epoch: 150. Train Loss: 0.9123. Test Loss: 1.333. Train Acc: 0.7722. Test Acc:0.6252
# Epoch: 160. Train Loss: 0.8665. Test Loss: 1.286. Train Acc: 0.7928. Test Acc:0.639
# Epoch: 170. Train Loss: 0.8225. Test Loss: 1.252. Train Acc: 0.8072. Test Acc:0.651
# Epoch: 180. Train Loss: 0.7825. Test Loss: 1.218. Train Acc: 0.8244. Test Acc:0.6671
# Epoch: 190. Train Loss: 0.751. Test Loss: 1.194. Train Acc: 0.836. Test Acc:0.6729
# Epoch: 200. Train Loss: 0.7202. Test Loss: 1.171. Train Acc: 0.8425. Test Acc:0.6841
# Epoch: 210. Train Loss: 0.6954. Test Loss: 1.169. Train Acc: 0.8523. Test Acc:0.6899
# Epoch: 220. Train Loss: 0.6677. Test Loss: 1.148. Train Acc: 0.8621. Test Acc:0.6948
# Epoch: 230. Train Loss: 0.6436. Test Loss: 1.116. Train Acc: 0.8711. Test Acc:0.7028
# Epoch: 240. Train Loss: 0.6277. Test Loss: 1.104. Train Acc: 0.8759. Test Acc:0.7024
# Epoch: 250. Train Loss: 0.6053. Test Loss: 1.101. Train Acc: 0.884. Test Acc:0.7073
# Epoch: 260. Train Loss: 0.5928. Test Loss: 1.1. Train Acc: 0.8848. Test Acc:0.7113
# Epoch: 270. Train Loss: 0.5731. Test Loss: 1.062. Train Acc: 0.892. Test Acc:0.7095
# Epoch: 280. Train Loss: 0.5554. Test Loss: 1.068. Train Acc: 0.8976. Test Acc:0.7166
# Epoch: 290. Train Loss: 0.5426. Test Loss: 1.064. Train Acc: 0.903. Test Acc:0.7171
# Epoch: 300. Train Loss: 0.5302. Test Loss: 1.047. Train Acc: 0.9015. Test Acc:0.7233
# Epoch: 310. Train Loss: 0.5137. Test Loss: 1.023. Train Acc: 0.9079. Test Acc:0.7224
# Epoch: 320. Train Loss: 0.5012. Test Loss: 1.045. Train Acc: 0.9123. Test Acc:0.726
# Epoch: 330. Train Loss: 0.4862. Test Loss: 1.026. Train Acc: 0.9118. Test Acc:0.73
# Epoch: 340. Train Loss: 0.4776. Test Loss: 1.026. Train Acc: 0.9114. Test Acc:0.7193
# Epoch: 350. Train Loss: 0.4647. Test Loss: 1.013. Train Acc: 0.9181. Test Acc:0.7269
# Epoch: 360. Train Loss: 0.4595. Test Loss: 1.036. Train Acc: 0.9176. Test Acc:0.7296
# Epoch: 370. Train Loss: 0.4431. Test Loss: 1.029. Train Acc: 0.9197. Test Acc:0.73
# Epoch: 380. Train Loss: 0.435. Test Loss: 1.02. Train Acc: 0.9237. Test Acc:0.7323
# Epoch: 390. Train Loss: 0.4251. Test Loss: 1.024. Train Acc: 0.9252. Test Acc:0.7332
# Epoch: 400. Train Loss: 0.4163. Test Loss: 1.017. Train Acc: 0.9247. Test Acc:0.7314
# Epoch: 410. Train Loss: 0.4071. Test Loss: 1.017. Train Acc: 0.9279. Test Acc:0.7305
# Epoch: 420. Train Loss: 0.4029. Test Loss: 1.035. Train Acc: 0.9287. Test Acc:0.7318
# Epoch: 430. Train Loss: 0.3938. Test Loss: 1.01. Train Acc: 0.9315. Test Acc:0.7305
# Epoch: 440. Train Loss: 0.3871. Test Loss: 0.9959. Train Acc: 0.9309. Test Acc:0.7381
# Epoch: 450. Train Loss: 0.3773. Test Loss: 1.003. Train Acc: 0.9345. Test Acc:0.7358
# Epoch: 460. Train Loss: 0.3717. Test Loss: 1.025. Train Acc: 0.935. Test Acc:0.7305
# Epoch: 470. Train Loss: 0.3636. Test Loss: 1.004. Train Acc: 0.9355. Test Acc:0.7358
# Epoch: 480. Train Loss: 0.3603. Test Loss: 1.021. Train Acc: 0.9354. Test Acc:0.7323
# Epoch: 490. Train Loss: 0.3514. Test Loss: 1.012. Train Acc: 0.9369. Test Acc:0.7394
# Epoch: 500. Train Loss: 0.3458. Test Loss: 1.021. Train Acc: 0.9374. Test Acc:0.7358
# Epoch: 510. Train Loss: 0.3379. Test Loss: 1.016. Train Acc: 0.941. Test Acc:0.7407
# Epoch: 520. Train Loss: 0.3421. Test Loss: 1.034. Train Acc: 0.9402. Test Acc:0.7372
# Epoch: 530. Train Loss: 0.3306. Test Loss: 1.035. Train Acc: 0.9413. Test Acc:0.7336
# Epoch: 540. Train Loss: 0.3226. Test Loss: 1.022. Train Acc: 0.9408. Test Acc:0.7367
# Epoch: 550. Train Loss: 0.3234. Test Loss: 1.028. Train Acc: 0.9412. Test Acc:0.7336
# Epoch: 560. Train Loss: 0.3127. Test Loss: 1.016. Train Acc: 0.9448. Test Acc:0.7363
# Epoch: 570. Train Loss: 0.3123. Test Loss: 1.007. Train Acc: 0.9428. Test Acc:0.7403
# Epoch: 580. Train Loss: 0.3032. Test Loss: 1.015. Train Acc: 0.9465. Test Acc:0.7403
# Epoch: 590. Train Loss: 0.2954. Test Loss: 1.013. Train Acc: 0.9485. Test Acc:0.743
# Epoch: 600. Train Loss: 0.2924. Test Loss: 1.02. Train Acc: 0.9463. Test Acc:0.7403
# Epoch: 610. Train Loss: 0.2943. Test Loss: 0.993. Train Acc: 0.9467. Test Acc:0.7349
# Epoch: 620. Train Loss: 0.2839. Test Loss: 1.026. Train Acc: 0.9465. Test Acc:0.7385
# Epoch: 630. Train Loss: 0.2795. Test Loss: 1.018. Train Acc: 0.9492. Test Acc:0.739
# Epoch: 640. Train Loss: 0.2758. Test Loss: 1.015. Train Acc: 0.9493. Test Acc:0.7434
# Epoch: 650. Train Loss: 0.2777. Test Loss: 1.004. Train Acc: 0.9472. Test Acc:0.7376
# Epoch: 660. Train Loss: 0.2669. Test Loss: 1.031. Train Acc: 0.9495. Test Acc:0.734
# Epoch: 670. Train Loss: 0.2664. Test Loss: 1.022. Train Acc: 0.948. Test Acc:0.7421
# Epoch: 680. Train Loss: 0.267. Test Loss: 1.045. Train Acc: 0.9482. Test Acc:0.734
# Epoch: 690. Train Loss: 0.2536. Test Loss: 1.024. Train Acc: 0.9526. Test Acc:0.7349
# Epoch: 700. Train Loss: 0.2525. Test Loss: 1.036. Train Acc: 0.9521. Test Acc:0.7363
# Epoch: 710. Train Loss: 0.2532. Test Loss: 1.023. Train Acc: 0.9511. Test Acc:0.7349
# Epoch: 720. Train Loss: 0.2493. Test Loss: 1.004. Train Acc: 0.9515. Test Acc:0.7327
# Epoch: 730. Train Loss: 0.2387. Test Loss: 1.039. Train Acc: 0.9556. Test Acc:0.7381
# Epoch: 740. Train Loss: 0.24. Test Loss: 1.03. Train Acc: 0.9556. Test Acc:0.7318
# Epoch: 750. Train Loss: 0.2346. Test Loss: 1.038. Train Acc: 0.9556. Test Acc:0.7305
# Epoch: 760. Train Loss: 0.2392. Test Loss: 1.014. Train Acc: 0.9566. Test Acc:0.7358
# Epoch: 770. Train Loss: 0.2247. Test Loss: 1.031. Train Acc: 0.9595. Test Acc:0.734
# Epoch: 780. Train Loss: 0.2445. Test Loss: 1.044. Train Acc: 0.9508. Test Acc:0.734
# Epoch: 790. Train Loss: 0.2374. Test Loss: 1.059. Train Acc: 0.9553. Test Acc:0.7349
# Epoch: 800. Train Loss: 0.2234. Test Loss: 1.056. Train Acc: 0.9573. Test Acc:0.739
# Epoch: 810. Train Loss: 0.2248. Test Loss: 1.075. Train Acc: 0.9573. Test Acc:0.7403
# Epoch: 820. Train Loss: 0.2215. Test Loss: 1.098. Train Acc: 0.9588. Test Acc:0.7349
# Epoch: 830. Train Loss: 0.2199. Test Loss: 1.102. Train Acc: 0.9571. Test Acc:0.7309
# Epoch: 840. Train Loss: 0.2202. Test Loss: 1.129. Train Acc: 0.9571. Test Acc:0.722
# Epoch: 850. Train Loss: 0.2112. Test Loss: 1.077. Train Acc: 0.9621. Test Acc:0.7398
# Epoch: 860. Train Loss: 0.2027. Test Loss: 1.051. Train Acc: 0.9608. Test Acc:0.7354
# Epoch: 870. Train Loss: 0.2035. Test Loss: 1.056. Train Acc: 0.9623. Test Acc:0.7363
# Epoch: 880. Train Loss: 0.1934. Test Loss: 1.069. Train Acc: 0.9649. Test Acc:0.7349
# Epoch: 890. Train Loss: 0.192. Test Loss: 1.061. Train Acc: 0.9648. Test Acc:0.7398
# Epoch: 900. Train Loss: 0.1912. Test Loss: 1.108. Train Acc: 0.9643. Test Acc:0.7327
# Epoch: 910. Train Loss: 0.1839. Test Loss: 1.072. Train Acc: 0.9673. Test Acc:0.7376
# Epoch: 920. Train Loss: 0.184. Test Loss: 1.075. Train Acc: 0.9656. Test Acc:0.7367
# Epoch: 930. Train Loss: 0.1768. Test Loss: 1.06. Train Acc: 0.9676. Test Acc:0.7376
# Epoch: 940. Train Loss: 0.1751. Test Loss: 1.074. Train Acc: 0.9671. Test Acc:0.7327
# Epoch: 950. Train Loss: 0.178. Test Loss: 1.076. Train Acc: 0.9674. Test Acc:0.739
# Epoch: 960. Train Loss: 0.1781. Test Loss: 1.077. Train Acc: 0.9674. Test Acc:0.7376
# Epoch: 970. Train Loss: 0.1719. Test Loss: 1.089. Train Acc: 0.9676. Test Acc:0.7287
# Epoch: 980. Train Loss: 0.1721. Test Loss: 1.084. Train Acc: 0.9676. Test Acc:0.7372
# Epoch: 990. Train Loss: 0.1665. Test Loss: 1.077. Train Acc: 0.9689. Test Acc:0.7349
# Epoch: 1000. Train Loss: 0.1647. Test Loss: 1.066. Train Acc: 0.9699. Test Acc:0.7376
# ASRCNN__conv_pool_avg__conv_dp_0.2__fc_dp_0.2__fn_retrained-wav2vec_features-c__obj_voice_cmd using retrained-wav2vec_features-c on fold#0
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
# =======================================================================
# Total params: 24,345
# Trainable params: 24,345
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 6018
# test_n: 2241
# Epoch: 10. Train Loss: 3.901. Test Loss: 3.972. Train Acc: 0.05882. Test Acc:0.04105
# Epoch: 20. Train Loss: 3.647. Test Loss: 3.75. Train Acc: 0.09372. Test Acc:0.07363
# Epoch: 30. Train Loss: 3.278. Test Loss: 3.472. Train Acc: 0.1431. Test Acc:0.1102
# Epoch: 40. Train Loss: 2.909. Test Loss: 3.142. Train Acc: 0.2245. Test Acc:0.199
# Epoch: 50. Train Loss: 2.582. Test Loss: 2.892. Train Acc: 0.3156. Test Acc:0.2619
# Epoch: 60. Train Loss: 2.315. Test Loss: 2.688. Train Acc: 0.3772. Test Acc:0.3043
# Epoch: 70. Train Loss: 2.127. Test Loss: 2.533. Train Acc: 0.4237. Test Acc:0.3365
# Epoch: 80. Train Loss: 1.968. Test Loss: 2.404. Train Acc: 0.4668. Test Acc:0.365
# Epoch: 90. Train Loss: 1.83. Test Loss: 2.282. Train Acc: 0.4983. Test Acc:0.3927
# Epoch: 100. Train Loss: 1.695. Test Loss: 2.147. Train Acc: 0.5327. Test Acc:0.4257
# Epoch: 110. Train Loss: 1.572. Test Loss: 2.051. Train Acc: 0.5698. Test Acc:0.4458
# Epoch: 120. Train Loss: 1.474. Test Loss: 1.967. Train Acc: 0.5977. Test Acc:0.4672
# Epoch: 130. Train Loss: 1.382. Test Loss: 1.884. Train Acc: 0.6263. Test Acc:0.4917
# Epoch: 140. Train Loss: 1.307. Test Loss: 1.823. Train Acc: 0.6487. Test Acc:0.5123
# Epoch: 150. Train Loss: 1.226. Test Loss: 1.76. Train Acc: 0.6741. Test Acc:0.5225
# Epoch: 160. Train Loss: 1.168. Test Loss: 1.72. Train Acc: 0.6878. Test Acc:0.5422
# Epoch: 170. Train Loss: 1.11. Test Loss: 1.673. Train Acc: 0.6984. Test Acc:0.5515
# Epoch: 180. Train Loss: 1.053. Test Loss: 1.628. Train Acc: 0.7165. Test Acc:0.5672
# Epoch: 190. Train Loss: 1.001. Test Loss: 1.582. Train Acc: 0.736. Test Acc:0.5788
# Epoch: 200. Train Loss: 0.9567. Test Loss: 1.534. Train Acc: 0.7463. Test Acc:0.602
# Epoch: 210. Train Loss: 0.9179. Test Loss: 1.514. Train Acc: 0.7569. Test Acc:0.6024
# Epoch: 220. Train Loss: 0.875. Test Loss: 1.472. Train Acc: 0.7695. Test Acc:0.6118
# Epoch: 230. Train Loss: 0.8525. Test Loss: 1.458. Train Acc: 0.774. Test Acc:0.6109
# Epoch: 240. Train Loss: 0.8164. Test Loss: 1.44. Train Acc: 0.786. Test Acc:0.614
# Epoch: 250. Train Loss: 0.7668. Test Loss: 1.391. Train Acc: 0.7969. Test Acc:0.6287
# Epoch: 260. Train Loss: 0.738. Test Loss: 1.368. Train Acc: 0.8049. Test Acc:0.6399
# Epoch: 270. Train Loss: 0.7042. Test Loss: 1.344. Train Acc: 0.8182. Test Acc:0.6461
# Epoch: 280. Train Loss: 0.6752. Test Loss: 1.324. Train Acc: 0.829. Test Acc:0.6546
# Epoch: 290. Train Loss: 0.6471. Test Loss: 1.309. Train Acc: 0.8368. Test Acc:0.6573
# Epoch: 300. Train Loss: 0.62. Test Loss: 1.285. Train Acc: 0.8436. Test Acc:0.6765
# Epoch: 310. Train Loss: 0.5978. Test Loss: 1.275. Train Acc: 0.8491. Test Acc:0.6765
# Epoch: 320. Train Loss: 0.5785. Test Loss: 1.266. Train Acc: 0.8544. Test Acc:0.6809
# ...
# Epoch: 250. Train Loss: 0.4594. Test Loss: 1.28. Train Acc: 0.8988. Test Acc:0.6986
# Epoch: 260. Train Loss: 0.4435. Test Loss: 1.277. Train Acc: 0.9034. Test Acc:0.7055
# Epoch: 270. Train Loss: 0.4361. Test Loss: 1.275. Train Acc: 0.9025. Test Acc:0.7098
# Epoch: 280. Train Loss: 0.4327. Test Loss: 1.267. Train Acc: 0.9005. Test Acc:0.7076
# Epoch: 290. Train Loss: 0.4051. Test Loss: 1.25. Train Acc: 0.9091. Test Acc:0.7102
# Epoch: 300. Train Loss: 0.3927. Test Loss: 1.248. Train Acc: 0.9135. Test Acc:0.7137
# Epoch: 310. Train Loss: 0.3834. Test Loss: 1.235. Train Acc: 0.9153. Test Acc:0.715
# Epoch: 320. Train Loss: 0.3694. Test Loss: 1.247. Train Acc: 0.9162. Test Acc:0.7145
# Epoch: 330. Train Loss: 0.3605. Test Loss: 1.221. Train Acc: 0.9178. Test Acc:0.718
# Epoch: 340. Train Loss: 0.3554. Test Loss: 1.244. Train Acc: 0.9192. Test Acc:0.7167
# Epoch: 350. Train Loss: 0.3461. Test Loss: 1.232. Train Acc: 0.9217. Test Acc:0.718
# Epoch: 360. Train Loss: 0.3311. Test Loss: 1.212. Train Acc: 0.9269. Test Acc:0.7249
# Epoch: 370. Train Loss: 0.325. Test Loss: 1.222. Train Acc: 0.9259. Test Acc:0.7219
# Epoch: 380. Train Loss: 0.322. Test Loss: 1.205. Train Acc: 0.9271. Test Acc:0.7206
# Epoch: 390. Train Loss: 0.3102. Test Loss: 1.199. Train Acc: 0.9306. Test Acc:0.7262
# Epoch: 400. Train Loss: 0.2985. Test Loss: 1.202. Train Acc: 0.934. Test Acc:0.7283
# Epoch: 410. Train Loss: 0.296. Test Loss: 1.208. Train Acc: 0.9338. Test Acc:0.7296
# Epoch: 420. Train Loss: 0.2847. Test Loss: 1.203. Train Acc: 0.9355. Test Acc:0.7253
# Epoch: 430. Train Loss: 0.2836. Test Loss: 1.189. Train Acc: 0.9375. Test Acc:0.7279
# Epoch: 440. Train Loss: 0.2698. Test Loss: 1.191. Train Acc: 0.9428. Test Acc:0.7318
# Epoch: 450. Train Loss: 0.2782. Test Loss: 1.207. Train Acc: 0.9374. Test Acc:0.7214
# Epoch: 460. Train Loss: 0.2741. Test Loss: 1.197. Train Acc: 0.9401. Test Acc:0.7223
# Epoch: 470. Train Loss: 0.2663. Test Loss: 1.195. Train Acc: 0.938. Test Acc:0.7262
# Epoch: 480. Train Loss: 0.2563. Test Loss: 1.195. Train Acc: 0.9418. Test Acc:0.7283
# Epoch: 490. Train Loss: 0.2503. Test Loss: 1.183. Train Acc: 0.9434. Test Acc:0.7279
# Epoch: 500. Train Loss: 0.2456. Test Loss: 1.178. Train Acc: 0.9458. Test Acc:0.7313
# Epoch: 510. Train Loss: 0.2358. Test Loss: 1.176. Train Acc: 0.9478. Test Acc:0.7365
# Epoch: 520. Train Loss: 0.2327. Test Loss: 1.168. Train Acc: 0.9485. Test Acc:0.7387
# Epoch: 530. Train Loss: 0.2403. Test Loss: 1.173. Train Acc: 0.9449. Test Acc:0.7335
# Epoch: 540. Train Loss: 0.2199. Test Loss: 1.143. Train Acc: 0.953. Test Acc:0.7426
# Epoch: 550. Train Loss: 0.2154. Test Loss: 1.157. Train Acc: 0.952. Test Acc:0.7391
# Epoch: 560. Train Loss: 0.2078. Test Loss: 1.15. Train Acc: 0.9547. Test Acc:0.7434
# Epoch: 570. Train Loss: 0.2068. Test Loss: 1.143. Train Acc: 0.9547. Test Acc:0.7443
# Epoch: 580. Train Loss: 0.2046. Test Loss: 1.156. Train Acc: 0.9571. Test Acc:0.7391
# Epoch: 590. Train Loss: 0.1966. Test Loss: 1.146. Train Acc: 0.9576. Test Acc:0.7451
# Epoch: 600. Train Loss: 0.1908. Test Loss: 1.149. Train Acc: 0.9584. Test Acc:0.746
# Epoch: 610. Train Loss: 0.1919. Test Loss: 1.156. Train Acc: 0.9581. Test Acc:0.7439
# Epoch: 620. Train Loss: 0.1871. Test Loss: 1.155. Train Acc: 0.9589. Test Acc:0.7486
# Epoch: 630. Train Loss: 0.1859. Test Loss: 1.143. Train Acc: 0.9599. Test Acc:0.7473
# Epoch: 640. Train Loss: 0.1852. Test Loss: 1.156. Train Acc: 0.9577. Test Acc:0.7456
# Epoch: 650. Train Loss: 0.1804. Test Loss: 1.148. Train Acc: 0.9606. Test Acc:0.7533
# Epoch: 660. Train Loss: 0.1786. Test Loss: 1.15. Train Acc: 0.9593. Test Acc:0.7503
# Epoch: 670. Train Loss: 0.1902. Test Loss: 1.171. Train Acc: 0.9549. Test Acc:0.7413
# Epoch: 680. Train Loss: 0.1703. Test Loss: 1.14. Train Acc: 0.9623. Test Acc:0.7495
# Epoch: 690. Train Loss: 0.1648. Test Loss: 1.148. Train Acc: 0.9667. Test Acc:0.7529
# Epoch: 700. Train Loss: 0.1711. Test Loss: 1.143. Train Acc: 0.9593. Test Acc:0.7516
# Epoch: 710. Train Loss: 0.1583. Test Loss: 1.14. Train Acc: 0.9635. Test Acc:0.7525
# Epoch: 720. Train Loss: 0.1638. Test Loss: 1.137. Train Acc: 0.9625. Test Acc:0.7542
# Epoch: 730. Train Loss: 0.1502. Test Loss: 1.14. Train Acc: 0.9673. Test Acc:0.7581
# Epoch: 740. Train Loss: 0.1473. Test Loss: 1.124. Train Acc: 0.967. Test Acc:0.7568
# Epoch: 750. Train Loss: 0.142. Test Loss: 1.131. Train Acc: 0.971. Test Acc:0.7598
# Epoch: 760. Train Loss: 0.1358. Test Loss: 1.113. Train Acc: 0.971. Test Acc:0.7663
# Epoch: 770. Train Loss: 0.1306. Test Loss: 1.115. Train Acc: 0.9724. Test Acc:0.7611
# Epoch: 780. Train Loss: 0.1369. Test Loss: 1.137. Train Acc: 0.9695. Test Acc:0.7594
# Epoch: 790. Train Loss: 0.1343. Test Loss: 1.15. Train Acc: 0.9699. Test Acc:0.7529
# Epoch: 800. Train Loss: 0.1295. Test Loss: 1.133. Train Acc: 0.9721. Test Acc:0.7628
# Epoch: 810. Train Loss: 0.1202. Test Loss: 1.137. Train Acc: 0.9732. Test Acc:0.7646
# Epoch: 820. Train Loss: 0.1196. Test Loss: 1.141. Train Acc: 0.9753. Test Acc:0.7628
# Epoch: 830. Train Loss: 0.1164. Test Loss: 1.135. Train Acc: 0.9754. Test Acc:0.768
# Epoch: 840. Train Loss: 0.1159. Test Loss: 1.123. Train Acc: 0.9753. Test Acc:0.7646
# Epoch: 850. Train Loss: 0.1128. Test Loss: 1.138. Train Acc: 0.9764. Test Acc:0.7611
# Epoch: 860. Train Loss: 0.1073. Test Loss: 1.134. Train Acc: 0.9779. Test Acc:0.7667
# Epoch: 870. Train Loss: 0.1087. Test Loss: 1.147. Train Acc: 0.9771. Test Acc:0.7684
# Epoch: 880. Train Loss: 0.1069. Test Loss: 1.142. Train Acc: 0.9768. Test Acc:0.7641
# Epoch: 890. Train Loss: 0.1047. Test Loss: 1.132. Train Acc: 0.9791. Test Acc:0.7654
# Epoch: 900. Train Loss: 0.1003. Test Loss: 1.136. Train Acc: 0.9795. Test Acc:0.7719
# Epoch: 910. Train Loss: 0.1062. Test Loss: 1.153. Train Acc: 0.9768. Test Acc:0.7607
# Epoch: 920. Train Loss: 0.09769. Test Loss: 1.161. Train Acc: 0.9788. Test Acc:0.7702
# Epoch: 930. Train Loss: 0.09767. Test Loss: 1.141. Train Acc: 0.979. Test Acc:0.765
# Epoch: 940. Train Loss: 0.0932. Test Loss: 1.154. Train Acc: 0.98. Test Acc:0.7676
# Epoch: 950. Train Loss: 0.09303. Test Loss: 1.154. Train Acc: 0.979. Test Acc:0.7663
# Epoch: 960. Train Loss: 0.08718. Test Loss: 1.148. Train Acc: 0.9808. Test Acc:0.7702
# Epoch: 970. Train Loss: 0.08656. Test Loss: 1.156. Train Acc: 0.9806. Test Acc:0.7779
# Epoch: 980. Train Loss: 0.08595. Test Loss: 1.144. Train Acc: 0.981. Test Acc:0.7753
# Epoch: 990. Train Loss: 0.08793. Test Loss: 1.142. Train Acc: 0.9805. Test Acc:0.7702
# Epoch: 1000. Train Loss: 0.08807. Test Loss: 1.156. Train Acc: 0.981. Test Acc:0.765
# ASRCNN__conv_pool_avg__conv_dp_0.2__fc_dp_0.2__fn_retrained-wav2vec_features-z__obj_voice_cmd__and__voice_cmd_lng using retrained-wav2vec_features-z on fold#1
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1        [10, 8, 200]           4,104           4,104
#           Conv1d-2        [10, 8, 198]             200             200
#          Dropout-3        [10, 8, 198]               0               0
#        AvgPool1d-4         [10, 8, 99]               0               0
#           Conv1d-5        [10, 16, 97]             400             400
#          Dropout-6        [10, 16, 97]               0               0
#        AvgPool1d-7        [10, 16, 48]               0               0
#           Conv1d-8        [10, 32, 46]           1,568           1,568
#          Dropout-9        [10, 32, 46]               0               0
#       AvgPool1d-10        [10, 32, 23]               0               0
#          Conv1d-11        [10, 64, 21]           6,208           6,208
#         Dropout-12        [10, 64, 21]               0               0
#       AvgPool1d-13        [10, 64, 10]               0               0
#         Dropout-14           [10, 112]               0               0
#          Linear-15           [10, 105]          11,865          11,865
#          Linear-16             [10, 5]             565             565
# =======================================================================
# Total params: 24,910
# Trainable params: 24,910
# Non-trainable params: 0
# -----------------------------------------------------------------------
# train_n: 5940
# test_n: 2319
# Epoch: 10. Train Loss: 2.737. Test Loss: 2.895. Train Acc: 0.05471. Test Acc:0.05778
# Epoch: 20. Train Loss: 2.328. Test Loss: 2.537. Train Acc: 0.153. Test Acc:0.1289
# Epoch: 30. Train Loss: 2.128. Test Loss: 2.375. Train Acc: 0.232. Test Acc:0.1815
# Epoch: 40. Train Loss: 1.868. Test Loss: 2.188. Train Acc: 0.3414. Test Acc:0.2497
# Epoch: 50. Train Loss: 1.646. Test Loss: 2.027. Train Acc: 0.436. Test Acc:0.3182
# Epoch: 60. Train Loss: 1.482. Test Loss: 1.912. Train Acc: 0.5111. Test Acc:0.3657
# Epoch: 70. Train Loss: 1.346. Test Loss: 1.827. Train Acc: 0.5684. Test Acc:0.3993
# Epoch: 80. Train Loss: 1.244. Test Loss: 1.754. Train Acc: 0.6012. Test Acc:0.4338
# Epoch: 90. Train Loss: 1.156. Test Loss: 1.688. Train Acc: 0.6488. Test Acc:0.4627
# Epoch: 100. Train Loss: 1.083. Test Loss: 1.629. Train Acc: 0.6771. Test Acc:0.4899
# Epoch: 110. Train Loss: 1.023. Test Loss: 1.589. Train Acc: 0.7103. Test Acc:0.505
# Epoch: 120. Train Loss: 0.9685. Test Loss: 1.546. Train Acc: 0.7293. Test Acc:0.5282
# Epoch: 130. Train Loss: 0.9225. Test Loss: 1.507. Train Acc: 0.7502. Test Acc:0.5438
# Epoch: 140. Train Loss: 0.88. Test Loss: 1.481. Train Acc: 0.7662. Test Acc:0.5593
# Epoch: 150. Train Loss: 0.8397. Test Loss: 1.447. Train Acc: 0.7887. Test Acc:0.5722
# Epoch: 160. Train Loss: 0.8158. Test Loss: 1.434. Train Acc: 0.7924. Test Acc:0.5765
# Epoch: 170. Train Loss: 0.7926. Test Loss: 1.408. Train Acc: 0.8042. Test Acc:0.5839
# Epoch: 180. Train Loss: 0.7597. Test Loss: 1.388. Train Acc: 0.813. Test Acc:0.5985
# Epoch: 190. Train Loss: 0.7405. Test Loss: 1.366. Train Acc: 0.8162. Test Acc:0.6093
# Epoch: 200. Train Loss: 0.7151. Test Loss: 1.348. Train Acc: 0.8322. Test Acc:0.6154
# Epoch: 210. Train Loss: 0.6962. Test Loss: 1.336. Train Acc: 0.8384. Test Acc:0.6141
# Epoch: 220. Train Loss: 0.6734. Test Loss: 1.326. Train Acc: 0.8485. Test Acc:0.627
# Epoch: 230. Train Loss: 0.6548. Test Loss: 1.335. Train Acc: 0.8503. Test Acc:0.624
# Epoch: 240. Train Loss: 0.636. Test Loss: 1.308. Train Acc: 0.8556. Test Acc:0.6304
# Epoch: 250. Train Loss: 0.6384. Test Loss: 1.316. Train Acc: 0.85. Test Acc:0.6261
# Epoch: 260. Train Loss: 0.598. Test Loss: 1.294. Train Acc: 0.8653. Test Acc:0.6412
# Epoch: 270. Train Loss: 0.5883. Test Loss: 1.321. Train Acc: 0.8684. Test Acc:0.6399
# Epoch: 280. Train Loss: 0.5672. Test Loss: 1.303. Train Acc: 0.8741. Test Acc:0.6464
# Epoch: 290. Train Loss: 0.5534. Test Loss: 1.297. Train Acc: 0.8759. Test Acc:0.6503
# Epoch: 300. Train Loss: 0.5501. Test Loss: 1.286. Train Acc: 0.8756. Test Acc:0.6468
# Epoch: 310. Train Loss: 0.5366. Test Loss: 1.287. Train Acc: 0.8786. Test Acc:0.6546
# Epoch: 320. Train Loss: 0.5074. Test Loss: 1.262. Train Acc: 0.8941. Test Acc:0.6641
# Epoch: 330. Train Loss: 0.4959. Test Loss: 1.252. Train Acc: 0.897. Test Acc:0.6667
# Epoch: 340. Train Loss: 0.4854. Test Loss: 1.25. Train Acc: 0.9002. Test Acc:0.6774
# Epoch: 350. Train Loss: 0.4714. Test Loss: 1.249. Train Acc: 0.9061. Test Acc:0.6762
# Epoch: 360. Train Loss: 0.468. Test Loss: 1.255. Train Acc: 0.9035. Test Acc:0.6697
# Epoch: 370. Train Loss: 0.4547. Test Loss: 1.236. Train Acc: 0.9109. Test Acc:0.6774
# Epoch: 380. Train Loss: 0.4458. Test Loss: 1.248. Train Acc: 0.9118. Test Acc:0.6701
# Epoch: 390. Train Loss: 0.4365. Test Loss: 1.263. Train Acc: 0.9099. Test Acc:0.674
# Epoch: 400. Train Loss: 0.4282. Test Loss: 1.246. Train Acc: 0.9189. Test Acc:0.68
# Epoch: 410. Train Loss: 0.423. Test Loss: 1.254. Train Acc: 0.9185. Test Acc:0.6757
# Epoch: 420. Train Loss: 0.4136. Test Loss: 1.253. Train Acc: 0.9184. Test Acc:0.6744
# Epoch: 430. Train Loss: 0.4054. Test Loss: 1.247. Train Acc: 0.9222. Test Acc:0.6809
# Epoch: 440. Train Loss: 0.3974. Test Loss: 1.239. Train Acc: 0.9234. Test Acc:0.6809
# Epoch: 450. Train Loss: 0.3964. Test Loss: 1.232. Train Acc: 0.9214. Test Acc:0.6848
# Epoch: 460. Train Loss: 0.386. Test Loss: 1.248. Train Acc: 0.9254. Test Acc:0.6779
# Epoch: 470. Train Loss: 0.3749. Test Loss: 1.257. Train Acc: 0.9276. Test Acc:0.6792
# Epoch: 480. Train Loss: 0.3698. Test Loss: 1.229. Train Acc: 0.9325. Test Acc:0.6831
# Epoch: 490. Train Loss: 0.3664. Test Loss: 1.263. Train Acc: 0.9288. Test Acc:0.6779
# Epoch: 500. Train Loss: 0.3572. Test Loss: 1.235. Train Acc: 0.9337. Test Acc:0.6822
# Epoch: 510. Train Loss: 0.3525. Test Loss: 1.235. Train Acc: 0.9305. Test Acc:0.6848
# Epoch: 520. Train Loss: 0.3457. Test Loss: 1.233. Train Acc: 0.9355. Test Acc:0.6861
# Epoch: 530. Train Loss: 0.3441. Test Loss: 1.23. Train Acc: 0.9352. Test Acc:0.6835
# Epoch: 540. Train Loss: 0.3357. Test Loss: 1.236. Train Acc: 0.9357. Test Acc:0.6869
# Epoch: 550. Train Loss: 0.3329. Test Loss: 1.246. Train Acc: 0.9377. Test Acc:0.6882
# Epoch: 560. Train Loss: 0.3204. Test Loss: 1.243. Train Acc: 0.9421. Test Acc:0.6869
# Epoch: 570. Train Loss: 0.3171. Test Loss: 1.225. Train Acc: 0.9421. Test Acc:0.6921
# Epoch: 580. Train Loss: 0.3169. Test Loss: 1.236. Train Acc: 0.9402. Test Acc:0.6895
# Epoch: 590. Train Loss: 0.3101. Test Loss: 1.252. Train Acc: 0.9451. Test Acc:0.69
# Epoch: 600. Train Loss: 0.3058. Test Loss: 1.233. Train Acc: 0.9419. Test Acc:0.6908
# Epoch: 610. Train Loss: 0.2992. Test Loss: 1.23. Train Acc: 0.946. Test Acc:0.6878
# Epoch: 620. Train Loss: 0.2968. Test Loss: 1.235. Train Acc: 0.9463. Test Acc:0.693
# Epoch: 630. Train Loss: 0.2947. Test Loss: 1.23. Train Acc: 0.9431. Test Acc:0.6869
# Epoch: 640. Train Loss: 0.2836. Test Loss: 1.235. Train Acc: 0.948. Test Acc:0.6908
# Epoch: 650. Train Loss: 0.2855. Test Loss: 1.24. Train Acc: 0.9483. Test Acc:0.6956
# Epoch: 660. Train Loss: 0.2751. Test Loss: 1.241. Train Acc: 0.949. Test Acc:0.6969
# Epoch: 670. Train Loss: 0.2713. Test Loss: 1.236. Train Acc: 0.9492. Test Acc:0.6943
# Epoch: 680. Train Loss: 0.2739. Test Loss: 1.257. Train Acc: 0.9485. Test Acc:0.6921
# Epoch: 690. Train Loss: 0.2623. Test Loss: 1.242. Train Acc: 0.9522. Test Acc:0.705
# Epoch: 700. Train Loss: 0.2564. Test Loss: 1.239. Train Acc: 0.9539. Test Acc:0.6999
# Epoch: 710. Train Loss: 0.2522. Test Loss: 1.234. Train Acc: 0.9549. Test Acc:0.6977
# Epoch: 720. Train Loss: 0.2536. Test Loss: 1.234. Train Acc: 0.9549. Test Acc:0.6969
# Epoch: 730. Train Loss: 0.2519. Test Loss: 1.225. Train Acc: 0.9547. Test Acc:0.7003
# Epoch: 740. Train Loss: 0.2434. Test Loss: 1.252. Train Acc: 0.9567. Test Acc:0.6973
# Epoch: 750. Train Loss: 0.2325. Test Loss: 1.259. Train Acc: 0.9608. Test Acc:0.6999
# Epoch: 760. Train Loss: 0.2332. Test Loss: 1.252. Train Acc: 0.9584. Test Acc:0.7016
# Epoch: 770. Train Loss: 0.2313. Test Loss: 1.24. Train Acc: 0.9598. Test Acc:0.6977
# Epoch: 780. Train Loss: 0.2307. Test Loss: 1.243. Train Acc: 0.9588. Test Acc:0.7055
# Epoch: 790. Train Loss: 0.2233. Test Loss: 1.258. Train Acc: 0.9606. Test Acc:0.6977
# Epoch: 800. Train Loss: 0.2184. Test Loss: 1.258. Train Acc: 0.9625. Test Acc:0.7016
# Epoch: 810. Train Loss: 0.2265. Test Loss: 1.259. Train Acc: 0.9598. Test Acc:0.7003
# Epoch: 820. Train Loss: 0.2092. Test Loss: 1.243. Train Acc: 0.9653. Test Acc:0.7055
# Epoch: 830. Train Loss: 0.2054. Test Loss: 1.256. Train Acc: 0.9643. Test Acc:0.7081
# Epoch: 840. Train Loss: 0.2007. Test Loss: 1.269. Train Acc: 0.9652. Test Acc:0.7033
# Epoch: 850. Train Loss: 0.1984. Test Loss: 1.259. Train Acc: 0.964. Test Acc:0.7046
# Epoch: 860. Train Loss: 0.1991. Test Loss: 1.262. Train Acc: 0.9658. Test Acc:0.702
# Epoch: 870. Train Loss: 0.1938. Test Loss: 1.265. Train Acc: 0.9667. Test Acc:0.7124
# Epoch: 880. Train Loss: 0.1926. Test Loss: 1.266. Train Acc: 0.9657. Test Acc:0.7089
# Epoch: 890. Train Loss: 0.1905. Test Loss: 1.294. Train Acc: 0.9655. Test Acc:0.7076
# Epoch: 900. Train Loss: 0.1949. Test Loss: 1.291. Train Acc: 0.9658. Test Acc:0.7072
# Epoch: 910. Train Loss: 0.1814. Test Loss: 1.292. Train Acc: 0.9677. Test Acc:0.7076
# Epoch: 920. Train Loss: 0.1822. Test Loss: 1.257. Train Acc: 0.9684. Test Acc:0.7107
