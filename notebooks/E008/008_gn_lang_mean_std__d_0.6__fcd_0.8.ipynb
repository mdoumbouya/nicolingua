# %%
from pathlib import Path
import csv
from itertools import groupby
import h5py
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.svm import SVC
# from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import random
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# # Configuration & Utilities

# %%
random.seed(42)
COLORS = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
ANNOTATIONS_PATH = "/media/xtrem/data/experiments/nicolingua-0001-language-id/language-id-annotations/metadata.csv"
FEATURE_DIRS = [
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-z',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-z'
]


dropout_p = 0.6
fc_dropout_p = 0.8

RESULTS_DIR = f'results_008_gn_lang_classification__dropout_{dropout_p}__fc_dropout_{fc_dropout_p}'

GPU_ID = 0

# %%
annotation_specification = {
    0: {
        'id': 0,
        'label': "maninka",
        'required_tags': set(['ct-speech', 'lng-maninka']),
        'forbidden_tags':  set(['lng-susu', 'lng-pular'])
    },
    1: {
        'id': 1,
        'label': "susu",
        'required_tags': set(['ct-speech', 'lng-susu']),
        'forbidden_tags':  set(['lng-maninka', 'lng-pular'])
    },
    2: {
        'id': 2,
        'label': "pular",
        'required_tags': set(['ct-speech', 'lng-pular']),
        'forbidden_tags':  set(['lng-susu', 'lng-maninka'])
    }
}

# %%
bias_category_specification = [
    {
        "category": "utterance",
        "subcategories": [
            {
                "subcategory": "verbal_nod",
                "tags": set(["utt-verbal-nod"])
            },
            {
                "subcategory": "multilingual",
                "tags": set(["utt-multi-lingual", "utt-multi-lingual-named-endity"])
            }
        ]
    },
    {
        "category": "speaker_count",
        "subcategories": [
            {
                "subcategory": "single",
                "tags": set(["spkr-single"])
            },
            {
                "subcategory": "multiple",
                "tags": set(["spkr-mult", "spkr-multi"])
            }
        ]
    },
    {
        "category": "gender",
        "subcategories": [
            {
                "subcategory": "male",
                "tags": set(["spkr-male"])
            },
            {
                "subcategory": "female",
                "tags": set(["spkr-female"])
            },
        ]
    },
    {
        "category": "language",
        "subcategories": [
            {
                "subcategory": "susu",
                "tags": set(["lng-susu"])
            },
            {
                "subcategory": "maninka",
                "tags": set(["lng-maninka"])
            },
            {
                "subcategory": "pular",
                "tags": set(["lng-pular"])
            }
        ]
    },
    {
        "category": "channel",
        "subcategories": [
            {
                "subcategory": "telephone",
                "tags": set(["ct-telephone"])
            },
            {
                "subcategory": "noise",
                "tags": set(["ct-noise"])
            },
            {
                "subcategory": "music",
                "tags": set(["ct-fg-music", "ct-tr-music", "ct-bg-music"])
            }
        ]
    }
]

flat_bias_category_specification = {}

for c in bias_category_specification:
    for sc in c['subcategories']:
        k = f"{c['category']}_{sc['subcategory']}"
        flat_bias_category_specification[k] = sc['tags']

_ = [print(f"{k}: {v}") for k,v in flat_bias_category_specification.items()]
# Out:
# utterance_verbal_nod: {'utt-verbal-nod'}
# utterance_multilingual: {'utt-multi-lingual-named-endity', 'utt-multi-lingual'}
# speaker_count_single: {'spkr-single'}
# speaker_count_multiple: {'spkr-multi', 'spkr-mult'}
# gender_male: {'spkr-male'}
# gender_female: {'spkr-female'}
# language_susu: {'lng-susu'}
# language_maninka: {'lng-maninka'}
# language_pular: {'lng-pular'}
# channel_telephone: {'ct-telephone'}
# channel_noise: {'ct-noise'}
# channel_music: {'ct-tr-music', 'ct-fg-music', 'ct-bg-music'}

# %%
def to_user_friendly_feature_name(fv_name):
    name = fv_name \
        .replace("features-", "") \
        .replace("wav2vec_", "") \
        .replace("average", "avg") \
        .replace("timestep", "T") \
        .replace("c.", "Context") \
        .replace("z.", "Latent")
    return name

# %% [markdown]
# # Load annotations

# %%
def load_annotations(a_file_path, a_specification):
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for row in reader:
            tag_set = set([t.strip() for t in row['tags'].split(";")])
            for label in annotation_specification.keys():
                spec = annotation_specification[label]
                if spec['required_tags'].issubset(tag_set):
                    if spec['forbidden_tags'].isdisjoint(tag_set):
                        yield row['file'], label, tag_set
                        break

data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
audio_files, audio_labels, audio_tags = zip(*data)

# %% [markdown]
# ## Inspect label counts

# %%
def inspect_label_counts():
    for label in annotation_specification:
        count = len([l for l in audio_labels if l == label])
        print("{:10} ({}): {}".format(
            annotation_specification[label]['label'],
            label, 
            count
        ))
inspect_label_counts()
# Out:
# maninka    (0): 114
# susu       (1): 32
# pular      (2): 28

# %% [markdown]
# ## Balance data

# %%
count_per_class = 28
data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
balanced_data = []
for label in annotation_specification:
    balanced_data.extend([d for d in data if d[1] == label][:count_per_class])
audio_files, audio_labels, audio_tags = zip(*balanced_data)

# %%
inspect_label_counts()
# Out:
# maninka    (0): 28
# susu       (1): 28
# pular      (2): 28

# %% [markdown]
# ## Inspect bias category counts in balanded data

# %%
def inspect_bias_category_counts():
    for name, tags in flat_bias_category_specification.items():
        count = len([ts for ts in audio_tags if len(tags.intersection(ts))>0])
        print(name, count, "/", len(audio_tags))
            
inspect_bias_category_counts()
# Out:
# utterance_verbal_nod 48 / 84
# utterance_multilingual 21 / 84
# speaker_count_single 25 / 84
# speaker_count_multiple 58 / 84
# gender_male 81 / 84
# gender_female 15 / 84
# language_susu 28 / 84
# language_maninka 28 / 84
# language_pular 28 / 84
# channel_telephone 27 / 84
# channel_noise 21 / 84
# channel_music 24 / 84

# %% [markdown]
# # Prepare 10 cross validation folds

# %%
TRAIN_PERCENT = .6
FOLD_COUNT = 10

n = len(audio_files)
n_train = int(np.ceil(n * .6))
n_test = n - n_train
all_indices = range(n)

cv_folds = {}
train_count_by_index = {i:0 for i in all_indices}
test_count_by_index = {i:0 for i in all_indices}

for fold_index in range(FOLD_COUNT):
    fold_rsampler = np.random.RandomState(seed=fold_index)
    train_index_set = set(fold_rsampler.choice(all_indices, n_train, replace=False))
    test_index_set = set(all_indices).difference(train_index_set)
        
    cv_folds[fold_index] = {
        'train_indices': sorted(list(train_index_set)),
        'test_indices': sorted(list(test_index_set)),
    }

# %% [markdown]
# # Load features

# %%
def load_features(audio_files, features_input_dir):
    id_list = []
    features_list = []

    for audio_file_name in audio_files:
        feature_file_name = audio_file_name.replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            # features = pool_feature_last_seq(features)
            features_list.append(features)
    return features_list

# %%
raw_features = {}
for feature_dir in FEATURE_DIRS:
    feature_name = Path(feature_dir).stem
    raw_features[feature_name] = load_features(audio_files, feature_dir)

# %% [markdown]
# ## Inspect feature shapes

# %%
for feature_name in raw_features.keys():
    print("feature_name: {}. feature shape: {}".format(
        to_user_friendly_feature_name(feature_name),
        raw_features[feature_name][0].shape
    ))
# Out:
# feature_name: c. feature shape: (2998, 512)
# feature_name: z. feature shape: (2998, 512)
# feature_name: retrained-c. feature shape: (2998, 512)
# feature_name: retrained-z. feature shape: (2998, 512)

# %% [markdown]
# ## Extract feature vectors

# %%
def extract_last_timestep_features(raw_features):
    return raw_features[-1, :]

def extract_neuron_average_features(raw_features):
    return np.mean(raw_features, axis=0)

def identity(x):
    return x

feature_extractors = {
    'last_timestep': extract_last_timestep_features,
    'neuron_average': extract_neuron_average_features,
    'raw_features': identity
}

# %%
feature_vectors = {}
for feature_name in raw_features.keys():
    for feature_extractor_name in feature_extractors.keys():
        fv_name = f"{feature_name}__{feature_extractor_name}"
        feature_vectors[fv_name] = []
        for f in raw_features[feature_name]:
            feature_vectors[fv_name].append(
                feature_extractors[feature_extractor_name](f)
            )
            
        feature_vectors[fv_name] = np.array(feature_vectors[fv_name])

# %% [markdown]
# ## Inspect feature vectors

# %%
for fvname in feature_vectors.keys():
    print(fvname, feature_vectors[fvname][0].shape)
# Out:
# wav2vec_features-c__last_timestep (512,)
# wav2vec_features-c__neuron_average (512,)
# wav2vec_features-c__raw_features (2998, 512)
# wav2vec_features-z__last_timestep (512,)
# wav2vec_features-z__neuron_average (512,)
# wav2vec_features-z__raw_features (2998, 512)
# retrained-wav2vec_features-c__last_timestep (512,)
# retrained-wav2vec_features-c__neuron_average (512,)
# retrained-wav2vec_features-c__raw_features (2998, 512)
# retrained-wav2vec_features-z__last_timestep (512,)
# retrained-wav2vec_features-z__neuron_average (512,)
# retrained-wav2vec_features-z__raw_features (2998, 512)

# %% [markdown]
# # Classification Models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
class LangIdCNN_Mean2_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_Mean2_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=9, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x
    

class LangIdCNN_MeanStd_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_MeanStd_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=18, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1_mean = torch.mean(x, dim=2)
        v1_std = torch.std(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2_mean = torch.mean(x, dim=2)
        v2_std = torch.std(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3_mean = torch.mean(x, dim=2)
        v3_std = torch.std(x, dim=2)
        
        v = torch.cat((v1_mean, v1_std, v2_mean, v2_std, v3_mean, v3_std), axis=1)
        
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x

# %% [markdown]
# # Train Classification Models

# %%
def get_data_for_fold(fold_id, feature_name, batch_size):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']    

    train_x = np.take(raw_features[feature_name], train_indices, axis=0)
    train_y = np.take(audio_labels, train_indices, axis=0)
    train_tags = np.take(audio_tags, train_indices, axis=0)
    train_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        train_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in train_tags]

    test_x = np.take(raw_features[feature_name], test_indices, axis=0)
    test_y = np.take(audio_labels, test_indices, axis=0)
    test_tags = np.take(audio_tags, test_indices, axis=0)
    test_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        test_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in test_tags]
        
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

def get_audio_files_for_fold(fold_id):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']
    
    train_files = np.take(audio_files, train_indices, axis=0)
    test_files = np.take(audio_files, test_indices, axis=0)
    
    return train_files, test_files
    

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name, batch_size)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y)
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y)
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
l2 = nn.PairwiseDistance(p=2)
margin = 1

# See:
# http://caffe.berkeleyvision.org/doxygen/classcaffe_1_1ContrastiveLossLayer.html#details
# http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf

def contrastive_loss(representations, labels):
    normalized_reps = F.normalize(representations, dim=1)
    
    loss = 0
    n = 0
    for i in range(normalized_reps.shape[0]):
        for j in range(normalized_reps.shape[0]):
            d = l2(
                normalized_reps[i].view(1, -1), 
                normalized_reps[j].view(1, -1)
            )
            if labels[i] == labels[j]:
                loss += torch.square(d)
            else:
                loss += torch.square(torch.max(
                    torch.tensor([margin-d, 0]).to(representations.device)
                ))
            
            n+=1
            
    loss = loss / (2*n)
    
    return loss[0]

# %%
def train_on_fold(model_class, fold_id, feature_name, batch_size, epochs, use_contrastive_term):
    device = torch.device(f"cuda:{GPU_ID}")
    torch.manual_seed(0)
    results = {}
    
    model = model_class().to(device)

    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model_class(), torch.zeros((10, 2998, 512)), show_input=False))

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0
        pred_train_classes = []
        true_train_classes = []

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
            
            optimizer.zero_grad()
            representations, outputs = model(x)
            pred_train_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )
            true_train_classes.extend(y.cpu().numpy())
            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += 0.1 * contrastive_loss(representations, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_n = len(true_train_classes)
        
        train_loss = train_loss/len(train_loader)
        train_acc = sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes)
        train_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes, sample_weight=sw)
            for category, sw in train_bias_category_labels.items()
        }
        

        pred_test_logits = []
        
        pred_test_classes = []
        true_test_classes = []
        
        model.eval()
        test_loss = 0
        for batch_idx, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            
            representations, outputs = model(x)
            
            pred_test_logits.extend(outputs.detach().cpu().numpy())

            pred_test_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )

            true_test_classes.extend(y.cpu().numpy())

            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += contrastive_loss(representations, y)
                
            test_loss += loss.item()


        test_n = len(true_test_classes)
        
        test_loss = test_loss / len(test_loader)
        test_acc = sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes)
        test_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes, sample_weight=sw)
            for category, sw in test_bias_category_labels.items()
        }

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_loss:0.4}. Test Loss: {test_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
        results[epoch] = {
            'epoch': epoch,
            'train_loss': train_loss,
            'test_loss': test_loss,
            'train_acc': train_acc,
            'test_acc': test_acc,
            'train_n': train_n,
            'test_n': test_n,
            'test_logits': pred_test_logits,
            'test_true_classes': true_test_classes
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))
        
    del model
    return results

# %%
import csv
from pathlib import Path

def write_epoch_test_logits(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        train_audio_files, test_audio_files = get_audio_files_for_fold(fold_index)
        
        for epoch in sorted(result_entry['epochs'].keys()):
            
            parent_dir = Path(f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}_data")
            parent_dir.mkdir(parents=True, exist_ok=True)

            file_name = parent_dir / f"epoch_{epoch:04}.csv"
            with open(file_name, "w") as f:
                writer = csv.DictWriter(f, fieldnames=["fold_id", "datum_index", "datum_name", "true_class_id", "logits"])
                writer.writeheader()
                
                test_logits = result_entry['epochs'][epoch]["test_logits"]
                test_true_classes = result_entry['epochs'][epoch]["test_true_classes"]
                
                for datum_index in range(len(test_logits)):
                    writer.writerow({
                        "fold_id": fold_index,
                        "datum_index": datum_index,
                        "datum_name": test_audio_files[datum_index],
                        "true_class_id": test_true_classes[datum_index],
                        "logits": test_logits[datum_index]
                    })
                

            annotation_specification.keys()

            field_names = ["index", "fname", "logits"]

            fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            fieldnames.remove("test_logits") # logged separately, differently
            fieldnames.remove("test_true_classes") # logged separately, differently
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='ignore')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
model_classes = [
    #LangIdCNN_MeanStd_FCD,
    LangIdCNN_Mean2_FCD,
]

for model_class in model_classes:
    all_folds_results = []
    for fold_index in [5, 6, 7, 8, 9]: #cv_folds:
        for feature_name in ['retrained-wav2vec_features-z', 'wav2vec_features-z']: #raw_features:
            use_contrastive_term = "Contrastive" in model_class.__name__
            
            print(f"{model_class.__name__} using {feature_name} on fold#{fold_index}. Contrastive: {use_contrastive_term}")
            resutls = train_on_fold(model_class, fold_index, feature_name, batch_size=100, epochs=1000, use_contrastive_term=use_contrastive_term)
            all_folds_results.append({
                'fold_index': fold_index,
                'feature_name': feature_name,
                'epochs': resutls
            })
            save_results(model_class.__name__, all_folds_results)
            write_epoch_test_logits(model_class.__name__, all_folds_results)
# Out:
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.065. Test Loss: 1.102. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.107. Test Loss: 1.097. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.103. Test Loss: 1.093. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.127. Test Loss: 1.092. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.074. Test Loss: 1.092. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.084. Test Loss: 1.093. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.11. Test Loss: 1.091. Train Acc: 0.2745. Test Acc:0.4545
# Epoch: 80. Train Loss: 1.111. Test Loss: 1.091. Train Acc: 0.2549. Test Acc:0.3939
# Epoch: 90. Train Loss: 1.102. Test Loss: 1.092. Train Acc: 0.2549. Test Acc:0.4545
# Epoch: 100. Train Loss: 1.075. Test Loss: 1.091. Train Acc: 0.4118. Test Acc:0.3939
# Epoch: 110. Train Loss: 1.089. Test Loss: 1.09. Train Acc: 0.2941. Test Acc:0.3939
# Epoch: 120. Train Loss: 1.078. Test Loss: 1.09. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 130. Train Loss: 1.072. Test Loss: 1.086. Train Acc: 0.3333. Test Acc:0.3939
# Epoch: 140. Train Loss: 1.044. Test Loss: 1.086. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 150. Train Loss: 1.013. Test Loss: 1.082. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 160. Train Loss: 1.024. Test Loss: 1.079. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 170. Train Loss: 0.9839. Test Loss: 1.077. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 180. Train Loss: 0.9644. Test Loss: 1.078. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 190. Train Loss: 0.9418. Test Loss: 1.079. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 200. Train Loss: 0.9718. Test Loss: 1.074. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 210. Train Loss: 0.9246. Test Loss: 1.073. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 220. Train Loss: 0.9667. Test Loss: 1.069. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 230. Train Loss: 0.9567. Test Loss: 1.074. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 240. Train Loss: 0.9144. Test Loss: 1.073. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 250. Train Loss: 0.8625. Test Loss: 1.063. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 260. Train Loss: 0.8366. Test Loss: 1.068. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 270. Train Loss: 0.8304. Test Loss: 1.061. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 280. Train Loss: 0.8525. Test Loss: 1.082. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 290. Train Loss: 0.84. Test Loss: 1.078. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 300. Train Loss: 0.8078. Test Loss: 1.067. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 310. Train Loss: 0.7814. Test Loss: 1.076. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 320. Train Loss: 0.792. Test Loss: 1.092. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 330. Train Loss: 0.7791. Test Loss: 1.076. Train Acc: 0.6078. Test Acc:0.4242
# Epoch: 340. Train Loss: 0.67. Test Loss: 1.099. Train Acc: 0.6863. Test Acc:0.3333
# Epoch: 350. Train Loss: 0.7573. Test Loss: 1.125. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 360. Train Loss: 0.6952. Test Loss: 1.126. Train Acc: 0.7059. Test Acc:0.303
# Epoch: 370. Train Loss: 0.741. Test Loss: 1.119. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 380. Train Loss: 0.6874. Test Loss: 1.124. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 390. Train Loss: 0.6378. Test Loss: 1.152. Train Acc: 0.6471. Test Acc:0.2727
# Epoch: 400. Train Loss: 0.7404. Test Loss: 1.197. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 410. Train Loss: 0.6471. Test Loss: 1.151. Train Acc: 0.6863. Test Acc:0.303
# Epoch: 420. Train Loss: 0.7514. Test Loss: 1.163. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 430. Train Loss: 0.6574. Test Loss: 1.174. Train Acc: 0.7059. Test Acc:0.303
# Epoch: 440. Train Loss: 0.6846. Test Loss: 1.187. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 450. Train Loss: 0.69. Test Loss: 1.23. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 460. Train Loss: 0.6423. Test Loss: 1.231. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 470. Train Loss: 0.6848. Test Loss: 1.256. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 480. Train Loss: 0.6444. Test Loss: 1.227. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 490. Train Loss: 0.6347. Test Loss: 1.265. Train Acc: 0.7647. Test Acc:0.303
# Epoch: 500. Train Loss: 0.632. Test Loss: 1.243. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 510. Train Loss: 0.6169. Test Loss: 1.27. Train Acc: 0.6863. Test Acc:0.2727
# Epoch: 520. Train Loss: 0.7164. Test Loss: 1.248. Train Acc: 0.549. Test Acc:0.303
# Epoch: 530. Train Loss: 0.6012. Test Loss: 1.23. Train Acc: 0.7059. Test Acc:0.303
# Epoch: 540. Train Loss: 0.6595. Test Loss: 1.258. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 550. Train Loss: 0.6103. Test Loss: 1.262. Train Acc: 0.7451. Test Acc:0.3333
# Epoch: 560. Train Loss: 0.6052. Test Loss: 1.276. Train Acc: 0.6863. Test Acc:0.3333
# Epoch: 570. Train Loss: 0.6564. Test Loss: 1.239. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 580. Train Loss: 0.5952. Test Loss: 1.274. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 590. Train Loss: 0.6265. Test Loss: 1.274. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 600. Train Loss: 0.6109. Test Loss: 1.264. Train Acc: 0.6863. Test Acc:0.3636
# Epoch: 610. Train Loss: 0.6132. Test Loss: 1.251. Train Acc: 0.6863. Test Acc:0.3939
# Epoch: 620. Train Loss: 0.6719. Test Loss: 1.323. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 630. Train Loss: 0.621. Test Loss: 1.242. Train Acc: 0.7059. Test Acc:0.3939
# Epoch: 640. Train Loss: 0.5386. Test Loss: 1.294. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 650. Train Loss: 0.6046. Test Loss: 1.224. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 660. Train Loss: 0.5075. Test Loss: 1.228. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 670. Train Loss: 0.5556. Test Loss: 1.239. Train Acc: 0.8039. Test Acc:0.4545
# Epoch: 680. Train Loss: 0.5092. Test Loss: 1.225. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.521. Test Loss: 1.254. Train Acc: 0.8039. Test Acc:0.4545
# Epoch: 700. Train Loss: 0.5511. Test Loss: 1.233. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 710. Train Loss: 0.4949. Test Loss: 1.224. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 720. Train Loss: 0.4651. Test Loss: 1.244. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 730. Train Loss: 0.4957. Test Loss: 1.213. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 740. Train Loss: 0.468. Test Loss: 1.25. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 750. Train Loss: 0.506. Test Loss: 1.271. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 760. Train Loss: 0.5104. Test Loss: 1.199. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 770. Train Loss: 0.489. Test Loss: 1.36. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 780. Train Loss: 0.465. Test Loss: 1.225. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 790. Train Loss: 0.4542. Test Loss: 1.247. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.4115. Test Loss: 1.227. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 810. Train Loss: 0.4442. Test Loss: 1.277. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 820. Train Loss: 0.4573. Test Loss: 1.187. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 830. Train Loss: 0.5023. Test Loss: 1.196. Train Acc: 0.7843. Test Acc:0.5152
# Epoch: 840. Train Loss: 0.5399. Test Loss: 1.191. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 850. Train Loss: 0.3798. Test Loss: 1.191. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 860. Train Loss: 0.4152. Test Loss: 1.255. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 870. Train Loss: 0.4267. Test Loss: 1.323. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 880. Train Loss: 0.4245. Test Loss: 1.3. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 890. Train Loss: 0.3604. Test Loss: 1.277. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 900. Train Loss: 0.5038. Test Loss: 1.27. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 910. Train Loss: 0.459. Test Loss: 1.245. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.2772. Test Loss: 1.254. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 930. Train Loss: 0.3674. Test Loss: 1.325. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 940. Train Loss: 0.4186. Test Loss: 1.292. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 950. Train Loss: 0.5023. Test Loss: 1.265. Train Acc: 0.8235. Test Acc:0.5455
# Epoch: 960. Train Loss: 0.4594. Test Loss: 1.313. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 970. Train Loss: 0.2683. Test Loss: 1.306. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 980. Train Loss: 0.4549. Test Loss: 1.316. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 990. Train Loss: 0.4026. Test Loss: 1.33. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.3389. Test Loss: 1.373. Train Acc: 0.8824. Test Acc:0.6061
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.065. Test Loss: 1.102. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.108. Test Loss: 1.097. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.103. Test Loss: 1.094. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.129. Test Loss: 1.093. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.074. Test Loss: 1.093. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.095. Test Loss: 1.094. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.118. Test Loss: 1.092. Train Acc: 0.2549. Test Acc:0.3939
# Epoch: 80. Train Loss: 1.117. Test Loss: 1.092. Train Acc: 0.2745. Test Acc:0.4848
# Epoch: 90. Train Loss: 1.114. Test Loss: 1.094. Train Acc: 0.2353. Test Acc:0.4242
# Epoch: 100. Train Loss: 1.087. Test Loss: 1.094. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 110. Train Loss: 1.114. Test Loss: 1.094. Train Acc: 0.2745. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.098. Test Loss: 1.094. Train Acc: 0.3137. Test Acc:0.303
# Epoch: 130. Train Loss: 1.101. Test Loss: 1.093. Train Acc: 0.2549. Test Acc:0.3636
# Epoch: 140. Train Loss: 1.088. Test Loss: 1.094. Train Acc: 0.2745. Test Acc:0.3333
# Epoch: 150. Train Loss: 1.05. Test Loss: 1.091. Train Acc: 0.4314. Test Acc:0.3333
# Epoch: 160. Train Loss: 1.068. Test Loss: 1.09. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 170. Train Loss: 1.034. Test Loss: 1.089. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 180. Train Loss: 1.047. Test Loss: 1.092. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 190. Train Loss: 1.007. Test Loss: 1.096. Train Acc: 0.549. Test Acc:0.2727
# Epoch: 200. Train Loss: 1.034. Test Loss: 1.088. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 210. Train Loss: 1.002. Test Loss: 1.085. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 220. Train Loss: 1.022. Test Loss: 1.085. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 230. Train Loss: 1.044. Test Loss: 1.098. Train Acc: 0.451. Test Acc:0.2727
# Epoch: 240. Train Loss: 1.036. Test Loss: 1.096. Train Acc: 0.4706. Test Acc:0.2121
# Epoch: 250. Train Loss: 0.9496. Test Loss: 1.089. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 260. Train Loss: 0.9514. Test Loss: 1.103. Train Acc: 0.549. Test Acc:0.2424
# Epoch: 270. Train Loss: 0.9331. Test Loss: 1.1. Train Acc: 0.549. Test Acc:0.303
# Epoch: 280. Train Loss: 0.9682. Test Loss: 1.121. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 290. Train Loss: 0.9707. Test Loss: 1.106. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 300. Train Loss: 0.9627. Test Loss: 1.11. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 310. Train Loss: 0.9166. Test Loss: 1.106. Train Acc: 0.549. Test Acc:0.303
# Epoch: 320. Train Loss: 0.9192. Test Loss: 1.124. Train Acc: 0.5098. Test Acc:0.2727
# Epoch: 330. Train Loss: 0.8903. Test Loss: 1.111. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 340. Train Loss: 0.8267. Test Loss: 1.116. Train Acc: 0.6078. Test Acc:0.303
# Epoch: 350. Train Loss: 0.9195. Test Loss: 1.132. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 360. Train Loss: 0.845. Test Loss: 1.133. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 370. Train Loss: 0.9313. Test Loss: 1.127. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 380. Train Loss: 0.8681. Test Loss: 1.122. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 390. Train Loss: 0.7989. Test Loss: 1.151. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 400. Train Loss: 0.8689. Test Loss: 1.139. Train Acc: 0.5098. Test Acc:0.303
# Epoch: 410. Train Loss: 0.7891. Test Loss: 1.134. Train Acc: 0.549. Test Acc:0.303
# Epoch: 420. Train Loss: 0.8821. Test Loss: 1.143. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 430. Train Loss: 0.8011. Test Loss: 1.125. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 440. Train Loss: 0.7813. Test Loss: 1.155. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 450. Train Loss: 0.8263. Test Loss: 1.146. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 460. Train Loss: 0.7491. Test Loss: 1.157. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 470. Train Loss: 0.7961. Test Loss: 1.159. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 480. Train Loss: 0.7516. Test Loss: 1.148. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 490. Train Loss: 0.7348. Test Loss: 1.166. Train Acc: 0.7647. Test Acc:0.3939
# Epoch: 500. Train Loss: 0.7229. Test Loss: 1.143. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 510. Train Loss: 0.7277. Test Loss: 1.152. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 520. Train Loss: 0.7764. Test Loss: 1.164. Train Acc: 0.4902. Test Acc:0.4545
# Epoch: 530. Train Loss: 0.701. Test Loss: 1.165. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 540. Train Loss: 0.7339. Test Loss: 1.168. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 550. Train Loss: 0.6883. Test Loss: 1.182. Train Acc: 0.6863. Test Acc:0.4242
# Epoch: 560. Train Loss: 0.6703. Test Loss: 1.192. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 570. Train Loss: 0.6954. Test Loss: 1.202. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 580. Train Loss: 0.6776. Test Loss: 1.213. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 590. Train Loss: 0.6986. Test Loss: 1.221. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 600. Train Loss: 0.7004. Test Loss: 1.263. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 610. Train Loss: 0.669. Test Loss: 1.282. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 620. Train Loss: 0.75. Test Loss: 1.311. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 630. Train Loss: 0.7417. Test Loss: 1.258. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 640. Train Loss: 0.61. Test Loss: 1.225. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 650. Train Loss: 0.6606. Test Loss: 1.217. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 660. Train Loss: 0.5883. Test Loss: 1.244. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 670. Train Loss: 0.6344. Test Loss: 1.253. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 680. Train Loss: 0.619. Test Loss: 1.231. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.6217. Test Loss: 1.242. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 700. Train Loss: 0.6231. Test Loss: 1.236. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 710. Train Loss: 0.634. Test Loss: 1.234. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 720. Train Loss: 0.5637. Test Loss: 1.247. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 730. Train Loss: 0.6485. Test Loss: 1.268. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 740. Train Loss: 0.5613. Test Loss: 1.254. Train Acc: 0.7843. Test Acc:0.5152
# Epoch: 750. Train Loss: 0.6025. Test Loss: 1.306. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 760. Train Loss: 0.6469. Test Loss: 1.245. Train Acc: 0.5882. Test Acc:0.4848
# Epoch: 770. Train Loss: 0.6171. Test Loss: 1.378. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 780. Train Loss: 0.5809. Test Loss: 1.294. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 790. Train Loss: 0.6044. Test Loss: 1.252. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.5686. Test Loss: 1.277. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 810. Train Loss: 0.5608. Test Loss: 1.27. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 820. Train Loss: 0.6369. Test Loss: 1.281. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 830. Train Loss: 0.6185. Test Loss: 1.279. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 840. Train Loss: 0.6744. Test Loss: 1.349. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 850. Train Loss: 0.543. Test Loss: 1.312. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 860. Train Loss: 0.5695. Test Loss: 1.298. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 870. Train Loss: 0.5629. Test Loss: 1.333. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 880. Train Loss: 0.551. Test Loss: 1.348. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 890. Train Loss: 0.5303. Test Loss: 1.337. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 900. Train Loss: 0.6226. Test Loss: 1.307. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 910. Train Loss: 0.6496. Test Loss: 1.301. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.4533. Test Loss: 1.295. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 930. Train Loss: 0.5369. Test Loss: 1.346. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 940. Train Loss: 0.5956. Test Loss: 1.344. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 950. Train Loss: 0.6031. Test Loss: 1.336. Train Acc: 0.7843. Test Acc:0.5758
# Epoch: 960. Train Loss: 0.604. Test Loss: 1.359. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 970. Train Loss: 0.4692. Test Loss: 1.372. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 980. Train Loss: 0.5756. Test Loss: 1.384. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 990. Train Loss: 0.5566. Test Loss: 1.405. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 1000. Train Loss: 0.4732. Test Loss: 1.501. Train Acc: 0.8431. Test Acc:0.5455
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#6. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.065. Test Loss: 1.105. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.109. Test Loss: 1.102. Train Acc: 0.2353. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.106. Test Loss: 1.1. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.125. Test Loss: 1.1. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.046. Test Loss: 1.103. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.098. Test Loss: 1.108. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.116. Test Loss: 1.104. Train Acc: 0.2157. Test Acc:0.3636
# Epoch: 80. Train Loss: 1.095. Test Loss: 1.102. Train Acc: 0.2549. Test Acc:0.3636
# Epoch: 90. Train Loss: 1.106. Test Loss: 1.108. Train Acc: 0.3137. Test Acc:0.2121
# Epoch: 100. Train Loss: 1.082. Test Loss: 1.102. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 110. Train Loss: 1.11. Test Loss: 1.1. Train Acc: 0.2745. Test Acc:0.303
# Epoch: 120. Train Loss: 1.069. Test Loss: 1.101. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 130. Train Loss: 1.072. Test Loss: 1.091. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 140. Train Loss: 1.071. Test Loss: 1.088. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 150. Train Loss: 1.032. Test Loss: 1.084. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 160. Train Loss: 1.023. Test Loss: 1.081. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 170. Train Loss: 1.003. Test Loss: 1.069. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 180. Train Loss: 0.9821. Test Loss: 1.076. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 190. Train Loss: 0.9955. Test Loss: 1.071. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 200. Train Loss: 1.012. Test Loss: 1.051. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 210. Train Loss: 0.9438. Test Loss: 1.06. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 220. Train Loss: 0.9568. Test Loss: 1.056. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 230. Train Loss: 0.9379. Test Loss: 1.055. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 240. Train Loss: 0.887. Test Loss: 1.053. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 250. Train Loss: 0.8759. Test Loss: 1.042. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 260. Train Loss: 0.907. Test Loss: 1.04. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 270. Train Loss: 0.8817. Test Loss: 1.03. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 280. Train Loss: 0.8718. Test Loss: 1.067. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 290. Train Loss: 0.8871. Test Loss: 1.034. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 300. Train Loss: 0.8489. Test Loss: 1.034. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 310. Train Loss: 0.8346. Test Loss: 1.006. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 320. Train Loss: 0.8343. Test Loss: 1.018. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 330. Train Loss: 0.78. Test Loss: 1.014. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 340. Train Loss: 0.7374. Test Loss: 1.01. Train Acc: 0.6863. Test Acc:0.4242
# Epoch: 350. Train Loss: 0.7825. Test Loss: 1.027. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 360. Train Loss: 0.7024. Test Loss: 1.005. Train Acc: 0.5882. Test Acc:0.4848
# Epoch: 370. Train Loss: 0.7488. Test Loss: 1.005. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 380. Train Loss: 0.715. Test Loss: 0.9962. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 390. Train Loss: 0.6887. Test Loss: 0.9985. Train Acc: 0.5882. Test Acc:0.4848
# Epoch: 400. Train Loss: 0.745. Test Loss: 0.9993. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 410. Train Loss: 0.6676. Test Loss: 0.9894. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 420. Train Loss: 0.7447. Test Loss: 1.004. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 430. Train Loss: 0.6854. Test Loss: 0.9801. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 440. Train Loss: 0.694. Test Loss: 0.973. Train Acc: 0.5294. Test Acc:0.5455
# Epoch: 450. Train Loss: 0.7043. Test Loss: 1.021. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 460. Train Loss: 0.6379. Test Loss: 1.012. Train Acc: 0.6667. Test Acc:0.4848
# Epoch: 470. Train Loss: 0.7108. Test Loss: 0.992. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 480. Train Loss: 0.6474. Test Loss: 0.954. Train Acc: 0.6471. Test Acc:0.5455
# Epoch: 490. Train Loss: 0.6341. Test Loss: 0.9862. Train Acc: 0.6471. Test Acc:0.5152
# Epoch: 500. Train Loss: 0.6133. Test Loss: 0.9709. Train Acc: 0.6667. Test Acc:0.5455
# Epoch: 510. Train Loss: 0.6351. Test Loss: 1.001. Train Acc: 0.6667. Test Acc:0.4848
# Epoch: 520. Train Loss: 0.7108. Test Loss: 1.005. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 530. Train Loss: 0.6339. Test Loss: 0.9569. Train Acc: 0.7059. Test Acc:0.5455
# Epoch: 540. Train Loss: 0.6438. Test Loss: 0.9423. Train Acc: 0.7059. Test Acc:0.6061
# Epoch: 550. Train Loss: 0.6165. Test Loss: 0.9585. Train Acc: 0.8235. Test Acc:0.5455
# Epoch: 560. Train Loss: 0.6287. Test Loss: 0.977. Train Acc: 0.6275. Test Acc:0.5152
# Epoch: 570. Train Loss: 0.6997. Test Loss: 0.9334. Train Acc: 0.549. Test Acc:0.5758
# Epoch: 580. Train Loss: 0.5857. Test Loss: 0.9056. Train Acc: 0.7255. Test Acc:0.5758
# Epoch: 590. Train Loss: 0.6259. Test Loss: 0.9171. Train Acc: 0.7255. Test Acc:0.6061
# Epoch: 600. Train Loss: 0.5943. Test Loss: 0.9353. Train Acc: 0.7647. Test Acc:0.5758
# Epoch: 610. Train Loss: 0.5442. Test Loss: 0.9067. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 620. Train Loss: 0.6539. Test Loss: 0.9489. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 630. Train Loss: 0.6048. Test Loss: 0.9005. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 640. Train Loss: 0.5305. Test Loss: 0.8863. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 650. Train Loss: 0.567. Test Loss: 0.8778. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 660. Train Loss: 0.5454. Test Loss: 0.8674. Train Acc: 0.7843. Test Acc:0.6667
# Epoch: 670. Train Loss: 0.5507. Test Loss: 0.8673. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 680. Train Loss: 0.5325. Test Loss: 0.8571. Train Acc: 0.7059. Test Acc:0.697
# Epoch: 690. Train Loss: 0.5465. Test Loss: 0.865. Train Acc: 0.8039. Test Acc:0.7576
# Epoch: 700. Train Loss: 0.5255. Test Loss: 0.8442. Train Acc: 0.7843. Test Acc:0.7273
# Epoch: 710. Train Loss: 0.4876. Test Loss: 0.8299. Train Acc: 0.8039. Test Acc:0.7879
# Epoch: 720. Train Loss: 0.4811. Test Loss: 0.8226. Train Acc: 0.8235. Test Acc:0.8182
# Epoch: 730. Train Loss: 0.4576. Test Loss: 0.8164. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 740. Train Loss: 0.4447. Test Loss: 0.8123. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 750. Train Loss: 0.4936. Test Loss: 0.8379. Train Acc: 0.7647. Test Acc:0.7576
# Epoch: 760. Train Loss: 0.4663. Test Loss: 0.8098. Train Acc: 0.8431. Test Acc:0.8182
# Epoch: 770. Train Loss: 0.4616. Test Loss: 0.848. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 780. Train Loss: 0.3992. Test Loss: 0.8307. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 790. Train Loss: 0.4733. Test Loss: 0.8308. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 800. Train Loss: 0.4301. Test Loss: 0.8217. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 810. Train Loss: 0.4366. Test Loss: 0.8166. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 820. Train Loss: 0.5252. Test Loss: 0.8264. Train Acc: 0.8235. Test Acc:0.7576
# Epoch: 830. Train Loss: 0.5072. Test Loss: 0.8326. Train Acc: 0.7843. Test Acc:0.7576
# Epoch: 840. Train Loss: 0.5859. Test Loss: 0.846. Train Acc: 0.7843. Test Acc:0.7576
# Epoch: 850. Train Loss: 0.4111. Test Loss: 0.84. Train Acc: 0.8824. Test Acc:0.7576
# Epoch: 860. Train Loss: 0.4388. Test Loss: 0.8094. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 870. Train Loss: 0.4268. Test Loss: 0.8163. Train Acc: 0.8627. Test Acc:0.8182
# Epoch: 880. Train Loss: 0.4618. Test Loss: 0.8178. Train Acc: 0.8627. Test Acc:0.8182
# Epoch: 890. Train Loss: 0.3814. Test Loss: 0.8258. Train Acc: 0.8627. Test Acc:0.8182
# Epoch: 900. Train Loss: 0.5513. Test Loss: 0.83. Train Acc: 0.8039. Test Acc:0.8182
# Epoch: 910. Train Loss: 0.5178. Test Loss: 0.8329. Train Acc: 0.8039. Test Acc:0.8182
# Epoch: 920. Train Loss: 0.275. Test Loss: 0.8662. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 930. Train Loss: 0.3821. Test Loss: 0.841. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 940. Train Loss: 0.4672. Test Loss: 0.8944. Train Acc: 0.8627. Test Acc:0.7576
# Epoch: 950. Train Loss: 0.4805. Test Loss: 0.9015. Train Acc: 0.8431. Test Acc:0.7576
# Epoch: 960. Train Loss: 0.5184. Test Loss: 0.8879. Train Acc: 0.8431. Test Acc:0.7576
# Epoch: 970. Train Loss: 0.288. Test Loss: 0.908. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 980. Train Loss: 0.4183. Test Loss: 0.8801. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 990. Train Loss: 0.4325. Test Loss: 0.8809. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 1000. Train Loss: 0.3417. Test Loss: 0.8777. Train Acc: 0.9216. Test Acc:0.8182
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#6. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.064. Test Loss: 1.106. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.109. Test Loss: 1.104. Train Acc: 0.2353. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.107. Test Loss: 1.102. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.128. Test Loss: 1.102. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.05. Test Loss: 1.105. Train Acc: 0.3922. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.105. Test Loss: 1.109. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.121. Test Loss: 1.108. Train Acc: 0.1961. Test Acc:0.3636
# Epoch: 80. Train Loss: 1.094. Test Loss: 1.107. Train Acc: 0.2157. Test Acc:0.3636
# Epoch: 90. Train Loss: 1.118. Test Loss: 1.113. Train Acc: 0.3137. Test Acc:0.2121
# Epoch: 100. Train Loss: 1.095. Test Loss: 1.111. Train Acc: 0.3529. Test Acc:0.2121
# Epoch: 110. Train Loss: 1.125. Test Loss: 1.111. Train Acc: 0.2353. Test Acc:0.2121
# Epoch: 120. Train Loss: 1.092. Test Loss: 1.112. Train Acc: 0.3137. Test Acc:0.2121
# Epoch: 130. Train Loss: 1.1. Test Loss: 1.107. Train Acc: 0.2941. Test Acc:0.2121
# Epoch: 140. Train Loss: 1.096. Test Loss: 1.107. Train Acc: 0.2941. Test Acc:0.2424
# Epoch: 150. Train Loss: 1.05. Test Loss: 1.107. Train Acc: 0.5098. Test Acc:0.2424
# Epoch: 160. Train Loss: 1.069. Test Loss: 1.108. Train Acc: 0.3922. Test Acc:0.2424
# Epoch: 170. Train Loss: 1.06. Test Loss: 1.099. Train Acc: 0.4314. Test Acc:0.3333
# Epoch: 180. Train Loss: 1.069. Test Loss: 1.1. Train Acc: 0.451. Test Acc:0.303
# Epoch: 190. Train Loss: 1.052. Test Loss: 1.11. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 200. Train Loss: 1.069. Test Loss: 1.099. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 210. Train Loss: 1.044. Test Loss: 1.094. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 220. Train Loss: 1.038. Test Loss: 1.086. Train Acc: 0.451. Test Acc:0.4242
# Epoch: 230. Train Loss: 1.027. Test Loss: 1.09. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 240. Train Loss: 1.016. Test Loss: 1.086. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 250. Train Loss: 1.02. Test Loss: 1.072. Train Acc: 0.4314. Test Acc:0.3939
# Epoch: 260. Train Loss: 1.03. Test Loss: 1.094. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 270. Train Loss: 1.004. Test Loss: 1.073. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 280. Train Loss: 0.9976. Test Loss: 1.092. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 290. Train Loss: 0.9984. Test Loss: 1.088. Train Acc: 0.4118. Test Acc:0.3939
# Epoch: 300. Train Loss: 0.9811. Test Loss: 1.063. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 310. Train Loss: 0.9639. Test Loss: 1.065. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 320. Train Loss: 0.9709. Test Loss: 1.066. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 330. Train Loss: 0.9603. Test Loss: 1.068. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 340. Train Loss: 0.9237. Test Loss: 1.065. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 350. Train Loss: 0.9324. Test Loss: 1.067. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 360. Train Loss: 0.8721. Test Loss: 1.055. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 370. Train Loss: 0.9514. Test Loss: 1.075. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 380. Train Loss: 0.896. Test Loss: 1.057. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 390. Train Loss: 0.8774. Test Loss: 1.085. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 400. Train Loss: 0.9408. Test Loss: 1.053. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 410. Train Loss: 0.8832. Test Loss: 1.043. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 420. Train Loss: 0.8648. Test Loss: 1.064. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 430. Train Loss: 0.8782. Test Loss: 1.016. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 440. Train Loss: 0.8614. Test Loss: 1.037. Train Acc: 0.549. Test Acc:0.4242
# Epoch: 450. Train Loss: 0.853. Test Loss: 1.035. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 460. Train Loss: 0.7596. Test Loss: 1.011. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 470. Train Loss: 0.8382. Test Loss: 1.008. Train Acc: 0.549. Test Acc:0.4848
# Epoch: 480. Train Loss: 0.7992. Test Loss: 0.9895. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 490. Train Loss: 0.7562. Test Loss: 1.01. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 500. Train Loss: 0.7451. Test Loss: 0.9752. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 510. Train Loss: 0.7383. Test Loss: 0.9725. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 520. Train Loss: 0.8147. Test Loss: 0.9937. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 530. Train Loss: 0.7406. Test Loss: 0.996. Train Acc: 0.5882. Test Acc:0.4848
# Epoch: 540. Train Loss: 0.701. Test Loss: 0.972. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 550. Train Loss: 0.7321. Test Loss: 0.9645. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 560. Train Loss: 0.7079. Test Loss: 0.9658. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 570. Train Loss: 0.7442. Test Loss: 0.9761. Train Acc: 0.549. Test Acc:0.5152
# Epoch: 580. Train Loss: 0.6626. Test Loss: 0.9713. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 590. Train Loss: 0.7351. Test Loss: 0.979. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 600. Train Loss: 0.688. Test Loss: 1.005. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 610. Train Loss: 0.6419. Test Loss: 0.9789. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 620. Train Loss: 0.7068. Test Loss: 0.997. Train Acc: 0.6471. Test Acc:0.5152
# Epoch: 630. Train Loss: 0.7024. Test Loss: 0.9899. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 640. Train Loss: 0.6097. Test Loss: 0.9875. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 650. Train Loss: 0.6228. Test Loss: 0.9924. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 660. Train Loss: 0.5989. Test Loss: 0.9815. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 670. Train Loss: 0.6115. Test Loss: 0.9832. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 680. Train Loss: 0.6163. Test Loss: 0.9838. Train Acc: 0.7451. Test Acc:0.5455
# Epoch: 690. Train Loss: 0.6283. Test Loss: 1.008. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 700. Train Loss: 0.6082. Test Loss: 0.9969. Train Acc: 0.7255. Test Acc:0.5455
# Epoch: 710. Train Loss: 0.5827. Test Loss: 1.005. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 720. Train Loss: 0.5747. Test Loss: 1.011. Train Acc: 0.7647. Test Acc:0.5455
# Epoch: 730. Train Loss: 0.5986. Test Loss: 1.018. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 740. Train Loss: 0.5486. Test Loss: 1.025. Train Acc: 0.7647. Test Acc:0.5455
# Epoch: 750. Train Loss: 0.5698. Test Loss: 1.054. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 760. Train Loss: 0.6098. Test Loss: 1.039. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 770. Train Loss: 0.5679. Test Loss: 1.115. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 780. Train Loss: 0.5412. Test Loss: 1.083. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 790. Train Loss: 0.586. Test Loss: 1.078. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.5463. Test Loss: 1.049. Train Acc: 0.7451. Test Acc:0.5455
# Epoch: 810. Train Loss: 0.5516. Test Loss: 1.054. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 820. Train Loss: 0.5986. Test Loss: 1.064. Train Acc: 0.6863. Test Acc:0.5455
# Epoch: 830. Train Loss: 0.6035. Test Loss: 1.07. Train Acc: 0.7451. Test Acc:0.5455
# Epoch: 840. Train Loss: 0.6643. Test Loss: 1.079. Train Acc: 0.7059. Test Acc:0.5455
# Epoch: 850. Train Loss: 0.5448. Test Loss: 1.078. Train Acc: 0.7255. Test Acc:0.5455
# Epoch: 860. Train Loss: 0.5304. Test Loss: 1.083. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 870. Train Loss: 0.5587. Test Loss: 1.094. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 880. Train Loss: 0.5676. Test Loss: 1.103. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 890. Train Loss: 0.5056. Test Loss: 1.111. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 900. Train Loss: 0.6474. Test Loss: 1.113. Train Acc: 0.7059. Test Acc:0.5455
# Epoch: 910. Train Loss: 0.6085. Test Loss: 1.115. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.3955. Test Loss: 1.115. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 930. Train Loss: 0.5478. Test Loss: 1.121. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 940. Train Loss: 0.5688. Test Loss: 1.135. Train Acc: 0.7647. Test Acc:0.5455
# Epoch: 950. Train Loss: 0.6048. Test Loss: 1.156. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 960. Train Loss: 0.5816. Test Loss: 1.165. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 970. Train Loss: 0.4284. Test Loss: 1.174. Train Acc: 0.9216. Test Acc:0.4848
# Epoch: 980. Train Loss: 0.5292. Test Loss: 1.185. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 990. Train Loss: 0.5204. Test Loss: 1.191. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.4401. Test Loss: 1.251. Train Acc: 0.8627. Test Acc:0.5758
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#7. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.056. Test Loss: 1.114. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 20. Train Loss: 1.106. Test Loss: 1.107. Train Acc: 0.2549. Test Acc:0.3333
# Epoch: 30. Train Loss: 1.101. Test Loss: 1.102. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 40. Train Loss: 1.12. Test Loss: 1.099. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 50. Train Loss: 1.06. Test Loss: 1.099. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 60. Train Loss: 1.104. Test Loss: 1.1. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 70. Train Loss: 1.12. Test Loss: 1.095. Train Acc: 0.2353. Test Acc:0.3333
# Epoch: 80. Train Loss: 1.109. Test Loss: 1.093. Train Acc: 0.2745. Test Acc:0.3333
# Epoch: 90. Train Loss: 1.118. Test Loss: 1.096. Train Acc: 0.3137. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.09. Test Loss: 1.093. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 110. Train Loss: 1.114. Test Loss: 1.09. Train Acc: 0.2549. Test Acc:0.3939
# Epoch: 120. Train Loss: 1.118. Test Loss: 1.09. Train Acc: 0.2549. Test Acc:0.3939
# Epoch: 130. Train Loss: 1.107. Test Loss: 1.083. Train Acc: 0.2549. Test Acc:0.4242
# Epoch: 140. Train Loss: 1.103. Test Loss: 1.081. Train Acc: 0.2549. Test Acc:0.4242
# Epoch: 150. Train Loss: 1.049. Test Loss: 1.076. Train Acc: 0.5098. Test Acc:0.4545
# Epoch: 160. Train Loss: 1.081. Test Loss: 1.072. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 170. Train Loss: 1.045. Test Loss: 1.059. Train Acc: 0.3922. Test Acc:0.4848
# Epoch: 180. Train Loss: 1.085. Test Loss: 1.058. Train Acc: 0.4314. Test Acc:0.4848
# Epoch: 190. Train Loss: 1.041. Test Loss: 1.062. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 200. Train Loss: 1.062. Test Loss: 1.042. Train Acc: 0.3922. Test Acc:0.4848
# Epoch: 210. Train Loss: 1.055. Test Loss: 1.02. Train Acc: 0.3922. Test Acc:0.4545
# Epoch: 220. Train Loss: 1.035. Test Loss: 1.007. Train Acc: 0.3725. Test Acc:0.4545
# Epoch: 230. Train Loss: 1.044. Test Loss: 1.011. Train Acc: 0.451. Test Acc:0.5152
# Epoch: 240. Train Loss: 1.014. Test Loss: 0.9871. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 250. Train Loss: 1.022. Test Loss: 0.974. Train Acc: 0.3922. Test Acc:0.5152
# Epoch: 260. Train Loss: 1.007. Test Loss: 0.9607. Train Acc: 0.5294. Test Acc:0.5152
# Epoch: 270. Train Loss: 1.004. Test Loss: 0.9416. Train Acc: 0.4314. Test Acc:0.5152
# Epoch: 280. Train Loss: 0.971. Test Loss: 0.9418. Train Acc: 0.4706. Test Acc:0.5152
# Epoch: 290. Train Loss: 0.9483. Test Loss: 0.9198. Train Acc: 0.4706. Test Acc:0.5152
# Epoch: 300. Train Loss: 0.9582. Test Loss: 0.901. Train Acc: 0.4706. Test Acc:0.5455
# Epoch: 310. Train Loss: 0.9681. Test Loss: 0.889. Train Acc: 0.5098. Test Acc:0.5455
# Epoch: 320. Train Loss: 1.018. Test Loss: 0.8885. Train Acc: 0.4314. Test Acc:0.5455
# Epoch: 330. Train Loss: 0.875. Test Loss: 0.8607. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 340. Train Loss: 0.8552. Test Loss: 0.8538. Train Acc: 0.5098. Test Acc:0.5758
# Epoch: 350. Train Loss: 0.9037. Test Loss: 0.8803. Train Acc: 0.4902. Test Acc:0.5455
# Epoch: 360. Train Loss: 0.8108. Test Loss: 0.8447. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 370. Train Loss: 0.8286. Test Loss: 0.8295. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 380. Train Loss: 0.8428. Test Loss: 0.8123. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 390. Train Loss: 0.815. Test Loss: 0.8259. Train Acc: 0.5098. Test Acc:0.6061
# Epoch: 400. Train Loss: 0.8519. Test Loss: 0.8437. Train Acc: 0.4902. Test Acc:0.6061
# Epoch: 410. Train Loss: 0.788. Test Loss: 0.7828. Train Acc: 0.5686. Test Acc:0.5758
# Epoch: 420. Train Loss: 0.8216. Test Loss: 0.7878. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 430. Train Loss: 0.7766. Test Loss: 0.7934. Train Acc: 0.4902. Test Acc:0.6061
# Epoch: 440. Train Loss: 0.7757. Test Loss: 0.7722. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 450. Train Loss: 0.7756. Test Loss: 0.8095. Train Acc: 0.5686. Test Acc:0.6061
# Epoch: 460. Train Loss: 0.7016. Test Loss: 0.8012. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 470. Train Loss: 0.796. Test Loss: 0.7729. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.7165. Test Loss: 0.7646. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.7029. Test Loss: 0.7771. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 500. Train Loss: 0.6817. Test Loss: 0.7636. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 510. Train Loss: 0.6771. Test Loss: 0.7557. Train Acc: 0.5686. Test Acc:0.5758
# Epoch: 520. Train Loss: 0.7391. Test Loss: 0.7618. Train Acc: 0.549. Test Acc:0.5758
# Epoch: 530. Train Loss: 0.6794. Test Loss: 0.7866. Train Acc: 0.5882. Test Acc:0.6061
# Epoch: 540. Train Loss: 0.6993. Test Loss: 0.7601. Train Acc: 0.6078. Test Acc:0.6061
# Epoch: 550. Train Loss: 0.6811. Test Loss: 0.7617. Train Acc: 0.6471. Test Acc:0.6667
# Epoch: 560. Train Loss: 0.6487. Test Loss: 0.762. Train Acc: 0.549. Test Acc:0.697
# Epoch: 570. Train Loss: 0.7341. Test Loss: 0.7807. Train Acc: 0.549. Test Acc:0.6061
# Epoch: 580. Train Loss: 0.6644. Test Loss: 0.8003. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 590. Train Loss: 0.6806. Test Loss: 0.7885. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 600. Train Loss: 0.6603. Test Loss: 0.7784. Train Acc: 0.6078. Test Acc:0.6364
# Epoch: 610. Train Loss: 0.6579. Test Loss: 0.7715. Train Acc: 0.5294. Test Acc:0.697
# Epoch: 620. Train Loss: 0.7318. Test Loss: 0.7985. Train Acc: 0.5686. Test Acc:0.6667
# Epoch: 630. Train Loss: 0.6927. Test Loss: 0.7888. Train Acc: 0.5686. Test Acc:0.6667
# Epoch: 640. Train Loss: 0.6027. Test Loss: 0.7864. Train Acc: 0.7451. Test Acc:0.697
# Epoch: 650. Train Loss: 0.6362. Test Loss: 0.7698. Train Acc: 0.6275. Test Acc:0.7576
# Epoch: 660. Train Loss: 0.6039. Test Loss: 0.7962. Train Acc: 0.6078. Test Acc:0.7576
# Epoch: 670. Train Loss: 0.6332. Test Loss: 0.7897. Train Acc: 0.6275. Test Acc:0.7576
# Epoch: 680. Train Loss: 0.6172. Test Loss: 0.7705. Train Acc: 0.7451. Test Acc:0.8788
# Epoch: 690. Train Loss: 0.6193. Test Loss: 0.8054. Train Acc: 0.6863. Test Acc:0.8182
# Epoch: 700. Train Loss: 0.6029. Test Loss: 0.7656. Train Acc: 0.7059. Test Acc:0.8182
# Epoch: 710. Train Loss: 0.6041. Test Loss: 0.7493. Train Acc: 0.7647. Test Acc:0.8485
# Epoch: 720. Train Loss: 0.5813. Test Loss: 0.7568. Train Acc: 0.7255. Test Acc:0.8485
# Epoch: 730. Train Loss: 0.5861. Test Loss: 0.7774. Train Acc: 0.7255. Test Acc:0.8788
# Epoch: 740. Train Loss: 0.5635. Test Loss: 0.7567. Train Acc: 0.7647. Test Acc:0.8485
# ...
# Epoch: 320. Train Loss: 0.9496. Test Loss: 0.8746. Train Acc: 0.3922. Test Acc:0.6061
# Epoch: 330. Train Loss: 0.8999. Test Loss: 0.8857. Train Acc: 0.5098. Test Acc:0.6667
# Epoch: 340. Train Loss: 0.8706. Test Loss: 0.89. Train Acc: 0.549. Test Acc:0.6667
# Epoch: 350. Train Loss: 0.8404. Test Loss: 0.8539. Train Acc: 0.549. Test Acc:0.6667
# Epoch: 360. Train Loss: 0.8068. Test Loss: 0.929. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 370. Train Loss: 0.8263. Test Loss: 0.8355. Train Acc: 0.5686. Test Acc:0.6667
# Epoch: 380. Train Loss: 0.8444. Test Loss: 0.8499. Train Acc: 0.549. Test Acc:0.6667
# Epoch: 390. Train Loss: 0.799. Test Loss: 0.8595. Train Acc: 0.6275. Test Acc:0.6364
# Epoch: 400. Train Loss: 0.8707. Test Loss: 0.8526. Train Acc: 0.4902. Test Acc:0.6364
# Epoch: 410. Train Loss: 0.7359. Test Loss: 0.8375. Train Acc: 0.6275. Test Acc:0.6364
# Epoch: 420. Train Loss: 0.821. Test Loss: 0.8428. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 430. Train Loss: 0.8192. Test Loss: 0.7777. Train Acc: 0.5294. Test Acc:0.6364
# Epoch: 440. Train Loss: 0.717. Test Loss: 0.7809. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 450. Train Loss: 0.7649. Test Loss: 0.8007. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 460. Train Loss: 0.6838. Test Loss: 0.7828. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 470. Train Loss: 0.7534. Test Loss: 0.7438. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 480. Train Loss: 0.686. Test Loss: 0.7527. Train Acc: 0.6667. Test Acc:0.6364
# Epoch: 490. Train Loss: 0.6701. Test Loss: 0.7379. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 500. Train Loss: 0.6662. Test Loss: 0.7059. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 510. Train Loss: 0.7022. Test Loss: 0.7067. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 520. Train Loss: 0.7013. Test Loss: 0.7149. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 530. Train Loss: 0.6454. Test Loss: 0.8068. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 540. Train Loss: 0.683. Test Loss: 0.7682. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.6374. Test Loss: 0.7571. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 560. Train Loss: 0.6681. Test Loss: 0.6693. Train Acc: 0.6275. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.6877. Test Loss: 0.683. Train Acc: 0.6275. Test Acc:0.6667
# Epoch: 580. Train Loss: 0.6438. Test Loss: 0.6516. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 590. Train Loss: 0.6368. Test Loss: 0.6766. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 600. Train Loss: 0.6533. Test Loss: 0.6711. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 610. Train Loss: 0.6318. Test Loss: 0.6944. Train Acc: 0.7255. Test Acc:0.6667
# Epoch: 620. Train Loss: 0.7043. Test Loss: 0.6778. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 630. Train Loss: 0.611. Test Loss: 0.7706. Train Acc: 0.7843. Test Acc:0.6667
# Epoch: 640. Train Loss: 0.5276. Test Loss: 0.7359. Train Acc: 0.8235. Test Acc:0.697
# Epoch: 650. Train Loss: 0.5605. Test Loss: 0.6717. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 660. Train Loss: 0.5461. Test Loss: 0.6652. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 670. Train Loss: 0.5454. Test Loss: 0.7226. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 680. Train Loss: 0.5248. Test Loss: 0.6951. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 690. Train Loss: 0.53. Test Loss: 0.6688. Train Acc: 0.8627. Test Acc:0.6364
# Epoch: 700. Train Loss: 0.5105. Test Loss: 0.6503. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 710. Train Loss: 0.4752. Test Loss: 0.6853. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 720. Train Loss: 0.4745. Test Loss: 0.6626. Train Acc: 0.8824. Test Acc:0.6667
# Epoch: 730. Train Loss: 0.4674. Test Loss: 0.6877. Train Acc: 0.902. Test Acc:0.6364
# Epoch: 740. Train Loss: 0.4738. Test Loss: 0.663. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 750. Train Loss: 0.4939. Test Loss: 0.6995. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 760. Train Loss: 0.4876. Test Loss: 0.6158. Train Acc: 0.8039. Test Acc:0.697
# Epoch: 770. Train Loss: 0.4955. Test Loss: 0.6399. Train Acc: 0.8235. Test Acc:0.6667
# Epoch: 780. Train Loss: 0.4344. Test Loss: 0.6238. Train Acc: 0.8235. Test Acc:0.697
# Epoch: 790. Train Loss: 0.4916. Test Loss: 0.7131. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 800. Train Loss: 0.4429. Test Loss: 0.7182. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 810. Train Loss: 0.4657. Test Loss: 0.7185. Train Acc: 0.8627. Test Acc:0.6061
# Epoch: 820. Train Loss: 0.4761. Test Loss: 0.701. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 830. Train Loss: 0.491. Test Loss: 0.65. Train Acc: 0.7647. Test Acc:0.697
# Epoch: 840. Train Loss: 0.562. Test Loss: 0.6328. Train Acc: 0.7843. Test Acc:0.697
# Epoch: 850. Train Loss: 0.4253. Test Loss: 0.611. Train Acc: 0.902. Test Acc:0.697
# Epoch: 860. Train Loss: 0.4071. Test Loss: 0.6065. Train Acc: 0.8627. Test Acc:0.7273
# Epoch: 870. Train Loss: 0.4039. Test Loss: 0.6258. Train Acc: 0.902. Test Acc:0.7273
# Epoch: 880. Train Loss: 0.4397. Test Loss: 0.6272. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 890. Train Loss: 0.3678. Test Loss: 0.612. Train Acc: 0.8627. Test Acc:0.697
# Epoch: 900. Train Loss: 0.5603. Test Loss: 0.6451. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 910. Train Loss: 0.4805. Test Loss: 0.6486. Train Acc: 0.8235. Test Acc:0.6667
# Epoch: 920. Train Loss: 0.2798. Test Loss: 0.6155. Train Acc: 0.9608. Test Acc:0.697
# Epoch: 930. Train Loss: 0.3757. Test Loss: 0.6497. Train Acc: 0.9216. Test Acc:0.6667
# Epoch: 940. Train Loss: 0.444. Test Loss: 0.5711. Train Acc: 0.8039. Test Acc:0.7273
# Epoch: 950. Train Loss: 0.5443. Test Loss: 0.5925. Train Acc: 0.7647. Test Acc:0.7273
# Epoch: 960. Train Loss: 0.4692. Test Loss: 0.6154. Train Acc: 0.8431. Test Acc:0.697
# Epoch: 970. Train Loss: 0.3082. Test Loss: 0.6166. Train Acc: 0.9412. Test Acc:0.697
# Epoch: 980. Train Loss: 0.4506. Test Loss: 0.62. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 990. Train Loss: 0.4429. Test Loss: 0.5851. Train Acc: 0.8431. Test Acc:0.7576
# Epoch: 1000. Train Loss: 0.4325. Test Loss: 0.5978. Train Acc: 0.8431. Test Acc:0.7576
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#9. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.053. Test Loss: 1.128. Train Acc: 0.4314. Test Acc:0.303
# Epoch: 20. Train Loss: 1.093. Test Loss: 1.122. Train Acc: 0.2745. Test Acc:0.303
# Epoch: 30. Train Loss: 1.104. Test Loss: 1.117. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 40. Train Loss: 1.125. Test Loss: 1.114. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 50. Train Loss: 1.058. Test Loss: 1.114. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 60. Train Loss: 1.105. Test Loss: 1.115. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 70. Train Loss: 1.122. Test Loss: 1.11. Train Acc: 0.2353. Test Acc:0.303
# Epoch: 80. Train Loss: 1.097. Test Loss: 1.108. Train Acc: 0.2745. Test Acc:0.303
# Epoch: 90. Train Loss: 1.13. Test Loss: 1.111. Train Acc: 0.2941. Test Acc:0.303
# Epoch: 100. Train Loss: 1.094. Test Loss: 1.108. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 110. Train Loss: 1.127. Test Loss: 1.107. Train Acc: 0.2941. Test Acc:0.303
# Epoch: 120. Train Loss: 1.107. Test Loss: 1.108. Train Acc: 0.2745. Test Acc:0.2424
# Epoch: 130. Train Loss: 1.112. Test Loss: 1.103. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.108. Test Loss: 1.104. Train Acc: 0.1961. Test Acc:0.2727
# Epoch: 150. Train Loss: 1.053. Test Loss: 1.103. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 160. Train Loss: 1.077. Test Loss: 1.101. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 170. Train Loss: 1.072. Test Loss: 1.091. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 180. Train Loss: 1.093. Test Loss: 1.095. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 190. Train Loss: 1.057. Test Loss: 1.105. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 200. Train Loss: 1.089. Test Loss: 1.102. Train Acc: 0.451. Test Acc:0.2727
# Epoch: 210. Train Loss: 1.074. Test Loss: 1.095. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 220. Train Loss: 1.069. Test Loss: 1.08. Train Acc: 0.3333. Test Acc:0.3939
# Epoch: 230. Train Loss: 1.077. Test Loss: 1.077. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 240. Train Loss: 1.081. Test Loss: 1.08. Train Acc: 0.4118. Test Acc:0.3939
# Epoch: 250. Train Loss: 1.049. Test Loss: 1.069. Train Acc: 0.4314. Test Acc:0.4242
# Epoch: 260. Train Loss: 1.059. Test Loss: 1.074. Train Acc: 0.3529. Test Acc:0.3939
# Epoch: 270. Train Loss: 1.047. Test Loss: 1.069. Train Acc: 0.3529. Test Acc:0.4242
# Epoch: 280. Train Loss: 1.066. Test Loss: 1.062. Train Acc: 0.3529. Test Acc:0.4242
# Epoch: 290. Train Loss: 1.042. Test Loss: 1.064. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 300. Train Loss: 1.054. Test Loss: 1.025. Train Acc: 0.4314. Test Acc:0.4848
# Epoch: 310. Train Loss: 1.032. Test Loss: 1.046. Train Acc: 0.451. Test Acc:0.4242
# Epoch: 320. Train Loss: 1.014. Test Loss: 1.021. Train Acc: 0.3725. Test Acc:0.4545
# Epoch: 330. Train Loss: 0.9806. Test Loss: 1.035. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 340. Train Loss: 0.9895. Test Loss: 1.0. Train Acc: 0.4118. Test Acc:0.4848
# Epoch: 350. Train Loss: 0.9747. Test Loss: 1.04. Train Acc: 0.4706. Test Acc:0.4242
# Epoch: 360. Train Loss: 0.9218. Test Loss: 1.004. Train Acc: 0.5098. Test Acc:0.4545
# Epoch: 370. Train Loss: 0.9584. Test Loss: 0.9954. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 380. Train Loss: 0.9365. Test Loss: 1.001. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 390. Train Loss: 0.912. Test Loss: 1.034. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 400. Train Loss: 0.92. Test Loss: 1.003. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 410. Train Loss: 0.8869. Test Loss: 0.9771. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 420. Train Loss: 0.9417. Test Loss: 1.033. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 430. Train Loss: 0.8978. Test Loss: 0.9795. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 440. Train Loss: 0.8177. Test Loss: 0.9771. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 450. Train Loss: 0.8699. Test Loss: 0.9993. Train Acc: 0.5098. Test Acc:0.5455
# Epoch: 460. Train Loss: 0.802. Test Loss: 0.979. Train Acc: 0.6078. Test Acc:0.6061
# Epoch: 470. Train Loss: 0.8638. Test Loss: 0.9978. Train Acc: 0.549. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.7983. Test Loss: 0.9261. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.7807. Test Loss: 0.9329. Train Acc: 0.5686. Test Acc:0.6061
# Epoch: 500. Train Loss: 0.7807. Test Loss: 0.92. Train Acc: 0.5686. Test Acc:0.5455
# Epoch: 510. Train Loss: 0.8176. Test Loss: 0.9309. Train Acc: 0.549. Test Acc:0.5455
# Epoch: 520. Train Loss: 0.7908. Test Loss: 0.9141. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 530. Train Loss: 0.7483. Test Loss: 0.9404. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 540. Train Loss: 0.7753. Test Loss: 0.8991. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 550. Train Loss: 0.7024. Test Loss: 0.9328. Train Acc: 0.6471. Test Acc:0.5758
# Epoch: 560. Train Loss: 0.7277. Test Loss: 0.9079. Train Acc: 0.5294. Test Acc:0.6061
# Epoch: 570. Train Loss: 0.7865. Test Loss: 0.894. Train Acc: 0.5294. Test Acc:0.6061
# Epoch: 580. Train Loss: 0.716. Test Loss: 0.9178. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 590. Train Loss: 0.751. Test Loss: 0.9424. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 600. Train Loss: 0.7443. Test Loss: 0.9569. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 610. Train Loss: 0.729. Test Loss: 1.059. Train Acc: 0.549. Test Acc:0.6364
# Epoch: 620. Train Loss: 0.7691. Test Loss: 1.044. Train Acc: 0.6078. Test Acc:0.6364
# Epoch: 630. Train Loss: 0.7523. Test Loss: 1.055. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 640. Train Loss: 0.6304. Test Loss: 0.9865. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 650. Train Loss: 0.6978. Test Loss: 0.8937. Train Acc: 0.5882. Test Acc:0.6061
# Epoch: 660. Train Loss: 0.6409. Test Loss: 0.9031. Train Acc: 0.7059. Test Acc:0.6061
# Epoch: 670. Train Loss: 0.6327. Test Loss: 0.9733. Train Acc: 0.6275. Test Acc:0.6364
# Epoch: 680. Train Loss: 0.6404. Test Loss: 0.9825. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 690. Train Loss: 0.6805. Test Loss: 0.8951. Train Acc: 0.7647. Test Acc:0.6667
# Epoch: 700. Train Loss: 0.6455. Test Loss: 0.8674. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 710. Train Loss: 0.6368. Test Loss: 0.875. Train Acc: 0.7059. Test Acc:0.6667
# Epoch: 720. Train Loss: 0.6233. Test Loss: 0.9249. Train Acc: 0.7255. Test Acc:0.6667
# Epoch: 730. Train Loss: 0.6342. Test Loss: 0.9383. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 740. Train Loss: 0.6192. Test Loss: 1.002. Train Acc: 0.7647. Test Acc:0.6667
# Epoch: 750. Train Loss: 0.6504. Test Loss: 1.017. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 760. Train Loss: 0.6559. Test Loss: 0.9016. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 770. Train Loss: 0.6293. Test Loss: 0.9698. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 780. Train Loss: 0.6265. Test Loss: 0.9647. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 790. Train Loss: 0.6495. Test Loss: 0.9404. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 800. Train Loss: 0.5989. Test Loss: 0.9744. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 810. Train Loss: 0.6082. Test Loss: 1.003. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 820. Train Loss: 0.6607. Test Loss: 0.9434. Train Acc: 0.6471. Test Acc:0.6667
# Epoch: 830. Train Loss: 0.6179. Test Loss: 0.9226. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 840. Train Loss: 0.699. Test Loss: 0.9215. Train Acc: 0.7059. Test Acc:0.6667
# Epoch: 850. Train Loss: 0.5821. Test Loss: 0.9252. Train Acc: 0.7059. Test Acc:0.6667
# Epoch: 860. Train Loss: 0.5886. Test Loss: 0.9501. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 870. Train Loss: 0.5828. Test Loss: 0.9931. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 880. Train Loss: 0.61. Test Loss: 1.047. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 890. Train Loss: 0.5497. Test Loss: 0.9699. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 900. Train Loss: 0.6817. Test Loss: 0.9551. Train Acc: 0.6667. Test Acc:0.6364
# Epoch: 910. Train Loss: 0.6459. Test Loss: 0.9358. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 920. Train Loss: 0.4923. Test Loss: 0.8967. Train Acc: 0.8235. Test Acc:0.6667
# Epoch: 930. Train Loss: 0.5557. Test Loss: 0.9511. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 940. Train Loss: 0.5946. Test Loss: 0.9429. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 950. Train Loss: 0.6529. Test Loss: 0.931. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 960. Train Loss: 0.628. Test Loss: 0.956. Train Acc: 0.8039. Test Acc:0.6061
# Epoch: 970. Train Loss: 0.5141. Test Loss: 0.9169. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 980. Train Loss: 0.6001. Test Loss: 0.9281. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 990. Train Loss: 0.5945. Test Loss: 0.9232. Train Acc: 0.7255. Test Acc:0.697
# Epoch: 1000. Train Loss: 0.5506. Test Loss: 1.061. Train Acc: 0.8039. Test Acc:0.5758

# %%
# raw_features.keys()
# ['wav2vec_features-c', 'wav2vec_features-z', 'retrained-wav2vec_features-c', 'retrained-wav2vec_features-z']
