# %%
from pathlib import Path
import csv
from itertools import groupby
import h5py
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.svm import SVC
# from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import random
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# # Configuration & Utilities

# %%
random.seed(42)
COLORS = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
ANNOTATIONS_PATH = "/media/xtrem/data/experiments/nicolingua-0001-language-id/language-id-annotations/metadata.csv"
FEATURE_DIRS = [
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-z',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-z'
]


dropout_p = 0.6
fc_dropout_p = 0.7

RESULTS_DIR = f'results_008_gn_lang_classification__dropout_{dropout_p}__fc_dropout_{fc_dropout_p}'

GPU_ID = 1

# %%
annotation_specification = {
    0: {
        'id': 0,
        'label': "maninka",
        'required_tags': set(['ct-speech', 'lng-maninka']),
        'forbidden_tags':  set(['lng-susu', 'lng-pular'])
    },
    1: {
        'id': 1,
        'label': "susu",
        'required_tags': set(['ct-speech', 'lng-susu']),
        'forbidden_tags':  set(['lng-maninka', 'lng-pular'])
    },
    2: {
        'id': 2,
        'label': "pular",
        'required_tags': set(['ct-speech', 'lng-pular']),
        'forbidden_tags':  set(['lng-susu', 'lng-maninka'])
    }
}

# %%
bias_category_specification = [
    {
        "category": "utterance",
        "subcategories": [
            {
                "subcategory": "verbal_nod",
                "tags": set(["utt-verbal-nod"])
            },
            {
                "subcategory": "multilingual",
                "tags": set(["utt-multi-lingual", "utt-multi-lingual-named-endity"])
            }
        ]
    },
    {
        "category": "speaker_count",
        "subcategories": [
            {
                "subcategory": "single",
                "tags": set(["spkr-single"])
            },
            {
                "subcategory": "multiple",
                "tags": set(["spkr-mult", "spkr-multi"])
            }
        ]
    },
    {
        "category": "gender",
        "subcategories": [
            {
                "subcategory": "male",
                "tags": set(["spkr-male"])
            },
            {
                "subcategory": "female",
                "tags": set(["spkr-female"])
            },
        ]
    },
    {
        "category": "language",
        "subcategories": [
            {
                "subcategory": "susu",
                "tags": set(["lng-susu"])
            },
            {
                "subcategory": "maninka",
                "tags": set(["lng-maninka"])
            },
            {
                "subcategory": "pular",
                "tags": set(["lng-pular"])
            }
        ]
    },
    {
        "category": "channel",
        "subcategories": [
            {
                "subcategory": "telephone",
                "tags": set(["ct-telephone"])
            },
            {
                "subcategory": "noise",
                "tags": set(["ct-noise"])
            },
            {
                "subcategory": "music",
                "tags": set(["ct-fg-music", "ct-tr-music", "ct-bg-music"])
            }
        ]
    }
]

flat_bias_category_specification = {}

for c in bias_category_specification:
    for sc in c['subcategories']:
        k = f"{c['category']}_{sc['subcategory']}"
        flat_bias_category_specification[k] = sc['tags']

_ = [print(f"{k}: {v}") for k,v in flat_bias_category_specification.items()]
# Out:
# utterance_verbal_nod: {'utt-verbal-nod'}
# utterance_multilingual: {'utt-multi-lingual', 'utt-multi-lingual-named-endity'}
# speaker_count_single: {'spkr-single'}
# speaker_count_multiple: {'spkr-mult', 'spkr-multi'}
# gender_male: {'spkr-male'}
# gender_female: {'spkr-female'}
# language_susu: {'lng-susu'}
# language_maninka: {'lng-maninka'}
# language_pular: {'lng-pular'}
# channel_telephone: {'ct-telephone'}
# channel_noise: {'ct-noise'}
# channel_music: {'ct-bg-music', 'ct-fg-music', 'ct-tr-music'}

# %%
def to_user_friendly_feature_name(fv_name):
    name = fv_name \
        .replace("features-", "") \
        .replace("wav2vec_", "") \
        .replace("average", "avg") \
        .replace("timestep", "T") \
        .replace("c.", "Context") \
        .replace("z.", "Latent")
    return name

# %% [markdown]
# # Load annotations

# %%
def load_annotations(a_file_path, a_specification):
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for row in reader:
            tag_set = set([t.strip() for t in row['tags'].split(";")])
            for label in annotation_specification.keys():
                spec = annotation_specification[label]
                if spec['required_tags'].issubset(tag_set):
                    if spec['forbidden_tags'].isdisjoint(tag_set):
                        yield row['file'], label, tag_set
                        break

data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
audio_files, audio_labels, audio_tags = zip(*data)

# %% [markdown]
# ## Inspect label counts

# %%
def inspect_label_counts():
    for label in annotation_specification:
        count = len([l for l in audio_labels if l == label])
        print("{:10} ({}): {}".format(
            annotation_specification[label]['label'],
            label, 
            count
        ))
inspect_label_counts()
# Out:
# maninka    (0): 114
# susu       (1): 32
# pular      (2): 28

# %% [markdown]
# ## Balance data

# %%
count_per_class = 28
data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
balanced_data = []
for label in annotation_specification:
    balanced_data.extend([d for d in data if d[1] == label][:count_per_class])
audio_files, audio_labels, audio_tags = zip(*balanced_data)

# %%
inspect_label_counts()
# Out:
# maninka    (0): 28
# susu       (1): 28
# pular      (2): 28

# %% [markdown]
# ## Inspect bias category counts in balanded data

# %%
def inspect_bias_category_counts():
    for name, tags in flat_bias_category_specification.items():
        count = len([ts for ts in audio_tags if len(tags.intersection(ts))>0])
        print(name, count, "/", len(audio_tags))
            
inspect_bias_category_counts()
# Out:
# utterance_verbal_nod 48 / 84
# utterance_multilingual 21 / 84
# speaker_count_single 25 / 84
# speaker_count_multiple 58 / 84
# gender_male 81 / 84
# gender_female 15 / 84
# language_susu 28 / 84
# language_maninka 28 / 84
# language_pular 28 / 84
# channel_telephone 27 / 84
# channel_noise 21 / 84
# channel_music 24 / 84

# %% [markdown]
# # Prepare 10 cross validation folds

# %%
TRAIN_PERCENT = .6
FOLD_COUNT = 10

n = len(audio_files)
n_train = int(np.ceil(n * .6))
n_test = n - n_train
all_indices = range(n)

cv_folds = {}
train_count_by_index = {i:0 for i in all_indices}
test_count_by_index = {i:0 for i in all_indices}

for fold_index in range(FOLD_COUNT):
    fold_rsampler = np.random.RandomState(seed=fold_index)
    train_index_set = set(fold_rsampler.choice(all_indices, n_train, replace=False))
    test_index_set = set(all_indices).difference(train_index_set)
        
    cv_folds[fold_index] = {
        'train_indices': sorted(list(train_index_set)),
        'test_indices': sorted(list(test_index_set)),
    }

# %% [markdown]
# # Load features

# %%
def load_features(audio_files, features_input_dir):
    id_list = []
    features_list = []

    for audio_file_name in audio_files:
        feature_file_name = audio_file_name.replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            # features = pool_feature_last_seq(features)
            features_list.append(features)
    return features_list

# %%
raw_features = {}
for feature_dir in FEATURE_DIRS:
    feature_name = Path(feature_dir).stem
    raw_features[feature_name] = load_features(audio_files, feature_dir)

# %% [markdown]
# ## Inspect feature shapes

# %%
for feature_name in raw_features.keys():
    print("feature_name: {}. feature shape: {}".format(
        to_user_friendly_feature_name(feature_name),
        raw_features[feature_name][0].shape
    ))
# Out:
# feature_name: c. feature shape: (2998, 512)
# feature_name: z. feature shape: (2998, 512)
# feature_name: retrained-c. feature shape: (2998, 512)
# feature_name: retrained-z. feature shape: (2998, 512)

# %% [markdown]
# ## Extract feature vectors

# %%
def extract_last_timestep_features(raw_features):
    return raw_features[-1, :]

def extract_neuron_average_features(raw_features):
    return np.mean(raw_features, axis=0)

def identity(x):
    return x

feature_extractors = {
    'last_timestep': extract_last_timestep_features,
    'neuron_average': extract_neuron_average_features,
    'raw_features': identity
}

# %%
feature_vectors = {}
for feature_name in raw_features.keys():
    for feature_extractor_name in feature_extractors.keys():
        fv_name = f"{feature_name}__{feature_extractor_name}"
        feature_vectors[fv_name] = []
        for f in raw_features[feature_name]:
            feature_vectors[fv_name].append(
                feature_extractors[feature_extractor_name](f)
            )
            
        feature_vectors[fv_name] = np.array(feature_vectors[fv_name])

# %% [markdown]
# ## Inspect feature vectors

# %%
for fvname in feature_vectors.keys():
    print(fvname, feature_vectors[fvname][0].shape)
# Out:
# wav2vec_features-c__last_timestep (512,)
# wav2vec_features-c__neuron_average (512,)
# wav2vec_features-c__raw_features (2998, 512)
# wav2vec_features-z__last_timestep (512,)
# wav2vec_features-z__neuron_average (512,)
# wav2vec_features-z__raw_features (2998, 512)
# retrained-wav2vec_features-c__last_timestep (512,)
# retrained-wav2vec_features-c__neuron_average (512,)
# retrained-wav2vec_features-c__raw_features (2998, 512)
# retrained-wav2vec_features-z__last_timestep (512,)
# retrained-wav2vec_features-z__neuron_average (512,)
# retrained-wav2vec_features-z__raw_features (2998, 512)

# %% [markdown]
# # Classification Models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
class LangIdCNN_Mean2_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_Mean2_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=9, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x
    

class LangIdCNN_MeanStd_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_MeanStd_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=18, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1_mean = torch.mean(x, dim=2)
        v1_std = torch.std(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2_mean = torch.mean(x, dim=2)
        v2_std = torch.std(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3_mean = torch.mean(x, dim=2)
        v3_std = torch.std(x, dim=2)
        
        v = torch.cat((v1_mean, v1_std, v2_mean, v2_std, v3_mean, v3_std), axis=1)
        
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x

# %% [markdown]
# # Train Classification Models

# %%
def get_data_for_fold(fold_id, feature_name, batch_size):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']    

    train_x = np.take(raw_features[feature_name], train_indices, axis=0)
    train_y = np.take(audio_labels, train_indices, axis=0)
    train_tags = np.take(audio_tags, train_indices, axis=0)
    train_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        train_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in train_tags]

    test_x = np.take(raw_features[feature_name], test_indices, axis=0)
    test_y = np.take(audio_labels, test_indices, axis=0)
    test_tags = np.take(audio_tags, test_indices, axis=0)
    test_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        test_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in test_tags]
        
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

def get_audio_files_for_fold(fold_id):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']
    
    train_files = np.take(audio_files, train_indices, axis=0)
    test_files = np.take(audio_files, test_indices, axis=0)
    
    return train_files, test_files
    

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name, batch_size)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y)
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y)
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
l2 = nn.PairwiseDistance(p=2)
margin = 1

# See:
# http://caffe.berkeleyvision.org/doxygen/classcaffe_1_1ContrastiveLossLayer.html#details
# http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf

def contrastive_loss(representations, labels):
    normalized_reps = F.normalize(representations, dim=1)
    
    loss = 0
    n = 0
    for i in range(normalized_reps.shape[0]):
        for j in range(normalized_reps.shape[0]):
            d = l2(
                normalized_reps[i].view(1, -1), 
                normalized_reps[j].view(1, -1)
            )
            if labels[i] == labels[j]:
                loss += torch.square(d)
            else:
                loss += torch.square(torch.max(
                    torch.tensor([margin-d, 0]).to(representations.device)
                ))
            
            n+=1
            
    loss = loss / (2*n)
    
    return loss[0]

# %%
def train_on_fold(model_class, fold_id, feature_name, batch_size, epochs, use_contrastive_term):
    device = torch.device(f"cuda:{GPU_ID}")
    torch.manual_seed(0)
    results = {}
    
    model = model_class().to(device)

    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model_class(), torch.zeros((10, 2998, 512)), show_input=False))

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0
        pred_train_classes = []
        true_train_classes = []

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
            
            optimizer.zero_grad()
            representations, outputs = model(x)
            pred_train_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )
            true_train_classes.extend(y.cpu().numpy())
            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += 0.1 * contrastive_loss(representations, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_n = len(true_train_classes)
        
        train_loss = train_loss/len(train_loader)
        train_acc = sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes)
        train_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes, sample_weight=sw)
            for category, sw in train_bias_category_labels.items()
        }
        

        pred_test_logits = []
        
        pred_test_classes = []
        true_test_classes = []
        
        model.eval()
        test_loss = 0
        for batch_idx, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            
            representations, outputs = model(x)
            
            pred_test_logits.extend(outputs.detach().cpu().numpy())

            pred_test_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )

            true_test_classes.extend(y.cpu().numpy())

            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += contrastive_loss(representations, y)
                
            test_loss += loss.item()


        test_n = len(true_test_classes)
        
        test_loss = test_loss / len(test_loader)
        test_acc = sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes)
        test_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes, sample_weight=sw)
            for category, sw in test_bias_category_labels.items()
        }

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_loss:0.4}. Test Loss: {test_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
        results[epoch] = {
            'epoch': epoch,
            'train_loss': train_loss,
            'test_loss': test_loss,
            'train_acc': train_acc,
            'test_acc': test_acc,
            'train_n': train_n,
            'test_n': test_n,
            'test_logits': pred_test_logits,
            'test_true_classes': true_test_classes
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))
        
    del model
    return results

# %%
import csv
from pathlib import Path

def write_epoch_test_logits(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        train_audio_files, test_audio_files = get_audio_files_for_fold(fold_index)
        
        for epoch in sorted(result_entry['epochs'].keys()):
            
            parent_dir = Path(f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}_data")
            parent_dir.mkdir(parents=True, exist_ok=True)

            file_name = parent_dir / f"epoch_{epoch:04}.csv"
            with open(file_name, "w") as f:
                writer = csv.DictWriter(f, fieldnames=["fold_id", "datum_index", "datum_name", "true_class_id", "logits"])
                writer.writeheader()
                
                test_logits = result_entry['epochs'][epoch]["test_logits"]
                test_true_classes = result_entry['epochs'][epoch]["test_true_classes"]
                
                for datum_index in range(len(test_logits)):
                    writer.writerow({
                        "fold_id": fold_index,
                        "datum_index": datum_index,
                        "datum_name": test_audio_files[datum_index],
                        "true_class_id": test_true_classes[datum_index],
                        "logits": test_logits[datum_index]
                    })
                

            annotation_specification.keys()

            field_names = ["index", "fname", "logits"]

            fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            fieldnames.remove("test_logits") # logged separately, differently
            fieldnames.remove("test_true_classes") # logged separately, differently
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='ignore')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
model_classes = [
    #LangIdCNN_MeanStd_FCD,
    LangIdCNN_Mean2_FCD,
]

for model_class in model_classes:
    all_folds_results = []
    for fold_index in [5, 6, 7, 8, 9]: #cv_folds:
        for feature_name in ['retrained-wav2vec_features-z', 'wav2vec_features-z']: #raw_features:
            use_contrastive_term = "Contrastive" in model_class.__name__
            
            print(f"{model_class.__name__} using {feature_name} on fold#{fold_index}. Contrastive: {use_contrastive_term}")
            resutls = train_on_fold(model_class, fold_index, feature_name, batch_size=100, epochs=1000, use_contrastive_term=use_contrastive_term)
            all_folds_results.append({
                'fold_index': fold_index,
                'feature_name': feature_name,
                'epochs': resutls
            })
            save_results(model_class.__name__, all_folds_results)
            write_epoch_test_logits(model_class.__name__, all_folds_results)
# Out:
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.105. Test Loss: 1.102. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.136. Test Loss: 1.096. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.117. Test Loss: 1.093. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.12. Test Loss: 1.091. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.071. Test Loss: 1.091. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.091. Test Loss: 1.092. Train Acc: 0.3529. Test Acc:0.3939
# Epoch: 70. Train Loss: 1.112. Test Loss: 1.089. Train Acc: 0.3333. Test Acc:0.4545
# Epoch: 80. Train Loss: 1.089. Test Loss: 1.089. Train Acc: 0.3529. Test Acc:0.4848
# Epoch: 90. Train Loss: 1.088. Test Loss: 1.09. Train Acc: 0.3137. Test Acc:0.5152
# Epoch: 100. Train Loss: 1.057. Test Loss: 1.088. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 110. Train Loss: 1.046. Test Loss: 1.084. Train Acc: 0.3922. Test Acc:0.3939
# Epoch: 120. Train Loss: 1.054. Test Loss: 1.084. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 130. Train Loss: 1.036. Test Loss: 1.081. Train Acc: 0.4314. Test Acc:0.3333
# Epoch: 140. Train Loss: 0.9973. Test Loss: 1.078. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 150. Train Loss: 0.9962. Test Loss: 1.075. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 160. Train Loss: 0.9371. Test Loss: 1.076. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 170. Train Loss: 0.9191. Test Loss: 1.073. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 180. Train Loss: 0.8701. Test Loss: 1.085. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 190. Train Loss: 0.8821. Test Loss: 1.083. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 200. Train Loss: 0.893. Test Loss: 1.087. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 210. Train Loss: 0.8551. Test Loss: 1.079. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 220. Train Loss: 0.8974. Test Loss: 1.091. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 230. Train Loss: 0.8635. Test Loss: 1.083. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 240. Train Loss: 0.7742. Test Loss: 1.101. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 250. Train Loss: 0.8044. Test Loss: 1.089. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 260. Train Loss: 0.7359. Test Loss: 1.097. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 270. Train Loss: 0.7192. Test Loss: 1.116. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 280. Train Loss: 0.7341. Test Loss: 1.115. Train Acc: 0.7059. Test Acc:0.3636
# Epoch: 290. Train Loss: 0.7319. Test Loss: 1.145. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 300. Train Loss: 0.7086. Test Loss: 1.144. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 310. Train Loss: 0.6738. Test Loss: 1.153. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 320. Train Loss: 0.7258. Test Loss: 1.191. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 330. Train Loss: 0.6554. Test Loss: 1.178. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 340. Train Loss: 0.6066. Test Loss: 1.186. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 350. Train Loss: 0.6344. Test Loss: 1.219. Train Acc: 0.7451. Test Acc:0.303
# Epoch: 360. Train Loss: 0.6272. Test Loss: 1.262. Train Acc: 0.7843. Test Acc:0.303
# Epoch: 370. Train Loss: 0.6268. Test Loss: 1.254. Train Acc: 0.6863. Test Acc:0.2727
# Epoch: 380. Train Loss: 0.6172. Test Loss: 1.237. Train Acc: 0.6078. Test Acc:0.303
# Epoch: 390. Train Loss: 0.5511. Test Loss: 1.235. Train Acc: 0.6863. Test Acc:0.2727
# Epoch: 400. Train Loss: 0.6161. Test Loss: 1.327. Train Acc: 0.6667. Test Acc:0.303
# Epoch: 410. Train Loss: 0.5793. Test Loss: 1.291. Train Acc: 0.6863. Test Acc:0.3333
# Epoch: 420. Train Loss: 0.6529. Test Loss: 1.274. Train Acc: 0.7059. Test Acc:0.2727
# Epoch: 430. Train Loss: 0.5919. Test Loss: 1.279. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 440. Train Loss: 0.5851. Test Loss: 1.32. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 450. Train Loss: 0.614. Test Loss: 1.353. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 460. Train Loss: 0.5446. Test Loss: 1.344. Train Acc: 0.7255. Test Acc:0.3333
# Epoch: 470. Train Loss: 0.624. Test Loss: 1.335. Train Acc: 0.6667. Test Acc:0.303
# Epoch: 480. Train Loss: 0.565. Test Loss: 1.344. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 490. Train Loss: 0.5607. Test Loss: 1.417. Train Acc: 0.7843. Test Acc:0.4242
# Epoch: 500. Train Loss: 0.5196. Test Loss: 1.357. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 510. Train Loss: 0.5659. Test Loss: 1.417. Train Acc: 0.6667. Test Acc:0.3939
# Epoch: 520. Train Loss: 0.6. Test Loss: 1.351. Train Acc: 0.6471. Test Acc:0.3636
# Epoch: 530. Train Loss: 0.5342. Test Loss: 1.322. Train Acc: 0.7059. Test Acc:0.3939
# Epoch: 540. Train Loss: 0.5684. Test Loss: 1.378. Train Acc: 0.7059. Test Acc:0.3636
# Epoch: 550. Train Loss: 0.5625. Test Loss: 1.386. Train Acc: 0.7451. Test Acc:0.3636
# Epoch: 560. Train Loss: 0.5664. Test Loss: 1.393. Train Acc: 0.7255. Test Acc:0.3939
# Epoch: 570. Train Loss: 0.5207. Test Loss: 1.339. Train Acc: 0.8235. Test Acc:0.3939
# Epoch: 580. Train Loss: 0.5011. Test Loss: 1.368. Train Acc: 0.8431. Test Acc:0.3939
# Epoch: 590. Train Loss: 0.5204. Test Loss: 1.4. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 600. Train Loss: 0.5413. Test Loss: 1.37. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 610. Train Loss: 0.5114. Test Loss: 1.359. Train Acc: 0.8431. Test Acc:0.4242
# Epoch: 620. Train Loss: 0.5339. Test Loss: 1.444. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 630. Train Loss: 0.466. Test Loss: 1.334. Train Acc: 0.8235. Test Acc:0.4545
# Epoch: 640. Train Loss: 0.4248. Test Loss: 1.38. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 650. Train Loss: 0.4721. Test Loss: 1.338. Train Acc: 0.8627. Test Acc:0.4545
# Epoch: 660. Train Loss: 0.3673. Test Loss: 1.342. Train Acc: 0.9412. Test Acc:0.4848
# Epoch: 670. Train Loss: 0.403. Test Loss: 1.398. Train Acc: 0.902. Test Acc:0.4848
# Epoch: 680. Train Loss: 0.3861. Test Loss: 1.442. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.4134. Test Loss: 1.42. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 700. Train Loss: 0.4043. Test Loss: 1.332. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 710. Train Loss: 0.3574. Test Loss: 1.334. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 720. Train Loss: 0.3815. Test Loss: 1.362. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 730. Train Loss: 0.3694. Test Loss: 1.378. Train Acc: 0.9216. Test Acc:0.5152
# Epoch: 740. Train Loss: 0.3324. Test Loss: 1.474. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 750. Train Loss: 0.3976. Test Loss: 1.483. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 760. Train Loss: 0.4068. Test Loss: 1.399. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 770. Train Loss: 0.3454. Test Loss: 1.482. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 780. Train Loss: 0.2577. Test Loss: 1.357. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 790. Train Loss: 0.3662. Test Loss: 1.404. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 800. Train Loss: 0.2588. Test Loss: 1.409. Train Acc: 0.9804. Test Acc:0.5152
# Epoch: 810. Train Loss: 0.3033. Test Loss: 1.443. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 820. Train Loss: 0.3076. Test Loss: 1.384. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 830. Train Loss: 0.3132. Test Loss: 1.402. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 840. Train Loss: 0.315. Test Loss: 1.418. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 850. Train Loss: 0.2461. Test Loss: 1.409. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 860. Train Loss: 0.244. Test Loss: 1.439. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 870. Train Loss: 0.2267. Test Loss: 1.535. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 880. Train Loss: 0.2539. Test Loss: 1.589. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 890. Train Loss: 0.2171. Test Loss: 1.53. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 900. Train Loss: 0.3056. Test Loss: 1.56. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 910. Train Loss: 0.3173. Test Loss: 1.516. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 920. Train Loss: 0.2082. Test Loss: 1.527. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 930. Train Loss: 0.2352. Test Loss: 1.566. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 940. Train Loss: 0.24. Test Loss: 1.56. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 950. Train Loss: 0.307. Test Loss: 1.529. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 960. Train Loss: 0.2822. Test Loss: 1.576. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 970. Train Loss: 0.143. Test Loss: 1.607. Train Acc: 1.0. Test Acc:0.5455
# Epoch: 980. Train Loss: 0.2995. Test Loss: 1.579. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 990. Train Loss: 0.2124. Test Loss: 1.577. Train Acc: 1.0. Test Acc:0.5758
# Epoch: 1000. Train Loss: 0.2495. Test Loss: 1.62. Train Acc: 0.9216. Test Acc:0.5455
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.106. Test Loss: 1.102. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.138. Test Loss: 1.097. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.12. Test Loss: 1.094. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.122. Test Loss: 1.092. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.075. Test Loss: 1.092. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.099. Test Loss: 1.094. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.125. Test Loss: 1.091. Train Acc: 0.2941. Test Acc:0.4242
# Epoch: 80. Train Loss: 1.101. Test Loss: 1.092. Train Acc: 0.3137. Test Acc:0.4848
# Epoch: 90. Train Loss: 1.108. Test Loss: 1.094. Train Acc: 0.2941. Test Acc:0.4242
# Epoch: 100. Train Loss: 1.077. Test Loss: 1.094. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 110. Train Loss: 1.09. Test Loss: 1.092. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.087. Test Loss: 1.092. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 130. Train Loss: 1.093. Test Loss: 1.091. Train Acc: 0.2941. Test Acc:0.3333
# Epoch: 140. Train Loss: 1.068. Test Loss: 1.091. Train Acc: 0.451. Test Acc:0.2424
# Epoch: 150. Train Loss: 1.054. Test Loss: 1.087. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 160. Train Loss: 1.026. Test Loss: 1.086. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 170. Train Loss: 0.9942. Test Loss: 1.085. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 180. Train Loss: 0.9848. Test Loss: 1.098. Train Acc: 0.5294. Test Acc:0.2727
# Epoch: 190. Train Loss: 0.9674. Test Loss: 1.096. Train Acc: 0.5098. Test Acc:0.2121
# Epoch: 200. Train Loss: 0.9812. Test Loss: 1.099. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 210. Train Loss: 0.9402. Test Loss: 1.1. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 220. Train Loss: 1.0. Test Loss: 1.111. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 230. Train Loss: 1.028. Test Loss: 1.127. Train Acc: 0.4902. Test Acc:0.2424
# Epoch: 240. Train Loss: 0.9405. Test Loss: 1.12. Train Acc: 0.549. Test Acc:0.303
# Epoch: 250. Train Loss: 0.8721. Test Loss: 1.127. Train Acc: 0.5882. Test Acc:0.2727
# Epoch: 260. Train Loss: 0.8693. Test Loss: 1.128. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 270. Train Loss: 0.8766. Test Loss: 1.151. Train Acc: 0.549. Test Acc:0.2727
# Epoch: 280. Train Loss: 0.9102. Test Loss: 1.146. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 290. Train Loss: 0.8992. Test Loss: 1.151. Train Acc: 0.6078. Test Acc:0.303
# Epoch: 300. Train Loss: 0.9275. Test Loss: 1.146. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 310. Train Loss: 0.8824. Test Loss: 1.147. Train Acc: 0.5294. Test Acc:0.303
# Epoch: 320. Train Loss: 0.8596. Test Loss: 1.169. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 330. Train Loss: 0.833. Test Loss: 1.145. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 340. Train Loss: 0.7634. Test Loss: 1.148. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 350. Train Loss: 0.8065. Test Loss: 1.172. Train Acc: 0.7059. Test Acc:0.3333
# Epoch: 360. Train Loss: 0.7764. Test Loss: 1.197. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 370. Train Loss: 0.8071. Test Loss: 1.163. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 380. Train Loss: 0.7741. Test Loss: 1.151. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 390. Train Loss: 0.6944. Test Loss: 1.168. Train Acc: 0.6863. Test Acc:0.3636
# Epoch: 400. Train Loss: 0.7395. Test Loss: 1.204. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 410. Train Loss: 0.7112. Test Loss: 1.229. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 420. Train Loss: 0.7724. Test Loss: 1.191. Train Acc: 0.6667. Test Acc:0.4242
# Epoch: 430. Train Loss: 0.7177. Test Loss: 1.152. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 440. Train Loss: 0.6879. Test Loss: 1.164. Train Acc: 0.5686. Test Acc:0.5152
# Epoch: 450. Train Loss: 0.6985. Test Loss: 1.22. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 460. Train Loss: 0.624. Test Loss: 1.271. Train Acc: 0.7255. Test Acc:0.3939
# Epoch: 470. Train Loss: 0.7088. Test Loss: 1.246. Train Acc: 0.6863. Test Acc:0.3939
# Epoch: 480. Train Loss: 0.6767. Test Loss: 1.217. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 490. Train Loss: 0.6547. Test Loss: 1.247. Train Acc: 0.7647. Test Acc:0.4242
# Epoch: 500. Train Loss: 0.6115. Test Loss: 1.212. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 510. Train Loss: 0.6436. Test Loss: 1.239. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 520. Train Loss: 0.6675. Test Loss: 1.288. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 530. Train Loss: 0.6249. Test Loss: 1.244. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 540. Train Loss: 0.6283. Test Loss: 1.245. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 550. Train Loss: 0.6172. Test Loss: 1.285. Train Acc: 0.7843. Test Acc:0.4242
# Epoch: 560. Train Loss: 0.6471. Test Loss: 1.356. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 570. Train Loss: 0.5891. Test Loss: 1.328. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 580. Train Loss: 0.5862. Test Loss: 1.306. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 590. Train Loss: 0.5914. Test Loss: 1.353. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 600. Train Loss: 0.6536. Test Loss: 1.373. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 610. Train Loss: 0.6012. Test Loss: 1.376. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 620. Train Loss: 0.6346. Test Loss: 1.394. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 630. Train Loss: 0.5699. Test Loss: 1.397. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 640. Train Loss: 0.5343. Test Loss: 1.351. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 650. Train Loss: 0.5663. Test Loss: 1.375. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 660. Train Loss: 0.4977. Test Loss: 1.382. Train Acc: 0.8039. Test Acc:0.4545
# Epoch: 670. Train Loss: 0.5245. Test Loss: 1.39. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 680. Train Loss: 0.5344. Test Loss: 1.396. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 690. Train Loss: 0.5464. Test Loss: 1.379. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 700. Train Loss: 0.5367. Test Loss: 1.344. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 710. Train Loss: 0.5521. Test Loss: 1.348. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 720. Train Loss: 0.5002. Test Loss: 1.432. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 730. Train Loss: 0.5809. Test Loss: 1.418. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 740. Train Loss: 0.5015. Test Loss: 1.414. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 750. Train Loss: 0.4998. Test Loss: 1.404. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 760. Train Loss: 0.5918. Test Loss: 1.34. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 770. Train Loss: 0.5474. Test Loss: 1.448. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 780. Train Loss: 0.4319. Test Loss: 1.394. Train Acc: 0.9216. Test Acc:0.4848
# Epoch: 790. Train Loss: 0.5295. Test Loss: 1.418. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.4794. Test Loss: 1.408. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 810. Train Loss: 0.4977. Test Loss: 1.416. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 820. Train Loss: 0.5477. Test Loss: 1.382. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 830. Train Loss: 0.5205. Test Loss: 1.391. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 840. Train Loss: 0.513. Test Loss: 1.427. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 850. Train Loss: 0.4455. Test Loss: 1.459. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 860. Train Loss: 0.4466. Test Loss: 1.429. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 870. Train Loss: 0.4319. Test Loss: 1.482. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 880. Train Loss: 0.4569. Test Loss: 1.548. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 890. Train Loss: 0.4324. Test Loss: 1.534. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 900. Train Loss: 0.5043. Test Loss: 1.531. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 910. Train Loss: 0.5. Test Loss: 1.51. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 920. Train Loss: 0.3815. Test Loss: 1.521. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 930. Train Loss: 0.4526. Test Loss: 1.575. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 940. Train Loss: 0.4658. Test Loss: 1.571. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 950. Train Loss: 0.4601. Test Loss: 1.486. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 960. Train Loss: 0.4445. Test Loss: 1.497. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 970. Train Loss: 0.3149. Test Loss: 1.534. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.4628. Test Loss: 1.57. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 990. Train Loss: 0.4206. Test Loss: 1.563. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.4157. Test Loss: 1.629. Train Acc: 0.7647. Test Acc:0.5152
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#6. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.107. Test Loss: 1.105. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.13. Test Loss: 1.102. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.115. Test Loss: 1.101. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.12. Test Loss: 1.102. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.056. Test Loss: 1.105. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.091. Test Loss: 1.11. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.123. Test Loss: 1.102. Train Acc: 0.1961. Test Acc:0.3636
# Epoch: 80. Train Loss: 1.083. Test Loss: 1.098. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 90. Train Loss: 1.083. Test Loss: 1.105. Train Acc: 0.3137. Test Acc:0.2424
# Epoch: 100. Train Loss: 1.058. Test Loss: 1.1. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 110. Train Loss: 1.08. Test Loss: 1.093. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.047. Test Loss: 1.09. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 130. Train Loss: 1.025. Test Loss: 1.081. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 140. Train Loss: 1.038. Test Loss: 1.075. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 150. Train Loss: 1.015. Test Loss: 1.067. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 160. Train Loss: 0.9633. Test Loss: 1.056. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 170. Train Loss: 0.9367. Test Loss: 1.055. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 180. Train Loss: 0.9048. Test Loss: 1.063. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 190. Train Loss: 0.9058. Test Loss: 1.05. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 200. Train Loss: 0.93. Test Loss: 1.07. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 210. Train Loss: 0.8596. Test Loss: 1.033. Train Acc: 0.5294. Test Acc:0.4545
# Epoch: 220. Train Loss: 0.9018. Test Loss: 1.077. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 230. Train Loss: 0.8828. Test Loss: 1.05. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 240. Train Loss: 0.7836. Test Loss: 1.054. Train Acc: 0.7059. Test Acc:0.3939
# Epoch: 250. Train Loss: 0.8004. Test Loss: 1.042. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 260. Train Loss: 0.8031. Test Loss: 1.028. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 270. Train Loss: 0.7838. Test Loss: 1.065. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 280. Train Loss: 0.7959. Test Loss: 1.032. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 290. Train Loss: 0.7843. Test Loss: 1.045. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 300. Train Loss: 0.7506. Test Loss: 1.028. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 310. Train Loss: 0.738. Test Loss: 1.015. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 320. Train Loss: 0.7492. Test Loss: 1.024. Train Acc: 0.5294. Test Acc:0.4545
# Epoch: 330. Train Loss: 0.6803. Test Loss: 1.047. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 340. Train Loss: 0.678. Test Loss: 1.016. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 350. Train Loss: 0.6765. Test Loss: 1.042. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 360. Train Loss: 0.6462. Test Loss: 1.053. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 370. Train Loss: 0.6512. Test Loss: 1.03. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 380. Train Loss: 0.6589. Test Loss: 1.029. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 390. Train Loss: 0.5783. Test Loss: 1.016. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 400. Train Loss: 0.6314. Test Loss: 1.051. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 410. Train Loss: 0.5745. Test Loss: 1.049. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 420. Train Loss: 0.6402. Test Loss: 1.024. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 430. Train Loss: 0.6404. Test Loss: 1.024. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 440. Train Loss: 0.5849. Test Loss: 1.04. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 450. Train Loss: 0.6273. Test Loss: 1.082. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 460. Train Loss: 0.5756. Test Loss: 1.055. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 470. Train Loss: 0.6057. Test Loss: 0.9984. Train Acc: 0.7059. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.5852. Test Loss: 0.9823. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.5608. Test Loss: 1.038. Train Acc: 0.7647. Test Acc:0.5455
# Epoch: 500. Train Loss: 0.5132. Test Loss: 1.025. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 510. Train Loss: 0.5716. Test Loss: 1.008. Train Acc: 0.6863. Test Acc:0.5455
# Epoch: 520. Train Loss: 0.5938. Test Loss: 1.003. Train Acc: 0.7059. Test Acc:0.5758
# Epoch: 530. Train Loss: 0.5519. Test Loss: 0.98. Train Acc: 0.7059. Test Acc:0.5758
# Epoch: 540. Train Loss: 0.5517. Test Loss: 0.9644. Train Acc: 0.7843. Test Acc:0.5758
# Epoch: 550. Train Loss: 0.5669. Test Loss: 0.9696. Train Acc: 0.8039. Test Acc:0.6061
# Epoch: 560. Train Loss: 0.588. Test Loss: 0.9732. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.5366. Test Loss: 0.9545. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 580. Train Loss: 0.4733. Test Loss: 0.9107. Train Acc: 0.902. Test Acc:0.6667
# Epoch: 590. Train Loss: 0.5132. Test Loss: 0.8955. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 600. Train Loss: 0.5339. Test Loss: 0.8951. Train Acc: 0.7451. Test Acc:0.7273
# Epoch: 610. Train Loss: 0.4623. Test Loss: 0.8863. Train Acc: 0.8627. Test Acc:0.7273
# Epoch: 620. Train Loss: 0.4955. Test Loss: 0.8759. Train Acc: 0.8431. Test Acc:0.7879
# Epoch: 630. Train Loss: 0.4388. Test Loss: 0.8548. Train Acc: 0.8235. Test Acc:0.7576
# Epoch: 640. Train Loss: 0.4061. Test Loss: 0.8536. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 650. Train Loss: 0.4535. Test Loss: 0.853. Train Acc: 0.8824. Test Acc:0.8182
# Epoch: 660. Train Loss: 0.4262. Test Loss: 0.8573. Train Acc: 0.8824. Test Acc:0.7273
# Epoch: 670. Train Loss: 0.3849. Test Loss: 0.8433. Train Acc: 0.9412. Test Acc:0.8485
# Epoch: 680. Train Loss: 0.3645. Test Loss: 0.8469. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 690. Train Loss: 0.4733. Test Loss: 0.8401. Train Acc: 0.8235. Test Acc:0.8182
# Epoch: 700. Train Loss: 0.3704. Test Loss: 0.8635. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 710. Train Loss: 0.3696. Test Loss: 0.8669. Train Acc: 0.8627. Test Acc:0.7879
# Epoch: 720. Train Loss: 0.4182. Test Loss: 0.855. Train Acc: 0.8235. Test Acc:0.8182
# Epoch: 730. Train Loss: 0.3311. Test Loss: 0.8471. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 740. Train Loss: 0.3246. Test Loss: 0.8578. Train Acc: 0.8824. Test Acc:0.8182
# Epoch: 750. Train Loss: 0.3991. Test Loss: 0.8723. Train Acc: 0.8431. Test Acc:0.7879
# Epoch: 760. Train Loss: 0.3842. Test Loss: 0.8597. Train Acc: 0.8824. Test Acc:0.8182
# Epoch: 770. Train Loss: 0.3376. Test Loss: 0.8685. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 780. Train Loss: 0.2104. Test Loss: 0.8876. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 790. Train Loss: 0.3906. Test Loss: 0.89. Train Acc: 0.8824. Test Acc:0.8182
# Epoch: 800. Train Loss: 0.2526. Test Loss: 0.8879. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 810. Train Loss: 0.2706. Test Loss: 0.8895. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 820. Train Loss: 0.3385. Test Loss: 0.9437. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 830. Train Loss: 0.3359. Test Loss: 0.9361. Train Acc: 0.8627. Test Acc:0.7576
# Epoch: 840. Train Loss: 0.3676. Test Loss: 0.9404. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 850. Train Loss: 0.2631. Test Loss: 0.9576. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 860. Train Loss: 0.2728. Test Loss: 0.9491. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 870. Train Loss: 0.2117. Test Loss: 0.9564. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 880. Train Loss: 0.2722. Test Loss: 0.9631. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 890. Train Loss: 0.2621. Test Loss: 0.9869. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 900. Train Loss: 0.3236. Test Loss: 0.9921. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 910. Train Loss: 0.3512. Test Loss: 0.9977. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 920. Train Loss: 0.2353. Test Loss: 1.058. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 930. Train Loss: 0.2561. Test Loss: 1.03. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 940. Train Loss: 0.2595. Test Loss: 1.091. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 950. Train Loss: 0.2596. Test Loss: 1.111. Train Acc: 0.902. Test Acc:0.7576
# Epoch: 960. Train Loss: 0.3198. Test Loss: 1.097. Train Acc: 0.902. Test Acc:0.7576
# Epoch: 970. Train Loss: 0.1612. Test Loss: 1.112. Train Acc: 0.9804. Test Acc:0.7576
# Epoch: 980. Train Loss: 0.2867. Test Loss: 1.094. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 990. Train Loss: 0.2581. Test Loss: 1.119. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 1000. Train Loss: 0.2477. Test Loss: 1.122. Train Acc: 0.9412. Test Acc:0.7879
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#6. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.108. Test Loss: 1.106. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.131. Test Loss: 1.104. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.117. Test Loss: 1.104. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.122. Test Loss: 1.105. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.061. Test Loss: 1.108. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.099. Test Loss: 1.114. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.135. Test Loss: 1.11. Train Acc: 0.1961. Test Acc:0.3636
# Epoch: 80. Train Loss: 1.089. Test Loss: 1.108. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 90. Train Loss: 1.104. Test Loss: 1.115. Train Acc: 0.3333. Test Acc:0.2121
# Epoch: 100. Train Loss: 1.081. Test Loss: 1.115. Train Acc: 0.3922. Test Acc:0.2121
# Epoch: 110. Train Loss: 1.111. Test Loss: 1.112. Train Acc: 0.3137. Test Acc:0.2121
# Epoch: 120. Train Loss: 1.086. Test Loss: 1.111. Train Acc: 0.3333. Test Acc:0.2121
# Epoch: 130. Train Loss: 1.09. Test Loss: 1.105. Train Acc: 0.3529. Test Acc:0.2424
# Epoch: 140. Train Loss: 1.097. Test Loss: 1.103. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 150. Train Loss: 1.06. Test Loss: 1.104. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 160. Train Loss: 1.048. Test Loss: 1.095. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 170. Train Loss: 1.031. Test Loss: 1.081. Train Acc: 0.4314. Test Acc:0.3939
# Epoch: 180. Train Loss: 1.035. Test Loss: 1.098. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 190. Train Loss: 1.032. Test Loss: 1.094. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 200. Train Loss: 1.041. Test Loss: 1.075. Train Acc: 0.451. Test Acc:0.4242
# Epoch: 210. Train Loss: 1.01. Test Loss: 1.08. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 220. Train Loss: 1.016. Test Loss: 1.064. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 230. Train Loss: 0.9746. Test Loss: 1.085. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 240. Train Loss: 0.9481. Test Loss: 1.064. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 250. Train Loss: 0.9577. Test Loss: 1.064. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 260. Train Loss: 0.9609. Test Loss: 1.062. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 270. Train Loss: 0.9315. Test Loss: 1.071. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 280. Train Loss: 0.9546. Test Loss: 1.068. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 290. Train Loss: 0.9188. Test Loss: 1.073. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 300. Train Loss: 0.9213. Test Loss: 1.063. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 310. Train Loss: 0.8987. Test Loss: 1.047. Train Acc: 0.4706. Test Acc:0.4242
# Epoch: 320. Train Loss: 0.9002. Test Loss: 1.074. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 330. Train Loss: 0.8629. Test Loss: 1.049. Train Acc: 0.549. Test Acc:0.4242
# Epoch: 340. Train Loss: 0.8547. Test Loss: 1.053. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 350. Train Loss: 0.8708. Test Loss: 1.051. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 360. Train Loss: 0.8099. Test Loss: 1.035. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 370. Train Loss: 0.8492. Test Loss: 1.042. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 380. Train Loss: 0.8126. Test Loss: 1.037. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 390. Train Loss: 0.7459. Test Loss: 1.025. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 400. Train Loss: 0.8044. Test Loss: 1.012. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 410. Train Loss: 0.7145. Test Loss: 1.005. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 420. Train Loss: 0.7494. Test Loss: 1.022. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 430. Train Loss: 0.7265. Test Loss: 0.9813. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 440. Train Loss: 0.6798. Test Loss: 0.9808. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 450. Train Loss: 0.7187. Test Loss: 0.984. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 460. Train Loss: 0.6504. Test Loss: 1.002. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 470. Train Loss: 0.6993. Test Loss: 0.9772. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 480. Train Loss: 0.6762. Test Loss: 0.9625. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 490. Train Loss: 0.6501. Test Loss: 0.978. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 500. Train Loss: 0.612. Test Loss: 0.9726. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 510. Train Loss: 0.6546. Test Loss: 0.9834. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 520. Train Loss: 0.6694. Test Loss: 0.9944. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 530. Train Loss: 0.6208. Test Loss: 1.002. Train Acc: 0.6078. Test Acc:0.5152
# Epoch: 540. Train Loss: 0.6201. Test Loss: 0.9897. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 550. Train Loss: 0.65. Test Loss: 0.9961. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 560. Train Loss: 0.6574. Test Loss: 1.006. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 570. Train Loss: 0.6013. Test Loss: 1.056. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 580. Train Loss: 0.5601. Test Loss: 1.049. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 590. Train Loss: 0.611. Test Loss: 1.036. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 600. Train Loss: 0.6178. Test Loss: 1.059. Train Acc: 0.6863. Test Acc:0.5152
# Epoch: 610. Train Loss: 0.5631. Test Loss: 1.044. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 620. Train Loss: 0.5646. Test Loss: 1.045. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 630. Train Loss: 0.5507. Test Loss: 1.057. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 640. Train Loss: 0.5272. Test Loss: 1.062. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 650. Train Loss: 0.5321. Test Loss: 1.094. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 660. Train Loss: 0.4895. Test Loss: 1.088. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 670. Train Loss: 0.4821. Test Loss: 1.087. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 680. Train Loss: 0.4932. Test Loss: 1.103. Train Acc: 0.9216. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.5687. Test Loss: 1.151. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 700. Train Loss: 0.5102. Test Loss: 1.128. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 710. Train Loss: 0.4969. Test Loss: 1.132. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 720. Train Loss: 0.5159. Test Loss: 1.142. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 730. Train Loss: 0.5053. Test Loss: 1.144. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 740. Train Loss: 0.4465. Test Loss: 1.16. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 750. Train Loss: 0.4847. Test Loss: 1.18. Train Acc: 0.8039. Test Acc:0.4545
# Epoch: 760. Train Loss: 0.5597. Test Loss: 1.17. Train Acc: 0.7255. Test Acc:0.5455
# Epoch: 770. Train Loss: 0.4673. Test Loss: 1.174. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 780. Train Loss: 0.3926. Test Loss: 1.177. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 790. Train Loss: 0.4964. Test Loss: 1.186. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.4266. Test Loss: 1.19. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 810. Train Loss: 0.4431. Test Loss: 1.201. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 820. Train Loss: 0.4793. Test Loss: 1.221. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 830. Train Loss: 0.4843. Test Loss: 1.227. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 840. Train Loss: 0.4959. Test Loss: 1.25. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 850. Train Loss: 0.4119. Test Loss: 1.274. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 860. Train Loss: 0.4052. Test Loss: 1.269. Train Acc: 0.8431. Test Acc:0.4545
# Epoch: 870. Train Loss: 0.3712. Test Loss: 1.288. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 880. Train Loss: 0.4348. Test Loss: 1.311. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 890. Train Loss: 0.3985. Test Loss: 1.332. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 900. Train Loss: 0.4623. Test Loss: 1.33. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 910. Train Loss: 0.4266. Test Loss: 1.327. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 920. Train Loss: 0.3752. Test Loss: 1.338. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 930. Train Loss: 0.4316. Test Loss: 1.362. Train Acc: 0.8627. Test Acc:0.4545
# Epoch: 940. Train Loss: 0.4079. Test Loss: 1.383. Train Acc: 0.9216. Test Acc:0.4545
# Epoch: 950. Train Loss: 0.4158. Test Loss: 1.421. Train Acc: 0.8235. Test Acc:0.4545
# Epoch: 960. Train Loss: 0.4139. Test Loss: 1.417. Train Acc: 0.8431. Test Acc:0.4545
# Epoch: 970. Train Loss: 0.2691. Test Loss: 1.43. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.4202. Test Loss: 1.449. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 990. Train Loss: 0.3686. Test Loss: 1.439. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.3579. Test Loss: 1.457. Train Acc: 0.8431. Test Acc:0.5455
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#7. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.095. Test Loss: 1.113. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 20. Train Loss: 1.136. Test Loss: 1.106. Train Acc: 0.3137. Test Acc:0.3333
# Epoch: 30. Train Loss: 1.113. Test Loss: 1.101. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 40. Train Loss: 1.118. Test Loss: 1.098. Train Acc: 0.2941. Test Acc:0.3333
# Epoch: 50. Train Loss: 1.067. Test Loss: 1.098. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 60. Train Loss: 1.106. Test Loss: 1.099. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 70. Train Loss: 1.128. Test Loss: 1.091. Train Acc: 0.2157. Test Acc:0.3333
# Epoch: 80. Train Loss: 1.099. Test Loss: 1.088. Train Acc: 0.2745. Test Acc:0.3939
# Epoch: 90. Train Loss: 1.105. Test Loss: 1.092. Train Acc: 0.3137. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.082. Test Loss: 1.089. Train Acc: 0.3922. Test Acc:0.3939
# Epoch: 110. Train Loss: 1.098. Test Loss: 1.082. Train Acc: 0.3333. Test Acc:0.4242
# Epoch: 120. Train Loss: 1.107. Test Loss: 1.077. Train Acc: 0.2941. Test Acc:0.4242
# Epoch: 130. Train Loss: 1.098. Test Loss: 1.068. Train Acc: 0.2549. Test Acc:0.4848
# Epoch: 140. Train Loss: 1.092. Test Loss: 1.059. Train Acc: 0.3137. Test Acc:0.4848
# Epoch: 150. Train Loss: 1.047. Test Loss: 1.046. Train Acc: 0.451. Test Acc:0.5152
# Epoch: 160. Train Loss: 1.037. Test Loss: 1.031. Train Acc: 0.5686. Test Acc:0.4848
# Epoch: 170. Train Loss: 1.01. Test Loss: 1.008. Train Acc: 0.3922. Test Acc:0.4242
# Epoch: 180. Train Loss: 1.038. Test Loss: 1.012. Train Acc: 0.4314. Test Acc:0.5152
# Epoch: 190. Train Loss: 1.025. Test Loss: 0.9878. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 200. Train Loss: 1.03. Test Loss: 0.9689. Train Acc: 0.4118. Test Acc:0.5152
# Epoch: 210. Train Loss: 1.018. Test Loss: 0.9462. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 220. Train Loss: 1.003. Test Loss: 0.932. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 230. Train Loss: 0.9711. Test Loss: 0.9235. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 240. Train Loss: 0.9275. Test Loss: 0.9065. Train Acc: 0.549. Test Acc:0.5455
# Epoch: 250. Train Loss: 0.9153. Test Loss: 0.8907. Train Acc: 0.5686. Test Acc:0.5758
# Epoch: 260. Train Loss: 0.9139. Test Loss: 0.8695. Train Acc: 0.5294. Test Acc:0.5455
# Epoch: 270. Train Loss: 0.915. Test Loss: 0.8611. Train Acc: 0.5686. Test Acc:0.5455
# Epoch: 280. Train Loss: 0.916. Test Loss: 0.8552. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 290. Train Loss: 0.8493. Test Loss: 0.8384. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 300. Train Loss: 0.8292. Test Loss: 0.842. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 310. Train Loss: 0.8127. Test Loss: 0.8248. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 320. Train Loss: 0.8588. Test Loss: 0.8243. Train Acc: 0.5294. Test Acc:0.5758
# Epoch: 330. Train Loss: 0.7456. Test Loss: 0.7988. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 340. Train Loss: 0.7376. Test Loss: 0.7884. Train Acc: 0.5098. Test Acc:0.5455
# Epoch: 350. Train Loss: 0.7409. Test Loss: 0.784. Train Acc: 0.6471. Test Acc:0.5455
# Epoch: 360. Train Loss: 0.6798. Test Loss: 0.7943. Train Acc: 0.7059. Test Acc:0.5758
# Epoch: 370. Train Loss: 0.6907. Test Loss: 0.8261. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 380. Train Loss: 0.7416. Test Loss: 0.8172. Train Acc: 0.549. Test Acc:0.6061
# Epoch: 390. Train Loss: 0.6341. Test Loss: 0.7625. Train Acc: 0.6471. Test Acc:0.5455
# Epoch: 400. Train Loss: 0.687. Test Loss: 0.7763. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 410. Train Loss: 0.6196. Test Loss: 0.7893. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 420. Train Loss: 0.7089. Test Loss: 0.772. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 430. Train Loss: 0.6778. Test Loss: 0.7675. Train Acc: 0.549. Test Acc:0.5758
# Epoch: 440. Train Loss: 0.6614. Test Loss: 0.773. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 450. Train Loss: 0.667. Test Loss: 0.8054. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 460. Train Loss: 0.5944. Test Loss: 0.8389. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 470. Train Loss: 0.6574. Test Loss: 0.7927. Train Acc: 0.549. Test Acc:0.6061
# Epoch: 480. Train Loss: 0.6243. Test Loss: 0.7679. Train Acc: 0.6078. Test Acc:0.6061
# Epoch: 490. Train Loss: 0.6189. Test Loss: 0.77. Train Acc: 0.5882. Test Acc:0.7576
# Epoch: 500. Train Loss: 0.568. Test Loss: 0.7918. Train Acc: 0.6667. Test Acc:0.7576
# Epoch: 510. Train Loss: 0.6182. Test Loss: 0.808. Train Acc: 0.6078. Test Acc:0.7576
# Epoch: 520. Train Loss: 0.6287. Test Loss: 0.7703. Train Acc: 0.6667. Test Acc:0.7576
# Epoch: 530. Train Loss: 0.5817. Test Loss: 0.7808. Train Acc: 0.6471. Test Acc:0.8485
# Epoch: 540. Train Loss: 0.6079. Test Loss: 0.7915. Train Acc: 0.6863. Test Acc:0.8182
# Epoch: 550. Train Loss: 0.6116. Test Loss: 0.7688. Train Acc: 0.7451. Test Acc:0.8485
# Epoch: 560. Train Loss: 0.6086. Test Loss: 0.7806. Train Acc: 0.6078. Test Acc:0.8485
# Epoch: 570. Train Loss: 0.5812. Test Loss: 0.8187. Train Acc: 0.7647. Test Acc:0.8182
# Epoch: 580. Train Loss: 0.5514. Test Loss: 0.8045. Train Acc: 0.8235. Test Acc:0.8485
# Epoch: 590. Train Loss: 0.5675. Test Loss: 0.7974. Train Acc: 0.7647. Test Acc:0.8485
# Epoch: 600. Train Loss: 0.611. Test Loss: 0.8033. Train Acc: 0.6078. Test Acc:0.8485
# Epoch: 610. Train Loss: 0.6032. Test Loss: 0.7996. Train Acc: 0.6863. Test Acc:0.8182
# Epoch: 620. Train Loss: 0.6175. Test Loss: 0.8009. Train Acc: 0.6863. Test Acc:0.8485
# Epoch: 630. Train Loss: 0.5262. Test Loss: 0.7807. Train Acc: 0.8039. Test Acc:0.8485
# Epoch: 640. Train Loss: 0.5061. Test Loss: 0.7655. Train Acc: 0.7843. Test Acc:0.8788
# Epoch: 650. Train Loss: 0.5315. Test Loss: 0.7619. Train Acc: 0.7451. Test Acc:0.8788
# Epoch: 660. Train Loss: 0.4913. Test Loss: 0.7466. Train Acc: 0.7647. Test Acc:0.8182
# Epoch: 670. Train Loss: 0.5052. Test Loss: 0.7554. Train Acc: 0.8431. Test Acc:0.8788
# Epoch: 680. Train Loss: 0.4851. Test Loss: 0.7383. Train Acc: 0.8235. Test Acc:0.8788
# Epoch: 690. Train Loss: 0.5242. Test Loss: 0.7445. Train Acc: 0.7059. Test Acc:0.8788
# Epoch: 700. Train Loss: 0.4899. Test Loss: 0.7434. Train Acc: 0.8824. Test Acc:0.8788
# Epoch: 710. Train Loss: 0.5051. Test Loss: 0.7554. Train Acc: 0.8235. Test Acc:0.8788
# Epoch: 720. Train Loss: 0.474. Test Loss: 0.8043. Train Acc: 0.8431. Test Acc:0.7879
# Epoch: 730. Train Loss: 0.4607. Test Loss: 0.7831. Train Acc: 0.8039. Test Acc:0.7879
# Epoch: 740. Train Loss: 0.4104. Test Loss: 0.7812. Train Acc: 0.8431. Test Acc:0.7879
# ...
# Epoch: 320. Train Loss: 0.874. Test Loss: 0.8412. Train Acc: 0.4706. Test Acc:0.6667
# Epoch: 330. Train Loss: 0.7643. Test Loss: 0.8323. Train Acc: 0.549. Test Acc:0.6667
# Epoch: 340. Train Loss: 0.7917. Test Loss: 0.8942. Train Acc: 0.5882. Test Acc:0.6364
# Epoch: 350. Train Loss: 0.7512. Test Loss: 0.8894. Train Acc: 0.5294. Test Acc:0.6364
# Epoch: 360. Train Loss: 0.7028. Test Loss: 0.8623. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 370. Train Loss: 0.7428. Test Loss: 0.8348. Train Acc: 0.5882. Test Acc:0.6061
# Epoch: 380. Train Loss: 0.7317. Test Loss: 0.8388. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 390. Train Loss: 0.6194. Test Loss: 0.8012. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 400. Train Loss: 0.7128. Test Loss: 0.8221. Train Acc: 0.6078. Test Acc:0.6061
# Epoch: 410. Train Loss: 0.6021. Test Loss: 0.8005. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 420. Train Loss: 0.6937. Test Loss: 0.7468. Train Acc: 0.7647. Test Acc:0.6061
# Epoch: 430. Train Loss: 0.6721. Test Loss: 0.7014. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 440. Train Loss: 0.5963. Test Loss: 0.7168. Train Acc: 0.8235. Test Acc:0.6061
# Epoch: 450. Train Loss: 0.6455. Test Loss: 0.7413. Train Acc: 0.7451. Test Acc:0.6061
# Epoch: 460. Train Loss: 0.5488. Test Loss: 0.7631. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 470. Train Loss: 0.6135. Test Loss: 0.7157. Train Acc: 0.7255. Test Acc:0.6061
# Epoch: 480. Train Loss: 0.5903. Test Loss: 0.7287. Train Acc: 0.8039. Test Acc:0.6061
# Epoch: 490. Train Loss: 0.5783. Test Loss: 0.7348. Train Acc: 0.7843. Test Acc:0.6061
# Epoch: 500. Train Loss: 0.5356. Test Loss: 0.6909. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 510. Train Loss: 0.5776. Test Loss: 0.6932. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 520. Train Loss: 0.5774. Test Loss: 0.6759. Train Acc: 0.8824. Test Acc:0.6364
# Epoch: 530. Train Loss: 0.5488. Test Loss: 0.7807. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 540. Train Loss: 0.5988. Test Loss: 0.7311. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.6015. Test Loss: 0.6996. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 560. Train Loss: 0.5498. Test Loss: 0.6581. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.4803. Test Loss: 0.7198. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 580. Train Loss: 0.483. Test Loss: 0.6654. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 590. Train Loss: 0.4887. Test Loss: 0.6381. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 600. Train Loss: 0.57. Test Loss: 0.6311. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 610. Train Loss: 0.5158. Test Loss: 0.637. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 620. Train Loss: 0.5448. Test Loss: 0.5985. Train Acc: 0.7843. Test Acc:0.697
# Epoch: 630. Train Loss: 0.4458. Test Loss: 0.6312. Train Acc: 0.9216. Test Acc:0.697
# Epoch: 640. Train Loss: 0.4042. Test Loss: 0.6798. Train Acc: 0.8627. Test Acc:0.6364
# Epoch: 650. Train Loss: 0.4561. Test Loss: 0.6407. Train Acc: 0.8627. Test Acc:0.697
# Epoch: 660. Train Loss: 0.3553. Test Loss: 0.6499. Train Acc: 0.902. Test Acc:0.697
# Epoch: 670. Train Loss: 0.3708. Test Loss: 0.6675. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 680. Train Loss: 0.3936. Test Loss: 0.6537. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 690. Train Loss: 0.4181. Test Loss: 0.6413. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 700. Train Loss: 0.4272. Test Loss: 0.6123. Train Acc: 0.8431. Test Acc:0.7273
# Epoch: 710. Train Loss: 0.397. Test Loss: 0.6715. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 720. Train Loss: 0.3885. Test Loss: 0.6864. Train Acc: 0.902. Test Acc:0.6667
# Epoch: 730. Train Loss: 0.3622. Test Loss: 0.7469. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 740. Train Loss: 0.3696. Test Loss: 0.6941. Train Acc: 0.9216. Test Acc:0.6061
# Epoch: 750. Train Loss: 0.3827. Test Loss: 0.7135. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 760. Train Loss: 0.3986. Test Loss: 0.6483. Train Acc: 0.8431. Test Acc:0.697
# Epoch: 770. Train Loss: 0.3364. Test Loss: 0.6546. Train Acc: 0.902. Test Acc:0.697
# Epoch: 780. Train Loss: 0.2526. Test Loss: 0.6444. Train Acc: 0.9216. Test Acc:0.7273
# Epoch: 790. Train Loss: 0.4006. Test Loss: 0.6868. Train Acc: 0.8431. Test Acc:0.697
# Epoch: 800. Train Loss: 0.2938. Test Loss: 0.7004. Train Acc: 0.902. Test Acc:0.6667
# Epoch: 810. Train Loss: 0.2691. Test Loss: 0.7176. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 820. Train Loss: 0.304. Test Loss: 0.6475. Train Acc: 0.8824. Test Acc:0.7273
# Epoch: 830. Train Loss: 0.3331. Test Loss: 0.6127. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 840. Train Loss: 0.3302. Test Loss: 0.6267. Train Acc: 0.902. Test Acc:0.7576
# Epoch: 850. Train Loss: 0.2643. Test Loss: 0.6357. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 860. Train Loss: 0.2554. Test Loss: 0.6241. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 870. Train Loss: 0.2137. Test Loss: 0.6637. Train Acc: 1.0. Test Acc:0.7273
# Epoch: 880. Train Loss: 0.2739. Test Loss: 0.658. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 890. Train Loss: 0.2473. Test Loss: 0.6414. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 900. Train Loss: 0.3592. Test Loss: 0.7122. Train Acc: 0.902. Test Acc:0.697
# Epoch: 910. Train Loss: 0.3266. Test Loss: 0.6812. Train Acc: 0.9412. Test Acc:0.697
# Epoch: 920. Train Loss: 0.2725. Test Loss: 0.6659. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 930. Train Loss: 0.254. Test Loss: 0.6856. Train Acc: 0.9412. Test Acc:0.6667
# Epoch: 940. Train Loss: 0.2744. Test Loss: 0.619. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 950. Train Loss: 0.3761. Test Loss: 0.6378. Train Acc: 0.8235. Test Acc:0.7576
# Epoch: 960. Train Loss: 0.3065. Test Loss: 0.6447. Train Acc: 0.902. Test Acc:0.7576
# Epoch: 970. Train Loss: 0.1918. Test Loss: 0.6653. Train Acc: 0.9412. Test Acc:0.7576
# Epoch: 980. Train Loss: 0.3437. Test Loss: 0.6483. Train Acc: 0.8824. Test Acc:0.7576
# Epoch: 990. Train Loss: 0.2514. Test Loss: 0.6407. Train Acc: 0.9412. Test Acc:0.7576
# Epoch: 1000. Train Loss: 0.3422. Test Loss: 0.674. Train Acc: 0.8627. Test Acc:0.7576
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#9. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.096. Test Loss: 1.129. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 20. Train Loss: 1.119. Test Loss: 1.122. Train Acc: 0.3137. Test Acc:0.303
# Epoch: 30. Train Loss: 1.117. Test Loss: 1.118. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 40. Train Loss: 1.118. Test Loss: 1.116. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 50. Train Loss: 1.07. Test Loss: 1.116. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 60. Train Loss: 1.101. Test Loss: 1.118. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 70. Train Loss: 1.131. Test Loss: 1.111. Train Acc: 0.2157. Test Acc:0.303
# Epoch: 80. Train Loss: 1.096. Test Loss: 1.108. Train Acc: 0.2745. Test Acc:0.303
# Epoch: 90. Train Loss: 1.116. Test Loss: 1.112. Train Acc: 0.3137. Test Acc:0.303
# Epoch: 100. Train Loss: 1.081. Test Loss: 1.111. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 110. Train Loss: 1.115. Test Loss: 1.108. Train Acc: 0.2941. Test Acc:0.303
# Epoch: 120. Train Loss: 1.104. Test Loss: 1.106. Train Acc: 0.3137. Test Acc:0.2121
# Epoch: 130. Train Loss: 1.113. Test Loss: 1.101. Train Acc: 0.2549. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.113. Test Loss: 1.098. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 150. Train Loss: 1.068. Test Loss: 1.094. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 160. Train Loss: 1.05. Test Loss: 1.086. Train Acc: 0.4314. Test Acc:0.3636
# Epoch: 170. Train Loss: 1.06. Test Loss: 1.067. Train Acc: 0.4314. Test Acc:0.4242
# Epoch: 180. Train Loss: 1.062. Test Loss: 1.09. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 190. Train Loss: 1.046. Test Loss: 1.097. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 200. Train Loss: 1.067. Test Loss: 1.064. Train Acc: 0.3333. Test Acc:0.4242
# Epoch: 210. Train Loss: 1.055. Test Loss: 1.059. Train Acc: 0.2745. Test Acc:0.4242
# Epoch: 220. Train Loss: 1.046. Test Loss: 1.041. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 230. Train Loss: 1.065. Test Loss: 1.052. Train Acc: 0.3922. Test Acc:0.4242
# Epoch: 240. Train Loss: 1.052. Test Loss: 1.027. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 250. Train Loss: 0.9927. Test Loss: 1.011. Train Acc: 0.5098. Test Acc:0.4848
# Epoch: 260. Train Loss: 0.9992. Test Loss: 1.014. Train Acc: 0.4118. Test Acc:0.4242
# Epoch: 270. Train Loss: 1.013. Test Loss: 0.9998. Train Acc: 0.3922. Test Acc:0.4545
# Epoch: 280. Train Loss: 1.018. Test Loss: 1.01. Train Acc: 0.3922. Test Acc:0.4242
# Epoch: 290. Train Loss: 0.9607. Test Loss: 0.9901. Train Acc: 0.4706. Test Acc:0.4545
# Epoch: 300. Train Loss: 0.9801. Test Loss: 1.0. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 310. Train Loss: 0.9263. Test Loss: 0.9863. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 320. Train Loss: 0.9356. Test Loss: 1.011. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 330. Train Loss: 0.8689. Test Loss: 0.9898. Train Acc: 0.4902. Test Acc:0.4545
# Epoch: 340. Train Loss: 0.8733. Test Loss: 0.9905. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 350. Train Loss: 0.8457. Test Loss: 0.9961. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 360. Train Loss: 0.7882. Test Loss: 1.009. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 370. Train Loss: 0.7976. Test Loss: 1.081. Train Acc: 0.549. Test Acc:0.4242
# Epoch: 380. Train Loss: 0.7966. Test Loss: 1.082. Train Acc: 0.5686. Test Acc:0.5152
# Epoch: 390. Train Loss: 0.7043. Test Loss: 1.029. Train Acc: 0.6667. Test Acc:0.5455
# Epoch: 400. Train Loss: 0.7845. Test Loss: 1.03. Train Acc: 0.549. Test Acc:0.5455
# Epoch: 410. Train Loss: 0.7028. Test Loss: 0.9447. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 420. Train Loss: 0.8001. Test Loss: 0.9114. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 430. Train Loss: 0.7401. Test Loss: 0.8776. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 440. Train Loss: 0.6722. Test Loss: 0.9426. Train Acc: 0.6275. Test Acc:0.5152
# Epoch: 450. Train Loss: 0.7172. Test Loss: 1.015. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 460. Train Loss: 0.6345. Test Loss: 1.052. Train Acc: 0.6471. Test Acc:0.5758
# Epoch: 470. Train Loss: 0.7306. Test Loss: 0.9312. Train Acc: 0.6667. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.6949. Test Loss: 0.9035. Train Acc: 0.549. Test Acc:0.6061
# Epoch: 490. Train Loss: 0.6825. Test Loss: 0.9384. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 500. Train Loss: 0.654. Test Loss: 0.9265. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 510. Train Loss: 0.6647. Test Loss: 0.9507. Train Acc: 0.6471. Test Acc:0.5758
# Epoch: 520. Train Loss: 0.6816. Test Loss: 0.9411. Train Acc: 0.7059. Test Acc:0.5758
# Epoch: 530. Train Loss: 0.6389. Test Loss: 0.9778. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 540. Train Loss: 0.6822. Test Loss: 0.9195. Train Acc: 0.6078. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.6366. Test Loss: 0.9416. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 560. Train Loss: 0.6887. Test Loss: 0.9563. Train Acc: 0.549. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.6414. Test Loss: 1.032. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 580. Train Loss: 0.6123. Test Loss: 0.9946. Train Acc: 0.6667. Test Acc:0.6364
# Epoch: 590. Train Loss: 0.6211. Test Loss: 0.9251. Train Acc: 0.6667. Test Acc:0.6364
# Epoch: 600. Train Loss: 0.6835. Test Loss: 0.9893. Train Acc: 0.5294. Test Acc:0.6061
# Epoch: 610. Train Loss: 0.6529. Test Loss: 1.065. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 620. Train Loss: 0.6663. Test Loss: 1.054. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 630. Train Loss: 0.6204. Test Loss: 1.112. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 640. Train Loss: 0.5685. Test Loss: 1.055. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 650. Train Loss: 0.6177. Test Loss: 0.9565. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 660. Train Loss: 0.551. Test Loss: 0.9492. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 670. Train Loss: 0.5491. Test Loss: 1.053. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 680. Train Loss: 0.5884. Test Loss: 1.078. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 690. Train Loss: 0.5916. Test Loss: 1.072. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 700. Train Loss: 0.5794. Test Loss: 0.9598. Train Acc: 0.7647. Test Acc:0.6667
# Epoch: 710. Train Loss: 0.584. Test Loss: 0.9433. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 720. Train Loss: 0.5597. Test Loss: 0.9989. Train Acc: 0.8235. Test Acc:0.6667
# Epoch: 730. Train Loss: 0.5591. Test Loss: 0.9612. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 740. Train Loss: 0.5416. Test Loss: 1.03. Train Acc: 0.7843. Test Acc:0.6667
# Epoch: 750. Train Loss: 0.5544. Test Loss: 1.089. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 760. Train Loss: 0.6201. Test Loss: 0.9604. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 770. Train Loss: 0.534. Test Loss: 1.003. Train Acc: 0.7647. Test Acc:0.6667
# Epoch: 780. Train Loss: 0.4911. Test Loss: 1.027. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 790. Train Loss: 0.5636. Test Loss: 1.059. Train Acc: 0.7647. Test Acc:0.6061
# Epoch: 800. Train Loss: 0.5025. Test Loss: 1.061. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 810. Train Loss: 0.5155. Test Loss: 1.095. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 820. Train Loss: 0.5407. Test Loss: 0.9984. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 830. Train Loss: 0.5063. Test Loss: 1.005. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 840. Train Loss: 0.5313. Test Loss: 1.045. Train Acc: 0.8039. Test Acc:0.6061
# Epoch: 850. Train Loss: 0.4523. Test Loss: 1.052. Train Acc: 0.902. Test Acc:0.6061
# Epoch: 860. Train Loss: 0.4695. Test Loss: 1.052. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 870. Train Loss: 0.4079. Test Loss: 1.077. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 880. Train Loss: 0.5114. Test Loss: 1.062. Train Acc: 0.7451. Test Acc:0.6061
# Epoch: 890. Train Loss: 0.447. Test Loss: 1.062. Train Acc: 0.8627. Test Acc:0.6061
# Epoch: 900. Train Loss: 0.5606. Test Loss: 1.194. Train Acc: 0.7647. Test Acc:0.5758
# Epoch: 910. Train Loss: 0.5008. Test Loss: 1.118. Train Acc: 0.7647. Test Acc:0.5758
# Epoch: 920. Train Loss: 0.4679. Test Loss: 1.054. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 930. Train Loss: 0.4653. Test Loss: 1.124. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 940. Train Loss: 0.4703. Test Loss: 1.084. Train Acc: 0.8235. Test Acc:0.6061
# Epoch: 950. Train Loss: 0.492. Test Loss: 1.047. Train Acc: 0.8039. Test Acc:0.697
# Epoch: 960. Train Loss: 0.4792. Test Loss: 1.085. Train Acc: 0.7843. Test Acc:0.6667
# Epoch: 970. Train Loss: 0.3766. Test Loss: 1.098. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 980. Train Loss: 0.4898. Test Loss: 1.146. Train Acc: 0.8039. Test Acc:0.6061
# Epoch: 990. Train Loss: 0.4262. Test Loss: 1.092. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 1000. Train Loss: 0.433. Test Loss: 1.472. Train Acc: 0.7647. Test Acc:0.5455

# %%
# raw_features.keys()
# ['wav2vec_features-c', 'wav2vec_features-z', 'retrained-wav2vec_features-c', 'retrained-wav2vec_features-z']
