# %%
from pathlib import Path
import csv
from itertools import groupby
import h5py
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.svm import SVC
# from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import random
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# # Configuration & Utilities

# %%
random.seed(42)
COLORS = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
ANNOTATIONS_PATH = "/media/xtrem/data/experiments/nicolingua-0001-language-id/language-id-annotations/metadata.csv"
FEATURE_DIRS = [
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-z',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-z'
]


dropout_p = 0.6
fc_dropout_p = 0.6

RESULTS_DIR = f'results_008_gn_lang_classification__dropout_{dropout_p}__fc_dropout_{fc_dropout_p}'

GPU_ID = 0

# %%
annotation_specification = {
    0: {
        'id': 0,
        'label': "maninka",
        'required_tags': set(['ct-speech', 'lng-maninka']),
        'forbidden_tags':  set(['lng-susu', 'lng-pular'])
    },
    1: {
        'id': 1,
        'label': "susu",
        'required_tags': set(['ct-speech', 'lng-susu']),
        'forbidden_tags':  set(['lng-maninka', 'lng-pular'])
    },
    2: {
        'id': 2,
        'label': "pular",
        'required_tags': set(['ct-speech', 'lng-pular']),
        'forbidden_tags':  set(['lng-susu', 'lng-maninka'])
    }
}

# %%
bias_category_specification = [
    {
        "category": "utterance",
        "subcategories": [
            {
                "subcategory": "verbal_nod",
                "tags": set(["utt-verbal-nod"])
            },
            {
                "subcategory": "multilingual",
                "tags": set(["utt-multi-lingual", "utt-multi-lingual-named-endity"])
            }
        ]
    },
    {
        "category": "speaker_count",
        "subcategories": [
            {
                "subcategory": "single",
                "tags": set(["spkr-single"])
            },
            {
                "subcategory": "multiple",
                "tags": set(["spkr-mult", "spkr-multi"])
            }
        ]
    },
    {
        "category": "gender",
        "subcategories": [
            {
                "subcategory": "male",
                "tags": set(["spkr-male"])
            },
            {
                "subcategory": "female",
                "tags": set(["spkr-female"])
            },
        ]
    },
    {
        "category": "language",
        "subcategories": [
            {
                "subcategory": "susu",
                "tags": set(["lng-susu"])
            },
            {
                "subcategory": "maninka",
                "tags": set(["lng-maninka"])
            },
            {
                "subcategory": "pular",
                "tags": set(["lng-pular"])
            }
        ]
    },
    {
        "category": "channel",
        "subcategories": [
            {
                "subcategory": "telephone",
                "tags": set(["ct-telephone"])
            },
            {
                "subcategory": "noise",
                "tags": set(["ct-noise"])
            },
            {
                "subcategory": "music",
                "tags": set(["ct-fg-music", "ct-tr-music", "ct-bg-music"])
            }
        ]
    }
]

flat_bias_category_specification = {}

for c in bias_category_specification:
    for sc in c['subcategories']:
        k = f"{c['category']}_{sc['subcategory']}"
        flat_bias_category_specification[k] = sc['tags']

_ = [print(f"{k}: {v}") for k,v in flat_bias_category_specification.items()]
# Out:
# utterance_verbal_nod: {'utt-verbal-nod'}
# utterance_multilingual: {'utt-multi-lingual', 'utt-multi-lingual-named-endity'}
# speaker_count_single: {'spkr-single'}
# speaker_count_multiple: {'spkr-mult', 'spkr-multi'}
# gender_male: {'spkr-male'}
# gender_female: {'spkr-female'}
# language_susu: {'lng-susu'}
# language_maninka: {'lng-maninka'}
# language_pular: {'lng-pular'}
# channel_telephone: {'ct-telephone'}
# channel_noise: {'ct-noise'}
# channel_music: {'ct-tr-music', 'ct-fg-music', 'ct-bg-music'}

# %%
def to_user_friendly_feature_name(fv_name):
    name = fv_name \
        .replace("features-", "") \
        .replace("wav2vec_", "") \
        .replace("average", "avg") \
        .replace("timestep", "T") \
        .replace("c.", "Context") \
        .replace("z.", "Latent")
    return name

# %% [markdown]
# # Load annotations

# %%
def load_annotations(a_file_path, a_specification):
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for row in reader:
            tag_set = set([t.strip() for t in row['tags'].split(";")])
            for label in annotation_specification.keys():
                spec = annotation_specification[label]
                if spec['required_tags'].issubset(tag_set):
                    if spec['forbidden_tags'].isdisjoint(tag_set):
                        yield row['file'], label, tag_set
                        break

data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
audio_files, audio_labels, audio_tags = zip(*data)

# %% [markdown]
# ## Inspect label counts

# %%
def inspect_label_counts():
    for label in annotation_specification:
        count = len([l for l in audio_labels if l == label])
        print("{:10} ({}): {}".format(
            annotation_specification[label]['label'],
            label, 
            count
        ))
inspect_label_counts()
# Out:
# maninka    (0): 114
# susu       (1): 32
# pular      (2): 28

# %% [markdown]
# ## Balance data

# %%
count_per_class = 28
data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
balanced_data = []
for label in annotation_specification:
    balanced_data.extend([d for d in data if d[1] == label][:count_per_class])
audio_files, audio_labels, audio_tags = zip(*balanced_data)

# %%
inspect_label_counts()
# Out:
# maninka    (0): 28
# susu       (1): 28
# pular      (2): 28

# %% [markdown]
# ## Inspect bias category counts in balanded data

# %%
def inspect_bias_category_counts():
    for name, tags in flat_bias_category_specification.items():
        count = len([ts for ts in audio_tags if len(tags.intersection(ts))>0])
        print(name, count, "/", len(audio_tags))
            
inspect_bias_category_counts()
# Out:
# utterance_verbal_nod 48 / 84
# utterance_multilingual 21 / 84
# speaker_count_single 25 / 84
# speaker_count_multiple 58 / 84
# gender_male 81 / 84
# gender_female 15 / 84
# language_susu 28 / 84
# language_maninka 28 / 84
# language_pular 28 / 84
# channel_telephone 27 / 84
# channel_noise 21 / 84
# channel_music 24 / 84

# %% [markdown]
# # Prepare 10 cross validation folds

# %%
TRAIN_PERCENT = .6
FOLD_COUNT = 10

n = len(audio_files)
n_train = int(np.ceil(n * .6))
n_test = n - n_train
all_indices = range(n)

cv_folds = {}
train_count_by_index = {i:0 for i in all_indices}
test_count_by_index = {i:0 for i in all_indices}

for fold_index in range(FOLD_COUNT):
    fold_rsampler = np.random.RandomState(seed=fold_index)
    train_index_set = set(fold_rsampler.choice(all_indices, n_train, replace=False))
    test_index_set = set(all_indices).difference(train_index_set)
        
    cv_folds[fold_index] = {
        'train_indices': sorted(list(train_index_set)),
        'test_indices': sorted(list(test_index_set)),
    }

# %% [markdown]
# # Load features

# %%
def load_features(audio_files, features_input_dir):
    id_list = []
    features_list = []

    for audio_file_name in audio_files:
        feature_file_name = audio_file_name.replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            # features = pool_feature_last_seq(features)
            features_list.append(features)
    return features_list

# %%
raw_features = {}
for feature_dir in FEATURE_DIRS:
    feature_name = Path(feature_dir).stem
    raw_features[feature_name] = load_features(audio_files, feature_dir)

# %% [markdown]
# ## Inspect feature shapes

# %%
for feature_name in raw_features.keys():
    print("feature_name: {}. feature shape: {}".format(
        to_user_friendly_feature_name(feature_name),
        raw_features[feature_name][0].shape
    ))
# Out:
# feature_name: c. feature shape: (2998, 512)
# feature_name: z. feature shape: (2998, 512)
# feature_name: retrained-c. feature shape: (2998, 512)
# feature_name: retrained-z. feature shape: (2998, 512)

# %% [markdown]
# ## Extract feature vectors

# %%
def extract_last_timestep_features(raw_features):
    return raw_features[-1, :]

def extract_neuron_average_features(raw_features):
    return np.mean(raw_features, axis=0)

def identity(x):
    return x

feature_extractors = {
    'last_timestep': extract_last_timestep_features,
    'neuron_average': extract_neuron_average_features,
    'raw_features': identity
}

# %%
feature_vectors = {}
for feature_name in raw_features.keys():
    for feature_extractor_name in feature_extractors.keys():
        fv_name = f"{feature_name}__{feature_extractor_name}"
        feature_vectors[fv_name] = []
        for f in raw_features[feature_name]:
            feature_vectors[fv_name].append(
                feature_extractors[feature_extractor_name](f)
            )
            
        feature_vectors[fv_name] = np.array(feature_vectors[fv_name])

# %% [markdown]
# ## Inspect feature vectors

# %%
for fvname in feature_vectors.keys():
    print(fvname, feature_vectors[fvname][0].shape)
# Out:
# wav2vec_features-c__last_timestep (512,)
# wav2vec_features-c__neuron_average (512,)
# wav2vec_features-c__raw_features (2998, 512)
# wav2vec_features-z__last_timestep (512,)
# wav2vec_features-z__neuron_average (512,)
# wav2vec_features-z__raw_features (2998, 512)
# retrained-wav2vec_features-c__last_timestep (512,)
# retrained-wav2vec_features-c__neuron_average (512,)
# retrained-wav2vec_features-c__raw_features (2998, 512)
# retrained-wav2vec_features-z__last_timestep (512,)
# retrained-wav2vec_features-z__neuron_average (512,)
# retrained-wav2vec_features-z__raw_features (2998, 512)

# %% [markdown]
# # Classification Models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
class LangIdCNN_Mean2_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_Mean2_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=9, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x
    

class LangIdCNN_MeanStd_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_MeanStd_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=18, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1_mean = torch.mean(x, dim=2)
        v1_std = torch.std(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2_mean = torch.mean(x, dim=2)
        v2_std = torch.std(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3_mean = torch.mean(x, dim=2)
        v3_std = torch.std(x, dim=2)
        
        v = torch.cat((v1_mean, v1_std, v2_mean, v2_std, v3_mean, v3_std), axis=1)
        
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x

# %% [markdown]
# # Train Classification Models

# %%
def get_data_for_fold(fold_id, feature_name, batch_size):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']    

    train_x = np.take(raw_features[feature_name], train_indices, axis=0)
    train_y = np.take(audio_labels, train_indices, axis=0)
    train_tags = np.take(audio_tags, train_indices, axis=0)
    train_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        train_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in train_tags]

    test_x = np.take(raw_features[feature_name], test_indices, axis=0)
    test_y = np.take(audio_labels, test_indices, axis=0)
    test_tags = np.take(audio_tags, test_indices, axis=0)
    test_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        test_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in test_tags]
        
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

def get_audio_files_for_fold(fold_id):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']
    
    train_files = np.take(audio_files, train_indices, axis=0)
    test_files = np.take(audio_files, test_indices, axis=0)
    
    return train_files, test_files
    

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name, batch_size)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y)
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y)
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
l2 = nn.PairwiseDistance(p=2)
margin = 1

# See:
# http://caffe.berkeleyvision.org/doxygen/classcaffe_1_1ContrastiveLossLayer.html#details
# http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf

def contrastive_loss(representations, labels):
    normalized_reps = F.normalize(representations, dim=1)
    
    loss = 0
    n = 0
    for i in range(normalized_reps.shape[0]):
        for j in range(normalized_reps.shape[0]):
            d = l2(
                normalized_reps[i].view(1, -1), 
                normalized_reps[j].view(1, -1)
            )
            if labels[i] == labels[j]:
                loss += torch.square(d)
            else:
                loss += torch.square(torch.max(
                    torch.tensor([margin-d, 0]).to(representations.device)
                ))
            
            n+=1
            
    loss = loss / (2*n)
    
    return loss[0]

# %%
def train_on_fold(model_class, fold_id, feature_name, batch_size, epochs, use_contrastive_term):
    device = torch.device(f"cuda:{GPU_ID}")
    torch.manual_seed(0)
    results = {}
    
    model = model_class().to(device)

    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model_class(), torch.zeros((10, 2998, 512)), show_input=False))

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0
        pred_train_classes = []
        true_train_classes = []

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
            
            optimizer.zero_grad()
            representations, outputs = model(x)
            pred_train_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )
            true_train_classes.extend(y.cpu().numpy())
            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += 0.1 * contrastive_loss(representations, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_n = len(true_train_classes)
        
        train_loss = train_loss/len(train_loader)
        train_acc = sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes)
        train_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes, sample_weight=sw)
            for category, sw in train_bias_category_labels.items()
        }
        

        pred_test_logits = []
        
        pred_test_classes = []
        true_test_classes = []
        
        model.eval()
        test_loss = 0
        for batch_idx, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            
            representations, outputs = model(x)
            
            pred_test_logits.extend(outputs.detach().cpu().numpy())

            pred_test_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )

            true_test_classes.extend(y.cpu().numpy())

            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += contrastive_loss(representations, y)
                
            test_loss += loss.item()


        test_n = len(true_test_classes)
        
        test_loss = test_loss / len(test_loader)
        test_acc = sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes)
        test_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes, sample_weight=sw)
            for category, sw in test_bias_category_labels.items()
        }

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_loss:0.4}. Test Loss: {test_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
        results[epoch] = {
            'epoch': epoch,
            'train_loss': train_loss,
            'test_loss': test_loss,
            'train_acc': train_acc,
            'test_acc': test_acc,
            'train_n': train_n,
            'test_n': test_n,
            'test_logits': pred_test_logits,
            'test_true_classes': true_test_classes
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))
        
    del model
    return results

# %%
import csv
from pathlib import Path

def write_epoch_test_logits(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        train_audio_files, test_audio_files = get_audio_files_for_fold(fold_index)
        
        for epoch in sorted(result_entry['epochs'].keys()):
            
            parent_dir = Path(f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}_data")
            parent_dir.mkdir(parents=True, exist_ok=True)

            file_name = parent_dir / f"epoch_{epoch:04}.csv"
            with open(file_name, "w") as f:
                writer = csv.DictWriter(f, fieldnames=["fold_id", "datum_index", "datum_name", "true_class_id", "logits"])
                writer.writeheader()
                
                test_logits = result_entry['epochs'][epoch]["test_logits"]
                test_true_classes = result_entry['epochs'][epoch]["test_true_classes"]
                
                for datum_index in range(len(test_logits)):
                    writer.writerow({
                        "fold_id": fold_index,
                        "datum_index": datum_index,
                        "datum_name": test_audio_files[datum_index],
                        "true_class_id": test_true_classes[datum_index],
                        "logits": test_logits[datum_index]
                    })
                

            annotation_specification.keys()

            field_names = ["index", "fname", "logits"]

            fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            fieldnames.remove("test_logits") # logged separately, differently
            fieldnames.remove("test_true_classes") # logged separately, differently
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='ignore')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
model_classes = [
    #LangIdCNN_MeanStd_FCD,
    LangIdCNN_Mean2_FCD,
]

for model_class in model_classes:
    all_folds_results = []
    for fold_index in [5, 6, 7, 8, 9]: #cv_folds:
        for feature_name in ['retrained-wav2vec_features-z', 'wav2vec_features-z']: #raw_features:
            use_contrastive_term = "Contrastive" in model_class.__name__
            
            print(f"{model_class.__name__} using {feature_name} on fold#{fold_index}. Contrastive: {use_contrastive_term}")
            resutls = train_on_fold(model_class, fold_index, feature_name, batch_size=100, epochs=1000, use_contrastive_term=use_contrastive_term)
            all_folds_results.append({
                'fold_index': fold_index,
                'feature_name': feature_name,
                'epochs': resutls
            })
            save_results(model_class.__name__, all_folds_results)
            write_epoch_test_logits(model_class.__name__, all_folds_results)
# Out:
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.125. Test Loss: 1.101. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.127. Test Loss: 1.096. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.109. Test Loss: 1.093. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.129. Test Loss: 1.091. Train Acc: 0.1765. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.085. Test Loss: 1.091. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.08. Test Loss: 1.091. Train Acc: 0.3922. Test Acc:0.3939
# Epoch: 70. Train Loss: 1.091. Test Loss: 1.087. Train Acc: 0.3529. Test Acc:0.4242
# Epoch: 80. Train Loss: 1.08. Test Loss: 1.086. Train Acc: 0.4118. Test Acc:0.4848
# Epoch: 90. Train Loss: 1.065. Test Loss: 1.085. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.043. Test Loss: 1.08. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 110. Train Loss: 1.015. Test Loss: 1.078. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.003. Test Loss: 1.079. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 130. Train Loss: 0.9765. Test Loss: 1.077. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 140. Train Loss: 0.9351. Test Loss: 1.077. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 150. Train Loss: 0.9192. Test Loss: 1.082. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 160. Train Loss: 0.8781. Test Loss: 1.08. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 170. Train Loss: 0.8533. Test Loss: 1.085. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 180. Train Loss: 0.8184. Test Loss: 1.088. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 190. Train Loss: 0.8102. Test Loss: 1.103. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 200. Train Loss: 0.8059. Test Loss: 1.097. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 210. Train Loss: 0.7568. Test Loss: 1.1. Train Acc: 0.6863. Test Acc:0.3939
# Epoch: 220. Train Loss: 0.8142. Test Loss: 1.109. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 230. Train Loss: 0.7568. Test Loss: 1.118. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 240. Train Loss: 0.6762. Test Loss: 1.127. Train Acc: 0.7059. Test Acc:0.3939
# Epoch: 250. Train Loss: 0.7208. Test Loss: 1.151. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 260. Train Loss: 0.6539. Test Loss: 1.142. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 270. Train Loss: 0.6591. Test Loss: 1.179. Train Acc: 0.7451. Test Acc:0.3333
# Epoch: 280. Train Loss: 0.6714. Test Loss: 1.195. Train Acc: 0.7059. Test Acc:0.3333
# Epoch: 290. Train Loss: 0.686. Test Loss: 1.222. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 300. Train Loss: 0.6286. Test Loss: 1.218. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 310. Train Loss: 0.6163. Test Loss: 1.231. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 320. Train Loss: 0.6233. Test Loss: 1.278. Train Acc: 0.6667. Test Acc:0.3333
# Epoch: 330. Train Loss: 0.6188. Test Loss: 1.277. Train Acc: 0.6471. Test Acc:0.3333
# Epoch: 340. Train Loss: 0.5597. Test Loss: 1.261. Train Acc: 0.7255. Test Acc:0.3636
# Epoch: 350. Train Loss: 0.5772. Test Loss: 1.302. Train Acc: 0.7255. Test Acc:0.3333
# Epoch: 360. Train Loss: 0.6081. Test Loss: 1.365. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 370. Train Loss: 0.5769. Test Loss: 1.351. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 380. Train Loss: 0.5868. Test Loss: 1.353. Train Acc: 0.6471. Test Acc:0.2727
# Epoch: 390. Train Loss: 0.5204. Test Loss: 1.315. Train Acc: 0.7647. Test Acc:0.2727
# Epoch: 400. Train Loss: 0.5878. Test Loss: 1.386. Train Acc: 0.5686. Test Acc:0.3333
# Epoch: 410. Train Loss: 0.5665. Test Loss: 1.403. Train Acc: 0.7059. Test Acc:0.3333
# Epoch: 420. Train Loss: 0.5757. Test Loss: 1.359. Train Acc: 0.6863. Test Acc:0.303
# Epoch: 430. Train Loss: 0.5742. Test Loss: 1.371. Train Acc: 0.6078. Test Acc:0.303
# Epoch: 440. Train Loss: 0.57. Test Loss: 1.439. Train Acc: 0.6667. Test Acc:0.303
# Epoch: 450. Train Loss: 0.5446. Test Loss: 1.414. Train Acc: 0.6863. Test Acc:0.3333
# Epoch: 460. Train Loss: 0.5299. Test Loss: 1.47. Train Acc: 0.7059. Test Acc:0.303
# Epoch: 470. Train Loss: 0.5839. Test Loss: 1.394. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 480. Train Loss: 0.511. Test Loss: 1.431. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 490. Train Loss: 0.5031. Test Loss: 1.514. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 500. Train Loss: 0.5125. Test Loss: 1.444. Train Acc: 0.7647. Test Acc:0.3939
# Epoch: 510. Train Loss: 0.5416. Test Loss: 1.506. Train Acc: 0.6667. Test Acc:0.4242
# Epoch: 520. Train Loss: 0.5428. Test Loss: 1.466. Train Acc: 0.7255. Test Acc:0.3636
# Epoch: 530. Train Loss: 0.5029. Test Loss: 1.44. Train Acc: 0.7451. Test Acc:0.3939
# Epoch: 540. Train Loss: 0.5119. Test Loss: 1.448. Train Acc: 0.7647. Test Acc:0.3939
# Epoch: 550. Train Loss: 0.5072. Test Loss: 1.485. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 560. Train Loss: 0.4933. Test Loss: 1.485. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 570. Train Loss: 0.4536. Test Loss: 1.413. Train Acc: 0.8627. Test Acc:0.4545
# Epoch: 580. Train Loss: 0.4374. Test Loss: 1.432. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 590. Train Loss: 0.4473. Test Loss: 1.476. Train Acc: 0.8235. Test Acc:0.4545
# Epoch: 600. Train Loss: 0.4555. Test Loss: 1.442. Train Acc: 0.8627. Test Acc:0.4545
# Epoch: 610. Train Loss: 0.4249. Test Loss: 1.506. Train Acc: 0.8431. Test Acc:0.4545
# Epoch: 620. Train Loss: 0.4449. Test Loss: 1.528. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 630. Train Loss: 0.3751. Test Loss: 1.458. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 640. Train Loss: 0.3382. Test Loss: 1.484. Train Acc: 0.9216. Test Acc:0.4848
# Epoch: 650. Train Loss: 0.343. Test Loss: 1.424. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 660. Train Loss: 0.2988. Test Loss: 1.467. Train Acc: 0.9412. Test Acc:0.4848
# Epoch: 670. Train Loss: 0.3365. Test Loss: 1.567. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 680. Train Loss: 0.319. Test Loss: 1.646. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 690. Train Loss: 0.3018. Test Loss: 1.588. Train Acc: 0.9216. Test Acc:0.5152
# Epoch: 700. Train Loss: 0.272. Test Loss: 1.499. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 710. Train Loss: 0.279. Test Loss: 1.504. Train Acc: 0.9216. Test Acc:0.5152
# Epoch: 720. Train Loss: 0.2603. Test Loss: 1.503. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 730. Train Loss: 0.2577. Test Loss: 1.553. Train Acc: 0.9804. Test Acc:0.5758
# Epoch: 740. Train Loss: 0.2212. Test Loss: 1.598. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 750. Train Loss: 0.3346. Test Loss: 1.624. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 760. Train Loss: 0.2511. Test Loss: 1.559. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 770. Train Loss: 0.1945. Test Loss: 1.637. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 780. Train Loss: 0.1825. Test Loss: 1.607. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 790. Train Loss: 0.2418. Test Loss: 1.65. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 800. Train Loss: 0.1917. Test Loss: 1.652. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 810. Train Loss: 0.185. Test Loss: 1.667. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 820. Train Loss: 0.2575. Test Loss: 1.608. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 830. Train Loss: 0.2048. Test Loss: 1.636. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 840. Train Loss: 0.1908. Test Loss: 1.674. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 850. Train Loss: 0.1907. Test Loss: 1.675. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 860. Train Loss: 0.2372. Test Loss: 1.71. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 870. Train Loss: 0.1997. Test Loss: 1.844. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 880. Train Loss: 0.1848. Test Loss: 1.785. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 890. Train Loss: 0.1547. Test Loss: 1.705. Train Acc: 0.9804. Test Acc:0.5758
# Epoch: 900. Train Loss: 0.203. Test Loss: 1.738. Train Acc: 0.9804. Test Acc:0.5455
# Epoch: 910. Train Loss: 0.2269. Test Loss: 1.755. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 920. Train Loss: 0.155. Test Loss: 1.797. Train Acc: 0.9804. Test Acc:0.5455
# Epoch: 930. Train Loss: 0.1701. Test Loss: 1.845. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 940. Train Loss: 0.1928. Test Loss: 1.796. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 950. Train Loss: 0.1988. Test Loss: 1.746. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 960. Train Loss: 0.1738. Test Loss: 1.758. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 970. Train Loss: 0.09254. Test Loss: 1.843. Train Acc: 1.0. Test Acc:0.5455
# Epoch: 980. Train Loss: 0.1839. Test Loss: 1.788. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 990. Train Loss: 0.1256. Test Loss: 1.817. Train Acc: 1.0. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.2342. Test Loss: 1.835. Train Acc: 0.9216. Test Acc:0.5455
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.127. Test Loss: 1.101. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.128. Test Loss: 1.096. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.113. Test Loss: 1.093. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.131. Test Loss: 1.092. Train Acc: 0.2157. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.092. Test Loss: 1.092. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.091. Test Loss: 1.093. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.105. Test Loss: 1.091. Train Acc: 0.3529. Test Acc:0.4848
# Epoch: 80. Train Loss: 1.1. Test Loss: 1.091. Train Acc: 0.3725. Test Acc:0.4848
# Epoch: 90. Train Loss: 1.099. Test Loss: 1.091. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.069. Test Loss: 1.089. Train Acc: 0.4902. Test Acc:0.3636
# Epoch: 110. Train Loss: 1.07. Test Loss: 1.087. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.057. Test Loss: 1.089. Train Acc: 0.5294. Test Acc:0.2727
# Epoch: 130. Train Loss: 1.059. Test Loss: 1.091. Train Acc: 0.3529. Test Acc:0.2424
# Epoch: 140. Train Loss: 1.029. Test Loss: 1.087. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 150. Train Loss: 1.006. Test Loss: 1.091. Train Acc: 0.5098. Test Acc:0.2727
# Epoch: 160. Train Loss: 0.9812. Test Loss: 1.087. Train Acc: 0.4706. Test Acc:0.3333
# Epoch: 170. Train Loss: 0.9397. Test Loss: 1.099. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 180. Train Loss: 0.9395. Test Loss: 1.108. Train Acc: 0.5294. Test Acc:0.2727
# Epoch: 190. Train Loss: 0.9088. Test Loss: 1.13. Train Acc: 0.549. Test Acc:0.2424
# Epoch: 200. Train Loss: 0.9208. Test Loss: 1.131. Train Acc: 0.5686. Test Acc:0.2727
# Epoch: 210. Train Loss: 0.8797. Test Loss: 1.131. Train Acc: 0.5882. Test Acc:0.3333
# Epoch: 220. Train Loss: 0.9969. Test Loss: 1.16. Train Acc: 0.4902. Test Acc:0.2727
# Epoch: 230. Train Loss: 0.9433. Test Loss: 1.153. Train Acc: 0.549. Test Acc:0.303
# Epoch: 240. Train Loss: 0.8669. Test Loss: 1.159. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 250. Train Loss: 0.836. Test Loss: 1.161. Train Acc: 0.5882. Test Acc:0.303
# Epoch: 260. Train Loss: 0.8624. Test Loss: 1.158. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 270. Train Loss: 0.8225. Test Loss: 1.203. Train Acc: 0.6275. Test Acc:0.303
# Epoch: 280. Train Loss: 0.8481. Test Loss: 1.177. Train Acc: 0.5686. Test Acc:0.303
# Epoch: 290. Train Loss: 0.8162. Test Loss: 1.206. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 300. Train Loss: 0.8338. Test Loss: 1.183. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 310. Train Loss: 0.7721. Test Loss: 1.19. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 320. Train Loss: 0.7649. Test Loss: 1.245. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 330. Train Loss: 0.7797. Test Loss: 1.185. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 340. Train Loss: 0.6766. Test Loss: 1.18. Train Acc: 0.7059. Test Acc:0.303
# Epoch: 350. Train Loss: 0.7141. Test Loss: 1.196. Train Acc: 0.6863. Test Acc:0.3333
# Epoch: 360. Train Loss: 0.7218. Test Loss: 1.249. Train Acc: 0.6471. Test Acc:0.3636
# Epoch: 370. Train Loss: 0.6955. Test Loss: 1.248. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 380. Train Loss: 0.6905. Test Loss: 1.252. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 390. Train Loss: 0.6152. Test Loss: 1.222. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 400. Train Loss: 0.6682. Test Loss: 1.229. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 410. Train Loss: 0.6457. Test Loss: 1.268. Train Acc: 0.7059. Test Acc:0.3939
# Epoch: 420. Train Loss: 0.6676. Test Loss: 1.278. Train Acc: 0.6471. Test Acc:0.3939
# Epoch: 430. Train Loss: 0.645. Test Loss: 1.267. Train Acc: 0.6275. Test Acc:0.3939
# Epoch: 440. Train Loss: 0.6132. Test Loss: 1.286. Train Acc: 0.6863. Test Acc:0.4242
# Epoch: 450. Train Loss: 0.6166. Test Loss: 1.286. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 460. Train Loss: 0.5847. Test Loss: 1.313. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 470. Train Loss: 0.6276. Test Loss: 1.336. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 480. Train Loss: 0.5745. Test Loss: 1.317. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 490. Train Loss: 0.5667. Test Loss: 1.333. Train Acc: 0.7059. Test Acc:0.4242
# Epoch: 500. Train Loss: 0.5807. Test Loss: 1.282. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 510. Train Loss: 0.5993. Test Loss: 1.329. Train Acc: 0.6667. Test Acc:0.4242
# Epoch: 520. Train Loss: 0.625. Test Loss: 1.366. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 530. Train Loss: 0.5776. Test Loss: 1.378. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 540. Train Loss: 0.5744. Test Loss: 1.397. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 550. Train Loss: 0.575. Test Loss: 1.387. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 560. Train Loss: 0.5722. Test Loss: 1.423. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 570. Train Loss: 0.5383. Test Loss: 1.394. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 580. Train Loss: 0.5284. Test Loss: 1.385. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 590. Train Loss: 0.541. Test Loss: 1.427. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 600. Train Loss: 0.5942. Test Loss: 1.44. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 610. Train Loss: 0.5349. Test Loss: 1.519. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 620. Train Loss: 0.5789. Test Loss: 1.482. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 630. Train Loss: 0.4937. Test Loss: 1.463. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 640. Train Loss: 0.4885. Test Loss: 1.401. Train Acc: 0.8039. Test Acc:0.4545
# Epoch: 650. Train Loss: 0.4902. Test Loss: 1.406. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 660. Train Loss: 0.4542. Test Loss: 1.448. Train Acc: 0.8039. Test Acc:0.4242
# Epoch: 670. Train Loss: 0.4935. Test Loss: 1.491. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 680. Train Loss: 0.486. Test Loss: 1.503. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.4889. Test Loss: 1.459. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 700. Train Loss: 0.459. Test Loss: 1.418. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 710. Train Loss: 0.5. Test Loss: 1.434. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 720. Train Loss: 0.4318. Test Loss: 1.433. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 730. Train Loss: 0.5195. Test Loss: 1.497. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 740. Train Loss: 0.424. Test Loss: 1.495. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 750. Train Loss: 0.4709. Test Loss: 1.497. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 760. Train Loss: 0.4782. Test Loss: 1.439. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 770. Train Loss: 0.427. Test Loss: 1.529. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 780. Train Loss: 0.38. Test Loss: 1.524. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 790. Train Loss: 0.4385. Test Loss: 1.519. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.4108. Test Loss: 1.549. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 810. Train Loss: 0.3862. Test Loss: 1.581. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 820. Train Loss: 0.4767. Test Loss: 1.53. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 830. Train Loss: 0.4316. Test Loss: 1.534. Train Acc: 0.8235. Test Acc:0.5455
# Epoch: 840. Train Loss: 0.3972. Test Loss: 1.62. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 850. Train Loss: 0.3804. Test Loss: 1.644. Train Acc: 0.902. Test Acc:0.4848
# Epoch: 860. Train Loss: 0.3742. Test Loss: 1.585. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 870. Train Loss: 0.4232. Test Loss: 1.604. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 880. Train Loss: 0.395. Test Loss: 1.656. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 890. Train Loss: 0.3461. Test Loss: 1.702. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 900. Train Loss: 0.396. Test Loss: 1.708. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 910. Train Loss: 0.4118. Test Loss: 1.639. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.3112. Test Loss: 1.651. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 930. Train Loss: 0.3755. Test Loss: 1.676. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 940. Train Loss: 0.3767. Test Loss: 1.688. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 950. Train Loss: 0.3729. Test Loss: 1.61. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 960. Train Loss: 0.3247. Test Loss: 1.609. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 970. Train Loss: 0.2491. Test Loss: 1.673. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 980. Train Loss: 0.3566. Test Loss: 1.69. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 990. Train Loss: 0.3195. Test Loss: 1.701. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.3479. Test Loss: 1.723. Train Acc: 0.7843. Test Acc:0.5455
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#6. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.116. Test Loss: 1.105. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.124. Test Loss: 1.103. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.111. Test Loss: 1.103. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.125. Test Loss: 1.105. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.074. Test Loss: 1.107. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.079. Test Loss: 1.109. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.095. Test Loss: 1.098. Train Acc: 0.3725. Test Acc:0.4848
# Epoch: 80. Train Loss: 1.071. Test Loss: 1.094. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 90. Train Loss: 1.063. Test Loss: 1.097. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.036. Test Loss: 1.086. Train Acc: 0.4314. Test Acc:0.303
# Epoch: 110. Train Loss: 1.026. Test Loss: 1.08. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.007. Test Loss: 1.075. Train Acc: 0.5294. Test Acc:0.3333
# Epoch: 130. Train Loss: 0.9741. Test Loss: 1.075. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 140. Train Loss: 0.994. Test Loss: 1.056. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 150. Train Loss: 0.9524. Test Loss: 1.061. Train Acc: 0.4706. Test Acc:0.3636
# Epoch: 160. Train Loss: 0.9064. Test Loss: 1.044. Train Acc: 0.5686. Test Acc:0.4545
# Epoch: 170. Train Loss: 0.8939. Test Loss: 1.059. Train Acc: 0.6078. Test Acc:0.3636
# Epoch: 180. Train Loss: 0.8382. Test Loss: 1.05. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 190. Train Loss: 0.8359. Test Loss: 1.07. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 200. Train Loss: 0.8561. Test Loss: 1.063. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 210. Train Loss: 0.7606. Test Loss: 1.04. Train Acc: 0.6863. Test Acc:0.4242
# Epoch: 220. Train Loss: 0.8409. Test Loss: 1.07. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 230. Train Loss: 0.7938. Test Loss: 1.067. Train Acc: 0.5686. Test Acc:0.3939
# Epoch: 240. Train Loss: 0.7066. Test Loss: 1.029. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 250. Train Loss: 0.7398. Test Loss: 1.048. Train Acc: 0.6667. Test Acc:0.3939
# Epoch: 260. Train Loss: 0.7151. Test Loss: 1.033. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 270. Train Loss: 0.7086. Test Loss: 1.065. Train Acc: 0.6667. Test Acc:0.3939
# Epoch: 280. Train Loss: 0.7401. Test Loss: 1.061. Train Acc: 0.549. Test Acc:0.4242
# Epoch: 290. Train Loss: 0.7162. Test Loss: 1.046. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 300. Train Loss: 0.6928. Test Loss: 1.036. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 310. Train Loss: 0.6552. Test Loss: 1.029. Train Acc: 0.6471. Test Acc:0.5152
# Epoch: 320. Train Loss: 0.6274. Test Loss: 1.042. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 330. Train Loss: 0.6394. Test Loss: 1.078. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 340. Train Loss: 0.6141. Test Loss: 1.046. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 350. Train Loss: 0.6182. Test Loss: 1.057. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 360. Train Loss: 0.62. Test Loss: 1.086. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 370. Train Loss: 0.6044. Test Loss: 1.078. Train Acc: 0.6078. Test Acc:0.4242
# Epoch: 380. Train Loss: 0.6062. Test Loss: 1.082. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 390. Train Loss: 0.5361. Test Loss: 1.038. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 400. Train Loss: 0.5928. Test Loss: 1.028. Train Acc: 0.7059. Test Acc:0.5455
# Epoch: 410. Train Loss: 0.5569. Test Loss: 1.068. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 420. Train Loss: 0.5688. Test Loss: 1.055. Train Acc: 0.7255. Test Acc:0.5152
# Epoch: 430. Train Loss: 0.5923. Test Loss: 1.081. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 440. Train Loss: 0.5521. Test Loss: 1.096. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 450. Train Loss: 0.5494. Test Loss: 1.065. Train Acc: 0.7843. Test Acc:0.5152
# Epoch: 460. Train Loss: 0.5508. Test Loss: 1.063. Train Acc: 0.6275. Test Acc:0.5152
# Epoch: 470. Train Loss: 0.5626. Test Loss: 1.004. Train Acc: 0.7255. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.5084. Test Loss: 1.012. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.5146. Test Loss: 1.033. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 500. Train Loss: 0.4975. Test Loss: 1.038. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 510. Train Loss: 0.535. Test Loss: 1.006. Train Acc: 0.7647. Test Acc:0.5758
# Epoch: 520. Train Loss: 0.5417. Test Loss: 0.9844. Train Acc: 0.8039. Test Acc:0.6061
# Epoch: 530. Train Loss: 0.5011. Test Loss: 0.9846. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 540. Train Loss: 0.4872. Test Loss: 0.9604. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.4994. Test Loss: 0.9407. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 560. Train Loss: 0.5044. Test Loss: 0.9402. Train Acc: 0.8235. Test Acc:0.6667
# Epoch: 570. Train Loss: 0.4357. Test Loss: 0.9236. Train Acc: 0.8039. Test Acc:0.697
# Epoch: 580. Train Loss: 0.4236. Test Loss: 0.9192. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 590. Train Loss: 0.4467. Test Loss: 0.8944. Train Acc: 0.7843. Test Acc:0.7879
# Epoch: 600. Train Loss: 0.4681. Test Loss: 0.8906. Train Acc: 0.8431. Test Acc:0.7879
# Epoch: 610. Train Loss: 0.3733. Test Loss: 0.8844. Train Acc: 0.8627. Test Acc:0.7576
# Epoch: 620. Train Loss: 0.4138. Test Loss: 0.8735. Train Acc: 0.8431. Test Acc:0.7576
# Epoch: 630. Train Loss: 0.3375. Test Loss: 0.8684. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 640. Train Loss: 0.3353. Test Loss: 0.8761. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 650. Train Loss: 0.3427. Test Loss: 0.8812. Train Acc: 0.8627. Test Acc:0.8182
# Epoch: 660. Train Loss: 0.3659. Test Loss: 0.8914. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 670. Train Loss: 0.3378. Test Loss: 0.8777. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 680. Train Loss: 0.2917. Test Loss: 0.8861. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 690. Train Loss: 0.3717. Test Loss: 0.8829. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 700. Train Loss: 0.2546. Test Loss: 0.9046. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 710. Train Loss: 0.2736. Test Loss: 0.9174. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 720. Train Loss: 0.3061. Test Loss: 0.9303. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 730. Train Loss: 0.2333. Test Loss: 0.9184. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 740. Train Loss: 0.2403. Test Loss: 0.9352. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 750. Train Loss: 0.2987. Test Loss: 0.9396. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 760. Train Loss: 0.2446. Test Loss: 0.9519. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 770. Train Loss: 0.2049. Test Loss: 0.9578. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 780. Train Loss: 0.1719. Test Loss: 0.9689. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 790. Train Loss: 0.3181. Test Loss: 0.98. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 800. Train Loss: 0.1721. Test Loss: 0.995. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 810. Train Loss: 0.168. Test Loss: 0.9993. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 820. Train Loss: 0.2596. Test Loss: 1.062. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 830. Train Loss: 0.2285. Test Loss: 1.08. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 840. Train Loss: 0.2319. Test Loss: 1.077. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 850. Train Loss: 0.1965. Test Loss: 1.098. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 860. Train Loss: 0.2167. Test Loss: 1.105. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 870. Train Loss: 0.1916. Test Loss: 1.1. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 880. Train Loss: 0.1742. Test Loss: 1.092. Train Acc: 0.9804. Test Acc:0.7879
# Epoch: 890. Train Loss: 0.1761. Test Loss: 1.129. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 900. Train Loss: 0.192. Test Loss: 1.14. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 910. Train Loss: 0.2575. Test Loss: 1.159. Train Acc: 0.902. Test Acc:0.7879
# Epoch: 920. Train Loss: 0.1942. Test Loss: 1.222. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 930. Train Loss: 0.199. Test Loss: 1.155. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 940. Train Loss: 0.2072. Test Loss: 1.221. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 950. Train Loss: 0.1811. Test Loss: 1.219. Train Acc: 0.9412. Test Acc:0.7576
# Epoch: 960. Train Loss: 0.1805. Test Loss: 1.238. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 970. Train Loss: 0.1089. Test Loss: 1.232. Train Acc: 0.9804. Test Acc:0.7879
# Epoch: 980. Train Loss: 0.1806. Test Loss: 1.233. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 990. Train Loss: 0.1631. Test Loss: 1.25. Train Acc: 0.9804. Test Acc:0.7879
# Epoch: 1000. Train Loss: 0.2234. Test Loss: 1.258. Train Acc: 0.9608. Test Acc:0.7879
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#6. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.117. Test Loss: 1.106. Train Acc: 0.3725. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.125. Test Loss: 1.104. Train Acc: 0.3333. Test Acc:0.3636
# Epoch: 30. Train Loss: 1.115. Test Loss: 1.106. Train Acc: 0.2941. Test Acc:0.3636
# Epoch: 40. Train Loss: 1.127. Test Loss: 1.109. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 50. Train Loss: 1.082. Test Loss: 1.111. Train Acc: 0.3529. Test Acc:0.3636
# Epoch: 60. Train Loss: 1.09. Test Loss: 1.116. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 70. Train Loss: 1.108. Test Loss: 1.111. Train Acc: 0.3137. Test Acc:0.4242
# Epoch: 80. Train Loss: 1.09. Test Loss: 1.109. Train Acc: 0.3922. Test Acc:0.2121
# Epoch: 90. Train Loss: 1.097. Test Loss: 1.111. Train Acc: 0.3529. Test Acc:0.2121
# Epoch: 100. Train Loss: 1.07. Test Loss: 1.107. Train Acc: 0.4314. Test Acc:0.2424
# Epoch: 110. Train Loss: 1.075. Test Loss: 1.105. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 120. Train Loss: 1.062. Test Loss: 1.1. Train Acc: 0.451. Test Acc:0.303
# Epoch: 130. Train Loss: 1.062. Test Loss: 1.102. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 140. Train Loss: 1.078. Test Loss: 1.095. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 150. Train Loss: 1.032. Test Loss: 1.092. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 160. Train Loss: 1.027. Test Loss: 1.068. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 170. Train Loss: 1.006. Test Loss: 1.074. Train Acc: 0.4314. Test Acc:0.4242
# Epoch: 180. Train Loss: 0.9918. Test Loss: 1.082. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 190. Train Loss: 0.9962. Test Loss: 1.071. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 200. Train Loss: 0.9912. Test Loss: 1.076. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 210. Train Loss: 0.948. Test Loss: 1.051. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 220. Train Loss: 0.9706. Test Loss: 1.077. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 230. Train Loss: 0.9047. Test Loss: 1.073. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 240. Train Loss: 0.8912. Test Loss: 1.052. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 250. Train Loss: 0.8819. Test Loss: 1.085. Train Acc: 0.6275. Test Acc:0.3636
# Epoch: 260. Train Loss: 0.8834. Test Loss: 1.047. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 270. Train Loss: 0.8725. Test Loss: 1.096. Train Acc: 0.5882. Test Acc:0.3636
# Epoch: 280. Train Loss: 0.8939. Test Loss: 1.052. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 290. Train Loss: 0.8421. Test Loss: 1.091. Train Acc: 0.549. Test Acc:0.3636
# Epoch: 300. Train Loss: 0.8599. Test Loss: 1.048. Train Acc: 0.549. Test Acc:0.4242
# Epoch: 310. Train Loss: 0.8163. Test Loss: 1.039. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 320. Train Loss: 0.8129. Test Loss: 1.06. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 330. Train Loss: 0.7954. Test Loss: 1.038. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 340. Train Loss: 0.7692. Test Loss: 1.018. Train Acc: 0.6667. Test Acc:0.3939
# Epoch: 350. Train Loss: 0.7967. Test Loss: 1.024. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 360. Train Loss: 0.7434. Test Loss: 1.025. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 370. Train Loss: 0.7324. Test Loss: 1.045. Train Acc: 0.6667. Test Acc:0.4848
# Epoch: 380. Train Loss: 0.718. Test Loss: 1.056. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 390. Train Loss: 0.6418. Test Loss: 1.024. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 400. Train Loss: 0.7027. Test Loss: 1.002. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 410. Train Loss: 0.6595. Test Loss: 1.018. Train Acc: 0.6078. Test Acc:0.4848
# Epoch: 420. Train Loss: 0.6645. Test Loss: 1.034. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 430. Train Loss: 0.6708. Test Loss: 0.991. Train Acc: 0.6275. Test Acc:0.4848
# Epoch: 440. Train Loss: 0.6214. Test Loss: 1.012. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 450. Train Loss: 0.623. Test Loss: 1.019. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 460. Train Loss: 0.6122. Test Loss: 1.029. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 470. Train Loss: 0.6161. Test Loss: 1.023. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 480. Train Loss: 0.569. Test Loss: 1.024. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 490. Train Loss: 0.5608. Test Loss: 1.027. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 500. Train Loss: 0.5725. Test Loss: 1.02. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 510. Train Loss: 0.606. Test Loss: 1.037. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 520. Train Loss: 0.6234. Test Loss: 1.039. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 530. Train Loss: 0.5634. Test Loss: 1.044. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 540. Train Loss: 0.5667. Test Loss: 1.054. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 550. Train Loss: 0.5767. Test Loss: 1.068. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 560. Train Loss: 0.5718. Test Loss: 1.086. Train Acc: 0.7451. Test Acc:0.4848
# Epoch: 570. Train Loss: 0.529. Test Loss: 1.116. Train Acc: 0.7255. Test Acc:0.5152
# Epoch: 580. Train Loss: 0.5145. Test Loss: 1.113. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 590. Train Loss: 0.5499. Test Loss: 1.1. Train Acc: 0.7647. Test Acc:0.4848
# Epoch: 600. Train Loss: 0.5574. Test Loss: 1.125. Train Acc: 0.7843. Test Acc:0.4848
# Epoch: 610. Train Loss: 0.4939. Test Loss: 1.14. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 620. Train Loss: 0.5298. Test Loss: 1.123. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 630. Train Loss: 0.4707. Test Loss: 1.135. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 640. Train Loss: 0.4728. Test Loss: 1.147. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 650. Train Loss: 0.4842. Test Loss: 1.165. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 660. Train Loss: 0.4574. Test Loss: 1.181. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 670. Train Loss: 0.4593. Test Loss: 1.191. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 680. Train Loss: 0.4456. Test Loss: 1.202. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 690. Train Loss: 0.4986. Test Loss: 1.235. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 700. Train Loss: 0.4082. Test Loss: 1.236. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 710. Train Loss: 0.4603. Test Loss: 1.248. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 720. Train Loss: 0.4306. Test Loss: 1.254. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 730. Train Loss: 0.4441. Test Loss: 1.262. Train Acc: 0.7843. Test Acc:0.5152
# Epoch: 740. Train Loss: 0.3869. Test Loss: 1.267. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 750. Train Loss: 0.4335. Test Loss: 1.285. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 760. Train Loss: 0.4327. Test Loss: 1.342. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 770. Train Loss: 0.3598. Test Loss: 1.335. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 780. Train Loss: 0.3572. Test Loss: 1.327. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 790. Train Loss: 0.4231. Test Loss: 1.334. Train Acc: 0.902. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.3636. Test Loss: 1.342. Train Acc: 0.8431. Test Acc:0.4848
# Epoch: 810. Train Loss: 0.342. Test Loss: 1.361. Train Acc: 0.902. Test Acc:0.4545
# Epoch: 820. Train Loss: 0.4067. Test Loss: 1.388. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 830. Train Loss: 0.403. Test Loss: 1.409. Train Acc: 0.8431. Test Acc:0.4545
# Epoch: 840. Train Loss: 0.3883. Test Loss: 1.423. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 850. Train Loss: 0.345. Test Loss: 1.433. Train Acc: 0.9216. Test Acc:0.5152
# Epoch: 860. Train Loss: 0.348. Test Loss: 1.453. Train Acc: 0.8627. Test Acc:0.4545
# Epoch: 870. Train Loss: 0.3447. Test Loss: 1.484. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 880. Train Loss: 0.3907. Test Loss: 1.477. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 890. Train Loss: 0.3109. Test Loss: 1.491. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 900. Train Loss: 0.3468. Test Loss: 1.497. Train Acc: 0.8431. Test Acc:0.5152
# Epoch: 910. Train Loss: 0.3456. Test Loss: 1.5. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 920. Train Loss: 0.3196. Test Loss: 1.515. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 930. Train Loss: 0.3185. Test Loss: 1.549. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 940. Train Loss: 0.3673. Test Loss: 1.584. Train Acc: 0.8627. Test Acc:0.4848
# Epoch: 950. Train Loss: 0.3268. Test Loss: 1.624. Train Acc: 0.9216. Test Acc:0.4242
# Epoch: 960. Train Loss: 0.2766. Test Loss: 1.652. Train Acc: 0.9216. Test Acc:0.4242
# Epoch: 970. Train Loss: 0.2012. Test Loss: 1.632. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.3131. Test Loss: 1.642. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 990. Train Loss: 0.2828. Test Loss: 1.642. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 1000. Train Loss: 0.3089. Test Loss: 1.661. Train Acc: 0.8627. Test Acc:0.5152
# LangIdCNN_Mean2_FCD using retrained-wav2vec_features-z on fold#7. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.112. Test Loss: 1.112. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 20. Train Loss: 1.128. Test Loss: 1.105. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 30. Train Loss: 1.103. Test Loss: 1.101. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 40. Train Loss: 1.131. Test Loss: 1.099. Train Acc: 0.2353. Test Acc:0.3333
# Epoch: 50. Train Loss: 1.086. Test Loss: 1.098. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 60. Train Loss: 1.094. Test Loss: 1.097. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 70. Train Loss: 1.108. Test Loss: 1.088. Train Acc: 0.2549. Test Acc:0.3636
# Epoch: 80. Train Loss: 1.1. Test Loss: 1.084. Train Acc: 0.3333. Test Acc:0.4545
# Epoch: 90. Train Loss: 1.105. Test Loss: 1.082. Train Acc: 0.3333. Test Acc:0.4545
# Epoch: 100. Train Loss: 1.075. Test Loss: 1.073. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 110. Train Loss: 1.071. Test Loss: 1.061. Train Acc: 0.451. Test Acc:0.4848
# Epoch: 120. Train Loss: 1.08. Test Loss: 1.052. Train Acc: 0.4314. Test Acc:0.5152
# Epoch: 130. Train Loss: 1.063. Test Loss: 1.039. Train Acc: 0.3529. Test Acc:0.5152
# Epoch: 140. Train Loss: 1.069. Test Loss: 1.016. Train Acc: 0.3529. Test Acc:0.5152
# Epoch: 150. Train Loss: 1.009. Test Loss: 0.9996. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 160. Train Loss: 1.016. Test Loss: 0.9666. Train Acc: 0.5098. Test Acc:0.4545
# Epoch: 170. Train Loss: 0.9551. Test Loss: 0.9536. Train Acc: 0.4902. Test Acc:0.5152
# Epoch: 180. Train Loss: 0.9798. Test Loss: 0.9389. Train Acc: 0.5098. Test Acc:0.5152
# Epoch: 190. Train Loss: 0.9612. Test Loss: 0.9207. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 200. Train Loss: 0.9468. Test Loss: 0.9058. Train Acc: 0.549. Test Acc:0.5455
# Epoch: 210. Train Loss: 0.9181. Test Loss: 0.8784. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 220. Train Loss: 0.9174. Test Loss: 0.8651. Train Acc: 0.5686. Test Acc:0.5455
# Epoch: 230. Train Loss: 0.8739. Test Loss: 0.8712. Train Acc: 0.5098. Test Acc:0.5455
# Epoch: 240. Train Loss: 0.8306. Test Loss: 0.8617. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 250. Train Loss: 0.8278. Test Loss: 0.8368. Train Acc: 0.5686. Test Acc:0.5455
# Epoch: 260. Train Loss: 0.7865. Test Loss: 0.8142. Train Acc: 0.549. Test Acc:0.5455
# Epoch: 270. Train Loss: 0.7914. Test Loss: 0.8186. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 280. Train Loss: 0.7896. Test Loss: 0.8292. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 290. Train Loss: 0.7058. Test Loss: 0.8151. Train Acc: 0.5686. Test Acc:0.5758
# Epoch: 300. Train Loss: 0.7064. Test Loss: 0.8026. Train Acc: 0.5882. Test Acc:0.5455
# Epoch: 310. Train Loss: 0.6775. Test Loss: 0.7893. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 320. Train Loss: 0.6884. Test Loss: 0.8067. Train Acc: 0.549. Test Acc:0.5455
# Epoch: 330. Train Loss: 0.6568. Test Loss: 0.7945. Train Acc: 0.5686. Test Acc:0.5152
# Epoch: 340. Train Loss: 0.6319. Test Loss: 0.7935. Train Acc: 0.6078. Test Acc:0.5455
# Epoch: 350. Train Loss: 0.6427. Test Loss: 0.7818. Train Acc: 0.7059. Test Acc:0.4848
# Epoch: 360. Train Loss: 0.6096. Test Loss: 0.8095. Train Acc: 0.6863. Test Acc:0.5758
# Epoch: 370. Train Loss: 0.627. Test Loss: 0.8439. Train Acc: 0.6275. Test Acc:0.5455
# Epoch: 380. Train Loss: 0.6525. Test Loss: 0.8632. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 390. Train Loss: 0.5703. Test Loss: 0.7852. Train Acc: 0.6275. Test Acc:0.5758
# Epoch: 400. Train Loss: 0.6274. Test Loss: 0.777. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 410. Train Loss: 0.5877. Test Loss: 0.7958. Train Acc: 0.5882. Test Acc:0.6061
# Epoch: 420. Train Loss: 0.6248. Test Loss: 0.8012. Train Acc: 0.5882. Test Acc:0.6061
# Epoch: 430. Train Loss: 0.6242. Test Loss: 0.7999. Train Acc: 0.5294. Test Acc:0.6061
# Epoch: 440. Train Loss: 0.6002. Test Loss: 0.8197. Train Acc: 0.5294. Test Acc:0.6061
# Epoch: 450. Train Loss: 0.5848. Test Loss: 0.8109. Train Acc: 0.6471. Test Acc:0.5758
# Epoch: 460. Train Loss: 0.5752. Test Loss: 0.8748. Train Acc: 0.6667. Test Acc:0.5758
# Epoch: 470. Train Loss: 0.5982. Test Loss: 0.802. Train Acc: 0.5686. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.534. Test Loss: 0.7993. Train Acc: 0.6275. Test Acc:0.6061
# Epoch: 490. Train Loss: 0.5655. Test Loss: 0.8031. Train Acc: 0.4706. Test Acc:0.697
# Epoch: 500. Train Loss: 0.5514. Test Loss: 0.8394. Train Acc: 0.7059. Test Acc:0.7879
# Epoch: 510. Train Loss: 0.5719. Test Loss: 0.8234. Train Acc: 0.6471. Test Acc:0.7879
# Epoch: 520. Train Loss: 0.5824. Test Loss: 0.7942. Train Acc: 0.6275. Test Acc:0.7576
# Epoch: 530. Train Loss: 0.5646. Test Loss: 0.8112. Train Acc: 0.6863. Test Acc:0.8182
# Epoch: 540. Train Loss: 0.5759. Test Loss: 0.8337. Train Acc: 0.7451. Test Acc:0.8182
# Epoch: 550. Train Loss: 0.5696. Test Loss: 0.8074. Train Acc: 0.6667. Test Acc:0.8182
# Epoch: 560. Train Loss: 0.5529. Test Loss: 0.8285. Train Acc: 0.6863. Test Acc:0.8485
# Epoch: 570. Train Loss: 0.5321. Test Loss: 0.8167. Train Acc: 0.7451. Test Acc:0.7879
# Epoch: 580. Train Loss: 0.5186. Test Loss: 0.8117. Train Acc: 0.8431. Test Acc:0.8182
# Epoch: 590. Train Loss: 0.5374. Test Loss: 0.8197. Train Acc: 0.7059. Test Acc:0.8788
# Epoch: 600. Train Loss: 0.5532. Test Loss: 0.8181. Train Acc: 0.6471. Test Acc:0.8485
# Epoch: 610. Train Loss: 0.5486. Test Loss: 0.8456. Train Acc: 0.7451. Test Acc:0.7879
# Epoch: 620. Train Loss: 0.5803. Test Loss: 0.8337. Train Acc: 0.7059. Test Acc:0.8182
# Epoch: 630. Train Loss: 0.4841. Test Loss: 0.8424. Train Acc: 0.8235. Test Acc:0.8485
# Epoch: 640. Train Loss: 0.4829. Test Loss: 0.7752. Train Acc: 0.7059. Test Acc:0.8485
# Epoch: 650. Train Loss: 0.4881. Test Loss: 0.7646. Train Acc: 0.7843. Test Acc:0.8182
# Epoch: 660. Train Loss: 0.4733. Test Loss: 0.7646. Train Acc: 0.7255. Test Acc:0.8485
# Epoch: 670. Train Loss: 0.4886. Test Loss: 0.7875. Train Acc: 0.8039. Test Acc:0.8788
# Epoch: 680. Train Loss: 0.4376. Test Loss: 0.7566. Train Acc: 0.8627. Test Acc:0.8788
# Epoch: 690. Train Loss: 0.4724. Test Loss: 0.7577. Train Acc: 0.8039. Test Acc:0.9091
# Epoch: 700. Train Loss: 0.4101. Test Loss: 0.7696. Train Acc: 0.8627. Test Acc:0.8485
# Epoch: 710. Train Loss: 0.4251. Test Loss: 0.8342. Train Acc: 0.8235. Test Acc:0.7576
# Epoch: 720. Train Loss: 0.3866. Test Loss: 0.8132. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 730. Train Loss: 0.3992. Test Loss: 0.8555. Train Acc: 0.8039. Test Acc:0.7576
# Epoch: 740. Train Loss: 0.3662. Test Loss: 0.8826. Train Acc: 0.902. Test Acc:0.7576
# ...
# Epoch: 320. Train Loss: 0.7436. Test Loss: 0.7849. Train Acc: 0.5098. Test Acc:0.6364
# Epoch: 330. Train Loss: 0.656. Test Loss: 0.7774. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 340. Train Loss: 0.649. Test Loss: 0.7958. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 350. Train Loss: 0.649. Test Loss: 0.7611. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 360. Train Loss: 0.5898. Test Loss: 0.816. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 370. Train Loss: 0.6131. Test Loss: 0.8539. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 380. Train Loss: 0.6398. Test Loss: 0.9069. Train Acc: 0.6471. Test Acc:0.6061
# Epoch: 390. Train Loss: 0.5462. Test Loss: 0.8711. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 400. Train Loss: 0.6274. Test Loss: 0.8531. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 410. Train Loss: 0.5478. Test Loss: 0.8302. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 420. Train Loss: 0.5584. Test Loss: 0.7584. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 430. Train Loss: 0.5648. Test Loss: 0.7404. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 440. Train Loss: 0.5249. Test Loss: 0.7962. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 450. Train Loss: 0.5369. Test Loss: 0.7487. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 460. Train Loss: 0.4906. Test Loss: 0.7549. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 470. Train Loss: 0.4988. Test Loss: 0.7191. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 480. Train Loss: 0.4662. Test Loss: 0.8037. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 490. Train Loss: 0.4699. Test Loss: 0.817. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 500. Train Loss: 0.4524. Test Loss: 0.7304. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 510. Train Loss: 0.4405. Test Loss: 0.7169. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 520. Train Loss: 0.4776. Test Loss: 0.6294. Train Acc: 0.8431. Test Acc:0.697
# Epoch: 530. Train Loss: 0.4652. Test Loss: 0.7166. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 540. Train Loss: 0.4707. Test Loss: 0.6705. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.4716. Test Loss: 0.7267. Train Acc: 0.7843. Test Acc:0.6667
# Epoch: 560. Train Loss: 0.3945. Test Loss: 0.6794. Train Acc: 0.8824. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.3498. Test Loss: 0.787. Train Acc: 0.9412. Test Acc:0.6667
# Epoch: 580. Train Loss: 0.3907. Test Loss: 0.7142. Train Acc: 0.8627. Test Acc:0.6061
# Epoch: 590. Train Loss: 0.3745. Test Loss: 0.654. Train Acc: 0.902. Test Acc:0.697
# Epoch: 600. Train Loss: 0.4279. Test Loss: 0.6194. Train Acc: 0.8431. Test Acc:0.7273
# Epoch: 610. Train Loss: 0.3672. Test Loss: 0.6521. Train Acc: 0.902. Test Acc:0.697
# Epoch: 620. Train Loss: 0.3869. Test Loss: 0.6026. Train Acc: 0.8431. Test Acc:0.7576
# Epoch: 630. Train Loss: 0.2977. Test Loss: 0.6681. Train Acc: 0.9608. Test Acc:0.697
# Epoch: 640. Train Loss: 0.3009. Test Loss: 0.7004. Train Acc: 0.902. Test Acc:0.697
# Epoch: 650. Train Loss: 0.3067. Test Loss: 0.6876. Train Acc: 0.9216. Test Acc:0.697
# Epoch: 660. Train Loss: 0.2632. Test Loss: 0.7078. Train Acc: 0.9216. Test Acc:0.697
# Epoch: 670. Train Loss: 0.3017. Test Loss: 0.73. Train Acc: 0.9412. Test Acc:0.6667
# Epoch: 680. Train Loss: 0.2873. Test Loss: 0.7046. Train Acc: 0.902. Test Acc:0.697
# Epoch: 690. Train Loss: 0.2946. Test Loss: 0.6999. Train Acc: 0.8824. Test Acc:0.697
# Epoch: 700. Train Loss: 0.2774. Test Loss: 0.6591. Train Acc: 0.9216. Test Acc:0.7273
# Epoch: 710. Train Loss: 0.2722. Test Loss: 0.7593. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 720. Train Loss: 0.2637. Test Loss: 0.6982. Train Acc: 0.9216. Test Acc:0.697
# Epoch: 730. Train Loss: 0.2246. Test Loss: 0.7634. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 740. Train Loss: 0.2249. Test Loss: 0.7183. Train Acc: 0.9216. Test Acc:0.697
# Epoch: 750. Train Loss: 0.2643. Test Loss: 0.716. Train Acc: 0.9216. Test Acc:0.697
# Epoch: 760. Train Loss: 0.2656. Test Loss: 0.6901. Train Acc: 0.9216. Test Acc:0.7273
# Epoch: 770. Train Loss: 0.1943. Test Loss: 0.6518. Train Acc: 0.9804. Test Acc:0.7879
# Epoch: 780. Train Loss: 0.2235. Test Loss: 0.6344. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 790. Train Loss: 0.2854. Test Loss: 0.6443. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 800. Train Loss: 0.1929. Test Loss: 0.6559. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 810. Train Loss: 0.1734. Test Loss: 0.6685. Train Acc: 0.9804. Test Acc:0.7879
# Epoch: 820. Train Loss: 0.2393. Test Loss: 0.6527. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 830. Train Loss: 0.2416. Test Loss: 0.6418. Train Acc: 0.9216. Test Acc:0.7879
# Epoch: 840. Train Loss: 0.1958. Test Loss: 0.6688. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 850. Train Loss: 0.1908. Test Loss: 0.708. Train Acc: 0.9804. Test Acc:0.7576
# Epoch: 860. Train Loss: 0.2168. Test Loss: 0.7031. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 870. Train Loss: 0.1782. Test Loss: 0.7573. Train Acc: 0.9804. Test Acc:0.7576
# Epoch: 880. Train Loss: 0.2171. Test Loss: 0.7273. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 890. Train Loss: 0.1746. Test Loss: 0.7058. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 900. Train Loss: 0.2209. Test Loss: 0.7246. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 910. Train Loss: 0.2359. Test Loss: 0.7051. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 920. Train Loss: 0.2156. Test Loss: 0.7302. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 930. Train Loss: 0.1947. Test Loss: 0.7715. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 940. Train Loss: 0.204. Test Loss: 0.6947. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 950. Train Loss: 0.2388. Test Loss: 0.726. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 960. Train Loss: 0.1863. Test Loss: 0.7176. Train Acc: 0.9412. Test Acc:0.7576
# Epoch: 970. Train Loss: 0.1069. Test Loss: 0.7243. Train Acc: 1.0. Test Acc:0.7576
# Epoch: 980. Train Loss: 0.2153. Test Loss: 0.704. Train Acc: 0.9216. Test Acc:0.7576
# Epoch: 990. Train Loss: 0.1728. Test Loss: 0.6999. Train Acc: 0.9608. Test Acc:0.7576
# Epoch: 1000. Train Loss: 0.2856. Test Loss: 0.7269. Train Acc: 0.8627. Test Acc:0.7576
# LangIdCNN_Mean2_FCD using wav2vec_features-z on fold#9. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14             [10, 9]               0               0
#          Linear-15             [10, 3]              30              30
# =======================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.104. Test Loss: 1.127. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 20. Train Loss: 1.113. Test Loss: 1.121. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 30. Train Loss: 1.109. Test Loss: 1.118. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 40. Train Loss: 1.126. Test Loss: 1.118. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 50. Train Loss: 1.09. Test Loss: 1.117. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 60. Train Loss: 1.094. Test Loss: 1.118. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 70. Train Loss: 1.11. Test Loss: 1.111. Train Acc: 0.2745. Test Acc:0.303
# Epoch: 80. Train Loss: 1.097. Test Loss: 1.107. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 90. Train Loss: 1.112. Test Loss: 1.108. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 100. Train Loss: 1.076. Test Loss: 1.105. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 110. Train Loss: 1.088. Test Loss: 1.1. Train Acc: 0.3725. Test Acc:0.2424
# Epoch: 120. Train Loss: 1.089. Test Loss: 1.094. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 130. Train Loss: 1.09. Test Loss: 1.095. Train Acc: 0.3137. Test Acc:0.303
# Epoch: 140. Train Loss: 1.097. Test Loss: 1.086. Train Acc: 0.2745. Test Acc:0.3636
# Epoch: 150. Train Loss: 1.049. Test Loss: 1.078. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 160. Train Loss: 1.031. Test Loss: 1.05. Train Acc: 0.4314. Test Acc:0.4242
# Epoch: 170. Train Loss: 1.034. Test Loss: 1.037. Train Acc: 0.4706. Test Acc:0.4848
# Epoch: 180. Train Loss: 1.02. Test Loss: 1.078. Train Acc: 0.4314. Test Acc:0.3939
# Epoch: 190. Train Loss: 0.9992. Test Loss: 1.038. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 200. Train Loss: 1.027. Test Loss: 1.029. Train Acc: 0.3725. Test Acc:0.4242
# Epoch: 210. Train Loss: 1.012. Test Loss: 1.005. Train Acc: 0.5098. Test Acc:0.4848
# Epoch: 220. Train Loss: 1.001. Test Loss: 1.017. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 230. Train Loss: 1.008. Test Loss: 1.005. Train Acc: 0.4902. Test Acc:0.4242
# Epoch: 240. Train Loss: 0.9673. Test Loss: 0.9747. Train Acc: 0.5294. Test Acc:0.4848
# Epoch: 250. Train Loss: 0.9373. Test Loss: 0.9828. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 260. Train Loss: 0.9179. Test Loss: 0.9596. Train Acc: 0.4706. Test Acc:0.4848
# Epoch: 270. Train Loss: 0.8888. Test Loss: 1.003. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 280. Train Loss: 0.9157. Test Loss: 0.9991. Train Acc: 0.5294. Test Acc:0.3939
# Epoch: 290. Train Loss: 0.8375. Test Loss: 0.9703. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 300. Train Loss: 0.8433. Test Loss: 0.9554. Train Acc: 0.549. Test Acc:0.4848
# Epoch: 310. Train Loss: 0.7932. Test Loss: 0.9903. Train Acc: 0.4706. Test Acc:0.4545
# Epoch: 320. Train Loss: 0.822. Test Loss: 1.032. Train Acc: 0.5686. Test Acc:0.4545
# Epoch: 330. Train Loss: 0.7617. Test Loss: 1.018. Train Acc: 0.5882. Test Acc:0.5152
# Epoch: 340. Train Loss: 0.7386. Test Loss: 1.009. Train Acc: 0.5294. Test Acc:0.4848
# Epoch: 350. Train Loss: 0.7425. Test Loss: 0.9671. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 360. Train Loss: 0.6979. Test Loss: 0.9579. Train Acc: 0.6667. Test Acc:0.5758
# Epoch: 370. Train Loss: 0.7042. Test Loss: 1.013. Train Acc: 0.5882. Test Acc:0.5455
# Epoch: 380. Train Loss: 0.6881. Test Loss: 1.037. Train Acc: 0.6863. Test Acc:0.5455
# Epoch: 390. Train Loss: 0.6137. Test Loss: 1.049. Train Acc: 0.7255. Test Acc:0.5455
# Epoch: 400. Train Loss: 0.6971. Test Loss: 1.017. Train Acc: 0.5882. Test Acc:0.5758
# Epoch: 410. Train Loss: 0.6352. Test Loss: 1.015. Train Acc: 0.6667. Test Acc:0.6061
# Epoch: 420. Train Loss: 0.669. Test Loss: 0.9651. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 430. Train Loss: 0.6803. Test Loss: 0.9533. Train Acc: 0.5098. Test Acc:0.5758
# Epoch: 440. Train Loss: 0.6249. Test Loss: 1.011. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 450. Train Loss: 0.6271. Test Loss: 1.006. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 460. Train Loss: 0.5885. Test Loss: 1.026. Train Acc: 0.6863. Test Acc:0.5758
# Epoch: 470. Train Loss: 0.6319. Test Loss: 0.9477. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 480. Train Loss: 0.5792. Test Loss: 1.016. Train Acc: 0.6863. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.5933. Test Loss: 1.058. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 500. Train Loss: 0.6052. Test Loss: 0.9902. Train Acc: 0.6667. Test Acc:0.6364
# Epoch: 510. Train Loss: 0.6072. Test Loss: 1.0. Train Acc: 0.6275. Test Acc:0.6364
# Epoch: 520. Train Loss: 0.6421. Test Loss: 0.9357. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 530. Train Loss: 0.6068. Test Loss: 0.9806. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 540. Train Loss: 0.6165. Test Loss: 0.969. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.5845. Test Loss: 1.002. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 560. Train Loss: 0.6089. Test Loss: 1.022. Train Acc: 0.6275. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.5708. Test Loss: 1.052. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 580. Train Loss: 0.5623. Test Loss: 1.034. Train Acc: 0.7059. Test Acc:0.6667
# Epoch: 590. Train Loss: 0.573. Test Loss: 0.9739. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 600. Train Loss: 0.624. Test Loss: 0.9797. Train Acc: 0.5882. Test Acc:0.6364
# Epoch: 610. Train Loss: 0.5782. Test Loss: 1.099. Train Acc: 0.6667. Test Acc:0.6667
# Epoch: 620. Train Loss: 0.6089. Test Loss: 1.079. Train Acc: 0.7255. Test Acc:0.6667
# Epoch: 630. Train Loss: 0.5379. Test Loss: 1.166. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 640. Train Loss: 0.5328. Test Loss: 1.105. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 650. Train Loss: 0.5473. Test Loss: 1.009. Train Acc: 0.7255. Test Acc:0.6667
# Epoch: 660. Train Loss: 0.496. Test Loss: 1.043. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 670. Train Loss: 0.5165. Test Loss: 1.134. Train Acc: 0.7647. Test Acc:0.6667
# Epoch: 680. Train Loss: 0.5309. Test Loss: 1.156. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 690. Train Loss: 0.5316. Test Loss: 1.16. Train Acc: 0.7843. Test Acc:0.6061
# Epoch: 700. Train Loss: 0.4858. Test Loss: 1.066. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 710. Train Loss: 0.4945. Test Loss: 1.06. Train Acc: 0.7647. Test Acc:0.6667
# Epoch: 720. Train Loss: 0.4664. Test Loss: 1.058. Train Acc: 0.902. Test Acc:0.6364
# Epoch: 730. Train Loss: 0.5062. Test Loss: 1.064. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 740. Train Loss: 0.4693. Test Loss: 1.103. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 750. Train Loss: 0.4878. Test Loss: 1.125. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 760. Train Loss: 0.5211. Test Loss: 1.056. Train Acc: 0.6863. Test Acc:0.6667
# Epoch: 770. Train Loss: 0.4261. Test Loss: 1.055. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 780. Train Loss: 0.4341. Test Loss: 1.063. Train Acc: 0.8824. Test Acc:0.6667
# Epoch: 790. Train Loss: 0.4536. Test Loss: 1.067. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 800. Train Loss: 0.4234. Test Loss: 1.136. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 810. Train Loss: 0.3975. Test Loss: 1.144. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 820. Train Loss: 0.4552. Test Loss: 1.091. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 830. Train Loss: 0.4208. Test Loss: 1.109. Train Acc: 0.8039. Test Acc:0.6364
# Epoch: 840. Train Loss: 0.3981. Test Loss: 1.153. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 850. Train Loss: 0.3526. Test Loss: 1.194. Train Acc: 0.902. Test Acc:0.6061
# Epoch: 860. Train Loss: 0.3942. Test Loss: 1.179. Train Acc: 0.8824. Test Acc:0.6667
# Epoch: 870. Train Loss: 0.3591. Test Loss: 1.226. Train Acc: 0.8627. Test Acc:0.6364
# Epoch: 880. Train Loss: 0.4257. Test Loss: 1.265. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 890. Train Loss: 0.3252. Test Loss: 1.379. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 900. Train Loss: 0.3957. Test Loss: 1.301. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 910. Train Loss: 0.4159. Test Loss: 1.228. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 920. Train Loss: 0.3764. Test Loss: 1.239. Train Acc: 0.902. Test Acc:0.697
# Epoch: 930. Train Loss: 0.3582. Test Loss: 1.318. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 940. Train Loss: 0.3685. Test Loss: 1.255. Train Acc: 0.8431. Test Acc:0.6667
# Epoch: 950. Train Loss: 0.3513. Test Loss: 1.283. Train Acc: 0.8824. Test Acc:0.6061
# Epoch: 960. Train Loss: 0.3391. Test Loss: 1.441. Train Acc: 0.8235. Test Acc:0.6364
# Epoch: 970. Train Loss: 0.2544. Test Loss: 1.367. Train Acc: 0.9608. Test Acc:0.6667
# Epoch: 980. Train Loss: 0.3225. Test Loss: 1.307. Train Acc: 0.902. Test Acc:0.6061
# Epoch: 990. Train Loss: 0.2983. Test Loss: 1.334. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 1000. Train Loss: 0.378. Test Loss: 1.727. Train Acc: 0.8039. Test Acc:0.6061

# %%
# raw_features.keys()
# ['wav2vec_features-c', 'wav2vec_features-z', 'retrained-wav2vec_features-c', 'retrained-wav2vec_features-z']
