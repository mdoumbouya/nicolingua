# %%
from pathlib import Path
import csv
from itertools import groupby
import h5py
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.svm import SVC
# from sklearn.linear_model import LogisticRegression
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import random
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# # Configuration & Utilities

# %%
random.seed(42)
COLORS = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"]
ANNOTATIONS_PATH = "/media/xtrem/data/experiments/nicolingua-0001-language-id/language-id-annotations/metadata.csv"
FEATURE_DIRS = [
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/wav2vec_features-z',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-c',
    '/media/xtrem/data/experiments/nicolingua-0001-language-id/retrained-wav2vec_features-z'
]


dropout_p = 0.6
fc_dropout_p = 0.5

RESULTS_DIR = f'results_008_gn_lang_classification__dropout_{dropout_p}__fc_dropout_{fc_dropout_p}'

GPU_ID = 1

# %%
annotation_specification = {
    0: {
        'id': 0,
        'label': "maninka",
        'required_tags': set(['ct-speech', 'lng-maninka']),
        'forbidden_tags':  set(['lng-susu', 'lng-pular'])
    },
    1: {
        'id': 1,
        'label': "susu",
        'required_tags': set(['ct-speech', 'lng-susu']),
        'forbidden_tags':  set(['lng-maninka', 'lng-pular'])
    },
    2: {
        'id': 2,
        'label': "pular",
        'required_tags': set(['ct-speech', 'lng-pular']),
        'forbidden_tags':  set(['lng-susu', 'lng-maninka'])
    }
}

# %%
bias_category_specification = [
    {
        "category": "utterance",
        "subcategories": [
            {
                "subcategory": "verbal_nod",
                "tags": set(["utt-verbal-nod"])
            },
            {
                "subcategory": "multilingual",
                "tags": set(["utt-multi-lingual", "utt-multi-lingual-named-endity"])
            }
        ]
    },
    {
        "category": "speaker_count",
        "subcategories": [
            {
                "subcategory": "single",
                "tags": set(["spkr-single"])
            },
            {
                "subcategory": "multiple",
                "tags": set(["spkr-mult", "spkr-multi"])
            }
        ]
    },
    {
        "category": "gender",
        "subcategories": [
            {
                "subcategory": "male",
                "tags": set(["spkr-male"])
            },
            {
                "subcategory": "female",
                "tags": set(["spkr-female"])
            },
        ]
    },
    {
        "category": "language",
        "subcategories": [
            {
                "subcategory": "susu",
                "tags": set(["lng-susu"])
            },
            {
                "subcategory": "maninka",
                "tags": set(["lng-maninka"])
            },
            {
                "subcategory": "pular",
                "tags": set(["lng-pular"])
            }
        ]
    },
    {
        "category": "channel",
        "subcategories": [
            {
                "subcategory": "telephone",
                "tags": set(["ct-telephone"])
            },
            {
                "subcategory": "noise",
                "tags": set(["ct-noise"])
            },
            {
                "subcategory": "music",
                "tags": set(["ct-fg-music", "ct-tr-music", "ct-bg-music"])
            }
        ]
    }
]

flat_bias_category_specification = {}

for c in bias_category_specification:
    for sc in c['subcategories']:
        k = f"{c['category']}_{sc['subcategory']}"
        flat_bias_category_specification[k] = sc['tags']

_ = [print(f"{k}: {v}") for k,v in flat_bias_category_specification.items()]
# Out:
# utterance_verbal_nod: {'utt-verbal-nod'}
# utterance_multilingual: {'utt-multi-lingual', 'utt-multi-lingual-named-endity'}
# speaker_count_single: {'spkr-single'}
# speaker_count_multiple: {'spkr-mult', 'spkr-multi'}
# gender_male: {'spkr-male'}
# gender_female: {'spkr-female'}
# language_susu: {'lng-susu'}
# language_maninka: {'lng-maninka'}
# language_pular: {'lng-pular'}
# channel_telephone: {'ct-telephone'}
# channel_noise: {'ct-noise'}
# channel_music: {'ct-fg-music', 'ct-bg-music', 'ct-tr-music'}

# %%
def to_user_friendly_feature_name(fv_name):
    name = fv_name \
        .replace("features-", "") \
        .replace("wav2vec_", "") \
        .replace("average", "avg") \
        .replace("timestep", "T") \
        .replace("c.", "Context") \
        .replace("z.", "Latent")
    return name

# %% [markdown]
# # Load annotations

# %%
def load_annotations(a_file_path, a_specification):
    with open(ANNOTATIONS_PATH) as f:
        reader = csv.DictReader(f)
        for row in reader:
            tag_set = set([t.strip() for t in row['tags'].split(";")])
            for label in annotation_specification.keys():
                spec = annotation_specification[label]
                if spec['required_tags'].issubset(tag_set):
                    if spec['forbidden_tags'].isdisjoint(tag_set):
                        yield row['file'], label, tag_set
                        break

data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
audio_files, audio_labels, audio_tags = zip(*data)

# %% [markdown]
# ## Inspect label counts

# %%
def inspect_label_counts():
    for label in annotation_specification:
        count = len([l for l in audio_labels if l == label])
        print("{:10} ({}): {}".format(
            annotation_specification[label]['label'],
            label, 
            count
        ))
inspect_label_counts()
# Out:
# maninka    (0): 114
# susu       (1): 32
# pular      (2): 28

# %% [markdown]
# ## Balance data

# %%
count_per_class = 28
data = list(load_annotations(ANNOTATIONS_PATH, annotation_specification))
balanced_data = []
for label in annotation_specification:
    balanced_data.extend([d for d in data if d[1] == label][:count_per_class])
audio_files, audio_labels, audio_tags = zip(*balanced_data)

# %%
inspect_label_counts()
# Out:
# maninka    (0): 28
# susu       (1): 28
# pular      (2): 28

# %% [markdown]
# ## Inspect bias category counts in balanded data

# %%
def inspect_bias_category_counts():
    for name, tags in flat_bias_category_specification.items():
        count = len([ts for ts in audio_tags if len(tags.intersection(ts))>0])
        print(name, count, "/", len(audio_tags))
            
inspect_bias_category_counts()
# Out:
# utterance_verbal_nod 48 / 84
# utterance_multilingual 21 / 84
# speaker_count_single 25 / 84
# speaker_count_multiple 58 / 84
# gender_male 81 / 84
# gender_female 15 / 84
# language_susu 28 / 84
# language_maninka 28 / 84
# language_pular 28 / 84
# channel_telephone 27 / 84
# channel_noise 21 / 84
# channel_music 24 / 84

# %% [markdown]
# # Prepare 10 cross validation folds

# %%
TRAIN_PERCENT = .6
FOLD_COUNT = 10

n = len(audio_files)
n_train = int(np.ceil(n * .6))
n_test = n - n_train
all_indices = range(n)

cv_folds = {}
train_count_by_index = {i:0 for i in all_indices}
test_count_by_index = {i:0 for i in all_indices}

for fold_index in range(FOLD_COUNT):
    fold_rsampler = np.random.RandomState(seed=fold_index)
    train_index_set = set(fold_rsampler.choice(all_indices, n_train, replace=False))
    test_index_set = set(all_indices).difference(train_index_set)
        
    cv_folds[fold_index] = {
        'train_indices': sorted(list(train_index_set)),
        'test_indices': sorted(list(test_index_set)),
    }

# %% [markdown]
# # Load features

# %%
def load_features(audio_files, features_input_dir):
    id_list = []
    features_list = []

    for audio_file_name in audio_files:
        feature_file_name = audio_file_name.replace(".wav", ".h5context")
        feature_path = Path(features_input_dir) / feature_file_name
        with h5py.File(feature_path, 'r') as f:
            features_shape = f['info'][1:].astype(int)
            features = np.array(f['features'][:]).reshape(features_shape)
            # features = pool_feature_last_seq(features)
            features_list.append(features)
    return features_list

# %%
raw_features = {}
for feature_dir in FEATURE_DIRS:
    feature_name = Path(feature_dir).stem
    raw_features[feature_name] = load_features(audio_files, feature_dir)

# %% [markdown]
# ## Inspect feature shapes

# %%
for feature_name in raw_features.keys():
    print("feature_name: {}. feature shape: {}".format(
        to_user_friendly_feature_name(feature_name),
        raw_features[feature_name][0].shape
    ))
# Out:
# feature_name: c. feature shape: (2998, 512)
# feature_name: z. feature shape: (2998, 512)
# feature_name: retrained-c. feature shape: (2998, 512)
# feature_name: retrained-z. feature shape: (2998, 512)

# %% [markdown]
# ## Extract feature vectors

# %%
def extract_last_timestep_features(raw_features):
    return raw_features[-1, :]

def extract_neuron_average_features(raw_features):
    return np.mean(raw_features, axis=0)

def identity(x):
    return x

feature_extractors = {
    'last_timestep': extract_last_timestep_features,
    'neuron_average': extract_neuron_average_features,
    'raw_features': identity
}

# %%
feature_vectors = {}
for feature_name in raw_features.keys():
    for feature_extractor_name in feature_extractors.keys():
        fv_name = f"{feature_name}__{feature_extractor_name}"
        feature_vectors[fv_name] = []
        for f in raw_features[feature_name]:
            feature_vectors[fv_name].append(
                feature_extractors[feature_extractor_name](f)
            )
            
        feature_vectors[fv_name] = np.array(feature_vectors[fv_name])

# %% [markdown]
# ## Inspect feature vectors

# %%
for fvname in feature_vectors.keys():
    print(fvname, feature_vectors[fvname][0].shape)
# Out:
# wav2vec_features-c__last_timestep (512,)
# wav2vec_features-c__neuron_average (512,)
# wav2vec_features-c__raw_features (2998, 512)
# wav2vec_features-z__last_timestep (512,)
# wav2vec_features-z__neuron_average (512,)
# wav2vec_features-z__raw_features (2998, 512)
# retrained-wav2vec_features-c__last_timestep (512,)
# retrained-wav2vec_features-c__neuron_average (512,)
# retrained-wav2vec_features-c__raw_features (2998, 512)
# retrained-wav2vec_features-z__last_timestep (512,)
# retrained-wav2vec_features-z__neuron_average (512,)
# retrained-wav2vec_features-z__raw_features (2998, 512)

# %% [markdown]
# # Classification Models

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from pytorch_model_summary import summary
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim

# %%
class LangIdCNN_Mean2_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_Mean2_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=9, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1 = torch.mean(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2 = torch.mean(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3 = torch.mean(x, dim=2)
        
        v = torch.cat((v1, v2, v3), axis=1)
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x
    

class LangIdCNN_MeanStd_FCD(nn.Module):
    def __init__(self):
        super(LangIdCNN_MeanStd_FCD, self).__init__()
        
        self.conv0 = nn.Conv1d(in_channels=512, out_channels=3, kernel_size=1)
        
        self.conv1 = nn.Conv1d(in_channels=3, out_channels=1, kernel_size=3)
        self.drop1 = nn.Dropout(p=dropout_p)
        self.pool1 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv2 = nn.Conv1d(in_channels=1, out_channels=3, kernel_size=3)
        self.drop2 = nn.Dropout(p=dropout_p)
        self.pool2 = nn.AvgPool1d(kernel_size=2, stride=2)
        
        self.conv3 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop3 = nn.Dropout(p=dropout_p)
        self.pool3 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.conv4 = nn.Conv1d(in_channels=3, out_channels=3, kernel_size=3)
        self.drop4 = nn.Dropout(p=dropout_p)
        self.pool4 = nn.AvgPool1d(kernel_size=2, stride=2)

        self.drop5 = nn.Dropout(p=fc_dropout_p)

        self.lin6 = nn.Linear(in_features=18, out_features=3)
        
        
    def forward(self, x):
        x = x.permute(0, 2, 1)
        
        x = self.conv0(x)
        
        x = self.conv1(x)
        x = F.elu(x)
        x = self.drop1(x)
        x = self.pool1(x)
        
        
        x = self.conv2(x)
        x = F.elu(x)
        x = self.drop2(x)
        x = self.pool2(x)
        
        v1_mean = torch.mean(x, dim=2)
        v1_std = torch.std(x, dim=2)
        
        x = self.conv3(x)
        x = F.elu(x)
        x = self.drop3(x)
        x = self.pool3(x)
        
        v2_mean = torch.mean(x, dim=2)
        v2_std = torch.std(x, dim=2)
        
        x = self.conv4(x)
        x = F.elu(x)
        x = self.drop4(x)
        x = self.pool4(x)
        
        v3_mean = torch.mean(x, dim=2)
        v3_std = torch.std(x, dim=2)
        
        v = torch.cat((v1_mean, v1_std, v2_mean, v2_std, v3_mean, v3_std), axis=1)
        
        v = self.drop5(v)
        
        x = self.lin6(v)
        
        return v, x

# %% [markdown]
# # Train Classification Models

# %%
def get_data_for_fold(fold_id, feature_name, batch_size):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']    

    train_x = np.take(raw_features[feature_name], train_indices, axis=0)
    train_y = np.take(audio_labels, train_indices, axis=0)
    train_tags = np.take(audio_tags, train_indices, axis=0)
    train_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        train_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in train_tags]

    test_x = np.take(raw_features[feature_name], test_indices, axis=0)
    test_y = np.take(audio_labels, test_indices, axis=0)
    test_tags = np.take(audio_tags, test_indices, axis=0)
    test_bias_category_labels = {}
    for category, tags in flat_bias_category_specification.items():
        test_bias_category_labels[category] = [1 if len(tags.intersection(ts))>0 else 0 for ts in test_tags]
        
    
    return train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels

def get_audio_files_for_fold(fold_id):
    train_indices = cv_folds[fold_id]['train_indices']
    test_indices = cv_folds[fold_id]['test_indices']
    
    train_files = np.take(audio_files, train_indices, axis=0)
    test_files = np.take(audio_files, test_indices, axis=0)
    
    return train_files, test_files
    

    
def get_loaders_for_fold(fold_id, feature_name, batch_size):
    
    train_x, train_y, test_x, test_y, train_bias_category_labels, test_bias_category_labels = \
        get_data_for_fold(fold_id, feature_name, batch_size)
    
    
    
    train_dataset = TensorDataset(
        torch.tensor(train_x), 
        torch.tensor(train_y)
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size)

    test_dataset = TensorDataset(
        torch.tensor(test_x), 
        torch.tensor(test_y)
    )

    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, test_loader, train_bias_category_labels, test_bias_category_labels


def get_predictions_for_logits(logits):
    probs = F.softmax(logits, dim=1)
    return torch.argmax(probs, dim=1)

# %%
l2 = nn.PairwiseDistance(p=2)
margin = 1

# See:
# http://caffe.berkeleyvision.org/doxygen/classcaffe_1_1ContrastiveLossLayer.html#details
# http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf

def contrastive_loss(representations, labels):
    normalized_reps = F.normalize(representations, dim=1)
    
    loss = 0
    n = 0
    for i in range(normalized_reps.shape[0]):
        for j in range(normalized_reps.shape[0]):
            d = l2(
                normalized_reps[i].view(1, -1), 
                normalized_reps[j].view(1, -1)
            )
            if labels[i] == labels[j]:
                loss += torch.square(d)
            else:
                loss += torch.square(torch.max(
                    torch.tensor([margin-d, 0]).to(representations.device)
                ))
            
            n+=1
            
    loss = loss / (2*n)
    
    return loss[0]

# %%
def train_on_fold(model_class, fold_id, feature_name, batch_size, epochs, use_contrastive_term):
    device = torch.device(f"cuda:{GPU_ID}")
    torch.manual_seed(0)
    results = {}
    
    model = model_class().to(device)

    train_loader, test_loader, train_bias_category_labels, test_bias_category_labels = get_loaders_for_fold(fold_id, feature_name, batch_size)

    print(summary(model_class(), torch.zeros((10, 2998, 512)), show_input=False))

    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0
        pred_train_classes = []
        true_train_classes = []

        for batch_idx, (x, y) in enumerate(train_loader):
            x = x.to(device)
            y = y.to(device)
            
            optimizer.zero_grad()
            representations, outputs = model(x)
            pred_train_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )
            true_train_classes.extend(y.cpu().numpy())
            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += 0.1 * contrastive_loss(representations, y)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_n = len(true_train_classes)
        
        train_loss = train_loss/len(train_loader)
        train_acc = sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes)
        train_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_train_classes, pred_train_classes, sample_weight=sw)
            for category, sw in train_bias_category_labels.items()
        }
        

        pred_test_logits = []
        
        pred_test_classes = []
        true_test_classes = []
        
        model.eval()
        test_loss = 0
        for batch_idx, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            
            representations, outputs = model(x)
            
            pred_test_logits.extend(outputs.detach().cpu().numpy())

            pred_test_classes.extend(
                get_predictions_for_logits(outputs).cpu().numpy()
            )

            true_test_classes.extend(y.cpu().numpy())

            loss = criterion(outputs, y)
            if (use_contrastive_term):
                loss += contrastive_loss(representations, y)
                
            test_loss += loss.item()


        test_n = len(true_test_classes)
        
        test_loss = test_loss / len(test_loader)
        test_acc = sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes)
        test_acc_by_bais_category = {
            category: sklearn.metrics.accuracy_score(true_test_classes, pred_test_classes, sample_weight=sw)
            for category, sw in test_bias_category_labels.items()
        }

        if epoch%10==0:
            print(f"Epoch: {epoch}. Train Loss: {train_loss:0.4}. Test Loss: {test_loss:0.4}. Train Acc: {train_acc:0.4}. Test Acc:{test_acc:0.4}")
        
        results[epoch] = {
            'epoch': epoch,
            'train_loss': train_loss,
            'test_loss': test_loss,
            'train_acc': train_acc,
            'test_acc': test_acc,
            'train_n': train_n,
            'test_n': test_n,
            'test_logits': pred_test_logits,
            'test_true_classes': true_test_classes
        }
        
        for c in train_acc_by_bais_category:
            results[epoch][f"train_acc_{c}"] = train_acc_by_bais_category[c]
            results[epoch][f"train_n_{c}"] = int(np.sum(train_bias_category_labels[c]))
            
        for c in test_acc_by_bais_category:
            results[epoch][f"test_acc_{c}"] = test_acc_by_bais_category[c]
            results[epoch][f"test_n_{c}"] = int(np.sum(test_bias_category_labels[c]))
        
    del model
    return results

# %%
import csv
from pathlib import Path

def write_epoch_test_logits(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        train_audio_files, test_audio_files = get_audio_files_for_fold(fold_index)
        
        for epoch in sorted(result_entry['epochs'].keys()):
            
            parent_dir = Path(f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}_data")
            parent_dir.mkdir(parents=True, exist_ok=True)

            file_name = parent_dir / f"epoch_{epoch:04}.csv"
            with open(file_name, "w") as f:
                writer = csv.DictWriter(f, fieldnames=["fold_id", "datum_index", "datum_name", "true_class_id", "logits"])
                writer.writeheader()
                
                test_logits = result_entry['epochs'][epoch]["test_logits"]
                test_true_classes = result_entry['epochs'][epoch]["test_true_classes"]
                
                for datum_index in range(len(test_logits)):
                    writer.writerow({
                        "fold_id": fold_index,
                        "datum_index": datum_index,
                        "datum_name": test_audio_files[datum_index],
                        "true_class_id": test_true_classes[datum_index],
                        "logits": test_logits[datum_index]
                    })
                

            annotation_specification.keys()

            field_names = ["index", "fname", "logits"]

            fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"

def save_results(model_name, all_folds_results):
    for result_entry in all_folds_results:
        feature_name = result_entry['feature_name']
        fold_index = result_entry['fold_index']
        
        Path(RESULTS_DIR).mkdir(exist_ok=True, parents=True)
        fname = f"{RESULTS_DIR}/{model_name}/{feature_name}_{fold_index}.csv"
        Path(fname).parent.mkdir(parents=True, exist_ok=True)
        with open(fname, 'w') as f:
            fieldnames = sorted(result_entry['epochs'][1].keys())
            fieldnames.remove("test_logits") # logged separately, differently
            fieldnames.remove("test_true_classes") # logged separately, differently
            
            writer = csv.DictWriter(f, fieldnames=fieldnames, extrasaction='ignore')
            
            writer.writeheader()
            
            for epoch in sorted(result_entry['epochs'].keys()):
                writer.writerow(result_entry['epochs'][epoch])

# %%
model_classes = [
    LangIdCNN_MeanStd_FCD,
    LangIdCNN_Mean2_FCD,
]

for model_class in model_classes:
    all_folds_results = []
    for fold_index in cv_folds:
        for feature_name in ['retrained-wav2vec_features-z', 'wav2vec_features-z']: #raw_features:
            use_contrastive_term = "Contrastive" in model_class.__name__
            
            print(f"{model_class.__name__} using {feature_name} on fold#{fold_index}. Contrastive: {use_contrastive_term}")
            resutls = train_on_fold(model_class, fold_index, feature_name, batch_size=100, epochs=1000, use_contrastive_term=use_contrastive_term)
            all_folds_results.append({
                'fold_index': fold_index,
                'feature_name': feature_name,
                'epochs': resutls
            })
            save_results(model_class.__name__, all_folds_results)
            write_epoch_test_logits(model_class.__name__, all_folds_results)
# Out:
# LangIdCNN_MeanStd_FCD using retrained-wav2vec_features-z on fold#0. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14            [10, 18]               0               0
#          Linear-15             [10, 3]              57              57
# =======================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.113. Test Loss: 1.107. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 20. Train Loss: 1.102. Test Loss: 1.103. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 30. Train Loss: 1.098. Test Loss: 1.101. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 40. Train Loss: 1.12. Test Loss: 1.099. Train Acc: 0.2549. Test Acc:0.3333
# Epoch: 50. Train Loss: 1.101. Test Loss: 1.099. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 60. Train Loss: 1.111. Test Loss: 1.098. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 70. Train Loss: 1.082. Test Loss: 1.097. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 80. Train Loss: 1.094. Test Loss: 1.097. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 90. Train Loss: 1.1. Test Loss: 1.096. Train Acc: 0.2941. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.089. Test Loss: 1.096. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 110. Train Loss: 1.087. Test Loss: 1.095. Train Acc: 0.3922. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.096. Test Loss: 1.093. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 130. Train Loss: 1.067. Test Loss: 1.091. Train Acc: 0.549. Test Acc:0.3333
# Epoch: 140. Train Loss: 1.05. Test Loss: 1.088. Train Acc: 0.549. Test Acc:0.3939
# Epoch: 150. Train Loss: 1.083. Test Loss: 1.08. Train Acc: 0.451. Test Acc:0.3939
# Epoch: 160. Train Loss: 1.051. Test Loss: 1.07. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 170. Train Loss: 1.031. Test Loss: 1.058. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 180. Train Loss: 1.011. Test Loss: 1.035. Train Acc: 0.5294. Test Acc:0.4242
# Epoch: 190. Train Loss: 0.9456. Test Loss: 1.012. Train Acc: 0.549. Test Acc:0.4545
# Epoch: 200. Train Loss: 0.9287. Test Loss: 0.9905. Train Acc: 0.5294. Test Acc:0.4545
# Epoch: 210. Train Loss: 0.8401. Test Loss: 0.96. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 220. Train Loss: 0.7841. Test Loss: 0.9292. Train Acc: 0.6471. Test Acc:0.4848
# Epoch: 230. Train Loss: 0.7064. Test Loss: 0.9062. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 240. Train Loss: 0.7596. Test Loss: 0.9064. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 250. Train Loss: 0.6802. Test Loss: 0.8877. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 260. Train Loss: 0.64. Test Loss: 0.8669. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 270. Train Loss: 0.5966. Test Loss: 0.807. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 280. Train Loss: 0.6597. Test Loss: 0.8381. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 290. Train Loss: 0.6053. Test Loss: 0.8474. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 300. Train Loss: 0.5209. Test Loss: 0.8428. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 310. Train Loss: 0.5329. Test Loss: 0.8374. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 320. Train Loss: 0.5251. Test Loss: 0.8941. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 330. Train Loss: 0.5441. Test Loss: 0.8221. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 340. Train Loss: 0.5206. Test Loss: 0.7128. Train Acc: 0.7255. Test Acc:0.5455
# Epoch: 350. Train Loss: 0.4345. Test Loss: 0.7352. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 360. Train Loss: 0.515. Test Loss: 0.7785. Train Acc: 0.6667. Test Acc:0.4848
# Epoch: 370. Train Loss: 0.4866. Test Loss: 0.724. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 380. Train Loss: 0.4493. Test Loss: 0.7754. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 390. Train Loss: 0.4088. Test Loss: 0.7986. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 400. Train Loss: 0.4758. Test Loss: 0.7838. Train Acc: 0.7647. Test Acc:0.5152
# Epoch: 410. Train Loss: 0.4274. Test Loss: 0.8515. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 420. Train Loss: 0.4358. Test Loss: 0.8052. Train Acc: 0.7843. Test Acc:0.5152
# Epoch: 430. Train Loss: 0.4065. Test Loss: 0.7841. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 440. Train Loss: 0.3594. Test Loss: 0.8012. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 450. Train Loss: 0.3799. Test Loss: 0.919. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 460. Train Loss: 0.3624. Test Loss: 0.8114. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 470. Train Loss: 0.4043. Test Loss: 0.7897. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.3633. Test Loss: 0.8021. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.3435. Test Loss: 0.7533. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 500. Train Loss: 0.3558. Test Loss: 0.9554. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 510. Train Loss: 0.3582. Test Loss: 0.997. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 520. Train Loss: 0.3613. Test Loss: 1.029. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 530. Train Loss: 0.2441. Test Loss: 0.8857. Train Acc: 1.0. Test Acc:0.5758
# Epoch: 540. Train Loss: 0.3338. Test Loss: 0.8843. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 550. Train Loss: 0.3112. Test Loss: 0.8874. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 560. Train Loss: 0.2895. Test Loss: 0.9527. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 570. Train Loss: 0.2653. Test Loss: 0.8676. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 580. Train Loss: 0.2782. Test Loss: 0.7915. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 590. Train Loss: 0.3013. Test Loss: 0.836. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 600. Train Loss: 0.2602. Test Loss: 0.9202. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 610. Train Loss: 0.2485. Test Loss: 0.9495. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 620. Train Loss: 0.2557. Test Loss: 1.004. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 630. Train Loss: 0.1929. Test Loss: 0.9741. Train Acc: 0.9804. Test Acc:0.5455
# Epoch: 640. Train Loss: 0.2054. Test Loss: 0.9502. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 650. Train Loss: 0.2734. Test Loss: 0.9812. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 660. Train Loss: 0.1975. Test Loss: 1.004. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 670. Train Loss: 0.221. Test Loss: 1.038. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 680. Train Loss: 0.1563. Test Loss: 0.9327. Train Acc: 0.9804. Test Acc:0.5758
# Epoch: 690. Train Loss: 0.1853. Test Loss: 0.8679. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 700. Train Loss: 0.2197. Test Loss: 0.7824. Train Acc: 0.9412. Test Acc:0.6364
# Epoch: 710. Train Loss: 0.2298. Test Loss: 0.9343. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 720. Train Loss: 0.2384. Test Loss: 0.9092. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 730. Train Loss: 0.1902. Test Loss: 0.9158. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 740. Train Loss: 0.1503. Test Loss: 0.9605. Train Acc: 0.9804. Test Acc:0.5758
# Epoch: 750. Train Loss: 0.2431. Test Loss: 0.9755. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 760. Train Loss: 0.1952. Test Loss: 1.077. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 770. Train Loss: 0.1761. Test Loss: 1.008. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 780. Train Loss: 0.1841. Test Loss: 0.9059. Train Acc: 0.9216. Test Acc:0.6061
# Epoch: 790. Train Loss: 0.1552. Test Loss: 0.8587. Train Acc: 0.9608. Test Acc:0.6364
# Epoch: 800. Train Loss: 0.1505. Test Loss: 0.8718. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 810. Train Loss: 0.1578. Test Loss: 0.7561. Train Acc: 0.9608. Test Acc:0.6364
# Epoch: 820. Train Loss: 0.2164. Test Loss: 0.892. Train Acc: 0.8824. Test Acc:0.6364
# Epoch: 830. Train Loss: 0.1224. Test Loss: 0.8936. Train Acc: 0.9804. Test Acc:0.6364
# Epoch: 840. Train Loss: 0.1677. Test Loss: 0.869. Train Acc: 0.9608. Test Acc:0.6364
# Epoch: 850. Train Loss: 0.2052. Test Loss: 0.9762. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 860. Train Loss: 0.1965. Test Loss: 0.9979. Train Acc: 0.9608. Test Acc:0.6364
# Epoch: 870. Train Loss: 0.1353. Test Loss: 0.859. Train Acc: 0.9804. Test Acc:0.6667
# Epoch: 880. Train Loss: 0.202. Test Loss: 0.7802. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 890. Train Loss: 0.08869. Test Loss: 0.877. Train Acc: 1.0. Test Acc:0.6667
# Epoch: 900. Train Loss: 0.1456. Test Loss: 0.9646. Train Acc: 0.9608. Test Acc:0.6364
# Epoch: 910. Train Loss: 0.144. Test Loss: 0.9073. Train Acc: 0.9608. Test Acc:0.6667
# Epoch: 920. Train Loss: 0.1153. Test Loss: 1.022. Train Acc: 0.9804. Test Acc:0.5455
# Epoch: 930. Train Loss: 0.1232. Test Loss: 0.8748. Train Acc: 0.9804. Test Acc:0.6667
# Epoch: 940. Train Loss: 0.1729. Test Loss: 0.9359. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 950. Train Loss: 0.1726. Test Loss: 1.018. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 960. Train Loss: 0.2588. Test Loss: 0.803. Train Acc: 0.9412. Test Acc:0.6667
# Epoch: 970. Train Loss: 0.1182. Test Loss: 0.8276. Train Acc: 0.9804. Test Acc:0.6667
# Epoch: 980. Train Loss: 0.1391. Test Loss: 0.9282. Train Acc: 0.9804. Test Acc:0.6667
# Epoch: 990. Train Loss: 0.0818. Test Loss: 0.8624. Train Acc: 1.0. Test Acc:0.6667
# Epoch: 1000. Train Loss: 0.1458. Test Loss: 0.8117. Train Acc: 0.9412. Test Acc:0.6667
# LangIdCNN_MeanStd_FCD using wav2vec_features-z on fold#0. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14            [10, 18]               0               0
#          Linear-15             [10, 3]              57              57
# =======================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.115. Test Loss: 1.107. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 20. Train Loss: 1.103. Test Loss: 1.103. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 30. Train Loss: 1.099. Test Loss: 1.1. Train Acc: 0.4314. Test Acc:0.3333
# Epoch: 40. Train Loss: 1.121. Test Loss: 1.099. Train Acc: 0.2941. Test Acc:0.3333
# Epoch: 50. Train Loss: 1.104. Test Loss: 1.099. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 60. Train Loss: 1.113. Test Loss: 1.098. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 70. Train Loss: 1.084. Test Loss: 1.098. Train Acc: 0.4118. Test Acc:0.3333
# Epoch: 80. Train Loss: 1.096. Test Loss: 1.097. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 90. Train Loss: 1.105. Test Loss: 1.097. Train Acc: 0.2745. Test Acc:0.3333
# Epoch: 100. Train Loss: 1.096. Test Loss: 1.097. Train Acc: 0.3725. Test Acc:0.3333
# Epoch: 110. Train Loss: 1.094. Test Loss: 1.097. Train Acc: 0.3529. Test Acc:0.3333
# Epoch: 120. Train Loss: 1.102. Test Loss: 1.096. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 130. Train Loss: 1.085. Test Loss: 1.095. Train Acc: 0.4902. Test Acc:0.3333
# Epoch: 140. Train Loss: 1.074. Test Loss: 1.094. Train Acc: 0.5098. Test Acc:0.3333
# Epoch: 150. Train Loss: 1.111. Test Loss: 1.092. Train Acc: 0.2941. Test Acc:0.3333
# Epoch: 160. Train Loss: 1.092. Test Loss: 1.089. Train Acc: 0.3333. Test Acc:0.3333
# Epoch: 170. Train Loss: 1.089. Test Loss: 1.085. Train Acc: 0.4118. Test Acc:0.3636
# Epoch: 180. Train Loss: 1.097. Test Loss: 1.081. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 190. Train Loss: 1.071. Test Loss: 1.081. Train Acc: 0.5098. Test Acc:0.3939
# Epoch: 200. Train Loss: 1.072. Test Loss: 1.075. Train Acc: 0.4118. Test Acc:0.3939
# Epoch: 210. Train Loss: 1.018. Test Loss: 1.054. Train Acc: 0.5882. Test Acc:0.4242
# Epoch: 220. Train Loss: 1.028. Test Loss: 1.055. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 230. Train Loss: 0.9632. Test Loss: 1.03. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 240. Train Loss: 0.9483. Test Loss: 1.02. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 250. Train Loss: 0.891. Test Loss: 1.022. Train Acc: 0.5882. Test Acc:0.3939
# Epoch: 260. Train Loss: 0.8651. Test Loss: 1.017. Train Acc: 0.6667. Test Acc:0.4848
# Epoch: 270. Train Loss: 0.8119. Test Loss: 0.9645. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 280. Train Loss: 0.869. Test Loss: 0.9558. Train Acc: 0.5686. Test Acc:0.4848
# Epoch: 290. Train Loss: 0.7722. Test Loss: 0.9568. Train Acc: 0.7255. Test Acc:0.5152
# Epoch: 300. Train Loss: 0.6633. Test Loss: 0.9271. Train Acc: 0.7451. Test Acc:0.4545
# Epoch: 310. Train Loss: 0.6852. Test Loss: 0.8727. Train Acc: 0.7843. Test Acc:0.4545
# Epoch: 320. Train Loss: 0.6576. Test Loss: 0.9633. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 330. Train Loss: 0.6475. Test Loss: 0.9061. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 340. Train Loss: 0.6412. Test Loss: 0.9708. Train Acc: 0.7647. Test Acc:0.4242
# Epoch: 350. Train Loss: 0.5186. Test Loss: 1.006. Train Acc: 0.8627. Test Acc:0.4242
# Epoch: 360. Train Loss: 0.5854. Test Loss: 1.046. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 370. Train Loss: 0.5484. Test Loss: 0.9907. Train Acc: 0.7451. Test Acc:0.4242
# Epoch: 380. Train Loss: 0.509. Test Loss: 0.9941. Train Acc: 0.8235. Test Acc:0.3939
# Epoch: 390. Train Loss: 0.419. Test Loss: 1.072. Train Acc: 0.9216. Test Acc:0.4242
# Epoch: 400. Train Loss: 0.5122. Test Loss: 1.092. Train Acc: 0.7843. Test Acc:0.3939
# Epoch: 410. Train Loss: 0.4419. Test Loss: 1.053. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 420. Train Loss: 0.4434. Test Loss: 1.086. Train Acc: 0.8824. Test Acc:0.4242
# Epoch: 430. Train Loss: 0.4741. Test Loss: 1.168. Train Acc: 0.8039. Test Acc:0.3939
# Epoch: 440. Train Loss: 0.4086. Test Loss: 1.039. Train Acc: 0.902. Test Acc:0.4242
# Epoch: 450. Train Loss: 0.4538. Test Loss: 1.135. Train Acc: 0.7843. Test Acc:0.4242
# Epoch: 460. Train Loss: 0.4184. Test Loss: 1.19. Train Acc: 0.8235. Test Acc:0.4242
# Epoch: 470. Train Loss: 0.411. Test Loss: 1.14. Train Acc: 0.8431. Test Acc:0.4242
# Epoch: 480. Train Loss: 0.4273. Test Loss: 0.996. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 490. Train Loss: 0.4017. Test Loss: 1.011. Train Acc: 0.8235. Test Acc:0.4848
# Epoch: 500. Train Loss: 0.3768. Test Loss: 1.209. Train Acc: 0.8627. Test Acc:0.3939
# Epoch: 510. Train Loss: 0.3863. Test Loss: 1.207. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 520. Train Loss: 0.4275. Test Loss: 1.319. Train Acc: 0.8431. Test Acc:0.3939
# Epoch: 530. Train Loss: 0.3271. Test Loss: 1.282. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 540. Train Loss: 0.3754. Test Loss: 1.275. Train Acc: 0.9216. Test Acc:0.3939
# Epoch: 550. Train Loss: 0.3572. Test Loss: 1.295. Train Acc: 0.9216. Test Acc:0.3939
# Epoch: 560. Train Loss: 0.3344. Test Loss: 1.343. Train Acc: 0.8431. Test Acc:0.3939
# Epoch: 570. Train Loss: 0.3321. Test Loss: 1.148. Train Acc: 0.902. Test Acc:0.4545
# Epoch: 580. Train Loss: 0.3171. Test Loss: 1.165. Train Acc: 0.902. Test Acc:0.4545
# Epoch: 590. Train Loss: 0.3769. Test Loss: 1.529. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 600. Train Loss: 0.2861. Test Loss: 1.491. Train Acc: 0.9412. Test Acc:0.3939
# Epoch: 610. Train Loss: 0.3189. Test Loss: 1.432. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 620. Train Loss: 0.3248. Test Loss: 1.334. Train Acc: 0.902. Test Acc:0.4242
# Epoch: 630. Train Loss: 0.249. Test Loss: 1.373. Train Acc: 0.9608. Test Acc:0.3939
# Epoch: 640. Train Loss: 0.2698. Test Loss: 1.372. Train Acc: 0.902. Test Acc:0.3939
# Epoch: 650. Train Loss: 0.3895. Test Loss: 1.335. Train Acc: 0.8039. Test Acc:0.4848
# Epoch: 660. Train Loss: 0.2482. Test Loss: 1.371. Train Acc: 0.902. Test Acc:0.4545
# Epoch: 670. Train Loss: 0.2885. Test Loss: 1.397. Train Acc: 0.8824. Test Acc:0.4848
# Epoch: 680. Train Loss: 0.2476. Test Loss: 1.34. Train Acc: 0.9608. Test Acc:0.4848
# Epoch: 690. Train Loss: 0.2817. Test Loss: 1.353. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 700. Train Loss: 0.2926. Test Loss: 1.295. Train Acc: 0.902. Test Acc:0.4848
# Epoch: 710. Train Loss: 0.2433. Test Loss: 1.458. Train Acc: 0.902. Test Acc:0.4848
# Epoch: 720. Train Loss: 0.2665. Test Loss: 1.489. Train Acc: 0.902. Test Acc:0.4545
# Epoch: 730. Train Loss: 0.2539. Test Loss: 1.541. Train Acc: 0.9216. Test Acc:0.4545
# Epoch: 740. Train Loss: 0.2057. Test Loss: 1.664. Train Acc: 0.9804. Test Acc:0.3939
# Epoch: 750. Train Loss: 0.3129. Test Loss: 1.496. Train Acc: 0.8627. Test Acc:0.4545
# Epoch: 760. Train Loss: 0.2476. Test Loss: 1.654. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 770. Train Loss: 0.25. Test Loss: 1.635. Train Acc: 0.8824. Test Acc:0.3939
# Epoch: 780. Train Loss: 0.2484. Test Loss: 1.415. Train Acc: 0.902. Test Acc:0.4545
# Epoch: 790. Train Loss: 0.2507. Test Loss: 1.435. Train Acc: 0.9216. Test Acc:0.4848
# Epoch: 800. Train Loss: 0.2026. Test Loss: 1.407. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 810. Train Loss: 0.2093. Test Loss: 1.411. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 820. Train Loss: 0.3446. Test Loss: 1.589. Train Acc: 0.8627. Test Acc:0.4242
# Epoch: 830. Train Loss: 0.2012. Test Loss: 1.519. Train Acc: 0.9412. Test Acc:0.4848
# Epoch: 840. Train Loss: 0.205. Test Loss: 1.542. Train Acc: 1.0. Test Acc:0.4545
# Epoch: 850. Train Loss: 0.2403. Test Loss: 1.566. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 860. Train Loss: 0.2527. Test Loss: 1.641. Train Acc: 0.8824. Test Acc:0.4545
# Epoch: 870. Train Loss: 0.1697. Test Loss: 1.543. Train Acc: 0.9804. Test Acc:0.5152
# Epoch: 880. Train Loss: 0.3403. Test Loss: 1.46. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 890. Train Loss: 0.1505. Test Loss: 1.528. Train Acc: 0.9804. Test Acc:0.5152
# Epoch: 900. Train Loss: 0.1993. Test Loss: 1.494. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 910. Train Loss: 0.2886. Test Loss: 1.535. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.1801. Test Loss: 1.665. Train Acc: 0.9608. Test Acc:0.4848
# Epoch: 930. Train Loss: 0.2061. Test Loss: 1.681. Train Acc: 0.9216. Test Acc:0.4545
# Epoch: 940. Train Loss: 0.3023. Test Loss: 1.608. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 950. Train Loss: 0.2127. Test Loss: 1.684. Train Acc: 0.9804. Test Acc:0.4545
# Epoch: 960. Train Loss: 0.3268. Test Loss: 1.447. Train Acc: 0.9216. Test Acc:0.4545
# Epoch: 970. Train Loss: 0.1926. Test Loss: 1.568. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.2106. Test Loss: 1.643. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 990. Train Loss: 0.1254. Test Loss: 1.565. Train Acc: 0.9804. Test Acc:0.5152
# Epoch: 1000. Train Loss: 0.2443. Test Loss: 1.53. Train Acc: 0.8824. Test Acc:0.5152
# LangIdCNN_MeanStd_FCD using retrained-wav2vec_features-z on fold#1. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14            [10, 18]               0               0
#          Linear-15             [10, 3]              57              57
# =======================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.149. Test Loss: 1.085. Train Acc: 0.2549. Test Acc:0.4848
# Epoch: 20. Train Loss: 1.134. Test Loss: 1.099. Train Acc: 0.2745. Test Acc:0.2727
# Epoch: 30. Train Loss: 1.11. Test Loss: 1.117. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 40. Train Loss: 1.105. Test Loss: 1.135. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 50. Train Loss: 1.09. Test Loss: 1.154. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 60. Train Loss: 1.082. Test Loss: 1.171. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 70. Train Loss: 1.081. Test Loss: 1.182. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 80. Train Loss: 1.094. Test Loss: 1.193. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 90. Train Loss: 1.106. Test Loss: 1.197. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 100. Train Loss: 1.089. Test Loss: 1.195. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 110. Train Loss: 1.079. Test Loss: 1.193. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 120. Train Loss: 1.08. Test Loss: 1.191. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 130. Train Loss: 1.057. Test Loss: 1.187. Train Acc: 0.4902. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.055. Test Loss: 1.177. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 150. Train Loss: 1.099. Test Loss: 1.18. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 160. Train Loss: 1.063. Test Loss: 1.188. Train Acc: 0.451. Test Acc:0.3333
# Epoch: 170. Train Loss: 1.043. Test Loss: 1.189. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 180. Train Loss: 1.047. Test Loss: 1.181. Train Acc: 0.3922. Test Acc:0.303
# Epoch: 190. Train Loss: 1.045. Test Loss: 1.175. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 200. Train Loss: 1.057. Test Loss: 1.154. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 210. Train Loss: 1.004. Test Loss: 1.15. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 220. Train Loss: 0.993. Test Loss: 1.112. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 230. Train Loss: 0.9344. Test Loss: 1.12. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 240. Train Loss: 0.9411. Test Loss: 1.054. Train Acc: 0.5294. Test Acc:0.3636
# Epoch: 250. Train Loss: 0.8755. Test Loss: 1.02. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 260. Train Loss: 0.8048. Test Loss: 1.038. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 270. Train Loss: 0.7905. Test Loss: 1.044. Train Acc: 0.6275. Test Acc:0.4242
# Epoch: 280. Train Loss: 0.7589. Test Loss: 0.98. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 290. Train Loss: 0.6941. Test Loss: 0.9356. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 300. Train Loss: 0.6531. Test Loss: 0.8913. Train Acc: 0.8235. Test Acc:0.697
# Epoch: 310. Train Loss: 0.664. Test Loss: 0.8941. Train Acc: 0.7255. Test Acc:0.697
# Epoch: 320. Train Loss: 0.6282. Test Loss: 0.9643. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 330. Train Loss: 0.6319. Test Loss: 0.9977. Train Acc: 0.7059. Test Acc:0.697
# Epoch: 340. Train Loss: 0.5972. Test Loss: 0.9702. Train Acc: 0.7451. Test Acc:0.7273
# Epoch: 350. Train Loss: 0.5058. Test Loss: 1.004. Train Acc: 0.7843. Test Acc:0.7273
# Epoch: 360. Train Loss: 0.5606. Test Loss: 0.9858. Train Acc: 0.7059. Test Acc:0.7879
# Epoch: 370. Train Loss: 0.4991. Test Loss: 1.043. Train Acc: 0.7451. Test Acc:0.7576
# Epoch: 380. Train Loss: 0.4768. Test Loss: 1.104. Train Acc: 0.8039. Test Acc:0.7273
# Epoch: 390. Train Loss: 0.3659. Test Loss: 1.148. Train Acc: 0.8431. Test Acc:0.7273
# Epoch: 400. Train Loss: 0.4724. Test Loss: 1.107. Train Acc: 0.8039. Test Acc:0.7273
# Epoch: 410. Train Loss: 0.4077. Test Loss: 1.063. Train Acc: 0.8431. Test Acc:0.7576
# Epoch: 420. Train Loss: 0.391. Test Loss: 1.104. Train Acc: 0.8235. Test Acc:0.7879
# Epoch: 430. Train Loss: 0.4302. Test Loss: 1.138. Train Acc: 0.8235. Test Acc:0.8182
# Epoch: 440. Train Loss: 0.4492. Test Loss: 1.199. Train Acc: 0.8039. Test Acc:0.8182
# Epoch: 450. Train Loss: 0.3682. Test Loss: 1.123. Train Acc: 0.8824. Test Acc:0.7273
# Epoch: 460. Train Loss: 0.3741. Test Loss: 1.167. Train Acc: 0.8627. Test Acc:0.7273
# Epoch: 470. Train Loss: 0.3635. Test Loss: 1.204. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 480. Train Loss: 0.2818. Test Loss: 1.248. Train Acc: 0.9216. Test Acc:0.8485
# Epoch: 490. Train Loss: 0.2728. Test Loss: 1.249. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 500. Train Loss: 0.3107. Test Loss: 1.222. Train Acc: 0.8235. Test Acc:0.7879
# Epoch: 510. Train Loss: 0.316. Test Loss: 1.234. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 520. Train Loss: 0.3565. Test Loss: 1.259. Train Acc: 0.8431. Test Acc:0.8182
# Epoch: 530. Train Loss: 0.297. Test Loss: 1.31. Train Acc: 0.8824. Test Acc:0.7879
# Epoch: 540. Train Loss: 0.2861. Test Loss: 1.341. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 550. Train Loss: 0.2615. Test Loss: 1.317. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 560. Train Loss: 0.2749. Test Loss: 1.352. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 570. Train Loss: 0.2411. Test Loss: 1.447. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 580. Train Loss: 0.2025. Test Loss: 1.517. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 590. Train Loss: 0.3051. Test Loss: 1.468. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 600. Train Loss: 0.248. Test Loss: 1.541. Train Acc: 0.8824. Test Acc:0.8182
# Epoch: 610. Train Loss: 0.2386. Test Loss: 1.541. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 620. Train Loss: 0.3071. Test Loss: 1.537. Train Acc: 0.8824. Test Acc:0.8182
# Epoch: 630. Train Loss: 0.1973. Test Loss: 1.639. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 640. Train Loss: 0.1769. Test Loss: 1.551. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 650. Train Loss: 0.2648. Test Loss: 1.52. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 660. Train Loss: 0.1634. Test Loss: 1.532. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 670. Train Loss: 0.2461. Test Loss: 1.556. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 680. Train Loss: 0.2015. Test Loss: 1.589. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 690. Train Loss: 0.2093. Test Loss: 1.564. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 700. Train Loss: 0.3134. Test Loss: 1.641. Train Acc: 0.8431. Test Acc:0.8182
# Epoch: 710. Train Loss: 0.1931. Test Loss: 1.634. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 720. Train Loss: 0.2544. Test Loss: 1.633. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 730. Train Loss: 0.1716. Test Loss: 1.668. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 740. Train Loss: 0.1698. Test Loss: 1.823. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 750. Train Loss: 0.1814. Test Loss: 1.908. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 760. Train Loss: 0.1559. Test Loss: 1.827. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 770. Train Loss: 0.1618. Test Loss: 1.927. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 780. Train Loss: 0.1651. Test Loss: 1.92. Train Acc: 0.9412. Test Acc:0.7879
# Epoch: 790. Train Loss: 0.1323. Test Loss: 1.876. Train Acc: 1.0. Test Acc:0.8182
# Epoch: 800. Train Loss: 0.07717. Test Loss: 1.905. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 810. Train Loss: 0.1665. Test Loss: 2.019. Train Acc: 0.9412. Test Acc:0.8182
# Epoch: 820. Train Loss: 0.2236. Test Loss: 1.944. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 830. Train Loss: 0.1529. Test Loss: 1.977. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 840. Train Loss: 0.1837. Test Loss: 2.045. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 850. Train Loss: 0.1462. Test Loss: 2.017. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 860. Train Loss: 0.1671. Test Loss: 1.926. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 870. Train Loss: 0.143. Test Loss: 1.912. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 880. Train Loss: 0.17. Test Loss: 1.933. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 890. Train Loss: 0.1106. Test Loss: 2.043. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 900. Train Loss: 0.131. Test Loss: 2.118. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 910. Train Loss: 0.1045. Test Loss: 2.055. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 920. Train Loss: 0.136. Test Loss: 2.191. Train Acc: 0.9608. Test Acc:0.8182
# Epoch: 930. Train Loss: 0.169. Test Loss: 2.19. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 940. Train Loss: 0.1664. Test Loss: 2.141. Train Acc: 0.9216. Test Acc:0.8182
# Epoch: 950. Train Loss: 0.1057. Test Loss: 2.237. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 960. Train Loss: 0.2096. Test Loss: 2.459. Train Acc: 0.9608. Test Acc:0.7879
# Epoch: 970. Train Loss: 0.08475. Test Loss: 2.333. Train Acc: 1.0. Test Acc:0.8182
# Epoch: 980. Train Loss: 0.2103. Test Loss: 2.146. Train Acc: 0.902. Test Acc:0.8182
# Epoch: 990. Train Loss: 0.1308. Test Loss: 2.277. Train Acc: 0.9804. Test Acc:0.8182
# Epoch: 1000. Train Loss: 0.1306. Test Loss: 2.324. Train Acc: 0.9608. Test Acc:0.8182
# LangIdCNN_MeanStd_FCD using wav2vec_features-z on fold#1. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14            [10, 18]               0               0
#          Linear-15             [10, 3]              57              57
# =======================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.152. Test Loss: 1.083. Train Acc: 0.2549. Test Acc:0.4848
# Epoch: 20. Train Loss: 1.136. Test Loss: 1.097. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 30. Train Loss: 1.113. Test Loss: 1.113. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 40. Train Loss: 1.108. Test Loss: 1.129. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 50. Train Loss: 1.093. Test Loss: 1.147. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 60. Train Loss: 1.088. Test Loss: 1.163. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 70. Train Loss: 1.082. Test Loss: 1.176. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 80. Train Loss: 1.096. Test Loss: 1.187. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 90. Train Loss: 1.11. Test Loss: 1.194. Train Acc: 0.2549. Test Acc:0.2727
# Epoch: 100. Train Loss: 1.09. Test Loss: 1.194. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 110. Train Loss: 1.083. Test Loss: 1.193. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 120. Train Loss: 1.084. Test Loss: 1.192. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 130. Train Loss: 1.063. Test Loss: 1.189. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.063. Test Loss: 1.181. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 150. Train Loss: 1.105. Test Loss: 1.18. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 160. Train Loss: 1.078. Test Loss: 1.184. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 170. Train Loss: 1.064. Test Loss: 1.187. Train Acc: 0.4902. Test Acc:0.2727
# Epoch: 180. Train Loss: 1.078. Test Loss: 1.189. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 190. Train Loss: 1.078. Test Loss: 1.187. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 200. Train Loss: 1.098. Test Loss: 1.184. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 210. Train Loss: 1.068. Test Loss: 1.178. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 220. Train Loss: 1.089. Test Loss: 1.184. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 230. Train Loss: 1.052. Test Loss: 1.183. Train Acc: 0.3922. Test Acc:0.3939
# Epoch: 240. Train Loss: 1.06. Test Loss: 1.178. Train Acc: 0.4706. Test Acc:0.3939
# Epoch: 250. Train Loss: 1.057. Test Loss: 1.17. Train Acc: 0.4118. Test Acc:0.3939
# Epoch: 260. Train Loss: 1.034. Test Loss: 1.168. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 270. Train Loss: 1.018. Test Loss: 1.165. Train Acc: 0.451. Test Acc:0.3636
# Epoch: 280. Train Loss: 1.02. Test Loss: 1.153. Train Acc: 0.5098. Test Acc:0.3636
# Epoch: 290. Train Loss: 0.9621. Test Loss: 1.151. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 300. Train Loss: 0.9566. Test Loss: 1.108. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 310. Train Loss: 0.9477. Test Loss: 1.104. Train Acc: 0.6078. Test Acc:0.3333
# Epoch: 320. Train Loss: 0.9045. Test Loss: 1.105. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 330. Train Loss: 0.8981. Test Loss: 1.139. Train Acc: 0.5686. Test Acc:0.3636
# Epoch: 340. Train Loss: 0.8441. Test Loss: 1.095. Train Acc: 0.6471. Test Acc:0.303
# Epoch: 350. Train Loss: 0.7778. Test Loss: 1.058. Train Acc: 0.7451. Test Acc:0.3939
# Epoch: 360. Train Loss: 0.8174. Test Loss: 1.002. Train Acc: 0.549. Test Acc:0.4545
# Epoch: 370. Train Loss: 0.7311. Test Loss: 1.008. Train Acc: 0.6863. Test Acc:0.4848
# Epoch: 380. Train Loss: 0.6972. Test Loss: 1.006. Train Acc: 0.7451. Test Acc:0.5152
# Epoch: 390. Train Loss: 0.601. Test Loss: 0.9879. Train Acc: 0.7843. Test Acc:0.5758
# Epoch: 400. Train Loss: 0.6613. Test Loss: 0.9469. Train Acc: 0.7843. Test Acc:0.6061
# Epoch: 410. Train Loss: 0.6387. Test Loss: 0.9269. Train Acc: 0.6667. Test Acc:0.6364
# Epoch: 420. Train Loss: 0.5961. Test Loss: 0.9454. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 430. Train Loss: 0.6269. Test Loss: 0.9207. Train Acc: 0.7451. Test Acc:0.6061
# Epoch: 440. Train Loss: 0.638. Test Loss: 0.9442. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 450. Train Loss: 0.5684. Test Loss: 0.9364. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 460. Train Loss: 0.5925. Test Loss: 0.9692. Train Acc: 0.7843. Test Acc:0.6061
# Epoch: 470. Train Loss: 0.5649. Test Loss: 1.003. Train Acc: 0.6863. Test Acc:0.6061
# Epoch: 480. Train Loss: 0.4395. Test Loss: 0.9934. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 490. Train Loss: 0.4103. Test Loss: 1.068. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 500. Train Loss: 0.4936. Test Loss: 0.9854. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 510. Train Loss: 0.5175. Test Loss: 0.9738. Train Acc: 0.7843. Test Acc:0.5758
# Epoch: 520. Train Loss: 0.5397. Test Loss: 0.9415. Train Acc: 0.8235. Test Acc:0.6061
# Epoch: 530. Train Loss: 0.4798. Test Loss: 0.9564. Train Acc: 0.7647. Test Acc:0.5758
# Epoch: 540. Train Loss: 0.4463. Test Loss: 0.9713. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 550. Train Loss: 0.4097. Test Loss: 0.9658. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 560. Train Loss: 0.4493. Test Loss: 0.9731. Train Acc: 0.8627. Test Acc:0.6061
# Epoch: 570. Train Loss: 0.4222. Test Loss: 0.988. Train Acc: 0.8627. Test Acc:0.6061
# Epoch: 580. Train Loss: 0.4097. Test Loss: 1.062. Train Acc: 0.902. Test Acc:0.6364
# Epoch: 590. Train Loss: 0.3785. Test Loss: 1.003. Train Acc: 0.8235. Test Acc:0.6061
# Epoch: 600. Train Loss: 0.3618. Test Loss: 1.032. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 610. Train Loss: 0.4222. Test Loss: 1.038. Train Acc: 0.7843. Test Acc:0.5758
# Epoch: 620. Train Loss: 0.4603. Test Loss: 1.026. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 630. Train Loss: 0.3396. Test Loss: 1.041. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 640. Train Loss: 0.348. Test Loss: 1.036. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 650. Train Loss: 0.4921. Test Loss: 1.066. Train Acc: 0.7647. Test Acc:0.5758
# Epoch: 660. Train Loss: 0.2807. Test Loss: 1.046. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 670. Train Loss: 0.3534. Test Loss: 1.045. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 680. Train Loss: 0.369. Test Loss: 1.064. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 690. Train Loss: 0.3767. Test Loss: 1.083. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 700. Train Loss: 0.3999. Test Loss: 1.1. Train Acc: 0.7843. Test Acc:0.6061
# Epoch: 710. Train Loss: 0.3737. Test Loss: 1.094. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 720. Train Loss: 0.4016. Test Loss: 1.097. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 730. Train Loss: 0.3176. Test Loss: 1.115. Train Acc: 0.902. Test Acc:0.6364
# Epoch: 740. Train Loss: 0.3256. Test Loss: 1.138. Train Acc: 0.8627. Test Acc:0.6061
# Epoch: 750. Train Loss: 0.295. Test Loss: 1.173. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 760. Train Loss: 0.3204. Test Loss: 1.175. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 770. Train Loss: 0.2936. Test Loss: 1.207. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 780. Train Loss: 0.3477. Test Loss: 1.218. Train Acc: 0.8235. Test Acc:0.6061
# Epoch: 790. Train Loss: 0.2674. Test Loss: 1.17. Train Acc: 0.902. Test Acc:0.6364
# Epoch: 800. Train Loss: 0.1561. Test Loss: 1.214. Train Acc: 1.0. Test Acc:0.6061
# Epoch: 810. Train Loss: 0.2657. Test Loss: 1.233. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 820. Train Loss: 0.3486. Test Loss: 1.218. Train Acc: 0.8824. Test Acc:0.6364
# Epoch: 830. Train Loss: 0.2172. Test Loss: 1.224. Train Acc: 0.9412. Test Acc:0.6364
# Epoch: 840. Train Loss: 0.279. Test Loss: 1.232. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 850. Train Loss: 0.2653. Test Loss: 1.235. Train Acc: 0.9216. Test Acc:0.6364
# Epoch: 860. Train Loss: 0.252. Test Loss: 1.24. Train Acc: 0.9608. Test Acc:0.6364
# Epoch: 870. Train Loss: 0.2498. Test Loss: 1.251. Train Acc: 0.8824. Test Acc:0.6364
# Epoch: 880. Train Loss: 0.2873. Test Loss: 1.258. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 890. Train Loss: 0.2189. Test Loss: 1.269. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 900. Train Loss: 0.2479. Test Loss: 1.282. Train Acc: 0.8824. Test Acc:0.6061
# Epoch: 910. Train Loss: 0.2177. Test Loss: 1.276. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.2493. Test Loss: 1.276. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 930. Train Loss: 0.2543. Test Loss: 1.283. Train Acc: 0.9216. Test Acc:0.5152
# Epoch: 940. Train Loss: 0.2646. Test Loss: 1.295. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 950. Train Loss: 0.2368. Test Loss: 1.311. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 960. Train Loss: 0.3208. Test Loss: 1.328. Train Acc: 0.8824. Test Acc:0.6061
# Epoch: 970. Train Loss: 0.1992. Test Loss: 1.325. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.2376. Test Loss: 1.332. Train Acc: 0.902. Test Acc:0.4848
# Epoch: 990. Train Loss: 0.2226. Test Loss: 1.359. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 1000. Train Loss: 0.2111. Test Loss: 1.39. Train Acc: 0.9412. Test Acc:0.6364
# LangIdCNN_MeanStd_FCD using retrained-wav2vec_features-z on fold#2. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14            [10, 18]               0               0
#          Linear-15             [10, 3]              57              57
# =======================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.113. Test Loss: 1.099. Train Acc: 0.3333. Test Acc:0.303
# Epoch: 20. Train Loss: 1.103. Test Loss: 1.099. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 30. Train Loss: 1.104. Test Loss: 1.099. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 40. Train Loss: 1.111. Test Loss: 1.102. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 50. Train Loss: 1.093. Test Loss: 1.105. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 60. Train Loss: 1.1. Test Loss: 1.107. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 70. Train Loss: 1.075. Test Loss: 1.11. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 80. Train Loss: 1.092. Test Loss: 1.111. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 90. Train Loss: 1.109. Test Loss: 1.111. Train Acc: 0.2549. Test Acc:0.2727
# Epoch: 100. Train Loss: 1.082. Test Loss: 1.109. Train Acc: 0.4706. Test Acc:0.2727
# Epoch: 110. Train Loss: 1.086. Test Loss: 1.107. Train Acc: 0.451. Test Acc:0.2727
# Epoch: 120. Train Loss: 1.09. Test Loss: 1.107. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 130. Train Loss: 1.062. Test Loss: 1.104. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.049. Test Loss: 1.103. Train Acc: 0.5098. Test Acc:0.2727
# Epoch: 150. Train Loss: 1.087. Test Loss: 1.099. Train Acc: 0.3137. Test Acc:0.2727
# Epoch: 160. Train Loss: 1.061. Test Loss: 1.095. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 170. Train Loss: 1.06. Test Loss: 1.095. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 180. Train Loss: 1.056. Test Loss: 1.082. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 190. Train Loss: 1.008. Test Loss: 1.083. Train Acc: 0.5098. Test Acc:0.4848
# Epoch: 200. Train Loss: 1.013. Test Loss: 1.067. Train Acc: 0.4902. Test Acc:0.4545
# Epoch: 210. Train Loss: 0.9725. Test Loss: 1.039. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 220. Train Loss: 0.9312. Test Loss: 1.025. Train Acc: 0.5686. Test Acc:0.4242
# Epoch: 230. Train Loss: 0.8489. Test Loss: 0.9912. Train Acc: 0.7059. Test Acc:0.4242
# Epoch: 240. Train Loss: 0.8729. Test Loss: 0.9692. Train Acc: 0.6667. Test Acc:0.4242
# Epoch: 250. Train Loss: 0.7931. Test Loss: 0.9416. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 260. Train Loss: 0.7358. Test Loss: 0.9279. Train Acc: 0.6471. Test Acc:0.4242
# Epoch: 270. Train Loss: 0.6574. Test Loss: 0.9197. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 280. Train Loss: 0.6964. Test Loss: 0.9137. Train Acc: 0.6078. Test Acc:0.4545
# Epoch: 290. Train Loss: 0.6375. Test Loss: 0.9225. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 300. Train Loss: 0.5518. Test Loss: 0.9308. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 310. Train Loss: 0.5956. Test Loss: 0.951. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 320. Train Loss: 0.5583. Test Loss: 0.9399. Train Acc: 0.5882. Test Acc:0.4545
# Epoch: 330. Train Loss: 0.565. Test Loss: 0.976. Train Acc: 0.6471. Test Acc:0.4545
# Epoch: 340. Train Loss: 0.5175. Test Loss: 0.9947. Train Acc: 0.8039. Test Acc:0.4545
# Epoch: 350. Train Loss: 0.5056. Test Loss: 0.9807. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 360. Train Loss: 0.516. Test Loss: 1.026. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 370. Train Loss: 0.5324. Test Loss: 1.092. Train Acc: 0.6667. Test Acc:0.4545
# Epoch: 380. Train Loss: 0.4915. Test Loss: 1.038. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 390. Train Loss: 0.4555. Test Loss: 1.028. Train Acc: 0.7647. Test Acc:0.4545
# Epoch: 400. Train Loss: 0.4949. Test Loss: 1.029. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 410. Train Loss: 0.4963. Test Loss: 1.08. Train Acc: 0.6275. Test Acc:0.4545
# Epoch: 420. Train Loss: 0.4953. Test Loss: 1.098. Train Acc: 0.6863. Test Acc:0.4545
# Epoch: 430. Train Loss: 0.4676. Test Loss: 1.132. Train Acc: 0.8235. Test Acc:0.4545
# Epoch: 440. Train Loss: 0.4763. Test Loss: 1.147. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 450. Train Loss: 0.4614. Test Loss: 1.115. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 460. Train Loss: 0.4341. Test Loss: 1.196. Train Acc: 0.7451. Test Acc:0.6061
# Epoch: 470. Train Loss: 0.4827. Test Loss: 1.097. Train Acc: 0.6667. Test Acc:0.5758
# Epoch: 480. Train Loss: 0.4574. Test Loss: 1.16. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 490. Train Loss: 0.4786. Test Loss: 1.182. Train Acc: 0.7255. Test Acc:0.5758
# Epoch: 500. Train Loss: 0.4691. Test Loss: 1.181. Train Acc: 0.6863. Test Acc:0.6364
# Epoch: 510. Train Loss: 0.452. Test Loss: 1.169. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 520. Train Loss: 0.4845. Test Loss: 1.182. Train Acc: 0.6471. Test Acc:0.6364
# Epoch: 530. Train Loss: 0.4357. Test Loss: 1.167. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 540. Train Loss: 0.4783. Test Loss: 1.242. Train Acc: 0.7059. Test Acc:0.6364
# Epoch: 550. Train Loss: 0.4373. Test Loss: 1.213. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 560. Train Loss: 0.4697. Test Loss: 1.233. Train Acc: 0.7255. Test Acc:0.6364
# Epoch: 570. Train Loss: 0.4301. Test Loss: 1.257. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 580. Train Loss: 0.4337. Test Loss: 1.249. Train Acc: 0.7451. Test Acc:0.6364
# Epoch: 590. Train Loss: 0.4026. Test Loss: 1.273. Train Acc: 0.7843. Test Acc:0.6364
# Epoch: 600. Train Loss: 0.4082. Test Loss: 1.289. Train Acc: 0.7647. Test Acc:0.6364
# Epoch: 610. Train Loss: 0.4186. Test Loss: 1.306. Train Acc: 0.7843. Test Acc:0.6667
# Epoch: 620. Train Loss: 0.4707. Test Loss: 1.406. Train Acc: 0.7451. Test Acc:0.697
# Epoch: 630. Train Loss: 0.411. Test Loss: 1.363. Train Acc: 0.7255. Test Acc:0.6667
# Epoch: 640. Train Loss: 0.3583. Test Loss: 1.355. Train Acc: 0.8431. Test Acc:0.6061
# Epoch: 650. Train Loss: 0.3205. Test Loss: 1.395. Train Acc: 0.9216. Test Acc:0.6667
# Epoch: 660. Train Loss: 0.3605. Test Loss: 1.439. Train Acc: 0.7451. Test Acc:0.6667
# Epoch: 670. Train Loss: 0.3486. Test Loss: 1.528. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 680. Train Loss: 0.3744. Test Loss: 1.549. Train Acc: 0.8431. Test Acc:0.6364
# Epoch: 690. Train Loss: 0.2553. Test Loss: 1.539. Train Acc: 0.9412. Test Acc:0.6667
# Epoch: 700. Train Loss: 0.303. Test Loss: 1.594. Train Acc: 0.902. Test Acc:0.6667
# Epoch: 710. Train Loss: 0.3022. Test Loss: 1.647. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 720. Train Loss: 0.3553. Test Loss: 1.691. Train Acc: 0.8039. Test Acc:0.6667
# Epoch: 730. Train Loss: 0.2919. Test Loss: 1.743. Train Acc: 0.8627. Test Acc:0.6667
# Epoch: 740. Train Loss: 0.2832. Test Loss: 1.79. Train Acc: 0.8431. Test Acc:0.6667
# ...
# Epoch: 20. Train Loss: 1.088. Test Loss: 1.123. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 30. Train Loss: 1.094. Test Loss: 1.121. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 40. Train Loss: 1.101. Test Loss: 1.122. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 50. Train Loss: 1.094. Test Loss: 1.124. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 60. Train Loss: 1.093. Test Loss: 1.126. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 70. Train Loss: 1.064. Test Loss: 1.127. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 80. Train Loss: 1.078. Test Loss: 1.127. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 90. Train Loss: 1.084. Test Loss: 1.128. Train Acc: 0.3725. Test Acc:0.303
# Epoch: 100. Train Loss: 1.081. Test Loss: 1.13. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 110. Train Loss: 1.086. Test Loss: 1.129. Train Acc: 0.3529. Test Acc:0.303
# Epoch: 120. Train Loss: 1.087. Test Loss: 1.129. Train Acc: 0.4118. Test Acc:0.303
# Epoch: 130. Train Loss: 1.068. Test Loss: 1.13. Train Acc: 0.451. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.054. Test Loss: 1.133. Train Acc: 0.4706. Test Acc:0.303
# Epoch: 150. Train Loss: 1.09. Test Loss: 1.128. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 160. Train Loss: 1.074. Test Loss: 1.124. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 170. Train Loss: 1.07. Test Loss: 1.125. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 180. Train Loss: 1.066. Test Loss: 1.122. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 190. Train Loss: 1.045. Test Loss: 1.119. Train Acc: 0.5294. Test Acc:0.2727
# Epoch: 200. Train Loss: 1.04. Test Loss: 1.129. Train Acc: 0.4706. Test Acc:0.2424
# Epoch: 210. Train Loss: 0.9994. Test Loss: 1.071. Train Acc: 0.451. Test Acc:0.303
# Epoch: 220. Train Loss: 1.0. Test Loss: 1.093. Train Acc: 0.4902. Test Acc:0.303
# Epoch: 230. Train Loss: 0.9543. Test Loss: 1.065. Train Acc: 0.5686. Test Acc:0.2727
# Epoch: 240. Train Loss: 0.9398. Test Loss: 1.038. Train Acc: 0.549. Test Acc:0.2727
# Epoch: 250. Train Loss: 0.8596. Test Loss: 1.021. Train Acc: 0.5882. Test Acc:0.2424
# Epoch: 260. Train Loss: 0.8402. Test Loss: 0.9742. Train Acc: 0.5882. Test Acc:0.2727
# Epoch: 270. Train Loss: 0.7467. Test Loss: 0.9317. Train Acc: 0.7843. Test Acc:0.3939
# Epoch: 280. Train Loss: 0.8701. Test Loss: 0.9011. Train Acc: 0.5294. Test Acc:0.4848
# Epoch: 290. Train Loss: 0.7641. Test Loss: 0.8741. Train Acc: 0.6471. Test Acc:0.5455
# Epoch: 300. Train Loss: 0.6534. Test Loss: 0.8817. Train Acc: 0.7059. Test Acc:0.4545
# Epoch: 310. Train Loss: 0.715. Test Loss: 0.858. Train Acc: 0.6471. Test Acc:0.5758
# Epoch: 320. Train Loss: 0.6127. Test Loss: 0.8507. Train Acc: 0.6863. Test Acc:0.5455
# Epoch: 330. Train Loss: 0.6759. Test Loss: 0.8374. Train Acc: 0.6078. Test Acc:0.5758
# Epoch: 340. Train Loss: 0.6194. Test Loss: 0.8297. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 350. Train Loss: 0.5842. Test Loss: 0.8257. Train Acc: 0.7451. Test Acc:0.5758
# Epoch: 360. Train Loss: 0.6257. Test Loss: 0.8238. Train Acc: 0.7451. Test Acc:0.6061
# Epoch: 370. Train Loss: 0.5673. Test Loss: 0.8179. Train Acc: 0.7843. Test Acc:0.6061
# Epoch: 380. Train Loss: 0.6198. Test Loss: 0.8136. Train Acc: 0.7255. Test Acc:0.5758
# Epoch: 390. Train Loss: 0.5162. Test Loss: 0.8105. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 400. Train Loss: 0.5309. Test Loss: 0.839. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 410. Train Loss: 0.4484. Test Loss: 0.8283. Train Acc: 0.8235. Test Acc:0.5455
# Epoch: 420. Train Loss: 0.5441. Test Loss: 0.8666. Train Acc: 0.7255. Test Acc:0.5152
# Epoch: 430. Train Loss: 0.5831. Test Loss: 0.8579. Train Acc: 0.7059. Test Acc:0.5455
# Epoch: 440. Train Loss: 0.5515. Test Loss: 0.8516. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 450. Train Loss: 0.4489. Test Loss: 0.8718. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 460. Train Loss: 0.4778. Test Loss: 0.8657. Train Acc: 0.8235. Test Acc:0.5455
# Epoch: 470. Train Loss: 0.4401. Test Loss: 0.8445. Train Acc: 0.7647. Test Acc:0.5455
# Epoch: 480. Train Loss: 0.4291. Test Loss: 0.8144. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 490. Train Loss: 0.4033. Test Loss: 0.7961. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 500. Train Loss: 0.4004. Test Loss: 0.8368. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 510. Train Loss: 0.4373. Test Loss: 0.8451. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 520. Train Loss: 0.4684. Test Loss: 0.889. Train Acc: 0.8235. Test Acc:0.5455
# Epoch: 530. Train Loss: 0.4153. Test Loss: 0.8717. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 540. Train Loss: 0.5053. Test Loss: 0.842. Train Acc: 0.7843. Test Acc:0.5758
# Epoch: 550. Train Loss: 0.4184. Test Loss: 0.9476. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 560. Train Loss: 0.4464. Test Loss: 0.9595. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 570. Train Loss: 0.3966. Test Loss: 0.8444. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 580. Train Loss: 0.4721. Test Loss: 0.8089. Train Acc: 0.8235. Test Acc:0.6061
# Epoch: 590. Train Loss: 0.4117. Test Loss: 0.8358. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 600. Train Loss: 0.4204. Test Loss: 0.8272. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 610. Train Loss: 0.3933. Test Loss: 0.8788. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 620. Train Loss: 0.422. Test Loss: 0.8865. Train Acc: 0.8039. Test Acc:0.5758
# Epoch: 630. Train Loss: 0.3722. Test Loss: 0.9184. Train Acc: 0.8235. Test Acc:0.5758
# Epoch: 640. Train Loss: 0.2873. Test Loss: 0.9593. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 650. Train Loss: 0.3874. Test Loss: 1.056. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 660. Train Loss: 0.29. Test Loss: 1.027. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 670. Train Loss: 0.334. Test Loss: 0.9774. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 680. Train Loss: 0.3171. Test Loss: 0.9524. Train Acc: 0.902. Test Acc:0.6061
# Epoch: 690. Train Loss: 0.3361. Test Loss: 0.8894. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 700. Train Loss: 0.3238. Test Loss: 0.8839. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 710. Train Loss: 0.4264. Test Loss: 0.9416. Train Acc: 0.8431. Test Acc:0.5758
# Epoch: 720. Train Loss: 0.4263. Test Loss: 0.9433. Train Acc: 0.8039. Test Acc:0.5455
# Epoch: 730. Train Loss: 0.3013. Test Loss: 0.9977. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 740. Train Loss: 0.3591. Test Loss: 0.9753. Train Acc: 0.902. Test Acc:0.6061
# Epoch: 750. Train Loss: 0.3627. Test Loss: 0.9492. Train Acc: 0.902. Test Acc:0.5455
# Epoch: 760. Train Loss: 0.2703. Test Loss: 0.9607. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 770. Train Loss: 0.3416. Test Loss: 0.9818. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 780. Train Loss: 0.3211. Test Loss: 0.9593. Train Acc: 0.8431. Test Acc:0.5455
# Epoch: 790. Train Loss: 0.2243. Test Loss: 1.021. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 800. Train Loss: 0.2718. Test Loss: 1.004. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 810. Train Loss: 0.2854. Test Loss: 1.012. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 820. Train Loss: 0.2584. Test Loss: 1.171. Train Acc: 0.9412. Test Acc:0.5758
# Epoch: 830. Train Loss: 0.3094. Test Loss: 1.157. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 840. Train Loss: 0.2679. Test Loss: 1.104. Train Acc: 0.8627. Test Acc:0.5758
# Epoch: 850. Train Loss: 0.3389. Test Loss: 1.116. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 860. Train Loss: 0.2696. Test Loss: 1.227. Train Acc: 0.9216. Test Acc:0.5758
# Epoch: 870. Train Loss: 0.2098. Test Loss: 1.143. Train Acc: 0.9804. Test Acc:0.5455
# Epoch: 880. Train Loss: 0.2948. Test Loss: 1.076. Train Acc: 0.9216. Test Acc:0.4848
# Epoch: 890. Train Loss: 0.2261. Test Loss: 1.233. Train Acc: 0.9804. Test Acc:0.5758
# Epoch: 900. Train Loss: 0.2248. Test Loss: 1.188. Train Acc: 0.9216. Test Acc:0.5152
# Epoch: 910. Train Loss: 0.2344. Test Loss: 1.186. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 920. Train Loss: 0.2207. Test Loss: 1.232. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 930. Train Loss: 0.1947. Test Loss: 1.106. Train Acc: 0.9804. Test Acc:0.4848
# Epoch: 940. Train Loss: 0.2258. Test Loss: 1.165. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 950. Train Loss: 0.228. Test Loss: 1.254. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 960. Train Loss: 0.3668. Test Loss: 1.175. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 970. Train Loss: 0.2944. Test Loss: 1.275. Train Acc: 0.902. Test Acc:0.5152
# Epoch: 980. Train Loss: 0.2433. Test Loss: 1.489. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 990. Train Loss: 0.2067. Test Loss: 1.335. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 1000. Train Loss: 0.2504. Test Loss: 1.233. Train Acc: 0.902. Test Acc:0.5152
# LangIdCNN_MeanStd_FCD using retrained-wav2vec_features-z on fold#5. Contrastive: False
# -----------------------------------------------------------------------
#       Layer (type)        Output Shape         Param #     Tr. Param #
# =======================================================================
#           Conv1d-1       [10, 3, 2998]           1,539           1,539
#           Conv1d-2       [10, 1, 2996]              10              10
#          Dropout-3       [10, 1, 2996]               0               0
#        AvgPool1d-4       [10, 1, 1498]               0               0
#           Conv1d-5       [10, 3, 1496]              12              12
#          Dropout-6       [10, 3, 1496]               0               0
#        AvgPool1d-7        [10, 3, 748]               0               0
#           Conv1d-8        [10, 3, 746]              30              30
#          Dropout-9        [10, 3, 746]               0               0
#       AvgPool1d-10        [10, 3, 373]               0               0
#          Conv1d-11        [10, 3, 371]              30              30
#         Dropout-12        [10, 3, 371]               0               0
#       AvgPool1d-13        [10, 3, 185]               0               0
#         Dropout-14            [10, 18]               0               0
#          Linear-15             [10, 3]              57              57
# =======================================================================
# Total params: 1,678
# Trainable params: 1,678
# Non-trainable params: 0
# -----------------------------------------------------------------------
# Epoch: 10. Train Loss: 1.12. Test Loss: 1.104. Train Acc: 0.3137. Test Acc:0.3636
# Epoch: 20. Train Loss: 1.116. Test Loss: 1.106. Train Acc: 0.3333. Test Acc:0.2727
# Epoch: 30. Train Loss: 1.103. Test Loss: 1.11. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 40. Train Loss: 1.12. Test Loss: 1.114. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 50. Train Loss: 1.097. Test Loss: 1.117. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 60. Train Loss: 1.104. Test Loss: 1.119. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 70. Train Loss: 1.087. Test Loss: 1.118. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 80. Train Loss: 1.097. Test Loss: 1.116. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 90. Train Loss: 1.101. Test Loss: 1.115. Train Acc: 0.2941. Test Acc:0.2727
# Epoch: 100. Train Loss: 1.091. Test Loss: 1.115. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 110. Train Loss: 1.089. Test Loss: 1.115. Train Acc: 0.3922. Test Acc:0.2727
# Epoch: 120. Train Loss: 1.093. Test Loss: 1.114. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 130. Train Loss: 1.073. Test Loss: 1.112. Train Acc: 0.4314. Test Acc:0.2727
# Epoch: 140. Train Loss: 1.059. Test Loss: 1.109. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 150. Train Loss: 1.085. Test Loss: 1.108. Train Acc: 0.4118. Test Acc:0.2727
# Epoch: 160. Train Loss: 1.047. Test Loss: 1.103. Train Acc: 0.3725. Test Acc:0.2727
# Epoch: 170. Train Loss: 1.038. Test Loss: 1.089. Train Acc: 0.3529. Test Acc:0.2727
# Epoch: 180. Train Loss: 0.9988. Test Loss: 1.076. Train Acc: 0.4902. Test Acc:0.3939
# Epoch: 190. Train Loss: 0.9254. Test Loss: 1.053. Train Acc: 0.6078. Test Acc:0.3939
# Epoch: 200. Train Loss: 0.9318. Test Loss: 1.029. Train Acc: 0.5098. Test Acc:0.4242
# Epoch: 210. Train Loss: 0.82. Test Loss: 1.011. Train Acc: 0.6667. Test Acc:0.3636
# Epoch: 220. Train Loss: 0.7481. Test Loss: 0.9966. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 230. Train Loss: 0.6606. Test Loss: 0.9865. Train Acc: 0.7255. Test Acc:0.4848
# Epoch: 240. Train Loss: 0.6982. Test Loss: 0.9819. Train Acc: 0.7255. Test Acc:0.4545
# Epoch: 250. Train Loss: 0.626. Test Loss: 0.9894. Train Acc: 0.7255. Test Acc:0.4242
# Epoch: 260. Train Loss: 0.6163. Test Loss: 0.9977. Train Acc: 0.7059. Test Acc:0.5152
# Epoch: 270. Train Loss: 0.5495. Test Loss: 1.019. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 280. Train Loss: 0.6427. Test Loss: 1.039. Train Acc: 0.6667. Test Acc:0.5152
# Epoch: 290. Train Loss: 0.5399. Test Loss: 1.059. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 300. Train Loss: 0.4257. Test Loss: 1.084. Train Acc: 0.8824. Test Acc:0.5152
# Epoch: 310. Train Loss: 0.4975. Test Loss: 1.112. Train Acc: 0.8235. Test Acc:0.5152
# Epoch: 320. Train Loss: 0.4763. Test Loss: 1.162. Train Acc: 0.7843. Test Acc:0.5455
# Epoch: 330. Train Loss: 0.4778. Test Loss: 1.157. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 340. Train Loss: 0.495. Test Loss: 1.181. Train Acc: 0.8039. Test Acc:0.5152
# Epoch: 350. Train Loss: 0.3368. Test Loss: 1.218. Train Acc: 0.9412. Test Acc:0.5152
# Epoch: 360. Train Loss: 0.4004. Test Loss: 1.273. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 370. Train Loss: 0.3518. Test Loss: 1.323. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 380. Train Loss: 0.3365. Test Loss: 1.342. Train Acc: 0.9608. Test Acc:0.5152
# Epoch: 390. Train Loss: 0.2804. Test Loss: 1.375. Train Acc: 0.902. Test Acc:0.5758
# Epoch: 400. Train Loss: 0.3432. Test Loss: 1.399. Train Acc: 0.8627. Test Acc:0.5152
# Epoch: 410. Train Loss: 0.2868. Test Loss: 1.433. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 420. Train Loss: 0.296. Test Loss: 1.457. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 430. Train Loss: 0.364. Test Loss: 1.487. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 440. Train Loss: 0.2822. Test Loss: 1.512. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 450. Train Loss: 0.2658. Test Loss: 1.553. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 460. Train Loss: 0.3226. Test Loss: 1.571. Train Acc: 0.8824. Test Acc:0.5758
# Epoch: 470. Train Loss: 0.2682. Test Loss: 1.583. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 480. Train Loss: 0.2735. Test Loss: 1.631. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 490. Train Loss: 0.2816. Test Loss: 1.67. Train Acc: 0.8627. Test Acc:0.5455
# Epoch: 500. Train Loss: 0.2311. Test Loss: 1.717. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 510. Train Loss: 0.2306. Test Loss: 1.747. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 520. Train Loss: 0.2858. Test Loss: 1.781. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 530. Train Loss: 0.2201. Test Loss: 1.823. Train Acc: 0.9804. Test Acc:0.5758
# Epoch: 540. Train Loss: 0.2415. Test Loss: 1.839. Train Acc: 0.9216. Test Acc:0.5455
# Epoch: 550. Train Loss: 0.2583. Test Loss: 1.852. Train Acc: 0.8824. Test Acc:0.5455
# Epoch: 560. Train Loss: 0.2018. Test Loss: 1.849. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 570. Train Loss: 0.2139. Test Loss: 1.902. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 580. Train Loss: 0.1905. Test Loss: 1.919. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 590. Train Loss: 0.195. Test Loss: 1.928. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 600. Train Loss: 0.178. Test Loss: 1.969. Train Acc: 0.9804. Test Acc:0.6061
# Epoch: 610. Train Loss: 0.1782. Test Loss: 2.001. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 620. Train Loss: 0.1997. Test Loss: 2.001. Train Acc: 0.9608. Test Acc:0.5758
# Epoch: 630. Train Loss: 0.1764. Test Loss: 2.014. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 640. Train Loss: 0.1472. Test Loss: 2.032. Train Acc: 0.9804. Test Acc:0.5455
# Epoch: 650. Train Loss: 0.205. Test Loss: 2.051. Train Acc: 0.9412. Test Acc:0.5455
# Epoch: 660. Train Loss: 0.1428. Test Loss: 2.092. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 670. Train Loss: 0.2159. Test Loss: 2.154. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 680. Train Loss: 0.1316. Test Loss: 2.216. Train Acc: 0.9608. Test Acc:0.6061
# Epoch: 690. Train Loss: 0.1681. Test Loss: 2.224. Train Acc: 0.9608. Test Acc:0.5455
# Epoch: 700. Train Loss: 0.1913. Test Loss: 2.288. Train Acc: 0.9412. Test Acc:0.6061
# Epoch: 710. Train Loss: 0.1549. Test Loss: 2.251. Train Acc: 0.9804. Test Acc:0.5455

# %%
# raw_features.keys()
# ['wav2vec_features-c', 'wav2vec_features-z', 'retrained-wav2vec_features-c', 'retrained-wav2vec_features-z']
